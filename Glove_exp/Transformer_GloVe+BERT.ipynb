# %%
import ast
from collections import Counter
from gensim import utils, matutils 
from gensim.corpora.dictionary import Dictionary
from gensim.utils import deprecated
import itertools
from nltk.corpus import stopwords
import numpy as np
from numpy import linalg as LA
from numpy.random import binomial
from numpy import dot, float32 as REAL, memmap as np_memmap, \
    double, array, zeros, vstack, sqrt, newaxis, integer, \
    ndarray, sum as np_sum, prod, argmax
from numpy.linalg import norm
import math, copy, time
import warnings 

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context(context="talk")
# %matplotlib inline

from keras import backend as K
from keras.models import load_model
from keras.preprocessing.sequence import pad_sequences
from keras import backend as K
import keras
from keras.utils import to_categorical
from keras.preprocessing import sequence
from keras.models import load_model

import os, sys, re, io, nltk, torch
import pandas as pd

from scipy import stats
from scipy.stats import bernoulli
from scipy.spatial import distance
from sklearn.utils.class_weight import compute_class_weight
from sklearn.utils import class_weight
from sklearn.preprocessing import Normalizer, normalize
from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import accuracy_score,f1_score, confusion_matrix, recall_score, precision_score

from six import string_types, integer_types
from six.moves import zip, range
if not sys.warnoptions:
    warnings.simplefilter("ignore")

from tqdm import tqdm, trange
import time
import transformers
from transformers import (
    WEIGHTS_NAME,
    AdamW,
    BertConfig,
    BertForMaskedLM,
    BertForSequenceClassification,
    BertTokenizer,
    CamembertConfig,
    CamembertForMaskedLM,
    CamembertTokenizer,
    DistilBertConfig,
    DistilBertForMaskedLM,
    DistilBertTokenizer,
    GPT2Config,
    GPT2LMHeadModel,
    GPT2Tokenizer,
    OpenAIGPTConfig,
    OpenAIGPTLMHeadModel,
    OpenAIGPTTokenizer,
    RobertaConfig,
    RobertaForMaskedLM,
    RobertaTokenizer,
    get_linear_schedule_with_warmup,
)

import torch.nn.functional as F
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler
from torch.autograd import Variable
import re
from nltk.corpus import stopwords
from nltk import WordNetLemmatizer
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.porter import *

stemmer_sn = SnowballStemmer("english")
stemmer = PorterStemmer()

stoplist = stopwords.words("english")
lemmatizer=WordNetLemmatizer()


'''
Compatible with tensorflow backend
gamma entre más alto más tolerante (queremos un gamma chico pero no demasiado! 0.25 - 5)
alpha pesos por clase (weights)
'''
def focal_loss(gamma=2., weights=1):   #weights np.asarray()
    weights= K.variable(weights)
    def focal_loss_fixed(y_true, y_pred):
        y_true = K.clip(y_true, K.epsilon(),1)
        y_pred = K.clip(y_pred,K.epsilon(),1)
        return - K.sum(weights* K.pow(1. - y_pred, gamma)* y_true * K.log(y_pred), axis=-1) 
    return focal_loss_fixed

keras.losses.focal_loss=keras.losses.MSE
keras.losses.focal_loss_fixed=keras.losses.MSE

n_gpu = torch.cuda.device_count()
torch.cuda.get_device_name(0)

if torch.cuda.is_available():     
    device = torch.device("cuda")
    print('There are',torch.cuda.device_count(),'GPU(s) available.')
    print('We will use the GPU:', torch.cuda.get_device_name(0))

else:
    print('No GPU available, using the CPU instead.')
    device = torch.device("cpu")

if not sys.warnoptions:
    warnings.simplefilter("ignore")
    
class Dummy_Embeddings(nn.Module):
    def __init__(self, d_model, dummy_vectors): 
        super(Dummy_Embeddings, self).__init__()
        aux = torch.from_numpy(dummy_vectors)#, dtype='float32'))
        self.index2dummy = nn.Embedding(aux.size()[0], d_model)
        self.index2dummy.weigth=nn.Parameter(aux)
        self.index2dummy.weigth.requires_grad=False
        self.d_model = d_model
        
    def forward(self, x):
        aux=x.numpy()
        #print ("aux original", aux)
        #print ("aux restado...",aux-np.ones(aux.shape))
        new_x= aux #- np.ones(aux.shape)
        new_x= torch.from_numpy(new_x)
        return self.index2dummy(new_x.long()) * math.sqrt(self.d_model) #debiese retornar matriz de batch_size x [ind_tw, k1,k2,k3,k4,k5,k6] (si son 6 modelos)
    
def match(objetos,ejemplo):
    i=0
    for obj in objetos:
        if obj==ejemplo:
            return i
        i+=1
        
def plot_confusion_matrix(cm, target_names, title='Confusion matrix (f1-score)',cmap=None, normalize=True):    
    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy
    if cmap is None:
        cmap = plt.get_cmap('Blues')
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        
    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap, vmin=0, vmax=1)
    plt.title(title)
    plt.colorbar()
    
    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)
    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()
    
    
class EncoderDecoderLogSoft(nn.Module):
    def __init__(self, encoder, src_embed, sequential):
        super(EncoderDecoderLogSoft, self).__init__()
        self.encoder = encoder
        self.linearSoft = sequential
        self.src_embed = src_embed
        
    def forward(self, src, src_mask):
        out=self.encode(src, src_mask)
        retorno=self.toSoftmax(out)
        return retorno
    
    def encode(self, src, src_mask):
        return self.encoder(self.src_embed(src), src_mask)
    
    def toSoftmax(self, tensor):
        a=tensor.size()[0]
        b=tensor.size()[-1]
        c=tensor.size()[-2]
        new_tensor= np.zeros((a, b))
        ini=True
        for ai in range(a):
            for ci in range(c):
                if ini:
                    new_tensor[ai]=tensor.data[ai][ci].numpy()
                    ini=False
                else: 
                    new_tensor[ai]*=tensor.data[ai][ci].numpy()
            ini=True
        new_tensor=torch.from_numpy(new_tensor)
        lineal=self.linearSoft(new_tensor.float())
        return F.log_softmax(lineal, dim = -1)
    
    def decode(self, memory, src_mask, tgt, tgt_mask):
        return self.decoder(self.tgt_embed(tgt), memory, src_mask, tgt_mask)
    
def clones(module, N):
    return nn.ModuleList([copy.deepcopy(module) for _ in range(N)])


class EncoderDecoderSoft(nn.Module):
    def __init__(self, encoder, src_embed, sequential):
        super(EncoderDecoderSoft, self).__init__()
        self.encoder = encoder
        self.linearSoft = sequential
        self.src_embed = src_embed
        
    def forward(self, src, src_mask):
        out=self.encode(src, src_mask)
        retorno=self.toSoftmax(out)
        return retorno
    
    def encode(self, src, src_mask):
        return self.encoder(self.src_embed(src), src_mask)
    
    def toSoftmax(self, tensor):
        a=tensor.size()[0]
        b=tensor.size()[-1]
        c=tensor.size()[-2]
        new_tensor= np.zeros((a, b))
        ini=True
        for ai in range(a):
            for ci in range(c):
                if ini:
                    new_tensor[ai]=tensor.data[ai][ci].numpy()
                    ini=False
                else: 
                    new_tensor[ai]*=tensor.data[ai][ci].numpy()
            ini=True
            
        new_tensor=torch.from_numpy(new_tensor)
        lineal=self.linearSoft(new_tensor.float())
        return F.softmax(lineal, dim = -1)
    
    def decode(self, memory, src_mask, tgt, tgt_mask):
        return self.decoder(self.tgt_embed(tgt), memory, src_mask, tgt_mask)
    
def clones(module, N):
    return nn.ModuleList([copy.deepcopy(module) for _ in range(N)])

class EncoderDecoder(nn.Module):
    def __init__(self, encoder, src_embed, generator):
        super(EncoderDecoder, self).__init__()
        self.encoder = encoder
        self.src_embed = src_embed
        self.generator = generator
        
    def forward(self, src, src_mask):
        return  self.encode(src, src_mask)

    def encode(self, src, src_mask):
        return self.encoder(self.src_embed(src), src_mask)
    
    def decode(self, memory, src_mask, tgt, tgt_mask):
        return self.decoder(self.tgt_embed(tgt), memory, src_mask, tgt_mask)
    
class Encoder(nn.Module):
    def __init__(self, layer, N):
        super(Encoder, self).__init__()
        self.layers = clones(layer, N)
        self.norm = LayerNorm(layer.size)
        
    def forward(self, x, mask):
        for layer in self.layers:
            x = layer(x, mask)
        return self.norm(x)
    
class LayerNorm(nn.Module):
    def __init__(self, features, eps=1e-6):
        super(LayerNorm, self).__init__()
        self.a_2 = nn.Parameter(torch.ones(features))
        self.b_2 = nn.Parameter(torch.zeros(features))
        self.eps = eps

    def forward(self, x):
        mean = x.mean(-1, keepdim=True)
        std = x.std(-1, keepdim=True)
        return self.a_2 * (x - mean) / (std + self.eps) + self.b_2
    
class SublayerConnection(nn.Module):
    def __init__(self, size, dropout):
        super(SublayerConnection, self).__init__()
        self.norm = LayerNorm(size)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, sublayer):
        return x + self.dropout(sublayer(self.norm(x)))    
    
class EncoderLayer(nn.Module):
    def __init__(self, size, self_attn, feed_forward, dropout):
        super(EncoderLayer, self).__init__()
        self.self_attn = self_attn
        self.feed_forward = feed_forward
        self.sublayer = clones(SublayerConnection(size, dropout), 2)
        self.size = size

    def forward(self, x, mask):
        x = self.sublayer[0](x, lambda x: self.self_attn(x, x, x, mask))
        return self.sublayer[1](x, self.feed_forward)
    
def subsequent_mask(size):
    attn_shape = (1, size, size)
    subsequent_mask = np.triu(np.ones(attn_shape), k=1).astype('uint8')
    return torch.from_numpy(subsequent_mask) == 0

class Generator(nn.Module):
    def __init__(self, d_model, vocab):
        super(Generator, self).__init__()
        self.proj = nn.Linear(d_model, vocab)

    def forward(self, x):
        return F.log_softmax(self.proj(x), dim=-1)
    
def attention(query, key, value, mask=None, dropout=None):
    d_k = query.size(-1)
    scores = torch.matmul(query, key.transpose(-2, -1)) \
             / math.sqrt(d_k)
    if mask is not None:
        scores = scores.masked_fill(mask == 0, -1e9)
    p_attn = F.softmax(scores, dim = -1)
    if dropout is not None:
        p_attn = dropout(p_attn)
    return torch.matmul(p_attn, value), p_attn

class MultiHeadedAttention(nn.Module):
    def __init__(self, h, d_model, dropout=0.1):
        super(MultiHeadedAttention, self).__init__()
        assert d_model % h == 0
        self.d_k = d_model // h
        self.h = h
        self.linears = clones(nn.Linear(d_model, d_model), 4)
        self.attn = None
        self.dropout = nn.Dropout(p=dropout)
        
    def forward(self, query, key, value, mask=None):
        #print ("mask para attn...", mask)
        if mask is not None:
            mask = mask.unsqueeze(1)
        nbatches = query.size(0)
        
        query, key, value = \
            [l(x).view(nbatches, -1, self.h, self.d_k).transpose(1, 2)
             for l, x in zip(self.linears, (query, key, value))]
         
        x, self.attn = attention(query, key, value, mask=mask, 
                                 dropout=self.dropout)
        
        x = x.transpose(1, 2).contiguous() \
             .view(nbatches, -1, self.h * self.d_k)
        return self.linears[-1](x)
    
class PositionalText(nn.Module):
    def __init__(self, d_model, dropout, max_len=50):
        super(PositionalText, self).__init__()
        self.dropout = nn.Dropout(p=dropout)
        
    def forward(self, x):
        x_text=x.data[:,0][:,None,:]
        x_machines=x.data[:,1:]
        
        x_return = x_machines* x_text
        return self.dropout(x_return)
    
class PositionalText_concat(nn.Module):
    def __init__(self, d_model, dropout, max_len=50):
        super(PositionalText_concat, self).__init__()
        self.dropout = nn.Dropout(p=dropout)
        
    def forward(self, x):
        return self.dropout(x)   

    
global max_src_in_batch, max_tgt_in_batch

def batch_size_fn(new, count, sofar):
    global max_src_in_batch, max_tgt_in_batch
    if count == 1:
        max_src_in_batch = 0
        max_tgt_in_batch = 0
    max_src_in_batch = max(max_src_in_batch,  len(new.src))
    max_tgt_in_batch = max(max_tgt_in_batch,  len(new.trg) + 2)
    src_elements = count * max_src_in_batch
    tgt_elements = count * max_tgt_in_batch
    maximo=max(src_elements, tgt_elements)
    return maximo

class NoamOpt:
    "Optim wrapper that implements rate."
    def __init__(self, model_size, factor, warmup, optimizer):
        self.optimizer = optimizer
        self._step = 0
        self.warmup = warmup
        self.factor = factor
        self.model_size = model_size
        self._rate = 0
        
    def step(self):
        "Update parameters and rate"
        self._step += 1
        rate = self.rate()
        for p in self.optimizer.param_groups:
            p['lr'] = rate
        self._rate = rate
        #print ("Rate de Noam_opt", self._rate, self._step)
        self.optimizer.step()
        
    def rate(self, step = None):
        "Implement `lrate` above"
        if step is None:
            step = self._step
        return self.factor * \
            (self.model_size ** (-0.5) *
            min(step ** (-0.5), step * self.warmup ** (-1.5)))
        
def get_std_opt(model):
    return NoamOpt(model.src_embed[0].d_model, 2, 4000,
            torch.optim.Adam(model.parameters(), lr=0, betas=(0.9, 0.98), eps=1e-9))

class LabelSmoothing(nn.Module):
    "Implement label smoothing."
    def __init__(self, size, padding_idx, smoothing=0.0):
        super(LabelSmoothing, self).__init__()
        self.criterion = nn.KLDivLoss(size_average=False)
        self.padding_idx = padding_idx
        self.confidence = 1.0 - smoothing
        self.smoothing = smoothing
        self.size = size
        self.true_dist = None
        
    def forward(self, x, target):
        assert x.size(1) == self.size
        true_dist = x.data.clone()
        true_dist.fill_(self.smoothing / (self.size - 2))
        true_dist.scatter_(1, target.data.unsqueeze(1), self.confidence)
        mask = torch.nonzero(target.data == self.padding_idx)
        self.true_dist = true_dist
        return self.criterion(x, Variable(true_dist, requires_grad=False))
    
class LabelCCE(nn.Module):
    def __init__(self, class_weights):
        super(LabelCCE, self).__init__()
        self.criterion = nn.CrossEntropyLoss(weight=class_weights)
                       
    def forward(self, x, target):
        return self.criterion(x, target)
    
class FocalLoss(nn.Module):
    def __init__(self, weights, gamma=2.0, reduce=True):#, logits=False, reduce=True):
        super(FocalLoss, self).__init__()
        self.weights = weights
        self.gamma = gamma
        #self.logits = logits
        self.reduce = reduce

    def forward(self, x, y):
        tensors = []
        for l in y:
            tensors.append(torch.zeros(4).scatter_(0, torch.tensor(l), 1))
        result = torch.stack(tensors, 0)
        
        CCE_loss = F.cross_entropy(x, result.long().argmax(dim=-1), reduction='none', weight=self.weights.float())
        pt = torch.exp(-CCE_loss)
        factor= (1-pt)**self.gamma * CCE_loss
        
        F_loss = factor  #*self.weights.float()-- peso esta dentro de la funcion

        if self.reduce:
            return torch.mean(F_loss)
        else:
            return F_loss
        
class SimpleLossComputeFL:
    "A simple loss compute and train function."
    def __init__(self, criterion, opt=None):
        self.criterion = criterion
        self.opt = opt
        
    def __call__(self, x, y, norm, mode):
        y_new=(y.float()-torch.ones((y.shape))).int() 
        #print ("nuevo Y en simplelosscompute", y_new, "antes era", y)
        # ahora
        #y_new=(y.float()).int()
        ac=accuracy_scorer(x, y_new)
        f1=f_scorer(x, y_new)
        cm=compute_confusion_matrix(x, y_new)
        tempa= x.contiguous().view(-1, x.size(-1))
        tempb= y_new.long().contiguous().view(-1)
        loss = self.criterion(tempa, tempb) #/ norm
        if mode!='Test':
            loss.backward()
        if self.opt is not None:
            self.opt.step()
            self.opt.optimizer.zero_grad()
        return [loss.data, ac ,f1, cm] #*norm #[0] * norm
    
class PositionwiseFeedForward(nn.Module):
    "Implements FFN equation."
    def __init__(self, d_model, d_ff, dropout=0.1):
        super(PositionwiseFeedForward, self).__init__()
        self.w_1 = nn.Linear(d_model, d_ff)
        self.w_2 = nn.Linear(d_ff, d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        return self.w_2(self.dropout(F.relu(self.w_1(x))))
    
def accuracy_scorer(predicho, target):
    predicho= torch.argmax(predicho, dim=1)
    return accuracy_score(target.numpy(),predicho.numpy())

def f_scorer(predicho, target):
    predicho= torch.argmax(predicho, dim=1)
    return f1_score(target.numpy(),predicho.numpy(), average=None, labels=[0,1,2,3])

def compute_confusion_matrix(predicho, target):
    predicho= torch.argmax(predicho, dim=1)
    return confusion_matrix(target.numpy(), predicho.numpy(), labels=[0,1,2,3])

def data_gen(batch_size,mode,n_machines,new_matrix):  
    """ESTA FUNCION DEBERÁ RETORNAR MATRICES DE TAMAÑO BATCH_SIZE * TW,M1,M2,M3,M4,M5,M6
    CADA EJEMPLO DEBERÁ SER ESTILO [ID_T, 1,2,1,2,1,2] SIENDO 1 CUANDO LA CLASE PREDICHA ES LA 0
    2 PARA CLASE PREDICHA 1, ETC. ID_T DEBEŔA INICIAR EN 5 PARA REFERIRSE AL PRIMER TW (EL PRIMERO DE TRAIN)"""
    x_data=[] 
    y_data=[]
    if mode=='Train':
        max_objs=matrix.shape[1]
        x_list=np.arange(max_objs)
        np.random.shuffle(x_list)        #indices desordenados de seccion train
        objs=ids_train
        labels=etiq     #np.load("matrices/y_train_num_4.npy")
        labels=np.asarray(labels) #+ np.ones(labels.shape),dtype='uint8')
    if mode=='Val':
        max_objs=matrix_val.shape[1] 
        x_list=np.arange(max_objs)
        x_list=[x+matrix.shape[1] for x in x_list]   
        np.random.shuffle(x_list)        #indices desordenados de seccion val
        objs=val['Tw_id']    #df_val['Unnamed: 0'].values        
        labels=np.asarray(etiq_v)     #np.load("matrices/y_val_num_4.npy")
        labels=np.asarray(labels) #+ np.ones(labels.shape),dtype='uint8') 
    if mode=='Test':
        max_objs=matrix_test.shape[1] 
        x_list=np.arange(max_objs)
        x_list=[x+matrix.shape[1]+matrix_val.shape[1] for x in x_list]
        total=matrix.shape[1]+matrix_val.shape[1]
        objs=test['Tw_id']     #np.arange(total, total+max_objs)
        
    #----------------------------------- COMPLETA MINI BATCHES ----------------------    
    if len(x_list)%batch_size==0:
        n_batches=len(x_list)/batch_size
        for nb in range(n_batches): 
            x_data.append(x_list[nb*batch_size:(nb+1)*batch_size])
    else:
        n_batches=int(len(x_list)/batch_size)
        resto=int(len(x_list)-n_batches*batch_size)
        to_repeat=batch_size-resto        
        for nb in range(n_batches): 
            x_data.append(x_list[nb*batch_size:(nb+1)*batch_size])
        cola=list(x_list[(nb+1)*batch_size:])
        for i in range(to_repeat):
            indice= np.random.randint(len(x_list))
            cola.append(x_list[indice])
        x_data.append(np.asarray(cola))
        if mode=='Test':
            print ("SE TUVIERON QUE REPETIR", to_repeat, "EJEMPLOS")
    #print ("los indices de train k voy a acceder random son", x_data[0])
            
    #-------------------------------- CONSTRUCCION MINI BATCHES (X,Y)----------------------   
    new_x_data=[] 
    for batch in x_data:
        #print ("transformando batch", batch)
        temp=[]
        for pos in batch:
            #print("en especifico el numerito", pos)
            temp2=[index_embeddings[pos+5]]#fromId2num[objs[exam]]] ### obj evaluado en maquinas  
            #print ("me dice que es el embed en index", temp2)
            for m in range(n_machines): 
                #print ("machine ",m,"dice:", np.argmax(new_matrix[m][pos])+1)
                temp2= temp2 + [np.argmax(new_matrix[m][pos])+1] 
                #matrix[4][cosa-5])+1)
            temp.append(temp2)
        new_x_data.append(temp)   

    if mode=='Train' or mode=='Val':    
        y_data=[]
        for conjunto in range(len(new_x_data)):
            batch=new_x_data[conjunto]
            temp_y=[]
            for linea in range(len(batch)):
                indice=x_data[conjunto][linea]  #pos
                lab=d_lab[lab_str_embeddings[indice+5]]+1 #labels_train
                temp_y.append([lab])       
            y_data.append(temp_y)
            
        y_data=np.asarray(y_data)
        
    new_x_data=np.asarray(new_x_data)
    #print ("primer batch X.Y", new_x_data[0], y_data[0])
    if mode=='Test':
        for x in new_x_data:
            src = Variable(torch.from_numpy(np.asarray(x)), requires_grad=False)
            yield Batch(src, None, 0)        
    else:          
        for x,y in zip(new_x_data, y_data):
            src = Variable(torch.from_numpy(np.asarray(x)), requires_grad=False)
            har = Variable(torch.from_numpy(np.asarray(y)), requires_grad=False)
            yield Batch(src, har, 0)
            

def make_model_concat(target, N=2, d_model=768, d_ff=1024, h=4, dropout=0.3, soft=True):  #recibir src_vocab si lo utiliza dummy_Emb
    c = copy.deepcopy
    attn = MultiHeadedAttention(h, d_model)
    ff = PositionwiseFeedForward(d_model, d_ff, dropout)
    position = PositionalText_concat(d_model, dropout)
    if soft:
        print ("Creando modelo con salida Softmax")
        model = EncoderDecoderSoft(
            Encoder(EncoderLayer(d_model, c(attn), c(ff), dropout), N),
            nn.Sequential(Dummy_Embeddings(768, K_list_new), c(position)),
            nn.Linear(d_model, 4))
    else:
        print ("")
        print ("Creando modelo con salida Log_softmax")
        model = EncoderDecoderLogSoft(
            Encoder(EncoderLayer(d_model, c(attn), c(ff), dropout), N),
            nn.Sequential(Dummy_Embeddings(768, K_list_new), c(position)),
            nn.Linear(d_model, 4))

    for p in model.parameters():
        if p.dim() > 1:
            nn.init.xavier_uniform(p)
    return model

class Batch:
    def __init__(self, src, trg=None, pad=0):
        self.src = src
        self.src_mask = (src != pad).unsqueeze(-2)
        if trg is not None:
            self.trg = trg[:, :]
            self.trg_y = trg[:, 0:]
            self.trg_mask = \
                self.make_std_mask(self.trg, pad)
            self.ntokens = (self.trg_y != pad).data.sum()
            
    @staticmethod
    def make_std_mask(tgt, pad):
        tgt_mask = (tgt != pad).unsqueeze(-2)
        tgt_mask = tgt_mask & Variable(
            subsequent_mask(tgt.size(-1)).type_as(tgt_mask.data))
        return tgt_mask
    
def run_epoch(data_iter, model, loss_compute, mode):
    if mode=='Test':
        with torch.no_grad():
            start = time.time()
            pred_classes=[]
            for i, batch in enumerate(data_iter):
                #print ("batch.src_mask en run epoch", batch.src_mask)
                out = model.forward(batch.src, batch.src_mask)
                pred_classes.append(out.argmax(dim=-1).numpy())
                #la loss del batch es sobre todos los ejemplos o es promedio en batch?
            return pred_classes
    
    else:
        start = time.time()
        total_learners = 0
        total_datos = 0
        total_loss = 0
        total_acc=0
        total_fm1=0
        total_fs=0
        n_batches = 0
        cm_last=np.zeros((4,4))
        for i, batch in enumerate(data_iter):
            #print ("BATCH\n", i, '\n', batch.src)
            out = model.forward(batch.src, batch.src_mask)
            loss,acc,f1,cm = loss_compute(out, batch.trg_y, batch.ntokens, mode)
            cm_last+=cm
            f_ma=np.mean(f1)
            total_loss += loss
            total_acc += np.array(acc)
            total_fm1 += np.sum(f1)/4.0    #4 clases (macro)
            total_fs += f1                 #none  
            total_datos += batch.ntokens
            n_batches += 1
        return total_loss/n_batches, torch.from_numpy(np.array(total_acc))/n_batches, torch.from_numpy(np.array(total_fm1))/n_batches, torch.from_numpy(np.array(total_fs))/n_batches, cm_last

emoji_pattern = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags=re.UNICODE)

def cleaner(post): 
    #re.sub(r'([a-z])\1+', r'\1', "user i think that ' s all you loooooove ")
    s= re.sub(r"http\S+", " html ", post)   ##########elimina http    
    s= re.sub(r'#\w+ ?', " hashtag ", s) ########3
    s= re.sub(r'@\w+ ?', " user ", s)##############    
    s= s.lower()
    s=emoji_pattern.sub(r'', s)
    s=re.sub(r"'\b", " ' ", s)
    s=re.sub(r"\b'\b", " ' ", s)
    s=re.sub(r"“\b", " “ ", s)
    #“
    s=re.sub(r"\b’", " ’ ", s)
    s=re.sub(r"‘\b", " ‘ ", s)
    s=re.sub(r"\b’\b", " ‘ ", s)
    s = re.sub(r"-", " - ", s)
    s = re.sub(r"\(", " ", s)
    s = re.sub(r"\)", " ", s)
    s = re.sub(r"\?", " ? ", s)    
    s = re.sub(r"\/", " ", s)
    s = re.sub(r"' ", " ' ", s)
    s = re.sub(r" '", " ' ", s)
    s = re.sub(r"\!", " ! ", s)
    s=re.sub("[\.]+", " . ", s)
    s=re.sub("[\,]+", " , ", s)
    s=re.sub("[\;]+", " ; ", s)
    s=re.sub("[\:]+", " : ", s)
    s=re.sub('[\"]+', ' " ', s)
    s=re.sub(r'\b[0-9]\b', " number ",  s)
    s=re.sub(r'\b[0-9]*[0-9]\b', " number ",  s)    
    s=re.sub(r'\b”', ' " ', s)
    sl= list(s.split())
    sl_2=[]
    for wd in sl:
        try: 
            q=Word2Index[wd]
            sl_2.append(wd)
        except:
            try: 
                if stemmer.stem(wd) in Word2Index.keys():
                    sl_2.append(stemmer.stem(wd))
                elif lemmatizer.lemmatize(wd) in Word2Index.keys():
                    sl_2.append(lemmatizer.lemmatize(wd))
                else:
                    sl_2.append(wd)
            except:
                sl_2.append(wd)
    sl=sl_2
    s=' '.join([word for word in sl])# if word not in stoplist])
    return s, sl

embeddings_index = {}
f = open(os.path.join("glove.twitter.27B.200d.txt"))#'glove.twitter.27B.100d.txt'))
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

print('Se encontraron %s terminos con sus vectores de embedding.' % len(embeddings_index))
# Out:
# Using TensorFlow backend.
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# There are 1 GPU(s) available.
# We will use the GPU: GeForce GTX 1060 6GB
# Se encontraron 1193514 terminos con sus vectores de embedding.

# %%
dict_cl=dict()
dict_cl[0]='support'
dict_cl[1]='denying'
dict_cl[2]='questioning'
dict_cl[3]='commenting'

#sdqc
d_lab=dict()
d_lab["support"]=0
d_lab["denying"]=1
d_lab["questioning"]=2
d_lab["commenting"]=3

train =pd.read_csv("../Tesis_exp/Fine-Tuning/CSV_Stance/train_semeval_raw.csv")
val=pd.read_csv("../Tesis_exp/Fine-Tuning/CSV_Stance/dev_semeval_raw.csv")
test=pd.read_csv("../Tesis_exp/Fine-Tuning/CSV_Stance/test_semeval_raw.csv")


word_index=dict()
j=1
for frase in train["Tweet"].values:
    frase=cleaner(frase)[-1]
    #print (frase)
    for term in frase:
        if term not in word_index.keys():
            word_index[term]=j
            j+=1

for frase in val["Tweet"].values:
    frase=cleaner(frase)[-1]
    #print (frase)
    for term in frase:
        if term not in word_index.keys():
            word_index[term]=j
            j+=1
            
for frase in test["Tweet"].values:
    frase=cleaner(frase)[-1]
    #print (frase)
    for term in frase:
        if term not in word_index.keys():
            word_index[term]=j
            j+=1
            
len(word_index.keys())
# Out:
# 7236

# %%
not_found=[]
pos_tag_nf=[]
Word2Index={}
idx_2_token={}

g_dim=200
emb_matrix = np.zeros((len(word_index.keys())+1, g_dim))  

for word, i in word_index.items():
    vector = embeddings_index.get(word)
    if vector is not None:
        # words sin match en Glove, serán vectores de ceros.
        emb_matrix[i] = vector
        Word2Index[word]=i
        idx_2_token[i]=word
    else:
        Word2Index[word]=i
        idx_2_token[i]=word
        not_found.append(word)
        pos_tag_nf.append(nltk.pos_tag([word])[0][-1])

# %%
transf = Normalizer().fit(emb_matrix) 
M_GLOVE_space=transf.transform(emb_matrix)

def my_tokenizer(lista):
    to_return=[]
    for l in lista:
        if l in word_index.keys():
            to_return.append(l)
        else:
            continue
    return to_return

def predict_data(trained, x_train, x_val, x_test, etiq, etiq_v, etiq_t, name_model):
    etiq = etiq.astype("int")
    trainPredict = trained.predict(x_train, batch_size=32)
    trainPredict=[np.argmax(pred) for pred in trainPredict]
    acc= accuracy_score(etiq, trainPredict)  
    f1=f1_score(etiq, trainPredict, average=None)  # labels=np.unique(trainPredict)
    f1_ma=f1_score(etiq, trainPredict, average='macro')  # labels=np.unique(trainPredict)
    #matriz=normalize(confusion_matrix(etiq, trainPredict))
    print ("")
    print ("Accuracy sobre Train", name_model, ":",acc)  
    print ("F1-score None sobre Train", name_model, ":",f1)
    print ("F1-score macro sobre Train", name_model, ":",f1_ma)
    ########################################
    trainPredict = trained.predict(x_val, batch_size=32)
    trainPredict=[np.argmax(pred) for pred in trainPredict]
    acc= accuracy_score(etiq_v, trainPredict)  
    f1=f1_score(etiq_v, trainPredict, average=None)  # labels=np.unique(trainPredict)
    f1_ma=f1_score(etiq_v, trainPredict, average='macro')  # labels=np.unique(trainPredict)
    #matriz=normalize(confusion_matrix(etiq_v, trainPredict))
    print ("")
    print ("Accuracy sobre Val", name_model, ":",acc)  
    print ("F1-score None sobre Val", name_model, ":",f1)
    print ("F1-score macro sobre Val", name_model, ":",f1_ma)
    ########################################
    trainPredict = trained.predict(x_test, batch_size=32)
    trainPredict=[np.argmax(pred) for pred in trainPredict]
    acc_t= accuracy_score(etiq_t, trainPredict)  
    f1_t=f1_score(etiq_t, trainPredict, average=None)  # labels=np.unique(trainPredict)
    f1_ma_t=f1_score(etiq_t, trainPredict, average='macro')  # labels=np.unique(trainPredict)
    matriz_t=normalize(confusion_matrix(etiq_t, trainPredict))
    print ("")
    print ("Accuracy sobre Test", name_model, ":",acc_t)  
    print ("F1-score None sobre Test", name_model, ":",f1_t)
    print ("F1-score macro sobre Test", name_model, ":",f1_ma_t)
    
    return f1_ma_t, f1_t, acc_t, matriz_t

# %%
from models import *

if not sys.warnoptions:
    warnings.simplefilter("ignore")
    
class Dummy_Embeddings(nn.Module):
    def __init__(self, d_model, dummy_vectors): 
        super(Dummy_Embeddings, self).__init__()
        aux = torch.from_numpy(dummy_vectors)#, dtype='float32'))
        self.index2dummy = nn.Embedding(aux.size()[0], d_model)
        self.index2dummy.weigth=nn.Parameter(aux)
        self.index2dummy.weigth.requires_grad=False
        self.d_model = d_model
        
    def forward(self, x):
        aux=x.numpy()
        #print ("aux original", aux)
        #print ("aux restado...",aux-np.ones(aux.shape))
        new_x= aux #- np.ones(aux.shape)
        new_x= torch.from_numpy(new_x)
        return self.index2dummy(new_x.long()) * math.sqrt(self.d_model) #debiese retornar matriz de batch_size x [ind_tw, k1,k2,k3,k4,k5,k6] (si son 6 modelos)
    
def match(objetos,ejemplo):
    i=0
    for obj in objetos:
        if obj==ejemplo:
            return i
        i+=1
        
def plot_confusion_matrix(cm, target_names, title='Confusion matrix (f1-score)',cmap=None, normalize=True):    
    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy
    if cmap is None:
        cmap = plt.get_cmap('Blues')
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        
    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap, vmin=0, vmax=1)
    plt.title(title)
    plt.colorbar()
    
    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)
    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()
    
MAX_LEN = 37

print ("Conteo por stance val\n", Counter(val['Label']))
print ("Conteo por stance test\n", Counter(test['Label']))
# Out:
# Conteo por stance val
#  Counter({'commenting': 173, 'support': 69, 'questioning': 28, 'denying': 11})
# Conteo por stance test
#  Counter({'commenting': 778, 'questioning': 106, 'denying': 69, 'support': 68})

# %%
ids_train=train['Tw_id']
tws_train=train['Tweet']
labels_train=[d_lab[lb] for lb in train['Label']]
#class_weights= compute_class_weight('balanced', np.unique(labels_train), labels_train)
class_weights= [1.0, 1.0, 1.0, 1.0]
class_weights=np.asarray(class_weights)
print ("Pesos de clases:", class_weights)
#print ("Pesos de clases:", class_weights)

etiq=labels_train.copy()
etiq=np.asarray(etiq)
sentences = tws_train
n_labels = np.array(etiq)
y_train=to_categorical(n_labels,num_classes=4)

input_ids=[]
for sent in sentences:
    sent_cl=cleaner(sent)[1]
    encoded_sent=[]
    for wd in sent_cl:
        try: 
            encoded_sent.append(Word2Index[wd])
        except: 
            continue   
    input_ids.append(encoded_sent)
    
input_ids = pad_sequences(input_ids,maxlen=MAX_LEN,dtype="long",value=0, truncating="post", padding="post")
shape=np.asarray(input_ids).shape
x_train=np.zeros((shape[0], shape[1], 200))
j=0
for in_id in input_ids:
    x_train[j]=M_GLOVE_space[in_id]
    j+=1
# Out:
# Pesos de clases: [1. 1. 1. 1.]

# %%
ids_val=val['Tw_id']
tws_val=val['Tweet']
labels_val=[d_lab[lb] for lb in val['Label']]

etiq_v=labels_val.copy()
etiq_v=np.asarray(etiq_v)
sentences_val = tws_val
n_labels_val = np.array(etiq_v)
y_val=to_categorical(n_labels_val,num_classes=4)

input_ids_val=[]
for sent in sentences_val:
    sent_cl=cleaner(sent)[1]
    encoded_sent=[]
    for wd in sent_cl:
        try: 
            encoded_sent.append(Word2Index[wd])
        except: 
            continue   
    input_ids_val.append(encoded_sent)
    
ids_test=test['Tw_id']
tws_test=test['Tweet']
labels_test=[d_lab[lb] for lb in test['Label']]

etiq_t=labels_test.copy()
etiq_t=np.asarray(etiq_t)
sentences_test = tws_test
n_labels_test = np.array(etiq_t)
y_test=to_categorical(n_labels_test,num_classes=4)

input_ids_test=[]
for sent in sentences_test:
    sent_cl=cleaner(sent)[1]
    encoded_sent=[]
    for wd in sent_cl:
        try: 
            encoded_sent.append(Word2Index[wd])
        except: 
            continue   
    input_ids_test.append(encoded_sent)
    
input_ids_val = pad_sequences(input_ids_val,maxlen=MAX_LEN,dtype="long",value=0, truncating="post", padding="post")
input_ids_test = pad_sequences(input_ids_test,maxlen=MAX_LEN,dtype="long",value=0, truncating="post", padding="post")


shape_val=np.asarray(input_ids_val).shape
x_val=np.zeros((shape_val[0], shape_val[1], 200))
i=0
for in_id in input_ids_val:
    x_val[i]=M_GLOVE_space[in_id]
    i+=1
    
shape_test=np.asarray(input_ids_test).shape
x_test=np.zeros((shape_test[0], shape_test[1], 200))
i=0
for in_id in input_ids_test:
    x_test[i]=M_GLOVE_space[in_id]
    i+=1

x_test.shape
# Out:
# (1021, 37, 200)

# %%
global_accs=[]
global_fnones=[]
global_fmacros=[]
global_cms=[]
global_attn=[]
dict_attn_enc={'00':[], '01':[], '02':[], '03':[], '10':[], '11':[], '12':[], '13':[]}
  
prob=0.0

for trans in range(1,6): 
    print ("Entrenando Run #", trans)
    cnn1 = load_model('../new_glove_augmented/stance_baselines/'+str(prob)+'/cnn1_'+str(trans)+'-exec.h5')
    cnn2 = load_model('../new_glove_augmented/stance_baselines/'+str(prob)+'/cnn2_'+str(trans)+'-exec.h5')
    rnn1 = load_model('../new_glove_augmented/stance_baselines/'+str(prob)+'/rnn1_'+str(trans)+'-exec.h5')
    rnn2 = load_model('../new_glove_augmented/stance_baselines/'+str(prob)+'/rnn2_'+str(trans)+'-exec.h5')
    rnn3 = load_model('../new_glove_augmented/stance_baselines/'+str(prob)+'/rnn3_'+str(trans)+'-exec.h5')

    list_models=['cnn1', 'cnn2', 'rnn1', 'rnn2', 'rnn3']
    index_models=np.arange(5)
    dict_models=dict((key, value) for (key, value) in zip(index_models,list_models))
    modelos=[cnn1, cnn2, rnn1, rnn2, rnn3]
    ind=np.arange(5)
    dict_trainedModel=dict((key, value) for (key, value) in zip(ind,modelos))

    bs=32
    predicciones_all=[]
    predicciones_all_val=[]
    predicciones_all_test=[]

    for i in dict_trainedModel.keys(): 
        a_evaluar=dict_models[i]
        predicciones_all.append(dict_trainedModel[i].predict(x_train, batch_size=bs))
    for i in dict_trainedModel.keys(): 
        a_evaluar=dict_models[i]
        predicciones_all_val.append(dict_trainedModel[i].predict(x_val, batch_size=bs))
    for i in dict_trainedModel.keys(): 
        a_evaluar=dict_models[i]
        predicciones_all_test.append(dict_trainedModel[i].predict(x_test, batch_size=bs))

    matrix=np.asarray(predicciones_all)
    matrix_val=np.asarray(predicciones_all_val)
    matrix_test=np.asarray(predicciones_all_test)
    new_matrix=np.concatenate([matrix,matrix_val,matrix_test], axis=1)
    
    espacio=[np.ones(768)]
    Ks=np.load("../../BERTransformer/Orthogonals_768.npy")
    random=np.random.randint(Ks.shape[0], size=4)
    K_list=Ks[random]
    K_list_ext=espacio+list(K_list)
    index_embeddings=[0,1,2,3,4]
    lab_str_embeddings=['','','','','']

    for i in range(len(labels_train)):
        folder='Original'
        ide=ids_train[i]
        clase=dict_cl[labels_train[i]]
        if ide<5000000:
            folder=clase #directorio a recuperar vector
            vector=np.load("../BaS_Original/"+str(prob)+"/"+str(trans)+"/"+folder+"/"+str(ide)+".npy")
        else:
            vector=np.load("../BaS_Original/"+folder+"/"+str(ide)+".npy")

        norm=np.linalg.norm(vector)
        vector= vector / norm
        index_embeddings.append(i+5)
        lab_str_embeddings.append(clase)
        K_list_ext.append(vector)

    objs_val=val['Tw_id']      #df_val['Unnamed: 0'].values
    objs_test=test['Tw_id']    #np.arange(df_test.shape[0])
    lab_val=val['Label']
    lab_test=test['Label']
    llaves=np.concatenate([objs_val,objs_test])
    clases=np.concatenate([lab_val,lab_test])

    for num in range(len(llaves)):
        i=llaves[num]
        clase=clases[num]
        vector=np.load("../BaS_Original/Original/"+str(i)+".npy")
        norm=np.linalg.norm(vector)
        vector= vector / norm
        index_embeddings.append(num+5+train.shape[0])
        lab_str_embeddings.append(clase)
        K_list_ext.append(vector)

    K_list_new= np.asarray(K_list_ext, dtype='float32')
    
    ###################################### TRANSFORMER ###############################
    V = 4
    pesos = torch.from_numpy(class_weights).float()
    criterion = FocalLoss(weights=pesos)
    model = make_model_concat(4, N=2,d_model=768, d_ff=128, h=4, dropout=0.35)
    model_opt = NoamOpt(model.src_embed[0].d_model, 1, 500, torch.optim.Adam(model.parameters(), lr=0, betas=(0.9, 0.98), eps=1e-5))

    
    for epoch in range(40):
        model.train()
        DATA=data_gen(32, 'Train', 5, new_matrix)
        loss_train, acc_train,fma_train, f_none, cm_train=run_epoch(DATA, model, SimpleLossComputeFL(criterion, model_opt), 'Train')
        
        model.eval()
        loss_val, acc_val,fma_val, f_val_none, cm_val=run_epoch(data_gen(bs, 'Val', 5, new_matrix), model, SimpleLossComputeFL(criterion, None),'Val')
        print ("Epoch",epoch, "\tacc_val:",acc_val, "\tF-macro_val:",fma_val)
    
    model.eval()
    print ("Testing run #",trans)
    predicciones = run_epoch(data_gen(bs, 'Test', 5, new_matrix), model, SimpleLossComputeFL(criterion, None),'Test')
    predicciones=np.concatenate(predicciones, axis=-1)
    
    glo_acc=accuracy_score(etiq_t, predicciones[:-3])
    glo_fno=f1_score(etiq_t,predicciones[:-3], average=None)
    glo_fma=f1_score(etiq_t,predicciones[:-3], average='macro')

    glo_cm=confusion_matrix(etiq_t, predicciones[:-3])

    plot_confusion_matrix(glo_cm,["support","Denying","Questioning","Commenting"],"Pre-trained Sin Aum 40-e Stance")
    global_accs.append(glo_acc)
    global_fnones.append(glo_fno)
    global_fmacros.append(glo_fma)
    global_cms.append(glo_cm)
    print("Test_ acc:",glo_acc) 
    print("Test_ f1 none:",glo_fno) 
    print("Test_ f1 macro:",glo_fma) 

    label=[['Text', 'm1', 'm2','m3','m4','m5']]
    for layer in range(2):
        fig, axs = plt.subplots(1,4, figsize=(20, 10))
        print ("Encoder Layer Attention head", layer)
        for head in range(4):
            matriz_attn=model.encoder.layers[layer].self_attn.attn[0,head].data
            dict_attn_enc[str(layer)+str(head)].append(matriz_attn)
            sns.heatmap(matriz_attn, xticklabels=label[0], yticklabels=label[0],
                        vmin=0.0, vmax=1.0, linewidths=.5, cmap="Blues", cbar=False, square=True, ax=axs[head]) #, annot=False,cbar_kws={"orientation": "horizontal","pad": 0.25})
        plt.show()
# Out:
# Entrenando Run # 1
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:Large dropout rate: 0.65 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.65 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:Large dropout rate: 0.65 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.65 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.65 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.6354, dtype=torch.float64) 	F-macro_val: tensor(0.3293, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.7014, dtype=torch.float64) 	F-macro_val: tensor(0.3834, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.7326, dtype=torch.float64) 	F-macro_val: tensor(0.5016, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.7361, dtype=torch.float64) 	F-macro_val: tensor(0.5622, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.7257, dtype=torch.float64) 	F-macro_val: tensor(0.5327, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.7257, dtype=torch.float64) 	F-macro_val: tensor(0.5473, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.7326, dtype=torch.float64) 	F-macro_val: tensor(0.5620, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.7361, dtype=torch.float64) 	F-macro_val: tensor(0.5519, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.7326, dtype=torch.float64) 	F-macro_val: tensor(0.5386, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.7361, dtype=torch.float64) 	F-macro_val: tensor(0.5729, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.7396, dtype=torch.float64) 	F-macro_val: tensor(0.5633, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.7292, dtype=torch.float64) 	F-macro_val: tensor(0.5623, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.7188, dtype=torch.float64) 	F-macro_val: tensor(0.5533, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.7188, dtype=torch.float64) 	F-macro_val: tensor(0.5315, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.7222, dtype=torch.float64) 	F-macro_val: tensor(0.5808, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.7292, dtype=torch.float64) 	F-macro_val: tensor(0.5522, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.7222, dtype=torch.float64) 	F-macro_val: tensor(0.5751, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.7257, dtype=torch.float64) 	F-macro_val: tensor(0.5453, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.7222, dtype=torch.float64) 	F-macro_val: tensor(0.5293, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.7188, dtype=torch.float64) 	F-macro_val: tensor(0.5215, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.7222, dtype=torch.float64) 	F-macro_val: tensor(0.5396, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.7222, dtype=torch.float64) 	F-macro_val: tensor(0.5529, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.7222, dtype=torch.float64) 	F-macro_val: tensor(0.5380, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.7153, dtype=torch.float64) 	F-macro_val: tensor(0.5373, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.7257, dtype=torch.float64) 	F-macro_val: tensor(0.5712, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.7292, dtype=torch.float64) 	F-macro_val: tensor(0.5300, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.7326, dtype=torch.float64) 	F-macro_val: tensor(0.5290, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.7361, dtype=torch.float64) 	F-macro_val: tensor(0.5659, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.7292, dtype=torch.float64) 	F-macro_val: tensor(0.5289, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.7292, dtype=torch.float64) 	F-macro_val: tensor(0.5515, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.7257, dtype=torch.float64) 	F-macro_val: tensor(0.5590, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.7257, dtype=torch.float64) 	F-macro_val: tensor(0.5379, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.7361, dtype=torch.float64) 	F-macro_val: tensor(0.5561, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.7326, dtype=torch.float64) 	F-macro_val: tensor(0.5646, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.7188, dtype=torch.float64) 	F-macro_val: tensor(0.5366, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.7188, dtype=torch.float64) 	F-macro_val: tensor(0.5582, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.7153, dtype=torch.float64) 	F-macro_val: tensor(0.5173, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.7222, dtype=torch.float64) 	F-macro_val: tensor(0.5584, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.5490, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.7292, dtype=torch.float64) 	F-macro_val: tensor(0.5414, dtype=torch.float64)
# Testing run # 1
# SE TUVIERON QUE REPETIR 3 EJEMPLOS
# Test_ acc: 0.7551420176297747
# Test_ f1 none: [0.04255319 0.23076923 0.62626263 0.85432099]
# Test_ f1 macro: 0.4384765090438849
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 2
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.6285, dtype=torch.float64) 	F-macro_val: tensor(0.2728, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.6701, dtype=torch.float64) 	F-macro_val: tensor(0.3474, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.6979, dtype=torch.float64) 	F-macro_val: tensor(0.4681, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.6771, dtype=torch.float64) 	F-macro_val: tensor(0.4680, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.5164, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.4867, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.7014, dtype=torch.float64) 	F-macro_val: tensor(0.4724, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.5169, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.7049, dtype=torch.float64) 	F-macro_val: tensor(0.4768, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.5152, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.6944, dtype=torch.float64) 	F-macro_val: tensor(0.4990, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.6944, dtype=torch.float64) 	F-macro_val: tensor(0.5134, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.6944, dtype=torch.float64) 	F-macro_val: tensor(0.4895, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.7049, dtype=torch.float64) 	F-macro_val: tensor(0.4631, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.7014, dtype=torch.float64) 	F-macro_val: tensor(0.4548, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.4654, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.7049, dtype=torch.float64) 	F-macro_val: tensor(0.4860, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.7014, dtype=torch.float64) 	F-macro_val: tensor(0.5135, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.5090, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.7014, dtype=torch.float64) 	F-macro_val: tensor(0.5130, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.4976, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.7014, dtype=torch.float64) 	F-macro_val: tensor(0.4871, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.6979, dtype=torch.float64) 	F-macro_val: tensor(0.4773, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.6944, dtype=torch.float64) 	F-macro_val: tensor(0.4770, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.7049, dtype=torch.float64) 	F-macro_val: tensor(0.4791, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.7049, dtype=torch.float64) 	F-macro_val: tensor(0.5361, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.4686, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.4986, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.6979, dtype=torch.float64) 	F-macro_val: tensor(0.5062, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.4873, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.4514, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.7014, dtype=torch.float64) 	F-macro_val: tensor(0.4765, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.7014, dtype=torch.float64) 	F-macro_val: tensor(0.4907, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.7049, dtype=torch.float64) 	F-macro_val: tensor(0.5149, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.7014, dtype=torch.float64) 	F-macro_val: tensor(0.5045, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.4952, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.7049, dtype=torch.float64) 	F-macro_val: tensor(0.5051, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.7049, dtype=torch.float64) 	F-macro_val: tensor(0.4741, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.7014, dtype=torch.float64) 	F-macro_val: tensor(0.4865, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.5179, dtype=torch.float64)
# Testing run # 2
# SE TUVIERON QUE REPETIR 3 EJEMPLOS
# Test_ acc: 0.752203721841332
# Test_ f1 none: [0.06741573 0.12389381 0.55172414 0.85234094]
# Test_ f1 macro: 0.3988436524880994
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 3
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.5139, dtype=torch.float64) 	F-macro_val: tensor(0.3961, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.7014, dtype=torch.float64) 	F-macro_val: tensor(0.4191, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.7014, dtype=torch.float64) 	F-macro_val: tensor(0.4426, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.6979, dtype=torch.float64) 	F-macro_val: tensor(0.4438, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.6875, dtype=torch.float64) 	F-macro_val: tensor(0.4290, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.6840, dtype=torch.float64) 	F-macro_val: tensor(0.4209, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.6910, dtype=torch.float64) 	F-macro_val: tensor(0.4381, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.6910, dtype=torch.float64) 	F-macro_val: tensor(0.4360, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.6875, dtype=torch.float64) 	F-macro_val: tensor(0.4565, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.6910, dtype=torch.float64) 	F-macro_val: tensor(0.4608, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.6979, dtype=torch.float64) 	F-macro_val: tensor(0.4693, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.7049, dtype=torch.float64) 	F-macro_val: tensor(0.4686, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.6979, dtype=torch.float64) 	F-macro_val: tensor(0.4429, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.7014, dtype=torch.float64) 	F-macro_val: tensor(0.4688, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.4650, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.6979, dtype=torch.float64) 	F-macro_val: tensor(0.4529, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.6944, dtype=torch.float64) 	F-macro_val: tensor(0.4752, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.6840, dtype=torch.float64) 	F-macro_val: tensor(0.4771, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.6875, dtype=torch.float64) 	F-macro_val: tensor(0.4880, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.6875, dtype=torch.float64) 	F-macro_val: tensor(0.4687, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.6910, dtype=torch.float64) 	F-macro_val: tensor(0.4865, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.4892, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.4994, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.7049, dtype=torch.float64) 	F-macro_val: tensor(0.4792, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.7153, dtype=torch.float64) 	F-macro_val: tensor(0.5533, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.4769, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.6979, dtype=torch.float64) 	F-macro_val: tensor(0.5036, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.6875, dtype=torch.float64) 	F-macro_val: tensor(0.4768, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.6979, dtype=torch.float64) 	F-macro_val: tensor(0.4675, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.4751, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.6979, dtype=torch.float64) 	F-macro_val: tensor(0.4716, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.6944, dtype=torch.float64) 	F-macro_val: tensor(0.4714, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.6979, dtype=torch.float64) 	F-macro_val: tensor(0.4858, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.6944, dtype=torch.float64) 	F-macro_val: tensor(0.4572, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.4953, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.5092, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.7153, dtype=torch.float64) 	F-macro_val: tensor(0.4894, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.7014, dtype=torch.float64) 	F-macro_val: tensor(0.4729, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.4870, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.4511, dtype=torch.float64)
# Testing run # 3
# SE TUVIERON QUE REPETIR 3 EJEMPLOS
# Test_ acc: 0.7629774730656219
# Test_ f1 none: [0.06818182 0.19607843 0.48780488 0.86018957]
# Test_ f1 macro: 0.40306367526571585
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 4
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.6840, dtype=torch.float64) 	F-macro_val: tensor(0.3475, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.6979, dtype=torch.float64) 	F-macro_val: tensor(0.3955, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.4682, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.7014, dtype=torch.float64) 	F-macro_val: tensor(0.4643, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.4486, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.7153, dtype=torch.float64) 	F-macro_val: tensor(0.4820, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.4861, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.4775, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.7049, dtype=torch.float64) 	F-macro_val: tensor(0.4539, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.4795, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.4444, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.4755, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.4918, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.4919, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.7049, dtype=torch.float64) 	F-macro_val: tensor(0.5005, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.6979, dtype=torch.float64) 	F-macro_val: tensor(0.4823, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.7049, dtype=torch.float64) 	F-macro_val: tensor(0.4830, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.4763, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.7153, dtype=torch.float64) 	F-macro_val: tensor(0.4767, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.7049, dtype=torch.float64) 	F-macro_val: tensor(0.4732, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.4661, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.4835, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.4935, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.4895, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.7153, dtype=torch.float64) 	F-macro_val: tensor(0.5155, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.6979, dtype=torch.float64) 	F-macro_val: tensor(0.4714, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.4672, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.4644, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.7049, dtype=torch.float64) 	F-macro_val: tensor(0.4710, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.4906, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.4813, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.7014, dtype=torch.float64) 	F-macro_val: tensor(0.4552, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.7049, dtype=torch.float64) 	F-macro_val: tensor(0.5160, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.4921, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.7049, dtype=torch.float64) 	F-macro_val: tensor(0.4980, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.7014, dtype=torch.float64) 	F-macro_val: tensor(0.5063, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.4823, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.4938, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.7049, dtype=torch.float64) 	F-macro_val: tensor(0.4663, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.7049, dtype=torch.float64) 	F-macro_val: tensor(0.4881, dtype=torch.float64)
# Testing run # 4
# SE TUVIERON QUE REPETIR 3 EJEMPLOS
# Test_ acc: 0.7531831537708129
# Test_ f1 none: [0.13445378 0.18556701 0.54748603 0.85367335]
# Test_ f1 macro: 0.43029504270451513
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 5
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.4757, dtype=torch.float64) 	F-macro_val: tensor(0.2353, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.6424, dtype=torch.float64) 	F-macro_val: tensor(0.2883, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.4434, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.4775, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.7292, dtype=torch.float64) 	F-macro_val: tensor(0.4856, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.7257, dtype=torch.float64) 	F-macro_val: tensor(0.4807, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.7326, dtype=torch.float64) 	F-macro_val: tensor(0.4626, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.7396, dtype=torch.float64) 	F-macro_val: tensor(0.4631, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.7292, dtype=torch.float64) 	F-macro_val: tensor(0.4860, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.7326, dtype=torch.float64) 	F-macro_val: tensor(0.4867, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.7326, dtype=torch.float64) 	F-macro_val: tensor(0.5039, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.7292, dtype=torch.float64) 	F-macro_val: tensor(0.4910, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.7188, dtype=torch.float64) 	F-macro_val: tensor(0.5063, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.7222, dtype=torch.float64) 	F-macro_val: tensor(0.4758, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.7326, dtype=torch.float64) 	F-macro_val: tensor(0.5190, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.7292, dtype=torch.float64) 	F-macro_val: tensor(0.5241, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.7326, dtype=torch.float64) 	F-macro_val: tensor(0.5240, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.7326, dtype=torch.float64) 	F-macro_val: tensor(0.4934, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.7396, dtype=torch.float64) 	F-macro_val: tensor(0.4812, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.7361, dtype=torch.float64) 	F-macro_val: tensor(0.5050, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.7396, dtype=torch.float64) 	F-macro_val: tensor(0.5171, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.7326, dtype=torch.float64) 	F-macro_val: tensor(0.5218, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.7396, dtype=torch.float64) 	F-macro_val: tensor(0.5216, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.7431, dtype=torch.float64) 	F-macro_val: tensor(0.5193, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.7465, dtype=torch.float64) 	F-macro_val: tensor(0.5188, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.7326, dtype=torch.float64) 	F-macro_val: tensor(0.5061, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.7396, dtype=torch.float64) 	F-macro_val: tensor(0.5105, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.7292, dtype=torch.float64) 	F-macro_val: tensor(0.5203, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.7465, dtype=torch.float64) 	F-macro_val: tensor(0.4901, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.7396, dtype=torch.float64) 	F-macro_val: tensor(0.5002, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.7326, dtype=torch.float64) 	F-macro_val: tensor(0.5092, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.7500, dtype=torch.float64) 	F-macro_val: tensor(0.5617, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.7500, dtype=torch.float64) 	F-macro_val: tensor(0.5292, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.7500, dtype=torch.float64) 	F-macro_val: tensor(0.5138, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.7535, dtype=torch.float64) 	F-macro_val: tensor(0.5383, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.7569, dtype=torch.float64) 	F-macro_val: tensor(0.5480, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.7396, dtype=torch.float64) 	F-macro_val: tensor(0.5230, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.7431, dtype=torch.float64) 	F-macro_val: tensor(0.4819, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.7500, dtype=torch.float64) 	F-macro_val: tensor(0.4905, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.7500, dtype=torch.float64) 	F-macro_val: tensor(0.5490, dtype=torch.float64)
# Testing run # 5
# SE TUVIERON QUE REPETIR 3 EJEMPLOS
# Test_ acc: 0.7600391772771793
# Test_ f1 none: [0.06521739 0.13043478 0.53846154 0.85680191]
# Test_ f1 macro: 0.39772890542061445
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1

# %%
print ("Acc:",np.mean(np.asarray(global_accs)))
print ("F-score:", np.mean(np.asarray(global_fmacros)))
sup=np.mean(np.asarray(global_fnones)[:,0])
den=np.mean(np.asarray(global_fnones)[:,1])
que=np.mean(np.asarray(global_fnones)[:,2])
com=np.mean(np.asarray(global_fnones)[:,3])

print ("S-D-Q-C:", sup,den,que,com)
# Out:
# Acc: 0.7567091087169441
# F-score: 0.4136815569845659
# S-D-Q-C: 0.07556438256504229 0.17334865207389766 0.5503478428447066 0.8554653504546174

# %%
m_temp=np.zeros((4,4))
for m in global_cms:
    m_temp+=np.asarray(m)
m_temp
# Out:
# array([[1.900e+01, 1.100e+01, 3.000e+00, 3.070e+02],
#        [1.000e+00, 4.700e+01, 1.000e+01, 2.870e+02],
#        [1.000e+01, 8.000e+00, 2.480e+02, 2.640e+02],
#        [1.120e+02, 1.230e+02, 1.060e+02, 3.549e+03]])

# %%
plot_confusion_matrix(normalize(m_temp),["S","D","Q","C"],"GloVe Transformer No aum - No CW", cmap='Blues')

# %%
label=[['Text', 'm1', 'm2','m3','m4','m5']]
for layer in range(2):
    fig, axs = plt.subplots(1,4, figsize=(20, 10))
    print ("Encoder Layer Attention head Promedio", layer)
    for head in range(4):
        at=np.zeros((6,6))
        matriz_attn= dict_attn_enc[str(layer)+str(head)]  #lista de 5 corridas en cada pos
        for m in matriz_attn:
            at+=m.numpy()
        sns.heatmap(at/5., xticklabels=label[0], yticklabels=label[0],
                    vmin=0.0, vmax=1.0, linewidths=.5, cmap="Purples", cbar=False, square=True, ax=axs[head]) #, annot=False,cbar_kws={"orientation": "horizontal","pad": 0.25})
    plt.show()
# Out:
# Encoder Layer Attention head Promedio 0
# Encoder Layer Attention head Promedio 1

# %% [markdown]
# ## 0.0 Class Weigths

# %%
class_weights= compute_class_weight('balanced', np.unique(labels_train), labels_train)
print ("Pesos de clases:", class_weights)
# Out:
# Pesos de clases: [1.25980975 3.18168168 3.21060606 0.38752743]

# %%
global_accs=[]
global_fnones=[]
global_fmacros=[]
global_cms=[]
global_attn=[]
dict_attn_enc={'00':[], '01':[], '02':[], '03':[], '10':[], '11':[], '12':[], '13':[]}
  
prob=0.0

for trans in range(1,6): 
    print ("Entrenando Run #", trans)
    cnn1 = load_model('../new_glove_augmented/stance_baselines/'+str(prob)+'_cw/cnn1_'+str(trans)+'-exec.h5')
    cnn2 = load_model('../new_glove_augmented/stance_baselines/'+str(prob)+'_cw/cnn2_'+str(trans)+'-exec.h5')
    rnn1 = load_model('../new_glove_augmented/stance_baselines/'+str(prob)+'_cw/rnn1_'+str(trans)+'-exec.h5')
    rnn2 = load_model('../new_glove_augmented/stance_baselines/'+str(prob)+'_cw/rnn2_'+str(trans)+'-exec.h5')
    rnn3 = load_model('../new_glove_augmented/stance_baselines/'+str(prob)+'_cw/rnn3_'+str(trans)+'-exec.h5')

    list_models=['cnn1', 'cnn2', 'rnn1', 'rnn2', 'rnn3']
    index_models=np.arange(5)
    dict_models=dict((key, value) for (key, value) in zip(index_models,list_models))
    modelos=[cnn1, cnn2, rnn1, rnn2, rnn3]
    ind=np.arange(5)
    dict_trainedModel=dict((key, value) for (key, value) in zip(ind,modelos))

    bs=32
    predicciones_all=[]
    predicciones_all_val=[]
    predicciones_all_test=[]

    for i in dict_trainedModel.keys(): 
        a_evaluar=dict_models[i]
        predicciones_all.append(dict_trainedModel[i].predict(x_train, batch_size=bs))
    for i in dict_trainedModel.keys(): 
        a_evaluar=dict_models[i]
        predicciones_all_val.append(dict_trainedModel[i].predict(x_val, batch_size=bs))
    for i in dict_trainedModel.keys(): 
        a_evaluar=dict_models[i]
        predicciones_all_test.append(dict_trainedModel[i].predict(x_test, batch_size=bs))

    matrix=np.asarray(predicciones_all)
    matrix_val=np.asarray(predicciones_all_val)
    matrix_test=np.asarray(predicciones_all_test)
    new_matrix=np.concatenate([matrix,matrix_val,matrix_test], axis=1)
    
    espacio=[np.ones(768)]
    Ks=np.load("../../BERTransformer/Orthogonals_768.npy")
    random=np.random.randint(Ks.shape[0], size=4)
    K_list=Ks[random]
    K_list_ext=espacio+list(K_list)
    index_embeddings=[0,1,2,3,4]
    lab_str_embeddings=['','','','','']

    for i in range(len(labels_train)):
        folder='Original'
        ide=ids_train[i]
        clase=dict_cl[labels_train[i]]
        if ide<5000000:
            folder=clase #directorio a recuperar vector
            vector=np.load("../BaS_Original/"+str(prob)+"/"+str(trans)+"/"+folder+"/"+str(ide)+".npy")
        else:
            vector=np.load("../BaS_Original/"+folder+"/"+str(ide)+".npy")

        norm=np.linalg.norm(vector)
        vector= vector / norm
        index_embeddings.append(i+5)
        lab_str_embeddings.append(clase)
        K_list_ext.append(vector)

    objs_val=val['Tw_id']      #df_val['Unnamed: 0'].values
    objs_test=test['Tw_id']    #np.arange(df_test.shape[0])
    lab_val=val['Label']
    lab_test=test['Label']
    llaves=np.concatenate([objs_val,objs_test])
    clases=np.concatenate([lab_val,lab_test])

    for num in range(len(llaves)):
        i=llaves[num]
        clase=clases[num]
        vector=np.load("../BaS_Original/Original/"+str(i)+".npy")
        norm=np.linalg.norm(vector)
        vector= vector / norm
        index_embeddings.append(num+5+train.shape[0])
        lab_str_embeddings.append(clase)
        K_list_ext.append(vector)

    K_list_new= np.asarray(K_list_ext, dtype='float32')
    
    ###################################### TRANSFORMER ###############################
    V = 4
    pesos = torch.from_numpy(class_weights).float()
    criterion = FocalLoss(weights=pesos)
    model = make_model_concat(4, N=2,d_model=768, d_ff=128, h=4, dropout=0.35)
    model_opt = NoamOpt(model.src_embed[0].d_model, 1, 500, torch.optim.Adam(model.parameters(), lr=0, betas=(0.9, 0.98), eps=1e-5))

    
    for epoch in range(40):
        model.train()
        DATA=data_gen(32, 'Train', 5, new_matrix)
        loss_train, acc_train,fma_train, f_none, cm_train=run_epoch(DATA, model, SimpleLossComputeFL(criterion, model_opt), 'Train')
        
        model.eval()
        loss_val, acc_val,fma_val, f_val_none, cm_val=run_epoch(data_gen(bs, 'Val', 5, new_matrix), model, SimpleLossComputeFL(criterion, None),'Val')
        print ("Epoch",epoch, "\tacc_val:",acc_val, "\tF-macro_val:",fma_val)
    
    model.eval()
    print ("Testing run #",trans)
    predicciones = run_epoch(data_gen(bs, 'Test', 5, new_matrix), model, SimpleLossComputeFL(criterion, None),'Test')
    predicciones=np.concatenate(predicciones, axis=-1)
    
    glo_acc=accuracy_score(etiq_t, predicciones[:-3])
    glo_fno=f1_score(etiq_t,predicciones[:-3], average=None)
    glo_fma=f1_score(etiq_t,predicciones[:-3], average='macro')

    glo_cm=confusion_matrix(etiq_t, predicciones[:-3])

    plot_confusion_matrix(glo_cm,["support","Denying","Questioning","Commenting"],"Pre-trained Sin Aum - Usa CW")
    global_accs.append(glo_acc)
    global_fnones.append(glo_fno)
    global_fmacros.append(glo_fma)
    global_cms.append(glo_cm)
    print("Test_ acc:",glo_acc) 
    print("Test_ f1 none:",glo_fno) 
    print("Test_ f1 macro:",glo_fma) 

    label=[['Text', 'm1', 'm2','m3','m4','m5']]
    for layer in range(2):
        fig, axs = plt.subplots(1,4, figsize=(20, 10))
        print ("Encoder Layer Attention head", layer)
        for head in range(4):
            matriz_attn=model.encoder.layers[layer].self_attn.attn[0,head].data
            dict_attn_enc[str(layer)+str(head)].append(matriz_attn)
            sns.heatmap(matriz_attn, xticklabels=label[0], yticklabels=label[0],
                        vmin=0.0, vmax=1.0, linewidths=.5, cmap="Blues", cbar=False, square=True, ax=axs[head]) #, annot=False,cbar_kws={"orientation": "horizontal","pad": 0.25})
        plt.show()
# Out:
# Entrenando Run # 1
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.3750, dtype=torch.float64) 	F-macro_val: tensor(0.2600, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.4410, dtype=torch.float64) 	F-macro_val: tensor(0.4061, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.4271, dtype=torch.float64) 	F-macro_val: tensor(0.4094, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.5069, dtype=torch.float64) 	F-macro_val: tensor(0.4528, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.5174, dtype=torch.float64) 	F-macro_val: tensor(0.4465, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.5382, dtype=torch.float64) 	F-macro_val: tensor(0.4647, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.5174, dtype=torch.float64) 	F-macro_val: tensor(0.4649, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.5139, dtype=torch.float64) 	F-macro_val: tensor(0.4710, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.5174, dtype=torch.float64) 	F-macro_val: tensor(0.4612, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.5382, dtype=torch.float64) 	F-macro_val: tensor(0.4510, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.5521, dtype=torch.float64) 	F-macro_val: tensor(0.4877, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.5521, dtype=torch.float64) 	F-macro_val: tensor(0.4723, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.5660, dtype=torch.float64) 	F-macro_val: tensor(0.4763, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.5694, dtype=torch.float64) 	F-macro_val: tensor(0.4815, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.5694, dtype=torch.float64) 	F-macro_val: tensor(0.4821, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.5521, dtype=torch.float64) 	F-macro_val: tensor(0.4745, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.5764, dtype=torch.float64) 	F-macro_val: tensor(0.4833, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.5799, dtype=torch.float64) 	F-macro_val: tensor(0.4720, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.5868, dtype=torch.float64) 	F-macro_val: tensor(0.4912, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.5764, dtype=torch.float64) 	F-macro_val: tensor(0.5064, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.5764, dtype=torch.float64) 	F-macro_val: tensor(0.4982, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.5729, dtype=torch.float64) 	F-macro_val: tensor(0.5003, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.5868, dtype=torch.float64) 	F-macro_val: tensor(0.4952, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.5868, dtype=torch.float64) 	F-macro_val: tensor(0.5183, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.5868, dtype=torch.float64) 	F-macro_val: tensor(0.4853, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.5868, dtype=torch.float64) 	F-macro_val: tensor(0.4847, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.5903, dtype=torch.float64) 	F-macro_val: tensor(0.4831, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.5938, dtype=torch.float64) 	F-macro_val: tensor(0.5082, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.5938, dtype=torch.float64) 	F-macro_val: tensor(0.4797, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.5764, dtype=torch.float64) 	F-macro_val: tensor(0.4832, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.5625, dtype=torch.float64) 	F-macro_val: tensor(0.4761, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.5694, dtype=torch.float64) 	F-macro_val: tensor(0.4684, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.5833, dtype=torch.float64) 	F-macro_val: tensor(0.5058, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.6042, dtype=torch.float64) 	F-macro_val: tensor(0.4980, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.5903, dtype=torch.float64) 	F-macro_val: tensor(0.5090, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.5764, dtype=torch.float64) 	F-macro_val: tensor(0.5035, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.5833, dtype=torch.float64) 	F-macro_val: tensor(0.4951, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.5833, dtype=torch.float64) 	F-macro_val: tensor(0.5086, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.5799, dtype=torch.float64) 	F-macro_val: tensor(0.4950, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.5903, dtype=torch.float64) 	F-macro_val: tensor(0.5017, dtype=torch.float64)
# Testing run # 1
# SE TUVIERON QUE REPETIR 3 EJEMPLOS
# Test_ acc: 0.5739471106758081
# Test_ f1 none: [0.21854305 0.28019324 0.65811966 0.68822171]
# Test_ f1 macro: 0.4612694125497946
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 2
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.2847, dtype=torch.float64) 	F-macro_val: tensor(0.2503, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.3125, dtype=torch.float64) 	F-macro_val: tensor(0.3088, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.4722, dtype=torch.float64) 	F-macro_val: tensor(0.4177, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.5347, dtype=torch.float64) 	F-macro_val: tensor(0.4733, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.5799, dtype=torch.float64) 	F-macro_val: tensor(0.4868, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.6146, dtype=torch.float64) 	F-macro_val: tensor(0.4910, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.6215, dtype=torch.float64) 	F-macro_val: tensor(0.5048, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.6007, dtype=torch.float64) 	F-macro_val: tensor(0.5184, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.5972, dtype=torch.float64) 	F-macro_val: tensor(0.5007, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.6042, dtype=torch.float64) 	F-macro_val: tensor(0.5046, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.6215, dtype=torch.float64) 	F-macro_val: tensor(0.5230, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.6215, dtype=torch.float64) 	F-macro_val: tensor(0.5094, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.6181, dtype=torch.float64) 	F-macro_val: tensor(0.5244, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.6146, dtype=torch.float64) 	F-macro_val: tensor(0.5427, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.6146, dtype=torch.float64) 	F-macro_val: tensor(0.5378, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.6285, dtype=torch.float64) 	F-macro_val: tensor(0.5204, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.6215, dtype=torch.float64) 	F-macro_val: tensor(0.5309, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.6250, dtype=torch.float64) 	F-macro_val: tensor(0.5422, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.6319, dtype=torch.float64) 	F-macro_val: tensor(0.5365, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.6146, dtype=torch.float64) 	F-macro_val: tensor(0.5173, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.6250, dtype=torch.float64) 	F-macro_val: tensor(0.5273, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.6250, dtype=torch.float64) 	F-macro_val: tensor(0.5336, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.6181, dtype=torch.float64) 	F-macro_val: tensor(0.5103, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.6250, dtype=torch.float64) 	F-macro_val: tensor(0.5209, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.6076, dtype=torch.float64) 	F-macro_val: tensor(0.5176, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.6215, dtype=torch.float64) 	F-macro_val: tensor(0.5435, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.6250, dtype=torch.float64) 	F-macro_val: tensor(0.5268, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.6215, dtype=torch.float64) 	F-macro_val: tensor(0.5484, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.6146, dtype=torch.float64) 	F-macro_val: tensor(0.5273, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.6215, dtype=torch.float64) 	F-macro_val: tensor(0.5117, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.6181, dtype=torch.float64) 	F-macro_val: tensor(0.5183, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.6181, dtype=torch.float64) 	F-macro_val: tensor(0.5040, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.6181, dtype=torch.float64) 	F-macro_val: tensor(0.5423, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.6215, dtype=torch.float64) 	F-macro_val: tensor(0.5093, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.6250, dtype=torch.float64) 	F-macro_val: tensor(0.5226, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.6285, dtype=torch.float64) 	F-macro_val: tensor(0.5279, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.6250, dtype=torch.float64) 	F-macro_val: tensor(0.5297, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.6111, dtype=torch.float64) 	F-macro_val: tensor(0.5460, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.6181, dtype=torch.float64) 	F-macro_val: tensor(0.5369, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.6215, dtype=torch.float64) 	F-macro_val: tensor(0.5250, dtype=torch.float64)
# Testing run # 2
# SE TUVIERON QUE REPETIR 3 EJEMPLOS
# Test_ acc: 0.5739471106758081
# Test_ f1 none: [0.19475655 0.25592417 0.55793991 0.70323065]
# Test_ f1 macro: 0.4279628231825492
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 3
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.2674, dtype=torch.float64) 	F-macro_val: tensor(0.2136, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.3160, dtype=torch.float64) 	F-macro_val: tensor(0.3099, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.3160, dtype=torch.float64) 	F-macro_val: tensor(0.3245, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.3194, dtype=torch.float64) 	F-macro_val: tensor(0.3335, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.3611, dtype=torch.float64) 	F-macro_val: tensor(0.3568, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.3472, dtype=torch.float64) 	F-macro_val: tensor(0.3799, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.3264, dtype=torch.float64) 	F-macro_val: tensor(0.3224, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.3438, dtype=torch.float64) 	F-macro_val: tensor(0.3163, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.3611, dtype=torch.float64) 	F-macro_val: tensor(0.3705, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.3750, dtype=torch.float64) 	F-macro_val: tensor(0.3368, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.3958, dtype=torch.float64) 	F-macro_val: tensor(0.3714, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.3958, dtype=torch.float64) 	F-macro_val: tensor(0.4036, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.4479, dtype=torch.float64) 	F-macro_val: tensor(0.4323, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.5243, dtype=torch.float64) 	F-macro_val: tensor(0.5023, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.5694, dtype=torch.float64) 	F-macro_val: tensor(0.4799, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.5868, dtype=torch.float64) 	F-macro_val: tensor(0.4499, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.6076, dtype=torch.float64) 	F-macro_val: tensor(0.5076, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.6146, dtype=torch.float64) 	F-macro_val: tensor(0.5061, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.6007, dtype=torch.float64) 	F-macro_val: tensor(0.4922, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.5903, dtype=torch.float64) 	F-macro_val: tensor(0.4892, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.5694, dtype=torch.float64) 	F-macro_val: tensor(0.4725, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.5729, dtype=torch.float64) 	F-macro_val: tensor(0.4919, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.5451, dtype=torch.float64) 	F-macro_val: tensor(0.4689, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.5521, dtype=torch.float64) 	F-macro_val: tensor(0.4513, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.5938, dtype=torch.float64) 	F-macro_val: tensor(0.5152, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.5799, dtype=torch.float64) 	F-macro_val: tensor(0.4673, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.6111, dtype=torch.float64) 	F-macro_val: tensor(0.4764, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.5972, dtype=torch.float64) 	F-macro_val: tensor(0.4886, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.6319, dtype=torch.float64) 	F-macro_val: tensor(0.5284, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.6389, dtype=torch.float64) 	F-macro_val: tensor(0.4961, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.6458, dtype=torch.float64) 	F-macro_val: tensor(0.5228, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.6597, dtype=torch.float64) 	F-macro_val: tensor(0.5411, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.6562, dtype=torch.float64) 	F-macro_val: tensor(0.5371, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.6597, dtype=torch.float64) 	F-macro_val: tensor(0.4953, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.6597, dtype=torch.float64) 	F-macro_val: tensor(0.5263, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.6632, dtype=torch.float64) 	F-macro_val: tensor(0.4927, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.6736, dtype=torch.float64) 	F-macro_val: tensor(0.5368, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.6667, dtype=torch.float64) 	F-macro_val: tensor(0.5504, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.6667, dtype=torch.float64) 	F-macro_val: tensor(0.5407, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.6736, dtype=torch.float64) 	F-macro_val: tensor(0.5334, dtype=torch.float64)
# Testing run # 3
# SE TUVIERON QUE REPETIR 3 EJEMPLOS
# Test_ acc: 0.6699314397649363
# Test_ f1 none: [0.22222222 0.28395062 0.62608696 0.78447678]
# Test_ f1 macro: 0.47918414512617413
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 4
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.2118, dtype=torch.float64) 	F-macro_val: tensor(0.1664, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.4479, dtype=torch.float64) 	F-macro_val: tensor(0.3427, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.5000, dtype=torch.float64) 	F-macro_val: tensor(0.4552, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.5799, dtype=torch.float64) 	F-macro_val: tensor(0.5049, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.6007, dtype=torch.float64) 	F-macro_val: tensor(0.5515, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.5833, dtype=torch.float64) 	F-macro_val: tensor(0.5280, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.5972, dtype=torch.float64) 	F-macro_val: tensor(0.5091, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.5799, dtype=torch.float64) 	F-macro_val: tensor(0.5221, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.5938, dtype=torch.float64) 	F-macro_val: tensor(0.5019, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.5938, dtype=torch.float64) 	F-macro_val: tensor(0.5173, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.5868, dtype=torch.float64) 	F-macro_val: tensor(0.5196, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.5764, dtype=torch.float64) 	F-macro_val: tensor(0.5214, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.6111, dtype=torch.float64) 	F-macro_val: tensor(0.5353, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.6111, dtype=torch.float64) 	F-macro_val: tensor(0.5342, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.6181, dtype=torch.float64) 	F-macro_val: tensor(0.5369, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.6215, dtype=torch.float64) 	F-macro_val: tensor(0.4978, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.5868, dtype=torch.float64) 	F-macro_val: tensor(0.5156, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.5903, dtype=torch.float64) 	F-macro_val: tensor(0.5002, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.5972, dtype=torch.float64) 	F-macro_val: tensor(0.5044, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.5972, dtype=torch.float64) 	F-macro_val: tensor(0.4915, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.5868, dtype=torch.float64) 	F-macro_val: tensor(0.5197, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.5833, dtype=torch.float64) 	F-macro_val: tensor(0.5173, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.6007, dtype=torch.float64) 	F-macro_val: tensor(0.5147, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.5938, dtype=torch.float64) 	F-macro_val: tensor(0.5150, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.5833, dtype=torch.float64) 	F-macro_val: tensor(0.5083, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.6007, dtype=torch.float64) 	F-macro_val: tensor(0.5024, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.5903, dtype=torch.float64) 	F-macro_val: tensor(0.4976, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.6042, dtype=torch.float64) 	F-macro_val: tensor(0.5165, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.6076, dtype=torch.float64) 	F-macro_val: tensor(0.5314, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.6111, dtype=torch.float64) 	F-macro_val: tensor(0.5220, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.6146, dtype=torch.float64) 	F-macro_val: tensor(0.5445, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.6076, dtype=torch.float64) 	F-macro_val: tensor(0.5448, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.6007, dtype=torch.float64) 	F-macro_val: tensor(0.5150, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.5972, dtype=torch.float64) 	F-macro_val: tensor(0.5357, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.6007, dtype=torch.float64) 	F-macro_val: tensor(0.5255, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.6042, dtype=torch.float64) 	F-macro_val: tensor(0.5262, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.5903, dtype=torch.float64) 	F-macro_val: tensor(0.4908, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.5868, dtype=torch.float64) 	F-macro_val: tensor(0.5311, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.5972, dtype=torch.float64) 	F-macro_val: tensor(0.5167, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.6007, dtype=torch.float64) 	F-macro_val: tensor(0.5158, dtype=torch.float64)
# Testing run # 4
# SE TUVIERON QUE REPETIR 3 EJEMPLOS
# Test_ acc: 0.5484818805093046
# Test_ f1 none: [0.20567376 0.24793388 0.60833333 0.66979656]
# Test_ f1 macro: 0.4329343834041508
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 5
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.1701, dtype=torch.float64) 	F-macro_val: tensor(0.1401, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.3854, dtype=torch.float64) 	F-macro_val: tensor(0.3331, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.3854, dtype=torch.float64) 	F-macro_val: tensor(0.3565, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.5451, dtype=torch.float64) 	F-macro_val: tensor(0.4676, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.6076, dtype=torch.float64) 	F-macro_val: tensor(0.5063, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.6111, dtype=torch.float64) 	F-macro_val: tensor(0.5091, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.6215, dtype=torch.float64) 	F-macro_val: tensor(0.5113, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.6181, dtype=torch.float64) 	F-macro_val: tensor(0.5125, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.6111, dtype=torch.float64) 	F-macro_val: tensor(0.4977, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.6076, dtype=torch.float64) 	F-macro_val: tensor(0.5055, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.6007, dtype=torch.float64) 	F-macro_val: tensor(0.5011, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.6111, dtype=torch.float64) 	F-macro_val: tensor(0.5202, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.6042, dtype=torch.float64) 	F-macro_val: tensor(0.5455, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.6076, dtype=torch.float64) 	F-macro_val: tensor(0.5025, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.6181, dtype=torch.float64) 	F-macro_val: tensor(0.5051, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.6146, dtype=torch.float64) 	F-macro_val: tensor(0.4714, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.6076, dtype=torch.float64) 	F-macro_val: tensor(0.5073, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.6181, dtype=torch.float64) 	F-macro_val: tensor(0.5115, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.6146, dtype=torch.float64) 	F-macro_val: tensor(0.5057, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.6250, dtype=torch.float64) 	F-macro_val: tensor(0.5290, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.6146, dtype=torch.float64) 	F-macro_val: tensor(0.5042, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.6181, dtype=torch.float64) 	F-macro_val: tensor(0.5105, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.6285, dtype=torch.float64) 	F-macro_val: tensor(0.5235, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.6354, dtype=torch.float64) 	F-macro_val: tensor(0.5176, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.6319, dtype=torch.float64) 	F-macro_val: tensor(0.5268, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.6354, dtype=torch.float64) 	F-macro_val: tensor(0.5034, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.6215, dtype=torch.float64) 	F-macro_val: tensor(0.5256, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.6181, dtype=torch.float64) 	F-macro_val: tensor(0.5064, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.6319, dtype=torch.float64) 	F-macro_val: tensor(0.5533, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.6285, dtype=torch.float64) 	F-macro_val: tensor(0.5476, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.6354, dtype=torch.float64) 	F-macro_val: tensor(0.5545, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.6354, dtype=torch.float64) 	F-macro_val: tensor(0.5387, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.6319, dtype=torch.float64) 	F-macro_val: tensor(0.5366, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.6354, dtype=torch.float64) 	F-macro_val: tensor(0.5337, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.6354, dtype=torch.float64) 	F-macro_val: tensor(0.5490, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.6250, dtype=torch.float64) 	F-macro_val: tensor(0.5234, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.6493, dtype=torch.float64) 	F-macro_val: tensor(0.5436, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.6319, dtype=torch.float64) 	F-macro_val: tensor(0.5203, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.6319, dtype=torch.float64) 	F-macro_val: tensor(0.5656, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.6285, dtype=torch.float64) 	F-macro_val: tensor(0.5299, dtype=torch.float64)
# Testing run # 5
# SE TUVIERON QUE REPETIR 3 EJEMPLOS
# Test_ acc: 0.5582761998041136
# Test_ f1 none: [0.16479401 0.24864865 0.57651246 0.67838044]
# Test_ f1 macro: 0.41708388868540625
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1

# %%
print ("Acc:",np.mean(np.asarray(global_accs)))
print ("F-score:", np.mean(np.asarray(global_fmacros)))
sup=np.mean(np.asarray(global_fnones)[:,0])
den=np.mean(np.asarray(global_fnones)[:,1])
que=np.mean(np.asarray(global_fnones)[:,2])
com=np.mean(np.asarray(global_fnones)[:,3])

print ("S-D-Q-C:", sup,den,que,com)
# Out:
# Acc: 0.584916748285994
# F-score: 0.443686930589615
# S-D-Q-C: 0.20119791784856783 0.26333011151224195 0.605398463530767 0.7048212294668831

# %%
m_temp=np.zeros((4,4))
for m in global_cms:
    m_temp+=np.asarray(m)
m_temp
# Out:
# array([[ 133.,   35.,   15.,  157.],
#        [  35.,  132.,   16.,  162.],
#        [  39.,   25.,  368.,   98.],
#        [ 778.,  470.,  289., 2353.]])

# %%
plot_confusion_matrix(normalize(m_temp),["S","D","Q","C"],"GloVe Transformer No aum - Usa CW", cmap='Blues')

# %%
label=[['Text', 'm1', 'm2','m3','m4','m5']]
for layer in range(2):
    fig, axs = plt.subplots(1,4, figsize=(20, 10))
    print ("Encoder Layer Attention head Promedio", layer)
    for head in range(4):
        at=np.zeros((6,6))
        matriz_attn= dict_attn_enc[str(layer)+str(head)]  #lista de 5 corridas en cada pos
        for m in matriz_attn:
            at+=m.numpy()
        sns.heatmap(at/5., xticklabels=label[0], yticklabels=label[0],
                    vmin=0.0, vmax=1.0, linewidths=.5, cmap="Purples", cbar=False, square=True, ax=axs[head]) #, annot=False,cbar_kws={"orientation": "horizontal","pad": 0.25})
    plt.show()
# Out:
# Encoder Layer Attention head Promedio 0
# Encoder Layer Attention head Promedio 1

# %%
for h in range(2):
    for hy in range(4):
        to_mean=dict_attn_enc[str(h)+str(hy)]
        at=np.zeros((6,6))
        for m in to_mean:
            at+=m.numpy()  
        print (np.asarray(at))
        global_attn.append(at/5.)
        
global_attn
# Out:
# [[1.23482989 0.90502137 1.06950919 0.49287161 0.859044   0.43872394]
#  [1.1814893  0.60554445 0.70538496 0.76735133 1.27282423 0.46740566]
#  [1.05272593 0.7976811  0.78361917 1.29447744 0.43327105 0.63822525]
#  [1.59068111 0.4692592  0.87098076 0.88447026 0.52122164 0.66338699]
#  [0.98310849 0.60624194 0.65306907 0.82503029 1.16387692 0.76867339]
#  [1.54319613 0.54018114 0.61870454 1.03425457 0.52935471 0.73430889]]
# [[0.84575222 0.70196155 0.81259065 0.9336479  0.74404132 0.96200617]
#  [1.39612855 0.61070386 0.47984656 0.58321606 1.26884483 0.66126009]
#  [1.90959631 0.54081748 0.83365114 0.61225991 0.49959866 0.60407656]
#  [1.07785257 0.70340528 0.84256134 0.82188287 0.8072921  0.74700578]
#  [1.29652474 0.62265084 0.55288647 0.75729588 1.05600059 0.71464138]
#  [1.49004523 0.73596596 0.61781149 0.70152237 0.67508851 0.7795664 ]]
# [[1.52298993 0.70871811 1.29858959 0.44463431 0.37158882 0.65347906]
#  [0.89778678 0.91078901 0.75989983 0.72162428 0.79695782 0.91294246]
#  [0.54904371 0.61261068 0.95991868 1.12893014 0.6632419  1.08625478]
#  [1.27405681 0.51457562 0.74254096 0.92816857 0.67807589 0.86258242]
#  [1.07055578 0.65466908 0.92717698 0.68382747 0.70918841 0.95458235]
#  [0.84302205 0.68133754 1.00193892 0.83802611 0.60633138 1.02934429]]
# [[1.42535388 0.59606859 0.73505736 0.58767981 0.86725043 0.78858998]
#  [1.58079734 0.76572141 0.83550162 0.47293656 0.65099964 0.69404364]
#  [1.04540304 0.73208238 1.45457471 0.59410762 0.43795343 0.73587886]
#  [0.75408109 0.83375354 0.92603007 0.76224511 0.68272772 1.04116262]
#  [1.14128633 0.72283945 0.85589031 0.67785501 0.68408398 0.91804495]
#  [1.42734296 0.66484163 0.81009604 0.65114361 0.57432529 0.87225069]]
# [[1.64692535 0.66104879 0.65849952 0.4700192  0.93412494 0.62938201]
#  [1.25306555 0.78878009 0.81782566 0.57031855 0.78342878 0.78658138]
#  [1.31576777 0.74001864 0.7422414  0.56520056 0.91938333 0.71738838]
#  [0.88126121 0.78780874 0.80938224 0.63902352 1.0100719  0.87245234]
#  [0.98935073 0.702258   0.70986347 0.80495879 1.00767632 0.78589282]
#  [0.90295263 0.76975421 0.7783683  0.63813491 1.05639229 0.85439774]]
# [[0.62320804 0.96661338 0.81267957 0.80663377 1.02195141 0.76891384]
#  [0.62268358 1.30780562 0.64735431 0.62595418 1.12462413 0.67157834]
#  [0.67894901 0.92964609 0.88250051 0.96221648 0.95552501 0.59116301]
#  [0.5043701  1.0692731  0.97410057 0.71645545 1.00219931 0.73360136]
#  [0.51298011 1.36208472 0.83658407 0.5064552  0.91827638 0.86361955]
#  [0.52403853 1.10538919 0.74268214 0.7240933  1.13407935 0.76971745]]
# [[0.66147598 0.91853337 0.81666923 0.80524801 0.8983669  0.89970669]
#  [0.99240735 0.73745498 0.82822588 0.80019432 0.75321097 0.88850665]
#  [1.14130752 0.73552749 0.75758199 0.7762168  0.74006929 0.84929669]
#  [1.25817837 0.58508537 0.74991895 0.87134051 0.63960215 0.89587466]
#  [1.15256363 0.52291798 0.65171191 1.08041271 0.68338086 0.9090129 ]
#  [1.19257233 0.60382231 0.65731049 0.82629919 0.80538426 0.91461152]]
# [[1.0616642  1.26381642 0.56162372 0.52862611 0.88500807 0.69926124]
#  [0.83798524 0.83479664 0.95366517 0.76880232 0.70172336 0.90302742]
#  [0.90788873 0.94288377 0.76834255 0.87660468 0.62360497 0.88067532]
#  [0.95395897 0.91690445 0.87318799 0.75232852 0.71755989 0.78606001]
#  [0.90656929 1.03910011 0.85962193 0.55316422 0.90119612 0.74034849]
#  [0.93519516 0.97204086 0.96047001 0.70697128 0.58412628 0.84119637]]
# [array([[0.24696598, 0.18100427, 0.21390184, 0.09857432, 0.1718088 ,
#          0.08774479],
#         [0.23629786, 0.12110889, 0.14107699, 0.15347027, 0.25456485,
#          0.09348113],
#         [0.21054519, 0.15953622, 0.15672383, 0.25889549, 0.08665421,
#          0.12764505],
#         [0.31813622, 0.09385184, 0.17419615, 0.17689405, 0.10424433,
#          0.1326774 ],
#         [0.1966217 , 0.12124839, 0.13061381, 0.16500606, 0.23277538,
#          0.15373468],
#         [0.30863923, 0.10803623, 0.12374091, 0.20685091, 0.10587094,
#          0.14686178]]),
#  array([[0.16915044, 0.14039231, 0.16251813, 0.18672958, 0.14880826,
#          0.19240123],
#         [0.27922571, 0.12214077, 0.09596931, 0.11664321, 0.25376897,
#          0.13225202],
#         [0.38191926, 0.1081635 , 0.16673023, 0.12245198, 0.09991973,
#          0.12081531],
#         [0.21557051, 0.14068106, 0.16851227, 0.16437657, 0.16145842,
#          0.14940116],
#         [0.25930495, 0.12453017, 0.11057729, 0.15145918, 0.21120012,
#          0.14292828],
#         [0.29800905, 0.14719319, 0.1235623 , 0.14030447, 0.1350177 ,
#          0.15591328]]),
#  array([[0.30459799, 0.14174362, 0.25971792, 0.08892686, 0.07431776,
#          0.13069581],
#         [0.17955736, 0.1821578 , 0.15197997, 0.14432486, 0.15939156,
#          0.18258849],
#         [0.10980874, 0.12252214, 0.19198374, 0.22578603, 0.13264838,
#          0.21725096],
#         [0.25481136, 0.10291512, 0.14850819, 0.18563371, 0.13561518,
#          0.17251648],
#         [0.21411116, 0.13093382, 0.1854354 , 0.13676549, 0.14183768,
#          0.19091647],
#         [0.16860441, 0.13626751, 0.20038778, 0.16760522, 0.12126628,
#          0.20586886]]),
#  array([[0.28507078, 0.11921372, 0.14701147, 0.11753596, 0.17345009,
#          0.157718  ],
#         [0.31615947, 0.15314428, 0.16710032, 0.09458731, 0.13019993,
#          0.13880873],
#         [0.20908061, 0.14641648, 0.29091494, 0.11882152, 0.08759069,
#          0.14717577],
#         [0.15081622, 0.16675071, 0.18520601, 0.15244902, 0.13654554,
#          0.20823252],
#         [0.22825727, 0.14456789, 0.17117806, 0.135571  , 0.1368168 ,
#          0.18360899],
#         [0.28546859, 0.13296833, 0.16201921, 0.13022872, 0.11486506,
#          0.17445014]]),
#  array([[0.32938507, 0.13220976, 0.1316999 , 0.09400384, 0.18682499,
#          0.1258764 ],
#         [0.25061311, 0.15775602, 0.16356513, 0.11406371, 0.15668576,
#          0.15731628],
#         [0.26315355, 0.14800373, 0.14844828, 0.11304011, 0.18387667,
#          0.14347768],
#         [0.17625224, 0.15756175, 0.16187645, 0.1278047 , 0.20201438,
#          0.17449047],
#         [0.19787015, 0.1404516 , 0.14197269, 0.16099176, 0.20153526,
#          0.15717856],
#         [0.18059053, 0.15395084, 0.15567366, 0.12762698, 0.21127846,
#          0.17087955]]),
#  array([[0.12464161, 0.19332268, 0.16253591, 0.16132675, 0.20439028,
#          0.15378277],
#         [0.12453672, 0.26156112, 0.12947086, 0.12519084, 0.22492483,
#          0.13431567],
#         [0.1357898 , 0.18592922, 0.1765001 , 0.1924433 , 0.191105  ,
#          0.1182326 ],
#         [0.10087402, 0.21385462, 0.19482011, 0.14329109, 0.20043986,
#          0.14672027],
#         [0.10259602, 0.27241694, 0.16731681, 0.10129104, 0.18365528,
#          0.17272391],
#         [0.10480771, 0.22107784, 0.14853643, 0.14481866, 0.22681587,
#          0.15394349]]),
#  array([[0.1322952 , 0.18370667, 0.16333385, 0.1610496 , 0.17967338,
#          0.17994134],
#         [0.19848147, 0.147491  , 0.16564518, 0.16003886, 0.15064219,
#          0.17770133],
#         [0.2282615 , 0.1471055 , 0.1515164 , 0.15524336, 0.14801386,
#          0.16985934],
#         [0.25163567, 0.11701707, 0.14998379, 0.1742681 , 0.12792043,
#          0.17917493],
#         [0.23051273, 0.1045836 , 0.13034238, 0.21608254, 0.13667617,
#          0.18180258],
#         [0.23851447, 0.12076446, 0.1314621 , 0.16525984, 0.16107685,
#          0.1829223 ]]),
#  array([[0.21233284, 0.25276328, 0.11232474, 0.10572522, 0.17700161,
#          0.13985225],
#         [0.16759705, 0.16695933, 0.19073303, 0.15376046, 0.14034467,
#          0.18060548],
#         [0.18157775, 0.18857675, 0.15366851, 0.17532094, 0.12472099,
#          0.17613506],
#         [0.19079179, 0.18338089, 0.1746376 , 0.1504657 , 0.14351198,
#          0.157212  ],
#         [0.18131386, 0.20782002, 0.17192439, 0.11063284, 0.18023922,
#          0.1480697 ],
#         [0.18703903, 0.19440817, 0.192094  , 0.14139426, 0.11682526,
#          0.16823927]])]

# %%
np.save("Attn_SinAum_GloVe_CW.npy", global_attn)
