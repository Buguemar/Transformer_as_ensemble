# %%
import ast
from collections import Counter
from gensim import utils, matutils 
from gensim.corpora.dictionary import Dictionary
from gensim.utils import deprecated
import itertools
from nltk.corpus import stopwords
import numpy as np
from numpy import linalg as LA
from numpy.random import binomial
from numpy import dot, float32 as REAL, memmap as np_memmap, \
    double, array, zeros, vstack, sqrt, newaxis, integer, \
    ndarray, sum as np_sum, prod, argmax
from numpy.linalg import norm
import math, copy, time
import warnings 

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context(context="talk")
# %matplotlib inline

from keras import backend as K
from keras.models import load_model
from keras.preprocessing.sequence import pad_sequences
from keras import backend as K
import keras
from keras.utils import to_categorical
from keras.preprocessing import sequence
from keras.models import load_model

import os, sys, re, io, nltk, torch
import pandas as pd

from scipy import stats
from scipy.stats import bernoulli
from scipy.stats import ortho_group  # Requires version 0.18 of scipy
from scipy.spatial import distance
from sklearn.utils.class_weight import compute_class_weight
from sklearn.utils import class_weight
from sklearn.preprocessing import Normalizer, normalize
from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import accuracy_score,f1_score, confusion_matrix, recall_score, precision_score

from six import string_types, integer_types
from six.moves import zip, range
if not sys.warnoptions:
    warnings.simplefilter("ignore")

from tqdm import tqdm, trange
import time
import transformers
from transformers import (
    WEIGHTS_NAME,
    AdamW,
    BertConfig,
    BertForMaskedLM,
    BertForSequenceClassification,
    BertTokenizer,
    CamembertConfig,
    CamembertForMaskedLM,
    CamembertTokenizer,
    DistilBertConfig,
    DistilBertForMaskedLM,
    DistilBertTokenizer,
    GPT2Config,
    GPT2LMHeadModel,
    GPT2Tokenizer,
    OpenAIGPTConfig,
    OpenAIGPTLMHeadModel,
    OpenAIGPTTokenizer,
    RobertaConfig,
    RobertaForMaskedLM,
    RobertaTokenizer,
    get_linear_schedule_with_warmup,
)

import torch.nn.functional as F
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler
from torch.autograd import Variable
import re
from nltk.corpus import stopwords
from nltk import WordNetLemmatizer
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.porter import *

stemmer_sn = SnowballStemmer("english")
stemmer = PorterStemmer()

stoplist = stopwords.words("english")
lemmatizer=WordNetLemmatizer()


'''
Compatible with tensorflow backend
gamma entre más alto más tolerante (queremos un gamma chico pero no demasiado! 0.25 - 5)
alpha pesos por clase (weights)
'''
def focal_loss(gamma=2., weights=1):   #weights np.asarray()
    weights= K.variable(weights)
    def focal_loss_fixed(y_true, y_pred):
        y_true = K.clip(y_true, K.epsilon(),1)
        y_pred = K.clip(y_pred,K.epsilon(),1)
        return - K.sum(weights* K.pow(1. - y_pred, gamma)* y_true * K.log(y_pred), axis=-1) 
    return focal_loss_fixed

keras.losses.focal_loss=keras.losses.MSE
keras.losses.focal_loss_fixed=keras.losses.MSE

n_gpu = torch.cuda.device_count()
torch.cuda.get_device_name(0)

if torch.cuda.is_available():     
    device = torch.device("cuda")
    print('There are',torch.cuda.device_count(),'GPU(s) available.')
    print('We will use the GPU:', torch.cuda.get_device_name(0))

else:
    print('No GPU available, using the CPU instead.')
    device = torch.device("cpu")

if not sys.warnoptions:
    warnings.simplefilter("ignore")
    
class Dummy_Embeddings(nn.Module):
    def __init__(self, d_model, dummy_vectors): 
        super(Dummy_Embeddings, self).__init__()
        aux = torch.from_numpy(dummy_vectors)#, dtype='float32'))
        self.index2dummy = nn.Embedding(aux.size()[0], d_model)
        self.index2dummy.weigth=nn.Parameter(aux)
        self.index2dummy.weigth.requires_grad=False
        self.d_model = d_model
        
    def forward(self, x):
        aux=x.numpy()
        #print ("aux original", aux)
        #print ("aux restado...",aux-np.ones(aux.shape))
        new_x= aux #- np.ones(aux.shape)
        new_x= torch.from_numpy(new_x)
        return self.index2dummy(new_x.long()) * math.sqrt(self.d_model) #debiese retornar matriz de batch_size x [ind_tw, k1,k2,k3,k4,k5,k6] (si son 6 modelos)
    
def match(objetos,ejemplo):
    i=0
    for obj in objetos:
        if obj==ejemplo:
            return i
        i+=1
        
def plot_confusion_matrix(cm, target_names, title='Confusion matrix (f1-score)',cmap=None, normalize=True):    
    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy
    if cmap is None:
        cmap = plt.get_cmap('Blues')
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        
    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap, vmin=0, vmax=1)
    plt.title(title)
    plt.colorbar()
    
    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)
    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()
    
    
class EncoderDecoderLogSoft(nn.Module):
    def __init__(self, encoder, src_embed, sequential):
        super(EncoderDecoderLogSoft, self).__init__()
        self.encoder = encoder
        self.linearSoft = sequential
        self.src_embed = src_embed
        
    def forward(self, src, src_mask):
        out=self.encode(src, src_mask)
        retorno=self.toSoftmax(out)
        return retorno
    
    def encode(self, src, src_mask):
        return self.encoder(self.src_embed(src), src_mask)
    
    def toSoftmax(self, tensor):
        a=tensor.size()[0]
        b=tensor.size()[-1]
        c=tensor.size()[-2]
        new_tensor= np.zeros((a, b))
        ini=True
        for ai in range(a):
            for ci in range(c):
                if ini:
                    new_tensor[ai]=tensor.data[ai][ci].numpy()
                    ini=False
                else: 
                    new_tensor[ai]*=tensor.data[ai][ci].numpy()
            ini=True
        new_tensor=torch.from_numpy(new_tensor)
        lineal=self.linearSoft(new_tensor.float())
        return F.log_softmax(lineal, dim = -1)
    
    def decode(self, memory, src_mask, tgt, tgt_mask):
        return self.decoder(self.tgt_embed(tgt), memory, src_mask, tgt_mask)
    
def clones(module, N):
    return nn.ModuleList([copy.deepcopy(module) for _ in range(N)])


class EncoderDecoderSoft(nn.Module):
    def __init__(self, encoder, src_embed, sequential):
        super(EncoderDecoderSoft, self).__init__()
        self.encoder = encoder
        self.linearSoft = sequential
        self.src_embed = src_embed
        
    def forward(self, src, src_mask):
        out=self.encode(src, src_mask)
        retorno=self.toSoftmax(out)
        return retorno
    
    def encode(self, src, src_mask):
        return self.encoder(self.src_embed(src), src_mask)
    
    def toSoftmax(self, tensor):
        a=tensor.size()[0]
        b=tensor.size()[-1]
        c=tensor.size()[-2]
        new_tensor= np.zeros((a, b))
        ini=True
        for ai in range(a):
            for ci in range(c):
                if ini:
                    new_tensor[ai]=tensor.data[ai][ci].numpy()
                    ini=False
                else: 
                    new_tensor[ai]*=tensor.data[ai][ci].numpy()
            ini=True
            
        new_tensor=torch.from_numpy(new_tensor)
        lineal=self.linearSoft(new_tensor.float())
        return F.softmax(lineal, dim = -1)
    
    def decode(self, memory, src_mask, tgt, tgt_mask):
        return self.decoder(self.tgt_embed(tgt), memory, src_mask, tgt_mask)
    
def clones(module, N):
    return nn.ModuleList([copy.deepcopy(module) for _ in range(N)])

class EncoderDecoder(nn.Module):
    def __init__(self, encoder, src_embed, generator):
        super(EncoderDecoder, self).__init__()
        self.encoder = encoder
        self.src_embed = src_embed
        self.generator = generator
        
    def forward(self, src, src_mask):
        return  self.encode(src, src_mask)

    def encode(self, src, src_mask):
        return self.encoder(self.src_embed(src), src_mask)
    
    def decode(self, memory, src_mask, tgt, tgt_mask):
        return self.decoder(self.tgt_embed(tgt), memory, src_mask, tgt_mask)
    
class Encoder(nn.Module):
    def __init__(self, layer, N):
        super(Encoder, self).__init__()
        self.layers = clones(layer, N)
        self.norm = LayerNorm(layer.size)
        
    def forward(self, x, mask):
        for layer in self.layers:
            x = layer(x, mask)
        return self.norm(x)
    
class LayerNorm(nn.Module):
    def __init__(self, features, eps=1e-6):
        super(LayerNorm, self).__init__()
        self.a_2 = nn.Parameter(torch.ones(features))
        self.b_2 = nn.Parameter(torch.zeros(features))
        self.eps = eps

    def forward(self, x):
        mean = x.mean(-1, keepdim=True)
        std = x.std(-1, keepdim=True)
        return self.a_2 * (x - mean) / (std + self.eps) + self.b_2
    
class SublayerConnection(nn.Module):
    def __init__(self, size, dropout):
        super(SublayerConnection, self).__init__()
        self.norm = LayerNorm(size)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, sublayer):
        return x + self.dropout(sublayer(self.norm(x)))    
    
class EncoderLayer(nn.Module):
    def __init__(self, size, self_attn, feed_forward, dropout):
        super(EncoderLayer, self).__init__()
        self.self_attn = self_attn
        self.feed_forward = feed_forward
        self.sublayer = clones(SublayerConnection(size, dropout), 2)
        self.size = size

    def forward(self, x, mask):
        x = self.sublayer[0](x, lambda x: self.self_attn(x, x, x, mask))
        return self.sublayer[1](x, self.feed_forward)
    
def subsequent_mask(size):
    attn_shape = (1, size, size)
    subsequent_mask = np.triu(np.ones(attn_shape), k=1).astype('uint8')
    return torch.from_numpy(subsequent_mask) == 0

class Generator(nn.Module):
    def __init__(self, d_model, vocab):
        super(Generator, self).__init__()
        self.proj = nn.Linear(d_model, vocab)

    def forward(self, x):
        return F.log_softmax(self.proj(x), dim=-1)
    
def attention(query, key, value, mask=None, dropout=None):
    d_k = query.size(-1)
    scores = torch.matmul(query, key.transpose(-2, -1)) \
             / math.sqrt(d_k)
    if mask is not None:
        scores = scores.masked_fill(mask == 0, -1e9)
    p_attn = F.softmax(scores, dim = -1)
    if dropout is not None:
        p_attn = dropout(p_attn)
    return torch.matmul(p_attn, value), p_attn

class MultiHeadedAttention(nn.Module):
    def __init__(self, h, d_model, dropout=0.1):
        super(MultiHeadedAttention, self).__init__()
        assert d_model % h == 0
        self.d_k = d_model // h
        self.h = h
        self.linears = clones(nn.Linear(d_model, d_model), 4)
        self.attn = None
        self.dropout = nn.Dropout(p=dropout)
        
    def forward(self, query, key, value, mask=None):
        #print ("mask para attn...", mask)
        if mask is not None:
            mask = mask.unsqueeze(1)
        nbatches = query.size(0)
        
        query, key, value = \
            [l(x).view(nbatches, -1, self.h, self.d_k).transpose(1, 2)
             for l, x in zip(self.linears, (query, key, value))]
         
        x, self.attn = attention(query, key, value, mask=mask, 
                                 dropout=self.dropout)
        
        x = x.transpose(1, 2).contiguous() \
             .view(nbatches, -1, self.h * self.d_k)
        return self.linears[-1](x)
    
class PositionalText(nn.Module):
    def __init__(self, d_model, dropout, max_len=50):
        super(PositionalText, self).__init__()
        self.dropout = nn.Dropout(p=dropout)
        
    def forward(self, x):
        x_text=x.data[:,0][:,None,:]
        x_machines=x.data[:,1:]
        
        x_return = x_machines* x_text
        return self.dropout(x_return)
    
class PositionalText_concat(nn.Module):
    def __init__(self, d_model, dropout, max_len=50):
        super(PositionalText_concat, self).__init__()
        self.dropout = nn.Dropout(p=dropout)
        
    def forward(self, x):
        return self.dropout(x)   

    
global max_src_in_batch, max_tgt_in_batch

def batch_size_fn(new, count, sofar):
    global max_src_in_batch, max_tgt_in_batch
    if count == 1:
        max_src_in_batch = 0
        max_tgt_in_batch = 0
    max_src_in_batch = max(max_src_in_batch,  len(new.src))
    max_tgt_in_batch = max(max_tgt_in_batch,  len(new.trg) + 2)
    src_elements = count * max_src_in_batch
    tgt_elements = count * max_tgt_in_batch
    maximo=max(src_elements, tgt_elements)
    return maximo

class NoamOpt:
    "Optim wrapper that implements rate."
    def __init__(self, model_size, factor, warmup, optimizer):
        self.optimizer = optimizer
        self._step = 0
        self.warmup = warmup
        self.factor = factor
        self.model_size = model_size
        self._rate = 0
        
    def step(self):
        "Update parameters and rate"
        self._step += 1
        rate = self.rate()
        for p in self.optimizer.param_groups:
            p['lr'] = rate
        self._rate = rate
        #print ("Rate de Noam_opt", self._rate, self._step)
        self.optimizer.step()
        
    def rate(self, step = None):
        "Implement `lrate` above"
        if step is None:
            step = self._step
        return self.factor * \
            (self.model_size ** (-0.5) *
            min(step ** (-0.5), step * self.warmup ** (-1.5)))
        
def get_std_opt(model):
    return NoamOpt(model.src_embed[0].d_model, 2, 4000,
            torch.optim.Adam(model.parameters(), lr=0, betas=(0.9, 0.98), eps=1e-9))

class LabelSmoothing(nn.Module):
    "Implement label smoothing."
    def __init__(self, size, padding_idx, smoothing=0.0):
        super(LabelSmoothing, self).__init__()
        self.criterion = nn.KLDivLoss(size_average=False)
        self.padding_idx = padding_idx
        self.confidence = 1.0 - smoothing
        self.smoothing = smoothing
        self.size = size
        self.true_dist = None
        
    def forward(self, x, target):
        assert x.size(1) == self.size
        true_dist = x.data.clone()
        true_dist.fill_(self.smoothing / (self.size - 2))
        true_dist.scatter_(1, target.data.unsqueeze(1), self.confidence)
        mask = torch.nonzero(target.data == self.padding_idx)
        self.true_dist = true_dist
        return self.criterion(x, Variable(true_dist, requires_grad=False))
    
class LabelCCE(nn.Module):
    def __init__(self, class_weights):
        super(LabelCCE, self).__init__()
        self.criterion = nn.CrossEntropyLoss(weight=class_weights)
                       
    def forward(self, x, target):
        return self.criterion(x, target)
    
class FocalLoss(nn.Module):
    def __init__(self, weights, gamma=2.0, reduce=True):#, logits=False, reduce=True):
        super(FocalLoss, self).__init__()
        self.weights = weights
        self.gamma = gamma
        #self.logits = logits
        self.reduce = reduce

    def forward(self, x, y):
        tensors = []
        for l in y:
            tensors.append(torch.zeros(4).scatter_(0, torch.tensor(l), 1))
        result = torch.stack(tensors, 0)
        
        CCE_loss = F.cross_entropy(x, result.long().argmax(dim=-1), reduction='none', weight=self.weights.float())
        pt = torch.exp(-CCE_loss)
        factor= (1-pt)**self.gamma * CCE_loss
        
        F_loss = factor  #*self.weights.float()-- peso esta dentro de la funcion

        if self.reduce:
            return torch.mean(F_loss)
        else:
            return F_loss
        
class SimpleLossComputeFL:
    "A simple loss compute and train function."
    def __init__(self, criterion, opt=None):
        self.criterion = criterion
        self.opt = opt
        
    def __call__(self, x, y, norm, mode):
        y_new=(y.float()-torch.ones((y.shape))).int() 
        #print ("nuevo Y en simplelosscompute", y_new, "antes era", y)
        # ahora
        #y_new=(y.float()).int()
        ac=accuracy_scorer(x, y_new)
        f1=f_scorer(x, y_new)
        cm=compute_confusion_matrix(x, y_new)
        tempa= x.contiguous().view(-1, x.size(-1))
        tempb= y_new.long().contiguous().view(-1)
        loss = self.criterion(tempa, tempb) #/ norm
        if mode!='Test':
            loss.backward()
        if self.opt is not None:
            self.opt.step()
            self.opt.optimizer.zero_grad()
        return [loss.data, ac ,f1, cm] #*norm #[0] * norm
    
class PositionwiseFeedForward(nn.Module):
    "Implements FFN equation."
    def __init__(self, d_model, d_ff, dropout=0.1):
        super(PositionwiseFeedForward, self).__init__()
        self.w_1 = nn.Linear(d_model, d_ff)
        self.w_2 = nn.Linear(d_ff, d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        return self.w_2(self.dropout(F.relu(self.w_1(x))))
    
def accuracy_scorer(predicho, target):
    predicho= torch.argmax(predicho, dim=1)
    return accuracy_score(target.numpy(),predicho.numpy())

def f_scorer(predicho, target):
    predicho= torch.argmax(predicho, dim=1)
    return f1_score(target.numpy(),predicho.numpy(), average=None, labels=[0,1,2,3])

def compute_confusion_matrix(predicho, target):
    predicho= torch.argmax(predicho, dim=1)
    return confusion_matrix(target.numpy(), predicho.numpy(), labels=[0,1,2,3])

def data_gen(batch_size,mode,n_machines,new_matrix):  
    """ESTA FUNCION DEBERÁ RETORNAR MATRICES DE TAMAÑO BATCH_SIZE * TW,M1,M2,M3,M4,M5,M6
    CADA EJEMPLO DEBERÁ SER ESTILO [ID_T, 1,2,1,2,1,2] SIENDO 1 CUANDO LA CLASE PREDICHA ES LA 0
    2 PARA CLASE PREDICHA 1, ETC. ID_T DEBEŔA INICIAR EN 5 PARA REFERIRSE AL PRIMER TW (EL PRIMERO DE TRAIN)"""
    x_data=[] 
    y_data=[]
    if mode=='Train':
        max_objs=matrix.shape[1]
        x_list=np.arange(max_objs)
        np.random.shuffle(x_list)        #indices desordenados de seccion train
        objs=ids_train
        labels=etiq     #np.load("matrices/y_train_num_4.npy")
        labels=np.asarray(labels) #+ np.ones(labels.shape),dtype='uint8')
    if mode=='Val':
        max_objs=matrix_val.shape[1] 
        x_list=np.arange(max_objs)
        x_list=[x+matrix.shape[1] for x in x_list]   
        np.random.shuffle(x_list)        #indices desordenados de seccion val
        objs=val['Tw_id']    #df_val['Unnamed: 0'].values        
        labels=np.asarray(etiq_v)     #np.load("matrices/y_val_num_4.npy")
        labels=np.asarray(labels) #+ np.ones(labels.shape),dtype='uint8') 
    if mode=='Test':
        max_objs=matrix_test.shape[1] 
        x_list=np.arange(max_objs)
        x_list=[x+matrix.shape[1]+matrix_val.shape[1] for x in x_list]
        total=matrix.shape[1]+matrix_val.shape[1]
        objs=test['Tw_id']     #np.arange(total, total+max_objs)
        
    #----------------------------------- COMPLETA MINI BATCHES ----------------------    
    if len(x_list)%batch_size==0:
        n_batches=len(x_list)/batch_size
        for nb in range(n_batches): 
            x_data.append(x_list[nb*batch_size:(nb+1)*batch_size])
    else:
        n_batches=int(len(x_list)/batch_size)
        resto=int(len(x_list)-n_batches*batch_size)
        to_repeat=batch_size-resto        
        for nb in range(n_batches): 
            x_data.append(x_list[nb*batch_size:(nb+1)*batch_size])
        cola=list(x_list[(nb+1)*batch_size:])
        for i in range(to_repeat):
            indice= np.random.randint(len(x_list))
            cola.append(x_list[indice])
        x_data.append(np.asarray(cola))
        if mode=='Test':
            print ("SE TUVIERON QUE REPETIR", to_repeat, "EJEMPLOS")
    #print ("los indices de train k voy a acceder random son", x_data[0])
            
    #-------------------------------- CONSTRUCCION MINI BATCHES (X,Y)----------------------   
    new_x_data=[] 
    for batch in x_data:
        #print ("transformando batch", batch)
        temp=[]
        for pos in batch:
            #print("en especifico el numerito", pos)
            temp2=[index_embeddings[pos+5]]#fromId2num[objs[exam]]] ### obj evaluado en maquinas  
            #print ("me dice que es el embed en index", temp2)
            for m in range(n_machines): 
                #print ("machine ",m,"dice:", np.argmax(new_matrix[m][pos])+1)
                temp2= temp2 + [np.argmax(new_matrix[m][pos])+1] 
                #matrix[4][cosa-5])+1)
            temp.append(temp2)
        new_x_data.append(temp)   

    if mode=='Train' or mode=='Val':    
        y_data=[]
        for conjunto in range(len(new_x_data)):
            batch=new_x_data[conjunto]
            temp_y=[]
            for linea in range(len(batch)):
                indice=x_data[conjunto][linea]  #pos
                lab=d_lab[lab_str_embeddings[indice+5]]+1 #labels_train
                temp_y.append([lab])       
            y_data.append(temp_y)
            
        y_data=np.asarray(y_data)
        
    new_x_data=np.asarray(new_x_data)
    #print ("primer batch X.Y", new_x_data[0], y_data[0])
    if mode=='Test':
        for x in new_x_data:
            src = Variable(torch.from_numpy(np.asarray(x)), requires_grad=False)
            yield Batch(src, None, 0)        
    else:          
        for x,y in zip(new_x_data, y_data):
            src = Variable(torch.from_numpy(np.asarray(x)), requires_grad=False)
            har = Variable(torch.from_numpy(np.asarray(y)), requires_grad=False)
            yield Batch(src, har, 0)
            

def make_model_concat(target, N=2, d_model=768, d_ff=1024, h=4, dropout=0.3, soft=True):  #recibir src_vocab si lo utiliza dummy_Emb
    c = copy.deepcopy
    attn = MultiHeadedAttention(h, d_model)
    ff = PositionwiseFeedForward(d_model, d_ff, dropout)
    position = PositionalText_concat(d_model, dropout)
    if soft:
        print ("Creando modelo con salida Softmax")
        model = EncoderDecoderSoft(
            Encoder(EncoderLayer(d_model, c(attn), c(ff), dropout), N),
            nn.Sequential(Dummy_Embeddings(d_model, K_list_new), c(position)),
            nn.Linear(d_model, 4))
    else:
        print ("")
        print ("Creando modelo con salida Log_softmax")
        model = EncoderDecoderLogSoft(
            Encoder(EncoderLayer(d_model, c(attn), c(ff), dropout), N),
            nn.Sequential(Dummy_Embeddings(d_model, K_list_new), c(position)),
            nn.Linear(d_model, 4))

    for p in model.parameters():
        if p.dim() > 1:
            nn.init.xavier_uniform(p)
    return model

class Batch:
    def __init__(self, src, trg=None, pad=0):
        self.src = src
        self.src_mask = (src != pad).unsqueeze(-2)
        if trg is not None:
            self.trg = trg[:, :]
            self.trg_y = trg[:, 0:]
            self.trg_mask = \
                self.make_std_mask(self.trg, pad)
            self.ntokens = (self.trg_y != pad).data.sum()
            
    @staticmethod
    def make_std_mask(tgt, pad):
        tgt_mask = (tgt != pad).unsqueeze(-2)
        tgt_mask = tgt_mask & Variable(
            subsequent_mask(tgt.size(-1)).type_as(tgt_mask.data))
        return tgt_mask
    
def run_epoch(data_iter, model, loss_compute, mode):
    if mode=='Test':
        with torch.no_grad():
            start = time.time()
            pred_classes=[]
            for i, batch in enumerate(data_iter):
                #print ("batch.src_mask en run epoch", batch.src_mask)
                out = model.forward(batch.src, batch.src_mask)
                pred_classes.append(out.argmax(dim=-1).numpy())
                #la loss del batch es sobre todos los ejemplos o es promedio en batch?
            return pred_classes
    
    else:
        start = time.time()
        total_learners = 0
        total_datos = 0
        total_loss = 0
        total_acc=0
        total_fm1=0
        total_fs=0
        n_batches = 0
        cm_last=np.zeros((4,4))
        for i, batch in enumerate(data_iter):
            #print ("BATCH\n", i, '\n', batch.src)
            out = model.forward(batch.src, batch.src_mask)
            loss,acc,f1,cm = loss_compute(out, batch.trg_y, batch.ntokens, mode)
            cm_last+=cm
            f_ma=np.mean(f1)
            total_loss += loss
            total_acc += np.array(acc)
            total_fm1 += np.sum(f1)/4.0    #4 clases (macro)
            total_fs += f1                 #none  
            total_datos += batch.ntokens
            n_batches += 1
        return total_loss/n_batches, torch.from_numpy(np.array(total_acc))/n_batches, torch.from_numpy(np.array(total_fm1))/n_batches, torch.from_numpy(np.array(total_fs))/n_batches, cm_last

emoji_pattern = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags=re.UNICODE)

def cleaner(post): 
    #re.sub(r'([a-z])\1+', r'\1', "user i think that ' s all you loooooove ")
    s= re.sub(r"http\S+", " html ", post)   ##########elimina http    
    s= re.sub(r'#\w+ ?', " hashtag ", s) ########3
    s= re.sub(r'@\w+ ?', " user ", s)##############    
    s= s.lower()
    s=emoji_pattern.sub(r'', s)
    s=re.sub(r"'\b", " ' ", s)
    s=re.sub(r"\b'\b", " ' ", s)
    s=re.sub(r"“\b", " “ ", s)
    #“
    s=re.sub(r"\b’", " ’ ", s)
    s=re.sub(r"‘\b", " ‘ ", s)
    s=re.sub(r"\b’\b", " ‘ ", s)
    s = re.sub(r"-", " - ", s)
    s = re.sub(r"\(", " ", s)
    s = re.sub(r"\)", " ", s)
    s = re.sub(r"\?", " ? ", s)    
    s = re.sub(r"\/", " ", s)
    s = re.sub(r"' ", " ' ", s)
    s = re.sub(r" '", " ' ", s)
    s = re.sub(r"\!", " ! ", s)
    s=re.sub("[\.]+", " . ", s)
    s=re.sub("[\,]+", " , ", s)
    s=re.sub("[\;]+", " ; ", s)
    s=re.sub("[\:]+", " : ", s)
    s=re.sub('[\"]+', ' " ', s)
    s=re.sub(r'\b[0-9]\b', " number ",  s)
    s=re.sub(r'\b[0-9]*[0-9]\b', " number ",  s)    
    s=re.sub(r'\b”', ' " ', s)
    sl= list(s.split())
    sl_2=[]
    for wd in sl:
        try: 
            q=Word2Index[wd]
            sl_2.append(wd)
        except:
            try: 
                if stemmer.stem(wd) in Word2Index.keys():
                    sl_2.append(stemmer.stem(wd))
                elif lemmatizer.lemmatize(wd) in Word2Index.keys():
                    sl_2.append(lemmatizer.lemmatize(wd))
                else:
                    sl_2.append(wd)
            except:
                sl_2.append(wd)
    sl=sl_2
    s=' '.join([word for word in sl])# if word not in stoplist])
    return s, sl

embeddings_index = {}
f = open(os.path.join("glove.twitter.27B.200d.txt"))#'glove.twitter.27B.100d.txt'))
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

print('Se encontraron %s terminos con sus vectores de embedding.' % len(embeddings_index))
# Out:
# There are 1 GPU(s) available.
# We will use the GPU: GeForce GTX 1060 6GB
# Se encontraron 1193514 terminos con sus vectores de embedding.

# %%
dict_cl=dict()
dict_cl[0]='support'
dict_cl[1]='denying'
dict_cl[2]='questioning'
dict_cl[3]='commenting'

#sdqc
d_lab=dict()
d_lab["support"]=0
d_lab["denying"]=1
d_lab["questioning"]=2
d_lab["commenting"]=3

train =pd.read_csv("../Tesis_exp/Fine-Tuning/CSV_Stance/train_semeval_raw.csv")
val=pd.read_csv("../Tesis_exp/Fine-Tuning/CSV_Stance/dev_semeval_raw.csv")
test=pd.read_csv("../Tesis_exp/Fine-Tuning/CSV_Stance/test_semeval_raw.csv")


word_index=dict()
j=1
for frase in train["Tweet"].values:
    frase=cleaner(frase)[-1]
    #print (frase)
    for term in frase:
        if term not in word_index.keys():
            word_index[term]=j
            j+=1

for frase in val["Tweet"].values:
    frase=cleaner(frase)[-1]
    #print (frase)
    for term in frase:
        if term not in word_index.keys():
            word_index[term]=j
            j+=1
            
for frase in test["Tweet"].values:
    frase=cleaner(frase)[-1]
    #print (frase)
    for term in frase:
        if term not in word_index.keys():
            word_index[term]=j
            j+=1
            
len(word_index.keys())
# Out:
# 7236

# %%
not_found=[]
pos_tag_nf=[]
Word2Index={}
idx_2_token={}

g_dim=200
emb_matrix = np.zeros((len(word_index.keys())+1, g_dim))  

for word, i in word_index.items():
    vector = embeddings_index.get(word)
    if vector is not None:
        # words sin match en Glove, serán vectores de ceros.
        emb_matrix[i] = vector
        Word2Index[word]=i
        idx_2_token[i]=word
    else:
        Word2Index[word]=i
        idx_2_token[i]=word
        not_found.append(word)
        pos_tag_nf.append(nltk.pos_tag([word])[0][-1])

# %%
transf = Normalizer().fit(emb_matrix) 
M_GLOVE_space=transf.transform(emb_matrix)

def my_tokenizer(lista):
    to_return=[]
    for l in lista:
        if l in word_index.keys():
            to_return.append(l)
        else:
            continue
    return to_return

def predict_data(trained, x_train, x_val, x_test, etiq, etiq_v, etiq_t, name_model):
    etiq = etiq.astype("int")
    trainPredict = trained.predict(x_train, batch_size=32)
    trainPredict=[np.argmax(pred) for pred in trainPredict]
    acc= accuracy_score(etiq, trainPredict)  
    f1=f1_score(etiq, trainPredict, average=None)  # labels=np.unique(trainPredict)
    f1_ma=f1_score(etiq, trainPredict, average='macro')  # labels=np.unique(trainPredict)
    #matriz=normalize(confusion_matrix(etiq, trainPredict))
    print ("")
    print ("Accuracy sobre Train", name_model, ":",acc)  
    print ("F1-score None sobre Train", name_model, ":",f1)
    print ("F1-score macro sobre Train", name_model, ":",f1_ma)
    ########################################
    trainPredict = trained.predict(x_val, batch_size=32)
    trainPredict=[np.argmax(pred) for pred in trainPredict]
    acc= accuracy_score(etiq_v, trainPredict)  
    f1=f1_score(etiq_v, trainPredict, average=None)  # labels=np.unique(trainPredict)
    f1_ma=f1_score(etiq_v, trainPredict, average='macro')  # labels=np.unique(trainPredict)
    #matriz=normalize(confusion_matrix(etiq_v, trainPredict))
    print ("")
    print ("Accuracy sobre Val", name_model, ":",acc)  
    print ("F1-score None sobre Val", name_model, ":",f1)
    print ("F1-score macro sobre Val", name_model, ":",f1_ma)
    ########################################
    trainPredict = trained.predict(x_test, batch_size=32)
    trainPredict=[np.argmax(pred) for pred in trainPredict]
    acc_t= accuracy_score(etiq_t, trainPredict)  
    f1_t=f1_score(etiq_t, trainPredict, average=None)  # labels=np.unique(trainPredict)
    f1_ma_t=f1_score(etiq_t, trainPredict, average='macro')  # labels=np.unique(trainPredict)
    matriz_t=normalize(confusion_matrix(etiq_t, trainPredict))
    print ("")
    print ("Accuracy sobre Test", name_model, ":",acc_t)  
    print ("F1-score None sobre Test", name_model, ":",f1_t)
    print ("F1-score macro sobre Test", name_model, ":",f1_ma_t)
    
    return f1_ma_t, f1_t, acc_t, matriz_t

# %%
from models import *

if not sys.warnoptions:
    warnings.simplefilter("ignore")
    
class Dummy_Embeddings(nn.Module):
    def __init__(self, d_model, dummy_vectors): 
        super(Dummy_Embeddings, self).__init__()
        aux = torch.from_numpy(dummy_vectors)#, dtype='float32'))
        self.index2dummy = nn.Embedding(aux.size()[0], d_model)
        self.index2dummy.weigth=nn.Parameter(aux)
        self.index2dummy.weigth.requires_grad=False
        self.d_model = d_model
        
    def forward(self, x):
        aux=x.numpy()
        #print ("aux original", aux)
        #print ("aux restado...",aux-np.ones(aux.shape))
        new_x= aux #- np.ones(aux.shape)
        new_x= torch.from_numpy(new_x)
        return self.index2dummy(new_x.long()) * math.sqrt(self.d_model) #debiese retornar matriz de batch_size x [ind_tw, k1,k2,k3,k4,k5,k6] (si son 6 modelos)
    
def match(objetos,ejemplo):
    i=0
    for obj in objetos:
        if obj==ejemplo:
            return i
        i+=1
        
def plot_confusion_matrix(cm, target_names, title='Confusion matrix (f1-score)',cmap=None, normalize=True):    
    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy
    if cmap is None:
        cmap = plt.get_cmap('Blues')
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        
    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap, vmin=0, vmax=1)
    plt.title(title)
    plt.colorbar()
    
    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)
    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()
    
MAX_LEN = 37

print ("Conteo por stance val\n", Counter(val['Label']))
print ("Conteo por stance test\n", Counter(test['Label']))
# Out:
# Conteo por stance val
#  Counter({'commenting': 173, 'support': 69, 'questioning': 28, 'denying': 11})
# Conteo por stance test
#  Counter({'commenting': 778, 'questioning': 106, 'denying': 69, 'support': 68})

# %%
ids_train=train['Tw_id']
tws_train=train['Tweet']
labels_train=[d_lab[lb] for lb in train['Label']]
#class_weights= compute_class_weight('balanced', np.unique(labels_train), labels_train)
class_weights= [1.0, 1.0, 1.0, 1.0]
class_weights=np.asarray(class_weights)
print ("Pesos de clases:", class_weights)
#print ("Pesos de clases:", class_weights)

etiq=labels_train.copy()
etiq=np.asarray(etiq)
sentences = tws_train
n_labels = np.array(etiq)
y_train=to_categorical(n_labels,num_classes=4)

input_ids=[]
for sent in sentences:
    sent_cl=cleaner(sent)[1]
    encoded_sent=[]
    for wd in sent_cl:
        try: 
            encoded_sent.append(Word2Index[wd])
        except: 
            continue   
    input_ids.append(encoded_sent)
    
input_ids = pad_sequences(input_ids,maxlen=MAX_LEN,dtype="long",value=0, truncating="post", padding="post")
shape=np.asarray(input_ids).shape
x_train=np.zeros((shape[0], shape[1], 200))
j=0
for in_id in input_ids:
    x_train[j]=M_GLOVE_space[in_id]
    j+=1
# Out:
# Pesos de clases: [1. 1. 1. 1.]

# %%
ids_val=val['Tw_id']
tws_val=val['Tweet']
labels_val=[d_lab[lb] for lb in val['Label']]

etiq_v=labels_val.copy()
etiq_v=np.asarray(etiq_v)
sentences_val = tws_val
n_labels_val = np.array(etiq_v)
y_val=to_categorical(n_labels_val,num_classes=4)

input_ids_val=[]
for sent in sentences_val:
    sent_cl=cleaner(sent)[1]
    encoded_sent=[]
    for wd in sent_cl:
        try: 
            encoded_sent.append(Word2Index[wd])
        except: 
            continue   
    input_ids_val.append(encoded_sent)
    
ids_test=test['Tw_id']
tws_test=test['Tweet']
labels_test=[d_lab[lb] for lb in test['Label']]

etiq_t=labels_test.copy()
etiq_t=np.asarray(etiq_t)
sentences_test = tws_test
n_labels_test = np.array(etiq_t)
y_test=to_categorical(n_labels_test,num_classes=4)

input_ids_test=[]
for sent in sentences_test:
    sent_cl=cleaner(sent)[1]
    encoded_sent=[]
    for wd in sent_cl:
        try: 
            encoded_sent.append(Word2Index[wd])
        except: 
            continue   
    input_ids_test.append(encoded_sent)
    
input_ids_val = pad_sequences(input_ids_val,maxlen=MAX_LEN,dtype="long",value=0, truncating="post", padding="post")
input_ids_test = pad_sequences(input_ids_test,maxlen=MAX_LEN,dtype="long",value=0, truncating="post", padding="post")


shape_val=np.asarray(input_ids_val).shape
x_val=np.zeros((shape_val[0], shape_val[1], 200))
i=0
for in_id in input_ids_val:
    x_val[i]=M_GLOVE_space[in_id]
    i+=1
    
shape_test=np.asarray(input_ids_test).shape
x_test=np.zeros((shape_test[0], shape_test[1], 200))
i=0
for in_id in input_ids_test:
    x_test[i]=M_GLOVE_space[in_id]
    i+=1

x_test.shape
# Out:
# (1021, 37, 200)

# %%
del embeddings_index

# %% [markdown]
# ## 0.0 No Class Weigths

# %%
global_accs=[]
global_fnones=[]
global_fmacros=[]
global_cms=[]
global_attn=[]
dict_attn_enc={'00':[], '01':[], '02':[], '03':[], '10':[], '11':[], '12':[], '13':[]}
  
prob=0.0

for trans in range(1,6): 
    print ("Entrenando Run #", trans)
    cnn1 = load_model('../new_glove_augmented/stance_baselines/'+str(prob)+'/cnn1_'+str(trans)+'-exec.h5')
    cnn2 = load_model('../new_glove_augmented/stance_baselines/'+str(prob)+'/cnn2_'+str(trans)+'-exec.h5')
    rnn1 = load_model('../new_glove_augmented/stance_baselines/'+str(prob)+'/rnn1_'+str(trans)+'-exec.h5')
    rnn2 = load_model('../new_glove_augmented/stance_baselines/'+str(prob)+'/rnn2_'+str(trans)+'-exec.h5')
    rnn3 = load_model('../new_glove_augmented/stance_baselines/'+str(prob)+'/rnn3_'+str(trans)+'-exec.h5')

    list_models=['cnn1', 'cnn2', 'rnn1', 'rnn2', 'rnn3']
    index_models=np.arange(5)
    dict_models=dict((key, value) for (key, value) in zip(index_models,list_models))
    modelos=[cnn1, cnn2, rnn1, rnn2, rnn3]
    ind=np.arange(5)
    dict_trainedModel=dict((key, value) for (key, value) in zip(ind,modelos))

    bs=32
    predicciones_all=[]
    predicciones_all_val=[]
    predicciones_all_test=[]
    
    print ("agregando predicciones Train")
    for i in dict_trainedModel.keys(): 
        a_evaluar=dict_models[i]
        predicciones_all.append(dict_trainedModel[i].predict(x_train, batch_size=bs))
    print ("agregando predicciones Val")
    for i in dict_trainedModel.keys(): 
        a_evaluar=dict_models[i]
        predicciones_all_val.append(dict_trainedModel[i].predict(x_val, batch_size=bs))
    print ("agregando predicciones Test")
    for i in dict_trainedModel.keys(): 
        a_evaluar=dict_models[i]
        predicciones_all_test.append(dict_trainedModel[i].predict(x_test, batch_size=bs))

    matrix=np.asarray(predicciones_all)
    matrix_val=np.asarray(predicciones_all_val)
    matrix_test=np.asarray(predicciones_all_test)
    new_matrix=np.concatenate([matrix,matrix_val,matrix_test], axis=1)
    
    
    espacio=[np.ones(g_dim)]
    #Ks=np.load("../../BERTransformer/Orthogonals_768.npy")
    
    Ks= ortho_group.rvs(dim=g_dim)
    random=np.random.randint(Ks.shape[0], size=4)
    K_list=Ks[random]
    #print (K_list.shape)
    #break
    K_list_ext=espacio+list(K_list)
    index_embeddings=[0,1,2,3,4]
    lab_str_embeddings=['','','','','']

    for i in range(len(sentences)):
        ide=ids_train[i]
        tw_tr=tws_train[i]
        tokens=cleaner(tw_tr)[1]
        clase=dict_cl[labels_train[i]]
        encoded_tok=[]
        for wd in tokens:
            try: 
                encoded_tok.append(Word2Index[wd])
            except: 
                continue 
                
        q_glove=len(encoded_tok)
        glove_tok_f=[M_GLOVE_space[ide] for ide in encoded_tok]
        final=np.sum(glove_tok_f, axis=0)
        final_awe=final/q_glove
        norm=np.linalg.norm(final_awe)
        final_awe= final_awe / norm
        #print ("final tiene norma (AWE)", np.linalg.norm(final_awe ))        
        index_embeddings.append(i+5)
        lab_str_embeddings.append(clase)
        K_list_ext.append(final_awe)
    
    
    objs_val=val['Tw_id']      #df_val['Unnamed: 0'].values
    objs_test=test['Tw_id']    #np.arange(df_test.shape[0])
    lab_val=val['Label']
    lab_test=test['Label']
    tw_val=val['Tweet']
    tw_test=test['Tweet']
    llaves=np.concatenate([objs_val,objs_test])
    clases=np.concatenate([lab_val,lab_test])
    sent_all=np.concatenate([tw_val,tw_test])

    for num in range(len(llaves)):
        i=llaves[num]
        clase=clases[num]
        tw_tr=sent_all[num]
        #vector=np.load("../BaS_Original/Original/"+str(i)+".npy")
        tokens=cleaner(tw_tr)[1]
        encoded_tok=[]
        for wd in tokens:
            try: 
                encoded_tok.append(Word2Index[wd])
            except: 
                continue 

        q_glove=len(encoded_tok)
        glove_tok_f=[M_GLOVE_space[ide] for ide in encoded_tok]
        final=np.sum(glove_tok_f, axis=0)
        final_awe=final/q_glove
        norm=np.linalg.norm(final_awe)
        final_awe= final_awe / norm

        index_embeddings.append(num+5+train.shape[0])
        lab_str_embeddings.append(clase)
        K_list_ext.append(final_awe)

    K_list_new= np.asarray(K_list_ext, dtype='float32')
    
    ###################################### TRANSFORMER ###############################
    V = 4
    pesos = torch.from_numpy(class_weights).float()
    criterion = FocalLoss(weights=pesos)
    model = make_model_concat(4, N=2,d_model=g_dim, d_ff=128, h=4, dropout=0.35)
    model_opt = NoamOpt(model.src_embed[0].d_model, 1, 500, torch.optim.Adam(model.parameters(), lr=0, betas=(0.9, 0.98), eps=1e-5))

    
    for epoch in range(40):
        model.train()
        DATA=data_gen(32, 'Train', 5, new_matrix)
        loss_train, acc_train,fma_train, f_none, cm_train=run_epoch(DATA, model, SimpleLossComputeFL(criterion, model_opt), 'Train')
        
        model.eval()
        loss_val, acc_val,fma_val, f_val_none, cm_val=run_epoch(data_gen(bs, 'Val', 5, new_matrix), model, SimpleLossComputeFL(criterion, None),'Val')
        print ("Epoch",epoch, "\tacc_val:",acc_val, "\tF-macro_val:",fma_val)
    
    model.eval()
    print ("Testing run #",trans)
    predicciones = run_epoch(data_gen(bs, 'Test', 5, new_matrix), model, SimpleLossComputeFL(criterion, None),'Test')
    predicciones=np.concatenate(predicciones, axis=-1)
    
    glo_acc=accuracy_score(etiq_t, predicciones[:-3])
    glo_fno=f1_score(etiq_t,predicciones[:-3], average=None)
    glo_fma=f1_score(etiq_t,predicciones[:-3], average='macro')

    glo_cm=confusion_matrix(etiq_t, predicciones[:-3])

    plot_confusion_matrix(glo_cm,["support","Denying","Questioning","Commenting"],"Pre-trained Sin Aum 40-e Stance")
    global_accs.append(glo_acc)
    global_fnones.append(glo_fno)
    global_fmacros.append(glo_fma)
    global_cms.append(glo_cm)
    print("Test_ acc:",glo_acc) 
    print("Test_ f1 none:",glo_fno) 
    print("Test_ f1 macro:",glo_fma) 

    label=[['Text', 'm1', 'm2','m3','m4','m5']]
    for layer in range(2):
        fig, axs = plt.subplots(1,4, figsize=(20, 10))
        print ("Encoder Layer Attention head", layer)
        for head in range(4):
            matriz_attn=model.encoder.layers[layer].self_attn.attn[0,head].data
            dict_attn_enc[str(layer)+str(head)].append(matriz_attn)
            sns.heatmap(matriz_attn, xticklabels=label[0], yticklabels=label[0],
                        vmin=0.0, vmax=1.0, linewidths=.5, cmap="Blues", cbar=False, square=True, ax=axs[head]) #, annot=False,cbar_kws={"orientation": "horizontal","pad": 0.25})
        plt.show()
# Out:
# Entrenando Run # 1
# agregando predicciones Train
# agregando predicciones Val
# agregando predicciones Test
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.5104, dtype=torch.float64) 	F-macro_val: tensor(0.2219, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.6562, dtype=torch.float64) 	F-macro_val: tensor(0.3044, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.6806, dtype=torch.float64) 	F-macro_val: tensor(0.3517, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.7014, dtype=torch.float64) 	F-macro_val: tensor(0.4126, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.7153, dtype=torch.float64) 	F-macro_val: tensor(0.4372, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.7188, dtype=torch.float64) 	F-macro_val: tensor(0.4862, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.7326, dtype=torch.float64) 	F-macro_val: tensor(0.4900, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.7326, dtype=torch.float64) 	F-macro_val: tensor(0.4999, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.7188, dtype=torch.float64) 	F-macro_val: tensor(0.5080, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.7153, dtype=torch.float64) 	F-macro_val: tensor(0.4881, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.7188, dtype=torch.float64) 	F-macro_val: tensor(0.4866, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.7292, dtype=torch.float64) 	F-macro_val: tensor(0.5474, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.7326, dtype=torch.float64) 	F-macro_val: tensor(0.5381, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.7326, dtype=torch.float64) 	F-macro_val: tensor(0.5309, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.7326, dtype=torch.float64) 	F-macro_val: tensor(0.5440, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.7257, dtype=torch.float64) 	F-macro_val: tensor(0.5286, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.7153, dtype=torch.float64) 	F-macro_val: tensor(0.5086, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.7257, dtype=torch.float64) 	F-macro_val: tensor(0.5380, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.7361, dtype=torch.float64) 	F-macro_val: tensor(0.5534, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.7361, dtype=torch.float64) 	F-macro_val: tensor(0.5504, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.7361, dtype=torch.float64) 	F-macro_val: tensor(0.5222, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.7292, dtype=torch.float64) 	F-macro_val: tensor(0.5463, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.7292, dtype=torch.float64) 	F-macro_val: tensor(0.5391, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.7222, dtype=torch.float64) 	F-macro_val: tensor(0.5115, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.7326, dtype=torch.float64) 	F-macro_val: tensor(0.5373, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.7257, dtype=torch.float64) 	F-macro_val: tensor(0.5464, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.7326, dtype=torch.float64) 	F-macro_val: tensor(0.5417, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.7326, dtype=torch.float64) 	F-macro_val: tensor(0.5608, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.7326, dtype=torch.float64) 	F-macro_val: tensor(0.5400, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.7361, dtype=torch.float64) 	F-macro_val: tensor(0.5754, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.7361, dtype=torch.float64) 	F-macro_val: tensor(0.5186, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.7361, dtype=torch.float64) 	F-macro_val: tensor(0.5625, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.7292, dtype=torch.float64) 	F-macro_val: tensor(0.5642, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.7292, dtype=torch.float64) 	F-macro_val: tensor(0.5613, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.7222, dtype=torch.float64) 	F-macro_val: tensor(0.5296, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.7292, dtype=torch.float64) 	F-macro_val: tensor(0.5566, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.7326, dtype=torch.float64) 	F-macro_val: tensor(0.5338, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.7292, dtype=torch.float64) 	F-macro_val: tensor(0.5382, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.7326, dtype=torch.float64) 	F-macro_val: tensor(0.5778, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.7257, dtype=torch.float64) 	F-macro_val: tensor(0.5314, dtype=torch.float64)
# Testing run # 1
# SE TUVIERON QUE REPETIR 3 EJEMPLOS
# Test_ acc: 0.7610186092066601
# Test_ f1 none: [0.10084034 0.15555556 0.62311558 0.85924113]
# Test_ f1 macro: 0.434688148912612
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 2
# agregando predicciones Train
# agregando predicciones Val
# agregando predicciones Test
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.2118, dtype=torch.float64) 	F-macro_val: tensor(0.1562, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.6528, dtype=torch.float64) 	F-macro_val: tensor(0.3113, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.6910, dtype=torch.float64) 	F-macro_val: tensor(0.3531, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.6979, dtype=torch.float64) 	F-macro_val: tensor(0.3987, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.6979, dtype=torch.float64) 	F-macro_val: tensor(0.4167, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.6910, dtype=torch.float64) 	F-macro_val: tensor(0.4121, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.7014, dtype=torch.float64) 	F-macro_val: tensor(0.4350, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.4286, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.7014, dtype=torch.float64) 	F-macro_val: tensor(0.4391, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.6979, dtype=torch.float64) 	F-macro_val: tensor(0.4563, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.7014, dtype=torch.float64) 	F-macro_val: tensor(0.4407, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.4320, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.4390, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.4509, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.4706, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.7153, dtype=torch.float64) 	F-macro_val: tensor(0.4637, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.4518, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.6979, dtype=torch.float64) 	F-macro_val: tensor(0.4553, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.7014, dtype=torch.float64) 	F-macro_val: tensor(0.4536, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.7153, dtype=torch.float64) 	F-macro_val: tensor(0.4660, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.7049, dtype=torch.float64) 	F-macro_val: tensor(0.4509, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.7014, dtype=torch.float64) 	F-macro_val: tensor(0.4608, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.4447, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.7014, dtype=torch.float64) 	F-macro_val: tensor(0.4596, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.7014, dtype=torch.float64) 	F-macro_val: tensor(0.4580, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.7049, dtype=torch.float64) 	F-macro_val: tensor(0.4239, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.7153, dtype=torch.float64) 	F-macro_val: tensor(0.4635, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.7188, dtype=torch.float64) 	F-macro_val: tensor(0.4613, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.7014, dtype=torch.float64) 	F-macro_val: tensor(0.4671, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.4359, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.7049, dtype=torch.float64) 	F-macro_val: tensor(0.4767, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.7188, dtype=torch.float64) 	F-macro_val: tensor(0.5002, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.4382, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.7153, dtype=torch.float64) 	F-macro_val: tensor(0.4532, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.7188, dtype=torch.float64) 	F-macro_val: tensor(0.4736, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.7153, dtype=torch.float64) 	F-macro_val: tensor(0.4753, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.7222, dtype=torch.float64) 	F-macro_val: tensor(0.4874, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.7188, dtype=torch.float64) 	F-macro_val: tensor(0.4679, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.7153, dtype=torch.float64) 	F-macro_val: tensor(0.4581, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.7188, dtype=torch.float64) 	F-macro_val: tensor(0.4599, dtype=torch.float64)
# Testing run # 2
# SE TUVIERON QUE REPETIR 3 EJEMPLOS
# Test_ acc: 0.7571008814887366
# Test_ f1 none: [0.05769231 0.09756098 0.5        0.85781991]
# Test_ f1 macro: 0.3782682971288335
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 3
# agregando predicciones Train
# agregando predicciones Val
# agregando predicciones Test
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.5035, dtype=torch.float64) 	F-macro_val: tensor(0.3658, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.7014, dtype=torch.float64) 	F-macro_val: tensor(0.4648, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.6944, dtype=torch.float64) 	F-macro_val: tensor(0.4236, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.6840, dtype=torch.float64) 	F-macro_val: tensor(0.4661, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.6771, dtype=torch.float64) 	F-macro_val: tensor(0.4584, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.6771, dtype=torch.float64) 	F-macro_val: tensor(0.4629, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.6840, dtype=torch.float64) 	F-macro_val: tensor(0.4475, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.6806, dtype=torch.float64) 	F-macro_val: tensor(0.4351, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.6771, dtype=torch.float64) 	F-macro_val: tensor(0.4635, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.6875, dtype=torch.float64) 	F-macro_val: tensor(0.4699, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.6771, dtype=torch.float64) 	F-macro_val: tensor(0.4494, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.6840, dtype=torch.float64) 	F-macro_val: tensor(0.4611, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.6840, dtype=torch.float64) 	F-macro_val: tensor(0.4330, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.6701, dtype=torch.float64) 	F-macro_val: tensor(0.4528, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.6840, dtype=torch.float64) 	F-macro_val: tensor(0.4520, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.6806, dtype=torch.float64) 	F-macro_val: tensor(0.4535, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.6875, dtype=torch.float64) 	F-macro_val: tensor(0.4872, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.6840, dtype=torch.float64) 	F-macro_val: tensor(0.4664, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.6944, dtype=torch.float64) 	F-macro_val: tensor(0.4452, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.6910, dtype=torch.float64) 	F-macro_val: tensor(0.4528, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.6944, dtype=torch.float64) 	F-macro_val: tensor(0.4544, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.6944, dtype=torch.float64) 	F-macro_val: tensor(0.4569, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.6840, dtype=torch.float64) 	F-macro_val: tensor(0.4639, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.6840, dtype=torch.float64) 	F-macro_val: tensor(0.4770, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.6875, dtype=torch.float64) 	F-macro_val: tensor(0.4687, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.6806, dtype=torch.float64) 	F-macro_val: tensor(0.4654, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.6944, dtype=torch.float64) 	F-macro_val: tensor(0.4575, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.6840, dtype=torch.float64) 	F-macro_val: tensor(0.4543, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.6944, dtype=torch.float64) 	F-macro_val: tensor(0.4650, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.6840, dtype=torch.float64) 	F-macro_val: tensor(0.4482, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.6840, dtype=torch.float64) 	F-macro_val: tensor(0.4242, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.6979, dtype=torch.float64) 	F-macro_val: tensor(0.4795, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.6875, dtype=torch.float64) 	F-macro_val: tensor(0.4315, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.6875, dtype=torch.float64) 	F-macro_val: tensor(0.4597, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.6875, dtype=torch.float64) 	F-macro_val: tensor(0.4727, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.6875, dtype=torch.float64) 	F-macro_val: tensor(0.4583, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.6944, dtype=torch.float64) 	F-macro_val: tensor(0.4731, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.6840, dtype=torch.float64) 	F-macro_val: tensor(0.4513, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.6979, dtype=torch.float64) 	F-macro_val: tensor(0.4495, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.6944, dtype=torch.float64) 	F-macro_val: tensor(0.4557, dtype=torch.float64)
# Testing run # 3
# SE TUVIERON QUE REPETIR 3 EJEMPLOS
# Test_ acc: 0.7629774730656219
# Test_ f1 none: [0.08510638 0.11764706 0.4939759  0.85916323]
# Test_ f1 macro: 0.38897314366119007
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 4
# agregando predicciones Train
# agregando predicciones Val
# agregando predicciones Test
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.6111, dtype=torch.float64) 	F-macro_val: tensor(0.3264, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.6910, dtype=torch.float64) 	F-macro_val: tensor(0.3842, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.7014, dtype=torch.float64) 	F-macro_val: tensor(0.4260, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.4376, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.7153, dtype=torch.float64) 	F-macro_val: tensor(0.4778, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.7188, dtype=torch.float64) 	F-macro_val: tensor(0.4516, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.7188, dtype=torch.float64) 	F-macro_val: tensor(0.4392, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.7153, dtype=torch.float64) 	F-macro_val: tensor(0.4563, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.7153, dtype=torch.float64) 	F-macro_val: tensor(0.4766, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.7188, dtype=torch.float64) 	F-macro_val: tensor(0.4392, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.7222, dtype=torch.float64) 	F-macro_val: tensor(0.4461, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.7222, dtype=torch.float64) 	F-macro_val: tensor(0.4890, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.7188, dtype=torch.float64) 	F-macro_val: tensor(0.4612, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.7222, dtype=torch.float64) 	F-macro_val: tensor(0.4465, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.7188, dtype=torch.float64) 	F-macro_val: tensor(0.4575, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.7222, dtype=torch.float64) 	F-macro_val: tensor(0.4616, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.7257, dtype=torch.float64) 	F-macro_val: tensor(0.4900, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.7292, dtype=torch.float64) 	F-macro_val: tensor(0.4624, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.7222, dtype=torch.float64) 	F-macro_val: tensor(0.4464, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.7292, dtype=torch.float64) 	F-macro_val: tensor(0.4711, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.7153, dtype=torch.float64) 	F-macro_val: tensor(0.4413, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.7188, dtype=torch.float64) 	F-macro_val: tensor(0.4355, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.7222, dtype=torch.float64) 	F-macro_val: tensor(0.4487, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.7292, dtype=torch.float64) 	F-macro_val: tensor(0.4752, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.7188, dtype=torch.float64) 	F-macro_val: tensor(0.4987, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.7188, dtype=torch.float64) 	F-macro_val: tensor(0.4821, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.7292, dtype=torch.float64) 	F-macro_val: tensor(0.4837, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.7292, dtype=torch.float64) 	F-macro_val: tensor(0.4904, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.7257, dtype=torch.float64) 	F-macro_val: tensor(0.4854, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.7292, dtype=torch.float64) 	F-macro_val: tensor(0.4848, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.7257, dtype=torch.float64) 	F-macro_val: tensor(0.4994, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.7396, dtype=torch.float64) 	F-macro_val: tensor(0.4912, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.7396, dtype=torch.float64) 	F-macro_val: tensor(0.4564, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.7326, dtype=torch.float64) 	F-macro_val: tensor(0.4894, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.7292, dtype=torch.float64) 	F-macro_val: tensor(0.4894, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.7257, dtype=torch.float64) 	F-macro_val: tensor(0.4681, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.7361, dtype=torch.float64) 	F-macro_val: tensor(0.5238, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.7292, dtype=torch.float64) 	F-macro_val: tensor(0.4787, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.7361, dtype=torch.float64) 	F-macro_val: tensor(0.4455, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.7222, dtype=torch.float64) 	F-macro_val: tensor(0.4972, dtype=torch.float64)
# Testing run # 4
# SE TUVIERON QUE REPETIR 3 EJEMPLOS
# Test_ acc: 0.77179236043095
# Test_ f1 none: [0.04651163 0.15730337 0.54143646 0.86595492]
# Test_ f1 macro: 0.40280159641907903
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 5
# agregando predicciones Train
# agregando predicciones Val
# agregando predicciones Test
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.6111, dtype=torch.float64) 	F-macro_val: tensor(0.2594, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.6632, dtype=torch.float64) 	F-macro_val: tensor(0.2986, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.4283, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.7257, dtype=torch.float64) 	F-macro_val: tensor(0.4641, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.4344, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.4832, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.4450, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.7153, dtype=torch.float64) 	F-macro_val: tensor(0.4600, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.4533, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.4727, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.4718, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.7153, dtype=torch.float64) 	F-macro_val: tensor(0.4602, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.7153, dtype=torch.float64) 	F-macro_val: tensor(0.4804, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.7153, dtype=torch.float64) 	F-macro_val: tensor(0.4740, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.4345, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.4426, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.4727, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.4550, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.7153, dtype=torch.float64) 	F-macro_val: tensor(0.4586, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.4435, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.7153, dtype=torch.float64) 	F-macro_val: tensor(0.4573, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.4714, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.7153, dtype=torch.float64) 	F-macro_val: tensor(0.4695, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.7222, dtype=torch.float64) 	F-macro_val: tensor(0.4843, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.7014, dtype=torch.float64) 	F-macro_val: tensor(0.4435, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.7049, dtype=torch.float64) 	F-macro_val: tensor(0.4694, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.7153, dtype=torch.float64) 	F-macro_val: tensor(0.4851, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.7049, dtype=torch.float64) 	F-macro_val: tensor(0.4577, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.7222, dtype=torch.float64) 	F-macro_val: tensor(0.4639, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.7153, dtype=torch.float64) 	F-macro_val: tensor(0.4881, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.4838, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.4577, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.4552, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.7014, dtype=torch.float64) 	F-macro_val: tensor(0.4272, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.4101, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.4660, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.7222, dtype=torch.float64) 	F-macro_val: tensor(0.4683, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.7188, dtype=torch.float64) 	F-macro_val: tensor(0.4937, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.7188, dtype=torch.float64) 	F-macro_val: tensor(0.4829, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.7153, dtype=torch.float64) 	F-macro_val: tensor(0.4718, dtype=torch.float64)
# Testing run # 5
# SE TUVIERON QUE REPETIR 3 EJEMPLOS
# Test_ acc: 0.7708129285014691
# Test_ f1 none: [0.22680412 0.1        0.41025641 0.86600351]
# Test_ f1 macro: 0.4007660111981986
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1

# %%
print ("Acc:",np.mean(np.asarray(global_accs)))
print ("F-score:", np.mean(np.asarray(global_fmacros)))
sup=np.mean(np.asarray(global_fnones)[:,0])
den=np.mean(np.asarray(global_fnones)[:,1])
que=np.mean(np.asarray(global_fnones)[:,2])
com=np.mean(np.asarray(global_fnones)[:,3])

print ("S-D-Q-C:", sup,den,que,com)
# Out:
# Acc: 0.7647404505386876
# F-score: 0.4010994394639826
# S-D-Q-C: 0.10339095568476035 0.12561339215507156 0.5137568711697427 0.861636538846356

# %%
m_temp=np.zeros((4,4))
for m in global_cms:
    m_temp+=np.asarray(m)
m_temp
# Out:
# array([[2.600e+01, 6.000e+00, 2.000e+00, 3.060e+02],
#        [2.000e+00, 2.700e+01, 1.000e+01, 3.060e+02],
#        [1.400e+01, 3.000e+00, 2.260e+02, 2.870e+02],
#        [1.180e+02, 4.500e+01, 1.020e+02, 3.625e+03]])

# %%
plot_confusion_matrix(normalize(m_temp),["S","D","Q","C"],"GloVe Transformer No aum - No CW", cmap='Blues')

# %%
label=[['Text', 'm1', 'm2','m3','m4','m5']]
for layer in range(2):
    fig, axs = plt.subplots(1,4, figsize=(20, 10))
    print ("Encoder Layer Attention head Promedio", layer)
    for head in range(4):
        at=np.zeros((6,6))
        matriz_attn= dict_attn_enc[str(layer)+str(head)]  #lista de 5 corridas en cada pos
        for m in matriz_attn:
            at+=m.numpy()
        sns.heatmap(at/5., xticklabels=label[0], yticklabels=label[0],
                    vmin=0.0, vmax=1.0, linewidths=.5, cmap="Purples", cbar=False, square=True, ax=axs[head]) #, annot=False,cbar_kws={"orientation": "horizontal","pad": 0.25})
    plt.show()
# Out:
# Encoder Layer Attention head Promedio 0
# Encoder Layer Attention head Promedio 1

# %% [markdown]
# ## 0.0 Class Weigths

# %%
class_weights= compute_class_weight('balanced', np.unique(labels_train), labels_train)
print ("Pesos de clases:", class_weights)
# Out:
# Pesos de clases: [1.25980975 3.18168168 3.21060606 0.38752743]

# %%
global_accs=[]
global_fnones=[]
global_fmacros=[]
global_cms=[]
global_attn=[]
dict_attn_enc={'00':[], '01':[], '02':[], '03':[], '10':[], '11':[], '12':[], '13':[]}
  
prob=0.0

for trans in range(1,6): 
    print ("Entrenando Run #", trans)
    cnn1 = load_model('../new_glove_augmented/stance_baselines/'+str(prob)+'_cw/cnn1_'+str(trans)+'-exec.h5')
    cnn2 = load_model('../new_glove_augmented/stance_baselines/'+str(prob)+'_cw/cnn2_'+str(trans)+'-exec.h5')
    rnn1 = load_model('../new_glove_augmented/stance_baselines/'+str(prob)+'_cw/rnn1_'+str(trans)+'-exec.h5')
    rnn2 = load_model('../new_glove_augmented/stance_baselines/'+str(prob)+'_cw/rnn2_'+str(trans)+'-exec.h5')
    rnn3 = load_model('../new_glove_augmented/stance_baselines/'+str(prob)+'_cw/rnn3_'+str(trans)+'-exec.h5')

    list_models=['cnn1', 'cnn2', 'rnn1', 'rnn2', 'rnn3']
    index_models=np.arange(5)
    dict_models=dict((key, value) for (key, value) in zip(index_models,list_models))
    modelos=[cnn1, cnn2, rnn1, rnn2, rnn3]
    ind=np.arange(5)
    dict_trainedModel=dict((key, value) for (key, value) in zip(ind,modelos))

    bs=32
    predicciones_all=[]
    predicciones_all_val=[]
    predicciones_all_test=[]
    
    print ("agregando predicciones Train")
    for i in dict_trainedModel.keys(): 
        a_evaluar=dict_models[i]
        predicciones_all.append(dict_trainedModel[i].predict(x_train, batch_size=bs))
    print ("agregando predicciones Val")
    for i in dict_trainedModel.keys(): 
        a_evaluar=dict_models[i]
        predicciones_all_val.append(dict_trainedModel[i].predict(x_val, batch_size=bs))
    print ("agregando predicciones Test")
    for i in dict_trainedModel.keys(): 
        a_evaluar=dict_models[i]
        predicciones_all_test.append(dict_trainedModel[i].predict(x_test, batch_size=bs))

    matrix=np.asarray(predicciones_all)
    matrix_val=np.asarray(predicciones_all_val)
    matrix_test=np.asarray(predicciones_all_test)
    new_matrix=np.concatenate([matrix,matrix_val,matrix_test], axis=1)
    
    
    espacio=[np.ones(g_dim)]
    #Ks=np.load("../../BERTransformer/Orthogonals_768.npy")
    
    Ks= ortho_group.rvs(dim=g_dim)
    random=np.random.randint(Ks.shape[0], size=4)
    K_list=Ks[random]
    #print (K_list.shape)
    #break
    K_list_ext=espacio+list(K_list)
    index_embeddings=[0,1,2,3,4]
    lab_str_embeddings=['','','','','']

    for i in range(len(sentences)):
        ide=ids_train[i]
        tw_tr=tws_train[i]
        tokens=cleaner(tw_tr)[1]
        clase=dict_cl[labels_train[i]]
        encoded_tok=[]
        for wd in tokens:
            try: 
                encoded_tok.append(Word2Index[wd])
            except: 
                continue 
                
        q_glove=len(encoded_tok)
        glove_tok_f=[M_GLOVE_space[ide] for ide in encoded_tok]
        final=np.sum(glove_tok_f, axis=0)
        final_awe=final/q_glove
        norm=np.linalg.norm(final_awe)
        final_awe= final_awe / norm
        #print ("final tiene norma (AWE)", np.linalg.norm(final_awe ))        
        index_embeddings.append(i+5)
        lab_str_embeddings.append(clase)
        K_list_ext.append(final_awe)
    
    
    objs_val=val['Tw_id']      #df_val['Unnamed: 0'].values
    objs_test=test['Tw_id']    #np.arange(df_test.shape[0])
    lab_val=val['Label']
    lab_test=test['Label']
    tw_val=val['Tweet']
    tw_test=test['Tweet']
    llaves=np.concatenate([objs_val,objs_test])
    clases=np.concatenate([lab_val,lab_test])
    sent_all=np.concatenate([tw_val,tw_test])

    for num in range(len(llaves)):
        i=llaves[num]
        clase=clases[num]
        tw_tr=sent_all[num]
        #vector=np.load("../BaS_Original/Original/"+str(i)+".npy")
        tokens=cleaner(tw_tr)[1]
        encoded_tok=[]
        for wd in tokens:
            try: 
                encoded_tok.append(Word2Index[wd])
            except: 
                continue 

        q_glove=len(encoded_tok)
        glove_tok_f=[M_GLOVE_space[ide] for ide in encoded_tok]
        final=np.sum(glove_tok_f, axis=0)
        final_awe=final/q_glove
        norm=np.linalg.norm(final_awe)
        final_awe= final_awe / norm

        index_embeddings.append(num+5+train.shape[0])
        lab_str_embeddings.append(clase)
        K_list_ext.append(final_awe)

    K_list_new= np.asarray(K_list_ext, dtype='float32')
    
    ###################################### TRANSFORMER ###############################
    V = 4
    pesos = torch.from_numpy(class_weights).float()
    criterion = FocalLoss(weights=pesos)
    model = make_model_concat(4, N=2,d_model=g_dim, d_ff=128, h=4, dropout=0.35)
    model_opt = NoamOpt(model.src_embed[0].d_model, 1, 500, torch.optim.Adam(model.parameters(), lr=0, betas=(0.9, 0.98), eps=1e-5))

    
    for epoch in range(40):
        model.train()
        DATA=data_gen(32, 'Train', 5, new_matrix)
        loss_train, acc_train,fma_train, f_none, cm_train=run_epoch(DATA, model, SimpleLossComputeFL(criterion, model_opt), 'Train')
        
        model.eval()
        loss_val, acc_val,fma_val, f_val_none, cm_val=run_epoch(data_gen(bs, 'Val', 5, new_matrix), model, SimpleLossComputeFL(criterion, None),'Val')
        print ("Epoch",epoch, "\tacc_val:",acc_val, "\tF-macro_val:",fma_val)
    
    model.eval()
    print ("Testing run #",trans)
    predicciones = run_epoch(data_gen(bs, 'Test', 5, new_matrix), model, SimpleLossComputeFL(criterion, None),'Test')
    predicciones=np.concatenate(predicciones, axis=-1)
    
    glo_acc=accuracy_score(etiq_t, predicciones[:-3])
    glo_fno=f1_score(etiq_t,predicciones[:-3], average=None)
    glo_fma=f1_score(etiq_t,predicciones[:-3], average='macro')

    glo_cm=confusion_matrix(etiq_t, predicciones[:-3])

    plot_confusion_matrix(glo_cm,["support","Denying","Questioning","Commenting"],"Pre-trained Sin Aum 40-e Stance")
    global_accs.append(glo_acc)
    global_fnones.append(glo_fno)
    global_fmacros.append(glo_fma)
    global_cms.append(glo_cm)
    print("Test_ acc:",glo_acc) 
    print("Test_ f1 none:",glo_fno) 
    print("Test_ f1 macro:",glo_fma) 

    label=[['Text', 'm1', 'm2','m3','m4','m5']]
    for layer in range(2):
        fig, axs = plt.subplots(1,4, figsize=(20, 10))
        print ("Encoder Layer Attention head", layer)
        for head in range(4):
            matriz_attn=model.encoder.layers[layer].self_attn.attn[0,head].data
            dict_attn_enc[str(layer)+str(head)].append(matriz_attn)
            sns.heatmap(matriz_attn, xticklabels=label[0], yticklabels=label[0],
                        vmin=0.0, vmax=1.0, linewidths=.5, cmap="Blues", cbar=False, square=True, ax=axs[head]) #, annot=False,cbar_kws={"orientation": "horizontal","pad": 0.25})
        plt.show()
# Out:
# Entrenando Run # 1
# agregando predicciones Train
# agregando predicciones Val
# agregando predicciones Test
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.6250, dtype=torch.float64) 	F-macro_val: tensor(0.3095, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.6493, dtype=torch.float64) 	F-macro_val: tensor(0.3423, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.6979, dtype=torch.float64) 	F-macro_val: tensor(0.5057, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.7014, dtype=torch.float64) 	F-macro_val: tensor(0.5019, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.7153, dtype=torch.float64) 	F-macro_val: tensor(0.5641, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.5134, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.7153, dtype=torch.float64) 	F-macro_val: tensor(0.5114, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.5479, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.7049, dtype=torch.float64) 	F-macro_val: tensor(0.5373, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.7153, dtype=torch.float64) 	F-macro_val: tensor(0.5385, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.5180, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.7222, dtype=torch.float64) 	F-macro_val: tensor(0.5194, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.5222, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.7153, dtype=torch.float64) 	F-macro_val: tensor(0.5197, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.7049, dtype=torch.float64) 	F-macro_val: tensor(0.5314, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.7153, dtype=torch.float64) 	F-macro_val: tensor(0.5493, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.5333, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.7014, dtype=torch.float64) 	F-macro_val: tensor(0.5056, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.7014, dtype=torch.float64) 	F-macro_val: tensor(0.5273, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.7014, dtype=torch.float64) 	F-macro_val: tensor(0.5211, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.5070, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.5526, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.7049, dtype=torch.float64) 	F-macro_val: tensor(0.5417, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.5224, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.7153, dtype=torch.float64) 	F-macro_val: tensor(0.5515, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.6979, dtype=torch.float64) 	F-macro_val: tensor(0.5365, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.5299, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.7188, dtype=torch.float64) 	F-macro_val: tensor(0.5458, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.7153, dtype=torch.float64) 	F-macro_val: tensor(0.5442, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.7222, dtype=torch.float64) 	F-macro_val: tensor(0.5649, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.7153, dtype=torch.float64) 	F-macro_val: tensor(0.5687, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.7153, dtype=torch.float64) 	F-macro_val: tensor(0.6091, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.5551, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.7188, dtype=torch.float64) 	F-macro_val: tensor(0.5338, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.7153, dtype=torch.float64) 	F-macro_val: tensor(0.5743, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.5802, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.7222, dtype=torch.float64) 	F-macro_val: tensor(0.5699, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.5297, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.7257, dtype=torch.float64) 	F-macro_val: tensor(0.5729, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.7188, dtype=torch.float64) 	F-macro_val: tensor(0.5681, dtype=torch.float64)
# Testing run # 1
# SE TUVIERON QUE REPETIR 3 EJEMPLOS
# Test_ acc: 0.7512242899118511
# Test_ f1 none: [0.04819277 0.22058824 0.63849765 0.84720497]
# Test_ f1 macro: 0.4386209069761785
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 2
# agregando predicciones Train
# agregando predicciones Val
# agregando predicciones Test
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.5625, dtype=torch.float64) 	F-macro_val: tensor(0.3119, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.6493, dtype=torch.float64) 	F-macro_val: tensor(0.3149, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.6875, dtype=torch.float64) 	F-macro_val: tensor(0.4416, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.6910, dtype=torch.float64) 	F-macro_val: tensor(0.4468, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.4948, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.4922, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.7153, dtype=torch.float64) 	F-macro_val: tensor(0.4974, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.7257, dtype=torch.float64) 	F-macro_val: tensor(0.5509, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.7292, dtype=torch.float64) 	F-macro_val: tensor(0.5624, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.7326, dtype=torch.float64) 	F-macro_val: tensor(0.5616, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.5083, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.7153, dtype=torch.float64) 	F-macro_val: tensor(0.5318, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.7222, dtype=torch.float64) 	F-macro_val: tensor(0.5154, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.7222, dtype=torch.float64) 	F-macro_val: tensor(0.5251, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.7292, dtype=torch.float64) 	F-macro_val: tensor(0.5104, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.7292, dtype=torch.float64) 	F-macro_val: tensor(0.5567, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.7222, dtype=torch.float64) 	F-macro_val: tensor(0.5365, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.7361, dtype=torch.float64) 	F-macro_val: tensor(0.5465, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.7257, dtype=torch.float64) 	F-macro_val: tensor(0.5641, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.7326, dtype=torch.float64) 	F-macro_val: tensor(0.5524, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.7326, dtype=torch.float64) 	F-macro_val: tensor(0.5510, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.7326, dtype=torch.float64) 	F-macro_val: tensor(0.5262, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.7188, dtype=torch.float64) 	F-macro_val: tensor(0.5444, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.7292, dtype=torch.float64) 	F-macro_val: tensor(0.5272, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.7396, dtype=torch.float64) 	F-macro_val: tensor(0.5604, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.7361, dtype=torch.float64) 	F-macro_val: tensor(0.5788, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.7361, dtype=torch.float64) 	F-macro_val: tensor(0.5534, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.7257, dtype=torch.float64) 	F-macro_val: tensor(0.5410, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.7257, dtype=torch.float64) 	F-macro_val: tensor(0.5347, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.7292, dtype=torch.float64) 	F-macro_val: tensor(0.5510, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.7292, dtype=torch.float64) 	F-macro_val: tensor(0.5406, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.5197, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.7222, dtype=torch.float64) 	F-macro_val: tensor(0.5539, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.7257, dtype=torch.float64) 	F-macro_val: tensor(0.5476, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.7292, dtype=torch.float64) 	F-macro_val: tensor(0.5645, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.7222, dtype=torch.float64) 	F-macro_val: tensor(0.5158, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.7257, dtype=torch.float64) 	F-macro_val: tensor(0.5614, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.7257, dtype=torch.float64) 	F-macro_val: tensor(0.5583, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.7326, dtype=torch.float64) 	F-macro_val: tensor(0.5370, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.7222, dtype=torch.float64) 	F-macro_val: tensor(0.5379, dtype=torch.float64)
# Testing run # 2
# SE TUVIERON QUE REPETIR 3 EJEMPLOS
# Test_ acc: 0.7561214495592556
# Test_ f1 none: [0.13675214 0.1978022  0.59615385 0.85239852]
# Test_ f1 macro: 0.44577667617335515
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 3
# agregando predicciones Train
# agregando predicciones Val
# agregando predicciones Test
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.3924, dtype=torch.float64) 	F-macro_val: tensor(0.2527, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.6493, dtype=torch.float64) 	F-macro_val: tensor(0.3041, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.6701, dtype=torch.float64) 	F-macro_val: tensor(0.4044, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.6979, dtype=torch.float64) 	F-macro_val: tensor(0.4850, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.6944, dtype=torch.float64) 	F-macro_val: tensor(0.4971, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.5362, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.7014, dtype=torch.float64) 	F-macro_val: tensor(0.5057, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.6979, dtype=torch.float64) 	F-macro_val: tensor(0.5343, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.6910, dtype=torch.float64) 	F-macro_val: tensor(0.5486, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.7153, dtype=torch.float64) 	F-macro_val: tensor(0.5689, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.5179, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.5285, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.7049, dtype=torch.float64) 	F-macro_val: tensor(0.5352, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.7049, dtype=torch.float64) 	F-macro_val: tensor(0.5280, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.5452, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.5555, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.6910, dtype=torch.float64) 	F-macro_val: tensor(0.5350, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.7049, dtype=torch.float64) 	F-macro_val: tensor(0.5735, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.5210, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.7014, dtype=torch.float64) 	F-macro_val: tensor(0.5402, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.5364, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.7049, dtype=torch.float64) 	F-macro_val: tensor(0.5318, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.5343, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.5155, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.5400, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.5009, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.5598, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.7049, dtype=torch.float64) 	F-macro_val: tensor(0.5804, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.7049, dtype=torch.float64) 	F-macro_val: tensor(0.5434, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.5389, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.6979, dtype=torch.float64) 	F-macro_val: tensor(0.5208, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.5293, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.5573, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.7049, dtype=torch.float64) 	F-macro_val: tensor(0.5746, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.7153, dtype=torch.float64) 	F-macro_val: tensor(0.5302, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.6979, dtype=torch.float64) 	F-macro_val: tensor(0.5563, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.7188, dtype=torch.float64) 	F-macro_val: tensor(0.5483, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.7153, dtype=torch.float64) 	F-macro_val: tensor(0.5624, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.5743, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.7049, dtype=torch.float64) 	F-macro_val: tensor(0.5156, dtype=torch.float64)
# Testing run # 3
# SE TUVIERON QUE REPETIR 3 EJEMPLOS
# Test_ acc: 0.7512242899118511
# Test_ f1 none: [0.08       0.24347826 0.61135371 0.84981227]
# Test_ f1 macro: 0.44616105949790563
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 4
# agregando predicciones Train
# agregando predicciones Val
# agregando predicciones Test
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.5035, dtype=torch.float64) 	F-macro_val: tensor(0.2309, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.6493, dtype=torch.float64) 	F-macro_val: tensor(0.3481, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.4726, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.7222, dtype=torch.float64) 	F-macro_val: tensor(0.4724, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.7292, dtype=torch.float64) 	F-macro_val: tensor(0.5115, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.7326, dtype=torch.float64) 	F-macro_val: tensor(0.5505, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.7396, dtype=torch.float64) 	F-macro_val: tensor(0.5254, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.7222, dtype=torch.float64) 	F-macro_val: tensor(0.5215, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.7361, dtype=torch.float64) 	F-macro_val: tensor(0.5062, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.7361, dtype=torch.float64) 	F-macro_val: tensor(0.5274, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.7257, dtype=torch.float64) 	F-macro_val: tensor(0.5424, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.7292, dtype=torch.float64) 	F-macro_val: tensor(0.5205, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.7222, dtype=torch.float64) 	F-macro_val: tensor(0.5064, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.7292, dtype=torch.float64) 	F-macro_val: tensor(0.5359, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.7292, dtype=torch.float64) 	F-macro_val: tensor(0.5252, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.7326, dtype=torch.float64) 	F-macro_val: tensor(0.5837, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.7257, dtype=torch.float64) 	F-macro_val: tensor(0.5207, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.7292, dtype=torch.float64) 	F-macro_val: tensor(0.5586, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.7361, dtype=torch.float64) 	F-macro_val: tensor(0.5499, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.7361, dtype=torch.float64) 	F-macro_val: tensor(0.4831, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.7326, dtype=torch.float64) 	F-macro_val: tensor(0.5611, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.7188, dtype=torch.float64) 	F-macro_val: tensor(0.5660, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.7188, dtype=torch.float64) 	F-macro_val: tensor(0.5364, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.7292, dtype=torch.float64) 	F-macro_val: tensor(0.5315, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.7257, dtype=torch.float64) 	F-macro_val: tensor(0.5083, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.7222, dtype=torch.float64) 	F-macro_val: tensor(0.5156, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.7257, dtype=torch.float64) 	F-macro_val: tensor(0.5349, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.7326, dtype=torch.float64) 	F-macro_val: tensor(0.5362, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.7257, dtype=torch.float64) 	F-macro_val: tensor(0.4975, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.7257, dtype=torch.float64) 	F-macro_val: tensor(0.5532, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.7222, dtype=torch.float64) 	F-macro_val: tensor(0.5252, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.7257, dtype=torch.float64) 	F-macro_val: tensor(0.5403, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.7188, dtype=torch.float64) 	F-macro_val: tensor(0.5055, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.7153, dtype=torch.float64) 	F-macro_val: tensor(0.5825, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.7153, dtype=torch.float64) 	F-macro_val: tensor(0.5485, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.7222, dtype=torch.float64) 	F-macro_val: tensor(0.5805, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.7188, dtype=torch.float64) 	F-macro_val: tensor(0.5458, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.7188, dtype=torch.float64) 	F-macro_val: tensor(0.5189, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.5417, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.7257, dtype=torch.float64) 	F-macro_val: tensor(0.5093, dtype=torch.float64)
# Testing run # 4
# SE TUVIERON QUE REPETIR 3 EJEMPLOS
# Test_ acc: 0.7159647404505387
# Test_ f1 none: [0.1037037  0.25373134 0.51396648 0.8293601 ]
# Test_ f1 macro: 0.4251904069526562
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 5
# agregando predicciones Train
# agregando predicciones Val
# agregando predicciones Test
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.4896, dtype=torch.float64) 	F-macro_val: tensor(0.2841, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.6076, dtype=torch.float64) 	F-macro_val: tensor(0.3175, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.6493, dtype=torch.float64) 	F-macro_val: tensor(0.3319, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.6979, dtype=torch.float64) 	F-macro_val: tensor(0.5351, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.7049, dtype=torch.float64) 	F-macro_val: tensor(0.5100, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.6875, dtype=torch.float64) 	F-macro_val: tensor(0.5267, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.7049, dtype=torch.float64) 	F-macro_val: tensor(0.5624, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.6806, dtype=torch.float64) 	F-macro_val: tensor(0.5532, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.5615, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.6979, dtype=torch.float64) 	F-macro_val: tensor(0.5429, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.5549, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.7049, dtype=torch.float64) 	F-macro_val: tensor(0.5278, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.7153, dtype=torch.float64) 	F-macro_val: tensor(0.5536, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.5462, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.6979, dtype=torch.float64) 	F-macro_val: tensor(0.5171, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.5540, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.6979, dtype=torch.float64) 	F-macro_val: tensor(0.5169, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.7153, dtype=torch.float64) 	F-macro_val: tensor(0.5583, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.7188, dtype=torch.float64) 	F-macro_val: tensor(0.5655, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.5550, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.5592, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.5366, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.5477, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.7153, dtype=torch.float64) 	F-macro_val: tensor(0.5585, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.7049, dtype=torch.float64) 	F-macro_val: tensor(0.5373, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.5401, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.5609, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.5203, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.7049, dtype=torch.float64) 	F-macro_val: tensor(0.5736, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.7014, dtype=torch.float64) 	F-macro_val: tensor(0.5346, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.5445, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.7049, dtype=torch.float64) 	F-macro_val: tensor(0.5723, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.5156, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.6840, dtype=torch.float64) 	F-macro_val: tensor(0.5214, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.7049, dtype=torch.float64) 	F-macro_val: tensor(0.5455, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.6979, dtype=torch.float64) 	F-macro_val: tensor(0.5527, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.5539, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.6875, dtype=torch.float64) 	F-macro_val: tensor(0.5331, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.7014, dtype=torch.float64) 	F-macro_val: tensor(0.5775, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.7049, dtype=torch.float64) 	F-macro_val: tensor(0.5410, dtype=torch.float64)
# Testing run # 5
# SE TUVIERON QUE REPETIR 3 EJEMPLOS
# Test_ acc: 0.692458374142997
# Test_ f1 none: [0.125      0.20408163 0.57723577 0.80604865]
# Test_ f1 macro: 0.4280915143033208
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1

# %%
print ("Acc:",np.mean(np.asarray(global_accs)))
print ("F-score:", np.mean(np.asarray(global_fmacros)))
sup=np.mean(np.asarray(global_fnones)[:,0])
den=np.mean(np.asarray(global_fnones)[:,1])
que=np.mean(np.asarray(global_fnones)[:,2])
com=np.mean(np.asarray(global_fnones)[:,3])

print ("S-D-Q-C:", sup,den,que,com)
# Out:
# Acc: 0.7333986287952987
# F-score: 0.4367681127806833
# S-D-Q-C: 0.09872972230803555 0.2239363339805048 0.5874414926662099 0.8369649021679827

# %%
m_temp=np.zeros((4,4))
for m in global_cms:
    m_temp+=np.asarray(m)
m_temp
# Out:
# array([[  29.,   14.,   10.,  287.],
#        [   9.,   70.,   12.,  254.],
#        [  14.,    9.,  317.,  190.],
#        [ 171.,  185.,  206., 3328.]])

# %%
plot_confusion_matrix(normalize(m_temp),["S","D","Q","C"],"GloVe Transformer No aum - Usa CW", cmap='Blues')

# %%
label=[['Text', 'm1', 'm2','m3','m4','m5']]
for layer in range(2):
    fig, axs = plt.subplots(1,4, figsize=(20, 10))
    print ("Encoder Layer Attention head Promedio", layer)
    for head in range(4):
        at=np.zeros((6,6))
        matriz_attn= dict_attn_enc[str(layer)+str(head)]  #lista de 5 corridas en cada pos
        for m in matriz_attn:
            at+=m.numpy()
        sns.heatmap(at/5., xticklabels=label[0], yticklabels=label[0],
                    vmin=0.0, vmax=1.0, linewidths=.5, cmap="Purples", cbar=False, square=True, ax=axs[head]) #, annot=False,cbar_kws={"orientation": "horizontal","pad": 0.25})
    plt.show()
# Out:
# Encoder Layer Attention head Promedio 0
# Encoder Layer Attention head Promedio 1

# %%
for h in range(2):
    for hy in range(4):
        to_mean=dict_attn_enc[str(h)+str(hy)]
        at=np.zeros((6,6))
        for m in to_mean:
            at+=m.numpy()  
        print (np.asarray(at))
        global_attn.append(at/5.)
        
global_attn
# Out:
# [[1.08126413 0.79745428 0.5952794  0.93442072 1.00145759 0.59012389]
#  [0.16862082 1.21834077 0.8550476  0.82281917 0.71153157 1.22363988]
#  [0.97307876 0.9118816  0.8996316  0.75540511 0.50973845 0.95026445]
#  [0.9285125  0.81511854 0.68188217 0.90721433 0.76270066 0.90457176]
#  [0.47376702 1.00344541 0.56213202 1.30518545 0.67367538 0.98179466]
#  [0.51054539 1.07853016 0.74832076 0.76716269 0.7274574  1.1679834 ]]
# [[1.11141307 0.37153694 0.64013365 0.73939768 1.27364792 0.86387076]
#  [1.83993792 0.60276033 0.50694266 0.77843957 0.62210461 0.64981471]
#  [1.47660211 0.47146351 0.89414937 0.68000578 0.83372646 0.64405291]
#  [1.18944231 0.70938006 0.92818862 0.63116693 0.87180106 0.67002112]
#  [1.06882451 0.80751418 0.86487952 0.93622245 0.52675591 0.79580321]
#  [1.81889623 0.59023293 0.61995031 0.67949886 0.74054753 0.550874  ]]
# [[0.69374431 1.34549364 1.00964616 0.4662222  0.61333885 0.87155472]
#  [1.16982363 0.76550035 0.78330997 1.18935785 0.42597883 0.6660295 ]
#  [1.76116315 0.50784    0.61652658 1.16378454 0.36383589 0.58684983]
#  [1.65067472 0.38621783 0.79408037 1.06366006 0.50688854 0.5984786 ]
#  [0.56963017 0.75689527 0.97593381 0.94345994 0.76217665 0.99190427]
#  [1.15905729 0.54151117 0.73780148 1.27710029 0.530758   0.75377195]]
# [[1.3180698  0.85261529 1.0094353  0.55751148 0.53083755 0.73153059]
#  [0.78687706 0.78629317 1.15933923 0.92850219 0.64170004 0.69728826]
#  [0.86458093 0.68126869 0.70811736 1.34049095 0.89590356 0.50963871]
#  [0.61187081 0.77307513 0.70165785 0.74279158 1.31469192 0.85591274]
#  [0.63241696 0.87274197 1.1614079  0.74117994 0.63842892 0.95382445]
#  [0.74422028 0.61987343 0.91029445 0.93392494 1.08897585 0.70271101]]
# [[1.16351806 0.65156287 1.05760108 0.77334841 0.73189957 0.62206994]
#  [0.94376358 0.70230108 0.8535939  0.99840801 0.82907925 0.67285427]
#  [0.9810413  0.73970705 0.83965372 0.84069026 0.84454053 0.75436686]
#  [1.02208327 0.71611947 0.81828443 0.89133239 0.80801876 0.74416182]
#  [1.15123561 0.70344846 0.78663445 0.91033339 0.82907065 0.61927739]
#  [0.94145215 0.67265877 0.86805828 1.02625486 0.79087497 0.70070112]]
# [[1.05668806 0.72339294 0.66338853 0.98639113 0.90238345 0.66775594]
#  [0.77808936 0.80961759 0.65982635 0.8600067  1.13770379 0.75475619]
#  [0.67169157 0.84297282 1.05150831 0.9316525  0.89511658 0.60705831]
#  [0.94128351 0.77926331 0.64461311 0.99613067 1.01692262 0.62178679]
#  [1.06299049 0.69241347 0.53946985 0.85033444 1.14195435 0.71283756]
#  [0.79001211 0.92399061 0.59314641 0.87176459 1.05457224 0.76651409]]
# [[0.67700779 0.85486408 0.82994875 0.91815026 0.85426252 0.8657665 ]
#  [0.8117868  0.84456219 0.78743626 1.00753605 0.824481   0.7241978 ]
#  [0.91149254 0.83447738 0.76999931 0.80097782 0.87585241 0.80720058]
#  [0.91820724 0.87676999 0.76679242 0.77316068 0.83860673 0.826463  ]
#  [0.56984987 0.90648345 0.96217032 0.96913034 0.71646432 0.87590163]
#  [0.84133133 0.7843276  0.82028922 1.01735887 0.80267244 0.73402061]]
# [[1.10604564 0.75076975 0.87231718 0.91340543 0.65737106 0.70009103]
#  [1.21190238 0.78454339 0.72247662 0.8244822  0.79422188 0.66237348]
#  [1.01526864 0.75119444 1.0198928  0.86232304 0.68656103 0.66476002]
#  [1.20300838 0.78680305 0.88823622 0.83446659 0.59455044 0.69293536]
#  [1.27940346 0.76956558 0.76659082 0.83847191 0.64691395 0.69905429]
#  [1.12950543 0.79890386 0.77257271 0.86714488 0.72683711 0.70503616]]
# [array([[0.21625283, 0.15949086, 0.11905588, 0.18688414, 0.20029152,
#          0.11802478],
#         [0.03372416, 0.24366815, 0.17100952, 0.16456383, 0.14230631,
#          0.24472798],
#         [0.19461575, 0.18237632, 0.17992632, 0.15108102, 0.10194769,
#          0.19005289],
#         [0.1857025 , 0.16302371, 0.13637643, 0.18144287, 0.15254013,
#          0.18091435],
#         [0.0947534 , 0.20068908, 0.1124264 , 0.26103709, 0.13473508,
#          0.19635893],
#         [0.10210908, 0.21570603, 0.14966415, 0.15343254, 0.14549148,
#          0.23359668]]),
#  array([[0.22228261, 0.07430739, 0.12802673, 0.14787954, 0.25472958,
#          0.17277415],
#         [0.36798758, 0.12055207, 0.10138853, 0.15568791, 0.12442092,
#          0.12996294],
#         [0.29532042, 0.0942927 , 0.17882987, 0.13600116, 0.16674529,
#          0.12881058],
#         [0.23788846, 0.14187601, 0.18563772, 0.12623339, 0.17436021,
#          0.13400422],
#         [0.2137649 , 0.16150284, 0.1729759 , 0.18724449, 0.10535118,
#          0.15916064],
#         [0.36377925, 0.11804659, 0.12399006, 0.13589977, 0.14810951,
#          0.1101748 ]]),
#  array([[0.13874886, 0.26909873, 0.20192923, 0.09324444, 0.12266777,
#          0.17431094],
#         [0.23396473, 0.15310007, 0.15666199, 0.23787157, 0.08519577,
#          0.1332059 ],
#         [0.35223263, 0.101568  , 0.12330532, 0.23275691, 0.07276718,
#          0.11736997],
#         [0.33013494, 0.07724357, 0.15881607, 0.21273201, 0.10137771,
#          0.11969572],
#         [0.11392603, 0.15137905, 0.19518676, 0.18869199, 0.15243533,
#          0.19838085],
#         [0.23181146, 0.10830223, 0.1475603 , 0.25542006, 0.1061516 ,
#          0.15075439]]),
#  array([[0.26361396, 0.17052306, 0.20188706, 0.1115023 , 0.10616751,
#          0.14630612],
#         [0.15737541, 0.15725863, 0.23186785, 0.18570044, 0.12834001,
#          0.13945765],
#         [0.17291619, 0.13625374, 0.14162347, 0.26809819, 0.17918071,
#          0.10192774],
#         [0.12237416, 0.15461503, 0.14033157, 0.14855832, 0.26293838,
#          0.17118255],
#         [0.12648339, 0.17454839, 0.23228158, 0.14823599, 0.12768578,
#          0.19076489],
#         [0.14884406, 0.12397469, 0.18205889, 0.18678499, 0.21779517,
#          0.1405422 ]]),
#  array([[0.23270361, 0.13031257, 0.21152022, 0.15466968, 0.14637991,
#          0.12441399],
#         [0.18875272, 0.14046022, 0.17071878, 0.1996816 , 0.16581585,
#          0.13457085],
#         [0.19620826, 0.14794141, 0.16793074, 0.16813805, 0.16890811,
#          0.15087337],
#         [0.20441665, 0.14322389, 0.16365689, 0.17826648, 0.16160375,
#          0.14883236],
#         [0.23024712, 0.14068969, 0.15732689, 0.18206668, 0.16581413,
#          0.12385548],
#         [0.18829043, 0.13453175, 0.17361166, 0.20525097, 0.15817499,
#          0.14014022]]),
#  array([[0.21133761, 0.14467859, 0.13267771, 0.19727823, 0.18047669,
#          0.13355119],
#         [0.15561787, 0.16192352, 0.13196527, 0.17200134, 0.22754076,
#          0.15095124],
#         [0.13433831, 0.16859456, 0.21030166, 0.1863305 , 0.17902332,
#          0.12141166],
#         [0.1882567 , 0.15585266, 0.12892262, 0.19922613, 0.20338452,
#          0.12435736],
#         [0.2125981 , 0.13848269, 0.10789397, 0.17006689, 0.22839087,
#          0.14256751],
#         [0.15800242, 0.18479812, 0.11862928, 0.17435292, 0.21091445,
#          0.15330282]]),
#  array([[0.13540156, 0.17097282, 0.16598975, 0.18363005, 0.1708525 ,
#          0.1731533 ],
#         [0.16235736, 0.16891244, 0.15748725, 0.20150721, 0.1648962 ,
#          0.14483956],
#         [0.18229851, 0.16689548, 0.15399986, 0.16019556, 0.17517048,
#          0.16144012],
#         [0.18364145, 0.175354  , 0.15335848, 0.15463214, 0.16772135,
#          0.1652926 ],
#         [0.11396997, 0.18129669, 0.19243406, 0.19382607, 0.14329286,
#          0.17518033],
#         [0.16826627, 0.15686552, 0.16405784, 0.20347177, 0.16053449,
#          0.14680412]]),
#  array([[0.22120913, 0.15015395, 0.17446344, 0.18268109, 0.13147421,
#          0.14001821],
#         [0.24238048, 0.15690868, 0.14449532, 0.16489644, 0.15884438,
#          0.1324747 ],
#         [0.20305373, 0.15023889, 0.20397856, 0.17246461, 0.13731221,
#          0.132952  ],
#         [0.24060168, 0.15736061, 0.17764724, 0.16689332, 0.11891009,
#          0.13858707],
#         [0.25588069, 0.15391312, 0.15331816, 0.16769438, 0.12938279,
#          0.13981086],
#         [0.22590109, 0.15978077, 0.15451454, 0.17342898, 0.14536742,
#          0.14100723]])]

# %%
np.save("Attn_SinAum_GloVe_sinBERT_CW.npy", global_attn)
