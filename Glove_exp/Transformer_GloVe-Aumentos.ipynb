# %%
import ast
from collections import Counter
from gensim import utils, matutils 
from gensim.corpora.dictionary import Dictionary
from gensim.utils import deprecated
import itertools
from nltk.corpus import stopwords
import numpy as np
from numpy import linalg as LA
from numpy.random import binomial
from numpy import dot, float32 as REAL, memmap as np_memmap, \
    double, array, zeros, vstack, sqrt, newaxis, integer, \
    ndarray, sum as np_sum, prod, argmax
from numpy.linalg import norm
import math, copy, time
import warnings 

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context(context="talk")
# %matplotlib inline

from keras import backend as K
from keras.models import load_model
from keras.preprocessing.sequence import pad_sequences
from keras import backend as K
import keras
from keras.utils import to_categorical
from keras.preprocessing import sequence
from keras.models import load_model

import os, sys, re, io, nltk, torch
import pandas as pd

from scipy import stats
from scipy.stats import bernoulli
from scipy.stats import ortho_group  # Requires version 0.18 of scipy
from scipy.spatial import distance
from sklearn.utils.class_weight import compute_class_weight
from sklearn.utils import class_weight
from sklearn.preprocessing import Normalizer, normalize
from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import accuracy_score,f1_score, confusion_matrix, recall_score, precision_score

from six import string_types, integer_types
from six.moves import zip, range
if not sys.warnoptions:
    warnings.simplefilter("ignore")

from tqdm import tqdm, trange
import time
import transformers
from transformers import (
    WEIGHTS_NAME,
    AdamW,
    BertConfig,
    BertForMaskedLM,
    BertForSequenceClassification,
    BertTokenizer,
    CamembertConfig,
    CamembertForMaskedLM,
    CamembertTokenizer,
    DistilBertConfig,
    DistilBertForMaskedLM,
    DistilBertTokenizer,
    GPT2Config,
    GPT2LMHeadModel,
    GPT2Tokenizer,
    OpenAIGPTConfig,
    OpenAIGPTLMHeadModel,
    OpenAIGPTTokenizer,
    RobertaConfig,
    RobertaForMaskedLM,
    RobertaTokenizer,
    get_linear_schedule_with_warmup,
)

import torch.nn.functional as F
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler
from torch.autograd import Variable
import re
from nltk.corpus import stopwords
from nltk import WordNetLemmatizer
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.porter import *

stemmer_sn = SnowballStemmer("english")
stemmer = PorterStemmer()

stoplist = stopwords.words("english")
lemmatizer=WordNetLemmatizer()


'''
Compatible with tensorflow backend
gamma entre más alto más tolerante (queremos un gamma chico pero no demasiado! 0.25 - 5)
alpha pesos por clase (weights)
'''
def focal_loss(gamma=2., weights=1):   #weights np.asarray()
    weights= K.variable(weights)
    def focal_loss_fixed(y_true, y_pred):
        y_true = K.clip(y_true, K.epsilon(),1)
        y_pred = K.clip(y_pred,K.epsilon(),1)
        return - K.sum(weights* K.pow(1. - y_pred, gamma)* y_true * K.log(y_pred), axis=-1) 
    return focal_loss_fixed

keras.losses.focal_loss=keras.losses.MSE
keras.losses.focal_loss_fixed=keras.losses.MSE

n_gpu = torch.cuda.device_count()
torch.cuda.get_device_name(0)

if torch.cuda.is_available():     
    device = torch.device("cuda")
    print('There are',torch.cuda.device_count(),'GPU(s) available.')
    print('We will use the GPU:', torch.cuda.get_device_name(0))

else:
    print('No GPU available, using the CPU instead.')
    device = torch.device("cpu")

if not sys.warnoptions:
    warnings.simplefilter("ignore")
    
class Dummy_Embeddings(nn.Module):
    def __init__(self, d_model, dummy_vectors): 
        super(Dummy_Embeddings, self).__init__()
        aux = torch.from_numpy(dummy_vectors)#, dtype='float32'))
        self.index2dummy = nn.Embedding(aux.size()[0], d_model)
        self.index2dummy.weigth=nn.Parameter(aux)
        self.index2dummy.weigth.requires_grad=False
        self.d_model = d_model
        
    def forward(self, x):
        aux=x.numpy()
        new_x= aux #- np.ones(aux.shape)
        new_x= torch.from_numpy(new_x)
        return self.index2dummy(new_x.long()) * math.sqrt(self.d_model) #debiese retornar matriz de batch_size x [ind_tw, k1,k2,k3,k4,k5,k6] (si son 6 modelos)
    
def match(objetos,ejemplo):
    i=0
    for obj in objetos:
        if obj==ejemplo:
            return i
        i+=1
        
def plot_confusion_matrix(cm, target_names, title='Confusion matrix (f1-score)',cmap=None, normalize=True):    
    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy
    if cmap is None:
        cmap = plt.get_cmap('Blues')
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        
    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap, vmin=0, vmax=1)
    plt.title(title)
    plt.colorbar()
    
    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)
    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()
    
    
class EncoderDecoderLogSoft(nn.Module):
    def __init__(self, encoder, src_embed, sequential):
        super(EncoderDecoderLogSoft, self).__init__()
        self.encoder = encoder
        self.linearSoft = sequential
        self.src_embed = src_embed
        
    def forward(self, src, src_mask):
        out=self.encode(src, src_mask)
        retorno=self.toSoftmax(out)
        return retorno
    
    def encode(self, src, src_mask):
        return self.encoder(self.src_embed(src), src_mask)
    
    def toSoftmax(self, tensor):
        a=tensor.size()[0]
        b=tensor.size()[-1]
        c=tensor.size()[-2]
        new_tensor= np.zeros((a, b))
        ini=True
        for ai in range(a):
            for ci in range(c):
                if ini:
                    new_tensor[ai]=tensor.data[ai][ci].numpy()
                    ini=False
                else: 
                    new_tensor[ai]*=tensor.data[ai][ci].numpy()
            ini=True
        new_tensor=torch.from_numpy(new_tensor)
        lineal=self.linearSoft(new_tensor.float())
        return F.log_softmax(lineal, dim = -1)
    
    def decode(self, memory, src_mask, tgt, tgt_mask):
        return self.decoder(self.tgt_embed(tgt), memory, src_mask, tgt_mask)
    
def clones(module, N):
    return nn.ModuleList([copy.deepcopy(module) for _ in range(N)])


class EncoderDecoderSoft(nn.Module):
    def __init__(self, encoder, src_embed, sequential):
        super(EncoderDecoderSoft, self).__init__()
        self.encoder = encoder
        self.linearSoft = sequential
        self.src_embed = src_embed
        
    def forward(self, src, src_mask):
        out=self.encode(src, src_mask)
        retorno=self.toSoftmax(out)
        return retorno
    
    def encode(self, src, src_mask):
        return self.encoder(self.src_embed(src), src_mask)
    
    def toSoftmax(self, tensor):
        a=tensor.size()[0]
        b=tensor.size()[-1]
        c=tensor.size()[-2]
        new_tensor= np.zeros((a, b))
        ini=True
        for ai in range(a):
            for ci in range(c):
                if ini:
                    new_tensor[ai]=tensor.data[ai][ci].numpy()
                    ini=False
                else: 
                    new_tensor[ai]*=tensor.data[ai][ci].numpy()
            ini=True
            
        new_tensor=torch.from_numpy(new_tensor)
        lineal=self.linearSoft(new_tensor.float())
        return F.softmax(lineal, dim = -1)
    
    def decode(self, memory, src_mask, tgt, tgt_mask):
        return self.decoder(self.tgt_embed(tgt), memory, src_mask, tgt_mask)
    
def clones(module, N):
    return nn.ModuleList([copy.deepcopy(module) for _ in range(N)])

class EncoderDecoder(nn.Module):
    def __init__(self, encoder, src_embed, generator):
        super(EncoderDecoder, self).__init__()
        self.encoder = encoder
        self.src_embed = src_embed
        self.generator = generator
        
    def forward(self, src, src_mask):
        return  self.encode(src, src_mask)

    def encode(self, src, src_mask):
        return self.encoder(self.src_embed(src), src_mask)
    
    def decode(self, memory, src_mask, tgt, tgt_mask):
        return self.decoder(self.tgt_embed(tgt), memory, src_mask, tgt_mask)
    
class Encoder(nn.Module):
    def __init__(self, layer, N):
        super(Encoder, self).__init__()
        self.layers = clones(layer, N)
        self.norm = LayerNorm(layer.size)
        
    def forward(self, x, mask):
        for layer in self.layers:
            x = layer(x, mask)
        return self.norm(x)
    
class LayerNorm(nn.Module):
    def __init__(self, features, eps=1e-6):
        super(LayerNorm, self).__init__()
        self.a_2 = nn.Parameter(torch.ones(features))
        self.b_2 = nn.Parameter(torch.zeros(features))
        self.eps = eps

    def forward(self, x):
        mean = x.mean(-1, keepdim=True)
        std = x.std(-1, keepdim=True)
        return self.a_2 * (x - mean) / (std + self.eps) + self.b_2
    
class SublayerConnection(nn.Module):
    def __init__(self, size, dropout):
        super(SublayerConnection, self).__init__()
        self.norm = LayerNorm(size)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, sublayer):
        return x + self.dropout(sublayer(self.norm(x)))    
    
class EncoderLayer(nn.Module):
    def __init__(self, size, self_attn, feed_forward, dropout):
        super(EncoderLayer, self).__init__()
        self.self_attn = self_attn
        self.feed_forward = feed_forward
        self.sublayer = clones(SublayerConnection(size, dropout), 2)
        self.size = size

    def forward(self, x, mask):
        x = self.sublayer[0](x, lambda x: self.self_attn(x, x, x, mask))
        return self.sublayer[1](x, self.feed_forward)
    
def subsequent_mask(size):
    attn_shape = (1, size, size)
    subsequent_mask = np.triu(np.ones(attn_shape), k=1).astype('uint8')
    return torch.from_numpy(subsequent_mask) == 0

class Generator(nn.Module):
    def __init__(self, d_model, vocab):
        super(Generator, self).__init__()
        self.proj = nn.Linear(d_model, vocab)

    def forward(self, x):
        return F.log_softmax(self.proj(x), dim=-1)
    
def attention(query, key, value, mask=None, dropout=None):
    d_k = query.size(-1)
    scores = torch.matmul(query, key.transpose(-2, -1)) \
             / math.sqrt(d_k)
    if mask is not None:
        scores = scores.masked_fill(mask == 0, -1e9)
    p_attn = F.softmax(scores, dim = -1)
    if dropout is not None:
        p_attn = dropout(p_attn)
    return torch.matmul(p_attn, value), p_attn

class MultiHeadedAttention(nn.Module):
    def __init__(self, h, d_model, dropout=0.1):
        super(MultiHeadedAttention, self).__init__()
        assert d_model % h == 0
        self.d_k = d_model // h
        self.h = h
        self.linears = clones(nn.Linear(d_model, d_model), 4)
        self.attn = None
        self.dropout = nn.Dropout(p=dropout)
        
    def forward(self, query, key, value, mask=None):
        #print ("mask para attn...", mask)
        if mask is not None:
            mask = mask.unsqueeze(1)
        nbatches = query.size(0)
        
        query, key, value = \
            [l(x).view(nbatches, -1, self.h, self.d_k).transpose(1, 2)
             for l, x in zip(self.linears, (query, key, value))]
         
        x, self.attn = attention(query, key, value, mask=mask, 
                                 dropout=self.dropout)
        
        x = x.transpose(1, 2).contiguous() \
             .view(nbatches, -1, self.h * self.d_k)
        return self.linears[-1](x)
    
class PositionalText(nn.Module):
    def __init__(self, d_model, dropout, max_len=50):
        super(PositionalText, self).__init__()
        self.dropout = nn.Dropout(p=dropout)
        
    def forward(self, x):
        x_text=x.data[:,0][:,None,:]
        x_machines=x.data[:,1:]
        
        x_return = x_machines* x_text
        return self.dropout(x_return)
    
class PositionalText_concat(nn.Module):
    def __init__(self, d_model, dropout, max_len=50):
        super(PositionalText_concat, self).__init__()
        self.dropout = nn.Dropout(p=dropout)
        
    def forward(self, x):
        return self.dropout(x)   

    
global max_src_in_batch, max_tgt_in_batch

def batch_size_fn(new, count, sofar):
    global max_src_in_batch, max_tgt_in_batch
    if count == 1:
        max_src_in_batch = 0
        max_tgt_in_batch = 0
    max_src_in_batch = max(max_src_in_batch,  len(new.src))
    max_tgt_in_batch = max(max_tgt_in_batch,  len(new.trg) + 2)
    src_elements = count * max_src_in_batch
    tgt_elements = count * max_tgt_in_batch
    maximo=max(src_elements, tgt_elements)
    return maximo

class NoamOpt:
    "Optim wrapper that implements rate."
    def __init__(self, model_size, factor, warmup, optimizer):
        self.optimizer = optimizer
        self._step = 0
        self.warmup = warmup
        self.factor = factor
        self.model_size = model_size
        self._rate = 0
        
    def step(self):
        "Update parameters and rate"
        self._step += 1
        rate = self.rate()
        for p in self.optimizer.param_groups:
            p['lr'] = rate
        self._rate = rate
        #print ("Rate de Noam_opt", self._rate, self._step)
        self.optimizer.step()
        
    def rate(self, step = None):
        "Implement `lrate` above"
        if step is None:
            step = self._step
        return self.factor * \
            (self.model_size ** (-0.5) *
            min(step ** (-0.5), step * self.warmup ** (-1.5)))
        
def get_std_opt(model):
    return NoamOpt(model.src_embed[0].d_model, 2, 4000,
            torch.optim.Adam(model.parameters(), lr=0, betas=(0.9, 0.98), eps=1e-9))

class LabelSmoothing(nn.Module):
    "Implement label smoothing."
    def __init__(self, size, padding_idx, smoothing=0.0):
        super(LabelSmoothing, self).__init__()
        self.criterion = nn.KLDivLoss(size_average=False)
        self.padding_idx = padding_idx
        self.confidence = 1.0 - smoothing
        self.smoothing = smoothing
        self.size = size
        self.true_dist = None
        
    def forward(self, x, target):
        assert x.size(1) == self.size
        true_dist = x.data.clone()
        true_dist.fill_(self.smoothing / (self.size - 2))
        true_dist.scatter_(1, target.data.unsqueeze(1), self.confidence)
        mask = torch.nonzero(target.data == self.padding_idx)
        self.true_dist = true_dist
        return self.criterion(x, Variable(true_dist, requires_grad=False))
    
class LabelCCE(nn.Module):
    def __init__(self, class_weights):
        super(LabelCCE, self).__init__()
        self.criterion = nn.CrossEntropyLoss(weight=class_weights)
                       
    def forward(self, x, target):
        return self.criterion(x, target)
    
class FocalLoss(nn.Module):
    def __init__(self, weights, gamma=2.0, reduce=True):#, logits=False, reduce=True):
        super(FocalLoss, self).__init__()
        self.weights = weights
        self.gamma = gamma
        #self.logits = logits
        self.reduce = reduce

    def forward(self, x, y):
        tensors = []
        for l in y:
            tensors.append(torch.zeros(4).scatter_(0, torch.tensor(l), 1))
        result = torch.stack(tensors, 0)
        
        CCE_loss = F.cross_entropy(x, result.long().argmax(dim=-1), reduction='none', weight=self.weights.float())
        pt = torch.exp(-CCE_loss)
        factor= (1-pt)**self.gamma * CCE_loss
        
        F_loss = factor  #*self.weights.float()-- peso esta dentro de la funcion

        if self.reduce:
            return torch.mean(F_loss)
        else:
            return F_loss
        
class SimpleLossComputeFL:
    "A simple loss compute and train function."
    def __init__(self, criterion, opt=None):
        self.criterion = criterion
        self.opt = opt
        
    def __call__(self, x, y, norm, mode):
        y_new=(y.float()-torch.ones((y.shape))).int() 
        #print ("nuevo Y en simplelosscompute", y_new, "antes era", y)
        # ahora
        #y_new=(y.float()).int()
        ac=accuracy_scorer(x, y_new)
        f1=f_scorer(x, y_new)
        cm=compute_confusion_matrix(x, y_new)
        tempa= x.contiguous().view(-1, x.size(-1))
        tempb= y_new.long().contiguous().view(-1)
        loss = self.criterion(tempa, tempb) #/ norm
        if mode!='Test':
            loss.backward()
        if self.opt is not None:
            self.opt.step()
            self.opt.optimizer.zero_grad()
        return [loss.data, ac ,f1, cm] #*norm #[0] * norm
    
class PositionwiseFeedForward(nn.Module):
    "Implements FFN equation."
    def __init__(self, d_model, d_ff, dropout=0.1):
        super(PositionwiseFeedForward, self).__init__()
        self.w_1 = nn.Linear(d_model, d_ff)
        self.w_2 = nn.Linear(d_ff, d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        return self.w_2(self.dropout(F.relu(self.w_1(x))))
    
def accuracy_scorer(predicho, target):
    predicho= torch.argmax(predicho, dim=1)
    return accuracy_score(target.numpy(),predicho.numpy())

def f_scorer(predicho, target):
    predicho= torch.argmax(predicho, dim=1)
    return f1_score(target.numpy(),predicho.numpy(), average=None, labels=[0,1,2,3])

def compute_confusion_matrix(predicho, target):
    predicho= torch.argmax(predicho, dim=1)
    return confusion_matrix(target.numpy(), predicho.numpy(), labels=[0,1,2,3])

def data_gen(batch_size,mode,n_machines,new_matrix):  
    """ESTA FUNCION DEBERÁ RETORNAR MATRICES DE TAMAÑO BATCH_SIZE * TW,M1,M2,M3,M4,M5,M6
    CADA EJEMPLO DEBERÁ SER ESTILO [ID_T, 1,2,1,2,1,2] SIENDO 1 CUANDO LA CLASE PREDICHA ES LA 0
    2 PARA CLASE PREDICHA 1, ETC. ID_T DEBEŔA INICIAR EN 5 PARA REFERIRSE AL PRIMER TW (EL PRIMERO DE TRAIN)"""
    x_data=[] 
    y_data=[]
    if mode=='Train':
        max_objs=matrix.shape[1]
        x_list=np.arange(max_objs)
        np.random.shuffle(x_list)        #indices desordenados de seccion train
        objs=ids_train
        labels=etiq     #np.load("matrices/y_train_num_4.npy")
        labels=np.asarray(labels) #+ np.ones(labels.shape),dtype='uint8')
    if mode=='Val':
        max_objs=matrix_val.shape[1] 
        x_list=np.arange(max_objs)
        x_list=[x+matrix.shape[1] for x in x_list]   
        np.random.shuffle(x_list)        #indices desordenados de seccion val
        objs=val['Tw_id']    #df_val['Unnamed: 0'].values        
        labels=np.asarray(etiq_v)     #np.load("matrices/y_val_num_4.npy")
        labels=np.asarray(labels) #+ np.ones(labels.shape),dtype='uint8') 
    if mode=='Test':
        max_objs=matrix_test.shape[1] 
        x_list=np.arange(max_objs)
        x_list=[x+matrix.shape[1]+matrix_val.shape[1] for x in x_list]
        total=matrix.shape[1]+matrix_val.shape[1]
        objs=test['Tw_id']     #np.arange(total, total+max_objs)
        
    #----------------------------------- COMPLETA MINI BATCHES ----------------------    
    if len(x_list)%batch_size==0:
        n_batches=len(x_list)/batch_size
        for nb in range(n_batches): 
            x_data.append(x_list[nb*batch_size:(nb+1)*batch_size])
    else:
        n_batches=int(len(x_list)/batch_size)
        resto=int(len(x_list)-n_batches*batch_size)
        to_repeat=batch_size-resto        
        for nb in range(n_batches): 
            x_data.append(x_list[nb*batch_size:(nb+1)*batch_size])
        cola=list(x_list[(nb+1)*batch_size:])
        for i in range(to_repeat):
            indice= np.random.randint(len(x_list))
            cola.append(x_list[indice])
        x_data.append(np.asarray(cola))
        if mode=='Test':
            print ("SE TUVIERON QUE REPETIR", to_repeat, "EJEMPLOS")
    #print ("los indices de train k voy a acceder random son", x_data[0])
            
    #-------------------------------- CONSTRUCCION MINI BATCHES (X,Y)----------------------   
    new_x_data=[] 
    for batch in x_data:
        #print ("transformando batch", batch)
        temp=[]
        for pos in batch:
            #print("en especifico el numerito", pos)
            temp2=[index_embeddings[pos+5]]#fromId2num[objs[exam]]] ### obj evaluado en maquinas  
            #print ("me dice que es el embed en index", temp2)
            for m in range(n_machines): 
                #print ("machine ",m,"dice:", np.argmax(new_matrix[m][pos])+1)
                temp2= temp2 + [np.argmax(new_matrix[m][pos])+1] 
                #matrix[4][cosa-5])+1)
            temp.append(temp2)
        new_x_data.append(temp)   

    if mode=='Train' or mode=='Val':    
        y_data=[]
        for conjunto in range(len(new_x_data)):
            batch=new_x_data[conjunto]
            temp_y=[]
            for linea in range(len(batch)):
                indice=x_data[conjunto][linea]  #pos
                lab=d_lab[lab_str_embeddings[indice+5]]+1 #labels_train
                temp_y.append([lab])       
            y_data.append(temp_y)
            
        y_data=np.asarray(y_data)
        
    new_x_data=np.asarray(new_x_data)
    #print ("primer batch X.Y", new_x_data[0], y_data[0])
    if mode=='Test':
        for x in new_x_data:
            src = Variable(torch.from_numpy(np.asarray(x)), requires_grad=False)
            yield Batch(src, None, 0)        
    else:          
        for x,y in zip(new_x_data, y_data):
            src = Variable(torch.from_numpy(np.asarray(x)), requires_grad=False)
            har = Variable(torch.from_numpy(np.asarray(y)), requires_grad=False)
            yield Batch(src, har, 0)
            

def make_model_concat(target, N=2, d_model=768, d_ff=1024, h=4, dropout=0.3, soft=True):  #recibir src_vocab si lo utiliza dummy_Emb
    c = copy.deepcopy
    attn = MultiHeadedAttention(h, d_model)
    ff = PositionwiseFeedForward(d_model, d_ff, dropout)
    position = PositionalText_concat(d_model, dropout)
    if soft:
        print ("Creando modelo con salida Softmax")
        model = EncoderDecoderSoft(
            Encoder(EncoderLayer(d_model, c(attn), c(ff), dropout), N),
            nn.Sequential(Dummy_Embeddings(d_model, K_list_new), c(position)),
            nn.Linear(d_model, 4))
    else:
        print ("")
        print ("Creando modelo con salida Log_softmax")
        model = EncoderDecoderLogSoft(
            Encoder(EncoderLayer(d_model, c(attn), c(ff), dropout), N),
            nn.Sequential(Dummy_Embeddings(d_model, K_list_new), c(position)),
            nn.Linear(d_model, 4))

    for p in model.parameters():
        if p.dim() > 1:
            nn.init.xavier_uniform(p)
    return model

class Batch:
    def __init__(self, src, trg=None, pad=0):
        self.src = src
        self.src_mask = (src != pad).unsqueeze(-2)
        if trg is not None:
            self.trg = trg[:, :]
            self.trg_y = trg[:, 0:]
            self.trg_mask = \
                self.make_std_mask(self.trg, pad)
            self.ntokens = (self.trg_y != pad).data.sum()
            
    @staticmethod
    def make_std_mask(tgt, pad):
        tgt_mask = (tgt != pad).unsqueeze(-2)
        tgt_mask = tgt_mask & Variable(
            subsequent_mask(tgt.size(-1)).type_as(tgt_mask.data))
        return tgt_mask
    
def run_epoch(data_iter, model, loss_compute, mode):
    if mode=='Test':
        with torch.no_grad():
            start = time.time()
            pred_classes=[]
            for i, batch in enumerate(data_iter):
                #print ("batch.src_mask en run epoch", batch.src_mask)
                out = model.forward(batch.src, batch.src_mask)
                pred_classes.append(out.argmax(dim=-1).numpy())
                #la loss del batch es sobre todos los ejemplos o es promedio en batch?
            return pred_classes
    
    else:
        start = time.time()
        total_learners = 0
        total_datos = 0
        total_loss = 0
        total_acc=0
        total_fm1=0
        total_fs=0
        n_batches = 0
        cm_last=np.zeros((4,4))
        for i, batch in enumerate(data_iter):
            #print ("BATCH\n", i, '\n', batch.src)
            out = model.forward(batch.src, batch.src_mask)
            loss,acc,f1,cm = loss_compute(out, batch.trg_y, batch.ntokens, mode)
            cm_last+=cm
            f_ma=np.mean(f1)
            total_loss += loss
            total_acc += np.array(acc)
            total_fm1 += np.sum(f1)/4.0    #4 clases (macro)
            total_fs += f1                 #none  
            total_datos += batch.ntokens
            n_batches += 1
        return total_loss/n_batches, torch.from_numpy(np.array(total_acc))/n_batches, torch.from_numpy(np.array(total_fm1))/n_batches, torch.from_numpy(np.array(total_fs))/n_batches, cm_last

emoji_pattern = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags=re.UNICODE)

def cleaner(post): 
    #re.sub(r'([a-z])\1+', r'\1', "user i think that ' s all you loooooove ")
    s= re.sub(r"http\S+", " html ", post)   ##########elimina http    
    s= re.sub(r'#\w+ ?', " hashtag ", s) ########3
    s= re.sub(r'@\w+ ?', " user ", s)##############    
    s= s.lower()
    s=emoji_pattern.sub(r'', s)
    s=re.sub(r"'\b", " ' ", s)
    s=re.sub(r"\b'\b", " ' ", s)
    s=re.sub(r"“\b", " “ ", s)
    #“
    s=re.sub(r"\b’", " ’ ", s)
    s=re.sub(r"‘\b", " ‘ ", s)
    s=re.sub(r"\b’\b", " ‘ ", s)
    s = re.sub(r"-", " - ", s)
    s = re.sub(r"\(", " ", s)
    s = re.sub(r"\)", " ", s)
    s = re.sub(r"\?", " ? ", s)    
    s = re.sub(r"\/", " ", s)
    s = re.sub(r"' ", " ' ", s)
    s = re.sub(r" '", " ' ", s)
    s = re.sub(r"\!", " ! ", s)
    s=re.sub("[\.]+", " . ", s)
    s=re.sub("[\,]+", " , ", s)
    s=re.sub("[\;]+", " ; ", s)
    s=re.sub("[\:]+", " : ", s)
    s=re.sub('[\"]+', ' " ', s)
    s=re.sub(r'\b[0-9]\b', " number ",  s)
    s=re.sub(r'\b[0-9]*[0-9]\b', " number ",  s)    
    s=re.sub(r'\b”', ' " ', s)
    sl= list(s.split())
    sl_2=[]
    for wd in sl:
        try: 
            q=Word2Index_valid[wd]
            sl_2.append(wd)
        except:
            try: 
                if stemmer.stem(wd) in Word2Index_valid.keys():
                    sl_2.append(stemmer.stem(wd))
                elif lemmatizer.lemmatize(wd) in Word2Index_valid.keys():
                    sl_2.append(lemmatizer.lemmatize(wd))
                else:
                    sl_2.append(wd)
            except:
                sl_2.append(wd)
    sl=sl_2
    s=' '.join([word for word in sl])# if word not in stoplist])
    return s, sl

embeddings_index = {}
f = open(os.path.join("glove.twitter.27B.200d.txt"))#'glove.twitter.27B.100d.txt'))
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

print('Se encontraron %s terminos con sus vectores de embedding.' % len(embeddings_index))
# Out:
# There are 1 GPU(s) available.
# We will use the GPU: GeForce GTX 1060 6GB
# Se encontraron 1193514 terminos con sus vectores de embedding.

# %%
dict_cl=dict()
dict_cl[0]='support'
dict_cl[1]='denying'
dict_cl[2]='questioning'
dict_cl[3]='commenting'

#sdqc
d_lab=dict()
d_lab["support"]=0
d_lab["denying"]=1
d_lab["questioning"]=2
d_lab["commenting"]=3

train =pd.read_csv("../Tesis_exp/Fine-Tuning/CSV_Stance/train_semeval_raw.csv")
val=pd.read_csv("../Tesis_exp/Fine-Tuning/CSV_Stance/dev_semeval_raw.csv")
test=pd.read_csv("../Tesis_exp/Fine-Tuning/CSV_Stance/test_semeval_raw.csv")


word_index=dict()
j=1
for frase in train["Tweet"].values:
    frase=cleaner(frase)[-1]
    #print (frase)
    for term in frase:
        if term not in word_index.keys():
            word_index[term]=j
            j+=1

for frase in val["Tweet"].values:
    frase=cleaner(frase)[-1]
    #print (frase)
    for term in frase:
        if term not in word_index.keys():
            word_index[term]=j
            j+=1
            
for frase in test["Tweet"].values:
    frase=cleaner(frase)[-1]
    #print (frase)
    for term in frase:
        if term not in word_index.keys():
            word_index[term]=j
            j+=1
            
len(word_index.keys())
# Out:
# 7220

# %%
not_found=[]
pos_tag_nf=[]
Word2Index={}
Word2Index_valid={}
idx_2_token={}
idx_2_token_valid={}

g_dim=200
emb_matrix = np.zeros((len(word_index.keys())+1, g_dim))  

k=1
for word, i in word_index.items():
    vector = embeddings_index.get(word)
    if vector is not None:
        # words sin match en Glove, serán vectores de ceros.
        emb_matrix[i] = vector
        Word2Index[word]=i
        Word2Index_valid[word]=k
        idx_2_token_valid[k]=word
        k+=1
        idx_2_token[i]=word
        
    else:
        Word2Index[word]=i
        idx_2_token[i]=word
        not_found.append(word)
        pos_tag_nf.append(nltk.pos_tag([word])[0][-1])

# %%
print (len(Word2Index_valid.keys()))
# Out:
# 6711

# %%
len(Word2Index.keys())
# Out:
# 7220

# %%
transf = Normalizer().fit(emb_matrix) 
M_GLOVE_space=transf.transform(emb_matrix)

def my_tokenizer(lista):
    encoded_sent=[]
    to_return_ide=[]
    for wd in lista:
        try:               
            to_return_ide.append(Word2Index_valid[wd])
            encoded_sent.append(wd)
        except: 
            continue   
           
    return to_return_ide, encoded_sent

def predict_data(trained, x_train, x_val, x_test, etiq, etiq_v, etiq_t, name_model):
    etiq = etiq.astype("int")
    trainPredict = trained.predict(x_train, batch_size=32)
    trainPredict=[np.argmax(pred) for pred in trainPredict]
    acc= accuracy_score(etiq, trainPredict)  
    f1=f1_score(etiq, trainPredict, average=None)  # labels=np.unique(trainPredict)
    f1_ma=f1_score(etiq, trainPredict, average='macro')  # labels=np.unique(trainPredict)
    #matriz=normalize(confusion_matrix(etiq, trainPredict))
    print ("")
    print ("Accuracy sobre Train", name_model, ":",acc)  
    print ("F1-score None sobre Train", name_model, ":",f1)
    print ("F1-score macro sobre Train", name_model, ":",f1_ma)
    ########################################
    trainPredict = trained.predict(x_val, batch_size=32)
    trainPredict=[np.argmax(pred) for pred in trainPredict]
    acc= accuracy_score(etiq_v, trainPredict)  
    f1=f1_score(etiq_v, trainPredict, average=None)  # labels=np.unique(trainPredict)
    f1_ma=f1_score(etiq_v, trainPredict, average='macro')  # labels=np.unique(trainPredict)
    #matriz=normalize(confusion_matrix(etiq_v, trainPredict))
    print ("")
    print ("Accuracy sobre Val", name_model, ":",acc)  
    print ("F1-score None sobre Val", name_model, ":",f1)
    print ("F1-score macro sobre Val", name_model, ":",f1_ma)
    ########################################
    trainPredict = trained.predict(x_test, batch_size=32)
    trainPredict=[np.argmax(pred) for pred in trainPredict]
    acc_t= accuracy_score(etiq_t, trainPredict)  
    f1_t=f1_score(etiq_t, trainPredict, average=None)  # labels=np.unique(trainPredict)
    f1_ma_t=f1_score(etiq_t, trainPredict, average='macro')  # labels=np.unique(trainPredict)
    matriz_t=normalize(confusion_matrix(etiq_t, trainPredict))
    print ("")
    print ("Accuracy sobre Test", name_model, ":",acc_t)  
    print ("F1-score None sobre Test", name_model, ":",f1_t)
    print ("F1-score macro sobre Test", name_model, ":",f1_ma_t)
    
    return f1_ma_t, f1_t, acc_t, matriz_t

# %%
from models import *

if not sys.warnoptions:
    warnings.simplefilter("ignore")
    
class Dummy_Embeddings(nn.Module):
    def __init__(self, d_model, dummy_vectors): 
        super(Dummy_Embeddings, self).__init__()
        aux = torch.from_numpy(dummy_vectors)#, dtype='float32'))
        self.index2dummy = nn.Embedding(aux.size()[0], d_model)
        self.index2dummy.weigth=nn.Parameter(aux)
        self.index2dummy.weigth.requires_grad=False
        self.d_model = d_model
        
    def forward(self, x):
        aux=x.numpy()
        #print ("aux original", aux)
        #print ("aux restado...",aux-np.ones(aux.shape))
        new_x= aux #- np.ones(aux.shape)
        new_x= torch.from_numpy(new_x)
        return self.index2dummy(new_x.long()) * math.sqrt(self.d_model) #debiese retornar matriz de batch_size x [ind_tw, k1,k2,k3,k4,k5,k6] (si son 6 modelos)
    
def match(objetos,ejemplo):
    i=0
    for obj in objetos:
        if obj==ejemplo:
            return i
        i+=1
        
def plot_confusion_matrix(cm, target_names, title='Confusion matrix (f1-score)',cmap=None, normalize=True):    
    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy
    if cmap is None:
        cmap = plt.get_cmap('Blues')
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        
    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap, vmin=0, vmax=1)
    plt.title(title)
    plt.colorbar()
    
    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)
    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()
    
MAX_LEN = 37

print ("Conteo por stance val\n", Counter(val['Label']))
print ("Conteo por stance test\n", Counter(test['Label']))
# Out:
# Conteo por stance val
#  Counter({'commenting': 173, 'support': 69, 'questioning': 28, 'denying': 11})
# Conteo por stance test
#  Counter({'commenting': 778, 'questioning': 106, 'denying': 69, 'support': 68})

# %%
#class_weights= compute_class_weight('balanced', np.unique(labels_train), labels_train)
class_weights= [1.0, 1.0, 1.0, 1.0]
class_weights=np.asarray(class_weights)
print ("Pesos de clases:", class_weights)
#print ("Pesos de clases:", class_weights)
# Out:
# Pesos de clases: [1. 1. 1. 1.]

# %%
ids_val=val['Tw_id']
tws_val=val['Tweet']
labels_val=[d_lab[lb] for lb in val['Label']]

etiq_v=labels_val.copy()
etiq_v=np.asarray(etiq_v)
sentences_val = tws_val
n_labels_val = np.array(etiq_v)
y_val=to_categorical(n_labels_val,num_classes=4)

input_ids_val=[]
for sent in sentences_val:
    encoded_sent, sent_valid =my_tokenizer(cleaner(sent)[1])  
    input_ids_val.append(encoded_sent)

ids_test=test['Tw_id']
tws_test=test['Tweet']
labels_test=[d_lab[lb] for lb in test['Label']]

etiq_t=labels_test.copy()
etiq_t=np.asarray(etiq_t)
sentences_test = tws_test
n_labels_test = np.array(etiq_t)
y_test=to_categorical(n_labels_test,num_classes=4)

input_ids_test=[]
for sent in sentences_test:
    encoded_sent, sent_valid = my_tokenizer(cleaner(sent)[1])
    input_ids_test.append(encoded_sent)
    
input_ids_val = pad_sequences(input_ids_val,maxlen=MAX_LEN,dtype="long",value=0, truncating="post", padding="post")
input_ids_test = pad_sequences(input_ids_test,maxlen=MAX_LEN,dtype="long",value=0, truncating="post", padding="post")


shape_val=np.asarray(input_ids_val).shape
x_val=np.zeros((shape_val[0], shape_val[1], 200))
i=0
for in_id in input_ids_val:
    x_val[i]=M_GLOVE_space[in_id]
    i+=1
    
shape_test=np.asarray(input_ids_test).shape
x_test=np.zeros((shape_test[0], shape_test[1], 200))
i=0
for in_id in input_ids_test:
    x_test[i]=M_GLOVE_space[in_id]
    i+=1

x_test.shape
# Out:
# (1021, 37, 200)

# %%
del embeddings_index

# %% [markdown]
# ## 0.15

# %% [markdown]
# ids_train=train['Tw_id']
# tws_train=train['Tweet']
# labels_train=[d_lab[lb] for lb in train['Label']]
#
# etiq=labels_train.copy()
# etiq=np.asarray(etiq)
# sentences = tws_train
# n_labels = np.array(etiq)
# y_train=to_categorical(n_labels,num_classes=4)
#
# input_ids=[]
# for sent in sentences:
#     sent_cl=cleaner(sent)[1]
#     encoded_sent=[]
#     for wd in sent_cl:
#         try:
#             encoded_sent.append(Word2Index[wd])
#         except:
#             continue
#     input_ids.append(encoded_sent)
#
# input_ids = pad_sequences(input_ids,maxlen=MAX_LEN,dtype="long",value=0, truncating="post", padding="post")
# shape=np.asarray(input_ids).shape
# x_train=np.zeros((shape[0], shape[1], 200))
# j=0
# for in_id in input_ids:
#     x_train[j]=M_GLOVE_space[in_id]
#     j+=1

# %%
val['Tweet'][0]
# Out:
# '#Germanwings latest: http://t.co/8tZopIBYLh\n- #Airbus A320 crashes in French Alps\n- Barcelona-to-Dusseldorf flight\n- 142 passengers &amp; 6 crew'

# %%
global_accs=[]
global_fnones=[]
global_fmacros=[]
global_cms=[]
global_attn=[]
dict_attn_enc={'00':[], '01':[], '02':[], '03':[], '10':[], '11':[], '12':[], '13':[]}
  
prob=0.15

for trans in range(1,6): 
    print ("Entrenando Run #", trans)
    macro_augmented= np.load('../new_glove_augmented/stance/Aumento_'+str(trans)+'-run_'+str(prob)+'_app1_Top1.npy', allow_pickle=True)

    ids_train=macro_augmented[:,0]
    tws_train=macro_augmented[:,1]
    labels_train=macro_augmented[:,2]

    etiq=labels_train.copy()
    sentences = tws_train
    n_labels = np.array(etiq)
    y_train=to_categorical(n_labels,num_classes=4)
    
    input_ids = []
    for sent in sentences:
        encoded_tok=[]
        for wd in sent:
            try: 
                encoded_tok.append(Word2Index_valid[wd])
            except: 
                continue 
        input_ids.append(encoded_tok)
    
    input_ids = pad_sequences(input_ids, maxlen=MAX_LEN, dtype="long", 
                              value=0, truncating="post", padding="post")
    
    shape=np.asarray(input_ids).shape
    x_train=np.zeros((shape[0], shape[1], g_dim))
    j=0
    for in_id in input_ids:
        x_train[j]=M_GLOVE_space[in_id]
        j+=1
        
        
    cnn1 = load_model('../new_glove_augmented/stance_baselines/'+str(prob)+'/cnn1_'+str(trans)+'-exec_app1_Top_1.h5')
    cnn2 = load_model('../new_glove_augmented/stance_baselines/'+str(prob)+'/cnn2_'+str(trans)+'-exec_app1_Top_1.h5')
    rnn1 = load_model('../new_glove_augmented/stance_baselines/'+str(prob)+'/rnn1_'+str(trans)+'-exec_app1_Top_1.h5')
    rnn2 = load_model('../new_glove_augmented/stance_baselines/'+str(prob)+'/rnn2_'+str(trans)+'-exec_app1_Top_1.h5')
    rnn3 = load_model('../new_glove_augmented/stance_baselines/'+str(prob)+'/rnn3_'+str(trans)+'-exec_app1_Top_1.h5')

    list_models=['cnn1', 'cnn2', 'rnn1', 'rnn2', 'rnn3']
    index_models=np.arange(5)
    dict_models=dict((key, value) for (key, value) in zip(index_models,list_models))
    modelos=[cnn1, cnn2, rnn1, rnn2, rnn3]
    ind=np.arange(5)
    dict_trainedModel=dict((key, value) for (key, value) in zip(ind,modelos))

    bs=32
    predicciones_all=[]
    predicciones_all_val=[]
    predicciones_all_test=[]
    
    print ("agregando predicciones Train")
    for i in dict_trainedModel.keys(): 
        a_evaluar=dict_models[i]
        predicciones_all.append(dict_trainedModel[i].predict(x_train, batch_size=bs))
    print ("agregando predicciones Val")
    for i in dict_trainedModel.keys(): 
        a_evaluar=dict_models[i]
        predicciones_all_val.append(dict_trainedModel[i].predict(x_val, batch_size=bs))
    print ("agregando predicciones Test")
    for i in dict_trainedModel.keys(): 
        a_evaluar=dict_models[i]
        predicciones_all_test.append(dict_trainedModel[i].predict(x_test, batch_size=bs))

    matrix=np.asarray(predicciones_all)
    matrix_val=np.asarray(predicciones_all_val)
    matrix_test=np.asarray(predicciones_all_test)
    new_matrix=np.concatenate([matrix,matrix_val,matrix_test], axis=1)
    
    
    espacio=[np.ones(g_dim)]
    #Ks=np.load("../../BERTransformer/Orthogonals_768.npy")
    
    Ks= ortho_group.rvs(dim=g_dim)
    random=np.random.randint(Ks.shape[0], size=4)
    K_list=Ks[random]
    #print (K_list.shape)
    #break
    K_list_ext=espacio+list(K_list)
    index_embeddings=[0,1,2,3,4]
    lab_str_embeddings=['','','','','']

    for i in range(len(sentences)):
        ide=ids_train[i]
        tw_tr=tws_train[i]
        #tokens=cleaner(tw_tr)[1]
        clase=dict_cl[labels_train[i]]
        
        encoded_tok=[]
        for wd in tw_tr:
            try: 
                encoded_tok.append(Word2Index_valid[wd])
            except: 
                continue 
                
        q_glove=len(encoded_tok)
        glove_tok_f=[M_GLOVE_space[ide] for ide in encoded_tok]
        final=np.sum(glove_tok_f, axis=0)
        final_awe=final/q_glove
        norm=np.linalg.norm(final_awe)
        final_awe= final_awe / norm
        #print (i, type(tw_tr), type(final_awe), final_awe.shape, len(encoded_tok))
        
        index_embeddings.append(i+5)
        lab_str_embeddings.append(clase)
        if len(encoded_tok)==0:
            K_list_ext.append(np.zeros(g_dim))
        else: 
            K_list_ext.append(final_awe)
        
        #alo=np.asarray(K_list_ext, dtype='float32')
    
    
    objs_val=val['Tw_id']      #df_val['Unnamed: 0'].values
    objs_test=test['Tw_id']    #np.arange(df_test.shape[0])
    lab_val=val['Label']
    lab_test=test['Label']
    tw_val=val['Tweet']
    tw_test=test['Tweet']
    llaves=np.concatenate([objs_val,objs_test])
    clases=np.concatenate([lab_val,lab_test])
    sent_all=np.concatenate([tw_val,tw_test])
    
       
    for num in range(len(llaves)):
        i=llaves[num]
        clase=clases[num]
        tw_tr=sent_all[num]
        #vector=np.load("../BaS_Original/Original/"+str(i)+".npy")
        encoded_tok, tokens_valid =my_tokenizer(cleaner(tw_tr)[1])
    
        q_glove=len(encoded_tok)
        glove_tok_f=[M_GLOVE_space[ide] for ide in encoded_tok]
        final=np.sum(glove_tok_f, axis=0)
        final_awe=final/q_glove
        norm=np.linalg.norm(final_awe)
        final_awe= final_awe / norm

        index_embeddings.append(num+5+train.shape[0])
        lab_str_embeddings.append(clase)
        K_list_ext.append(final_awe)

    K_list_new= np.asarray(K_list_ext, dtype='float32')
    
    ###################################### TRANSFORMER ###############################
    V = 4
    pesos = torch.from_numpy(class_weights).float()
    criterion = FocalLoss(weights=pesos)
    model = make_model_concat(4, N=2,d_model=g_dim, d_ff=128, h=4, dropout=0.35)
    model_opt = NoamOpt(model.src_embed[0].d_model, 1, 500, torch.optim.Adam(model.parameters(), lr=0, betas=(0.9, 0.98), eps=1e-5))

    
    for epoch in range(40):
        model.train()
        DATA=data_gen(32, 'Train', 5, new_matrix)
        loss_train, acc_train,fma_train, f_none, cm_train=run_epoch(DATA, model, SimpleLossComputeFL(criterion, model_opt), 'Train')
        
        model.eval()
        loss_val, acc_val,fma_val, f_val_none, cm_val=run_epoch(data_gen(bs, 'Val', 5, new_matrix), model, SimpleLossComputeFL(criterion, None),'Val')
        print ("Epoch",epoch, "\tacc_val:",acc_val, "\tF-macro_val:",fma_val)
    
    model.eval()
    print ("Testing run #",trans)
    predicciones = run_epoch(data_gen(bs, 'Test', 5, new_matrix), model, SimpleLossComputeFL(criterion, None),'Test')
    predicciones=np.concatenate(predicciones, axis=-1)
    
    glo_acc=accuracy_score(etiq_t, predicciones[:-3])
    glo_fno=f1_score(etiq_t,predicciones[:-3], average=None)
    glo_fma=f1_score(etiq_t,predicciones[:-3], average='macro')

    glo_cm=confusion_matrix(etiq_t, predicciones[:-3])

    plot_confusion_matrix(glo_cm,["support","Denying","Questioning","Commenting"],"Pre-trained Sin Aum 40-e Stance")
    global_accs.append(glo_acc)
    global_fnones.append(glo_fno)
    global_fmacros.append(glo_fma)
    global_cms.append(glo_cm)
    print("Test_ acc:",glo_acc) 
    print("Test_ f1 none:",glo_fno) 
    print("Test_ f1 macro:",glo_fma) 

    label=[['Text', 'm1', 'm2','m3','m4','m5']]
    for layer in range(2):
        fig, axs = plt.subplots(1,4, figsize=(20, 10))
        print ("Encoder Layer Attention head", layer)
        for head in range(4):
            matriz_attn=model.encoder.layers[layer].self_attn.attn[0,head].data
            dict_attn_enc[str(layer)+str(head)].append(matriz_attn)
            sns.heatmap(matriz_attn, xticklabels=label[0], yticklabels=label[0],
                        vmin=0.0, vmax=1.0, linewidths=.5, cmap="Blues", cbar=False, square=True, ax=axs[head]) #, annot=False,cbar_kws={"orientation": "horizontal","pad": 0.25})
        plt.show()
# Out:
# Entrenando Run # 1
# agregando predicciones Train
# agregando predicciones Val
# agregando predicciones Test
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.3576, dtype=torch.float64) 	F-macro_val: tensor(0.3038, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.5035, dtype=torch.float64) 	F-macro_val: tensor(0.3870, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.5278, dtype=torch.float64) 	F-macro_val: tensor(0.3912, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.5312, dtype=torch.float64) 	F-macro_val: tensor(0.4082, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.5347, dtype=torch.float64) 	F-macro_val: tensor(0.4077, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.5486, dtype=torch.float64) 	F-macro_val: tensor(0.4346, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.5208, dtype=torch.float64) 	F-macro_val: tensor(0.4013, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.5521, dtype=torch.float64) 	F-macro_val: tensor(0.4026, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.5521, dtype=torch.float64) 	F-macro_val: tensor(0.4430, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.5486, dtype=torch.float64) 	F-macro_val: tensor(0.4383, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.5278, dtype=torch.float64) 	F-macro_val: tensor(0.3713, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.5451, dtype=torch.float64) 	F-macro_val: tensor(0.4119, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.5729, dtype=torch.float64) 	F-macro_val: tensor(0.4325, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.5694, dtype=torch.float64) 	F-macro_val: tensor(0.4277, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.5833, dtype=torch.float64) 	F-macro_val: tensor(0.4210, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.5833, dtype=torch.float64) 	F-macro_val: tensor(0.4274, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.5868, dtype=torch.float64) 	F-macro_val: tensor(0.4294, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.5417, dtype=torch.float64) 	F-macro_val: tensor(0.4085, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.5417, dtype=torch.float64) 	F-macro_val: tensor(0.4176, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.5312, dtype=torch.float64) 	F-macro_val: tensor(0.4171, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.5694, dtype=torch.float64) 	F-macro_val: tensor(0.4020, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.5868, dtype=torch.float64) 	F-macro_val: tensor(0.4208, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.5625, dtype=torch.float64) 	F-macro_val: tensor(0.4236, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.5521, dtype=torch.float64) 	F-macro_val: tensor(0.4221, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.5903, dtype=torch.float64) 	F-macro_val: tensor(0.4398, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.5590, dtype=torch.float64) 	F-macro_val: tensor(0.4221, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.5660, dtype=torch.float64) 	F-macro_val: tensor(0.4015, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.5660, dtype=torch.float64) 	F-macro_val: tensor(0.4384, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.5625, dtype=torch.float64) 	F-macro_val: tensor(0.4179, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.5833, dtype=torch.float64) 	F-macro_val: tensor(0.4193, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.5833, dtype=torch.float64) 	F-macro_val: tensor(0.4032, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.5694, dtype=torch.float64) 	F-macro_val: tensor(0.4301, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.5938, dtype=torch.float64) 	F-macro_val: tensor(0.4220, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.5799, dtype=torch.float64) 	F-macro_val: tensor(0.4455, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.5590, dtype=torch.float64) 	F-macro_val: tensor(0.4238, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.5660, dtype=torch.float64) 	F-macro_val: tensor(0.4284, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.5521, dtype=torch.float64) 	F-macro_val: tensor(0.4136, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.5660, dtype=torch.float64) 	F-macro_val: tensor(0.4082, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.5625, dtype=torch.float64) 	F-macro_val: tensor(0.3940, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.5694, dtype=torch.float64) 	F-macro_val: tensor(0.4235, dtype=torch.float64)
# Testing run # 1
# SE TUVIERON QUE REPETIR 3 EJEMPLOS
# Test_ acc: 0.5954946131243879
# Test_ f1 none: [0.1774744  0.08695652 0.56666667 0.7302726 ]
# Test_ f1 macro: 0.390342546994947
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 2
# agregando predicciones Train
# agregando predicciones Val
# agregando predicciones Test
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.2882, dtype=torch.float64) 	F-macro_val: tensor(0.2995, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.5035, dtype=torch.float64) 	F-macro_val: tensor(0.3577, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.4965, dtype=torch.float64) 	F-macro_val: tensor(0.3598, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.5174, dtype=torch.float64) 	F-macro_val: tensor(0.3990, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.5312, dtype=torch.float64) 	F-macro_val: tensor(0.3973, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.5625, dtype=torch.float64) 	F-macro_val: tensor(0.4071, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.5660, dtype=torch.float64) 	F-macro_val: tensor(0.4171, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.5556, dtype=torch.float64) 	F-macro_val: tensor(0.4084, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.5625, dtype=torch.float64) 	F-macro_val: tensor(0.4247, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.5799, dtype=torch.float64) 	F-macro_val: tensor(0.4282, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.5764, dtype=torch.float64) 	F-macro_val: tensor(0.4185, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.5799, dtype=torch.float64) 	F-macro_val: tensor(0.4190, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.5174, dtype=torch.float64) 	F-macro_val: tensor(0.4124, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.5382, dtype=torch.float64) 	F-macro_val: tensor(0.4090, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.5556, dtype=torch.float64) 	F-macro_val: tensor(0.4190, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.5833, dtype=torch.float64) 	F-macro_val: tensor(0.4448, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.5868, dtype=torch.float64) 	F-macro_val: tensor(0.4249, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.5729, dtype=torch.float64) 	F-macro_val: tensor(0.4050, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.5694, dtype=torch.float64) 	F-macro_val: tensor(0.4302, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.5972, dtype=torch.float64) 	F-macro_val: tensor(0.4517, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.5347, dtype=torch.float64) 	F-macro_val: tensor(0.4110, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.5521, dtype=torch.float64) 	F-macro_val: tensor(0.4127, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.5938, dtype=torch.float64) 	F-macro_val: tensor(0.4411, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.5764, dtype=torch.float64) 	F-macro_val: tensor(0.4341, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.5799, dtype=torch.float64) 	F-macro_val: tensor(0.4276, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.5764, dtype=torch.float64) 	F-macro_val: tensor(0.4358, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.5694, dtype=torch.float64) 	F-macro_val: tensor(0.4269, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.5660, dtype=torch.float64) 	F-macro_val: tensor(0.4122, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.5104, dtype=torch.float64) 	F-macro_val: tensor(0.4110, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.5799, dtype=torch.float64) 	F-macro_val: tensor(0.4242, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.5833, dtype=torch.float64) 	F-macro_val: tensor(0.4207, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.5764, dtype=torch.float64) 	F-macro_val: tensor(0.4220, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.5903, dtype=torch.float64) 	F-macro_val: tensor(0.4092, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.5868, dtype=torch.float64) 	F-macro_val: tensor(0.4474, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.5660, dtype=torch.float64) 	F-macro_val: tensor(0.4127, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.5035, dtype=torch.float64) 	F-macro_val: tensor(0.3999, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.5590, dtype=torch.float64) 	F-macro_val: tensor(0.4237, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.5868, dtype=torch.float64) 	F-macro_val: tensor(0.4244, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.5486, dtype=torch.float64) 	F-macro_val: tensor(0.4227, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.5486, dtype=torch.float64) 	F-macro_val: tensor(0.4305, dtype=torch.float64)
# Testing run # 2
# SE TUVIERON QUE REPETIR 3 EJEMPLOS
# Test_ acc: 0.5690499510284035
# Test_ f1 none: [0.09589041 0.14285714 0.5        0.70742358]
# Test_ f1 macro: 0.3615427836505183
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 3
# agregando predicciones Train
# agregando predicciones Val
# agregando predicciones Test
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.4618, dtype=torch.float64) 	F-macro_val: tensor(0.3508, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.5208, dtype=torch.float64) 	F-macro_val: tensor(0.3654, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.5451, dtype=torch.float64) 	F-macro_val: tensor(0.4059, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.5556, dtype=torch.float64) 	F-macro_val: tensor(0.4030, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.5243, dtype=torch.float64) 	F-macro_val: tensor(0.3808, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.5069, dtype=torch.float64) 	F-macro_val: tensor(0.3964, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.5451, dtype=torch.float64) 	F-macro_val: tensor(0.4183, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.5799, dtype=torch.float64) 	F-macro_val: tensor(0.4226, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.5868, dtype=torch.float64) 	F-macro_val: tensor(0.4135, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.5764, dtype=torch.float64) 	F-macro_val: tensor(0.4045, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.5660, dtype=torch.float64) 	F-macro_val: tensor(0.3984, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.5868, dtype=torch.float64) 	F-macro_val: tensor(0.4086, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.6250, dtype=torch.float64) 	F-macro_val: tensor(0.4269, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.6181, dtype=torch.float64) 	F-macro_val: tensor(0.4339, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.6042, dtype=torch.float64) 	F-macro_val: tensor(0.4356, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.5486, dtype=torch.float64) 	F-macro_val: tensor(0.4193, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.6181, dtype=torch.float64) 	F-macro_val: tensor(0.4360, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.5799, dtype=torch.float64) 	F-macro_val: tensor(0.4195, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.6111, dtype=torch.float64) 	F-macro_val: tensor(0.4314, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.5938, dtype=torch.float64) 	F-macro_val: tensor(0.4173, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.6007, dtype=torch.float64) 	F-macro_val: tensor(0.4061, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.5868, dtype=torch.float64) 	F-macro_val: tensor(0.4015, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.6424, dtype=torch.float64) 	F-macro_val: tensor(0.4481, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.6076, dtype=torch.float64) 	F-macro_val: tensor(0.4099, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.6285, dtype=torch.float64) 	F-macro_val: tensor(0.4252, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.6319, dtype=torch.float64) 	F-macro_val: tensor(0.4329, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.6146, dtype=torch.float64) 	F-macro_val: tensor(0.4233, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.6007, dtype=torch.float64) 	F-macro_val: tensor(0.4107, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.6146, dtype=torch.float64) 	F-macro_val: tensor(0.4260, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.5938, dtype=torch.float64) 	F-macro_val: tensor(0.4218, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.6215, dtype=torch.float64) 	F-macro_val: tensor(0.4197, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.5799, dtype=torch.float64) 	F-macro_val: tensor(0.4134, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.6146, dtype=torch.float64) 	F-macro_val: tensor(0.3949, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.6319, dtype=torch.float64) 	F-macro_val: tensor(0.4317, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.6146, dtype=torch.float64) 	F-macro_val: tensor(0.4170, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.6111, dtype=torch.float64) 	F-macro_val: tensor(0.4039, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.6285, dtype=torch.float64) 	F-macro_val: tensor(0.4416, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.6215, dtype=torch.float64) 	F-macro_val: tensor(0.4389, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.6389, dtype=torch.float64) 	F-macro_val: tensor(0.4316, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.6319, dtype=torch.float64) 	F-macro_val: tensor(0.4262, dtype=torch.float64)
# Testing run # 3
# SE TUVIERON QUE REPETIR 3 EJEMPLOS
# Test_ acc: 0.6807051909892262
# Test_ f1 none: [0.08955224 0.08888889 0.47191011 0.80206319]
# Test_ f1 macro: 0.36310360627407945
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 4
# agregando predicciones Train
# agregando predicciones Val
# agregando predicciones Test
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.1181, dtype=torch.float64) 	F-macro_val: tensor(0.1559, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.3646, dtype=torch.float64) 	F-macro_val: tensor(0.3628, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.4965, dtype=torch.float64) 	F-macro_val: tensor(0.3999, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.4792, dtype=torch.float64) 	F-macro_val: tensor(0.4122, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.4965, dtype=torch.float64) 	F-macro_val: tensor(0.4136, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.5660, dtype=torch.float64) 	F-macro_val: tensor(0.4371, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.5972, dtype=torch.float64) 	F-macro_val: tensor(0.4524, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.5625, dtype=torch.float64) 	F-macro_val: tensor(0.4243, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.5868, dtype=torch.float64) 	F-macro_val: tensor(0.4435, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.5521, dtype=torch.float64) 	F-macro_val: tensor(0.4393, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.5938, dtype=torch.float64) 	F-macro_val: tensor(0.4356, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.5868, dtype=torch.float64) 	F-macro_val: tensor(0.4390, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.5972, dtype=torch.float64) 	F-macro_val: tensor(0.4671, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.5556, dtype=torch.float64) 	F-macro_val: tensor(0.4409, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.5833, dtype=torch.float64) 	F-macro_val: tensor(0.4388, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.6111, dtype=torch.float64) 	F-macro_val: tensor(0.4210, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.5938, dtype=torch.float64) 	F-macro_val: tensor(0.4233, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.5868, dtype=torch.float64) 	F-macro_val: tensor(0.4407, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.5938, dtype=torch.float64) 	F-macro_val: tensor(0.4619, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.6354, dtype=torch.float64) 	F-macro_val: tensor(0.4503, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.5799, dtype=torch.float64) 	F-macro_val: tensor(0.4532, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.6076, dtype=torch.float64) 	F-macro_val: tensor(0.4190, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.6285, dtype=torch.float64) 	F-macro_val: tensor(0.4561, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.6076, dtype=torch.float64) 	F-macro_val: tensor(0.4544, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.6042, dtype=torch.float64) 	F-macro_val: tensor(0.4256, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.5799, dtype=torch.float64) 	F-macro_val: tensor(0.4332, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.6111, dtype=torch.float64) 	F-macro_val: tensor(0.4563, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.6076, dtype=torch.float64) 	F-macro_val: tensor(0.4489, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.6111, dtype=torch.float64) 	F-macro_val: tensor(0.4472, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.6111, dtype=torch.float64) 	F-macro_val: tensor(0.4509, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.5833, dtype=torch.float64) 	F-macro_val: tensor(0.4385, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.6181, dtype=torch.float64) 	F-macro_val: tensor(0.4620, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.5903, dtype=torch.float64) 	F-macro_val: tensor(0.4525, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.6111, dtype=torch.float64) 	F-macro_val: tensor(0.4257, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.5764, dtype=torch.float64) 	F-macro_val: tensor(0.4495, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.5833, dtype=torch.float64) 	F-macro_val: tensor(0.4244, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.6250, dtype=torch.float64) 	F-macro_val: tensor(0.4557, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.6424, dtype=torch.float64) 	F-macro_val: tensor(0.4601, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.5972, dtype=torch.float64) 	F-macro_val: tensor(0.4547, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.6215, dtype=torch.float64) 	F-macro_val: tensor(0.4450, dtype=torch.float64)
# Testing run # 4
# SE TUVIERON QUE REPETIR 3 EJEMPLOS
# Test_ acc: 0.6395690499510284
# Test_ f1 none: [0.10666667 0.12080537 0.53521127 0.76764907]
# Test_ f1 macro: 0.38258309452713046
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 5
# agregando predicciones Train
# agregando predicciones Val
# agregando predicciones Test
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.5312, dtype=torch.float64) 	F-macro_val: tensor(0.3694, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.5278, dtype=torch.float64) 	F-macro_val: tensor(0.3843, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.5451, dtype=torch.float64) 	F-macro_val: tensor(0.3868, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.5556, dtype=torch.float64) 	F-macro_val: tensor(0.4221, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.5556, dtype=torch.float64) 	F-macro_val: tensor(0.4067, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.5938, dtype=torch.float64) 	F-macro_val: tensor(0.4219, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.6111, dtype=torch.float64) 	F-macro_val: tensor(0.4270, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.5729, dtype=torch.float64) 	F-macro_val: tensor(0.4171, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.6319, dtype=torch.float64) 	F-macro_val: tensor(0.4308, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.6146, dtype=torch.float64) 	F-macro_val: tensor(0.4477, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.6007, dtype=torch.float64) 	F-macro_val: tensor(0.4356, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.6215, dtype=torch.float64) 	F-macro_val: tensor(0.4340, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.6528, dtype=torch.float64) 	F-macro_val: tensor(0.4220, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.6250, dtype=torch.float64) 	F-macro_val: tensor(0.4260, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.6562, dtype=torch.float64) 	F-macro_val: tensor(0.4378, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.6076, dtype=torch.float64) 	F-macro_val: tensor(0.4372, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.6389, dtype=torch.float64) 	F-macro_val: tensor(0.4518, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.6111, dtype=torch.float64) 	F-macro_val: tensor(0.4202, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.6215, dtype=torch.float64) 	F-macro_val: tensor(0.4161, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.6250, dtype=torch.float64) 	F-macro_val: tensor(0.4214, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.6111, dtype=torch.float64) 	F-macro_val: tensor(0.4493, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.6076, dtype=torch.float64) 	F-macro_val: tensor(0.4258, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.6111, dtype=torch.float64) 	F-macro_val: tensor(0.4122, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.6042, dtype=torch.float64) 	F-macro_val: tensor(0.4457, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.6215, dtype=torch.float64) 	F-macro_val: tensor(0.4523, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.6250, dtype=torch.float64) 	F-macro_val: tensor(0.4331, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.6389, dtype=torch.float64) 	F-macro_val: tensor(0.4543, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.6181, dtype=torch.float64) 	F-macro_val: tensor(0.4297, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.6250, dtype=torch.float64) 	F-macro_val: tensor(0.4169, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.6181, dtype=torch.float64) 	F-macro_val: tensor(0.4188, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.6285, dtype=torch.float64) 	F-macro_val: tensor(0.4371, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.6042, dtype=torch.float64) 	F-macro_val: tensor(0.4133, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.6354, dtype=torch.float64) 	F-macro_val: tensor(0.4054, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.6076, dtype=torch.float64) 	F-macro_val: tensor(0.4287, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.6285, dtype=torch.float64) 	F-macro_val: tensor(0.4247, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.6111, dtype=torch.float64) 	F-macro_val: tensor(0.4174, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.6285, dtype=torch.float64) 	F-macro_val: tensor(0.4039, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.6493, dtype=torch.float64) 	F-macro_val: tensor(0.4319, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.6042, dtype=torch.float64) 	F-macro_val: tensor(0.4379, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.6458, dtype=torch.float64) 	F-macro_val: tensor(0.4176, dtype=torch.float64)
# Testing run # 5
# SE TUVIERON QUE REPETIR 3 EJEMPLOS
# Test_ acc: 0.6718903036238981
# Test_ f1 none: [0.05       0.0483871  0.5        0.80130719]
# Test_ f1 macro: 0.3499235715791693
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1

# %%
print ("Acc:",np.mean(np.asarray(global_accs)))
print ("F-score:", np.mean(np.asarray(global_fmacros)))
sup=np.mean(np.asarray(global_fnones)[:,0])
den=np.mean(np.asarray(global_fnones)[:,1])
que=np.mean(np.asarray(global_fnones)[:,2])
com=np.mean(np.asarray(global_fnones)[:,3])

print ("(0.15) S-D-Q-C:", sup,den,que,com)
# Out:
# Acc: 0.6313418217433888
# F-score: 0.36949912060516893
# (0.15) S-D-Q-C: 0.1039167438323833 0.0975790038773745 0.5147576093263702 0.7617431253845477

# %%
m_temp=np.zeros((4,4))
for m in global_cms:
    m_temp+=np.asarray(m)
m_temp
# Out:
# array([[  50.,   32.,   21.,  237.],
#        [  28.,   38.,   31.,  248.],
#        [  30.,   12.,  345.,  143.],
#        [ 395.,  289.,  416., 2790.]])

# %%
plot_confusion_matrix(normalize(m_temp),["S","D","Q","C"],"(0.15) GloVe Transformer No aum - No CW", cmap='Blues')

# %%
label=[['Text', 'm1', 'm2','m3','m4','m5']]
for layer in range(2):
    fig, axs = plt.subplots(1,4, figsize=(20, 10))
    print ("Encoder Layer Attention head Promedio", layer)
    for head in range(4):
        at=np.zeros((6,6))
        matriz_attn= dict_attn_enc[str(layer)+str(head)]  #lista de 5 corridas en cada pos
        for m in matriz_attn:
            at+=m.numpy()
        sns.heatmap(at/5., xticklabels=label[0], yticklabels=label[0],
                    vmin=0.0, vmax=1.0, linewidths=.5, cmap="Purples", cbar=False, square=True, ax=axs[head]) #, annot=False,cbar_kws={"orientation": "horizontal","pad": 0.25})
    plt.show()
# Out:
# Encoder Layer Attention head Promedio 0
# Encoder Layer Attention head Promedio 1

# %%
np.save("Attn_SinAum_GloVe_AWE_15.npy", global_attn)

# %% [markdown]
# ## 0.0 Class Weigths

# %%
class_weights= compute_class_weight('balanced', np.unique(labels_train), labels_train)
print ("Pesos de clases:", class_weights)
# Out:
# Pesos de clases: [1. 1. 1. 1.]

# %%
global_accs=[]
global_fnones=[]
global_fmacros=[]
global_cms=[]
global_attn=[]
dict_attn_enc={'00':[], '01':[], '02':[], '03':[], '10':[], '11':[], '12':[], '13':[]}
  
prob=0.5

for trans in range(1,6): 
    print ("Entrenando Run #", trans)
    macro_augmented= np.load('../new_glove_augmented/stance/Aumento_'+str(trans)+'-run_'+str(prob)+'_app1_Top1.npy', allow_pickle=True)

    ids_train=macro_augmented[:,0]
    tws_train=macro_augmented[:,1]
    labels_train=macro_augmented[:,2]

    etiq=labels_train.copy()
    sentences = tws_train
    n_labels = np.array(etiq)
    y_train=to_categorical(n_labels,num_classes=4)
    
    input_ids = []
    for sent in sentences:
        encoded_tok=[]
        for wd in sent:
            try: 
                encoded_tok.append(Word2Index_valid[wd])
            except: 
                continue 
        input_ids.append(encoded_tok)
    
    input_ids = pad_sequences(input_ids, maxlen=MAX_LEN, dtype="long", 
                              value=0, truncating="post", padding="post")
    
    shape=np.asarray(input_ids).shape
    x_train=np.zeros((shape[0], shape[1], g_dim))
    j=0
    for in_id in input_ids:
        x_train[j]=M_GLOVE_space[in_id]
        j+=1
        
        
    cnn1 = load_model('../new_glove_augmented/stance_baselines/'+str(prob)+'/cnn1_'+str(trans)+'-exec_app1_Top_1.h5')
    cnn2 = load_model('../new_glove_augmented/stance_baselines/'+str(prob)+'/cnn2_'+str(trans)+'-exec_app1_Top_1.h5')
    rnn1 = load_model('../new_glove_augmented/stance_baselines/'+str(prob)+'/rnn1_'+str(trans)+'-exec_app1_Top_1.h5')
    rnn2 = load_model('../new_glove_augmented/stance_baselines/'+str(prob)+'/rnn2_'+str(trans)+'-exec_app1_Top_1.h5')
    rnn3 = load_model('../new_glove_augmented/stance_baselines/'+str(prob)+'/rnn3_'+str(trans)+'-exec_app1_Top_1.h5')

    list_models=['cnn1', 'cnn2', 'rnn1', 'rnn2', 'rnn3']
    index_models=np.arange(5)
    dict_models=dict((key, value) for (key, value) in zip(index_models,list_models))
    modelos=[cnn1, cnn2, rnn1, rnn2, rnn3]
    ind=np.arange(5)
    dict_trainedModel=dict((key, value) for (key, value) in zip(ind,modelos))

    bs=32
    predicciones_all=[]
    predicciones_all_val=[]
    predicciones_all_test=[]
    
    print ("agregando predicciones Train")
    for i in dict_trainedModel.keys(): 
        a_evaluar=dict_models[i]
        predicciones_all.append(dict_trainedModel[i].predict(x_train, batch_size=bs))
    print ("agregando predicciones Val")
    for i in dict_trainedModel.keys(): 
        a_evaluar=dict_models[i]
        predicciones_all_val.append(dict_trainedModel[i].predict(x_val, batch_size=bs))
    print ("agregando predicciones Test")
    for i in dict_trainedModel.keys(): 
        a_evaluar=dict_models[i]
        predicciones_all_test.append(dict_trainedModel[i].predict(x_test, batch_size=bs))

    matrix=np.asarray(predicciones_all)
    matrix_val=np.asarray(predicciones_all_val)
    matrix_test=np.asarray(predicciones_all_test)
    new_matrix=np.concatenate([matrix,matrix_val,matrix_test], axis=1)
    
    
    espacio=[np.ones(g_dim)]
    #Ks=np.load("../../BERTransformer/Orthogonals_768.npy")
    
    Ks= ortho_group.rvs(dim=g_dim)
    random=np.random.randint(Ks.shape[0], size=4)
    K_list=Ks[random]
    #print (K_list.shape)
    #break
    K_list_ext=espacio+list(K_list)
    index_embeddings=[0,1,2,3,4]
    lab_str_embeddings=['','','','','']

    for i in range(len(sentences)):
        ide=ids_train[i]
        tw_tr=tws_train[i]
        #tokens=cleaner(tw_tr)[1]
        clase=dict_cl[labels_train[i]]
        
        encoded_tok=[]
        for wd in tw_tr:
            try: 
                encoded_tok.append(Word2Index_valid[wd])
            except: 
                continue 
                
        q_glove=len(encoded_tok)
        glove_tok_f=[M_GLOVE_space[ide] for ide in encoded_tok]
        final=np.sum(glove_tok_f, axis=0)
        final_awe=final/q_glove
        norm=np.linalg.norm(final_awe)
        final_awe= final_awe / norm
        #print (i, type(tw_tr), type(final_awe), final_awe.shape, len(encoded_tok))
        
        index_embeddings.append(i+5)
        lab_str_embeddings.append(clase)
        if len(encoded_tok)==0:
            K_list_ext.append(np.zeros(g_dim))
        else: 
            K_list_ext.append(final_awe)
        
        #alo=np.asarray(K_list_ext, dtype='float32')
    
    
    objs_val=val['Tw_id']      #df_val['Unnamed: 0'].values
    objs_test=test['Tw_id']    #np.arange(df_test.shape[0])
    lab_val=val['Label']
    lab_test=test['Label']
    tw_val=val['Tweet']
    tw_test=test['Tweet']
    llaves=np.concatenate([objs_val,objs_test])
    clases=np.concatenate([lab_val,lab_test])
    sent_all=np.concatenate([tw_val,tw_test])
    
       
    for num in range(len(llaves)):
        i=llaves[num]
        clase=clases[num]
        tw_tr=sent_all[num]
        #vector=np.load("../BaS_Original/Original/"+str(i)+".npy")
        encoded_tok, tokens_valid =my_tokenizer(cleaner(tw_tr)[1])
    
        q_glove=len(encoded_tok)
        glove_tok_f=[M_GLOVE_space[ide] for ide in encoded_tok]
        final=np.sum(glove_tok_f, axis=0)
        final_awe=final/q_glove
        norm=np.linalg.norm(final_awe)
        final_awe= final_awe / norm

        index_embeddings.append(num+5+train.shape[0])
        lab_str_embeddings.append(clase)
        K_list_ext.append(final_awe)

    K_list_new= np.asarray(K_list_ext, dtype='float32')
    
    ###################################### TRANSFORMER ###############################
    V = 4
    pesos = torch.from_numpy(class_weights).float()
    criterion = FocalLoss(weights=pesos)
    model = make_model_concat(4, N=2,d_model=g_dim, d_ff=128, h=4, dropout=0.35)
    model_opt = NoamOpt(model.src_embed[0].d_model, 1, 500, torch.optim.Adam(model.parameters(), lr=0, betas=(0.9, 0.98), eps=1e-5))

    
    for epoch in range(40):
        model.train()
        DATA=data_gen(32, 'Train', 5, new_matrix)
        loss_train, acc_train,fma_train, f_none, cm_train=run_epoch(DATA, model, SimpleLossComputeFL(criterion, model_opt), 'Train')
        
        model.eval()
        loss_val, acc_val,fma_val, f_val_none, cm_val=run_epoch(data_gen(bs, 'Val', 5, new_matrix), model, SimpleLossComputeFL(criterion, None),'Val')
        print ("Epoch",epoch, "\tacc_val:",acc_val, "\tF-macro_val:",fma_val)
    
    model.eval()
    print ("Testing run #",trans)
    predicciones = run_epoch(data_gen(bs, 'Test', 5, new_matrix), model, SimpleLossComputeFL(criterion, None),'Test')
    predicciones=np.concatenate(predicciones, axis=-1)
    
    glo_acc=accuracy_score(etiq_t, predicciones[:-3])
    glo_fno=f1_score(etiq_t,predicciones[:-3], average=None)
    glo_fma=f1_score(etiq_t,predicciones[:-3], average='macro')

    glo_cm=confusion_matrix(etiq_t, predicciones[:-3])

    plot_confusion_matrix(glo_cm,["support","Denying","Questioning","Commenting"],"Pre-trained 0.5 aumento AWE")
    global_accs.append(glo_acc)
    global_fnones.append(glo_fno)
    global_fmacros.append(glo_fma)
    global_cms.append(glo_cm)
    print("Test_ acc:",glo_acc) 
    print("Test_ f1 none:",glo_fno) 
    print("Test_ f1 macro:",glo_fma) 

    label=[['Text', 'm1', 'm2','m3','m4','m5']]
    for layer in range(2):
        fig, axs = plt.subplots(1,4, figsize=(20, 10))
        print ("Encoder Layer Attention head", layer)
        for head in range(4):
            matriz_attn=model.encoder.layers[layer].self_attn.attn[0,head].data
            dict_attn_enc[str(layer)+str(head)].append(matriz_attn)
            sns.heatmap(matriz_attn, xticklabels=label[0], yticklabels=label[0],
                        vmin=0.0, vmax=1.0, linewidths=.5, cmap="Blues", cbar=False, square=True, ax=axs[head]) #, annot=False,cbar_kws={"orientation": "horizontal","pad": 0.25})
        plt.show()
# Out:
# Entrenando Run # 1
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:Large dropout rate: 0.65 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.65 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:Large dropout rate: 0.65 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.65 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.65 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# agregando predicciones Train
# agregando predicciones Val
# agregando predicciones Test
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.4410, dtype=torch.float64) 	F-macro_val: tensor(0.3516, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.5521, dtype=torch.float64) 	F-macro_val: tensor(0.4260, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.5590, dtype=torch.float64) 	F-macro_val: tensor(0.4307, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.5694, dtype=torch.float64) 	F-macro_val: tensor(0.4259, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.5590, dtype=torch.float64) 	F-macro_val: tensor(0.4284, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.5417, dtype=torch.float64) 	F-macro_val: tensor(0.3959, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.5382, dtype=torch.float64) 	F-macro_val: tensor(0.4164, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.5451, dtype=torch.float64) 	F-macro_val: tensor(0.4172, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.5521, dtype=torch.float64) 	F-macro_val: tensor(0.4342, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.5486, dtype=torch.float64) 	F-macro_val: tensor(0.4340, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.5451, dtype=torch.float64) 	F-macro_val: tensor(0.4171, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.5764, dtype=torch.float64) 	F-macro_val: tensor(0.4441, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.5382, dtype=torch.float64) 	F-macro_val: tensor(0.4168, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.5521, dtype=torch.float64) 	F-macro_val: tensor(0.4166, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.5521, dtype=torch.float64) 	F-macro_val: tensor(0.4137, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.5417, dtype=torch.float64) 	F-macro_val: tensor(0.4142, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.5243, dtype=torch.float64) 	F-macro_val: tensor(0.4213, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.5486, dtype=torch.float64) 	F-macro_val: tensor(0.4399, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.5590, dtype=torch.float64) 	F-macro_val: tensor(0.4206, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.5382, dtype=torch.float64) 	F-macro_val: tensor(0.3960, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.5694, dtype=torch.float64) 	F-macro_val: tensor(0.4314, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.5729, dtype=torch.float64) 	F-macro_val: tensor(0.4345, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.5486, dtype=torch.float64) 	F-macro_val: tensor(0.4193, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.5903, dtype=torch.float64) 	F-macro_val: tensor(0.4484, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.5799, dtype=torch.float64) 	F-macro_val: tensor(0.4428, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.5660, dtype=torch.float64) 	F-macro_val: tensor(0.4087, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.5660, dtype=torch.float64) 	F-macro_val: tensor(0.4533, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.5590, dtype=torch.float64) 	F-macro_val: tensor(0.4256, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.5729, dtype=torch.float64) 	F-macro_val: tensor(0.4290, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.5694, dtype=torch.float64) 	F-macro_val: tensor(0.4267, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.5764, dtype=torch.float64) 	F-macro_val: tensor(0.4329, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.5694, dtype=torch.float64) 	F-macro_val: tensor(0.4376, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.5660, dtype=torch.float64) 	F-macro_val: tensor(0.4104, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.5764, dtype=torch.float64) 	F-macro_val: tensor(0.4210, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.5556, dtype=torch.float64) 	F-macro_val: tensor(0.4447, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.5486, dtype=torch.float64) 	F-macro_val: tensor(0.4312, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.5660, dtype=torch.float64) 	F-macro_val: tensor(0.4364, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.5625, dtype=torch.float64) 	F-macro_val: tensor(0.4297, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.5625, dtype=torch.float64) 	F-macro_val: tensor(0.4455, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.5590, dtype=torch.float64) 	F-macro_val: tensor(0.4270, dtype=torch.float64)
# Testing run # 1
# SE TUVIERON QUE REPETIR 3 EJEMPLOS
# Test_ acc: 0.48579823702252695
# Test_ f1 none: [0.12195122 0.11707317 0.54298643 0.62732919]
# Test_ f1 macro: 0.3523350020324632
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 2
# agregando predicciones Train
# agregando predicciones Val
# agregando predicciones Test
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.3507, dtype=torch.float64) 	F-macro_val: tensor(0.3021, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.5035, dtype=torch.float64) 	F-macro_val: tensor(0.3871, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.5104, dtype=torch.float64) 	F-macro_val: tensor(0.4010, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.5139, dtype=torch.float64) 	F-macro_val: tensor(0.3856, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.5278, dtype=torch.float64) 	F-macro_val: tensor(0.4248, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.5278, dtype=torch.float64) 	F-macro_val: tensor(0.4232, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.5486, dtype=torch.float64) 	F-macro_val: tensor(0.4306, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.5382, dtype=torch.float64) 	F-macro_val: tensor(0.4210, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.5694, dtype=torch.float64) 	F-macro_val: tensor(0.4432, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.5833, dtype=torch.float64) 	F-macro_val: tensor(0.4510, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.5729, dtype=torch.float64) 	F-macro_val: tensor(0.4371, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.5660, dtype=torch.float64) 	F-macro_val: tensor(0.4062, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.5660, dtype=torch.float64) 	F-macro_val: tensor(0.4208, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.5660, dtype=torch.float64) 	F-macro_val: tensor(0.4294, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.5590, dtype=torch.float64) 	F-macro_val: tensor(0.4074, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.5799, dtype=torch.float64) 	F-macro_val: tensor(0.4386, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.5903, dtype=torch.float64) 	F-macro_val: tensor(0.4407, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.6042, dtype=torch.float64) 	F-macro_val: tensor(0.4502, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.5521, dtype=torch.float64) 	F-macro_val: tensor(0.4301, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.5417, dtype=torch.float64) 	F-macro_val: tensor(0.4238, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.5556, dtype=torch.float64) 	F-macro_val: tensor(0.4283, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.5833, dtype=torch.float64) 	F-macro_val: tensor(0.4477, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.5590, dtype=torch.float64) 	F-macro_val: tensor(0.4323, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.5486, dtype=torch.float64) 	F-macro_val: tensor(0.4135, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.5660, dtype=torch.float64) 	F-macro_val: tensor(0.4297, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.5868, dtype=torch.float64) 	F-macro_val: tensor(0.4421, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.5868, dtype=torch.float64) 	F-macro_val: tensor(0.4307, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.5556, dtype=torch.float64) 	F-macro_val: tensor(0.4401, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.5903, dtype=torch.float64) 	F-macro_val: tensor(0.4469, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.5799, dtype=torch.float64) 	F-macro_val: tensor(0.4181, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.5833, dtype=torch.float64) 	F-macro_val: tensor(0.4469, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.5764, dtype=torch.float64) 	F-macro_val: tensor(0.4639, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.5660, dtype=torch.float64) 	F-macro_val: tensor(0.4357, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.5868, dtype=torch.float64) 	F-macro_val: tensor(0.4471, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.5486, dtype=torch.float64) 	F-macro_val: tensor(0.4056, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.5938, dtype=torch.float64) 	F-macro_val: tensor(0.4526, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.5833, dtype=torch.float64) 	F-macro_val: tensor(0.4416, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.5868, dtype=torch.float64) 	F-macro_val: tensor(0.4420, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.5694, dtype=torch.float64) 	F-macro_val: tensor(0.4207, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.5833, dtype=torch.float64) 	F-macro_val: tensor(0.4366, dtype=torch.float64)
# Testing run # 2
# SE TUVIERON QUE REPETIR 3 EJEMPLOS
# Test_ acc: 0.555337904015671
# Test_ f1 none: [0.12658228 0.09142857 0.49420849 0.70021882]
# Test_ f1 macro: 0.35310954062470556
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 3
# agregando predicciones Train
# agregando predicciones Val
# agregando predicciones Test
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.5694, dtype=torch.float64) 	F-macro_val: tensor(0.3880, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.5764, dtype=torch.float64) 	F-macro_val: tensor(0.4309, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.5764, dtype=torch.float64) 	F-macro_val: tensor(0.4147, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.5590, dtype=torch.float64) 	F-macro_val: tensor(0.4228, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.5938, dtype=torch.float64) 	F-macro_val: tensor(0.4201, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.5590, dtype=torch.float64) 	F-macro_val: tensor(0.4264, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.5694, dtype=torch.float64) 	F-macro_val: tensor(0.4144, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.5347, dtype=torch.float64) 	F-macro_val: tensor(0.4056, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.5382, dtype=torch.float64) 	F-macro_val: tensor(0.3994, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.5590, dtype=torch.float64) 	F-macro_val: tensor(0.4089, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.5972, dtype=torch.float64) 	F-macro_val: tensor(0.4531, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.5764, dtype=torch.float64) 	F-macro_val: tensor(0.4141, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.5868, dtype=torch.float64) 	F-macro_val: tensor(0.4268, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.5521, dtype=torch.float64) 	F-macro_val: tensor(0.4106, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.5833, dtype=torch.float64) 	F-macro_val: tensor(0.4481, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.5833, dtype=torch.float64) 	F-macro_val: tensor(0.4336, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.6076, dtype=torch.float64) 	F-macro_val: tensor(0.4346, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.5764, dtype=torch.float64) 	F-macro_val: tensor(0.4397, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.5938, dtype=torch.float64) 	F-macro_val: tensor(0.4399, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.6042, dtype=torch.float64) 	F-macro_val: tensor(0.4386, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.5938, dtype=torch.float64) 	F-macro_val: tensor(0.4298, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.5660, dtype=torch.float64) 	F-macro_val: tensor(0.4203, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.5694, dtype=torch.float64) 	F-macro_val: tensor(0.4327, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.5556, dtype=torch.float64) 	F-macro_val: tensor(0.4079, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.5972, dtype=torch.float64) 	F-macro_val: tensor(0.4333, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.5903, dtype=torch.float64) 	F-macro_val: tensor(0.4299, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.5938, dtype=torch.float64) 	F-macro_val: tensor(0.4516, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.5833, dtype=torch.float64) 	F-macro_val: tensor(0.4245, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.6042, dtype=torch.float64) 	F-macro_val: tensor(0.4192, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.5729, dtype=torch.float64) 	F-macro_val: tensor(0.4203, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.5451, dtype=torch.float64) 	F-macro_val: tensor(0.4090, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.5799, dtype=torch.float64) 	F-macro_val: tensor(0.4236, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.5660, dtype=torch.float64) 	F-macro_val: tensor(0.4121, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.5660, dtype=torch.float64) 	F-macro_val: tensor(0.4224, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.5694, dtype=torch.float64) 	F-macro_val: tensor(0.4257, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.5938, dtype=torch.float64) 	F-macro_val: tensor(0.4316, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.6042, dtype=torch.float64) 	F-macro_val: tensor(0.4604, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.5590, dtype=torch.float64) 	F-macro_val: tensor(0.4318, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.5938, dtype=torch.float64) 	F-macro_val: tensor(0.4294, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.5833, dtype=torch.float64) 	F-macro_val: tensor(0.4342, dtype=torch.float64)
# Testing run # 3
# SE TUVIERON QUE REPETIR 3 EJEMPLOS
# Test_ acc: 0.6160626836434868
# Test_ f1 none: [0.09150327 0.0952381  0.48648649 0.7564276 ]
# Test_ f1 macro: 0.3574138636424714
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 4
# agregando predicciones Train
# agregando predicciones Val
# agregando predicciones Test
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.5486, dtype=torch.float64) 	F-macro_val: tensor(0.3902, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.5938, dtype=torch.float64) 	F-macro_val: tensor(0.3946, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.5660, dtype=torch.float64) 	F-macro_val: tensor(0.4174, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.5625, dtype=torch.float64) 	F-macro_val: tensor(0.4209, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.5833, dtype=torch.float64) 	F-macro_val: tensor(0.3814, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.5660, dtype=torch.float64) 	F-macro_val: tensor(0.3973, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.5868, dtype=torch.float64) 	F-macro_val: tensor(0.3974, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.6042, dtype=torch.float64) 	F-macro_val: tensor(0.4246, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.5833, dtype=torch.float64) 	F-macro_val: tensor(0.3779, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.5903, dtype=torch.float64) 	F-macro_val: tensor(0.4281, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.5868, dtype=torch.float64) 	F-macro_val: tensor(0.4154, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.5972, dtype=torch.float64) 	F-macro_val: tensor(0.4199, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.5972, dtype=torch.float64) 	F-macro_val: tensor(0.4358, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.5938, dtype=torch.float64) 	F-macro_val: tensor(0.3950, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.5903, dtype=torch.float64) 	F-macro_val: tensor(0.4242, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.6181, dtype=torch.float64) 	F-macro_val: tensor(0.4275, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.5694, dtype=torch.float64) 	F-macro_val: tensor(0.4086, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.5938, dtype=torch.float64) 	F-macro_val: tensor(0.4115, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.5764, dtype=torch.float64) 	F-macro_val: tensor(0.4303, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.6007, dtype=torch.float64) 	F-macro_val: tensor(0.4371, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.6007, dtype=torch.float64) 	F-macro_val: tensor(0.4029, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.5868, dtype=torch.float64) 	F-macro_val: tensor(0.4141, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.5972, dtype=torch.float64) 	F-macro_val: tensor(0.4347, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.5972, dtype=torch.float64) 	F-macro_val: tensor(0.3870, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.5972, dtype=torch.float64) 	F-macro_val: tensor(0.4174, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.6146, dtype=torch.float64) 	F-macro_val: tensor(0.4124, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.5972, dtype=torch.float64) 	F-macro_val: tensor(0.4062, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.6076, dtype=torch.float64) 	F-macro_val: tensor(0.4222, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.6111, dtype=torch.float64) 	F-macro_val: tensor(0.4052, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.5729, dtype=torch.float64) 	F-macro_val: tensor(0.4079, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.6215, dtype=torch.float64) 	F-macro_val: tensor(0.4210, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.6319, dtype=torch.float64) 	F-macro_val: tensor(0.4450, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.6146, dtype=torch.float64) 	F-macro_val: tensor(0.4287, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.6007, dtype=torch.float64) 	F-macro_val: tensor(0.4347, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.6250, dtype=torch.float64) 	F-macro_val: tensor(0.4439, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.5938, dtype=torch.float64) 	F-macro_val: tensor(0.3989, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.6181, dtype=torch.float64) 	F-macro_val: tensor(0.4304, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.6111, dtype=torch.float64) 	F-macro_val: tensor(0.4253, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.6007, dtype=torch.float64) 	F-macro_val: tensor(0.4122, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.6076, dtype=torch.float64) 	F-macro_val: tensor(0.4207, dtype=torch.float64)
# Testing run # 4
# SE TUVIERON QUE REPETIR 3 EJEMPLOS
# Test_ acc: 0.67384916748286
# Test_ f1 none: [0.12820513 0.14965986 0.54700855 0.8013289 ]
# Test_ f1 macro: 0.4065506107034347
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 5
# agregando predicciones Train
# agregando predicciones Val
# agregando predicciones Test
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.1771, dtype=torch.float64) 	F-macro_val: tensor(0.2318, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.5243, dtype=torch.float64) 	F-macro_val: tensor(0.4295, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.5694, dtype=torch.float64) 	F-macro_val: tensor(0.4344, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.5799, dtype=torch.float64) 	F-macro_val: tensor(0.4412, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.5694, dtype=torch.float64) 	F-macro_val: tensor(0.4549, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.5694, dtype=torch.float64) 	F-macro_val: tensor(0.4181, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.5660, dtype=torch.float64) 	F-macro_val: tensor(0.4375, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.5208, dtype=torch.float64) 	F-macro_val: tensor(0.4114, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.5903, dtype=torch.float64) 	F-macro_val: tensor(0.4412, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.5868, dtype=torch.float64) 	F-macro_val: tensor(0.4375, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.5417, dtype=torch.float64) 	F-macro_val: tensor(0.4271, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.5556, dtype=torch.float64) 	F-macro_val: tensor(0.4167, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.5799, dtype=torch.float64) 	F-macro_val: tensor(0.4461, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.5903, dtype=torch.float64) 	F-macro_val: tensor(0.4538, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.5312, dtype=torch.float64) 	F-macro_val: tensor(0.4210, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.5833, dtype=torch.float64) 	F-macro_val: tensor(0.4297, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.5799, dtype=torch.float64) 	F-macro_val: tensor(0.4342, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.5868, dtype=torch.float64) 	F-macro_val: tensor(0.4441, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.5764, dtype=torch.float64) 	F-macro_val: tensor(0.4347, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.5556, dtype=torch.float64) 	F-macro_val: tensor(0.4122, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.5347, dtype=torch.float64) 	F-macro_val: tensor(0.4212, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.5972, dtype=torch.float64) 	F-macro_val: tensor(0.4013, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.6146, dtype=torch.float64) 	F-macro_val: tensor(0.4127, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.5938, dtype=torch.float64) 	F-macro_val: tensor(0.4203, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.5833, dtype=torch.float64) 	F-macro_val: tensor(0.4074, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.5694, dtype=torch.float64) 	F-macro_val: tensor(0.4323, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.5972, dtype=torch.float64) 	F-macro_val: tensor(0.4286, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.6076, dtype=torch.float64) 	F-macro_val: tensor(0.4152, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.5833, dtype=torch.float64) 	F-macro_val: tensor(0.4346, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.5729, dtype=torch.float64) 	F-macro_val: tensor(0.4439, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.5799, dtype=torch.float64) 	F-macro_val: tensor(0.4367, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.5868, dtype=torch.float64) 	F-macro_val: tensor(0.4473, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.6146, dtype=torch.float64) 	F-macro_val: tensor(0.4449, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.5868, dtype=torch.float64) 	F-macro_val: tensor(0.4298, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.5833, dtype=torch.float64) 	F-macro_val: tensor(0.4460, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.5938, dtype=torch.float64) 	F-macro_val: tensor(0.4531, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.6007, dtype=torch.float64) 	F-macro_val: tensor(0.4433, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.5938, dtype=torch.float64) 	F-macro_val: tensor(0.4315, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.5903, dtype=torch.float64) 	F-macro_val: tensor(0.4387, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.5729, dtype=torch.float64) 	F-macro_val: tensor(0.4100, dtype=torch.float64)
# Testing run # 5
# SE TUVIERON QUE REPETIR 3 EJEMPLOS
# Test_ acc: 0.6101860920666013
# Test_ f1 none: [0.12       0.14414414 0.50241546 0.74641148]
# Test_ f1 macro: 0.37824277158373265
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1

# %%
print ("Acc:",np.mean(np.asarray(global_accs)))
print ("F-score:", np.mean(np.asarray(global_fmacros)))
sup=np.mean(np.asarray(global_fnones)[:,0])
den=np.mean(np.asarray(global_fnones)[:,1])
que=np.mean(np.asarray(global_fnones)[:,2])
com=np.mean(np.asarray(global_fnones)[:,3])

print ("(0.5) S-D-Q-C:", sup,den,que,com)
# Out:
# Acc: 0.5882468168462293
# F-score: 0.3695303577173615
# (0.5) S-D-Q-C: 0.11764837883443843 0.11950876909761927 0.5146210823960184 0.7263432005413698

# %%
m_temp=np.zeros((4,4))
for m in global_cms:
    m_temp+=np.asarray(m)
m_temp
# Out:
# array([[  61.,   35.,   12.,  232.],
#        [  42.,   56.,   28.,  219.],
#        [  41.,   23.,  294.,  172.],
#        [ 540.,  479.,  279., 2592.]])

# %%
plot_confusion_matrix(normalize(m_temp),["S","D","Q","C"],"(0.5) GloVe Transformer Aum ", cmap='Blues')

# %%
label=[['Text', 'm1', 'm2','m3','m4','m5']]
for layer in range(2):
    fig, axs = plt.subplots(1,4, figsize=(20, 10))
    print ("Encoder Layer Attention head Promedio", layer)
    for head in range(4):
        at=np.zeros((6,6))
        matriz_attn= dict_attn_enc[str(layer)+str(head)]  #lista de 5 corridas en cada pos
        for m in matriz_attn:
            at+=m.numpy()
        sns.heatmap(at/5., xticklabels=label[0], yticklabels=label[0],
                    vmin=0.0, vmax=1.0, linewidths=.5, cmap="Purples", cbar=False, square=True, ax=axs[head]) #, annot=False,cbar_kws={"orientation": "horizontal","pad": 0.25})
    plt.show()
# Out:
# Encoder Layer Attention head Promedio 0
# Encoder Layer Attention head Promedio 1

# %%
np.save("Attn_SinAum_GloVe_AWE_50.npy", global_attn)

# %% [markdown]
# ### 0.85

# %%
global_accs=[]
global_fnones=[]
global_fmacros=[]
global_cms=[]
global_attn=[]
dict_attn_enc={'00':[], '01':[], '02':[], '03':[], '10':[], '11':[], '12':[], '13':[]}
  
prob=0.85

for trans in range(1,6): 
    print ("Entrenando Run #", trans)
    macro_augmented= np.load('../new_glove_augmented/stance/Aumento_'+str(trans)+'-run_'+str(prob)+'_app1_Top1.npy', allow_pickle=True)

    ids_train=macro_augmented[:,0]
    tws_train=macro_augmented[:,1]
    labels_train=macro_augmented[:,2]

    etiq=labels_train.copy()
    sentences = tws_train
    n_labels = np.array(etiq)
    y_train=to_categorical(n_labels,num_classes=4)
    
    input_ids = []
    for sent in sentences:
        encoded_tok=[]
        for wd in sent:
            try: 
                encoded_tok.append(Word2Index_valid[wd])
            except: 
                continue 
        input_ids.append(encoded_tok)
    
    input_ids = pad_sequences(input_ids, maxlen=MAX_LEN, dtype="long", 
                              value=0, truncating="post", padding="post")
    
    shape=np.asarray(input_ids).shape
    x_train=np.zeros((shape[0], shape[1], g_dim))
    j=0
    for in_id in input_ids:
        x_train[j]=M_GLOVE_space[in_id]
        j+=1
        
        
    cnn1 = load_model('../new_glove_augmented/stance_baselines/'+str(prob)+'/cnn1_'+str(trans)+'-exec_app1_Top_1.h5')
    cnn2 = load_model('../new_glove_augmented/stance_baselines/'+str(prob)+'/cnn2_'+str(trans)+'-exec_app1_Top_1.h5')
    rnn1 = load_model('../new_glove_augmented/stance_baselines/'+str(prob)+'/rnn1_'+str(trans)+'-exec_app1_Top_1.h5')
    rnn2 = load_model('../new_glove_augmented/stance_baselines/'+str(prob)+'/rnn2_'+str(trans)+'-exec_app1_Top_1.h5')
    rnn3 = load_model('../new_glove_augmented/stance_baselines/'+str(prob)+'/rnn3_'+str(trans)+'-exec_app1_Top_1.h5')

    list_models=['cnn1', 'cnn2', 'rnn1', 'rnn2', 'rnn3']
    index_models=np.arange(5)
    dict_models=dict((key, value) for (key, value) in zip(index_models,list_models))
    modelos=[cnn1, cnn2, rnn1, rnn2, rnn3]
    ind=np.arange(5)
    dict_trainedModel=dict((key, value) for (key, value) in zip(ind,modelos))

    bs=32
    predicciones_all=[]
    predicciones_all_val=[]
    predicciones_all_test=[]
    
    print ("agregando predicciones Train")
    for i in dict_trainedModel.keys(): 
        a_evaluar=dict_models[i]
        predicciones_all.append(dict_trainedModel[i].predict(x_train, batch_size=bs))
    print ("agregando predicciones Val")
    for i in dict_trainedModel.keys(): 
        a_evaluar=dict_models[i]
        predicciones_all_val.append(dict_trainedModel[i].predict(x_val, batch_size=bs))
    print ("agregando predicciones Test")
    for i in dict_trainedModel.keys(): 
        a_evaluar=dict_models[i]
        predicciones_all_test.append(dict_trainedModel[i].predict(x_test, batch_size=bs))

    matrix=np.asarray(predicciones_all)
    matrix_val=np.asarray(predicciones_all_val)
    matrix_test=np.asarray(predicciones_all_test)
    new_matrix=np.concatenate([matrix,matrix_val,matrix_test], axis=1)
    
    
    espacio=[np.ones(g_dim)]
    #Ks=np.load("../../BERTransformer/Orthogonals_768.npy")
    
    Ks= ortho_group.rvs(dim=g_dim)
    random=np.random.randint(Ks.shape[0], size=4)
    K_list=Ks[random]
    #print (K_list.shape)
    #break
    K_list_ext=espacio+list(K_list)
    index_embeddings=[0,1,2,3,4]
    lab_str_embeddings=['','','','','']

    for i in range(len(sentences)):
        ide=ids_train[i]
        tw_tr=tws_train[i]
        #tokens=cleaner(tw_tr)[1]
        clase=dict_cl[labels_train[i]]
        
        encoded_tok=[]
        for wd in tw_tr:
            try: 
                encoded_tok.append(Word2Index_valid[wd])
            except: 
                continue 
                
        q_glove=len(encoded_tok)
        glove_tok_f=[M_GLOVE_space[ide] for ide in encoded_tok]
        final=np.sum(glove_tok_f, axis=0)
        final_awe=final/q_glove
        norm=np.linalg.norm(final_awe)
        final_awe= final_awe / norm
        #print (i, type(tw_tr), type(final_awe), final_awe.shape, len(encoded_tok))
        
        index_embeddings.append(i+5)
        lab_str_embeddings.append(clase)
        if len(encoded_tok)==0:
            K_list_ext.append(np.zeros(g_dim))
        else: 
            K_list_ext.append(final_awe)
        
        #alo=np.asarray(K_list_ext, dtype='float32')
    
    
    objs_val=val['Tw_id']      #df_val['Unnamed: 0'].values
    objs_test=test['Tw_id']    #np.arange(df_test.shape[0])
    lab_val=val['Label']
    lab_test=test['Label']
    tw_val=val['Tweet']
    tw_test=test['Tweet']
    llaves=np.concatenate([objs_val,objs_test])
    clases=np.concatenate([lab_val,lab_test])
    sent_all=np.concatenate([tw_val,tw_test])
    
       
    for num in range(len(llaves)):
        i=llaves[num]
        clase=clases[num]
        tw_tr=sent_all[num]
        #vector=np.load("../BaS_Original/Original/"+str(i)+".npy")
        encoded_tok, tokens_valid =my_tokenizer(cleaner(tw_tr)[1])
    
        q_glove=len(encoded_tok)
        glove_tok_f=[M_GLOVE_space[ide] for ide in encoded_tok]
        final=np.sum(glove_tok_f, axis=0)
        final_awe=final/q_glove
        norm=np.linalg.norm(final_awe)
        final_awe= final_awe / norm

        index_embeddings.append(num+5+train.shape[0])
        lab_str_embeddings.append(clase)
        K_list_ext.append(final_awe)

    K_list_new= np.asarray(K_list_ext, dtype='float32')
    
    ###################################### TRANSFORMER ###############################
    V = 4
    pesos = torch.from_numpy(class_weights).float()
    criterion = FocalLoss(weights=pesos)
    model = make_model_concat(4, N=2,d_model=g_dim, d_ff=128, h=4, dropout=0.35)
    model_opt = NoamOpt(model.src_embed[0].d_model, 1, 500, torch.optim.Adam(model.parameters(), lr=0, betas=(0.9, 0.98), eps=1e-5))

    
    for epoch in range(40):
        model.train()
        DATA=data_gen(32, 'Train', 5, new_matrix)
        loss_train, acc_train,fma_train, f_none, cm_train=run_epoch(DATA, model, SimpleLossComputeFL(criterion, model_opt), 'Train')
        
        model.eval()
        loss_val, acc_val,fma_val, f_val_none, cm_val=run_epoch(data_gen(bs, 'Val', 5, new_matrix), model, SimpleLossComputeFL(criterion, None),'Val')
        print ("Epoch",epoch, "\tacc_val:",acc_val, "\tF-macro_val:",fma_val)
    
    model.eval()
    print ("Testing run #",trans)
    predicciones = run_epoch(data_gen(bs, 'Test', 5, new_matrix), model, SimpleLossComputeFL(criterion, None),'Test')
    predicciones=np.concatenate(predicciones, axis=-1)
    
    glo_acc=accuracy_score(etiq_t, predicciones[:-3])
    glo_fno=f1_score(etiq_t,predicciones[:-3], average=None)
    glo_fma=f1_score(etiq_t,predicciones[:-3], average='macro')

    glo_cm=confusion_matrix(etiq_t, predicciones[:-3])

    plot_confusion_matrix(glo_cm,["support","Denying","Questioning","Commenting"],"Pre-trained 0.5 aumento AWE")
    global_accs.append(glo_acc)
    global_fnones.append(glo_fno)
    global_fmacros.append(glo_fma)
    global_cms.append(glo_cm)
    print("Test_ acc:",glo_acc) 
    print("Test_ f1 none:",glo_fno) 
    print("Test_ f1 macro:",glo_fma) 

    label=[['Text', 'm1', 'm2','m3','m4','m5']]
    for layer in range(2):
        fig, axs = plt.subplots(1,4, figsize=(20, 10))
        print ("Encoder Layer Attention head", layer)
        for head in range(4):
            matriz_attn=model.encoder.layers[layer].self_attn.attn[0,head].data
            dict_attn_enc[str(layer)+str(head)].append(matriz_attn)
            sns.heatmap(matriz_attn, xticklabels=label[0], yticklabels=label[0],
                        vmin=0.0, vmax=1.0, linewidths=.5, cmap="Blues", cbar=False, square=True, ax=axs[head]) #, annot=False,cbar_kws={"orientation": "horizontal","pad": 0.25})
        plt.show()
# Out:
# Entrenando Run # 1
# agregando predicciones Train
# agregando predicciones Val
# agregando predicciones Test
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.3333, dtype=torch.float64) 	F-macro_val: tensor(0.2581, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.5625, dtype=torch.float64) 	F-macro_val: tensor(0.3984, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.5764, dtype=torch.float64) 	F-macro_val: tensor(0.4206, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.6007, dtype=torch.float64) 	F-macro_val: tensor(0.4125, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.5660, dtype=torch.float64) 	F-macro_val: tensor(0.4054, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.5868, dtype=torch.float64) 	F-macro_val: tensor(0.4410, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.5972, dtype=torch.float64) 	F-macro_val: tensor(0.4266, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.5694, dtype=torch.float64) 	F-macro_val: tensor(0.4355, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.6042, dtype=torch.float64) 	F-macro_val: tensor(0.4302, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.6076, dtype=torch.float64) 	F-macro_val: tensor(0.4304, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.5660, dtype=torch.float64) 	F-macro_val: tensor(0.4156, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.5938, dtype=torch.float64) 	F-macro_val: tensor(0.4371, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.5833, dtype=torch.float64) 	F-macro_val: tensor(0.4169, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.5903, dtype=torch.float64) 	F-macro_val: tensor(0.4323, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.5903, dtype=torch.float64) 	F-macro_val: tensor(0.4250, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.5833, dtype=torch.float64) 	F-macro_val: tensor(0.4182, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.5903, dtype=torch.float64) 	F-macro_val: tensor(0.4555, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.5799, dtype=torch.float64) 	F-macro_val: tensor(0.4241, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.5799, dtype=torch.float64) 	F-macro_val: tensor(0.4008, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.5625, dtype=torch.float64) 	F-macro_val: tensor(0.4237, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.5972, dtype=torch.float64) 	F-macro_val: tensor(0.4235, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.5660, dtype=torch.float64) 	F-macro_val: tensor(0.4247, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.5799, dtype=torch.float64) 	F-macro_val: tensor(0.4272, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.5799, dtype=torch.float64) 	F-macro_val: tensor(0.4020, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.5764, dtype=torch.float64) 	F-macro_val: tensor(0.4287, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.5868, dtype=torch.float64) 	F-macro_val: tensor(0.4401, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.5694, dtype=torch.float64) 	F-macro_val: tensor(0.4136, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.5972, dtype=torch.float64) 	F-macro_val: tensor(0.4523, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.5833, dtype=torch.float64) 	F-macro_val: tensor(0.4123, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.5764, dtype=torch.float64) 	F-macro_val: tensor(0.4106, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.5625, dtype=torch.float64) 	F-macro_val: tensor(0.4006, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.5903, dtype=torch.float64) 	F-macro_val: tensor(0.4170, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.5799, dtype=torch.float64) 	F-macro_val: tensor(0.4124, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.5729, dtype=torch.float64) 	F-macro_val: tensor(0.4248, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.5660, dtype=torch.float64) 	F-macro_val: tensor(0.4321, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.5833, dtype=torch.float64) 	F-macro_val: tensor(0.4155, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.5938, dtype=torch.float64) 	F-macro_val: tensor(0.4282, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.6076, dtype=torch.float64) 	F-macro_val: tensor(0.4440, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.5868, dtype=torch.float64) 	F-macro_val: tensor(0.4196, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.5938, dtype=torch.float64) 	F-macro_val: tensor(0.4210, dtype=torch.float64)
# Testing run # 1
# SE TUVIERON QUE REPETIR 3 EJEMPLOS
# Test_ acc: 0.6405484818805093
# Test_ f1 none: [0.10928962 0.09448819 0.48945148 0.77591973]
# Test_ f1 macro: 0.36728725392435935
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 2
# agregando predicciones Train
# agregando predicciones Val
# agregando predicciones Test
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.6250, dtype=torch.float64) 	F-macro_val: tensor(0.4360, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.5312, dtype=torch.float64) 	F-macro_val: tensor(0.4140, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.5833, dtype=torch.float64) 	F-macro_val: tensor(0.4272, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.6007, dtype=torch.float64) 	F-macro_val: tensor(0.4049, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.6146, dtype=torch.float64) 	F-macro_val: tensor(0.4135, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.6146, dtype=torch.float64) 	F-macro_val: tensor(0.4266, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.6319, dtype=torch.float64) 	F-macro_val: tensor(0.4398, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.6319, dtype=torch.float64) 	F-macro_val: tensor(0.4455, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.6354, dtype=torch.float64) 	F-macro_val: tensor(0.4286, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.6111, dtype=torch.float64) 	F-macro_val: tensor(0.4138, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.6250, dtype=torch.float64) 	F-macro_val: tensor(0.4235, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.6354, dtype=torch.float64) 	F-macro_val: tensor(0.4297, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.6424, dtype=torch.float64) 	F-macro_val: tensor(0.4335, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.6562, dtype=torch.float64) 	F-macro_val: tensor(0.4189, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.6181, dtype=torch.float64) 	F-macro_val: tensor(0.4217, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.6181, dtype=torch.float64) 	F-macro_val: tensor(0.4167, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.6250, dtype=torch.float64) 	F-macro_val: tensor(0.4245, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.6562, dtype=torch.float64) 	F-macro_val: tensor(0.4549, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.6354, dtype=torch.float64) 	F-macro_val: tensor(0.4377, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.6285, dtype=torch.float64) 	F-macro_val: tensor(0.4013, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.6493, dtype=torch.float64) 	F-macro_val: tensor(0.4609, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.6319, dtype=torch.float64) 	F-macro_val: tensor(0.4385, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.6458, dtype=torch.float64) 	F-macro_val: tensor(0.4032, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.6076, dtype=torch.float64) 	F-macro_val: tensor(0.4141, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.6354, dtype=torch.float64) 	F-macro_val: tensor(0.4336, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.6424, dtype=torch.float64) 	F-macro_val: tensor(0.4312, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.6458, dtype=torch.float64) 	F-macro_val: tensor(0.4477, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.6319, dtype=torch.float64) 	F-macro_val: tensor(0.4266, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.6285, dtype=torch.float64) 	F-macro_val: tensor(0.4101, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.6562, dtype=torch.float64) 	F-macro_val: tensor(0.4297, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.6354, dtype=torch.float64) 	F-macro_val: tensor(0.4213, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.6215, dtype=torch.float64) 	F-macro_val: tensor(0.4211, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.6493, dtype=torch.float64) 	F-macro_val: tensor(0.4393, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.6319, dtype=torch.float64) 	F-macro_val: tensor(0.4393, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.6215, dtype=torch.float64) 	F-macro_val: tensor(0.4345, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.6250, dtype=torch.float64) 	F-macro_val: tensor(0.4406, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.6319, dtype=torch.float64) 	F-macro_val: tensor(0.4325, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.6319, dtype=torch.float64) 	F-macro_val: tensor(0.4261, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.6458, dtype=torch.float64) 	F-macro_val: tensor(0.4328, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.6319, dtype=torch.float64) 	F-macro_val: tensor(0.4325, dtype=torch.float64)
# Testing run # 2
# SE TUVIERON QUE REPETIR 3 EJEMPLOS
# Test_ acc: 0.6503428011753183
# Test_ f1 none: [0.15300546 0.09160305 0.48113208 0.7823219 ]
# Test_ f1 macro: 0.37701562328095867
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 3
# agregando predicciones Train
# agregando predicciones Val
# agregando predicciones Test
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.5069, dtype=torch.float64) 	F-macro_val: tensor(0.3935, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.5556, dtype=torch.float64) 	F-macro_val: tensor(0.4237, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.5625, dtype=torch.float64) 	F-macro_val: tensor(0.3890, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.5208, dtype=torch.float64) 	F-macro_val: tensor(0.4017, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.5174, dtype=torch.float64) 	F-macro_val: tensor(0.3985, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.4722, dtype=torch.float64) 	F-macro_val: tensor(0.3662, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.5694, dtype=torch.float64) 	F-macro_val: tensor(0.4333, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.5382, dtype=torch.float64) 	F-macro_val: tensor(0.3874, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.5451, dtype=torch.float64) 	F-macro_val: tensor(0.4208, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.5174, dtype=torch.float64) 	F-macro_val: tensor(0.3945, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.5729, dtype=torch.float64) 	F-macro_val: tensor(0.4015, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.5521, dtype=torch.float64) 	F-macro_val: tensor(0.4240, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.5521, dtype=torch.float64) 	F-macro_val: tensor(0.4066, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.5660, dtype=torch.float64) 	F-macro_val: tensor(0.3947, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.5660, dtype=torch.float64) 	F-macro_val: tensor(0.4041, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.5694, dtype=torch.float64) 	F-macro_val: tensor(0.4118, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.5660, dtype=torch.float64) 	F-macro_val: tensor(0.3873, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.5694, dtype=torch.float64) 	F-macro_val: tensor(0.4127, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.5764, dtype=torch.float64) 	F-macro_val: tensor(0.4260, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.5868, dtype=torch.float64) 	F-macro_val: tensor(0.4028, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.5660, dtype=torch.float64) 	F-macro_val: tensor(0.4334, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.5833, dtype=torch.float64) 	F-macro_val: tensor(0.4197, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.5764, dtype=torch.float64) 	F-macro_val: tensor(0.4135, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.5729, dtype=torch.float64) 	F-macro_val: tensor(0.4245, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.5556, dtype=torch.float64) 	F-macro_val: tensor(0.4160, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.5729, dtype=torch.float64) 	F-macro_val: tensor(0.3865, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.5417, dtype=torch.float64) 	F-macro_val: tensor(0.3993, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.5660, dtype=torch.float64) 	F-macro_val: tensor(0.3969, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.5764, dtype=torch.float64) 	F-macro_val: tensor(0.4073, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.5660, dtype=torch.float64) 	F-macro_val: tensor(0.4032, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.6007, dtype=torch.float64) 	F-macro_val: tensor(0.4246, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.5833, dtype=torch.float64) 	F-macro_val: tensor(0.4143, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.6007, dtype=torch.float64) 	F-macro_val: tensor(0.4285, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.5868, dtype=torch.float64) 	F-macro_val: tensor(0.4278, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.5764, dtype=torch.float64) 	F-macro_val: tensor(0.4125, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.5868, dtype=torch.float64) 	F-macro_val: tensor(0.4356, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.5660, dtype=torch.float64) 	F-macro_val: tensor(0.4135, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.5972, dtype=torch.float64) 	F-macro_val: tensor(0.4152, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.5694, dtype=torch.float64) 	F-macro_val: tensor(0.3911, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.5729, dtype=torch.float64) 	F-macro_val: tensor(0.4042, dtype=torch.float64)
# Testing run # 3
# SE TUVIERON QUE REPETIR 3 EJEMPLOS
# Test_ acc: 0.604309500489716
# Test_ f1 none: [0.13131313 0.11764706 0.49593496 0.73910035]
# Test_ f1 macro: 0.3709988738767539
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 4
# agregando predicciones Train
# agregando predicciones Val
# agregando predicciones Test
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.5903, dtype=torch.float64) 	F-macro_val: tensor(0.4033, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.5729, dtype=torch.float64) 	F-macro_val: tensor(0.4146, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.5451, dtype=torch.float64) 	F-macro_val: tensor(0.3900, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.5347, dtype=torch.float64) 	F-macro_val: tensor(0.3964, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.5347, dtype=torch.float64) 	F-macro_val: tensor(0.3853, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.5625, dtype=torch.float64) 	F-macro_val: tensor(0.4087, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.5208, dtype=torch.float64) 	F-macro_val: tensor(0.4094, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.5556, dtype=torch.float64) 	F-macro_val: tensor(0.3961, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.5694, dtype=torch.float64) 	F-macro_val: tensor(0.4002, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.5486, dtype=torch.float64) 	F-macro_val: tensor(0.4133, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.5278, dtype=torch.float64) 	F-macro_val: tensor(0.3925, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.5451, dtype=torch.float64) 	F-macro_val: tensor(0.4101, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.5451, dtype=torch.float64) 	F-macro_val: tensor(0.4244, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.5312, dtype=torch.float64) 	F-macro_val: tensor(0.3860, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.5590, dtype=torch.float64) 	F-macro_val: tensor(0.4081, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.5417, dtype=torch.float64) 	F-macro_val: tensor(0.4074, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.5451, dtype=torch.float64) 	F-macro_val: tensor(0.3859, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.6007, dtype=torch.float64) 	F-macro_val: tensor(0.4306, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.5556, dtype=torch.float64) 	F-macro_val: tensor(0.3882, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.5729, dtype=torch.float64) 	F-macro_val: tensor(0.4095, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.5556, dtype=torch.float64) 	F-macro_val: tensor(0.4318, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.5556, dtype=torch.float64) 	F-macro_val: tensor(0.4091, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.5660, dtype=torch.float64) 	F-macro_val: tensor(0.4133, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.5729, dtype=torch.float64) 	F-macro_val: tensor(0.3976, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.5694, dtype=torch.float64) 	F-macro_val: tensor(0.4073, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.5799, dtype=torch.float64) 	F-macro_val: tensor(0.4058, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.5799, dtype=torch.float64) 	F-macro_val: tensor(0.4009, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.5486, dtype=torch.float64) 	F-macro_val: tensor(0.3871, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.5694, dtype=torch.float64) 	F-macro_val: tensor(0.3809, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.5799, dtype=torch.float64) 	F-macro_val: tensor(0.3994, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.5764, dtype=torch.float64) 	F-macro_val: tensor(0.4188, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.5868, dtype=torch.float64) 	F-macro_val: tensor(0.4121, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.5625, dtype=torch.float64) 	F-macro_val: tensor(0.4060, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.5764, dtype=torch.float64) 	F-macro_val: tensor(0.4254, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.5625, dtype=torch.float64) 	F-macro_val: tensor(0.4009, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.5868, dtype=torch.float64) 	F-macro_val: tensor(0.4218, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.5729, dtype=torch.float64) 	F-macro_val: tensor(0.4119, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.5903, dtype=torch.float64) 	F-macro_val: tensor(0.4048, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.5799, dtype=torch.float64) 	F-macro_val: tensor(0.4032, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.5799, dtype=torch.float64) 	F-macro_val: tensor(0.4104, dtype=torch.float64)
# Testing run # 4
# SE TUVIERON QUE REPETIR 3 EJEMPLOS
# Test_ acc: 0.594515181194907
# Test_ f1 none: [0.1399177  0.05405405 0.47011952 0.7348643 ]
# Test_ f1 macro: 0.34973889301649014
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 5
# agregando predicciones Train
# agregando predicciones Val
# agregando predicciones Test
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.5799, dtype=torch.float64) 	F-macro_val: tensor(0.3304, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.6111, dtype=torch.float64) 	F-macro_val: tensor(0.4443, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.5868, dtype=torch.float64) 	F-macro_val: tensor(0.4245, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.5833, dtype=torch.float64) 	F-macro_val: tensor(0.4296, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.6042, dtype=torch.float64) 	F-macro_val: tensor(0.4127, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.5764, dtype=torch.float64) 	F-macro_val: tensor(0.4017, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.6181, dtype=torch.float64) 	F-macro_val: tensor(0.4466, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.5868, dtype=torch.float64) 	F-macro_val: tensor(0.4165, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.6076, dtype=torch.float64) 	F-macro_val: tensor(0.4197, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.6354, dtype=torch.float64) 	F-macro_val: tensor(0.4618, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.5972, dtype=torch.float64) 	F-macro_val: tensor(0.4430, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.6250, dtype=torch.float64) 	F-macro_val: tensor(0.4316, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.6042, dtype=torch.float64) 	F-macro_val: tensor(0.4330, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.6042, dtype=torch.float64) 	F-macro_val: tensor(0.4267, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.5972, dtype=torch.float64) 	F-macro_val: tensor(0.4231, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.6007, dtype=torch.float64) 	F-macro_val: tensor(0.4229, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.6076, dtype=torch.float64) 	F-macro_val: tensor(0.4264, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.6111, dtype=torch.float64) 	F-macro_val: tensor(0.4371, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.5938, dtype=torch.float64) 	F-macro_val: tensor(0.4166, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.5903, dtype=torch.float64) 	F-macro_val: tensor(0.4207, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.6111, dtype=torch.float64) 	F-macro_val: tensor(0.4562, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.5938, dtype=torch.float64) 	F-macro_val: tensor(0.4409, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.6285, dtype=torch.float64) 	F-macro_val: tensor(0.4146, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.6285, dtype=torch.float64) 	F-macro_val: tensor(0.4491, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.6111, dtype=torch.float64) 	F-macro_val: tensor(0.4300, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.6111, dtype=torch.float64) 	F-macro_val: tensor(0.4202, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.6354, dtype=torch.float64) 	F-macro_val: tensor(0.4541, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.6042, dtype=torch.float64) 	F-macro_val: tensor(0.4402, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.5833, dtype=torch.float64) 	F-macro_val: tensor(0.4099, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.6007, dtype=torch.float64) 	F-macro_val: tensor(0.4085, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.5972, dtype=torch.float64) 	F-macro_val: tensor(0.4414, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.5729, dtype=torch.float64) 	F-macro_val: tensor(0.4024, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.6042, dtype=torch.float64) 	F-macro_val: tensor(0.4598, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.6111, dtype=torch.float64) 	F-macro_val: tensor(0.4497, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.5972, dtype=torch.float64) 	F-macro_val: tensor(0.4387, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.5972, dtype=torch.float64) 	F-macro_val: tensor(0.4390, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.6042, dtype=torch.float64) 	F-macro_val: tensor(0.4419, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.5868, dtype=torch.float64) 	F-macro_val: tensor(0.4415, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.6146, dtype=torch.float64) 	F-macro_val: tensor(0.4611, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.5903, dtype=torch.float64) 	F-macro_val: tensor(0.4173, dtype=torch.float64)
# Testing run # 5
# SE TUVIERON QUE REPETIR 3 EJEMPLOS
# Test_ acc: 0.6101860920666013
# Test_ f1 none: [0.12206573 0.0617284  0.46938776 0.76002719]
# Test_ f1 macro: 0.35330226756235794
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1

# %%
print ("Acc:",np.mean(np.asarray(global_accs)))
print ("F-score:", np.mean(np.asarray(global_fmacros)))
sup=np.mean(np.asarray(global_fnones)[:,0])
den=np.mean(np.asarray(global_fnones)[:,1])
que=np.mean(np.asarray(global_fnones)[:,2])
com=np.mean(np.asarray(global_fnones)[:,3])

print ("(0.85) S-D-Q-C:", sup,den,que,com)
# Out:
# Acc: 0.6199804113614104
# F-score: 0.363668582332184
# (0.85) S-D-Q-C: 0.1311183272906252 0.08390415007016086 0.4812051577257864 0.7584466942421634

# %%
m_temp=np.zeros((4,4))
for m in global_cms:
    m_temp+=np.asarray(m)
m_temp
# Out:
# array([[  67.,   17.,   18.,  238.],
#        [  47.,   29.,   27.,  242.],
#        [  40.,   15.,  275.,  200.],
#        [ 526.,  278.,  292., 2794.]])

# %%
plot_confusion_matrix(normalize(m_temp),["S","D","Q","C"],"(0.85) GloVe Transformer Aum ", cmap='Blues')

# %%
label=[['Text', 'm1', 'm2','m3','m4','m5']]
for layer in range(2):
    fig, axs = plt.subplots(1,4, figsize=(20, 10))
    print ("Encoder Layer Attention head Promedio", layer)
    for head in range(4):
        at=np.zeros((6,6))
        matriz_attn= dict_attn_enc[str(layer)+str(head)]  #lista de 5 corridas en cada pos
        for m in matriz_attn:
            at+=m.numpy()
        sns.heatmap(at/5., xticklabels=label[0], yticklabels=label[0],
                    vmin=0.0, vmax=1.0, linewidths=.5, cmap="Purples", cbar=False, square=True, ax=axs[head]) #, annot=False,cbar_kws={"orientation": "horizontal","pad": 0.25})
    plt.show()
# Out:
# Encoder Layer Attention head Promedio 0
# Encoder Layer Attention head Promedio 1

# %%
np.save("Attn_SinAum_GloVe_AWE_85.npy", global_attn)

# %% [markdown]
# ## No aum _ sin CW

# %%
train['Tweet'][0]
# Out:
# '@julia_goo_lia @BBCWorld clarified that earlier. Cheers'

# %%
ids_train=train['Tw_id']
tws_train=train['Tweet']
labels_train=[d_lab[lb] for lb in train['Label']]
#class_weights= compute_class_weight('balanced', np.unique(labels_train), labels_train)
class_weights= [1.0, 1.0, 1.0, 1.0]
class_weights=np.asarray(class_weights)
print ("Pesos de clases:", class_weights)
#print ("Pesos de clases:", class_weights)

etiq=labels_train.copy()
etiq=np.asarray(etiq)
sentences = tws_train
n_labels = np.array(etiq)
y_train=to_categorical(n_labels,num_classes=4)


input_ids=[]
for sent in sentences:
    encoded_sent, sent_valid =my_tokenizer(cleaner(sent)[1])  
    input_ids.append(encoded_sent) 
    
input_ids = pad_sequences(input_ids,maxlen=MAX_LEN,dtype="long",value=0, truncating="post", padding="post")
shape=np.asarray(input_ids).shape
x_train=np.zeros((shape[0], shape[1], 200))
j=0
for in_id in input_ids:
    x_train[j]=M_GLOVE_space[in_id]
    j+=1
# Out:
# Pesos de clases: [1. 1. 1. 1.]

# %%
global_accs=[]
global_fnones=[]
global_fmacros=[]
global_cms=[]
global_attn=[]
dict_attn_enc={'00':[], '01':[], '02':[], '03':[], '10':[], '11':[], '12':[], '13':[]}
  
prob=0.0

for trans in range(1,6): 
    print ("Entrenando Run #", trans)
    cnn1 = load_model('../new_glove_augmented/stance_baselines/'+str(prob)+'/cnn1_'+str(trans)+'-exec.h5')
    cnn2 = load_model('../new_glove_augmented/stance_baselines/'+str(prob)+'/cnn2_'+str(trans)+'-exec.h5')
    rnn1 = load_model('../new_glove_augmented/stance_baselines/'+str(prob)+'/rnn1_'+str(trans)+'-exec.h5')
    rnn2 = load_model('../new_glove_augmented/stance_baselines/'+str(prob)+'/rnn2_'+str(trans)+'-exec.h5')
    rnn3 = load_model('../new_glove_augmented/stance_baselines/'+str(prob)+'/rnn3_'+str(trans)+'-exec.h5')

    list_models=['cnn1', 'cnn2', 'rnn1', 'rnn2', 'rnn3']
    index_models=np.arange(5)
    dict_models=dict((key, value) for (key, value) in zip(index_models,list_models))
    modelos=[cnn1, cnn2, rnn1, rnn2, rnn3]
    ind=np.arange(5)
    dict_trainedModel=dict((key, value) for (key, value) in zip(ind,modelos))

    bs=32
    predicciones_all=[]
    predicciones_all_val=[]
    predicciones_all_test=[]
    
    print ("agregando predicciones Train")
    for i in dict_trainedModel.keys(): 
        a_evaluar=dict_models[i]
        predicciones_all.append(dict_trainedModel[i].predict(x_train, batch_size=bs))
    print ("agregando predicciones Val")
    for i in dict_trainedModel.keys(): 
        a_evaluar=dict_models[i]
        predicciones_all_val.append(dict_trainedModel[i].predict(x_val, batch_size=bs))
    print ("agregando predicciones Test")
    for i in dict_trainedModel.keys(): 
        a_evaluar=dict_models[i]
        predicciones_all_test.append(dict_trainedModel[i].predict(x_test, batch_size=bs))

    matrix=np.asarray(predicciones_all)
    matrix_val=np.asarray(predicciones_all_val)
    matrix_test=np.asarray(predicciones_all_test)
    new_matrix=np.concatenate([matrix,matrix_val,matrix_test], axis=1)
    
    
    espacio=[np.ones(g_dim)]
    #Ks=np.load("../../BERTransformer/Orthogonals_768.npy")
    
    Ks= ortho_group.rvs(dim=g_dim)
    random=np.random.randint(Ks.shape[0], size=4)
    K_list=Ks[random]
    #print (K_list.shape)
    #break
    K_list_ext=espacio+list(K_list)
    index_embeddings=[0,1,2,3,4]
    lab_str_embeddings=['','','','','']

    for i in range(len(sentences)):
        ide=ids_train[i]
        tw_tr=tws_train[i]
        tokens=cleaner(tw_tr)[1]
        clase=dict_cl[labels_train[i]]
        encoded_tok, sentence_valid = my_tokenizer(tw_tr)
                
        q_glove=len(encoded_tok)
        glove_tok_f=[M_GLOVE_space[ide] for ide in encoded_tok]
        final=np.sum(glove_tok_f, axis=0)
        final_awe=final/q_glove
        norm=np.linalg.norm(final_awe)
        final_awe= final_awe / norm
        #print ("final tiene norma (AWE)", np.linalg.norm(final_awe ))        
        index_embeddings.append(i+5)
        lab_str_embeddings.append(clase)
        if len(encoded_tok)==0:
            K_list_ext.append(np.zeros(g_dim))
        else: 
            K_list_ext.append(final_awe)
    
    objs_val=val['Tw_id']      #df_val['Unnamed: 0'].values
    objs_test=test['Tw_id']    #np.arange(df_test.shape[0])
    lab_val=val['Label']
    lab_test=test['Label']
    tw_val=val['Tweet']
    tw_test=test['Tweet']
    llaves=np.concatenate([objs_val,objs_test])
    clases=np.concatenate([lab_val,lab_test])
    sent_all=np.concatenate([tw_val,tw_test])
      
    for num in range(len(llaves)):
        i=llaves[num]
        clase=clases[num]
        tw_tr=sent_all[num]
        #vector=np.load("../BaS_Original/Original/"+str(i)+".npy")
        encoded_tok, tokens_valid =my_tokenizer(cleaner(tw_tr)[1])
    
        q_glove=len(encoded_tok)
        glove_tok_f=[M_GLOVE_space[ide] for ide in encoded_tok]
        final=np.sum(glove_tok_f, axis=0)
        final_awe=final/q_glove
        norm=np.linalg.norm(final_awe)
        final_awe= final_awe / norm

        index_embeddings.append(num+5+train.shape[0])
        lab_str_embeddings.append(clase)
        K_list_ext.append(final_awe)

    K_list_new= np.asarray(K_list_ext, dtype='float32')
    
    ###################################### TRANSFORMER ###############################
    V = 4
    pesos = torch.from_numpy(class_weights).float()
    criterion = FocalLoss(weights=pesos)
    model = make_model_concat(4, N=2,d_model=g_dim, d_ff=128, h=4, dropout=0.35)
    model_opt = NoamOpt(model.src_embed[0].d_model, 1, 500, torch.optim.Adam(model.parameters(), lr=0, betas=(0.9, 0.98), eps=1e-5))

    
    for epoch in range(40):
        model.train()
        DATA=data_gen(32, 'Train', 5, new_matrix)
        loss_train, acc_train,fma_train, f_none, cm_train=run_epoch(DATA, model, SimpleLossComputeFL(criterion, model_opt), 'Train')
        
        model.eval()
        loss_val, acc_val,fma_val, f_val_none, cm_val=run_epoch(data_gen(bs, 'Val', 5, new_matrix), model, SimpleLossComputeFL(criterion, None),'Val')
        print ("Epoch",epoch, "\tacc_val:",acc_val, "\tF-macro_val:",fma_val)
    
    model.eval()
    print ("Testing run #",trans)
    predicciones = run_epoch(data_gen(bs, 'Test', 5, new_matrix), model, SimpleLossComputeFL(criterion, None),'Test')
    predicciones=np.concatenate(predicciones, axis=-1)
    
    glo_acc=accuracy_score(etiq_t, predicciones[:-3])
    glo_fno=f1_score(etiq_t,predicciones[:-3], average=None)
    glo_fma=f1_score(etiq_t,predicciones[:-3], average='macro')

    glo_cm=confusion_matrix(etiq_t, predicciones[:-3])

    plot_confusion_matrix(glo_cm,["support","Denying","Questioning","Commenting"],"GloVe Sin Aum No Cw")
    global_accs.append(glo_acc)
    global_fnones.append(glo_fno)
    global_fmacros.append(glo_fma)
    global_cms.append(glo_cm)
    print("Test_ acc:",glo_acc) 
    print("Test_ f1 none:",glo_fno) 
    print("Test_ f1 macro:",glo_fma) 

    label=[['Text', 'm1', 'm2','m3','m4','m5']]
    for layer in range(2):
        fig, axs = plt.subplots(1,4, figsize=(20, 10))
        print ("Encoder Layer Attention head", layer)
        for head in range(4):
            matriz_attn=model.encoder.layers[layer].self_attn.attn[0,head].data
            dict_attn_enc[str(layer)+str(head)].append(matriz_attn)
            sns.heatmap(matriz_attn, xticklabels=label[0], yticklabels=label[0],
                        vmin=0.0, vmax=1.0, linewidths=.5, cmap="Blues", cbar=False, square=True, ax=axs[head]) #, annot=False,cbar_kws={"orientation": "horizontal","pad": 0.25})
        plt.show()
# Out:
# Entrenando Run # 1
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:Large dropout rate: 0.65 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.65 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:Large dropout rate: 0.65 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.65 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.65 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# agregando predicciones Train
# agregando predicciones Val
# agregando predicciones Test
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.0660, dtype=torch.float64) 	F-macro_val: tensor(0.0561, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.6146, dtype=torch.float64) 	F-macro_val: tensor(0.2438, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.6319, dtype=torch.float64) 	F-macro_val: tensor(0.2670, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.6458, dtype=torch.float64) 	F-macro_val: tensor(0.2859, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.6528, dtype=torch.float64) 	F-macro_val: tensor(0.2962, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.6771, dtype=torch.float64) 	F-macro_val: tensor(0.3256, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.6632, dtype=torch.float64) 	F-macro_val: tensor(0.3044, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.6597, dtype=torch.float64) 	F-macro_val: tensor(0.3142, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.6701, dtype=torch.float64) 	F-macro_val: tensor(0.3339, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.6806, dtype=torch.float64) 	F-macro_val: tensor(0.3300, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.6632, dtype=torch.float64) 	F-macro_val: tensor(0.3258, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.6701, dtype=torch.float64) 	F-macro_val: tensor(0.3318, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.7014, dtype=torch.float64) 	F-macro_val: tensor(0.3671, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.6979, dtype=torch.float64) 	F-macro_val: tensor(0.4021, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.6840, dtype=torch.float64) 	F-macro_val: tensor(0.3836, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.6806, dtype=torch.float64) 	F-macro_val: tensor(0.3937, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.6910, dtype=torch.float64) 	F-macro_val: tensor(0.4183, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.4112, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.4190, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.4759, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.7153, dtype=torch.float64) 	F-macro_val: tensor(0.4632, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.7049, dtype=torch.float64) 	F-macro_val: tensor(0.4472, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.6840, dtype=torch.float64) 	F-macro_val: tensor(0.3891, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.6944, dtype=torch.float64) 	F-macro_val: tensor(0.4247, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.6979, dtype=torch.float64) 	F-macro_val: tensor(0.4120, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.7049, dtype=torch.float64) 	F-macro_val: tensor(0.4477, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.6979, dtype=torch.float64) 	F-macro_val: tensor(0.4160, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.6979, dtype=torch.float64) 	F-macro_val: tensor(0.4046, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.6979, dtype=torch.float64) 	F-macro_val: tensor(0.4588, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.6979, dtype=torch.float64) 	F-macro_val: tensor(0.4316, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.7083, dtype=torch.float64) 	F-macro_val: tensor(0.4533, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.6979, dtype=torch.float64) 	F-macro_val: tensor(0.4278, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.6910, dtype=torch.float64) 	F-macro_val: tensor(0.4392, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.7118, dtype=torch.float64) 	F-macro_val: tensor(0.4500, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.7014, dtype=torch.float64) 	F-macro_val: tensor(0.4209, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.7014, dtype=torch.float64) 	F-macro_val: tensor(0.4489, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.6910, dtype=torch.float64) 	F-macro_val: tensor(0.4307, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.6944, dtype=torch.float64) 	F-macro_val: tensor(0.4309, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.7014, dtype=torch.float64) 	F-macro_val: tensor(0.4401, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.7014, dtype=torch.float64) 	F-macro_val: tensor(0.4504, dtype=torch.float64)
# Testing run # 1
# SE TUVIERON QUE REPETIR 3 EJEMPLOS
# Test_ acc: 0.77179236043095
# Test_ f1 none: [0.04705882 0.         0.45859873 0.86655113]
# Test_ f1 macro: 0.34305216904013147
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 2
# agregando predicciones Train
# agregando predicciones Val
# agregando predicciones Test
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.1528, dtype=torch.float64) 	F-macro_val: tensor(0.1204, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.6111, dtype=torch.float64) 	F-macro_val: tensor(0.2035, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.6146, dtype=torch.float64) 	F-macro_val: tensor(0.1928, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.6285, dtype=torch.float64) 	F-macro_val: tensor(0.2224, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.6458, dtype=torch.float64) 	F-macro_val: tensor(0.2776, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.6667, dtype=torch.float64) 	F-macro_val: tensor(0.3266, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.6597, dtype=torch.float64) 	F-macro_val: tensor(0.3451, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.6701, dtype=torch.float64) 	F-macro_val: tensor(0.3575, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.6806, dtype=torch.float64) 	F-macro_val: tensor(0.3799, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.6701, dtype=torch.float64) 	F-macro_val: tensor(0.3250, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.6736, dtype=torch.float64) 	F-macro_val: tensor(0.3624, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.6667, dtype=torch.float64) 	F-macro_val: tensor(0.3336, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.6875, dtype=torch.float64) 	F-macro_val: tensor(0.3789, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.6910, dtype=torch.float64) 	F-macro_val: tensor(0.3703, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.6910, dtype=torch.float64) 	F-macro_val: tensor(0.4111, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.6875, dtype=torch.float64) 	F-macro_val: tensor(0.4166, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.6806, dtype=torch.float64) 	F-macro_val: tensor(0.3923, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.6875, dtype=torch.float64) 	F-macro_val: tensor(0.3991, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.6910, dtype=torch.float64) 	F-macro_val: tensor(0.3990, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.6806, dtype=torch.float64) 	F-macro_val: tensor(0.3667, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.7049, dtype=torch.float64) 	F-macro_val: tensor(0.4098, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.6875, dtype=torch.float64) 	F-macro_val: tensor(0.3698, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.6840, dtype=torch.float64) 	F-macro_val: tensor(0.3991, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.6944, dtype=torch.float64) 	F-macro_val: tensor(0.3995, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.6979, dtype=torch.float64) 	F-macro_val: tensor(0.4160, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.6979, dtype=torch.float64) 	F-macro_val: tensor(0.4032, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.7014, dtype=torch.float64) 	F-macro_val: tensor(0.4156, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.6979, dtype=torch.float64) 	F-macro_val: tensor(0.4044, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.6979, dtype=torch.float64) 	F-macro_val: tensor(0.4287, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.6910, dtype=torch.float64) 	F-macro_val: tensor(0.4239, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.6875, dtype=torch.float64) 	F-macro_val: tensor(0.3819, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.6944, dtype=torch.float64) 	F-macro_val: tensor(0.3836, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.6910, dtype=torch.float64) 	F-macro_val: tensor(0.3790, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.6944, dtype=torch.float64) 	F-macro_val: tensor(0.4142, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.6910, dtype=torch.float64) 	F-macro_val: tensor(0.4011, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.6875, dtype=torch.float64) 	F-macro_val: tensor(0.4230, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.6944, dtype=torch.float64) 	F-macro_val: tensor(0.4071, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.6979, dtype=torch.float64) 	F-macro_val: tensor(0.3866, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.6806, dtype=torch.float64) 	F-macro_val: tensor(0.3502, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.6910, dtype=torch.float64) 	F-macro_val: tensor(0.4141, dtype=torch.float64)
# Testing run # 2
# SE TUVIERON QUE REPETIR 3 EJEMPLOS
# Test_ acc: 0.7708129285014691
# Test_ f1 none: [0.07228916 0.         0.27906977 0.86996025]
# Test_ f1 macro: 0.3053297934816004
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 3
# agregando predicciones Train
# agregando predicciones Val
# agregando predicciones Test
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.5903, dtype=torch.float64) 	F-macro_val: tensor(0.2121, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.6354, dtype=torch.float64) 	F-macro_val: tensor(0.2751, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.6632, dtype=torch.float64) 	F-macro_val: tensor(0.3233, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.6597, dtype=torch.float64) 	F-macro_val: tensor(0.3559, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.6632, dtype=torch.float64) 	F-macro_val: tensor(0.3904, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.6597, dtype=torch.float64) 	F-macro_val: tensor(0.3429, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.6597, dtype=torch.float64) 	F-macro_val: tensor(0.3304, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.6667, dtype=torch.float64) 	F-macro_val: tensor(0.3459, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.6701, dtype=torch.float64) 	F-macro_val: tensor(0.3828, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.6632, dtype=torch.float64) 	F-macro_val: tensor(0.3508, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.6701, dtype=torch.float64) 	F-macro_val: tensor(0.3500, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.6597, dtype=torch.float64) 	F-macro_val: tensor(0.3761, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.6806, dtype=torch.float64) 	F-macro_val: tensor(0.3767, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.6771, dtype=torch.float64) 	F-macro_val: tensor(0.3725, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.6701, dtype=torch.float64) 	F-macro_val: tensor(0.3702, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.6875, dtype=torch.float64) 	F-macro_val: tensor(0.3997, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.6771, dtype=torch.float64) 	F-macro_val: tensor(0.3916, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.6736, dtype=torch.float64) 	F-macro_val: tensor(0.3941, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.6806, dtype=torch.float64) 	F-macro_val: tensor(0.3767, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.6806, dtype=torch.float64) 	F-macro_val: tensor(0.3834, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.6771, dtype=torch.float64) 	F-macro_val: tensor(0.3901, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.6771, dtype=torch.float64) 	F-macro_val: tensor(0.4159, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.6771, dtype=torch.float64) 	F-macro_val: tensor(0.3911, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.6806, dtype=torch.float64) 	F-macro_val: tensor(0.4523, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.6875, dtype=torch.float64) 	F-macro_val: tensor(0.4171, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.6875, dtype=torch.float64) 	F-macro_val: tensor(0.4214, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.6806, dtype=torch.float64) 	F-macro_val: tensor(0.4206, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.6806, dtype=torch.float64) 	F-macro_val: tensor(0.4230, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.6806, dtype=torch.float64) 	F-macro_val: tensor(0.4029, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.6736, dtype=torch.float64) 	F-macro_val: tensor(0.4044, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.6736, dtype=torch.float64) 	F-macro_val: tensor(0.4090, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.6806, dtype=torch.float64) 	F-macro_val: tensor(0.4138, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.6840, dtype=torch.float64) 	F-macro_val: tensor(0.4141, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.6771, dtype=torch.float64) 	F-macro_val: tensor(0.4154, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.6840, dtype=torch.float64) 	F-macro_val: tensor(0.3869, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.6840, dtype=torch.float64) 	F-macro_val: tensor(0.4074, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.6875, dtype=torch.float64) 	F-macro_val: tensor(0.4266, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.6806, dtype=torch.float64) 	F-macro_val: tensor(0.3894, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.6806, dtype=torch.float64) 	F-macro_val: tensor(0.4152, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.6771, dtype=torch.float64) 	F-macro_val: tensor(0.3967, dtype=torch.float64)
# Testing run # 3
# SE TUVIERON QUE REPETIR 3 EJEMPLOS
# Test_ acc: 0.7698334965719883
# Test_ f1 none: [0.075      0.         0.29850746 0.86753837]
# Test_ f1 macro: 0.3102614591906867
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 4
# agregando predicciones Train
# agregando predicciones Val
# agregando predicciones Test
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.6250, dtype=torch.float64) 	F-macro_val: tensor(0.2080, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.6354, dtype=torch.float64) 	F-macro_val: tensor(0.2337, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.6632, dtype=torch.float64) 	F-macro_val: tensor(0.3136, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.6528, dtype=torch.float64) 	F-macro_val: tensor(0.3195, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.6667, dtype=torch.float64) 	F-macro_val: tensor(0.3485, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.6632, dtype=torch.float64) 	F-macro_val: tensor(0.3203, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.6667, dtype=torch.float64) 	F-macro_val: tensor(0.3342, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.6771, dtype=torch.float64) 	F-macro_val: tensor(0.3659, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.6875, dtype=torch.float64) 	F-macro_val: tensor(0.3588, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.6944, dtype=torch.float64) 	F-macro_val: tensor(0.4128, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.6979, dtype=torch.float64) 	F-macro_val: tensor(0.4033, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.6875, dtype=torch.float64) 	F-macro_val: tensor(0.3954, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.6944, dtype=torch.float64) 	F-macro_val: tensor(0.4095, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.6875, dtype=torch.float64) 	F-macro_val: tensor(0.3780, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.6910, dtype=torch.float64) 	F-macro_val: tensor(0.3991, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.6944, dtype=torch.float64) 	F-macro_val: tensor(0.3742, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.6910, dtype=torch.float64) 	F-macro_val: tensor(0.3684, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.6910, dtype=torch.float64) 	F-macro_val: tensor(0.3757, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.6910, dtype=torch.float64) 	F-macro_val: tensor(0.4001, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.6910, dtype=torch.float64) 	F-macro_val: tensor(0.3739, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.6910, dtype=torch.float64) 	F-macro_val: tensor(0.3808, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.6944, dtype=torch.float64) 	F-macro_val: tensor(0.3952, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.6944, dtype=torch.float64) 	F-macro_val: tensor(0.4049, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.6910, dtype=torch.float64) 	F-macro_val: tensor(0.3783, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.6875, dtype=torch.float64) 	F-macro_val: tensor(0.3911, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.6944, dtype=torch.float64) 	F-macro_val: tensor(0.4078, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.6875, dtype=torch.float64) 	F-macro_val: tensor(0.3826, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.6910, dtype=torch.float64) 	F-macro_val: tensor(0.3935, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.6944, dtype=torch.float64) 	F-macro_val: tensor(0.3731, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.6840, dtype=torch.float64) 	F-macro_val: tensor(0.3962, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.6944, dtype=torch.float64) 	F-macro_val: tensor(0.3856, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.6875, dtype=torch.float64) 	F-macro_val: tensor(0.3942, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.6910, dtype=torch.float64) 	F-macro_val: tensor(0.3953, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.6875, dtype=torch.float64) 	F-macro_val: tensor(0.3769, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.6979, dtype=torch.float64) 	F-macro_val: tensor(0.3881, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.6875, dtype=torch.float64) 	F-macro_val: tensor(0.3779, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.6875, dtype=torch.float64) 	F-macro_val: tensor(0.4004, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.6840, dtype=torch.float64) 	F-macro_val: tensor(0.4131, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.6840, dtype=torch.float64) 	F-macro_val: tensor(0.4066, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.6944, dtype=torch.float64) 	F-macro_val: tensor(0.4086, dtype=torch.float64)
# Testing run # 4
# SE TUVIERON QUE REPETIR 3 EJEMPLOS
# Test_ acc: 0.7727717923604309
# Test_ f1 none: [0.05128205 0.         0.3030303  0.87010777]
# Test_ f1 macro: 0.30610503128937616
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 5
# agregando predicciones Train
# agregando predicciones Val
# agregando predicciones Test
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.5347, dtype=torch.float64) 	F-macro_val: tensor(0.2455, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.6146, dtype=torch.float64) 	F-macro_val: tensor(0.1962, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.6111, dtype=torch.float64) 	F-macro_val: tensor(0.1887, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.6389, dtype=torch.float64) 	F-macro_val: tensor(0.2664, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.6354, dtype=torch.float64) 	F-macro_val: tensor(0.2889, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.6528, dtype=torch.float64) 	F-macro_val: tensor(0.2974, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.6632, dtype=torch.float64) 	F-macro_val: tensor(0.3180, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.6701, dtype=torch.float64) 	F-macro_val: tensor(0.3220, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.6701, dtype=torch.float64) 	F-macro_val: tensor(0.3407, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.6910, dtype=torch.float64) 	F-macro_val: tensor(0.3849, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.6736, dtype=torch.float64) 	F-macro_val: tensor(0.3898, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.6806, dtype=torch.float64) 	F-macro_val: tensor(0.4105, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.6875, dtype=torch.float64) 	F-macro_val: tensor(0.4135, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.6840, dtype=torch.float64) 	F-macro_val: tensor(0.3909, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.6840, dtype=torch.float64) 	F-macro_val: tensor(0.3995, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.6840, dtype=torch.float64) 	F-macro_val: tensor(0.3964, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.6840, dtype=torch.float64) 	F-macro_val: tensor(0.4066, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.6840, dtype=torch.float64) 	F-macro_val: tensor(0.4167, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.6944, dtype=torch.float64) 	F-macro_val: tensor(0.4485, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.6910, dtype=torch.float64) 	F-macro_val: tensor(0.4198, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.6910, dtype=torch.float64) 	F-macro_val: tensor(0.4066, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.6875, dtype=torch.float64) 	F-macro_val: tensor(0.4236, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.6771, dtype=torch.float64) 	F-macro_val: tensor(0.4324, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.6910, dtype=torch.float64) 	F-macro_val: tensor(0.4345, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.6840, dtype=torch.float64) 	F-macro_val: tensor(0.4046, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.6840, dtype=torch.float64) 	F-macro_val: tensor(0.4134, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.6840, dtype=torch.float64) 	F-macro_val: tensor(0.4214, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.6944, dtype=torch.float64) 	F-macro_val: tensor(0.4297, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.6944, dtype=torch.float64) 	F-macro_val: tensor(0.4428, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.6944, dtype=torch.float64) 	F-macro_val: tensor(0.3949, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.6979, dtype=torch.float64) 	F-macro_val: tensor(0.4321, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.6875, dtype=torch.float64) 	F-macro_val: tensor(0.4161, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.6806, dtype=torch.float64) 	F-macro_val: tensor(0.3948, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.6910, dtype=torch.float64) 	F-macro_val: tensor(0.4217, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.6806, dtype=torch.float64) 	F-macro_val: tensor(0.4473, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.6806, dtype=torch.float64) 	F-macro_val: tensor(0.4037, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.6771, dtype=torch.float64) 	F-macro_val: tensor(0.4011, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.6910, dtype=torch.float64) 	F-macro_val: tensor(0.4275, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.6806, dtype=torch.float64) 	F-macro_val: tensor(0.4385, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.6910, dtype=torch.float64) 	F-macro_val: tensor(0.4372, dtype=torch.float64)
# Testing run # 5
# SE TUVIERON QUE REPETIR 3 EJEMPLOS
# Test_ acc: 0.7649363369245837
# Test_ f1 none: [0.0990099  0.         0.40540541 0.86542923]
# Test_ f1 macro: 0.34246113518356286
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1

# %%
print ("Acc:",np.mean(np.asarray(global_accs)))
print ("F-score:", np.mean(np.asarray(global_fmacros)))
sup=np.mean(np.asarray(global_fnones)[:,0])
den=np.mean(np.asarray(global_fnones)[:,1])
que=np.mean(np.asarray(global_fnones)[:,2])
com=np.mean(np.asarray(global_fnones)[:,3])

print ("(0.0_No CW) S-D-Q-C:", sup,den,que,com)
# Out:
# Acc: 0.7700293829578845
# F-score: 0.32144191763707153
# (0.0_No CW) S-D-Q-C: 0.06892798648561363 0.0 0.34892233293575714 0.8679173511269154

# %%
m_temp=np.zeros((4,4))
for m in global_cms:
    m_temp+=np.asarray(m)
m_temp
# Out:
# array([[1.500e+01, 0.000e+00, 2.000e+00, 3.230e+02],
#        [2.000e+00, 0.000e+00, 6.000e+00, 3.370e+02],
#        [1.000e+01, 0.000e+00, 1.240e+02, 3.960e+02],
#        [6.000e+01, 0.000e+00, 3.800e+01, 3.792e+03]])

# %%
plot_confusion_matrix(normalize(m_temp),["S","D","Q","C"],"(0.0 No CW) GloVe Transformer", cmap='Blues')

# %%
label=[['Text', 'm1', 'm2','m3','m4','m5']]
for layer in range(2):
    fig, axs = plt.subplots(1,4, figsize=(20, 10))
    print ("Encoder Layer Attention head Promedio", layer)
    for head in range(4):
        at=np.zeros((6,6))
        matriz_attn= dict_attn_enc[str(layer)+str(head)]  #lista de 5 corridas en cada pos
        for m in matriz_attn:
            at+=m.numpy()
        sns.heatmap(at/5., xticklabels=label[0], yticklabels=label[0],
                    vmin=0.0, vmax=1.0, linewidths=.5, cmap="Purples", cbar=False, square=True, ax=axs[head]) #, annot=False,cbar_kws={"orientation": "horizontal","pad": 0.25})
    plt.show()
# Out:
# Encoder Layer Attention head Promedio 0
# Encoder Layer Attention head Promedio 1

# %%
np.save("Attn_SinAum_GloVe_NoCW.npy", global_attn)

# %% [markdown]
# ### 0.0 Use CW

# %%
class_weights= compute_class_weight('balanced', np.unique(labels_train), labels_train)
print ("Pesos de clases:", class_weights)
# Out:
# Pesos de clases: [1.25980975 3.18168168 3.21060606 0.38752743]

# %%
global_accs=[]
global_fnones=[]
global_fmacros=[]
global_cms=[]
global_attn=[]
dict_attn_enc={'00':[], '01':[], '02':[], '03':[], '10':[], '11':[], '12':[], '13':[]}
  
prob=0.0

for trans in range(1,6): 
    print ("Entrenando Run #", trans)
    cnn1 = load_model('../new_glove_augmented/stance_baselines/'+str(prob)+'_cw/cnn1_'+str(trans)+'-exec.h5')
    cnn2 = load_model('../new_glove_augmented/stance_baselines/'+str(prob)+'_cw/cnn2_'+str(trans)+'-exec.h5')
    rnn1 = load_model('../new_glove_augmented/stance_baselines/'+str(prob)+'_cw/rnn1_'+str(trans)+'-exec.h5')
    rnn2 = load_model('../new_glove_augmented/stance_baselines/'+str(prob)+'_cw/rnn2_'+str(trans)+'-exec.h5')
    rnn3 = load_model('../new_glove_augmented/stance_baselines/'+str(prob)+'_cw/rnn3_'+str(trans)+'-exec.h5')

    list_models=['cnn1', 'cnn2', 'rnn1', 'rnn2', 'rnn3']
    index_models=np.arange(5)
    dict_models=dict((key, value) for (key, value) in zip(index_models,list_models))
    modelos=[cnn1, cnn2, rnn1, rnn2, rnn3]
    ind=np.arange(5)
    dict_trainedModel=dict((key, value) for (key, value) in zip(ind,modelos))

    bs=32
    predicciones_all=[]
    predicciones_all_val=[]
    predicciones_all_test=[]
    
    print ("agregando predicciones Train")
    for i in dict_trainedModel.keys(): 
        a_evaluar=dict_models[i]
        predicciones_all.append(dict_trainedModel[i].predict(x_train, batch_size=bs))
    print ("agregando predicciones Val")
    for i in dict_trainedModel.keys(): 
        a_evaluar=dict_models[i]
        predicciones_all_val.append(dict_trainedModel[i].predict(x_val, batch_size=bs))
    print ("agregando predicciones Test")
    for i in dict_trainedModel.keys(): 
        a_evaluar=dict_models[i]
        predicciones_all_test.append(dict_trainedModel[i].predict(x_test, batch_size=bs))

    matrix=np.asarray(predicciones_all)
    matrix_val=np.asarray(predicciones_all_val)
    matrix_test=np.asarray(predicciones_all_test)
    new_matrix=np.concatenate([matrix,matrix_val,matrix_test], axis=1)
    
    
    espacio=[np.ones(g_dim)]
    #Ks=np.load("../../BERTransformer/Orthogonals_768.npy")
    
    Ks= ortho_group.rvs(dim=g_dim)
    random=np.random.randint(Ks.shape[0], size=4)
    K_list=Ks[random]
    #print (K_list.shape)
    #break
    K_list_ext=espacio+list(K_list)
    index_embeddings=[0,1,2,3,4]
    lab_str_embeddings=['','','','','']

    for i in range(len(sentences)):
        ide=ids_train[i]
        tw_tr=tws_train[i]
        tokens=cleaner(tw_tr)[1]
        clase=dict_cl[labels_train[i]]
        encoded_tok, sentence_valid = my_tokenizer(tw_tr)
                
        q_glove=len(encoded_tok)
        glove_tok_f=[M_GLOVE_space[ide] for ide in encoded_tok]
        final=np.sum(glove_tok_f, axis=0)
        final_awe=final/q_glove
        norm=np.linalg.norm(final_awe)
        final_awe= final_awe / norm
        #print ("final tiene norma (AWE)", np.linalg.norm(final_awe ))        
        index_embeddings.append(i+5)
        lab_str_embeddings.append(clase)
        if len(encoded_tok)==0:
            K_list_ext.append(np.zeros(g_dim))
        else: 
            K_list_ext.append(final_awe)
    
    objs_val=val['Tw_id']      #df_val['Unnamed: 0'].values
    objs_test=test['Tw_id']    #np.arange(df_test.shape[0])
    lab_val=val['Label']
    lab_test=test['Label']
    tw_val=val['Tweet']
    tw_test=test['Tweet']
    llaves=np.concatenate([objs_val,objs_test])
    clases=np.concatenate([lab_val,lab_test])
    sent_all=np.concatenate([tw_val,tw_test])
      
    for num in range(len(llaves)):
        i=llaves[num]
        clase=clases[num]
        tw_tr=sent_all[num]
        #vector=np.load("../BaS_Original/Original/"+str(i)+".npy")
        encoded_tok, tokens_valid =my_tokenizer(cleaner(tw_tr)[1])
    
        q_glove=len(encoded_tok)
        glove_tok_f=[M_GLOVE_space[ide] for ide in encoded_tok]
        final=np.sum(glove_tok_f, axis=0)
        final_awe=final/q_glove
        norm=np.linalg.norm(final_awe)
        final_awe= final_awe / norm

        index_embeddings.append(num+5+train.shape[0])
        lab_str_embeddings.append(clase)
        K_list_ext.append(final_awe)

    K_list_new= np.asarray(K_list_ext, dtype='float32')
    
    ###################################### TRANSFORMER ###############################
    V = 4
    pesos = torch.from_numpy(class_weights).float()
    criterion = FocalLoss(weights=pesos)
    model = make_model_concat(4, N=2,d_model=g_dim, d_ff=128, h=4, dropout=0.35)
    model_opt = NoamOpt(model.src_embed[0].d_model, 1, 500, torch.optim.Adam(model.parameters(), lr=0, betas=(0.9, 0.98), eps=1e-5))

    
    for epoch in range(40):
        model.train()
        DATA=data_gen(32, 'Train', 5, new_matrix)
        loss_train, acc_train,fma_train, f_none, cm_train=run_epoch(DATA, model, SimpleLossComputeFL(criterion, model_opt), 'Train')
        
        model.eval()
        loss_val, acc_val,fma_val, f_val_none, cm_val=run_epoch(data_gen(bs, 'Val', 5, new_matrix), model, SimpleLossComputeFL(criterion, None),'Val')
        print ("Epoch",epoch, "\tacc_val:",acc_val, "\tF-macro_val:",fma_val)
    
    model.eval()
    print ("Testing run #",trans)
    predicciones = run_epoch(data_gen(bs, 'Test', 5, new_matrix), model, SimpleLossComputeFL(criterion, None),'Test')
    predicciones=np.concatenate(predicciones, axis=-1)
    
    glo_acc=accuracy_score(etiq_t, predicciones[:-3])
    glo_fno=f1_score(etiq_t,predicciones[:-3], average=None)
    glo_fma=f1_score(etiq_t,predicciones[:-3], average='macro')

    glo_cm=confusion_matrix(etiq_t, predicciones[:-3])

    plot_confusion_matrix(glo_cm,["support","Denying","Questioning","Commenting"],"GloVe Sin Aum No Cw")
    global_accs.append(glo_acc)
    global_fnones.append(glo_fno)
    global_fmacros.append(glo_fma)
    global_cms.append(glo_cm)
    print("Test_ acc:",glo_acc) 
    print("Test_ f1 none:",glo_fno) 
    print("Test_ f1 macro:",glo_fma) 

    label=[['Text', 'm1', 'm2','m3','m4','m5']]
    for layer in range(2):
        fig, axs = plt.subplots(1,4, figsize=(20, 10))
        print ("Encoder Layer Attention head", layer)
        for head in range(4):
            matriz_attn=model.encoder.layers[layer].self_attn.attn[0,head].data
            dict_attn_enc[str(layer)+str(head)].append(matriz_attn)
            sns.heatmap(matriz_attn, xticklabels=label[0], yticklabels=label[0],
                        vmin=0.0, vmax=1.0, linewidths=.5, cmap="Blues", cbar=False, square=True, ax=axs[head]) #, annot=False,cbar_kws={"orientation": "horizontal","pad": 0.25})
        plt.show()
# Out:
# Entrenando Run # 1
# agregando predicciones Train
# agregando predicciones Val
# agregando predicciones Test
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.1771, dtype=torch.float64) 	F-macro_val: tensor(0.2519, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.2049, dtype=torch.float64) 	F-macro_val: tensor(0.2617, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.2153, dtype=torch.float64) 	F-macro_val: tensor(0.2621, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.2257, dtype=torch.float64) 	F-macro_val: tensor(0.2470, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.2361, dtype=torch.float64) 	F-macro_val: tensor(0.2400, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.2465, dtype=torch.float64) 	F-macro_val: tensor(0.2516, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.2431, dtype=torch.float64) 	F-macro_val: tensor(0.2554, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.2361, dtype=torch.float64) 	F-macro_val: tensor(0.2528, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.2361, dtype=torch.float64) 	F-macro_val: tensor(0.2559, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.2535, dtype=torch.float64) 	F-macro_val: tensor(0.2697, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.2396, dtype=torch.float64) 	F-macro_val: tensor(0.2536, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.2361, dtype=torch.float64) 	F-macro_val: tensor(0.2524, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.2326, dtype=torch.float64) 	F-macro_val: tensor(0.2564, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.2326, dtype=torch.float64) 	F-macro_val: tensor(0.2496, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.2361, dtype=torch.float64) 	F-macro_val: tensor(0.2722, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.2361, dtype=torch.float64) 	F-macro_val: tensor(0.2687, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.2326, dtype=torch.float64) 	F-macro_val: tensor(0.2540, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.2361, dtype=torch.float64) 	F-macro_val: tensor(0.2539, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.2326, dtype=torch.float64) 	F-macro_val: tensor(0.2507, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.2396, dtype=torch.float64) 	F-macro_val: tensor(0.2709, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.2326, dtype=torch.float64) 	F-macro_val: tensor(0.2483, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.2326, dtype=torch.float64) 	F-macro_val: tensor(0.2478, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.2326, dtype=torch.float64) 	F-macro_val: tensor(0.2648, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.2361, dtype=torch.float64) 	F-macro_val: tensor(0.2507, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.2361, dtype=torch.float64) 	F-macro_val: tensor(0.2616, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.2292, dtype=torch.float64) 	F-macro_val: tensor(0.2572, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.2396, dtype=torch.float64) 	F-macro_val: tensor(0.2634, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.2465, dtype=torch.float64) 	F-macro_val: tensor(0.2741, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.2431, dtype=torch.float64) 	F-macro_val: tensor(0.2531, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.2326, dtype=torch.float64) 	F-macro_val: tensor(0.2598, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.2396, dtype=torch.float64) 	F-macro_val: tensor(0.2834, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.2361, dtype=torch.float64) 	F-macro_val: tensor(0.2561, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.2396, dtype=torch.float64) 	F-macro_val: tensor(0.2702, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.2396, dtype=torch.float64) 	F-macro_val: tensor(0.2765, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.2465, dtype=torch.float64) 	F-macro_val: tensor(0.2552, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.2361, dtype=torch.float64) 	F-macro_val: tensor(0.2689, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.2396, dtype=torch.float64) 	F-macro_val: tensor(0.2698, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.2431, dtype=torch.float64) 	F-macro_val: tensor(0.2805, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.2431, dtype=torch.float64) 	F-macro_val: tensor(0.2679, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.2500, dtype=torch.float64) 	F-macro_val: tensor(0.2785, dtype=torch.float64)
# Testing run # 1
# SE TUVIERON QUE REPETIR 3 EJEMPLOS
# Test_ acc: 0.14887365328109697
# Test_ f1 none: [0.14330218 0.15740741 0.52881356 0.        ]
# Test_ f1 macro: 0.20738078685369987
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 2
# agregando predicciones Train
# agregando predicciones Val
# agregando predicciones Test
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.1806, dtype=torch.float64) 	F-macro_val: tensor(0.1615, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.2188, dtype=torch.float64) 	F-macro_val: tensor(0.1818, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.2569, dtype=torch.float64) 	F-macro_val: tensor(0.2714, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.2500, dtype=torch.float64) 	F-macro_val: tensor(0.2814, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.2431, dtype=torch.float64) 	F-macro_val: tensor(0.2711, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.2500, dtype=torch.float64) 	F-macro_val: tensor(0.2479, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.2465, dtype=torch.float64) 	F-macro_val: tensor(0.2533, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.2639, dtype=torch.float64) 	F-macro_val: tensor(0.2446, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.2674, dtype=torch.float64) 	F-macro_val: tensor(0.2551, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.2708, dtype=torch.float64) 	F-macro_val: tensor(0.2806, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.2708, dtype=torch.float64) 	F-macro_val: tensor(0.2860, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.2743, dtype=torch.float64) 	F-macro_val: tensor(0.2622, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.2882, dtype=torch.float64) 	F-macro_val: tensor(0.2748, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.2812, dtype=torch.float64) 	F-macro_val: tensor(0.2599, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.2743, dtype=torch.float64) 	F-macro_val: tensor(0.2851, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.2917, dtype=torch.float64) 	F-macro_val: tensor(0.2898, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.2847, dtype=torch.float64) 	F-macro_val: tensor(0.2782, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.2812, dtype=torch.float64) 	F-macro_val: tensor(0.2700, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.2812, dtype=torch.float64) 	F-macro_val: tensor(0.2824, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.2986, dtype=torch.float64) 	F-macro_val: tensor(0.2957, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.2847, dtype=torch.float64) 	F-macro_val: tensor(0.2926, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.3021, dtype=torch.float64) 	F-macro_val: tensor(0.2986, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.3021, dtype=torch.float64) 	F-macro_val: tensor(0.3148, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.2812, dtype=torch.float64) 	F-macro_val: tensor(0.3100, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.2882, dtype=torch.float64) 	F-macro_val: tensor(0.2985, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.2778, dtype=torch.float64) 	F-macro_val: tensor(0.2950, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.2812, dtype=torch.float64) 	F-macro_val: tensor(0.2934, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.2847, dtype=torch.float64) 	F-macro_val: tensor(0.2944, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.2951, dtype=torch.float64) 	F-macro_val: tensor(0.3118, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.2812, dtype=torch.float64) 	F-macro_val: tensor(0.3007, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.2882, dtype=torch.float64) 	F-macro_val: tensor(0.3036, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.2917, dtype=torch.float64) 	F-macro_val: tensor(0.3067, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.2986, dtype=torch.float64) 	F-macro_val: tensor(0.3171, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.2917, dtype=torch.float64) 	F-macro_val: tensor(0.3106, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.3090, dtype=torch.float64) 	F-macro_val: tensor(0.3172, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.2986, dtype=torch.float64) 	F-macro_val: tensor(0.3193, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.2778, dtype=torch.float64) 	F-macro_val: tensor(0.2967, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.2847, dtype=torch.float64) 	F-macro_val: tensor(0.2944, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.2917, dtype=torch.float64) 	F-macro_val: tensor(0.3172, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.2986, dtype=torch.float64) 	F-macro_val: tensor(0.2998, dtype=torch.float64)
# Testing run # 2
# SE TUVIERON QUE REPETIR 3 EJEMPLOS
# Test_ acc: 0.12340842311459353
# Test_ f1 none: [0.13059701 0.144      0.48245614 0.        ]
# Test_ f1 macro: 0.1892632888190626
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 3
# agregando predicciones Train
# agregando predicciones Val
# agregando predicciones Test
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.2222, dtype=torch.float64) 	F-macro_val: tensor(0.1711, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.2917, dtype=torch.float64) 	F-macro_val: tensor(0.2142, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.3160, dtype=torch.float64) 	F-macro_val: tensor(0.2700, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.2986, dtype=torch.float64) 	F-macro_val: tensor(0.2580, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.3056, dtype=torch.float64) 	F-macro_val: tensor(0.2726, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.2639, dtype=torch.float64) 	F-macro_val: tensor(0.2771, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.2917, dtype=torch.float64) 	F-macro_val: tensor(0.2830, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.2882, dtype=torch.float64) 	F-macro_val: tensor(0.2440, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.2882, dtype=torch.float64) 	F-macro_val: tensor(0.2670, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.2708, dtype=torch.float64) 	F-macro_val: tensor(0.2633, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.2847, dtype=torch.float64) 	F-macro_val: tensor(0.2810, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.2882, dtype=torch.float64) 	F-macro_val: tensor(0.2743, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.2743, dtype=torch.float64) 	F-macro_val: tensor(0.2912, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.2743, dtype=torch.float64) 	F-macro_val: tensor(0.2638, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.2674, dtype=torch.float64) 	F-macro_val: tensor(0.3044, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.2535, dtype=torch.float64) 	F-macro_val: tensor(0.3045, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.2639, dtype=torch.float64) 	F-macro_val: tensor(0.2943, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.2535, dtype=torch.float64) 	F-macro_val: tensor(0.3025, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.2535, dtype=torch.float64) 	F-macro_val: tensor(0.3002, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.2882, dtype=torch.float64) 	F-macro_val: tensor(0.2982, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.2639, dtype=torch.float64) 	F-macro_val: tensor(0.2908, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.2569, dtype=torch.float64) 	F-macro_val: tensor(0.2978, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.2465, dtype=torch.float64) 	F-macro_val: tensor(0.3067, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.2465, dtype=torch.float64) 	F-macro_val: tensor(0.2999, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.2431, dtype=torch.float64) 	F-macro_val: tensor(0.2912, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.2396, dtype=torch.float64) 	F-macro_val: tensor(0.2855, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.2569, dtype=torch.float64) 	F-macro_val: tensor(0.2980, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.2778, dtype=torch.float64) 	F-macro_val: tensor(0.3010, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.2431, dtype=torch.float64) 	F-macro_val: tensor(0.2887, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.2674, dtype=torch.float64) 	F-macro_val: tensor(0.3008, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.2535, dtype=torch.float64) 	F-macro_val: tensor(0.2941, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.2465, dtype=torch.float64) 	F-macro_val: tensor(0.3035, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.2465, dtype=torch.float64) 	F-macro_val: tensor(0.2928, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.2535, dtype=torch.float64) 	F-macro_val: tensor(0.3004, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.2500, dtype=torch.float64) 	F-macro_val: tensor(0.3035, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.2535, dtype=torch.float64) 	F-macro_val: tensor(0.2656, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.2639, dtype=torch.float64) 	F-macro_val: tensor(0.2973, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.2604, dtype=torch.float64) 	F-macro_val: tensor(0.2921, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.2812, dtype=torch.float64) 	F-macro_val: tensor(0.2726, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.2743, dtype=torch.float64) 	F-macro_val: tensor(0.2756, dtype=torch.float64)
# Testing run # 3
# SE TUVIERON QUE REPETIR 3 EJEMPLOS
# Test_ acc: 0.13418217433888344
# Test_ f1 none: [0.15352697 0.11394892 0.52014652 0.        ]
# Test_ f1 macro: 0.19690560263769466
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 4
# agregando predicciones Train
# agregando predicciones Val
# agregando predicciones Test
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.2049, dtype=torch.float64) 	F-macro_val: tensor(0.1870, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.2604, dtype=torch.float64) 	F-macro_val: tensor(0.1779, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.2847, dtype=torch.float64) 	F-macro_val: tensor(0.2064, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.2917, dtype=torch.float64) 	F-macro_val: tensor(0.2582, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.2535, dtype=torch.float64) 	F-macro_val: tensor(0.2954, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.2535, dtype=torch.float64) 	F-macro_val: tensor(0.2707, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.2500, dtype=torch.float64) 	F-macro_val: tensor(0.2993, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.2431, dtype=torch.float64) 	F-macro_val: tensor(0.2845, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.2465, dtype=torch.float64) 	F-macro_val: tensor(0.2924, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.2639, dtype=torch.float64) 	F-macro_val: tensor(0.3163, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.2500, dtype=torch.float64) 	F-macro_val: tensor(0.3140, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.2500, dtype=torch.float64) 	F-macro_val: tensor(0.2934, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.2569, dtype=torch.float64) 	F-macro_val: tensor(0.3030, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.2535, dtype=torch.float64) 	F-macro_val: tensor(0.3136, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.2500, dtype=torch.float64) 	F-macro_val: tensor(0.2895, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.2674, dtype=torch.float64) 	F-macro_val: tensor(0.3052, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.2535, dtype=torch.float64) 	F-macro_val: tensor(0.3056, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.2639, dtype=torch.float64) 	F-macro_val: tensor(0.3184, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.2604, dtype=torch.float64) 	F-macro_val: tensor(0.3095, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.2500, dtype=torch.float64) 	F-macro_val: tensor(0.2854, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.2604, dtype=torch.float64) 	F-macro_val: tensor(0.2960, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.2674, dtype=torch.float64) 	F-macro_val: tensor(0.2999, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.2674, dtype=torch.float64) 	F-macro_val: tensor(0.2937, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.2639, dtype=torch.float64) 	F-macro_val: tensor(0.2808, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.2569, dtype=torch.float64) 	F-macro_val: tensor(0.2777, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.2708, dtype=torch.float64) 	F-macro_val: tensor(0.2792, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.2743, dtype=torch.float64) 	F-macro_val: tensor(0.2869, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.2674, dtype=torch.float64) 	F-macro_val: tensor(0.2858, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.2569, dtype=torch.float64) 	F-macro_val: tensor(0.2990, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.2535, dtype=torch.float64) 	F-macro_val: tensor(0.3073, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.2465, dtype=torch.float64) 	F-macro_val: tensor(0.2986, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.2535, dtype=torch.float64) 	F-macro_val: tensor(0.3035, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.2569, dtype=torch.float64) 	F-macro_val: tensor(0.3025, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.2500, dtype=torch.float64) 	F-macro_val: tensor(0.2988, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.2465, dtype=torch.float64) 	F-macro_val: tensor(0.3041, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.2500, dtype=torch.float64) 	F-macro_val: tensor(0.2719, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.2569, dtype=torch.float64) 	F-macro_val: tensor(0.2959, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.2639, dtype=torch.float64) 	F-macro_val: tensor(0.2842, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.2639, dtype=torch.float64) 	F-macro_val: tensor(0.3048, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.2674, dtype=torch.float64) 	F-macro_val: tensor(0.2874, dtype=torch.float64)
# Testing run # 4
# SE TUVIERON QUE REPETIR 3 EJEMPLOS
# Test_ acc: 0.14593535749265427
# Test_ f1 none: [0.17921147 0.14945652 0.53658537 0.00768246]
# Test_ f1 macro: 0.21823395387838074
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 5
# agregando predicciones Train
# agregando predicciones Val
# agregando predicciones Test
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.2778, dtype=torch.float64) 	F-macro_val: tensor(0.2464, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.2326, dtype=torch.float64) 	F-macro_val: tensor(0.2211, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.2882, dtype=torch.float64) 	F-macro_val: tensor(0.2632, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.2951, dtype=torch.float64) 	F-macro_val: tensor(0.2464, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.2708, dtype=torch.float64) 	F-macro_val: tensor(0.2514, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.2812, dtype=torch.float64) 	F-macro_val: tensor(0.2503, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.2708, dtype=torch.float64) 	F-macro_val: tensor(0.2447, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.2847, dtype=torch.float64) 	F-macro_val: tensor(0.2627, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.2778, dtype=torch.float64) 	F-macro_val: tensor(0.2478, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.2778, dtype=torch.float64) 	F-macro_val: tensor(0.2598, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.2743, dtype=torch.float64) 	F-macro_val: tensor(0.2578, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.2743, dtype=torch.float64) 	F-macro_val: tensor(0.2673, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.2743, dtype=torch.float64) 	F-macro_val: tensor(0.2442, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.2917, dtype=torch.float64) 	F-macro_val: tensor(0.2676, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.2812, dtype=torch.float64) 	F-macro_val: tensor(0.2523, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.2882, dtype=torch.float64) 	F-macro_val: tensor(0.2684, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.2847, dtype=torch.float64) 	F-macro_val: tensor(0.2828, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.2917, dtype=torch.float64) 	F-macro_val: tensor(0.2752, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.2708, dtype=torch.float64) 	F-macro_val: tensor(0.2608, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.2847, dtype=torch.float64) 	F-macro_val: tensor(0.2546, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.2674, dtype=torch.float64) 	F-macro_val: tensor(0.2508, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.2812, dtype=torch.float64) 	F-macro_val: tensor(0.2723, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.2917, dtype=torch.float64) 	F-macro_val: tensor(0.2717, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.2917, dtype=torch.float64) 	F-macro_val: tensor(0.2776, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.2812, dtype=torch.float64) 	F-macro_val: tensor(0.2657, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.2882, dtype=torch.float64) 	F-macro_val: tensor(0.2779, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.2847, dtype=torch.float64) 	F-macro_val: tensor(0.2758, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.2847, dtype=torch.float64) 	F-macro_val: tensor(0.2726, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.2847, dtype=torch.float64) 	F-macro_val: tensor(0.2741, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.2847, dtype=torch.float64) 	F-macro_val: tensor(0.2626, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.2917, dtype=torch.float64) 	F-macro_val: tensor(0.2799, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.2882, dtype=torch.float64) 	F-macro_val: tensor(0.2676, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.2812, dtype=torch.float64) 	F-macro_val: tensor(0.2835, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.2778, dtype=torch.float64) 	F-macro_val: tensor(0.2585, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.2847, dtype=torch.float64) 	F-macro_val: tensor(0.2778, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.2847, dtype=torch.float64) 	F-macro_val: tensor(0.2746, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.2743, dtype=torch.float64) 	F-macro_val: tensor(0.2619, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.2882, dtype=torch.float64) 	F-macro_val: tensor(0.2757, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.2847, dtype=torch.float64) 	F-macro_val: tensor(0.2770, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.2847, dtype=torch.float64) 	F-macro_val: tensor(0.2662, dtype=torch.float64)
# Testing run # 5
# SE TUVIERON QUE REPETIR 3 EJEMPLOS
# Test_ acc: 0.14201762977473065
# Test_ f1 none: [0.14814815 0.15966387 0.37346437 0.00768246]
# Test_ f1 macro: 0.17223971138635594
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1

# %%
print ("Acc:",np.mean(np.asarray(global_accs)))
print ("F-score:", np.mean(np.asarray(global_fmacros)))
sup=np.mean(np.asarray(global_fnones)[:,0])
den=np.mean(np.asarray(global_fnones)[:,1])
que=np.mean(np.asarray(global_fnones)[:,2])
com=np.mean(np.asarray(global_fnones)[:,3])

print ("(0.0_CW) S-D-Q-C:", sup,den,que,com)
# Out:
# Acc: 0.13888344760039179
# F-score: 0.19680466871503877
# (0.0_CW) S-D-Q-C: 0.15095715684945732 0.14489534282853161 0.48829319182749265 0.003072983354673495

# %%
m_temp=np.zeros((4,4))
for m in global_cms:
    m_temp+=np.asarray(m)
m_temp
# Out:
# array([[ 148.,  169.,   23.,    0.],
#        [  99.,  209.,   37.,    0.],
#        [  77.,  107.,  346.,    0.],
#        [1332., 2039.,  513.,    6.]])

# %%
plot_confusion_matrix(normalize(m_temp),["S","D","Q","C"],"(0.0 CW) GloVe Transformer", cmap='Blues')

# %%
label=[['Text', 'm1', 'm2','m3','m4','m5']]
for layer in range(2):
    fig, axs = plt.subplots(1,4, figsize=(20, 10))
    print ("Encoder Layer Attention head Promedio", layer)
    for head in range(4):
        at=np.zeros((6,6))
        matriz_attn= dict_attn_enc[str(layer)+str(head)]  #lista de 5 corridas en cada pos
        for m in matriz_attn:
            at+=m.numpy()
        sns.heatmap(at/5., xticklabels=label[0], yticklabels=label[0],
                    vmin=0.0, vmax=1.0, linewidths=.5, cmap="Purples", cbar=False, square=True, ax=axs[head]) #, annot=False,cbar_kws={"orientation": "horizontal","pad": 0.25})
    plt.show()
# Out:
# Encoder Layer Attention head Promedio 0
# Encoder Layer Attention head Promedio 1

# %%
np.save("Attn_SinAum_GloVe_CW.npy", global_attn)
