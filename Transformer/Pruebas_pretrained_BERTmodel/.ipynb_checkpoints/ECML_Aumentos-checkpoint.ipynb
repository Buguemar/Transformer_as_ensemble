# %%
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler
from keras.preprocessing.sequence import pad_sequences
import pandas as pd
from models import *
import time
import re, io, nltk, torch 
from nltk.corpus import stopwords
from numpy import linalg as LA
from numpy.linalg import norm
from sklearn.preprocessing import normalize
from sklearn.model_selection import train_test_split
from tqdm import tqdm, trange
from sklearn.utils.class_weight import compute_class_weight
from gensim import utils, matutils  
from gensim.corpora.dictionary import Dictionary
from six import string_types, integer_types
from six.moves import zip, range
from numpy import linalg as LA
from sklearn.preprocessing import Normalizer
from scipy import stats
from gensim.utils import deprecated
from numpy import dot, float32 as REAL, memmap as np_memmap, \
    double, array, zeros, vstack, sqrt, newaxis, integer, \
    ndarray, sum as np_sum, prod, argmax
from collections import Counter
from scipy.spatial import distance
from numpy.random import binomial
from scipy.stats import bernoulli
import numpy as np

import transformers
from transformers import (
    WEIGHTS_NAME,
    AdamW,
    BertConfig,
    BertForMaskedLM,
    BertForSequenceClassification,
    BertTokenizer,
    CamembertConfig,
    CamembertForMaskedLM,
    CamembertTokenizer,
    DistilBertConfig,
    DistilBertForMaskedLM,
    DistilBertTokenizer,
    GPT2Config,
    GPT2LMHeadModel,
    GPT2Tokenizer,
    OpenAIGPTConfig,
    OpenAIGPTLMHeadModel,
    OpenAIGPTTokenizer,
    RobertaConfig,
    RobertaForMaskedLM,
    RobertaTokenizer,
    get_linear_schedule_with_warmup,
)

n_gpu = torch.cuda.device_count()
torch.cuda.get_device_name(0)

if torch.cuda.is_available():     
    device = torch.device("cuda")
    print('There are',torch.cuda.device_count(),'GPU(s) available.')
    print('We will use the GPU:', torch.cuda.get_device_name(0))

else:
    print('No GPU available, using the CPU instead.')
    device = torch.device("cpu")

from keras.preprocessing.sequence import pad_sequences
import matplotlib.pyplot as plt


train =pd.read_csv("../../Fine-Tuning/CSV_Harassment/train_format.csv")
val=pd.read_csv("../../Fine-Tuning/CSV_Harassment/val_format.csv")
test=pd.read_csv("../../Fine-Tuning/CSV_Harassment/test_format.csv")

dict_cl=dict()
dict_cl[0]="NonH"
dict_cl[1]="IndirectH"
dict_cl[2]="PhysicalH"
dict_cl[3]="SexualH"

#sdqc
d_lab=dict()
d_lab["NonH"]=0
d_lab["IndirectH"]=1
d_lab["PhysicalH"]=2
d_lab["SexualH"]=3

etiq_v=[d_lab[y] for y in val['Label']]
etiq_t=[d_lab[y] for y in test['Label']]
# Out:
# Using TensorFlow backend.
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# There are 1 GPU(s) available.
# We will use the GPU: GeForce GTX 1060 6GB

# %%
import re
from nltk.corpus import stopwords
from nltk import WordNetLemmatizer
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.porter import *

stemmer_sn = SnowballStemmer("english")
stemmer = PorterStemmer()

stoplist = stopwords.words("english")
lemmatizer=WordNetLemmatizer()

emoji_pattern = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags=re.UNICODE)

def cleaner(post): 
    #re.sub(r'([a-z])\1+', r'\1', "user i think that ' s all you loooooove ")
    s= re.sub(r"http\S+", " html ", post)   ##########elimina http    
    s= re.sub(r'#\w+ ?', " hashtag ", s) ########3
    s= re.sub(r'@\w+ ?', " user ", s)##############    
    s= s.lower()
    s=emoji_pattern.sub(r'', s)
    s=re.sub(r"'\b", " ' ", s)
    s=re.sub(r"\b'\b", " ' ", s)
    s=re.sub(r"\b’", " ’ ", s)
    s=re.sub(r"‘\b", " ‘ ", s)
    s=re.sub(r"\b’\b", " ‘ ", s)
    s = re.sub(r"-", " - ", s)
    s = re.sub(r"\(", " ", s)
    s = re.sub(r"\)", " ", s)
    s = re.sub(r"\?", " ? ", s)    
    s = re.sub(r"\/", " ", s)
    s = re.sub(r"' ", " ' ", s)
    s = re.sub(r" '", " ' ", s)
    s = re.sub(r"\!", " ! ", s)
    s=re.sub("[\.]+", " . ", s)
    s=re.sub("[\,]+", " , ", s)
    s=re.sub("[\;]+", " ; ", s)
    s=re.sub("[\:]+", " : ", s)
    s=re.sub('[\"]+', ' " ', s)
    s=re.sub(r'\b[0-9]\b', " number ",  s)
    s=re.sub(r'\b[0-9]*[0-9]\b', " number ",  s)    
    s=re.sub(r'\b”', ' " ', s)
    sl= list(s.split())
    #sl= [stemmer.stem(wd) for wd in sl]
    ############3
    sl_2=[]
    for wd in sl:
        try: 
            q=Word2Index[wd]
            sl_2.append(wd)
        except:
            try: 
                if stemmer.stem(wd) in Word2Index.keys():
                    sl_2.append(stemmer.stem(wd))
                    #print ("dejamos el stemmed de", wd)
                elif lemmatizer.lemmatize(wd) in Word2Index.keys():
                    sl_2.append(lemmatizer.lemmatize(wd))
                else:
                    sl_2.append(wd)
                    #print ("dejamos el lema de", wd)
                #print ("veamos si ",stemmer.stem(wd), "\tdel termino ", wd, "\testa:")
                #r=Word2Index[stemmer.stem(wd)]
                #sl_2.append(stemmer.stem(wd))
                
            except:
                sl_2.append(wd)
    sl=sl_2
    ##########
    s=' '.join([word for word in sl])# if word not in stoplist])
    return s, sl

# %%
tokenizer_loaded = BertTokenizer.from_pretrained('bert-base-uncased')
model_loaded = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=4)#'bert-base-uncased',  num_labels=4) 
idx_2_token = tokenizer_loaded.ids_to_tokens
Word2Index=tokenizer_loaded.vocab
M_BERT_space = model_loaded.bert.embeddings.word_embeddings.weight.detach().cpu().numpy()

# %%
not_found=[]
found=[]
found_train=[]
pos_tag_nf=[]

MAX_LEN=50

etiq=[]
for et in train['Label'].values:
    etiq.append(d_lab[et])
n_labels = np.array(etiq)
y_train=to_categorical(n_labels,num_classes=4)
sentences = train['Tweet'].values
input_ids = []
i=0

for sent in sentences:
    temp=cleaner(sent)
    encoded_sent2 = tokenizer_loaded.encode(temp[0],add_special_tokens = False) 
    encoded_sent=[]
    iterar=temp[1]
    for wd in iterar:
        try:
            indice=Word2Index[wd]
            encoded_sent.append(wd)
            if wd not in found:
                found.append(wd)
                found_train.append(wd)
        except: 
            if wd not in not_found:
                not_found.append(wd)
                pos_tag_nf.append(nltk.pos_tag([wd])[0][-1])

    input_ids.append(encoded_sent2)
    """ if i<3:
        print ("-----------------------------------------------------------------")
        print ("\nsentencia original:", sent)
        #print ("\nsentencia procesada My cleaner:",temp[0])
        print ("\nsentencia tokenizada usando Transformer vocabulary:", encoded_sent)
        print ("\nsentencia tokenizada usando Transformer Tokenizer:", encoded_sent2)
    i+=1"""

input_ids = pad_sequences(input_ids, maxlen=MAX_LEN, dtype="long", value=0, truncating="post", padding="post")

# %%
etiq_v=[]
for et in val['Label'].values:
    etiq_v.append(d_lab[et])
n_labels_val = np.array(etiq_v)
y_val=to_categorical(n_labels_val,num_classes=4)
sentences_val = val['Tweet'].values
input_ids_val = []
i=0
for sent in sentences_val:
    temp=cleaner(sent)
    encoded_sent2 = tokenizer_loaded.encode(temp[0],add_special_tokens = False) 
    encoded_sent=[]
    iterar=temp[1]
    for wd in iterar:
        try:
            indice=Word2Index[wd]
            encoded_sent.append(wd)
            if wd not in found: 
                found.append(wd)
        except: 
            if wd not in not_found:
                not_found.append(wd)
                pos_tag_nf.append(nltk.pos_tag([wd])[0][-1])
            
    input_ids_val.append(encoded_sent2)
    """if i<3:
        print ("-----------------------------------------------------------------")
        print ("\nsentencia original:", sent)
        #print ("\nsentencia procesada My cleaner:",temp[0])
        print ("\nsentencia tokenizada usando Transformer vocabulary:", encoded_sent)
        print ("\nsentencia tokenizada usando Transformer Tokenizer:", encoded_sent2)
    i+=1"""
    
input_ids_val = pad_sequences(input_ids_val, maxlen=MAX_LEN, dtype="long", value=0, truncating="post", padding="post")


etiq_t=[]
for et in test['Label'].values:
    etiq_t.append(d_lab[et])
n_labels_test = np.array(etiq_t)
y_test=to_categorical(n_labels_test,num_classes=4)
sentences_test = test['Tweet'].values
input_ids_test = []
i=0
for sent in sentences_test:
    temp=cleaner(sent)
    #encoded_sent=[Word2Index[wd] for wd in temp]
    encoded_sent2 = tokenizer_loaded.encode(temp[0],add_special_tokens = False) 
    encoded_sent=[]
    iterar=temp[1]
    for wd in iterar:
        try:
            indice=Word2Index[wd]
            encoded_sent.append(wd)
            if wd not in found:
                found.append(wd)            
        except: 
            if wd not in not_found:
                #print ("not found", wd)
                not_found.append(wd)
                pos_tag_nf.append(nltk.pos_tag([wd])[0][-1])
            
    input_ids_test.append(encoded_sent2)
    """if i<3:
        print ("-----------------------------------------------------------------")
        print ("\nsentencia original:", sent)
        #print ("\nsentencia procesada My cleaner:",temp[0])
        print ("\nsentencia tokenizada usando Transformer vocabulary:", encoded_sent)
        print ("\nsentencia tokenizada usando Transformer Tokenizer:", encoded_sent2)
    i+=1"""

input_ids_test = pad_sequences(input_ids_test, maxlen=MAX_LEN, dtype="long", value=0, truncating="post", padding="post")

# %%
len(not_found)
# Out:
# 12567

# %%
len(found)
# Out:
# 8949

# %%
print ("[my_cleaner] \t#Palabras NO encontradas en vocab BERT:",len(not_found))
print ("[my_cleaner] \t#Palabras encontradas en vocab BERT:",len(found))
print ("Distribución de palabras no encontradas en POS tag:", Counter(pos_tag_nf) )
# Out:
# [my_cleaner] 	#Palabras NO encontradas en vocab BERT: 12567
# [my_cleaner] 	#Palabras encontradas en vocab BERT: 8949
# Distribución de palabras no encontradas en POS tag: Counter({'NN': 10457, 'NNS': 915, 'CD': 439, 'VBG': 225, 'JJ': 219, 'VBN': 143, 'RB': 130, 'VB': 16, 'JJS': 10, 'VBD': 9, 'IN': 2, 'WDT': 1, 'DT': 1})

# %%
for wd in not_found[:30]:
    print ("[",wd,"] \t\tlema:",lemmatizer.lemmatize(wd), "\tStem:",stemmer.stem(wd), "\tStem snow:", stemmer_sn.stem(wd))
# Out:
# [ safka ] 		lema: safka 	Stem: safka 	Stem snow: safka
# [ slut ] 		lema: slut 	Stem: slut 	Stem snow: slut
# [ toon ] 		lema: toon 	Stem: toon 	Stem snow: toon
# [ shereiqns ] 		lema: shereiqns 	Stem: shereiqn 	Stem snow: shereiqn
# [ gotdamn ] 		lema: gotdamn 	Stem: gotdamn 	Stem snow: gotdamn
# [ chore ] 		lema: chore 	Stem: chore 	Stem snow: chore
# [ breakingnews ] 		lema: breakingnews 	Stem: breakingnew 	Stem snow: breakingnew
# [ unexplained ] 		lema: unexplained 	Stem: unexplain 	Stem snow: unexplain
# [ samswey ] 		lema: samswey 	Stem: samswey 	Stem snow: samswey
# [ sifill ] 		lema: sifill 	Stem: sifil 	Stem snow: sifil
# [ ldf ] 		lema: ldf 	Stem: ldf 	Stem snow: ldf
# [ handjob ] 		lema: handjob 	Stem: handjob 	Stem snow: handjob
# [ gangbang ] 		lema: gangbang 	Stem: gangbang 	Stem snow: gangbang
# [ x89 ] 		lema: x89 	Stem: x89 	Stem snow: x89
# [ wrm4xo00vj ] 		lema: wrm4xo00vj 	Stem: wrm4xo00vj 	Stem snow: wrm4xo00vj
# [ miliondollameat ] 		lema: miliondollameat 	Stem: miliondollameat 	Stem snow: miliondollameat
# [ sexting ] 		lema: sexting 	Stem: sext 	Stem snow: sext
# [ ngirl ] 		lema: ngirl 	Stem: ngirl 	Stem snow: ngirl
# [ ella939ella ] 		lema: ella939ella 	Stem: ella939ella 	Stem snow: ella939ella
# [ vickycornell ] 		lema: vickycornell 	Stem: vickycornel 	Stem snow: vickycornel
# [ grieving ] 		lema: grieving 	Stem: griev 	Stem snow: griev
# [ sp00kybitchhhh ] 		lema: sp00kybitchhhh 	Stem: sp00kybitchhhh 	Stem snow: sp00kybitchhhh
# [ sissy ] 		lema: sissy 	Stem: sissi 	Stem snow: sissi
# [ intox ] 		lema: intox 	Stem: intox 	Stem snow: intox
# [ sarahspain ] 		lema: sarahspain 	Stem: sarahspain 	Stem snow: sarahspain
# [ nadiaistoocool ] 		lema: nadiaistoocool 	Stem: nadiaistoocool 	Stem snow: nadiaistoocool
# [ peyt ] 		lema: peyt 	Stem: peyt 	Stem snow: peyt
# [ cervantes1127 ] 		lema: cervantes1127 	Stem: cervantes1127 	Stem snow: cervantes1127
# [ shamer ] 		lema: shamer 	Stem: shamer 	Stem snow: shamer
# [ ir6vjyuzka ] 		lema: ir6vjyuzka 	Stem: ir6vjyuzka 	Stem snow: ir6vjyuzka

# %%
for twt in train['Tweet'].values[:5]:
    print ("\n\nOrig:", twt)
    print ("tokenzed:", tokenizer_loaded.tokenize(twt))
# Out:
# Orig: pics mexican school girl naked melanie safka fake nude photos hardcore slut movies alicia moore porn star toon love
# tokenzed: ['pic', '##s', 'mexican', 'school', 'girl', 'naked', 'melanie', 'sa', '##fk', '##a', 'fake', 'nude', 'photos', 'hardcore', 'sl', '##ut', 'movies', 'alicia', 'moore', 'porn', 'star', 'too', '##n', 'love']
#
#
# Orig: RT shereiqns Having curly hair is a gotdamn chore Do not let the internets fool you ok
# tokenzed: ['rt', 'she', '##re', '##iq', '##ns', 'having', 'curly', 'hair', 'is', 'a', 'got', '##dam', '##n', 'cho', '##re', 'do', 'not', 'let', 'the', 'internet', '##s', 'fool', 'you', 'ok']
#
#
# Orig:  BreakingNews 7 Unexplained Prisoners Deaths Murder amp 50 Attempted Suicides samswey shacking Sifill LDF
# tokenzed: ['breaking', '##ne', '##ws', '7', 'une', '##x', '##pl', '##aine', '##d', 'prisoners', 'deaths', 'murder', 'amp', '50', 'attempted', 'suicide', '##s', 'sam', '##sw', '##ey', 'shack', '##ing', 'si', '##fi', '##ll', 'ld', '##f']
#
#
# Orig:  girl dirty quarterback latino pokemon young handjob kissing gangbang w x89 t co Wrm4xo00vJ
# tokenzed: ['girl', 'dirty', 'quarterback', 'latino', 'pokemon', 'young', 'hand', '##jo', '##b', 'kissing', 'gang', '##bang', 'w', 'x', '##8', '##9', 't', 'co', 'wr', '##m', '##4', '##x', '##o', '##00', '##v', '##j']
#
#
# Orig:  miliondollameat sexting n ngirl daddy n nme listen bitch gonna watch these what
# tokenzed: ['mil', '##ion', '##do', '##lla', '##me', '##at', 'sex', '##ting', 'n', 'ng', '##ir', '##l', 'daddy', 'n', 'nme', 'listen', 'bitch', 'gonna', 'watch', 'these', 'what']

# %%
train.columns
# Out:
# Index(['tweet_id', 'Tweet', 'Label'], dtype='object')

# %%
def my_normalize(v):
    norm = np.linalg.norm(v)
    if norm == 0: 
        return v
    return v/norm

#el peso max es igual a la clase mas grande
def det_samples(df, dict_class, c_weights=None):
    conteos= Counter(df)
    aumentos= dict()
    maxi= max(conteos.values())
    for clase in conteos:
        if conteos[clase]==maxi:
            class_maxi=clase
            
    if c_weights is None:        # uniform class weights
        for tipo in conteos:
            actual= conteos[tipo]
            if actual<maxi:
                aumentos[tipo]=int(maxi-actual)
            else:
                aumentos[tipo]=0
        return aumentos   
    else:
        try:
            weigths=my_normalize(c_weights)
            max_wei=max(weigths)
            class_max= list(weigths).index(max_wei)
            str_class=dict_class[class_max]
            samples_max=conteos[str_class]
            
            clase=0
            for peso in weigths:
                k=dict_class[clase]
                if peso == max_wei:
                    aumentos[k]= int(samples_max-conteos[k])
                    #print ("aumentos[k]", aumentos[k], 'sampples min', samples_max, 'conteos[clase]', conteos[clase])
                else:
                    futuro=(samples_max/max_wei)*peso
                    aumentos[k]=int(futuro-conteos[k])
                    #print ("aumentos[k] para pesos no minimos ", aumentos[k], "futuro", futuro, "actual", conteos[k])
                clase+=1
            return aumentos
        except:
            print ("No se ha especificado el vector de pesos par balance de datos")
            
            
def Sort_Tuple(tup):  
    return(sorted(tup, key = lambda x: x[1]))   
  
def re_generar(muestra, tags_all, tag, prob):
    sent, indices, tags = just_tag_word(muestra, tags_all, tag)
    noise_mask = bernoulli.rvs(prob, size=sent.shape)
    bool_list=list(map(bool,noise_mask))
    to_replace=sent[bool_list]
    indix=indices[bool_list]  
    tagx=tags[bool_list] 
    idx_to_orig=len(sent)
    return  to_replace , indix, tagx, idx_to_orig

puntos='!?."()[´]“<>¡¿-/;:=_”@#.'

def just_tag_word(sentence, tags_all, tag):
    n_sentence=[]
    indices=[]
    valid=[]
    i=0
    for wd in sentence:
        if wd in puntos or wd[0]=='#':
            i+=1
            continue
        else:
            if tags_all[i] not in tag:
                i+=1
                continue
            else:
                n_sentence.append(wd)
                indices.append(i)
                valid.append(tags_all[i])
            i+=1
    return np.asarray(n_sentence), np.asarray(indices), np.asarray(valid)

def all_tag_word(sentence):    
    n_sentence=[]
    for wd in sentence:
        if wd in puntos or wd[0]=='#':
            continue
        else:
            n_sentence.append(wd)    
    return np.asarray(n_sentence), np.asarray(indices), np.asarray(valid)
    
def all_tag_word2(sentence):
    n_sentence=[]
    for wd in sentence:
        if ('unused' in token) or token.isdigit() or token[:-2].isdigit() or token in puntos or "##" in token or len(token) < 2: 
            continue
        else:
            n_sentence.append(wd)
    return np.asarray(n_sentence)
        
def check_word(token, tag, clase):
    if ('unused' in token) or token.isdigit() or token[:-2].isdigit() or token in puntos or "##" in token or len(token) < 2: 
        return False
    else:
        if nltk.pos_tag([token])[0][-1]==tag and token in vocabulary[clase]:
            return True
        else: 
            return False

def check_vocab(token, clase):
    if ('unused' in token) or token.isdigit() or token[:-2].isdigit() or  token in puntos or "##" in token or len(token) < 2: 
        return False
    else:
        if token in vocabulary[clase]:
            return True
        else: 
            return False
        
def check_tag(token, tag):
    if ('unused' in token) or token.isdigit() or token[:-2].isdigit() or token in puntos or "##" in token or len(token) < 2: 
        return False
    else:
        if nltk.pos_tag([token])[0][-1]==tag:
            return True
        else: 
            return False
        
def check_vocab(token, clase):
    if ('unused' in token) or token.isdigit() or token[:-2].isdigit() or token in puntos or "##" in token or len(token) < 2: 
        return False
    else:
        if token in vocabulary[clase]:
            return True
        else: 
            return False
            
def check_valid(lista, tags):
    keep=[]
    lista_tag= [nltk.pos_tag([wd])[0][-1] for wd in lista] 
    #print ("Tags de pos/neg:", lista_tag)
    for tag, word in list(zip(lista_tag , lista)):
        if tag in tags:
            keep.append(word)
    return keep
            
def my_most_similar_cosmul(space, M_BERT_space, bias, positive=None, negative=None, topn=1 ): #agregar space de vpcab
    if isinstance(topn, int) and topn < 1:
        return []
    if positive is None:
        positive = []
    #if negative is None:
    #    negative = []
    if isinstance(positive, str) and not negative:
        positive = [positive]
  
    ids_pos = [
        Word2Index[word] if isinstance(word, string_types) else 'Tipo positivo no admitido'
        for word in positive
    ]    
    positive = [M_BERT_space[idx] for idx in ids_pos]  #space de vocab
    
    if negative is None:
        negative = []
    else: 
        #print ("\n\nSE SOLICITAN NEGATIVOS\n\n")
        ids_nega= [
            Word2Index[word] if isinstance(word, string_types) else 'Tipo negativo no admitido'
            for word in negative
        ]
        negative = [M_BERT_space[idx] for idx in ids_nega] #space de vocab

    if not positive:
        raise ValueError("cannot compute similarity with no input")
    
    
    pos_dists = [((1 + dot(space, term))/2) for term in positive]
    
    pos_dists[0]=pos_dists[0] + bias
    neg_dists = [((1 + dot(space, term))/2) for term in negative]
    dists = prod(pos_dists, axis=0) / (prod(neg_dists, axis=0) + 0.000001)
    
    if not topn:
        return dists
    best = matutils.argsort(dists, topn=topn + len(positive + negative), reverse=True)  #ordena en vocab used


    return best, dists[best] #retorna indices y distancias asociadas


def find_positive(lista, target, id_target, bias, window=4):
    to_return=[target]
    to_return=to_return*int(bias)
    positive_temp=find_window(lista, target, id_target, window=window)
    to_return+=positive_temp
    
    return to_return
                  

def find_window(lista, target, id_target, window=4):  #wind debe ser par   
    to_return=[]
    sub_w=int(window/2)
    
    if id_target >= sub_w and id_target + sub_w < len(lista):
        atras=lista[id_target-sub_w:id_target]
        adelante=lista[id_target+1:id_target+1+sub_w]
        
    elif id_target  < sub_w:
        atras=lista[:id_target]
        adelante=lista[id_target+1:id_target+sub_w+1]
        
    elif id_target + sub_w >= len(lista): 
        atras=lista[id_target-sub_w:id_target]
        adelante= lista[id_target+1:]
        
    to_return+=atras
    to_return+=adelante
    return to_return


def find_negative(target, not_sent, window=4):
    cleaned = cleaner(not_sent)[0]
    cleaned= tokenizer_loaded.tokenize(cleaned, add_special_tokens = False)
    ide = cleaned.index(target)
    wind_neg=find_window(list(cleaned), target, ide, window=window)
   
    return wind_neg


def sample_neg_class(cl):
    if type(cl) != list:
        cl = [cl]
    aux = list(d_lab.keys())
    for value in cl:
        aux.remove(value)
    samp_neg = np.random.choice(aux)
    
    used_classes = cl
    used_classes.append(samp_neg)
    return samp_neg, used_classes

def check_special(lista):
    exceptions=['[CLS]', '[SEP]', '[MASK]']
    to_return=[]
    for item in lista:  #es una tupla
        if item[0] not in exceptions: 
            to_return.append(item[0])
        else:
            continue
    return to_return

def choose_replace(candidatos, ide, target):
    candidatos=check_special(candidatos)
    try:
        candidatos.remove(target)
    except:
        pass
    
    elem=np.random.choice(candidatos)
    return (elem, ide)
        

def aumentar_clase(clase, num_ejem, tags_all, prob, TOPN):
    dict_resumen=dict()
    new_sample=[]
    indx=train['Label']==clase
    print ("Consultando por la clase", clase)
    label=d_lab[clase]    
    print ("Entrega label", label)
    contador=1
    
    no_modificados=0
    modificados=0
    terms_modif=0  
    terms_supuestos=0  
    totales=0
    largos=0
    SENT_LEN=0
    TOPE_LEN=0
    
    if num_ejem>0:
        while (len(new_sample)<num_ejem):
            muestras=train['Tweet'][indx]
            tw_ids=train['tweet_id'][indx]
            for muestra in muestras:  
                if len(new_sample)<num_ejem:
                    pre=np.asarray(tokenizer_loaded.tokenize(cleaner(muestra)[0], add_special_tokens=False))                    
                    tags_pre= [nltk.pos_tag([wd])[0][-1] for wd in pre]
                    terms, indxs, tagx, tope_replace= re_generar(pre, tags_pre, tags_all, prob)  #terms to replace
                    terms_supuestos+=len(terms)

                    news=[]
                    TOPE_LEN+=tope_replace
                    SENT_LEN+=len(terms)
                    
                    if len(terms)>0:     
                        
                        for term, ind, tag in list(zip(terms, indxs, tagx)):                           
                            mask_words = np.asarray(d_vocab[clase]) & np.asarray(d_pos[tag])
                            vocab_used_pos = np.arange(len(mask_words))[mask_words]
                            space= M_BERT_space[mask_words] #vocab de clase y tag
                            
                            if term!='user' and term!='hashtag' and term!='html':
                                not_clase, used_classes = sample_neg_class(clase) #definir clases a buscar
                                
                                valid_pos=[]
                                pos = find_positive(list(pre), term, ind, bias=1, window=4) #se puede cambiar la ventana! 
                                valid_pos=check_valid(pos, tags_all)

                                id_need = 999999999 #simbolo de que no encontró tweet
                                neg = []
                                while(id_need == 999999999):
                                    try:
                                        id_need = np.random.choice(dic_IdxI[not_clase][term]) #sample id
                                    except:
                                        if len(used_classes) == len(d_lab.keys()): 
                                            break #ya revisó todas las clases
                                        not_clase, used_classes = sample_neg_class(used_classes) # change class 

                                valid_neg=[]
                                if id_need != 999999999: #si encontró tweet
                                    not_sent = train["Tweet"][id_need]
                                    neg = find_negative(term, not_sent, window=4) 
                                    valid_neg=check_valid(neg, tags_all)

                                if len(valid_neg)<1 or len(valid_pos)<1:
                                    continue
                                    #pass

                                best, dists_best = my_most_similar_cosmul(space, M_BERT_space, 0.0, positive=valid_pos, negative=valid_neg, topn=TOPN)
                                #best, dists_best = my_most_similar_cosmul(space, M_BERT_space, 0.0, positive=valid_pos, negative=None, topn=TOPN)

                                todo_words = {
                                    Word2Index[word] for word in valid_pos + valid_neg
                                    if not isinstance(word, ndarray) and word in Word2Index
                                    }
                                result = []
                                for sim, dist_sim in list(zip(best, dists_best)):
                                    n_sim = vocab_used_pos[sim]
                                    if n_sim not in todo_words:
                                        result.append((idx_2_token[n_sim], float(dist_sim)))
                                        
                                if len(result)>0:
                                    candidatos = result[:TOPN] #+2
                                else:
                                    continue

                                new = choose_replace(candidatos, ind, term)  
                                news.append(new) 
                                if tag in dict_resumen.keys():
                                    dict_resumen[tag]+=1
                                else:
                                    dict_resumen[tag]=1
                                
                        cambia=False
                        news= Sort_Tuple(news) 
                        
                        if len(news)<1:
                            no_modificados+=1
                            continue
                        else:
                            x=np.asarray(news)[:,1]
                            y=np.asarray(news)[:,0]
                            n_news=np.asarray(np.vstack((x,y))).T

                            nueva_sent=[]
                            cont_new=0
                            for i in range(len(pre)):
                                try:
                                    if int(n_news[cont_new][0])==i:
                                        nueva_sent.append(n_news[cont_new][1])                 
                                        cont_new+=1
                                    else: 
                                        nueva_sent.append(pre[i])
                                except: 
                                    nueva_sent.append(pre[i])
                       
                            totales+=cont_new
                            new_sample.append([contador, nueva_sent, label])
                            modificados+=1
                            terms_modif+=len(news)
                            largos+=len(pre)
                            contador+=1
                            
                            #"""
                            if len(new_sample)<10:
                                print ("Sentencia original:")
                                print (pre)
                                print ("Sentencia final:" , label)
                                print (nueva_sent)
                                print ("")
                                print ("")
                            #"""                              

                else:
                    count= Counter(train['Label'])   
                    for muestra, twid in list(zip(muestras,tw_ids)) :
                        pre=np.asarray(cleaner(muestra)[1])
                        new_sample.append([twid, pre, label])
                    break
                    
    else:
        count= Counter(train['Label'])
        news= train[indx].sample(count[clase]+num_ejem)
        news_tw=news['Tweet'].values
        news_id=news['tweet_id'].values
        for muestra, twid in list(zip(news_tw, news_id)):
            pre=np.asarray(cleaner(muestra)[1])
            new_sample.append([twid, pre, label])

    try:
        print ("# terms modificados promedio", terms_modif/modificados ,"términos por sentencia")
        print ("Largo de sentencia promedio", largos/modificados ,"términos por sentencia")
        print ("para esta ejecución se debiesen reemplazar", SENT_LEN, " de" ,TOPE_LEN, "terminos")

    except: 
        print ("No se generan ejemplos")

    return new_sample, dict_resumen


def predict_data(trained, x_train, x_val, x_test, etiq, etiq_v, etiq_t, name_model):
    etiq = etiq.astype("int")
    trainPredict = trained.predict(x_train, batch_size=32)
    trainPredict=[np.argmax(pred) for pred in trainPredict]
    acc= accuracy_score(etiq, trainPredict)  
    f1=f1_score(etiq, trainPredict, average=None)  # labels=np.unique(trainPredict)
    f1_ma=f1_score(etiq, trainPredict, average='macro')  # labels=np.unique(trainPredict)
    #matriz=normalize(confusion_matrix(etiq, trainPredict))
    print ("")
    print ("Accuracy sobre Train", name_model, ":",acc)  
    print ("F1-score None sobre Train", name_model, ":",f1)
    print ("F1-score macro sobre Train", name_model, ":",f1_ma)
    ########################################
    trainPredict = trained.predict(x_val, batch_size=32)
    trainPredict=[np.argmax(pred) for pred in trainPredict]
    acc= accuracy_score(etiq_v, trainPredict)  
    f1=f1_score(etiq_v, trainPredict, average=None)  # labels=np.unique(trainPredict)
    f1_ma=f1_score(etiq_v, trainPredict, average='macro')  # labels=np.unique(trainPredict)
    #matriz=normalize(confusion_matrix(etiq_v, trainPredict))
    print ("")
    print ("Accuracy sobre Val", name_model, ":",acc)  
    print ("F1-score None sobre Val", name_model, ":",f1)
    print ("F1-score macro sobre Val", name_model, ":",f1_ma)
    ########################################
    trainPredict = trained.predict(x_test, batch_size=32)
    trainPredict=[np.argmax(pred) for pred in trainPredict]
    acc_t= accuracy_score(etiq_t, trainPredict)  
    f1_t=f1_score(etiq_t, trainPredict, average=None)  # labels=np.unique(trainPredict)
    f1_ma_t=f1_score(etiq_t, trainPredict, average='macro')  # labels=np.unique(trainPredict)
    matriz_t=normalize(confusion_matrix(etiq_t, trainPredict))
    print ("")
    print ("Accuracy sobre Test", name_model, ":",acc_t)  
    print ("F1-score None sobre Test", name_model, ":",f1_t)
    print ("F1-score macro sobre Test", name_model, ":",f1_ma_t)
    
    return f1_ma_t, f1_t, acc_t, matriz_t

# %%
transformer = Normalizer().fit(M_BERT_space) 
M_BERT_space=transformer.transform(M_BERT_space)

#indice invertido para cada clase
tr_s=train.loc[train['Label']=='NonH']
tr_d=train.loc[train['Label']=='IndirectH']
tr_q=train.loc[train['Label']=='PhysicalH']
tr_c=train.loc[train['Label']=='SexualH']

keys=['NonH', 'IndirectH', 'PhysicalH', 'SexualH']

dict_vocab={}
for key in keys: 
    tr_k=train.loc[train['Label']==key]
    tr_k=tr_k['Tweet'].values    
    trs_k=[]
    for tw in tr_k:
        encoded = cleaner(tw)[1]
        apen=[]
        for wd in encoded:
            try: 
                h=Word2Index[wd]
                apen.append(wd)
            except: 
                continue
        
        #trs_k+=list(set(encoded))
        trs_k+=apen
    dict_vocab[key]=list(set(trs_k ))
    print ("#terms ",key,":",len(dict_vocab[key]))
# Out:
# #terms  NonH : 5937
# #terms  IndirectH : 371
# #terms  PhysicalH : 499
# #terms  SexualH : 3658

# %%
all_terms=[]
for key in keys:
    all_terms+=dict_vocab[key]
    
len(set(all_terms))
# Out:
# 7109

# %%
len(found_train)
# Out:
# 7109

# %%
vocabulary=dict_vocab
dic_IdxI = {value: {} for value in d_lab.keys()}
for i, (muestra, label) in enumerate(list(zip(train['Tweet'],train['Label']))):
    pre=np.asarray(cleaner(muestra)[1])
    for token in pre:
        if token not in dic_IdxI[label]:
            dic_IdxI[label][token] = [i]
        else:
            dic_IdxI[label][token].append(i)

# %%
tags=['NN','NNS', 'JJ', 'JJR', 'JJS', 'VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ']
clases=['NonH', 'IndirectH', 'PhysicalH', 'SexualH']

# %%
d_pos= dict()
for tag in tags:
    d_pos[tag]= [check_tag(k, tag) for k in idx_2_token.values()]
    
d_vocab=dict()
for clase in clases:
    d_vocab[clase]= [check_vocab(k, clase) for k in idx_2_token.values()]

# %%
shape_val=np.asarray(input_ids_val).shape
x_val=np.zeros((shape_val[0], shape_val[1], 768))
i=0
for in_id in input_ids_val:
    x_val[i]=M_BERT_space[in_id]
    i+=1
    
shape_test=np.asarray(input_ids_test).shape
x_test=np.zeros((shape_test[0], shape_test[1], 768))
i=0
for in_id in input_ids_test:
    x_test[i]=M_BERT_space[in_id]
    i+=1

x_test.shape
# Out:
# (2123, 50, 768)

# %% [markdown]
# ### Generar 0.15 [pos + negativo classic]

# %%
prob= 0.15
TOPN = 1

fs_macro={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
fs_none={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
accs={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
confusions={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}

aum_weight=det_samples(train['Label'], dict_cl)

for i in range(1,6): 
    macro_augmented=[]
    print ("\n--------------------------------------------------------")
    print ("\nGenerando ejemplos en base a probabilidad --> ", prob)
    print ("--------------------------------------------------------")
    for clase in aum_weight:
        start_time=time.time()
        print ("\n\nGenerando", aum_weight[clase], "nuevos ejemplos para la clase", clase)
        muestras, dict_aumentos=aumentar_clase(clase, aum_weight[clase], tags, prob, TOPN)
        macro_augmented+=muestras
        print ("Resumen de modificaciones:", dict_aumentos)
        elapsed_time= time.time() - start_time
        print ("Este proceso tomó", elapsed_time, "seg")   

    macro_augmented = np.asarray(macro_augmented, dtype=object)
    np.random.shuffle(macro_augmented)
    np.save('../../../new_data_augmented/harassment/Aumento_'+str(i)+'-run_'+str(prob)+'_app1_Top'+str(TOPN)+'.npy', macro_augmented)
# Out:
# --------------------------------------------------------
#
# Generando ejemplos en base a probabilidad -->  0.15
# --------------------------------------------------------
#
#
# Generando 1079 nuevos ejemplos para la clase SexualH
# Consultando por la clase SexualH
# Entrega label 3
# Sentencia original:
# ['pic' 'mexican' 'school' 'girl' 'naked' 'melanie' 'sa' '##fk' '##a'
#  'fake' 'nude' 'photos' 'hardcore' 'sl' '##ut' 'movies' 'alicia' 'moore'
#  'porn' 'star' 'too' '##n' 'love']
# Sentencia final: 3
# ['college', 'mexican', 'school', 'girl', 'naked', 'melanie', 'valentin', '##fk', '##a', 'fake', 'nude', 'photos', 'hardcore', 'sl', '##ut', 'movies', 'alicia', 'moore', 'porn', 'star', 'too', '##n', 'love']
#
#
# Sentencia original:
# ['girl' 'dirty' 'quarterback' 'latino' 'pokemon' 'young' 'hand' '##jo'
#  '##b' 'kissing' 'gang' '##bang' 'w' 'x' '##8' '##9' 't' 'co' 'wr' '##m'
#  '##4' '##x' '##o' '##00' '##v' '##j']
# Sentencia final: 3
# ['girl', 'dirty', 'quarterback', 'latino', 'pokemon', 'young', 'hand', '##jo', '##b', 'kissing', 'gang', '##bang', 'w', 'wc', '##8', '##9', 't', 'co', 'wr', '##m', '##4', '##x', '##o', '##00', '##v', '##j']
#
#
# Sentencia original:
# ['museum' 'sl' '##ut' 'if' 'you' 'know' 'somewhere' 'we' 'can' 'do' 'it'
#  'then' 'i' 'am' 'game']
# Sentencia final: 3
# ['museum', 'sl', '##ut', 'if', 'you', 'know', 'somewhere', 'we', 'can', 'do', 'it', 'then', 'i', 'are', 'game']
#
#
# Sentencia original:
# ['rt' 'sp' '##00' '##ky' '##bit' '##ch' '##hh' '##h' 'i' 'have' 'spots'
#  'open' 'sis' '##sy' 'sl' '##ut' 'into' '##x' 'bitch' 'human' 'atm'
#  'amazon' 'boy' 'do' 'you' 'have' 'what' 'it' 'takes' 'can' 'you' 'live'
#  'up' 'to' 'my']
# Sentencia final: 3
# ['rt', 'sp', '##00', '##ky', '##bit', '##ch', '##hh', '##h', 'i', 'take', 'spots', 'open', 'sis', '##sy', 'silvia', '##ut', 'into', '##x', 'bitch', 'human', 'atm', 'amazon', 'boy', 'do', 'you', 'have', 'what', 'it', 'takes', 'can', 'you', 'live', 'up', 'to', 'my']
#
#
# Sentencia original:
# ['venus' 'astro' '##logy' 'living' 'standards' 'ni' '##t' 'x' '##8' '##9'
#  's' 'illusion' 'i' 'x' '##8' '##9' 'm' 'fucking' 'nwa' '##iting'
#  'waiting' 'wai' 'x' '##8' '##9']
# Sentencia final: 3
# ['venus', 'astro', '##logy', 'living', 'standards', 'ni', '##t', 'x', '##8', '##9', 's', 'illusion', 'i', 'x', '##8', '##9', 'thong', 'fucking', 'nwa', '##iting', 'crying', 'wai', 'violin', '##8', '##9']
#
#
# Sentencia original:
# ['add' 'me' 'on' 'snap' '##cha' '##t' 'and' 'watch' 'me' 'cum' 'colt'
#  '##oe' '##8' 'send' '##nu' '##des' 'nude' 'nude' 'snap' '##cha' '##t'
#  'girls' 'boo' '##bs' 'pussy' 'horn' '##y']
# Sentencia final: 3
# ['add', 'me', 'on', 'snap', '##cha', '##t', 'and', 'watch', 'me', 'cum', 'colt', '##oe', '##8', 'blackish', '##nu', '##des', 'nude', 'nude', 'snap', '##cha', '##t', 'girls', 'boo', '##bs', 'pussy', 'horn', '##y']
#
#
# Sentencia original:
# ['rt' 'ole' '##sm' '##eh' '##a' '##86' 'he' 'need' 'me' 'to' 'eat' 'his'
#  'dick' 'because' 'eat' 'dick' 'it' 's' 'my' 'skill' 'sl' '##ut' 'ass'
#  'dick' 'cock' 'jail' '##bai' '##t' 'bbc' 'gang' '##bang' 'cu' '##cko'
#  '##ld']
# Sentencia final: 3
# ['nt', 'ol', '##sm', '##eh', '##a', '##86', 'he', 'need', 'me', 'to', 'eat', 'his', 'dick', 'because', 'eat', 'ate', 'it', 's', 'my', 'skill', 'sl', '##ut', 'ass', 'dick', 'butt', 'jail', '##bai', '##t', 'gangster', 'gang', '##bang', 'cu', '##cko', '##ld']
#
#
# Sentencia original:
# ['rt' 'tia' '##po' '##gai' '##51' 'please' 'sleep' 'i' 'will' 'do' 'it'
#  'for' 'you' 'guy' 'gt' 'register' 'note' 'verify' 'email' 'to' 'send'
#  'ms' '##g' 'to' 'girls' 'sl' '##ut']
# Sentencia final: 3
# ['rt', 'tia', '##po', '##gai', '##51', 'please', 'slept', 'i', 'will', 'do', 'it', 'for', 'you', 'guy', 'gt', 'register', 'note', 'clench', 'email', 'to', 'send', 'fake', '##g', 'to', 'girls', 'sl', '##ut']
#
#
# Sentencia original:
# ['reality' 'pro' '##zzi' '##e' 'mouth' 'n' 't' 'co' 'f' '##q' '##b' '##3'
#  '##ny' '##it' '##p' '##1' 'under' '##age' 'cum' '##shot' 'movies' 'bust'
#  '##y' '##hard' '##core' '##ba' '##bes' 'european' 'girl' 'x' '##8' '##9'
#  't' 'co' 'vs' '##k' '##cts' '##y' '##q' '##eo']
# Sentencia final: 3
# ['world', 'pro', '##zzi', '##e', 'rb', 'n', 't', 'co', 'f', '##q', '##b', '##3', '##ny', '##it', '##p', '##1', 'under', '##age', 'brunette', '##shot', 'movies', 'bust', '##y', '##hard', '##core', '##ba', '##bes', 'european', 'girl', 'x', '##8', '##9', 't', 'co', 'vs', '##k', '##cts', '##y', '##q', '##eo']
#
#
# # terms modificados promedio 2.0593141797961074 términos por sentencia
# Largo de sentencia promedio 24.88507877664504 términos por sentencia
# para esta ejecución se debiesen reemplazar 2555  de 16741 terminos
# Resumen de modificaciones: {'NN': 1685, 'VBP': 9, 'VB': 78, 'VBG': 72, 'JJ': 149, 'VBN': 36, 'VBD': 31, 'VBZ': 37, 'NNS': 119, 'JJS': 5, 'JJR': 1}
# Este proceso tomó 17.50653314590454 seg
#
#
# Generando 0 nuevos ejemplos para la clase NonH
# Consultando por la clase NonH
# Entrega label 0
# No se generan ejemplos
# Resumen de modificaciones: {}
# Este proceso tomó 0.43671298027038574 seg
#
#
# Generando 3585 nuevos ejemplos para la clase PhysicalH
# Consultando por la clase PhysicalH
# Entrega label 2
# Sentencia original:
# ['deep' '##th' '##ro' '##at' 'cum' '##shot' 'perfect' 'boo' '##bs'
#  'jewish' 'indian' 'pussy' 'naked' 'lesbian' 'japanese' 'beau' '##t' 'x'
#  '##8' '##9' 't' 'co' 'g' '##f' '##w' '##x' '##st' '##n' '##2' '##fk']
# Sentencia final: 2
# ['deep', '##th', '##ro', '##at', 'cum', '##shot', 'perfect', 'boo', '##bs', 'jewish', 'indian', 'pussy', 'naked', 'lesbian', 'japanese', 'beau', '##t', 'perfect', '##8', '##9', 't', 'co', 'g', '##f', '##w', '##x', '##st', '##n', '##2', '##fk']
#
#
# Sentencia original:
# ['rt' 'debbie' '##d' '##7' '##47' '##9' '##9' '##11' '##8' 'steve' '##d'
#  '##48' '##48' 'how' 'dare' 'she' 'honest' 'people' 'and' 'children'
#  'were' 'killed' 'in' 'manchester' 'and' 'this' 'sc' '##um' 'says' 'that'
#  's' 'fair' 're' '##tal' '##i']
# Sentencia final: 2
# ['rt', 'debbie', '##d', '##7', '##47', '##9', '##9', '##11', '##8', 'steve', '##d', '##48', '##48', 'how', 'dare', 'she', 'honest', 'people', 'and', 'children', 'were', 'tortured', 'in', 'manchester', 'and', 'this', 'sc', '##um', 'says', 'that', 'se', 'fair', 're', '##tal', '##i']
#
#
# Sentencia original:
# ['pr' '##ae' '##tors' '##uit' 'which' 'specifically' 'i' 'x' '##8' '##9'
#  'd' 'personally' 'pitch' 'black' 'world' 'devil' 'there' 'rap' '##ist'
#  'an' 'x' '##8' '##9' 't' 'co' 'bu' '##rg' '##t' '##j' '##fr' '##ya']
# Sentencia final: 2
# ['pr', '##ae', '##tors', '##uit', 'which', 'specifically', 'i', 'x', '##8', '##9', 'd', 'personally', 'pitch', 'black', 'world', 'devil', 'there', 'rap', '##ist', 'an', 'x', '##8', '##9', 'rt', 'co', 'rt', '##rg', '##t', '##j', '##fr', '##ya']
#
#
# Sentencia original:
# ['sas' '##sy' 'wants' 'signing' 'first' 'prepare' 'good' 'don' 't' 'know'
#  'x' '##8' '##9' 't' 'co' 'qi' '##q' '##gi' '##b' '##17' '##ik']
# Sentencia final: 2
# ['sas', '##sy', 'wants', 'signing', 'first', 'prepare', 'other', 'don', 't', 'know', 'rt', '##8', '##9', 't', 'co', 'qi', '##q', '##gi', '##b', '##17', '##ik']
#
#
# Sentencia original:
# ['the' 'woman' 'brutally' 'tortured' 'minor' 'servant' 'starved' 'major'
#  'am' '##mara' 'm' 'x' '##8' '##9' 't' 'co' 'y' '##j' '##9' '##6' '##d'
#  '##2' '##x' '##gr' '##p']
# Sentencia final: 2
# ['the', 'woman', 'brutally', 'tortured', 'minor', 'servant', 'addicted', 'big', 'am', '##mara', 'chopped', 'rt', '##8', '##9', 't', 'co', 'rt', '##j', '##9', '##6', '##d', '##2', '##x', '##gr', '##p']
#
#
# Sentencia original:
# ['what' 'i' 'don' 't' 'get' 'is' 'how' 'y' 'all' 'try' 'to' 'drag' 'becky'
#  'for' 'body' 'shame' 'charlotte' 'when' 'she' 'didn' 't' 'but' 'laugh'
#  'at' 'a' 'fan' 'th']
# Sentencia final: 2
# ['what', 'i', 'don', 'head', 'get', 'is', 'how', 'y', 'all', 'try', 'to', 'drag', 'becky', 'for', 'body', 'life', 'charlotte', 'when', 'she', 'doesn', 't', 'but', 'laugh', 'at', 'a', 'fan', 'th']
#
#
# Sentencia original:
# ['x' 'wilde' '##st' '##dre' '##ams' 'really' 'being' 'sas' '##sy'
#  'twitter' 't' 'co' 'bt' '##bl' '##sz' '##x' '##b' '##w' '##0']
# Sentencia final: 2
# ['cast', 'wilde', '##st', '##dre', '##ams', 'really', 'discussing', 'sas', '##sy', 'twitter', 't', 'co', 'bt', '##bl', '##sz', '##x', '##b', '##w', '##0']
#
#
# Sentencia original:
# ['heaven' '##bra' '##t' 'really' 'really' 'bitch' 'bullshit' 'n' '##2'
#  'much' 'x' '##8' '##9']
# Sentencia final: 2
# ['divine', '##bra', '##t', 'really', 'really', 'bitch', 'bullshit', 'n', '##2', 'horrible', 'x', '##8', '##9']
#
#
# Sentencia original:
# ['ne' '##h' '##22' '##3' 'ni' '##gga' 'getting' 'chopped' 'whole' 'dream'
#  'shit']
# Sentencia final: 2
# ['ne', '##h', '##22', '##3', 'anwar', '##gga', 'getting', 'murderer', 'horrible', 'chop', 'shit']
# # terms modificados promedio 2.0736401673640166 términos por sentencia
# Largo de sentencia promedio 24.676150627615062 términos por sentencia
# para esta ejecución se debiesen reemplazar 8169  de 54262 terminos
# Resumen de modificaciones: {'NN': 5567, 'VBN': 143, 'JJ': 372, 'VBG': 296, 'VBZ': 196, 'NNS': 306, 'VB': 329, 'VBD': 145, 'VBP': 53, 'JJS': 27}
# Este proceso tomó 40.04898953437805 seg
#
#
# Generando 3606 nuevos ejemplos para la clase IndirectH
# Consultando por la clase IndirectH
# Entrega label 1
# Sentencia original:
# ['the' 'people' 'that' 'work' 'in' 'the' 'dining' 'hall' 'are' 'all'
#  'sitting' 'here' 'talking' 'shit' 'about' 'this' 'girl' 'that' 'came'
#  'in' 'first' 'thing']
# Sentencia final: 1
# ['the', 'people', 'that', 'work', 'in', 'the', 'dining', 'hall', 'are', 'all', 'messing', 'here', 'talking', 'shit', 'about', 'this', 'girl', 'that', 'came', 'in', 'first', 'thing']
#
#
# Sentencia original:
# ['i' 'will' 'never' 'understand' 'how' 'girls' 'can' 'sl' '##ut' 'shame'
#  'other' 'girls' 'for' 'having' 'male' 'friends']
# Sentencia final: 1
# ['time', 'will', 'never', 'understand', 'how', 'girls', 'can', 'sl', '##ut', 'shame', 'other', 'girls', 'for', 'having', 'male', 'girlfriends']
#
#
# Sentencia original:
# ['the' '##kat' '##ied' '##ren' '##nen' 'katie' 'is' 'totally' 'turning'
#  'into' 'one' 'of' 'those' 'girls' 'who' 'gets' 'married' 'and' 'forget'
#  'two' 'years' 'ago' 'she' 'wa']
# Sentencia final: 1
# ['the', '##kat', '##ied', '##ren', '##nen', 'katie', 'is', 'totally', 'turning', 'into', 'one', 'of', 'those', 'girls', 'who', 'wants', 'married', 'and', 'forget', 'two', 'years', 'ago', 'she', 'wa']
#
#
# Sentencia original:
# ['baku' '##bro' '##ws' 'freaked' '##by' '##du' '##bu' '##l' '##g' 'sara'
#  '##ot' '##5' 'how' 'can' 'u' 'go' 'from' 'wonder' 'girls' 'and' 'miss'
#  'a' 'to' 'twice' 'and' 'these' 'ladies' 'l' '##m' '##fa' '##o' 'i' 'can'
#  't']
# Sentencia final: 1
# ['baku', '##bro', '##ws', 'freaked', '##by', '##du', '##bu', '##l', '##g', 'leftist', '##ot', '##5', 'how', 'can', 'u', 'go', 'from', 'wonder', 'girls', 'and', 'miss', 'a', 'to', 'twice', 'and', 'these', 'ladies', 'l', '##m', '##fa', '##o', 'i', 'can', 't']
#
#
# Sentencia original:
# ['love' '##toy' 'ca' 'that' 's' 'a' 'well' 'trained' 'girl']
# Sentencia final: 1
# ['want', '##toy', 'ca', 'that', 'time', 'a', 'well', 'trained', 'girl']
#
#
# Sentencia original:
# ['number' 't' 'you' 'should' 'do' 'to' 'him' 'all' 'by' 'now' 'you' 'will'
#  'need' 'to' 'make' 'him' 'a' 'few' 'times' 'until' 'she' 'is' 'ready'
#  'and' 'he' 'just' 'lets' 'h']
# Sentencia final: 1
# ['number', 't', 'you', 'should', 'do', 'to', 'him', 'all', 'by', 'now', 'you', 'will', 'need', 'to', 'make', 'him', 'a', 'disappointed', 'times', 'until', 'she', 'is', 'ready', 'and', 'he', 'just', 'mosques', 'h']
#
#
# Sentencia original:
# ['mrs' 'hc' '##m' 'tr' '##ad' '##po' '##aster' '##100' '##0' 'also'
#  'though' 'if' 'eggs' 'are' 'the' 'resource' 'guys' 'are' 'after' 'vs' 'a'
#  'good' 'and' 'vi' '##rt' '##uous' 'wife' 'who' 'will']
# Sentencia final: 1
# ['ms', 'hc', '##m', 'tr', '##ad', '##po', '##aster', '##100', '##0', 'also', 'though', 'if', 'eggs', 'are', 'the', 'resource', 'aren', 'are', 'after', 'mrs', 'a', 'good', 'and', 'vi', '##rt', '##uous', 'girlfriend', 'who', 'will']
#
#
# Sentencia original:
# ['rt' 'maxi' '##pen' '##al' '##ty' 'when' 'will' 'the' 'phenomenon' 'of'
#  'white' 'women' 'with' 'no' 'personality' 'who' 'can' 't' 'do'
#  'literally' 'anything' 'without' 'wine' 'just' 'fucking' 'die']
# Sentencia final: 1
# ['cheryl', 'maxi', '##pen', '##al', '##ty', 'when', 'will', 'the', 'phenomenon', 'of', 'white', 'women', 'with', 'no', 'personality', 'who', 'can', 't', 'be', 'literally', 'anything', 'without', 'wine', 'just', 'dining', 'die']
#
#
# Sentencia original:
# ['dj' 'nine' '##r' 'fundamental' '##s' '##34' '##5' 'she' 'shouldn' 't'
#  'even' 'be' 'where' 'she' 'is' 'that' 's' 'fucking' 'dumb' 'as' 'hell'
#  'she' 'has' 'got' 'to' 'grow' 'up']
# Sentencia final: 1
# ['dj', 'nine', '##r', 'fundamental', '##s', '##34', '##5', 'she', 'shouldn', 'didn', 'even', 'be', 'where', 'she', 'is', 'that', 's', 'being', 'dumb', 'as', 'hell', 'she', 'gets', 'got', 'to', 'grow', 'up']
#
#
# # terms modificados promedio 1.9453688297282308 términos por sentencia
# Largo de sentencia promedio 23.936772046589017 términos por sentencia
# para esta ejecución se debiesen reemplazar 7682  de 51812 terminos
# Resumen de modificaciones: {'VBG': 279, 'NN': 5011, 'NNS': 480, 'VBZ': 241, 'JJ': 420, 'VB': 228, 'VBN': 206, 'VBD': 137, 'VBP': 13}
# Este proceso tomó 38.5105345249176 seg
#
# --------------------------------------------------------
#
# Generando ejemplos en base a probabilidad -->  0.15
# --------------------------------------------------------
#
#
# Generando 1079 nuevos ejemplos para la clase SexualH
# Consultando por la clase SexualH
# Entrega label 3
# Sentencia original:
# ['pic' 'mexican' 'school' 'girl' 'naked' 'melanie' 'sa' '##fk' '##a'
#  'fake' 'nude' 'photos' 'hardcore' 'sl' '##ut' 'movies' 'alicia' 'moore'
#  'porn' 'star' 'too' '##n' 'love']
# Sentencia final: 3
# ['pic', 'mexican', 'school', 'girl', 'naked', 'melanie', 'sa', '##fk', '##a', 'fake', 'nude', 'photos', 'hardcore', 'sl', '##ut', 'movies', 'alicia', 'moore', 'pornography', 'star', 'too', '##n', 'love']
#
#
# Sentencia original:
# ['girl' 'dirty' 'quarterback' 'latino' 'pokemon' 'young' 'hand' '##jo'
#  '##b' 'kissing' 'gang' '##bang' 'w' 'x' '##8' '##9' 't' 'co' 'wr' '##m'
#  '##4' '##x' '##o' '##00' '##v' '##j']
# Sentencia final: 3
# ['girl', 'dirty', 'boy', 'latino', 'pokemon', 'young', 'hand', '##jo', '##b', 'kissing', 'gang', '##bang', 'w', 'croft', '##8', '##9', 't', 'co', 'wr', '##m', '##4', '##x', '##o', '##00', '##v', '##j']
#
#
# Sentencia original:
# ['mil' '##ion' '##do' '##lla' '##me' '##at' 'sex' '##ting' 'n' 'ng' '##ir'
#  '##l' 'daddy' 'n' 'nme' 'listen' 'bitch' 'gonna' 'watch' 'these' 'what']
# Sentencia final: 3
# ['mil', '##ion', '##do', '##lla', '##me', '##at', 'bonn', '##ting', 'n', 'ng', '##ir', '##l', 'fulham', 'n', 'nme', 'listen', 'bitch', 'gonna', 'watch', 'these', 'what']
#
#
# Sentencia original:
# ['rt' 'sp' '##00' '##ky' '##bit' '##ch' '##hh' '##h' 'i' 'have' 'spots'
#  'open' 'sis' '##sy' 'sl' '##ut' 'into' '##x' 'bitch' 'human' 'atm'
#  'amazon' 'boy' 'do' 'you' 'have' 'what' 'it' 'takes' 'can' 'you' 'live'
#  'up' 'to' 'my']
# Sentencia final: 3
# ['rt', 'sp', '##00', '##ky', '##bit', '##ch', '##hh', '##h', 'i', 'have', 'spots', 'open', 'sis', '##sy', 'gal', '##ut', 'into', '##x', 'asshole', 'human', 'atm', 'amazon', 'boy', 'do', 'you', 'have', 'what', 'it', 'takes', 'can', 'you', 'live', 'up', 'to', 'my']
#
#
# Sentencia original:
# ['venus' 'astro' '##logy' 'living' 'standards' 'ni' '##t' 'x' '##8' '##9'
#  's' 'illusion' 'i' 'x' '##8' '##9' 'm' 'fucking' 'nwa' '##iting'
#  'waiting' 'wai' 'x' '##8' '##9']
# Sentencia final: 3
# ['venus', 'astro', '##logy', 'living', 'standards', 'ni', '##t', 'x', '##8', '##9', 's', 'illusion', 'i', 'x', '##8', '##9', 'nylon', 'fucking', 'nwa', '##iting', 'waiting', 'wai', 'x', '##8', '##9']
#
#
# Sentencia original:
# ['add' 'me' 'on' 'snap' '##cha' '##t' 'and' 'watch' 'me' 'cum' 'colt'
#  '##oe' '##8' 'send' '##nu' '##des' 'nude' 'nude' 'snap' '##cha' '##t'
#  'girls' 'boo' '##bs' 'pussy' 'horn' '##y']
# Sentencia final: 3
# ['add', 'me', 'on', 'snap', '##cha', '##t', 'and', 'watch', 'me', 'cum', 'colt', '##oe', '##8', 'send', '##nu', '##des', 'nude', 'nude', 'snap', '##cha', '##t', 'boys', 'boo', '##bs', 'pussy', 'horn', '##y']
#
#
# Sentencia original:
# ['rt' 'ole' '##sm' '##eh' '##a' '##86' 'he' 'need' 'me' 'to' 'eat' 'his'
#  'dick' 'because' 'eat' 'dick' 'it' 's' 'my' 'skill' 'sl' '##ut' 'ass'
#  'dick' 'cock' 'jail' '##bai' '##t' 'bbc' 'gang' '##bang' 'cu' '##cko'
#  '##ld']
# Sentencia final: 3
# ['rt', 'ole', '##sm', '##eh', '##a', '##86', 'he', 'need', 'me', 'to', 'eat', 'his', 'dick', 'because', 'penis', 'dick', 'it', 's', 'my', 'skill', 'sl', '##ut', 'ass', 'dick', 'cock', 'jail', '##bai', '##t', 'bbc', 'gang', '##bang', 'cu', '##cko', '##ld']
#
#
# Sentencia original:
# ['rt' 'tia' '##po' '##gai' '##51' 'please' 'sleep' 'i' 'will' 'do' 'it'
#  'for' 'you' 'guy' 'gt' 'register' 'note' 'verify' 'email' 'to' 'send'
#  'ms' '##g' 'to' 'girls' 'sl' '##ut']
# Sentencia final: 3
# ['rt', 'tia', '##po', '##gai', '##51', 'childish', 'sleep', 'i', 'will', 'do', 'it', 'for', 'you', 'guy', 'gt', 'register', 'note', 'verify', 'email', 'to', 'send', 'ms', '##g', 'to', 'girls', 'sl', '##ut']
#
#
# Sentencia original:
# ['rt' 'ns' '##f' '##w' 'bitch' 'imagine' 'your' 'cute' 'little' 'sub' 'on'
#  'their' 'knees' 'sucking' 'your' 'cock' 'softly' 'they' 'bat' 'their'
#  'eyes' 'and' 'stop' 'sucking' 'you' 'grab' 'the' '##i']
# Sentencia final: 3
# ['bt', 'ns', '##f', '##w', 'bitch', 'imagine', 'your', 'cute', 'little', 'sub', 'on', 'their', 'knees', 'sucking', 'your', 'cock', 'softly', 'they', 'bat', 'their', 'eyes', 'and', 'stop', 'sucking', 'you', 'grab', 'the', '##i']
# # terms modificados promedio 2.0630213160333644 términos por sentencia
# Largo de sentencia promedio 24.790546802594996 términos por sentencia
# para esta ejecución se debiesen reemplazar 2552  de 16969 terminos
# Resumen de modificaciones: {'NN': 1688, 'NNS': 110, 'VBD': 21, 'VB': 66, 'VBG': 76, 'VBZ': 52, 'JJ': 159, 'JJS': 4, 'VBN': 38, 'VBP': 12}
# Este proceso tomó 17.49295735359192 seg
#
#
# Generando 0 nuevos ejemplos para la clase NonH
# Consultando por la clase NonH
# Entrega label 0
# No se generan ejemplos
# Resumen de modificaciones: {}
# Este proceso tomó 0.43026041984558105 seg
#
#
# Generando 3585 nuevos ejemplos para la clase PhysicalH
# Consultando por la clase PhysicalH
# Entrega label 2
# Sentencia original:
# ['deep' '##th' '##ro' '##at' 'cum' '##shot' 'perfect' 'boo' '##bs'
#  'jewish' 'indian' 'pussy' 'naked' 'lesbian' 'japanese' 'beau' '##t' 'x'
#  '##8' '##9' 't' 'co' 'g' '##f' '##w' '##x' '##st' '##n' '##2' '##fk']
# Sentencia final: 2
# ['deep', '##th', '##ro', '##at', 'cum', '##shot', 'perfect', 'boo', '##bs', 'jewish', 'indian', 'pussy', 'islamic', 'lesbian', 'japanese', 'beau', '##t', 'x', '##8', '##9', 't', 'co', 're', '##f', '##w', '##x', '##st', '##n', '##2', '##fk']
#
#
# Sentencia original:
# ['rt' 'debbie' '##d' '##7' '##47' '##9' '##9' '##11' '##8' 'steve' '##d'
#  '##48' '##48' 'how' 'dare' 'she' 'honest' 'people' 'and' 'children'
#  'were' 'killed' 'in' 'manchester' 'and' 'this' 'sc' '##um' 'says' 'that'
#  's' 'fair' 're' '##tal' '##i']
# Sentencia final: 2
# ['rt', 'debbie', '##d', '##7', '##47', '##9', '##9', '##11', '##8', 'steve', '##d', '##48', '##48', 'how', 'dare', 'she', 'honest', 'people', 'and', 'children', 'were', 'tortured', 'in', 'manchester', 'and', 'this', 'sc', '##um', 'is', 'that', 's', 'fair', 'ma', '##tal', '##i']
#
#
# Sentencia original:
# ['pr' '##ae' '##tors' '##uit' 'which' 'specifically' 'i' 'x' '##8' '##9'
#  'd' 'personally' 'pitch' 'black' 'world' 'devil' 'there' 'rap' '##ist'
#  'an' 'x' '##8' '##9' 't' 'co' 'bu' '##rg' '##t' '##j' '##fr' '##ya']
# Sentencia final: 2
# ['pr', '##ae', '##tors', '##uit', 'which', 'specifically', 'i', 'x', '##8', '##9', 'd', 'personally', 'pitch', 'black', 'world', 'devil', 'there', 'rap', '##ist', 'an', 'x', '##8', '##9', 'rt', 'co', 'rt', '##rg', '##t', '##j', '##fr', '##ya']
#
#
# Sentencia original:
# ['sas' '##sy' 'wants' 'signing' 'first' 'prepare' 'good' 'don' 't' 'know'
#  'x' '##8' '##9' 't' 'co' 'qi' '##q' '##gi' '##b' '##17' '##ik']
# Sentencia final: 2
# ['sas', '##sy', 'wants', 'signing', 'first', 'destroy', 'good', 'don', 't', 'know', 'x', '##8', '##9', 't', 'co', 'qi', '##q', '##gi', '##b', '##17', '##ik']
#
#
# Sentencia original:
# ['bb' '##adi' '##cal' '##i' 'sarcastic' '##fe' '##m' '##23' 'ms' '##vani'
#  '##llar' '##ose' 'facebook' 'habit' '##ually' 'hara' '##ss' 'calling'
#  'addicted' 'drug' '##gy' 'hooker' 'for' 'x' '##8' '##9']
# Sentencia final: 2
# ['bb', '##adi', '##cal', '##i', 'sarcastic', '##fe', '##m', '##23', 'ms', '##vani', '##llar', '##ose', 'facebook', 'habit', '##ually', 'hara', '##ss', 'calling', 'addicted', 'drug', '##gy', 'hooker', 'for', 'minor', '##8', '##9']
#
#
# Sentencia original:
# ['the' 'woman' 'brutally' 'tortured' 'minor' 'servant' 'starved' 'major'
#  'am' '##mara' 'm' 'x' '##8' '##9' 't' 'co' 'y' '##j' '##9' '##6' '##d'
#  '##2' '##x' '##gr' '##p']
# Sentencia final: 2
# ['the', 'woman', 'brutally', 'starved', 'minor', 'servant', 'starved', 'major', 'am', '##mara', 'm', 'x', '##8', '##9', 't', 're', 'rt', '##j', '##9', '##6', '##d', '##2', '##x', '##gr', '##p']
#
#
# Sentencia original:
# ['p' '##0' '##rn' '##sf' '##w' 'daddy' 'behave' 'baby' 'daddy' 'tight'
#  'open' 'yeah' 'little' 'x' '##8' '##9']
# Sentencia final: 2
# ['p', '##0', '##rn', '##sf', '##w', 'daddy', 'behave', 'juicy', 'daddy', 'tight', 'open', 'yeah', 'little', 'x', '##8', '##9']
#
#
# Sentencia original:
# ['what' 'i' 'don' 't' 'get' 'is' 'how' 'y' 'all' 'try' 'to' 'drag' 'becky'
#  'for' 'body' 'shame' 'charlotte' 'when' 'she' 'didn' 't' 'but' 'laugh'
#  'at' 'a' 'fan' 'th']
# Sentencia final: 2
# ['what', 'i', 'don', 't', 'get', 'is', 'how', 'y', 'all', 'try', 'to', 'look', 'becky', 'for', 'body', 'jewish', 'charlotte', 'when', 'she', 'didn', 't', 'but', 'laugh', 'at', 'a', 'fan', 'th']
#
#
# Sentencia original:
# ['ne' '##h' '##22' '##3' 'ni' '##gga' 'getting' 'chopped' 'whole' 'dream'
#  'shit']
# Sentencia final: 2
# ['ne', '##h', '##22', '##3', 'ni', '##gga', 'discussing', 'chopped', 'whole', 'dream', 'shit']
#
#
# # terms modificados promedio 2.0641562064156207 términos por sentencia
# Largo de sentencia promedio 24.737517433751744 términos por sentencia
# para esta ejecución se debiesen reemplazar 8125  de 54262 terminos
# Resumen de modificaciones: {'JJ': 366, 'NN': 5502, 'VBN': 126, 'VBZ': 205, 'VBG': 265, 'NNS': 355, 'VB': 357, 'VBD': 163, 'JJS': 23, 'VBP': 38}
# Este proceso tomó 39.501879930496216 seg
#
#
# Generando 3606 nuevos ejemplos para la clase IndirectH
# Consultando por la clase IndirectH
# Entrega label 1
# Sentencia original:
# ['the' 'people' 'that' 'work' 'in' 'the' 'dining' 'hall' 'are' 'all'
#  'sitting' 'here' 'talking' 'shit' 'about' 'this' 'girl' 'that' 'came'
#  'in' 'first' 'thing']
# Sentencia final: 1
# ['the', 'people', 'that', 'work', 'in', 'the', 'dining', 'hall', 'are', 'all', 'sitting', 'here', 'talking', 'shit', 'about', 'this', 'girl', 'that', 'was', 'in', 'first', 'thing']
#
#
# Sentencia original:
# ['i' 'will' 'never' 'understand' 'how' 'girls' 'can' 'sl' '##ut' 'shame'
#  'other' 'girls' 'for' 'having' 'male' 'friends']
# Sentencia final: 1
# ['time', 'will', 'never', 'girl', 'how', 'girls', 'can', 'sl', '##ut', 'shame', 'other', 'girls', 'for', 'having', 'male', 'friends']
#
#
# Sentencia original:
# ['shy' '##ler' '##lit' '##tle' '##e' 'honestly' 'can' 'x' '##8' '##9' 't'
#  'relate' 'girls' 'shame' 'different' 'every' 'weekend' 'fuck' '##in'
#  'number' 'x' '##8' '##9']
# Sentencia final: 1
# ['shy', '##ler', '##lit', '##tle', '##e', 'honestly', 'can', 'confirm', '##8', '##9', 't', 'faulty', 'boys', 'shame', 'different', 'every', 'weekend', 'fuck', '##in', 'number', 'x', '##8', '##9']
#
#
# Sentencia original:
# ['baku' '##bro' '##ws' 'freaked' '##by' '##du' '##bu' '##l' '##g' 'sara'
#  '##ot' '##5' 'how' 'can' 'u' 'go' 'from' 'wonder' 'girls' 'and' 'miss'
#  'a' 'to' 'twice' 'and' 'these' 'ladies' 'l' '##m' '##fa' '##o' 'i' 'can'
#  't']
# Sentencia final: 1
# ['baku', '##bro', '##ws', 'freaked', '##by', '##du', '##bu', '##l', '##g', 'leftist', '##ot', '##5', 'how', 'can', 'u', 'go', 'from', 'wonder', 'girls', 'and', 'miss', 'a', 'to', 'twice', 'and', 'these', 'ladies', 'l', '##m', '##fa', '##o', 'time', 'can', 't']
#
#
# Sentencia original:
# ['rt' 'maxi' '##pen' '##al' '##ty' 'when' 'will' 'the' 'phenomenon' 'of'
#  'white' 'women' 'with' 'no' 'personality' 'who' 'can' 't' 'do'
#  'literally' 'anything' 'without' 'wine' 'just' 'fucking' 'die']
# Sentencia final: 1
# ['rt', 'maxi', '##pen', '##al', '##ty', 'when', 'will', 'the', 'phenomenon', 'of', 'white', 'women', 'with', 'no', 'personality', 'who', 'can', 'work', 'do', 'literally', 'anything', 'without', 'feminism', 'just', 'fucking', 'die']
#
#
# Sentencia original:
# ['dj' 'nine' '##r' 'fundamental' '##s' '##34' '##5' 'she' 'shouldn' 't'
#  'even' 'be' 'where' 'she' 'is' 'that' 's' 'fucking' 'dumb' 'as' 'hell'
#  'she' 'has' 'got' 'to' 'grow' 'up']
# Sentencia final: 1
# ['dj', 'nine', '##r', 'fundamental', '##s', '##34', '##5', 'she', 'shouldn', 't', 'even', 'be', 'where', 'she', 'is', 'that', 's', 'smashing', 'crazy', 'as', 'hell', 'she', 'has', 'got', 'to', 'grown', 'up']
#
#
# Sentencia original:
# ['ava' 'has' 'the' 'sniff' '##les' 'and' 'a' 'cough' 'amp' 'she' 's'
#  'just' 'wants' 'to' 'be' 'cu' '##ddled' 'i' 'm' 'sad' 'she' 's' 'feeling'
#  'blah' 'but' 'i' 'love' 'being' 'her' 'comfort']
# Sentencia final: 1
# ['ava', 'wants', 'the', 'sniff', '##les', 'and', 'a', 'cough', 'amp', 'she', 's', 'just', 'wants', 'to', 'identify', 'cu', '##ddled', 'i', 've', 'sad', 'she', 's', 'feeling', 'blah', 'but', 'i', 'love', 'being', 'her', 'comfort']
#
#
# Sentencia original:
# ['u' '##gh' 'i' 'fucking' 'hate' 'ava' 'doesn' 't' 'she' 'see' 'that'
#  'cheryl' 'drives' 'easton' 'crazy']
# Sentencia final: 1
# ['co', '##gh', 'i', 'smashing', 'hate', 'ava', 'doesn', 't', 'she', 'do', 'that', 'cheryl', 'drives', 'faulty', 'crazy']
#
#
# Sentencia original:
# ['dr' '##sa' '##q' '##lain' '##sh' 'bitch' 'brutally' 'tortured' 'minor'
#  'servant' 'starved' 'major' 'am' '##mara' 'media' 'is' 'x' '##8' '##9']
# Sentencia final: 1
# ['dr', '##sa', '##q', '##lain', '##sh', 'bitch', 'brutally', 'tortured', 'minor', 'slave', 'starved', 'major', 'am', '##mara', 'media', 'is', 'x', '##8', '##9']
# # terms modificados promedio 1.9434276206322796 términos por sentencia
# Largo de sentencia promedio 23.887687188019967 términos por sentencia
# para esta ejecución se debiesen reemplazar 7651  de 51150 terminos
# Resumen de modificaciones: {'VBD': 137, 'NN': 5015, 'NNS': 500, 'VBG': 261, 'VBZ': 236, 'VB': 230, 'JJ': 399, 'VBN': 213, 'VBP': 17}
# Este proceso tomó 37.78477191925049 seg
#
# --------------------------------------------------------
#
# Generando ejemplos en base a probabilidad -->  0.15
# --------------------------------------------------------
#
#
# Generando 1079 nuevos ejemplos para la clase SexualH
# Consultando por la clase SexualH
# Entrega label 3
# Sentencia original:
# ['pic' 'mexican' 'school' 'girl' 'naked' 'melanie' 'sa' '##fk' '##a'
#  'fake' 'nude' 'photos' 'hardcore' 'sl' '##ut' 'movies' 'alicia' 'moore'
#  'porn' 'star' 'too' '##n' 'love']
# Sentencia final: 3
# ['college', 'mexican', 'school', 'silvia', 'naked', 'melanie', 'sa', '##fk', '##a', 'fake', 'nude', 'photos', 'hardcore', 'sl', '##ut', 'stevens', 'alicia', 'moore', 'porn', 'cleavage', 'too', '##n', 'love']
#
#
# Sentencia original:
# ['girl' 'dirty' 'quarterback' 'latino' 'pokemon' 'young' 'hand' '##jo'
#  '##b' 'kissing' 'gang' '##bang' 'w' 'x' '##8' '##9' 't' 'co' 'wr' '##m'
#  '##4' '##x' '##o' '##00' '##v' '##j']
# Sentencia final: 3
# ['girl', 'boy', 'quarterback', 'latino', 'pokemon', 'young', 'hand', '##jo', '##b', 'menacing', 'gang', '##bang', 'w', 'x', '##8', '##9', 't', 'co', 'wr', '##m', '##4', '##x', '##o', '##00', '##v', '##j']
#
#
# Sentencia original:
# ['mil' '##ion' '##do' '##lla' '##me' '##at' 'sex' '##ting' 'n' 'ng' '##ir'
#  '##l' 'daddy' 'n' 'nme' 'listen' 'bitch' 'gonna' 'watch' 'these' 'what']
# Sentencia final: 3
# ['peyton', '##ion', '##do', '##lla', '##me', '##at', 'sex', '##ting', 'n', 'ng', '##ir', '##l', 'daddy', 'n', 'asshole', 'listen', 'bitch', 'gonna', 'watch', 'these', 'what']
#
#
# Sentencia original:
# ['museum' 'sl' '##ut' 'if' 'you' 'know' 'somewhere' 'we' 'can' 'do' 'it'
#  'then' 'i' 'am' 'game']
# Sentencia final: 3
# ['museum', 'sl', '##ut', 'if', 'you', 'know', 'somewhere', 'we', 'can', 'happen', 'it', 'then', 'i', 'am', 'game']
#
#
# Sentencia original:
# ['venus' 'astro' '##logy' 'living' 'standards' 'ni' '##t' 'x' '##8' '##9'
#  's' 'illusion' 'i' 'x' '##8' '##9' 'm' 'fucking' 'nwa' '##iting'
#  'waiting' 'wai' 'x' '##8' '##9']
# Sentencia final: 3
# ['venus', 'astro', '##logy', 'standard', 'standards', 'ni', '##t', 'x', '##8', '##9', 'pinto', 'illusion', 'i', 'x', '##8', '##9', 'm', 'fucking', 'nwa', '##iting', 'waiting', 'wai', 'x', '##8', '##9']
#
#
# Sentencia original:
# ['add' 'me' 'on' 'snap' '##cha' '##t' 'and' 'watch' 'me' 'cum' 'colt'
#  '##oe' '##8' 'send' '##nu' '##des' 'nude' 'nude' 'snap' '##cha' '##t'
#  'girls' 'boo' '##bs' 'pussy' 'horn' '##y']
# Sentencia final: 3
# ['add', 'me', 'on', 'dammit', '##cha', '##t', 'and', 'watch', 'me', 'cum', 'colt', '##oe', '##8', 'send', '##nu', '##des', 'nude', 'nude', 'disgrace', '##cha', '##t', 'cooks', 'girl', '##bs', 'pussy', 'horn', '##y']
#
#
# Sentencia original:
# ['rt' 'ole' '##sm' '##eh' '##a' '##86' 'he' 'need' 'me' 'to' 'eat' 'his'
#  'dick' 'because' 'eat' 'dick' 'it' 's' 'my' 'skill' 'sl' '##ut' 'ass'
#  'dick' 'cock' 'jail' '##bai' '##t' 'bbc' 'gang' '##bang' 'cu' '##cko'
#  '##ld']
# Sentencia final: 3
# ['rt', 'ole', '##sm', '##eh', '##a', '##86', 'he', 'need', 'me', 'to', 'eat', 'his', 'dick', 'because', 'eat', 'dick', 'it', 's', 'my', 'skill', 'sl', '##ut', 'ass', 'asshole', 'penis', 'jail', '##bai', '##t', 'bbc', 'gang', '##bang', 'cu', '##cko', '##ld']
#
#
# Sentencia original:
# ['rt' 'tia' '##po' '##gai' '##51' 'please' 'sleep' 'i' 'will' 'do' 'it'
#  'for' 'you' 'guy' 'gt' 'register' 'note' 'verify' 'email' 'to' 'send'
#  'ms' '##g' 'to' 'girls' 'sl' '##ut']
# Sentencia final: 3
# ['rt', 'tia', '##po', '##gai', '##51', 'please', 'sleep', 'slept', 'will', 'do', 'it', 'for', 'you', 'guy', 'gt', 'register', 'note', 'jogging', 'email', 'to', 'send', 'ms', '##g', 'to', 'girls', 'girl', '##ut']
#
#
# Sentencia original:
# ['rt' 'ns' '##f' '##w' 'bitch' 'imagine' 'your' 'cute' 'little' 'sub' 'on'
#  'their' 'knees' 'sucking' 'your' 'cock' 'softly' 'they' 'bat' 'their'
#  'eyes' 'and' 'stop' 'sucking' 'you' 'grab' 'the' '##i']
# Sentencia final: 3
# ['rt', 'ns', '##f', '##w', 'bitch', 'imagine', 'your', 'cute', 'little', 'sub', 'on', 'their', 'fangs', 'sucking', 'your', 'cock', 'softly', 'they', 'bat', 'their', 'eyes', 'and', 'stop', 'sucking', 'you', 'grab', 'the', '##i']
#
#
# # terms modificados promedio 2.0806302131603336 términos por sentencia
# Largo de sentencia promedio 24.978683966635774 términos por sentencia
# para esta ejecución se debiesen reemplazar 2587  de 16829 terminos
# Resumen de modificaciones: {'NN': 1720, 'NNS': 123, 'VBG': 70, 'VB': 75, 'VBD': 27, 'JJ': 131, 'VBZ': 45, 'VBN': 39, 'JJS': 7, 'VBP': 7, 'JJR': 1}
# Este proceso tomó 17.527783632278442 seg
#
#
# Generando 0 nuevos ejemplos para la clase NonH
# Consultando por la clase NonH
# Entrega label 0
# No se generan ejemplos
# Resumen de modificaciones: {}
# Este proceso tomó 0.43370747566223145 seg
#
#
# Generando 3585 nuevos ejemplos para la clase PhysicalH
# Consultando por la clase PhysicalH
# Entrega label 2
# Sentencia original:
# ['deep' '##th' '##ro' '##at' 'cum' '##shot' 'perfect' 'boo' '##bs'
#  'jewish' 'indian' 'pussy' 'naked' 'lesbian' 'japanese' 'beau' '##t' 'x'
#  '##8' '##9' 't' 'co' 'g' '##f' '##w' '##x' '##st' '##n' '##2' '##fk']
# Sentencia final: 2
# ['time', '##th', '##ro', '##at', 'cum', '##shot', 'perfect', 'boo', '##bs', 'jewish', 'indian', 'pussy', 'naked', 'lesbian', 'japanese', 'racist', '##t', 'x', '##8', '##9', 'strict', 'co', 'g', '##f', '##w', '##x', '##st', '##n', '##2', '##fk']
#
#
# Sentencia original:
# ['rt' 'debbie' '##d' '##7' '##47' '##9' '##9' '##11' '##8' 'steve' '##d'
#  '##48' '##48' 'how' 'dare' 'she' 'honest' 'people' 'and' 'children'
#  'were' 'killed' 'in' 'manchester' 'and' 'this' 'sc' '##um' 'says' 'that'
#  's' 'fair' 're' '##tal' '##i']
# Sentencia final: 2
# ['rt', 'debbie', '##d', '##7', '##47', '##9', '##9', '##11', '##8', 'steve', '##d', '##48', '##48', 'how', 'dare', 'she', 'honest', 'people', 'and', 'children', 'were', 'killed', 'in', 'manchester', 'and', 'this', 'sc', '##um', 'says', 'that', 'day', 'fair', 're', '##tal', '##i']
#
#
# Sentencia original:
# ['hot' 'british' 'sl' '##ut' 'cr' '##iss' '##y' 'will' 'give' 'you' 'a'
#  'wet' 'dream' 'when' 'she' 'rubs' 'on' 'her' 'pussy' 'cam' '##girl']
# Sentencia final: 2
# ['hot', 'british', 'sl', '##ut', 'cr', '##iss', '##y', 'will', 'give', 'you', 'a', 'wet', 'dream', 'when', 'she', 'rubs', 'on', 'her', 'pussy', 'girl', '##girl']
#
#
# Sentencia original:
# ['the' 'woman' 'brutally' 'tortured' 'minor' 'servant' 'starved' 'major'
#  'am' '##mara' 'm' 'x' '##8' '##9' 't' 'co' 'y' '##j' '##9' '##6' '##d'
#  '##2' '##x' '##gr' '##p']
# Sentencia final: 2
# ['the', 'woman', 'brutally', 'tortured', 'minor', 'servant', 'starved', 'major', 'am', '##mara', 'rt', 'x', '##8', '##9', 't', 'co', 'y', '##j', '##9', '##6', '##d', '##2', '##x', '##gr', '##p']
#
#
# Sentencia original:
# ['p' '##0' '##rn' '##sf' '##w' 'daddy' 'behave' 'baby' 'daddy' 'tight'
#  'open' 'yeah' 'little' 'x' '##8' '##9']
# Sentencia final: 2
# ['p', '##0', '##rn', '##sf', '##w', 'daddy', 'behave', 'baby', 'gonna', 'tight', 'open', 'yeah', 'little', 'x', '##8', '##9']
#
#
# Sentencia original:
# ['what' 'i' 'don' 't' 'get' 'is' 'how' 'y' 'all' 'try' 'to' 'drag' 'becky'
#  'for' 'body' 'shame' 'charlotte' 'when' 'she' 'didn' 't' 'but' 'laugh'
#  'at' 'a' 'fan' 'th']
# Sentencia final: 2
# ['what', 'i', 'don', 're', 'get', 'is', 'how', 'y', 'all', 'try', 'to', 'drag', 'becky', 'for', 'jax', 'shame', 'charlotte', 'when', 'she', 'didn', 't', 'but', 'laugh', 'at', 'a', 'fan', 'way']
#
#
# Sentencia original:
# ['x' 'wilde' '##st' '##dre' '##ams' 'really' 'being' 'sas' '##sy'
#  'twitter' 't' 'co' 'bt' '##bl' '##sz' '##x' '##b' '##w' '##0']
# Sentencia final: 2
# ['x', 'wilde', '##st', '##dre', '##ams', 'really', 'disgusting', 'sas', '##sy', 'twitter', 't', 'facebook', 'bt', '##bl', '##sz', '##x', '##b', '##w', '##0']
#
#
# Sentencia original:
# ['heaven' '##bra' '##t' 'really' 'really' 'bitch' 'bullshit' 'n' '##2'
#  'much' 'x' '##8' '##9']
# Sentencia final: 2
# ['heaven', '##bra', '##t', 'really', 'really', 'bitch', 'bullshit', 'n', '##2', 'much', 'world', '##8', '##9']
#
#
# Sentencia original:
# ['never' 'getting' 'james' 'constantly' 'fat' 'shame' 'and' 'sl' '##ut'
#  'shame' 'girls' 'at' 'least' 'jax' 'just' 'fuck' 'over' 'his' 'partners'
#  'james']
# Sentencia final: 2
# ['never', 'being', 'james', 'constantly', 'cute', 'shame', 'and', 'anwar', '##ut', 'shame', 'girls', 'at', 'least', 'jax', 'just', 'fuck', 'over', 'his', 'partners', 'james']
# # terms modificados promedio 2.0853556485355647 términos por sentencia
# Largo de sentencia promedio 24.69205020920502 términos por sentencia
# para esta ejecución se debiesen reemplazar 8223  de 54436 terminos
# Resumen de modificaciones: {'NN': 5574, 'VBG': 281, 'VBN': 149, 'JJ': 370, 'VBP': 46, 'VBD': 162, 'VB': 357, 'NNS': 333, 'VBZ': 181, 'JJS': 23}
# Este proceso tomó 39.93988656997681 seg
#
#
# Generando 3606 nuevos ejemplos para la clase IndirectH
# Consultando por la clase IndirectH
# Entrega label 1
# Sentencia original:
# ['the' 'people' 'that' 'work' 'in' 'the' 'dining' 'hall' 'are' 'all'
#  'sitting' 'here' 'talking' 'shit' 'about' 'this' 'girl' 'that' 'came'
#  'in' 'first' 'thing']
# Sentencia final: 1
# ['the', 'people', 'that', 'work', 'in', 'the', 'dining', 'hall', 'are', 'all', 'sitting', 'here', 'talking', 'shit', 'about', 'this', 'woman', 'that', 'came', 'in', 'first', 'thing']
#
#
# Sentencia original:
# ['shy' '##ler' '##lit' '##tle' '##e' 'honestly' 'can' 'x' '##8' '##9' 't'
#  'relate' 'girls' 'shame' 'different' 'every' 'weekend' 'fuck' '##in'
#  'number' 'x' '##8' '##9']
# Sentencia final: 1
# ['shy', '##ler', '##lit', '##tle', '##e', 'honestly', 'can', 'x', '##8', '##9', 't', 'relate', 'girls', 'shame', 'different', 'every', 'weekend', 'fuck', '##in', 'number', 'faulty', '##8', '##9']
#
#
# Sentencia original:
# ['baku' '##bro' '##ws' 'freaked' '##by' '##du' '##bu' '##l' '##g' 'sara'
#  '##ot' '##5' 'how' 'can' 'u' 'go' 'from' 'wonder' 'girls' 'and' 'miss'
#  'a' 'to' 'twice' 'and' 'these' 'ladies' 'l' '##m' '##fa' '##o' 'i' 'can'
#  't']
# Sentencia final: 1
# ['baku', '##bro', '##ws', 'freaked', '##by', '##du', '##bu', '##l', '##g', 'sara', '##ot', '##5', 'how', 'can', 'time', 'be', 'from', 'wonder', 'women', 'and', 'miss', 'a', 'to', 'twice', 'and', 'these', 'times', 'l', '##m', '##fa', '##o', 'i', 'can', 't']
#
#
# Sentencia original:
# ['just' 'inn' '##7' 'kai' '##tma' '##rie' '##ox' 'sl' '##ut' 'arm' '##pit'
#  '##s' 'hairy' 'surely' 'don' 't' 'feminist' 'so' 'x' '##8' '##9' 't' 'co'
#  'ca' '##y' '##z' '##13' '##cu' '##3' '##e']
# Sentencia final: 1
# ['just', 'inn', '##7', 'kai', '##tma', '##rie', '##ox', 'sl', '##ut', 'arm', '##pit', '##s', 'hairy', 'surely', 'don', 'didn', 'feminist', 'so', 'x', '##8', '##9', 'rt', 'co', 'ca', '##y', '##z', '##13', '##cu', '##3', '##e']
#
#
# Sentencia original:
# ['number' 't' 'you' 'should' 'do' 'to' 'him' 'all' 'by' 'now' 'you' 'will'
#  'need' 'to' 'make' 'him' 'a' 'few' 'times' 'until' 'she' 'is' 'ready'
#  'and' 'he' 'just' 'lets' 'h']
# Sentencia final: 1
# ['number', 't', 'you', 'should', 'do', 'to', 'him', 'all', 'by', 'now', 'you', 'will', 'need', 'to', 'have', 'him', 'a', 'few', 'times', 'until', 'she', 'is', 'ready', 'and', 'he', 'just', 'feels', 'h']
#
#
# Sentencia original:
# ['mrs' 'hc' '##m' 'tr' '##ad' '##po' '##aster' '##100' '##0' 'also'
#  'though' 'if' 'eggs' 'are' 'the' 'resource' 'guys' 'are' 'after' 'vs' 'a'
#  'good' 'and' 'vi' '##rt' '##uous' 'wife' 'who' 'will']
# Sentencia final: 1
# ['ms', 'hc', '##m', 'tr', '##ad', '##po', '##aster', '##100', '##0', 'also', 'though', 'if', 'eggs', 'are', 'the', 'want', 'guys', 'are', 'after', 'vs', 'a', 'good', 'and', 'vi', '##rt', '##uous', 'wife', 'who', 'will']
#
#
# Sentencia original:
# ['rt' 'maxi' '##pen' '##al' '##ty' 'when' 'will' 'the' 'phenomenon' 'of'
#  'white' 'women' 'with' 'no' 'personality' 'who' 'can' 't' 'do'
#  'literally' 'anything' 'without' 'wine' 'just' 'fucking' 'die']
# Sentencia final: 1
# ['rt', 'maxi', '##pen', '##al', '##ty', 'when', 'will', 'the', 'phenomenon', 'of', 'white', 'women', 'with', 'no', 'personality', 'who', 'can', 't', 'do', 'literally', 'anything', 'without', 'wine', 'just', 'enjoying', 'die']
#
#
# Sentencia original:
# ['ava' 'has' 'the' 'sniff' '##les' 'and' 'a' 'cough' 'amp' 'she' 's'
#  'just' 'wants' 'to' 'be' 'cu' '##ddled' 'i' 'm' 'sad' 'she' 's' 'feeling'
#  'blah' 'but' 'i' 'love' 'being' 'her' 'comfort']
# Sentencia final: 1
# ['ava', 'has', 'the', 'sniff', '##les', 'and', 'a', 'cough', 'amp', 'she', 's', 'just', 'is', 'to', 'be', 've', '##ddled', 'i', 'mrs', 'sad', 'she', 's', 'feeling', 'blah', 'but', 'i', 'love', 'being', 'her', 'comfort']
#
#
# Sentencia original:
# ['u' '##gh' 'i' 'fucking' 'hate' 'ava' 'doesn' 't' 'she' 'see' 'that'
#  'cheryl' 'drives' 'easton' 'crazy']
# Sentencia final: 1
# ['u', '##gh', 'i', 'smashing', 'hate', 'leftist', 'doesn', 't', 'she', 'know', 'that', 'cheryl', 'drives', 'faulty', 'crazy']
#
#
# # terms modificados promedio 1.973655019412091 términos por sentencia
# Largo de sentencia promedio 23.820576816417084 términos por sentencia
# para esta ejecución se debiesen reemplazar 7784  de 52259 terminos
# Resumen de modificaciones: {'NN': 4996, 'VB': 248, 'NNS': 525, 'VBG': 311, 'VBZ': 235, 'VBP': 14, 'JJ': 407, 'VBD': 136, 'VBN': 245}
# Este proceso tomó 38.52349328994751 seg
#
# --------------------------------------------------------
#
# Generando ejemplos en base a probabilidad -->  0.15
# --------------------------------------------------------
#
#
# Generando 1079 nuevos ejemplos para la clase SexualH
# Consultando por la clase SexualH
# Entrega label 3
# Sentencia original:
# ['pic' 'mexican' 'school' 'girl' 'naked' 'melanie' 'sa' '##fk' '##a'
#  'fake' 'nude' 'photos' 'hardcore' 'sl' '##ut' 'movies' 'alicia' 'moore'
#  'porn' 'star' 'too' '##n' 'love']
# Sentencia final: 3
# ['pic', 'mexican', 'silvia', 'girl', 'naked', 'melanie', 'sa', '##fk', '##a', 'photo', 'nude', 'photos', 'hardcore', 'sl', '##ut', 'movies', 'alicia', 'moore', 'porn', 'star', 'too', '##n', 'love']
#
#
# Sentencia original:
# ['girl' 'dirty' 'quarterback' 'latino' 'pokemon' 'young' 'hand' '##jo'
#  '##b' 'kissing' 'gang' '##bang' 'w' 'x' '##8' '##9' 't' 'co' 'wr' '##m'
#  '##4' '##x' '##o' '##00' '##v' '##j']
# Sentencia final: 3
# ['girl', 'dirty', 'quarterback', 'latino', 'pokemon', 'young', 'hand', '##jo', '##b', 'embracing', 'gang', '##bang', 'wc', 'x', '##8', '##9', 't', 'co', 'wr', '##m', '##4', '##x', '##o', '##00', '##v', '##j']
#
#
# Sentencia original:
# ['mil' '##ion' '##do' '##lla' '##me' '##at' 'sex' '##ting' 'n' 'ng' '##ir'
#  '##l' 'daddy' 'n' 'nme' 'listen' 'bitch' 'gonna' 'watch' 'these' 'what']
# Sentencia final: 3
# ['mil', '##ion', '##do', '##lla', '##me', '##at', 'sex', '##ting', 'nme', 'ng', '##ir', '##l', 'rn', 'n', 'nme', 'listen', 'bitch', 'gonna', 'watch', 'these', 'what']
#
#
# Sentencia original:
# ['rt' 'sp' '##00' '##ky' '##bit' '##ch' '##hh' '##h' 'i' 'have' 'spots'
#  'open' 'sis' '##sy' 'sl' '##ut' 'into' '##x' 'bitch' 'human' 'atm'
#  'amazon' 'boy' 'do' 'you' 'have' 'what' 'it' 'takes' 'can' 'you' 'live'
#  'up' 'to' 'my']
# Sentencia final: 3
# ['rt', 'sp', '##00', '##ky', '##bit', '##ch', '##hh', '##h', 'place', 'have', 'spots', 'open', 'sis', '##sy', 'sum', '##ut', 'into', '##x', 'bitch', 'human', 'atm', 'amazon', 'boy', 'do', 'you', 'make', 'what', 'it', 'takes', 'can', 'you', 'live', 'up', 'to', 'my']
#
#
# Sentencia original:
# ['venus' 'astro' '##logy' 'living' 'standards' 'ni' '##t' 'x' '##8' '##9'
#  's' 'illusion' 'i' 'x' '##8' '##9' 'm' 'fucking' 'nwa' '##iting'
#  'waiting' 'wai' 'x' '##8' '##9']
# Sentencia final: 3
# ['venus', 'astro', '##logy', 'living', 'standards', 'ni', '##t', 'pinto', '##8', '##9', 'dino', 'illusion', 'i', 'x', '##8', '##9', 'm', 'fucking', 'nwa', '##iting', 'waiting', 'wai', 'x', '##8', '##9']
#
#
# Sentencia original:
# ['add' 'me' 'on' 'snap' '##cha' '##t' 'and' 'watch' 'me' 'cum' 'colt'
#  '##oe' '##8' 'send' '##nu' '##des' 'nude' 'nude' 'snap' '##cha' '##t'
#  'girls' 'boo' '##bs' 'pussy' 'horn' '##y']
# Sentencia final: 3
# ['add', 'me', 'on', 'snap', '##cha', '##t', 'and', 'watch', 'me', 'cum', 'colt', '##oe', '##8', 'send', '##nu', '##des', 'nude', 'kemp', 'snap', '##cha', '##t', 'girls', 'boo', '##bs', 'pussy', 'horn', '##y']
#
#
# Sentencia original:
# ['rt' 'ole' '##sm' '##eh' '##a' '##86' 'he' 'need' 'me' 'to' 'eat' 'his'
#  'dick' 'because' 'eat' 'dick' 'it' 's' 'my' 'skill' 'sl' '##ut' 'ass'
#  'dick' 'cock' 'jail' '##bai' '##t' 'bbc' 'gang' '##bang' 'cu' '##cko'
#  '##ld']
# Sentencia final: 3
# ['rt', 'ole', '##sm', '##eh', '##a', '##86', 'he', 'need', 'me', 'to', 'eat', 'his', 'dick', 'because', 'cock', 'dick', 'it', 's', 'my', 'skill', 'sl', '##ut', 'ass', 'dick', 'cock', 'penis', '##bai', '##t', 'bbc', 'gang', '##bang', 'cu', '##cko', '##ld']
#
#
# Sentencia original:
# ['rt' 'tia' '##po' '##gai' '##51' 'please' 'sleep' 'i' 'will' 'do' 'it'
#  'for' 'you' 'guy' 'gt' 'register' 'note' 'verify' 'email' 'to' 'send'
#  'ms' '##g' 'to' 'girls' 'sl' '##ut']
# Sentencia final: 3
# ['rt', 'tia', '##po', '##gai', '##51', 'please', 'sleep', 'slept', 'will', 'do', 'it', 'for', 'you', 'guy', 'gt', 'register', 'note', 'verify', 'ipad', 'to', 'send', 'ms', '##g', 'to', 'girls', 'sl', '##ut']
#
#
# Sentencia original:
# ['rt' 'ns' '##f' '##w' 'bitch' 'imagine' 'your' 'cute' 'little' 'sub' 'on'
#  'their' 'knees' 'sucking' 'your' 'cock' 'softly' 'they' 'bat' 'their'
#  'eyes' 'and' 'stop' 'sucking' 'you' 'grab' 'the' '##i']
# Sentencia final: 3
# ['nt', 'ns', '##f', '##w', 'bitch', 'imagine', 'your', 'cute', 'little', 'sub', 'on', 'their', 'knees', 'coughing', 'your', 'cock', 'softly', 'they', 'bat', 'their', 'eyes', 'and', 'stop', 'sucking', 'you', 'grab', 'the', '##i']
# # terms modificados promedio 2.0695088044485637 términos por sentencia
# Largo de sentencia promedio 25.18813716404078 términos por sentencia
# para esta ejecución se debiesen reemplazar 2537  de 17018 terminos
# Resumen de modificaciones: {'NN': 1728, 'VBG': 69, 'VB': 68, 'NNS': 117, 'JJ': 147, 'VBZ': 29, 'VBD': 21, 'VBN': 38, 'VBP': 12, 'JJS': 4}
# Este proceso tomó 17.59339141845703 seg
#
#
# Generando 0 nuevos ejemplos para la clase NonH
# Consultando por la clase NonH
# Entrega label 0
# No se generan ejemplos
# Resumen de modificaciones: {}
# Este proceso tomó 0.44330382347106934 seg
#
#
# Generando 3585 nuevos ejemplos para la clase PhysicalH
# Consultando por la clase PhysicalH
# Entrega label 2
# Sentencia original:
# ['deep' '##th' '##ro' '##at' 'cum' '##shot' 'perfect' 'boo' '##bs'
#  'jewish' 'indian' 'pussy' 'naked' 'lesbian' 'japanese' 'beau' '##t' 'x'
#  '##8' '##9' 't' 'co' 'g' '##f' '##w' '##x' '##st' '##n' '##2' '##fk']
# Sentencia final: 2
# ['deep', '##th', '##ro', '##at', 'cum', '##shot', 'perfect', 'chopped', '##bs', 'jewish', 'indian', 'pussy', 'naked', 'lesbian', 'japanese', 'beau', '##t', 'x', '##8', '##9', 'se', 'co', 'g', '##f', '##w', '##x', '##st', '##n', '##2', '##fk']
#
#
# Sentencia original:
# ['rt' 'debbie' '##d' '##7' '##47' '##9' '##9' '##11' '##8' 'steve' '##d'
#  '##48' '##48' 'how' 'dare' 'she' 'honest' 'people' 'and' 'children'
#  'were' 'killed' 'in' 'manchester' 'and' 'this' 'sc' '##um' 'says' 'that'
#  's' 'fair' 're' '##tal' '##i']
# Sentencia final: 2
# ['rt', 'debbie', '##d', '##7', '##47', '##9', '##9', '##11', '##8', 'steve', '##d', '##48', '##48', 'how', 'dare', 'she', 'honest', 'women', 'and', 'children', 'were', 'tortured', 'in', 'manchester', 'and', 'this', 'sc', '##um', 'says', 'that', 's', 'fair', 're', '##tal', '##i']
#
#
# Sentencia original:
# ['bb' '##adi' '##cal' '##i' 'sarcastic' '##fe' '##m' '##23' 'ms' '##vani'
#  '##llar' '##ose' 'facebook' 'habit' '##ually' 'hara' '##ss' 'calling'
#  'addicted' 'drug' '##gy' 'hooker' 'for' 'x' '##8' '##9']
# Sentencia final: 2
# ['bb', '##adi', '##cal', '##i', 'sarcastic', '##fe', '##m', '##23', 'anwar', '##vani', '##llar', '##ose', 'facebook', 'habit', '##ually', 'hara', '##ss', 'calling', 'addicted', 'drug', '##gy', 'hooker', 'for', 'x', '##8', '##9']
#
#
# Sentencia original:
# ['hot' 'british' 'sl' '##ut' 'cr' '##iss' '##y' 'will' 'give' 'you' 'a'
#  'wet' 'dream' 'when' 'she' 'rubs' 'on' 'her' 'pussy' 'cam' '##girl']
# Sentencia final: 2
# ['hot', 'british', 'sl', '##ut', 'cr', '##iss', '##y', 'will', 'give', 'you', 'a', 'wet', 'day', 'when', 'she', 'rubs', 'on', 'her', 'pussy', 'cam', '##girl']
#
#
# Sentencia original:
# ['the' 'woman' 'brutally' 'tortured' 'minor' 'servant' 'starved' 'major'
#  'am' '##mara' 'm' 'x' '##8' '##9' 't' 'co' 'y' '##j' '##9' '##6' '##d'
#  '##2' '##x' '##gr' '##p']
# Sentencia final: 2
# ['the', 'way', 'brutally', 'tortured', 'hooker', 'anwar', 'starved', 'major', 'am', '##mara', 'm', 'x', '##8', '##9', 't', 'rt', 'y', '##j', '##9', '##6', '##d', '##2', '##x', '##gr', '##p']
#
#
# Sentencia original:
# ['what' 'i' 'don' 't' 'get' 'is' 'how' 'y' 'all' 'try' 'to' 'drag' 'becky'
#  'for' 'body' 'shame' 'charlotte' 'when' 'she' 'didn' 't' 'but' 'laugh'
#  'at' 'a' 'fan' 'th']
# Sentencia final: 2
# ['what', 'i', 'don', 't', 'get', 'is', 'how', 'y', 'all', 'try', 'to', 'drag', 'becky', 'for', 'body', 'shame', 'charlotte', 'when', 'she', 'didn', 'doesn', 'but', 'laugh', 'at', 'a', 'se', 'way']
#
#
# Sentencia original:
# ['x' 'wilde' '##st' '##dre' '##ams' 'really' 'being' 'sas' '##sy'
#  'twitter' 't' 'co' 'bt' '##bl' '##sz' '##x' '##b' '##w' '##0']
# Sentencia final: 2
# ['x', 'wilde', '##st', '##dre', '##ams', 'really', 'being', 'sas', '##sy', 'twitter', 't', 'facebook', 'bt', '##bl', '##sz', '##x', '##b', '##w', '##0']
#
#
# Sentencia original:
# ['rt' 'k' '##th' '##fu' '##ck' '##z' 'don' 't' 'u' 'love' 'when' 'u' 're'
#  'like' 'this' 'kitten' 'all' 'tied' 'up' 'amp' 'useless' 'ur' 'pretty'
#  'mouth' 'gag' 'and' 'ur' 'ass' 'covered' 'in' 'bruises' 'u' 'look']
# Sentencia final: 2
# ['rt', 'k', '##th', '##fu', '##ck', '##z', 'don', 't', 'u', 'love', 'when', 'u', 're', 'like', 'this', 'kitten', 'all', 'tied', 'up', 'amp', 'useless', 'ur', 'pretty', 'name', 'gag', 'and', 'ur', 'ass', 'covered', 'in', 'bruises', 'u', 'look']
#
#
# Sentencia original:
# ['the' 'bitch' 'brutally' 'tortured' 'minor' 'servant' 'starved' 'major'
#  'am' '##mara' 'm' 'x' '##8' '##9' 't' 'co' 'mg' '##k' '##nu' '##7' '##zz'
#  '##jm']
# Sentencia final: 2
# ['the', 'bitch', 'brutally', 'tortured', 'minor', 'beaten', 'starved', 'major', 'am', '##mara', 'm', 'x', '##8', '##9', 't', 'co', 'mg', '##k', '##nu', '##7', '##zz', '##jm']
#
#
# ...
#
#
# Sentencia original:
# ['love' '##toy' 'ca' 'that' 's' 'a' 'well' 'trained' 'girl']
# Sentencia final: 1
# ['love', '##toy', 'ca', 'that', 's', 'a', 'well', 'tortured', 'girl']
#
#
# Sentencia original:
# ['just' 'inn' '##7' 'kai' '##tma' '##rie' '##ox' 'sl' '##ut' 'arm' '##pit'
#  '##s' 'hairy' 'surely' 'don' 't' 'feminist' 'so' 'x' '##8' '##9' 't' 'co'
#  'ca' '##y' '##z' '##13' '##cu' '##3' '##e']
# Sentencia final: 1
# ['just', 'inn', '##7', 'faulty', '##tma', '##rie', '##ox', 'sl', '##ut', 'arm', '##pit', '##s', 'hairy', 'surely', 'don', 't', 'feminist', 'so', 'x', '##8', '##9', 't', 'co', 'ca', '##y', '##z', '##13', '##cu', '##3', '##e']
#
#
# Sentencia original:
# ['number' 't' 'you' 'should' 'do' 'to' 'him' 'all' 'by' 'now' 'you' 'will'
#  'need' 'to' 'make' 'him' 'a' 'few' 'times' 'until' 'she' 'is' 'ready'
#  'and' 'he' 'just' 'lets' 'h']
# Sentencia final: 1
# ['number', 't', 'you', 'should', 'do', 'to', 'him', 'all', 'by', 'now', 'you', 'will', 'need', 'to', 'make', 'him', 'a', 'other', 'times', 'until', 'she', 'is', 'ready', 'and', 'he', 'just', 'lets', 'h']
#
#
# Sentencia original:
# ['mrs' 'hc' '##m' 'tr' '##ad' '##po' '##aster' '##100' '##0' 'also'
#  'though' 'if' 'eggs' 'are' 'the' 'resource' 'guys' 'are' 'after' 'vs' 'a'
#  'good' 'and' 'vi' '##rt' '##uous' 'wife' 'who' 'will']
# Sentencia final: 1
# ['mrs', 'hc', '##m', 'tr', '##ad', '##po', '##aster', '##100', '##0', 'also', 'though', 'if', 'aren', 'are', 'the', 'resource', 'guys', 'are', 'after', 'vs', 'a', 'good', 'and', 'vi', '##rt', '##uous', 'wife', 'who', 'will']
#
#
# Sentencia original:
# ['rt' 'maxi' '##pen' '##al' '##ty' 'when' 'will' 'the' 'phenomenon' 'of'
#  'white' 'women' 'with' 'no' 'personality' 'who' 'can' 't' 'do'
#  'literally' 'anything' 'without' 'wine' 'just' 'fucking' 'die']
# Sentencia final: 1
# ['rt', 'maxi', '##pen', '##al', '##ty', 'when', 'will', 'the', 'phenomenon', 'of', 'white', 'women', 'with', 'no', 'personality', 'who', 'can', 'asleep', 'do', 'literally', 'anything', 'without', 'wine', 'just', 'fucking', 'die']
# # terms modificados promedio 1.9731003882418192 términos por sentencia
# Largo de sentencia promedio 23.79506378258458 términos por sentencia
# para esta ejecución se debiesen reemplazar 7783  de 51892 terminos
# Resumen de modificaciones: {'NNS': 520, 'VBG': 323, 'NN': 5018, 'JJ': 410, 'VBN': 197, 'VBZ': 223, 'VB': 270, 'VBD': 142, 'VBP': 12}
# Este proceso tomó 38.465601205825806 seg
#
# --------------------------------------------------------
#
# Generando ejemplos en base a probabilidad -->  0.15
# --------------------------------------------------------
#
#
# Generando 1079 nuevos ejemplos para la clase SexualH
# Consultando por la clase SexualH
# Entrega label 3
# Sentencia original:
# ['pic' 'mexican' 'school' 'girl' 'naked' 'melanie' 'sa' '##fk' '##a'
#  'fake' 'nude' 'photos' 'hardcore' 'sl' '##ut' 'movies' 'alicia' 'moore'
#  'porn' 'star' 'too' '##n' 'love']
# Sentencia final: 3
# ['pic', 'mexican', 'school', 'woman', 'naked', 'melanie', 'sa', '##fk', '##a', 'fake', 'nude', 'prostitutes', 'photographer', 'sl', '##ut', 'movies', 'alicia', 'movie', 'porn', 'star', 'too', '##n', 'love']
#
#
# Sentencia original:
# ['girl' 'dirty' 'quarterback' 'latino' 'pokemon' 'young' 'hand' '##jo'
#  '##b' 'kissing' 'gang' '##bang' 'w' 'x' '##8' '##9' 't' 'co' 'wr' '##m'
#  '##4' '##x' '##o' '##00' '##v' '##j']
# Sentencia final: 3
# ['girl', 'brunette', 'quarterback', 'latino', 'pokemon', 'young', 'juvenile', '##jo', '##b', 'kissing', 'bop', '##bang', 'gangster', 'x', '##8', '##9', 't', 'co', 'wr', '##m', '##4', '##x', '##o', '##00', '##v', '##j']
#
#
# Sentencia original:
# ['rt' 'sp' '##00' '##ky' '##bit' '##ch' '##hh' '##h' 'i' 'have' 'spots'
#  'open' 'sis' '##sy' 'sl' '##ut' 'into' '##x' 'bitch' 'human' 'atm'
#  'amazon' 'boy' 'do' 'you' 'have' 'what' 'it' 'takes' 'can' 'you' 'live'
#  'up' 'to' 'my']
# Sentencia final: 3
# ['rt', 'sp', '##00', '##ky', '##bit', '##ch', '##hh', '##h', 'i', 'have', 'spots', 'open', 'sis', '##sy', 'sl', '##ut', 'into', '##x', 'bitch', 'blockbuster', 'atm', 'amazon', 'boy', 'go', 'you', 'have', 'what', 'it', 'is', 'can', 'you', 'live', 'up', 'to', 'my']
#
#
# Sentencia original:
# ['venus' 'astro' '##logy' 'living' 'standards' 'ni' '##t' 'x' '##8' '##9'
#  's' 'illusion' 'i' 'x' '##8' '##9' 'm' 'fucking' 'nwa' '##iting'
#  'waiting' 'wai' 'x' '##8' '##9']
# Sentencia final: 3
# ['venus', 'astro', '##logy', 'living', 'standards', 'standard', '##t', 'x', '##8', '##9', 's', 'illusion', 'i', 'x', '##8', '##9', 'm', 'fucking', 'nwa', '##iting', 'waiting', 'wai', 'x', '##8', '##9']
#
#
# Sentencia original:
# ['add' 'me' 'on' 'snap' '##cha' '##t' 'and' 'watch' 'me' 'cum' 'colt'
#  '##oe' '##8' 'send' '##nu' '##des' 'nude' 'nude' 'snap' '##cha' '##t'
#  'girls' 'boo' '##bs' 'pussy' 'horn' '##y']
# Sentencia final: 3
# ['add', 'me', 'on', 'snap', '##cha', '##t', 'and', 'watch', 'me', 'cum', 'creamy', '##oe', '##8', 'send', '##nu', '##des', 'nude', 'nude', 'snap', '##cha', '##t', 'girls', 'boo', '##bs', 'dick', 'horn', '##y']
#
#
# Sentencia original:
# ['rt' 'ole' '##sm' '##eh' '##a' '##86' 'he' 'need' 'me' 'to' 'eat' 'his'
#  'dick' 'because' 'eat' 'dick' 'it' 's' 'my' 'skill' 'sl' '##ut' 'ass'
#  'dick' 'cock' 'jail' '##bai' '##t' 'bbc' 'gang' '##bang' 'cu' '##cko'
#  '##ld']
# Sentencia final: 3
# ['rt', 'ole', '##sm', '##eh', '##a', '##86', 'he', 'need', 'me', 'to', 'eat', 'his', 'ate', 'because', 'eat', 'dick', 'it', 's', 'my', 'skill', 'sl', '##ut', 'ass', 'dick', 'cock', 'jail', '##bai', '##t', 'bbc', 'croft', '##bang', 'cu', '##cko', '##ld']
#
#
# Sentencia original:
# ['rt' 'tia' '##po' '##gai' '##51' 'please' 'sleep' 'i' 'will' 'do' 'it'
#  'for' 'you' 'guy' 'gt' 'register' 'note' 'verify' 'email' 'to' 'send'
#  'ms' '##g' 'to' 'girls' 'sl' '##ut']
# Sentencia final: 3
# ['rt', 'tia', '##po', '##gai', '##51', 'please', 'sleep', 'i', 'will', 'do', 'it', 'for', 'you', 'guy', 'gt', 'register', 'compute', 'verify', 'email', 'to', 'send', 'ms', '##g', 'to', 'girls', 'girl', '##ut']
#
#
# Sentencia original:
# ['rt' 'ns' '##f' '##w' 'bitch' 'imagine' 'your' 'cute' 'little' 'sub' 'on'
#  'their' 'knees' 'sucking' 'your' 'cock' 'softly' 'they' 'bat' 'their'
#  'eyes' 'and' 'stop' 'sucking' 'you' 'grab' 'the' '##i']
# Sentencia final: 3
# ['rt', 'ns', '##f', '##w', 'bitch', 'shitty', 'your', 'cute', 'little', 'sub', 'on', 'their', 'knees', 'sucking', 'your', 'cock', 'softly', 'they', 'bat', 'their', 'eyes', 'and', 'stop', 'sucking', 'you', 'grab', 'the', '##i']
#
#
# Sentencia original:
# ['reality' 'pro' '##zzi' '##e' 'mouth' 'n' 't' 'co' 'f' '##q' '##b' '##3'
#  '##ny' '##it' '##p' '##1' 'under' '##age' 'cum' '##shot' 'movies' 'bust'
#  '##y' '##hard' '##core' '##ba' '##bes' 'european' 'girl' 'x' '##8' '##9'
#  't' 'co' 'vs' '##k' '##cts' '##y' '##q' '##eo']
# Sentencia final: 3
# ['reality', 'de', '##zzi', '##e', 'mouth', 'n', 't', 'fl', 'f', '##q', '##b', '##3', '##ny', '##it', '##p', '##1', 'under', '##age', 'cum', '##shot', 'clips', 'bust', '##y', '##hard', '##core', '##ba', '##bes', 'european', 'europe', 'x', '##8', '##9', 't', 'co', 'rt', '##k', '##cts', '##y', '##q', '##eo']
#
#
# # terms modificados promedio 2.072289156626506 términos por sentencia
# Largo de sentencia promedio 24.91566265060241 términos por sentencia
# para esta ejecución se debiesen reemplazar 2518  de 16924 terminos
# Resumen de modificaciones: {'NN': 1687, 'NNS': 130, 'VB': 81, 'VBZ': 43, 'JJ': 156, 'VBG': 73, 'VBN': 26, 'VBD': 21, 'VBP': 11, 'JJS': 7, 'JJR': 1}
# Este proceso tomó 17.23843502998352 seg
#
#
# Generando 0 nuevos ejemplos para la clase NonH
# Consultando por la clase NonH
# Entrega label 0
# No se generan ejemplos
# Resumen de modificaciones: {}
# Este proceso tomó 0.43555307388305664 seg
#
#
# Generando 3585 nuevos ejemplos para la clase PhysicalH
# Consultando por la clase PhysicalH
# Entrega label 2
# Sentencia original:
# ['deep' '##th' '##ro' '##at' 'cum' '##shot' 'perfect' 'boo' '##bs'
#  'jewish' 'indian' 'pussy' 'naked' 'lesbian' 'japanese' 'beau' '##t' 'x'
#  '##8' '##9' 't' 'co' 'g' '##f' '##w' '##x' '##st' '##n' '##2' '##fk']
# Sentencia final: 2
# ['deep', '##th', '##ro', '##at', 'cum', '##shot', 'perfect', 'boo', '##bs', 'jewish', 'lesbian', 'pussy', 'naked', 'lesbian', 'japanese', 'beau', '##t', 'x', '##8', '##9', 'rt', 'co', 'hu', '##f', '##w', '##x', '##st', '##n', '##2', '##fk']
#
#
# Sentencia original:
# ['rt' 'debbie' '##d' '##7' '##47' '##9' '##9' '##11' '##8' 'steve' '##d'
#  '##48' '##48' 'how' 'dare' 'she' 'honest' 'people' 'and' 'children'
#  'were' 'killed' 'in' 'manchester' 'and' 'this' 'sc' '##um' 'says' 'that'
#  's' 'fair' 're' '##tal' '##i']
# Sentencia final: 2
# ['rt', 'behave', '##d', '##7', '##47', '##9', '##9', '##11', '##8', 'steve', '##d', '##48', '##48', 'how', 'behave', 'she', 'honest', 'people', 'and', 'women', 'were', 'killed', 'in', 'manchester', 'and', 'this', 'sc', '##um', 'says', 'that', 's', 'fair', 're', '##tal', '##i']
#
#
# Sentencia original:
# ['bb' '##adi' '##cal' '##i' 'sarcastic' '##fe' '##m' '##23' 'ms' '##vani'
#  '##llar' '##ose' 'facebook' 'habit' '##ually' 'hara' '##ss' 'calling'
#  'addicted' 'drug' '##gy' 'hooker' 'for' 'x' '##8' '##9']
# Sentencia final: 2
# ['bb', '##adi', '##cal', '##i', 'sarcastic', '##fe', '##m', '##23', 'ms', '##vani', '##llar', '##ose', 'facebook', 'twitter', '##ually', 'hara', '##ss', 'calling', 'addicted', 'drug', '##gy', 'hooker', 'for', 'x', '##8', '##9']
#
#
# Sentencia original:
# ['hot' 'british' 'sl' '##ut' 'cr' '##iss' '##y' 'will' 'give' 'you' 'a'
#  'wet' 'dream' 'when' 'she' 'rubs' 'on' 'her' 'pussy' 'cam' '##girl']
# Sentencia final: 2
# ['hot', 'red', 'chopped', '##ut', 'cr', '##iss', '##y', 'will', 'give', 'you', 'a', 'wet', 'dream', 'when', 'she', 'rubs', 'on', 'her', 'pussy', 'cam', '##girl']
#
#
# Sentencia original:
# ['the' 'woman' 'brutally' 'tortured' 'minor' 'servant' 'starved' 'major'
#  'am' '##mara' 'm' 'x' '##8' '##9' 't' 'co' 'y' '##j' '##9' '##6' '##d'
#  '##2' '##x' '##gr' '##p']
# Sentencia final: 2
# ['the', 'woman', 'brutally', 'fucked', 'minor', 'servant', 'starved', 'big', 'are', '##mara', 'm', 'x', '##8', '##9', 't', 'co', 'y', '##j', '##9', '##6', '##d', '##2', '##x', '##gr', '##p']
#
#
# Sentencia original:
# ['p' '##0' '##rn' '##sf' '##w' 'daddy' 'behave' 'baby' 'daddy' 'tight'
#  'open' 'yeah' 'little' 'x' '##8' '##9']
# Sentencia final: 2
# ['p', '##0', '##rn', '##sf', '##w', 'anwar', 'behave', 'baby', 'daddy', 'tight', 'open', 'yeah', 'little', 'x', '##8', '##9']
#
#
# Sentencia original:
# ['what' 'i' 'don' 't' 'get' 'is' 'how' 'y' 'all' 'try' 'to' 'drag' 'becky'
#  'for' 'body' 'shame' 'charlotte' 'when' 'she' 'didn' 't' 'but' 'laugh'
#  'at' 'a' 'fan' 'th']
# Sentencia final: 2
# ['what', 'didn', 'don', 't', 'get', 'is', 'how', 'y', 'all', 'try', 'to', 'drag', 'becky', 'for', 'body', 'shame', 'charlotte', 'when', 'she', 'doesn', 't', 'but', 'name', 'at', 'a', 'fan', 'oh']
#
#
# Sentencia original:
# ['x' 'wilde' '##st' '##dre' '##ams' 'really' 'being' 'sas' '##sy'
#  'twitter' 't' 'co' 'bt' '##bl' '##sz' '##x' '##b' '##w' '##0']
# Sentencia final: 2
# ['day', 'wilde', '##st', '##dre', '##ams', 'really', 'being', 'facebook', '##sy', 'twitter', 't', 'facebook', 'bt', '##bl', '##sz', '##x', '##b', '##w', '##0']
#
#
# Sentencia original:
# ['ne' '##h' '##22' '##3' 'ni' '##gga' 'getting' 'chopped' 'whole' 'dream'
#  'shit']
# Sentencia final: 2
# ['ne', '##h', '##22', '##3', 'ni', '##gga', 'gaping', 'chop', 'whole', 'dream', 'shit']
# # terms modificados promedio 2.0638772663877267 términos por sentencia
# Largo de sentencia promedio 24.699860529986054 términos por sentencia
# para esta ejecución se debiesen reemplazar 8137  de 54354 terminos
# Resumen de modificaciones: {'JJ': 359, 'NN': 5577, 'NNS': 321, 'VBN': 132, 'VBP': 43, 'VBG': 267, 'VB': 320, 'VBZ': 220, 'VBD': 139, 'JJS': 21}
# Este proceso tomó 39.745434045791626 seg
#
#
# Generando 3606 nuevos ejemplos para la clase IndirectH
# Consultando por la clase IndirectH
# Entrega label 1
# Sentencia original:
# ['the' 'people' 'that' 'work' 'in' 'the' 'dining' 'hall' 'are' 'all'
#  'sitting' 'here' 'talking' 'shit' 'about' 'this' 'girl' 'that' 'came'
#  'in' 'first' 'thing']
# Sentencia final: 1
# ['the', 'people', 'that', 'work', 'in', 'the', 'dining', 'hall', 'are', 'all', 'sitting', 'here', 'talking', 'shit', 'about', 'this', 'girl', 'that', 'was', 'in', 'first', 'thing']
#
#
# Sentencia original:
# ['i' 'will' 'never' 'understand' 'how' 'girls' 'can' 'sl' '##ut' 'shame'
#  'other' 'girls' 'for' 'having' 'male' 'friends']
# Sentencia final: 1
# ['i', 'will', 'never', 'understand', 'how', 'girls', 'can', 'feminism', '##ut', 'shame', 'other', 'girls', 'for', 'having', 'male', 'friends']
#
#
# Sentencia original:
# ['shy' '##ler' '##lit' '##tle' '##e' 'honestly' 'can' 'x' '##8' '##9' 't'
#  'relate' 'girls' 'shame' 'different' 'every' 'weekend' 'fuck' '##in'
#  'number' 'x' '##8' '##9']
# Sentencia final: 1
# ['shy', '##ler', '##lit', '##tle', '##e', 'honestly', 'can', 'x', '##8', '##9', 't', 'feminism', 'girls', 'embarrassment', 'different', 'every', 'weekend', 'fuck', '##in', 'number', 'x', '##8', '##9']
#
#
# Sentencia original:
# ['the' '##kat' '##ied' '##ren' '##nen' 'katie' 'is' 'totally' 'turning'
#  'into' 'one' 'of' 'those' 'girls' 'who' 'gets' 'married' 'and' 'forget'
#  'two' 'years' 'ago' 'she' 'wa']
# Sentencia final: 1
# ['the', '##kat', '##ied', '##ren', '##nen', 'katie', 'is', 'totally', 'turning', 'into', 'one', 'of', 'those', 'girls', 'who', 'gets', 'married', 'and', 'forget', 'two', 'times', 'ago', 'she', 'part']
#
#
# Sentencia original:
# ['baku' '##bro' '##ws' 'freaked' '##by' '##du' '##bu' '##l' '##g' 'sara'
#  '##ot' '##5' 'how' 'can' 'u' 'go' 'from' 'wonder' 'girls' 'and' 'miss'
#  'a' 'to' 'twice' 'and' 'these' 'ladies' 'l' '##m' '##fa' '##o' 'i' 'can'
#  't']
# Sentencia final: 1
# ['baku', '##bro', '##ws', 'freaked', '##by', '##du', '##bu', '##l', '##g', 'sara', '##ot', '##5', 'how', 'can', 'u', 'go', 'from', 'wonder', 'girls', 'and', 'miss', 'a', 'to', 'twice', 'and', 'these', 'people', 'woman', '##m', '##fa', '##o', 'i', 'can', 't']
#
#
# Sentencia original:
# ['just' 'inn' '##7' 'kai' '##tma' '##rie' '##ox' 'sl' '##ut' 'arm' '##pit'
#  '##s' 'hairy' 'surely' 'don' 't' 'feminist' 'so' 'x' '##8' '##9' 't' 'co'
#  'ca' '##y' '##z' '##13' '##cu' '##3' '##e']
# Sentencia final: 1
# ['just', 'inn', '##7', 'kai', '##tma', '##rie', '##ox', 'leftist', '##ut', 'arm', '##pit', '##s', 'hairy', 'surely', 'don', 't', 'feminist', 'so', 'x', '##8', '##9', 't', 'co', 'ca', '##y', '##z', '##13', '##cu', '##3', '##e']
#
#
# Sentencia original:
# ['number' 't' 'you' 'should' 'do' 'to' 'him' 'all' 'by' 'now' 'you' 'will'
#  'need' 'to' 'make' 'him' 'a' 'few' 'times' 'until' 'she' 'is' 'ready'
#  'and' 'he' 'just' 'lets' 'h']
# Sentencia final: 1
# ['number', 't', 'you', 'should', 'go', 'to', 'him', 'all', 'by', 'now', 'you', 'will', 'need', 'to', 'have', 'him', 'a', 'disappointed', 'lets', 'until', 'she', 'is', 'ready', 'and', 'he', 'just', 'lets', 'h']
#
#
# Sentencia original:
# ['mrs' 'hc' '##m' 'tr' '##ad' '##po' '##aster' '##100' '##0' 'also'
#  'though' 'if' 'eggs' 'are' 'the' 'resource' 'guys' 'are' 'after' 'vs' 'a'
#  'good' 'and' 'vi' '##rt' '##uous' 'wife' 'who' 'will']
# Sentencia final: 1
# ['mrs', 'hc', '##m', 'tr', '##ad', '##po', '##aster', '##100', '##0', 'also', 'though', 'if', 'eggs', 'are', 'the', 'resource', 'guys', 'are', 'after', 'vs', 'a', 'good', 'and', 'vi', '##rt', '##uous', 'girlfriend', 'who', 'will']
#
#
# Sentencia original:
# ['rt' 'maxi' '##pen' '##al' '##ty' 'when' 'will' 'the' 'phenomenon' 'of'
#  'white' 'women' 'with' 'no' 'personality' 'who' 'can' 't' 'do'
#  'literally' 'anything' 'without' 'wine' 'just' 'fucking' 'die']
# Sentencia final: 1
# ['rt', 'lil', '##pen', '##al', '##ty', 'when', 'will', 'the', 'phenomenon', 'of', 'white', 'women', 'with', 'no', 'personality', 'who', 'can', 't', 'do', 'literally', 'leftist', 'without', 'wine', 'just', 'fucking', 'die']
#
#
# # terms modificados promedio 1.973377703826955 términos por sentencia
# Largo de sentencia promedio 23.81336661120355 términos por sentencia
# para esta ejecución se debiesen reemplazar 7732  de 51786 terminos
# Resumen de modificaciones: {'VBD': 120, 'NN': 5092, 'NNS': 496, 'VB': 241, 'JJ': 403, 'VBZ': 213, 'VBG': 305, 'VBN': 231, 'VBP': 15}
# Este proceso tomó 38.46005892753601 seg

# %%
prob=0.15 
TOPN=1

fs_macro={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
fs_none={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
accs={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
confusions={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}


for i in range(1,6):
    print ("----------------------- Entrenando running ", i,"-----------------------")
    macro_augmented=np.load('../../../new_data_augmented/harassment/Aumento_'+str(i)+'-run_'+str(prob)+'_app1_Top'+str(TOPN)+'.npy', allow_pickle=True)
    
    ids_train=macro_augmented[:,0]
    tws_train=macro_augmented[:,1]
    labels_train=macro_augmented[:,2]
    class_weights= compute_class_weight('balanced', np.unique(labels_train), labels_train)
    print ("Pesos de clases:", class_weights)
    
    etiq=labels_train.copy()
    sentences = tws_train
    n_labels = np.array(etiq)

    input_ids = []
    for sent in sentences:
        encoded_sent = tokenizer_loaded.encode(list(sent),add_special_tokens = False)    
        input_ids.append(encoded_sent)
    input_ids = pad_sequences(input_ids,maxlen=MAX_LEN,dtype="long",value=0, truncating="post", padding="post")
    y_train=to_categorical(n_labels,num_classes=4)
    shape=np.asarray(input_ids).shape
    x_train=np.zeros((shape[0], shape[1], 768))
    j=0
    for in_id in input_ids:
        x_train[j]=M_BERT_space[in_id]
        j+=1

    ###########################################################
    ############################################################
    ############################################################
    
    cnn1=create_ccn1(x_train.shape[1:])
    trained =train_model(cnn1, x_train, y_train, x_val, y_val, class_weights, e=30, BS=32, verb=0, focal=True)
    trained.save('../../../new_data_augmented/harassment_baselines/'+str(prob)+'/cnn1_'+str(i)+'-exec_app1_Top_'+str(TOPN)+'.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(trained, x_train, x_val, x_test, etiq, etiq_v, etiq_t, 'cnn1')
    fs_macro['cnn1'].append(f1_ma_t)
    fs_none['cnn1'].append(f1_t)
    accs['cnn1'].append(acc_t)
    confusions['cnn1'].append(matriz_t)
    
    cnn2=create_cnn2(x_train.shape[1:])
    trained =train_model(cnn2, x_train, y_train, x_val, y_val, class_weights, e=30, BS=32, verb=0, focal=True)
    trained.save('../../../new_data_augmented/harassment_baselines/'+str(prob)+'/cnn2_'+str(i)+'-exec_app1_Top_'+str(TOPN)+'.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(trained, x_train, x_val, x_test, etiq, etiq_v, etiq_t, 'cnn2')
    fs_macro['cnn2'].append(f1_ma_t)
    fs_none['cnn2'].append(f1_t)
    accs['cnn2'].append(acc_t)
    confusions['cnn2'].append(matriz_t)
    
    rnn1=create_complex_GRU_2(128,64,"adam",x_train.shape[1:])
    trained =train_model(rnn1, x_train, y_train, x_val, y_val, class_weights, e=30, BS=32, verb=0, focal=True)
    trained.save('../../../new_data_augmented/harassment_baselines/'+str(prob)+'/rnn1_'+str(i)+'-exec_app1_Top_'+str(TOPN)+'.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(trained, x_train, x_val, x_test, etiq, etiq_v, etiq_t, 'rnn1')
    fs_macro['rnn1'].append(f1_ma_t)
    fs_none['rnn1'].append(f1_t)
    accs['rnn1'].append(acc_t)
    confusions['rnn1'].append(matriz_t)
    
    rnn2=create_complex_GRU_3(256,128,64,"adam",x_train.shape[1:])
    trained =train_model(rnn2, x_train, y_train, x_val, y_val, class_weights, e=30, BS=32, verb=0, focal=True)
    trained.save('../../../new_data_augmented/harassment_baselines/'+str(prob)+'/rnn2_'+str(i)+'-exec_app1_Top_'+str(TOPN)+'.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(trained, x_train, x_val, x_test, etiq, etiq_v, etiq_t, 'rnn2')
    fs_macro['rnn2'].append(f1_ma_t)
    fs_none['rnn2'].append(f1_t)
    accs['rnn2'].append(acc_t)
    confusions['rnn2'].append(matriz_t)
    
    rnn3=create_complex_GRU_3(256,128,64,"adam",x_train.shape[1:])
    trained =train_model(rnn3, x_train, y_train, x_val, y_val, class_weights, e=30, BS=32, verb=0, focal=False)
    trained.save('../../../new_data_augmented/harassment_baselines/'+str(prob)+'/rnn3_'+str(i)+'-exec_app1_Top_'+str(TOPN)+'.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(trained, x_train, x_val, x_test, etiq, etiq_v, etiq_t, 'rnn3')
    fs_macro['rnn3'].append(f1_ma_t)
    fs_none['rnn3'].append(f1_t)
    accs['rnn3'].append(acc_t)
    confusions['rnn3'].append(matriz_t)
# Out:
# ----------------------- Entrenando running  1 -----------------------
# Pesos de clases: [1. 1. 1. 1.]
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:Large dropout rate: 0.65 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.65 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:1702: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:1205: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
#
# Accuracy sobre Train cnn1 : 0.9795137940453428
# F1-score None sobre Train cnn1 : [0.96112103 0.99904385 0.99767601 0.96026041]
# F1-score macro sobre Train cnn1 : 0.9795253243457334
#
# Accuracy sobre Val cnn1 : 0.7035294117647058
# F1-score None sobre Val cnn1 : [0.77907884 0.02380952 0.04545455 0.63461538]
# F1-score macro sobre Val cnn1 : 0.3707395746330172
#
# Accuracy sobre Test cnn1 : 0.7268016957136129
# F1-score None sobre Test cnn1 : [0.83011326 0.         0.05063291 0.55765595]
# F1-score macro sobre Test cnn1 : 0.35960053096297495
# WARNING:tensorflow:Large dropout rate: 0.65 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.65 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
#
# Accuracy sobre Train cnn2 : 0.9604616225075117
# F1-score None sobre Train cnn2 : [0.92682298 0.998635   0.99794886 0.91796138]
# F1-score macro sobre Train cnn2 : 0.9603420542765653
#
# Accuracy sobre Val cnn2 : 0.7350588235294118
# F1-score None sobre Val cnn2 : [0.80937973 0.02439024 0.04761905 0.66126856]
# F1-score macro sobre Val cnn2 : 0.3856643938030525
#
# Accuracy sobre Test cnn2 : 0.754592557701366
# F1-score None sobre Test cnn2 : [0.85263835 0.         0.02597403 0.57801047]
# F1-score macro sobre Test cnn2 : 0.3641557124541418
#
# Accuracy sobre Train rnn1 : 0.9753482655012292
# F1-score None sobre Train rnn1 : [0.95412364 0.99890681 0.99877167 0.94937071]
# F1-score macro sobre Train rnn1 : 0.9752932062318682
#
# Accuracy sobre Val rnn1 : 0.7567058823529412
# F1-score None sobre Val rnn1 : [0.8314121  0.07920792 0.05633803 0.68817204]
# F1-score macro sobre Val rnn1 : 0.41378252392956094
#
# Accuracy sobre Test rnn1 : 0.7498822421102214
# F1-score None sobre Test rnn1 : [0.84966112 0.10447761 0.11111111 0.52770449]
# F1-score macro sobre Test rnn1 : 0.39823858247992416
# WARNING:tensorflow:Large dropout rate: 0.65 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
#
# Accuracy sobre Train rnn2 : 0.9834744605299098
# F1-score None sobre Train rnn2 : [0.96877076 0.99863388 0.999181   0.96726149]
# F1-score macro sobre Train rnn2 : 0.9834617824158615
#
# Accuracy sobre Val rnn2 : 0.7374117647058823
# F1-score None sobre Val rnn2 : [0.81440238 0.09433962 0.0625     0.66810967]
# F1-score macro sobre Val rnn2 : 0.4098379166001923
#
# Accuracy sobre Test rnn2 : 0.7399905793688177
# F1-score None sobre Test rnn2 : [0.84070796 0.12987013 0.11965812 0.55240444]
# F1-score macro sobre Test rnn2 : 0.41066016327356525
#
# Accuracy sobre Train rnn3 : 0.9928298279158699
# F1-score None sobre Train rnn3 : [0.98667392 0.99890621 0.999181   0.9865643 ]
# F1-score macro sobre Train rnn3 : 0.9928313562086439
#
# Accuracy sobre Val rnn3 : 0.699764705882353
# F1-score None sobre Val rnn3 : [0.78144172 0.08403361 0.04761905 0.64072272]
# F1-score macro sobre Val rnn3 : 0.3884542757424513
#
# Accuracy sobre Test rnn3 : 0.7121997173810646
# F1-score None sobre Test rnn3 : [0.82088566 0.01574803 0.1010101  0.53118712]
# F1-score macro sobre Test rnn3 : 0.36720772821910563
# ----------------------- Entrenando running  2 -----------------------
# Pesos de clases: [1. 1. 1. 1.]
#
# Accuracy sobre Train cnn1 : 0.9775334608030593
# F1-score None sobre Train cnn1 : [0.95676047 0.99849788 0.99808848 0.95676998]
# F1-score macro sobre Train cnn1 : 0.9775292025057069
#
# Accuracy sobre Val cnn1 : 0.7176470588235294
# F1-score None sobre Val cnn1 : [0.79302326 0.02439024 0.04347826 0.64850843]
# F1-score macro sobre Val cnn1 : 0.3773500477988889
#
# Accuracy sobre Test cnn1 : 0.7343382006594442
# F1-score None sobre Test cnn1 : [0.83521595 0.03418803 0.075      0.57170356]
# F1-score macro sobre Test cnn1 : 0.3790268855370865
#
# Accuracy sobre Train cnn2 : 0.9754165528544113
# F1-score None sobre Train cnn2 : [0.95243273 0.9989071  0.99863425 0.95170143]
# F1-score macro sobre Train cnn2 : 0.9754188775122755
#
# Accuracy sobre Val cnn2 : 0.7176470588235294
# F1-score None sobre Val cnn2 : [0.79123414 0.         0.04444444 0.64663619]
# F1-score macro sobre Val cnn2 : 0.3705786926648068
#
# Accuracy sobre Test cnn2 : 0.7517663683466792
# F1-score None sobre Test cnn2 : [0.84966052 0.         0.02564103 0.58057851]
# F1-score macro sobre Test cnn2 : 0.3639700154502641
#
# Accuracy sobre Train rnn1 : 0.9406582900846763
# F1-score None sobre Train rnn1 : [0.96074766 0.93607773 0.98327489 0.8750381 ]
# F1-score macro sobre Train rnn1 : 0.9387845941313002
#
# Accuracy sobre Val rnn1 : 0.5595294117647058
# F1-score None sobre Val rnn1 : [0.73164862 0.09734513 0.05970149 0.54214123]
# F1-score macro sobre Val rnn1 : 0.357709117868541
#
# Accuracy sobre Test rnn1 : 0.6005652378709374
# F1-score None sobre Test rnn1 : [0.75730256 0.19161677 0.14611872 0.49488055]
# F1-score macro sobre Test rnn1 : 0.3974796486018083
#
# Accuracy sobre Train rnn2 : 0.9907129199672221
# F1-score None sobre Train rnn2 : [0.9822518  0.999181   0.99877066 0.98263562]
# F1-score macro sobre Train rnn2 : 0.9907097696635428
#
# Accuracy sobre Val rnn2 : 0.6
# F1-score None sobre Val rnn2 : [0.66522304 0.02298851 0.07142857 0.56836158]
# F1-score macro sobre Val rnn2 : 0.3320004248434445
#
# Accuracy sobre Test rnn2 : 0.6245878473857749
# F1-score None sobre Test rnn2 : [0.74101519 0.10769231 0.20740741 0.47581903]
# F1-score macro sobre Test rnn2 : 0.3829834846681093
#
# Accuracy sobre Train rnn3 : 0.9445506692160612
# F1-score None sobre Train rnn3 : [0.93459825 0.970444   0.93452457 0.9377068 ]
# F1-score macro sobre Train rnn3 : 0.9443184057595506
# Accuracy sobre Val rnn3 : 0.35858823529411765
# F1-score None sobre Val rnn3 : [0.40422164 0.08211144 0.0456942  0.61231884]
# F1-score macro sobre Val rnn3 : 0.2860865284413139
#
# Accuracy sobre Test rnn3 : 0.3758831841733396
# F1-score None sobre Test rnn3 : [0.46421846 0.1511772  0.13903743 0.54376658]
# F1-score macro sobre Test rnn3 : 0.32454991666315836
# ----------------------- Entrenando running  3 -----------------------
# Pesos de clases: [1. 1. 1. 1.]
#
# Accuracy sobre Train cnn1 : 0.9577984157334062
# F1-score None sobre Train cnn1 : [0.92217402 0.99794774 0.99863463 0.91183805]
# F1-score macro sobre Train cnn1 : 0.9576486093676397
#
# Accuracy sobre Val cnn1 : 0.7595294117647059
# F1-score None sobre Val cnn1 : [0.83112094 0.         0.04545455 0.6874116 ]
# F1-score macro sobre Val cnn1 : 0.3909967719275088
#
# Accuracy sobre Test cnn1 : 0.7861516721620349
# F1-score None sobre Test cnn1 : [0.87241273 0.         0.05063291 0.61893204]
# F1-score macro sobre Test cnn1 : 0.3854944195154427
#
# Accuracy sobre Train cnn2 : 0.9767822999180552
# F1-score None sobre Train cnn2 : [0.9547711  0.99849747 0.99863388 0.95524003]
# F1-score macro sobre Train cnn2 : 0.9767856193694434
#
# Accuracy sobre Val cnn2 : 0.7087058823529412
# F1-score None sobre Val cnn2 : [0.78577013 0.         0.08888889 0.63405337]
# F1-score macro sobre Val cnn2 : 0.3771780972556277
#
# Accuracy sobre Test cnn2 : 0.7225624116815826
# F1-score None sobre Test cnn2 : [0.82793184 0.         0.05128205 0.54817587]
# F1-score macro sobre Test cnn2 : 0.3568474393847411
#
# Accuracy sobre Train rnn1 : 0.9863425293635618
# F1-score None sobre Train rnn1 : [0.974736   0.99918055 0.99808691 0.97335008]
# F1-score macro sobre Train rnn1 : 0.9863383838388017
#
# Accuracy sobre Val rnn1 : 0.744
# F1-score None sobre Val rnn1 : [0.82091212 0.07633588 0.06779661 0.68525312]
# F1-score macro sobre Val rnn1 : 0.41257443268418675
#
# Accuracy sobre Test rnn1 : 0.7494112105511069
# F1-score None sobre Test rnn1 : [0.84982829 0.07751938 0.15686275 0.53448276]
# F1-score macro sobre Test rnn1 : 0.4046732923863955
#
# Accuracy sobre Train rnn2 : 0.8447828462168806
# F1-score None sobre Train rnn2 : [0.90171514 0.96121993 0.71406003 0.78844703]
# F1-score macro sobre Train rnn2 : 0.8413605323737835
#
# Accuracy sobre Val rnn2 : 0.5134117647058823
# F1-score None sobre Val rnn2 : [0.55349501 0.08181818 0.         0.52910053]
# F1-score macro sobre Val rnn2 : 0.2911034295128446
#
# Accuracy sobre Test rnn2 : 0.5303815355628827
# F1-score None sobre Test rnn2 : [0.64401294 0.17228464 0.         0.42937063]
# F1-score macro sobre Test rnn2 : 0.3114170546373012
#
# Accuracy sobre Train rnn3 : 0.9926932532095056
# F1-score None sobre Train rnn3 : [0.98648833 0.9989071  0.99863388 0.98675044]
# F1-score macro sobre Train rnn3 : 0.9926949395915388
#
# Accuracy sobre Val rnn3 : 0.568
# F1-score None sobre Val rnn3 : [0.62140288 0.09174312 0.04494382 0.55689278]
# F1-score macro sobre Val rnn3 : 0.32874564904551284
#
# Accuracy sobre Test rnn3 : 0.5600565237870937
# F1-score None sobre Test rnn3 : [0.67723232 0.15757576 0.14634146 0.43308271]
# F1-score macro sobre Test rnn3 : 0.3535580607951448
# ----------------------- Entrenando running  4 -----------------------
# Pesos de clases: [1. 1. 1. 1.]
#
# Accuracy sobre Train cnn1 : 0.9747336793225895
# F1-score None sobre Train cnn1 : [0.95238095 0.9989074  0.9980916  0.94941634]
# F1-score macro sobre Train cnn1 : 0.974699075048981
#
# Accuracy sobre Val cnn1 : 0.7364705882352941
# F1-score None sobre Val cnn1 : [0.81341877 0.         0.02439024 0.67314365]
# F1-score macro sobre Val cnn1 : 0.3777381663369346
#
# Accuracy sobre Test cnn1 : 0.7635421573245408
# F1-score None sobre Test cnn1 : [0.85769603 0.         0.16494845 0.60169492]
# F1-score macro sobre Test cnn1 : 0.40608484996005484
#
# Accuracy sobre Train cnn2 : 0.9640125648729855
# F1-score None sobre Train cnn2 : [0.93251212 0.99836021 0.9989074  0.92603677]
# F1-score macro sobre Train cnn2 : 0.9639541248787107
#
# Accuracy sobre Val cnn2 : 0.764235294117647
# F1-score None sobre Val cnn2 : [0.83613753 0.         0.04545455 0.69015097]
# F1-score macro sobre Val cnn2 : 0.3929357608529203
#
# Accuracy sobre Test cnn2 : 0.7861516721620349
# F1-score None sobre Test cnn2 : [0.87134146 0.         0.05128205 0.60869565]
# F1-score macro sobre Test cnn2 : 0.38282979171764964
#
# Accuracy sobre Train rnn1 : 0.9868888281890194
# F1-score None sobre Train rnn1 : [0.97528278 0.998772   0.99645969 0.97692514]
# F1-score macro sobre Train rnn1 : 0.9868599048061995
#
# Accuracy sobre Val rnn1 : 0.595764705882353
# F1-score None sobre Val rnn1 : [0.67757211 0.08275862 0.05988024 0.57956656]
# F1-score macro sobre Val rnn1 : 0.3499443821786741
#
# Accuracy sobre Test rnn1 : 0.5986811116344795
# F1-score None sobre Test rnn1 : [0.72063253 0.18099548 0.19323671 0.47160069]
# F1-score macro sobre Test rnn1 : 0.391616352169402
#
# Accuracy sobre Train rnn2 : 0.9836110352362742
# F1-score None sobre Train rnn2 : [0.9691358  0.99876999 0.99753695 0.96907764]
# F1-score macro sobre Train rnn2 : 0.9836300934181492
#
# Accuracy sobre Val rnn2 : 0.5703529411764706
# F1-score None sobre Val rnn2 : [0.62494412 0.07228916 0.04255319 0.54062666]
# F1-score macro sobre Val rnn2 : 0.32010328232326307
#
# Accuracy sobre Test rnn2 : 0.569477154969383
# F1-score None sobre Test rnn2 : [0.69076923 0.06557377 0.08602151 0.42348008]
# F1-score macro sobre Test rnn2 : 0.31646114762370514
#
# Accuracy sobre Train rnn3 : 0.9771920240371483
# F1-score None sobre Train rnn3 : [0.95391639 0.99876931 0.99863425 0.95735217]
# F1-score macro sobre Train rnn3 : 0.977168033175403
#
# Accuracy sobre Val rnn3 : 0.5849411764705882
# F1-score None sobre Val rnn3 : [0.64345527 0.06741573 0.07407407 0.55277476]
# F1-score macro sobre Val rnn3 : 0.3344299565542749
#
# Accuracy sobre Test rnn3 : 0.5817239755063589
# F1-score None sobre Test rnn3 : [0.70336391 0.01574803 0.1010101  0.44017094]
# F1-score macro sobre Test rnn3 : 0.3150732467625482
# ----------------------- Entrenando running  5 -----------------------
# Pesos de clases: [1. 1. 1. 1.]
#
# Accuracy sobre Train cnn1 : 0.9756897022671401
# F1-score None sobre Train cnn1 : [0.95347269 0.99863351 0.99849829 0.95214385]
# F1-score macro sobre Train cnn1 : 0.9756870838800067
#
# Accuracy sobre Val cnn1 : 0.7181176470588235
# F1-score None sobre Val cnn1 : [0.79382239 0.         0.04761905 0.64378238]
# F1-score macro sobre Val cnn1 : 0.3713059562152826
#
# Accuracy sobre Test cnn1 : 0.7390485162505888
# F1-score None sobre Test cnn1 : [0.84165572 0.         0.05128205 0.56243854]
# F1-score macro sobre Test cnn1 : 0.36384407804610613
#
# Accuracy sobre Train cnn2 : 0.9771237366839661
# F1-score None sobre Train cnn2 : [0.95529478 0.998635   0.99809108 0.95635877]
# F1-score macro sobre Train cnn2 : 0.9770949061869122
#
# Accuracy sobre Val cnn2 : 0.6823529411764706
# F1-score None sobre Val cnn2 : [0.75582329 0.05263158 0.09090909 0.61585366]
# F1-score macro sobre Val cnn2 : 0.3788044053914339
#
# Accuracy sobre Test cnn2 : 0.701365991521432
# F1-score None sobre Test cnn2 : [0.80888889 0.         0.05063291 0.53948536]
# F1-score macro sobre Test cnn2 : 0.3497517899106074
#
# Accuracy sobre Train rnn1 : 0.9890740234908495
# F1-score None sobre Train rnn1 : [0.97892986 0.99931741 0.9989077  0.97912458]
# F1-score macro sobre Train rnn1 : 0.989069886146545
#
# Accuracy sobre Val rnn1 : 0.6545882352941177
# F1-score None sobre Val rnn1 : [0.73180703 0.05172414 0.03738318 0.62112587]
# F1-score macro sobre Val rnn1 : 0.36051005427316146
#
# Accuracy sobre Test rnn1 : 0.6796985398021668
# F1-score None sobre Test rnn1 : [0.79417879 0.125      0.10596026 0.53193518]
# F1-score macro sobre Test rnn1 : 0.38926855885947326
#
# Accuracy sobre Train rnn2 : 0.9764408631521442
# F1-score None sobre Train rnn2 : [0.97884615 0.97106742 0.99186771 0.96404794]
# F1-score macro sobre Train rnn2 : 0.9764573051223944
#
# Accuracy sobre Val rnn2 : 0.6861176470588235
# F1-score None sobre Val rnn2 : [0.77169664 0.02777778 0.06060606 0.62634409]
# F1-score macro sobre Val rnn2 : 0.371606140600945
#
# Accuracy sobre Test rnn2 : 0.7202072538860104
# F1-score None sobre Test rnn2 : [0.83148269 0.         0.10294118 0.52978723]
# F1-score macro sobre Test rnn2 : 0.3660527753911854
#
# Accuracy sobre Train rnn3 : 0.9952881726304288
# F1-score None sobre Train rnn3 : [0.99165184 0.998908   0.99918033 0.99141104]
# F1-score macro sobre Train rnn3 : 0.9952878026055837
# Accuracy sobre Val rnn3 : 0.7430588235294118
# F1-score None sobre Val rnn3 : [0.82173428 0.08510638 0.09876543 0.6935123 ]
# F1-score macro sobre Val rnn3 : 0.4247795988681118
#
# Accuracy sobre Test rnn3 : 0.731040979745643
# F1-score None sobre Test rnn3 : [0.83419689 0.09625668 0.16       0.57919622]
# F1-score macro sobre Test rnn3 : 0.41741244829444457

# %%
for key in fs_none.keys():
    temp=np.zeros(4)
    for result in fs_none[key]:
        temp+=result
    print ("(0.15) F1-score promedio para",key,":" ,temp/5)

print ("")
for key in fs_macro.keys():
    temp=np.sum(fs_macro[key])
    print ("(0.15) F1-score macro promedio para",key,":" ,temp/5, "desvest: ",np.std(fs_macro[key]))

print ("")
for key in accs.keys():
    temp=np.sum(accs[key])
    print ("(0.15) Accuracy promedio para",key,":" ,temp/5)
# Out:
# (0.15) F1-score promedio para cnn1 : [0.84741874 0.00683761 0.07849927 0.582485  ]
# (0.15) F1-score promedio para cnn2 : [0.84209221 0.         0.04096241 0.57098917]
# (0.15) F1-score promedio para rnn1 : [0.79432066 0.13592185 0.14265791 0.51212073]
# (0.15) F1-score promedio para rnn2 : [0.7495976  0.09508417 0.10320564 0.48217228]
# (0.15) F1-score promedio para rnn3 : [0.69997945 0.08730114 0.12947982 0.50548071]
#
# (0.15) F1-score macro promedio para cnn1 : 0.378810152804333 desvest:  0.01662304703979299
# (0.15) F1-score macro promedio para cnn2 : 0.3635109497834808 desvest:  0.011023256915328598
# (0.15) F1-score macro promedio para rnn1 : 0.39625528689940065 desvest:  0.005415337910975034
# (0.15) F1-score macro promedio para rnn2 : 0.35751492511877325 desvest:  0.03835722894282875
# (0.15) F1-score macro promedio para rnn3 : 0.35556028014688035 desvest:  0.036238667605580616
#
# (0.15) Accuracy promedio para cnn1 : 0.7499764484220444
# (0.15) Accuracy promedio para cnn2 : 0.743287800282619
# (0.15) Accuracy promedio para rnn1 : 0.6756476683937824
# (0.15) Accuracy promedio para rnn2 : 0.6369288742345737
# (0.15) Accuracy promedio para rnn3 : 0.5921808761187

# %%
for key in confusions.keys():
    temp=np.sum(confusions[key], axis=0)/5.0
    plot_confusion_matrix(temp, ['NonH','IndirectH','PhysicalH','SexualH'], "(0.15) Classic - Confusion Matrix "+str(key), cmap='RdPu')

# %% [markdown]
# ### Generar 0.5 harassment [positivo classic]

# %%
prob= 0.5
TOPN = 1

fs_macro={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
fs_none={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
accs={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
confusions={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}

aum_weight=det_samples(train['Label'], dict_cl)

for i in range(1,6): 
    macro_augmented=[]
    print ("\n--------------------------------------------------------")
    print ("\nGenerando ejemplos en base a probabilidad --> ", prob)
    print ("--------------------------------------------------------")
    for clase in aum_weight:
        start_time=time.time()
        print ("\n\nGenerando", aum_weight[clase], "nuevos ejemplos para la clase", clase)
        muestras, dict_aumentos=aumentar_clase(clase, aum_weight[clase], tags, prob, TOPN)
        macro_augmented+=muestras
        print ("Resumen de modificaciones:", dict_aumentos)
        elapsed_time= time.time() - start_time
        print ("Este proceso tomó", elapsed_time, "seg")   

    macro_augmented = np.asarray(macro_augmented, dtype=object)
    np.random.shuffle(macro_augmented)
    np.save('../../../new_data_augmented/harassment/Aumento_'+str(i)+'-run_'+str(prob)+'_app1_Top'+str(TOPN)+'.npy', macro_augmented)
# Out:
# --------------------------------------------------------
#
# Generando ejemplos en base a probabilidad -->  0.5
# --------------------------------------------------------
#
#
# Generando 1079 nuevos ejemplos para la clase SexualH
# Consultando por la clase SexualH
# Entrega label 3
# Sentencia original:
# ['pic' 'mexican' 'school' 'girl' 'naked' 'melanie' 'sa' '##fk' '##a'
#  'fake' 'nude' 'photos' 'hardcore' 'sl' '##ut' 'movies' 'alicia' 'moore'
#  'porn' 'star' 'too' '##n' 'love']
# Sentencia final: 3
# ['college', 'colombian', 'brunette', 'prostitute', 'live', 'melanie', 'sa', '##fk', '##a', 'fake', 'gangster', 'photos', 'photographer', 'brighton', '##ut', 'movies', 'alicia', 'movie', 'porn', 'ellen', 'too', '##n', 'love']
#
#
# Sentencia original:
# ['girl' 'dirty' 'quarterback' 'latino' 'pokemon' 'young' 'hand' '##jo'
#  '##b' 'kissing' 'gang' '##bang' 'w' 'x' '##8' '##9' 't' 'co' 'wr' '##m'
#  '##4' '##x' '##o' '##00' '##v' '##j']
# Sentencia final: 3
# ['boy', 'brunette', 'quarterback', 'latino', 'pokemon', 'young', 'repetitive', '##jo', '##b', 'menacing', 'gang', '##bang', 'jock', 'x', '##8', '##9', 'wc', 're', 'wr', '##m', '##4', '##x', '##o', '##00', '##v', '##j']
#
#
# Sentencia original:
# ['mil' '##ion' '##do' '##lla' '##me' '##at' 'sex' '##ting' 'n' 'ng' '##ir'
#  '##l' 'daddy' 'n' 'nme' 'listen' 'bitch' 'gonna' 'watch' 'these' 'what']
# Sentencia final: 3
# ['concerto', '##ion', '##do', '##lla', '##me', '##at', 'sex', '##ting', 'yvonne', 'hs', '##ir', '##l', 'rn', 'n', 'mommy', 'listen', 'gotta', 'hear', 'watch', 'these', 'what']
#
#
# Sentencia original:
# ['museum' 'sl' '##ut' 'if' 'you' 'know' 'somewhere' 'we' 'can' 'do' 'it'
#  'then' 'i' 'am' 'game']
# Sentencia final: 3
# ['league', 'sl', '##ut', 'if', 'you', 'know', 'somewhere', 'we', 'can', 'do', 'it', 'then', 'i', 'am', 'game']
#
#
# Sentencia original:
# ['rt' 'sp' '##00' '##ky' '##bit' '##ch' '##hh' '##h' 'i' 'have' 'spots'
#  'open' 'sis' '##sy' 'sl' '##ut' 'into' '##x' 'bitch' 'human' 'atm'
#  'amazon' 'boy' 'do' 'you' 'have' 'what' 'it' 'takes' 'can' 'you' 'live'
#  'up' 'to' 'my']
# Sentencia final: 3
# ['rt', 'sp', '##00', '##ky', '##bit', '##ch', '##hh', '##h', 'bonn', 'do', 'spots', 'open', 'sb', '##sy', 'gal', '##ut', 'into', '##x', 'bitch', 'blockbuster', 'atm', 'amazon', 'doesn', 'do', 'you', 'know', 'what', 'it', 'gives', 'can', 'you', 'black', 'up', 'to', 'my']
#
#
# Sentencia original:
# ['venus' 'astro' '##logy' 'living' 'standards' 'ni' '##t' 'x' '##8' '##9'
#  's' 'illusion' 'i' 'x' '##8' '##9' 'm' 'fucking' 'nwa' '##iting'
#  'waiting' 'wai' 'x' '##8' '##9']
# Sentencia final: 3
# ['venus', 'astro', '##logy', 'woken', 'cooks', 'ni', '##t', 'x', '##8', '##9', 's', 'illusion', 'vi', 'pinto', '##8', '##9', 'banging', 'educating', 'nwa', '##iting', 'appealing', 'wai', 'x', '##8', '##9']
#
#
# Sentencia original:
# ['add' 'me' 'on' 'snap' '##cha' '##t' 'and' 'watch' 'me' 'cum' 'colt'
#  '##oe' '##8' 'send' '##nu' '##des' 'nude' 'nude' 'snap' '##cha' '##t'
#  'girls' 'boo' '##bs' 'pussy' 'horn' '##y']
# Sentencia final: 3
# ['happen', 'me', 'on', 'dammit', '##cha', '##t', 'and', 'watch', 'me', 'gonna', 'creamy', '##oe', '##8', 'blackish', '##nu', '##des', 'nude', 'nude', 'bikini', '##cha', '##t', 'girls', 'boo', '##bs', 'bum', 'horn', '##y']
#
#
# Sentencia original:
# ['rt' 'ole' '##sm' '##eh' '##a' '##86' 'he' 'need' 'me' 'to' 'eat' 'his'
#  'dick' 'because' 'eat' 'dick' 'it' 's' 'my' 'skill' 'sl' '##ut' 'ass'
#  'dick' 'cock' 'jail' '##bai' '##t' 'bbc' 'gang' '##bang' 'cu' '##cko'
#  '##ld']
# Sentencia final: 3
# ['rb', 'ole', '##sm', '##eh', '##a', '##86', 'he', 'need', 'me', 'to', 'eat', 'his', 'dick', 'because', 'eat', 'top', 'it', 's', 'my', 'skill', 'sl', '##ut', 'ass', 'dick', 'butt', 'jail', '##bai', '##t', 'duran', 'croft', '##bang', 'cu', '##cko', '##ld']
#
#
# Sentencia original:
# ['rt' 'tia' '##po' '##gai' '##51' 'please' 'sleep' 'i' 'will' 'do' 'it'
#  'for' 'you' 'guy' 'gt' 'register' 'note' 'verify' 'email' 'to' 'send'
#  'ms' '##g' 'to' 'girls' 'sl' '##ut']
# Sentencia final: 3
# ['po', 'tia', '##po', '##gai', '##51', 'croft', 'work', 'dino', 'will', 'do', 'it', 'for', 'you', 'guy', 'gal', 'register', 'compute', 'compute', 'ipad', 'to', 'send', 'ms', '##g', 'to', 'girls', 'girl', '##ut']
#
#
# # terms modificados promedio 5.54772937905468 términos por sentencia
# Largo de sentencia promedio 24.07136237256719 términos por sentencia
# para esta ejecución se debiesen reemplazar 6831  de 13608 terminos
# Resumen de modificaciones: {'NN': 4515, 'JJ': 405, 'VBG': 193, 'VB': 187, 'VBZ': 115, 'NNS': 359, 'VBN': 97, 'VBD': 68, 'VBP': 32, 'JJS': 12, 'JJR': 3}
# Este proceso tomó 38.58716869354248 seg
#
#
# Generando 0 nuevos ejemplos para la clase NonH
# Consultando por la clase NonH
# Entrega label 0
# No se generan ejemplos
# Resumen de modificaciones: {}
# Este proceso tomó 0.4334120750427246 seg
#
#
# Generando 3585 nuevos ejemplos para la clase PhysicalH
# Consultando por la clase PhysicalH
# Entrega label 2
# Sentencia original:
# ['deep' '##th' '##ro' '##at' 'cum' '##shot' 'perfect' 'boo' '##bs'
#  'jewish' 'indian' 'pussy' 'naked' 'lesbian' 'japanese' 'beau' '##t' 'x'
#  '##8' '##9' 't' 'co' 'g' '##f' '##w' '##x' '##st' '##n' '##2' '##fk']
# Sentencia final: 2
# ['deep', '##th', '##ro', '##at', 'cum', '##shot', 'perfect', 'boo', '##bs', 'muslim', 'islamic', 'pussy', 'naked', 'aesthetic', 'difficult', 'racist', '##t', 'hussain', '##8', '##9', 't', 'co', 'g', '##f', '##w', '##x', '##st', '##n', '##2', '##fk']
#
#
# Sentencia original:
# ['rt' 'debbie' '##d' '##7' '##47' '##9' '##9' '##11' '##8' 'steve' '##d'
#  '##48' '##48' 'how' 'dare' 'she' 'honest' 'people' 'and' 'children'
#  'were' 'killed' 'in' 'manchester' 'and' 'this' 'sc' '##um' 'says' 'that'
#  's' 'fair' 're' '##tal' '##i']
# Sentencia final: 2
# ['katie', 'debbie', '##d', '##7', '##47', '##9', '##9', '##11', '##8', 'hussain', '##d', '##48', '##48', 'how', 'dare', 'she', 'anwar', 'people', 'and', 'children', 'was', 'killed', 'in', 'manchester', 'and', 'this', 'sc', '##um', 'says', 'that', 's', 'fair', 'se', '##tal', '##i']
#
#
# Sentencia original:
# ['pr' '##ae' '##tors' '##uit' 'which' 'specifically' 'i' 'x' '##8' '##9'
#  'd' 'personally' 'pitch' 'black' 'world' 'devil' 'there' 'rap' '##ist'
#  'an' 'x' '##8' '##9' 't' 'co' 'bu' '##rg' '##t' '##j' '##fr' '##ya']
# Sentencia final: 2
# ['rt', '##ae', '##tors', '##uit', 'which', 'specifically', 'time', 'x', '##8', '##9', 'd', 'personally', 'pitch', 'black', 'world', 'devil', 'there', 'life', '##ist', 'an', 'x', '##8', '##9', 'hu', 'co', 'bu', '##rg', '##t', '##j', '##fr', '##ya']
#
#
# Sentencia original:
# ['sas' '##sy' 'wants' 'signing' 'first' 'prepare' 'good' 'don' 't' 'know'
#  'x' '##8' '##9' 't' 'co' 'qi' '##q' '##gi' '##b' '##17' '##ik']
# Sentencia final: 2
# ['sas', '##sy', 'wants', 'anwar', 'first', 'destroy', 'ready', 'don', 't', 'know', 'destroy', '##8', '##9', 't', 'pic', 'qi', '##q', '##gi', '##b', '##17', '##ik']
#
#
# Sentencia original:
# ['bb' '##adi' '##cal' '##i' 'sarcastic' '##fe' '##m' '##23' 'ms' '##vani'
#  '##llar' '##ose' 'facebook' 'habit' '##ually' 'hara' '##ss' 'calling'
#  'addicted' 'drug' '##gy' 'hooker' 'for' 'x' '##8' '##9']
# Sentencia final: 2
# ['ll', '##adi', '##cal', '##i', 'sarcastic', '##fe', '##m', '##23', 'family', '##vani', '##llar', '##ose', 'facebook', 'habit', '##ually', 'hara', '##ss', 'choking', 'fucked', 'drug', '##gy', 'suicidal', 'for', 'line', '##8', '##9']
#
#
# Sentencia original:
# ['hot' 'british' 'sl' '##ut' 'cr' '##iss' '##y' 'will' 'give' 'you' 'a'
#  'wet' 'dream' 'when' 'she' 'rubs' 'on' 'her' 'pussy' 'cam' '##girl']
# Sentencia final: 2
# ['hot', 'japanese', 'sl', '##ut', 'cr', '##iss', '##y', 'will', 'give', 'you', 'a', 'wet', 'wish', 'when', 'she', 'rubs', 'on', 'her', 'gonna', 'cam', '##girl']
#
#
# Sentencia original:
# ['the' 'woman' 'brutally' 'tortured' 'minor' 'servant' 'starved' 'major'
#  'am' '##mara' 'm' 'x' '##8' '##9' 't' 'co' 'y' '##j' '##9' '##6' '##d'
#  '##2' '##x' '##gr' '##p']
# Sentencia final: 2
# ['the', 'woman', 'brutally', 'starved', 'minor', 'servant', 'starved', 'major', 'am', '##mara', 'm', 'hussain', '##8', '##9', 're', 're', 'y', '##j', '##9', '##6', '##d', '##2', '##x', '##gr', '##p']
#
#
# Sentencia original:
# ['p' '##0' '##rn' '##sf' '##w' 'daddy' 'behave' 'baby' 'daddy' 'tight'
#  'open' 'yeah' 'little' 'x' '##8' '##9']
# Sentencia final: 2
# ['ll', '##0', '##rn', '##sf', '##w', 'anwar', 'behave', 'father', 'daddy', 'tight', 'horrible', 'yeah', 'little', 'oh', '##8', '##9']
#
#
# Sentencia original:
# ['what' 'i' 'don' 't' 'get' 'is' 'how' 'y' 'all' 'try' 'to' 'drag' 'becky'
#  'for' 'body' 'shame' 'charlotte' 'when' 'she' 'didn' 't' 'but' 'laugh'
#  'at' 'a' 'fan' 'th']
# Sentencia final: 2
# ['what', 'didn', 'didn', 't', 'be', 'is', 'how', 'y', 'all', 'try', 'to', 'drag', 'becky', 'for', 'murderer', 'shame', 'charlotte', 'when', 'she', 'didn', 't', 'but', 'laugh', 'at', 'a', 'fan', 'th']
# # terms modificados promedio 5.64881450488145 términos por sentencia
# Largo de sentencia promedio 24.090655509065552 términos por sentencia
# para esta ejecución se debiesen reemplazar 22176  de 44218 terminos
# Resumen de modificaciones: {'NN': 15116, 'JJ': 1012, 'VBD': 387, 'VBG': 728, 'VBN': 386, 'VB': 912, 'NNS': 914, 'VBZ': 594, 'VBP': 133, 'JJS': 69}
# Este proceso tomó 83.2207145690918 seg
#
#
# Generando 3606 nuevos ejemplos para la clase IndirectH
# Consultando por la clase IndirectH
# Entrega label 1
# Sentencia original:
# ['the' 'people' 'that' 'work' 'in' 'the' 'dining' 'hall' 'are' 'all'
#  'sitting' 'here' 'talking' 'shit' 'about' 'this' 'girl' 'that' 'came'
#  'in' 'first' 'thing']
# Sentencia final: 1
# ['the', 'women', 'that', 'work', 'in', 'the', 'dining', 'hall', 'are', 'all', 'being', 'here', 'talking', 'family', 'about', 'this', 'man', 'that', 'was', 'in', 'first', 'thing']
#
#
# Sentencia original:
# ['i' 'will' 'never' 'understand' 'how' 'girls' 'can' 'sl' '##ut' 'shame'
#  'other' 'girls' 'for' 'having' 'male' 'friends']
# Sentencia final: 1
# ['right', 'will', 'never', 'girl', 'how', 'girls', 'can', 'sl', '##ut', 'leftist', 'unacceptable', 'girls', 'for', 'having', 'male', 'boys']
#
#
# Sentencia original:
# ['shy' '##ler' '##lit' '##tle' '##e' 'honestly' 'can' 'x' '##8' '##9' 't'
#  'relate' 'girls' 'shame' 'different' 'every' 'weekend' 'fuck' '##in'
#  'number' 'x' '##8' '##9']
# Sentencia final: 1
# ['right', '##ler', '##lit', '##tle', '##e', 'honestly', 'can', 'confirm', '##8', '##9', 't', 'faulty', 'girls', 'shame', 'different', 'every', 'leftist', 'fuck', '##in', 'faulty', 'x', '##8', '##9']
#
#
# Sentencia original:
# ['the' '##kat' '##ied' '##ren' '##nen' 'katie' 'is' 'totally' 'turning'
#  'into' 'one' 'of' 'those' 'girls' 'who' 'gets' 'married' 'and' 'forget'
#  'two' 'years' 'ago' 'she' 'wa']
# Sentencia final: 1
# ['the', '##kat', '##ied', '##ren', '##nen', 'feminism', 'gets', 'totally', 'turning', 'into', 'one', 'of', 'those', 'boys', 'who', 'is', 'married', 'and', 'wife', 'two', 'years', 'ago', 'she', 'wa']
#
#
# Sentencia original:
# ['baku' '##bro' '##ws' 'freaked' '##by' '##du' '##bu' '##l' '##g' 'sara'
#  '##ot' '##5' 'how' 'can' 'u' 'go' 'from' 'wonder' 'girls' 'and' 'miss'
#  'a' 'to' 'twice' 'and' 'these' 'ladies' 'l' '##m' '##fa' '##o' 'i' 'can'
#  't']
# Sentencia final: 1
# ['baku', '##bro', '##ws', 'freaked', '##by', '##du', '##bu', '##l', '##g', 'leftist', '##ot', '##5', 'how', 'can', 'usa', 'be', 'from', 'wonder', 'ladies', 'and', 'girl', 'a', 'to', 'twice', 'and', 'these', 'ladies', 'l', '##m', '##fa', '##o', 'da', 'can', 'time']
#
#
# Sentencia original:
# ['love' '##toy' 'ca' 'that' 's' 'a' 'well' 'trained' 'girl']
# Sentencia final: 1
# ['love', '##toy', 'ca', 'that', 'll', 'a', 'well', 'tortured', 'girl']
#
#
# Sentencia original:
# ['just' 'inn' '##7' 'kai' '##tma' '##rie' '##ox' 'sl' '##ut' 'arm' '##pit'
#  '##s' 'hairy' 'surely' 'don' 't' 'feminist' 'so' 'x' '##8' '##9' 't' 'co'
#  'ca' '##y' '##z' '##13' '##cu' '##3' '##e']
# Sentencia final: 1
# ['just', 'inn', '##7', 'faulty', '##tma', '##rie', '##ox', 'sl', '##ut', 'faulty', '##pit', '##s', 'hairy', 'surely', 'don', 't', 'feminist', 'so', 'x', '##8', '##9', 'rt', 'co', 'ca', '##y', '##z', '##13', '##cu', '##3', '##e']
#
#
# Sentencia original:
# ['number' 't' 'you' 'should' 'do' 'to' 'him' 'all' 'by' 'now' 'you' 'will'
#  'need' 'to' 'make' 'him' 'a' 'few' 'times' 'until' 'she' 'is' 'ready'
#  'and' 'he' 'just' 'lets' 'h']
# Sentencia final: 1
# ['number', 't', 'you', 'should', 'be', 'to', 'him', 'all', 'by', 'now', 'you', 'will', 'need', 'to', 'make', 'him', 'a', 'few', 'times', 'until', 'she', 'is', 'much', 'and', 'he', 'just', 'lets', 'h']
#
#
# Sentencia original:
# ['mrs' 'hc' '##m' 'tr' '##ad' '##po' '##aster' '##100' '##0' 'also'
#  'though' 'if' 'eggs' 'are' 'the' 'resource' 'guys' 'are' 'after' 'vs' 'a'
#  'good' 'and' 'vi' '##rt' '##uous' 'wife' 'who' 'will']
# Sentencia final: 1
# ['ms', 'hc', '##m', 'rt', '##ad', '##po', '##aster', '##100', '##0', 'also', 'though', 'if', 'aren', 'are', 'the', 'work', 'guys', 'are', 'after', 'mrs', 'a', 'good', 'and', 'vi', '##rt', '##uous', 'wife', 'who', 'will']
#
#
# # terms modificados promedio 5.139212423738214 términos por sentencia
# Largo de sentencia promedio 22.827232390460345 términos por sentencia
# para esta ejecución se debiesen reemplazar 20233  de 40224 terminos
# Resumen de modificaciones: {'NNS': 1362, 'VBG': 796, 'NN': 13192, 'VBD': 364, 'JJ': 1029, 'VBZ': 573, 'VB': 611, 'VBN': 576, 'VBP': 29}
# Este proceso tomó 76.04181122779846 seg
#
# --------------------------------------------------------
#
# Generando ejemplos en base a probabilidad -->  0.5
# --------------------------------------------------------
#
#
# Generando 1079 nuevos ejemplos para la clase SexualH
# Consultando por la clase SexualH
# Entrega label 3
# Sentencia original:
# ['pic' 'mexican' 'school' 'girl' 'naked' 'melanie' 'sa' '##fk' '##a'
#  'fake' 'nude' 'photos' 'hardcore' 'sl' '##ut' 'movies' 'alicia' 'moore'
#  'porn' 'star' 'too' '##n' 'love']
# Sentencia final: 3
# ['pic', 'colombian', 'girlfriend', 'girlfriend', 'appalled', 'melanie', 'sa', '##fk', '##a', 'fake', 'nude', 'photos', 'hardcore', 'brighton', '##ut', 'james', 'alicia', 'moore', 'light', 'star', 'too', '##n', 'love']
#
#
# Sentencia original:
# ['girl' 'dirty' 'quarterback' 'latino' 'pokemon' 'young' 'hand' '##jo'
#  '##b' 'kissing' 'gang' '##bang' 'w' 'x' '##8' '##9' 't' 'co' 'wr' '##m'
#  '##4' '##x' '##o' '##00' '##v' '##j']
# Sentencia final: 3
# ['girl', 'dirty', 'boy', 'latino', 'pokemon', 'young', 'pinto', '##jo', '##b', 'embracing', 'gangster', '##bang', 'w', 'x', '##8', '##9', 'mcconnell', 'ha', 'wr', '##m', '##4', '##x', '##o', '##00', '##v', '##j']
#
#
# Sentencia original:
# ['mil' '##ion' '##do' '##lla' '##me' '##at' 'sex' '##ting' 'n' 'ng' '##ir'
#  '##l' 'daddy' 'n' 'nme' 'listen' 'bitch' 'gonna' 'watch' 'these' 'what']
# Sentencia final: 3
# ['concerto', '##ion', '##do', '##lla', '##me', '##at', 'prostitution', '##ting', 'n', 'hs', '##ir', '##l', 'rn', 'n', 'mommy', 'rihanna', 'gotta', 'gonna', 'watch', 'these', 'what']
#
#
# Sentencia original:
# ['museum' 'sl' '##ut' 'if' 'you' 'know' 'somewhere' 'we' 'can' 'do' 'it'
#  'then' 'i' 'am' 'game']
# Sentencia final: 3
# ['museum', 'rampage', '##ut', 'if', 'you', 'see', 'somewhere', 'we', 'can', 'see', 'it', 'then', 'i', 'am', 'game']
#
#
# Sentencia original:
# ['rt' 'sp' '##00' '##ky' '##bit' '##ch' '##hh' '##h' 'i' 'have' 'spots'
#  'open' 'sis' '##sy' 'sl' '##ut' 'into' '##x' 'bitch' 'human' 'atm'
#  'amazon' 'boy' 'do' 'you' 'have' 'what' 'it' 'takes' 'can' 'you' 'live'
#  'up' 'to' 'my']
# Sentencia final: 3
# ['rt', 'sp', '##00', '##ky', '##bit', '##ch', '##hh', '##h', 'need', 'have', 'spots', 'open', 'sis', '##sy', 'silvia', '##ut', 'into', '##x', 'bastard', 'human', 'atm', 'amazon', 'rb', 'be', 'you', 'have', 'what', 'it', 'takes', 'can', 'you', 'last', 'up', 'to', 'my']
#
#
# Sentencia original:
# ['venus' 'astro' '##logy' 'living' 'standards' 'ni' '##t' 'x' '##8' '##9'
#  's' 'illusion' 'i' 'x' '##8' '##9' 'm' 'fucking' 'nwa' '##iting'
#  'waiting' 'wai' 'x' '##8' '##9']
# Sentencia final: 3
# ['venus', 'astro', '##logy', 'mendez', 'cooks', 'ni', '##t', 'x', '##8', '##9', 's', 'illusion', 'i', 'pinto', '##8', '##9', 'm', 'educating', 'nwa', '##iting', 'waiting', 'wai', 'x', '##8', '##9']
#
#
# Sentencia original:
# ['add' 'me' 'on' 'snap' '##cha' '##t' 'and' 'watch' 'me' 'cum' 'colt'
#  '##oe' '##8' 'send' '##nu' '##des' 'nude' 'nude' 'snap' '##cha' '##t'
#  'girls' 'boo' '##bs' 'pussy' 'horn' '##y']
# Sentencia final: 3
# ['add', 'me', 'on', 'ba', '##cha', '##t', 'and', 'watch', 'me', 'rock', 'creamy', '##oe', '##8', 'send', '##nu', '##des', 'umm', 'kemp', 'disgrace', '##cha', '##t', 'girls', 'fulham', '##bs', 'li', 'horn', '##y']
#
#
# Sentencia original:
# ['rt' 'ole' '##sm' '##eh' '##a' '##86' 'he' 'need' 'me' 'to' 'eat' 'his'
#  'dick' 'because' 'eat' 'dick' 'it' 's' 'my' 'skill' 'sl' '##ut' 'ass'
#  'dick' 'cock' 'jail' '##bai' '##t' 'bbc' 'gang' '##bang' 'cu' '##cko'
#  '##ld']
# Sentencia final: 3
# ['rt', 'ol', '##sm', '##eh', '##a', '##86', 'he', 'bonn', 'me', 'to', 'eat', 'his', 'ate', 'because', 'eat', 'dick', 'it', 's', 'my', 'skill', 'butt', '##ut', 'ass', 'dick', 'cock', 'jail', '##bai', '##t', 'gangster', 'gang', '##bang', 'cu', '##cko', '##ld']
#
#
# Sentencia original:
# ['rt' 'tia' '##po' '##gai' '##51' 'please' 'sleep' 'i' 'will' 'do' 'it'
#  'for' 'you' 'guy' 'gt' 'register' 'note' 'verify' 'email' 'to' 'send'
#  'ms' '##g' 'to' 'girls' 'sl' '##ut']
# Sentencia final: 3
# ['po', 'tia', '##po', '##gai', '##51', 'croft', 'sleep', 'slept', 'will', 'do', 'it', 'for', 'you', 'compute', 'place', 'register', 'note', 'compute', 'ipad', 'to', 'send', 'day', '##g', 'to', 'girls', 'sl', '##ut']
# # terms modificados promedio 5.479147358665431 términos por sentencia
# Largo de sentencia promedio 24.057460611677477 términos por sentencia
# para esta ejecución se debiesen reemplazar 6765  de 13592 terminos
# Resumen de modificaciones: {'JJ': 409, 'NN': 4494, 'NNS': 330, 'VBG': 203, 'VB': 155, 'VBN': 91, 'VBD': 69, 'VBZ': 111, 'JJS': 13, 'VBP': 35, 'JJR': 2}
# Este proceso tomó 38.019930839538574 seg
#
#
# Generando 0 nuevos ejemplos para la clase NonH
# Consultando por la clase NonH
# Entrega label 0
# No se generan ejemplos
# Resumen de modificaciones: {}
# Este proceso tomó 0.43386125564575195 seg
#
#
# Generando 3585 nuevos ejemplos para la clase PhysicalH
# Consultando por la clase PhysicalH
# Entrega label 2
# Sentencia original:
# ['deep' '##th' '##ro' '##at' 'cum' '##shot' 'perfect' 'boo' '##bs'
#  'jewish' 'indian' 'pussy' 'naked' 'lesbian' 'japanese' 'beau' '##t' 'x'
#  '##8' '##9' 't' 'co' 'g' '##f' '##w' '##x' '##st' '##n' '##2' '##fk']
# Sentencia final: 2
# ['deep', '##th', '##ro', '##at', 'anwar', '##shot', 'perfect', 'boo', '##bs', 'muslim', 'indian', 'pussy', 'naked', 'jealous', 'aesthetic', 'racist', '##t', 'cute', '##8', '##9', 't', 'co', 'g', '##f', '##w', '##x', '##st', '##n', '##2', '##fk']
#
#
# Sentencia original:
# ['rt' 'debbie' '##d' '##7' '##47' '##9' '##9' '##11' '##8' 'steve' '##d'
#  '##48' '##48' 'how' 'dare' 'she' 'honest' 'people' 'and' 'children'
#  'were' 'killed' 'in' 'manchester' 'and' 'this' 'sc' '##um' 'says' 'that'
#  's' 'fair' 're' '##tal' '##i']
# Sentencia final: 2
# ['manchester', 'debbie', '##d', '##7', '##47', '##9', '##9', '##11', '##8', 'steve', '##d', '##48', '##48', 'how', 'behave', 'she', 'person', 'women', 'and', 'children', 'was', 'killed', 'in', 'kill', 'and', 'this', 'sc', '##um', 'says', 'that', 'chopped', 'fair', 're', '##tal', '##i']
#
#
# Sentencia original:
# ['pr' '##ae' '##tors' '##uit' 'which' 'specifically' 'i' 'x' '##8' '##9'
#  'd' 'personally' 'pitch' 'black' 'world' 'devil' 'there' 'rap' '##ist'
#  'an' 'x' '##8' '##9' 't' 'co' 'bu' '##rg' '##t' '##j' '##fr' '##ya']
# Sentencia final: 2
# ['pr', '##ae', '##tors', '##uit', 'which', 'specifically', 'i', 'x', '##8', '##9', 'head', 'personally', 'pitch', 'black', 'world', 'fuck', 'there', 'life', '##ist', 'an', 'racist', '##8', '##9', 'th', 'co', 'se', '##rg', '##t', '##j', '##fr', '##ya']
#
#
# Sentencia original:
# ['sas' '##sy' 'wants' 'signing' 'first' 'prepare' 'good' 'don' 't' 'know'
#  'x' '##8' '##9' 't' 'co' 'qi' '##q' '##gi' '##b' '##17' '##ik']
# Sentencia final: 2
# ['want', '##sy', 'wants', 'signing', 'first', 'prepare', 'horrible', 'don', 'juicy', 'know', 'x', '##8', '##9', 't', 'co', 'qi', '##q', '##gi', '##b', '##17', '##ik']
#
#
# Sentencia original:
# ['bb' '##adi' '##cal' '##i' 'sarcastic' '##fe' '##m' '##23' 'ms' '##vani'
#  '##llar' '##ose' 'facebook' 'habit' '##ually' 'hara' '##ss' 'calling'
#  'addicted' 'drug' '##gy' 'hooker' 'for' 'x' '##8' '##9']
# Sentencia final: 2
# ['kendrick', '##adi', '##cal', '##i', 'aesthetic', '##fe', '##m', '##23', 'ms', '##vani', '##llar', '##ose', 'facebook', 'habit', '##ually', 'hara', '##ss', 'choking', 'fucked', 'hussain', '##gy', 'suicidal', 'for', 'suicidal', '##8', '##9']
#
#
# Sentencia original:
# ['hot' 'british' 'sl' '##ut' 'cr' '##iss' '##y' 'will' 'give' 'you' 'a'
#  'wet' 'dream' 'when' 'she' 'rubs' 'on' 'her' 'pussy' 'cam' '##girl']
# Sentencia final: 2
# ['japanese', 'japanese', 'sl', '##ut', 'fl', '##iss', '##y', 'will', 'give', 'you', 'a', 'wet', 'dream', 'when', 'she', 'rubs', 'on', 'her', 'pussy', 'cam', '##girl']
#
#
# Sentencia original:
# ['the' 'woman' 'brutally' 'tortured' 'minor' 'servant' 'starved' 'major'
#  'am' '##mara' 'm' 'x' '##8' '##9' 't' 'co' 'y' '##j' '##9' '##6' '##d'
#  '##2' '##x' '##gr' '##p']
# Sentencia final: 2
# ['the', 'girl', 'brutally', 'tortured', 'beaten', 'anwar', 'addicted', 'major', 'am', '##mara', 'anwar', 'x', '##8', '##9', 't', 'co', 'y', '##j', '##9', '##6', '##d', '##2', '##x', '##gr', '##p']
#
#
# Sentencia original:
# ['p' '##0' '##rn' '##sf' '##w' 'daddy' 'behave' 'baby' 'daddy' 'tight'
#  'open' 'yeah' 'little' 'x' '##8' '##9']
# Sentencia final: 2
# ['p', '##0', '##rn', '##sf', '##w', 'daddy', 'behave', 'cute', 'juicy', 'tight', 'horrible', 'yeah', 'little', 'x', '##8', '##9']
#
#
# Sentencia original:
# ['what' 'i' 'don' 't' 'get' 'is' 'how' 'y' 'all' 'try' 'to' 'drag' 'becky'
#  'for' 'body' 'shame' 'charlotte' 'when' 'she' 'didn' 't' 'but' 'laugh'
#  'at' 'a' 'fan' 'th']
# Sentencia final: 2
# ['what', 'i', 'don', 'time', 'get', 'has', 'how', 'stop', 'all', 'try', 'to', 'drag', 'becky', 'for', 'katie', 'shame', 'charlotte', 'when', 'she', 'didn', 't', 'but', 'laugh', 'at', 'a', 'fan', 'th']
#
#
# # terms modificados promedio 5.674476987447699 términos por sentencia
# Largo de sentencia promedio 24.102370990237098 términos por sentencia
# para esta ejecución se debiesen reemplazar 22306  de 44251 terminos
# Resumen de modificaciones: {'NN': 15219, 'JJ': 1065, 'NNS': 933, 'VBD': 388, 'VBG': 722, 'VBN': 391, 'VBZ': 556, 'VB': 868, 'JJS': 57, 'VBP': 144}
# Este proceso tomó 83.65110778808594 seg
#
#
# Generando 3606 nuevos ejemplos para la clase IndirectH
# Consultando por la clase IndirectH
# Entrega label 1
# Sentencia original:
# ['the' 'people' 'that' 'work' 'in' 'the' 'dining' 'hall' 'are' 'all'
#  'sitting' 'here' 'talking' 'shit' 'about' 'this' 'girl' 'that' 'came'
#  'in' 'first' 'thing']
# Sentencia final: 1
# ['the', 'people', 'that', 'work', 'in', 'the', 'dining', 'hall', 'are', 'all', 'messing', 'here', 'being', 'shit', 'about', 'this', 'woman', 'that', 'was', 'in', 'first', 'anything']
#
#
# Sentencia original:
# ['i' 'will' 'never' 'understand' 'how' 'girls' 'can' 'sl' '##ut' 'shame'
#  'other' 'girls' 'for' 'having' 'male' 'friends']
# Sentencia final: 1
# ['i', 'will', 'never', 'understand', 'how', 'boys', 'can', 'sl', '##ut', 'leftist', 'unacceptable', 'girls', 'for', 'having', 'meeting', 'girlfriends']
#
#
# Sentencia original:
# ['shy' '##ler' '##lit' '##tle' '##e' 'honestly' 'can' 'x' '##8' '##9' 't'
#  'relate' 'girls' 'shame' 'different' 'every' 'weekend' 'fuck' '##in'
#  'number' 'x' '##8' '##9']
# Sentencia final: 1
# ['shy', '##ler', '##lit', '##tle', '##e', 'honestly', 'can', 'confirm', '##8', '##9', 'faulty', 'relate', 'girls', 'faulty', 'different', 'every', 'hell', 'leftist', '##in', 'faulty', 'x', '##8', '##9']
#
#
# Sentencia original:
# ['the' '##kat' '##ied' '##ren' '##nen' 'katie' 'is' 'totally' 'turning'
#  'into' 'one' 'of' 'those' 'girls' 'who' 'gets' 'married' 'and' 'forget'
#  'two' 'years' 'ago' 'she' 'wa']
# Sentencia final: 1
# ['the', '##kat', '##ied', '##ren', '##nen', 'katie', 'is', 'totally', 'turning', 'into', 'one', 'of', 'those', 'girls', 'who', 'wants', 'married', 'and', 'forget', 'two', 'years', 'ago', 'she', 'wa']
#
#
# Sentencia original:
# ['baku' '##bro' '##ws' 'freaked' '##by' '##du' '##bu' '##l' '##g' 'sara'
#  '##ot' '##5' 'how' 'can' 'u' 'go' 'from' 'wonder' 'girls' 'and' 'miss'
#  'a' 'to' 'twice' 'and' 'these' 'ladies' 'l' '##m' '##fa' '##o' 'i' 'can'
#  't']
# Sentencia final: 1
# ['baku', '##bro', '##ws', 'freaked', '##by', '##du', '##bu', '##l', '##g', 'leftist', '##ot', '##5', 'how', 'can', 'u', 'do', 'from', 'wonder', 'women', 'and', 'miss', 'a', 'to', 'twice', 'and', 'these', 'people', 'l', '##m', '##fa', '##o', 'i', 'can', 'right']
#
#
# Sentencia original:
# ['love' '##toy' 'ca' 'that' 's' 'a' 'well' 'trained' 'girl']
# Sentencia final: 1
# ['understand', '##toy', 'ca', 'that', 's', 'a', 'well', 'tortured', 'woman']
#
#
# Sentencia original:
# ['just' 'inn' '##7' 'kai' '##tma' '##rie' '##ox' 'sl' '##ut' 'arm' '##pit'
#  '##s' 'hairy' 'surely' 'don' 't' 'feminist' 'so' 'x' '##8' '##9' 't' 'co'
#  'ca' '##y' '##z' '##13' '##cu' '##3' '##e']
# Sentencia final: 1
# ['just', 'inn', '##7', 'kai', '##tma', '##rie', '##ox', 'faulty', '##ut', 'arm', '##pit', '##s', 'time', 'surely', 'feminism', 't', 'feminist', 'so', 'feminism', '##8', '##9', 'work', 'part', 'ca', '##y', '##z', '##13', '##cu', '##3', '##e']
#
#
# Sentencia original:
# ['number' 't' 'you' 'should' 'do' 'to' 'him' 'all' 'by' 'now' 'you' 'will'
#  'need' 'to' 'make' 'him' 'a' 'few' 'times' 'until' 'she' 'is' 'ready'
#  'and' 'he' 'just' 'lets' 'h']
# Sentencia final: 1
# ['number', 't', 'you', 'should', 'say', 'to', 'him', 'all', 'by', 'now', 'you', 'will', 'need', 'to', 'make', 'him', 'a', 'disappointed', 'times', 'until', 'she', 'is', 'other', 'and', 'he', 'just', 'mosques', 'h']
#
#
# Sentencia original:
# ['mrs' 'hc' '##m' 'tr' '##ad' '##po' '##aster' '##100' '##0' 'also'
#  'though' 'if' 'eggs' 'are' 'the' 'resource' 'guys' 'are' 'after' 'vs' 'a'
#  'good' 'and' 'vi' '##rt' '##uous' 'wife' 'who' 'will']
# Sentencia final: 1
# ['ms', 'leftist', '##m', 'rt', '##ad', '##po', '##aster', '##100', '##0', 'also', 'though', 'if', 'aren', 'are', 'the', 'resource', 'aren', 'are', 'after', 'vs', 'a', 'new', 'and', 'faulty', '##rt', '##uous', 'wife', 'who', 'will']
# # terms modificados promedio 5.0876317249029395 términos por sentencia
# Largo de sentencia promedio 22.820576816417084 términos por sentencia
# para esta ejecución se debiesen reemplazar 20013  de 40182 terminos
# Resumen de modificaciones: {'VBG': 799, 'NN': 13034, 'VBD': 354, 'NNS': 1339, 'JJ': 1027, 'VBZ': 602, 'VB': 597, 'VBN': 556, 'VBP': 38}
# Este proceso tomó 75.29481887817383 seg
#
# --------------------------------------------------------
#
# Generando ejemplos en base a probabilidad -->  0.5
# --------------------------------------------------------
#
#
# Generando 1079 nuevos ejemplos para la clase SexualH
# Consultando por la clase SexualH
# Entrega label 3
# Sentencia original:
# ['pic' 'mexican' 'school' 'girl' 'naked' 'melanie' 'sa' '##fk' '##a'
#  'fake' 'nude' 'photos' 'hardcore' 'sl' '##ut' 'movies' 'alicia' 'moore'
#  'porn' 'star' 'too' '##n' 'love']
# Sentencia final: 3
# ['pic', 'colombian', 'silvia', 'prostitute', 'live', 'melanie', 'sa', '##fk', '##a', 'fake', 'gangster', 'videos', 'photographer', 'porn', '##ut', 'dishes', 'alicia', 'movie', 'porn', 'star', 'too', '##n', 'romance']
#
#
# Sentencia original:
# ['girl' 'dirty' 'quarterback' 'latino' 'pokemon' 'young' 'hand' '##jo'
#  '##b' 'kissing' 'gang' '##bang' 'w' 'x' '##8' '##9' 't' 'co' 'wr' '##m'
#  '##4' '##x' '##o' '##00' '##v' '##j']
# Sentencia final: 3
# ['girlfriend', 'dirty', 'quarterback', 'latino', 'pokemon', 'japanese', 'hand', '##jo', '##b', 'embracing', 'gang', '##bang', 'w', 'x', '##8', '##9', 'rb', 'co', 'wr', '##m', '##4', '##x', '##o', '##00', '##v', '##j']
#
#
# Sentencia original:
# ['mil' '##ion' '##do' '##lla' '##me' '##at' 'sex' '##ting' 'n' 'ng' '##ir'
#  '##l' 'daddy' 'n' 'nme' 'listen' 'bitch' 'gonna' 'watch' 'these' 'what']
# Sentencia final: 3
# ['peyton', '##ion', '##do', '##lla', '##me', '##at', 'den', '##ting', 'n', 'hs', '##ir', '##l', 'fulham', 'mommy', 'nme', 'listen', 'asshole', 'gonna', 'watch', 'these', 'what']
#
#
# Sentencia original:
# ['museum' 'sl' '##ut' 'if' 'you' 'know' 'somewhere' 'we' 'can' 'do' 'it'
#  'then' 'i' 'am' 'game']
# Sentencia final: 3
# ['museum', 'sl', '##ut', 'if', 'you', 'believe', 'somewhere', 'we', 'can', 'do', 'it', 'then', 'series', 'are', 'game']
#
#
# Sentencia original:
# ['rt' 'sp' '##00' '##ky' '##bit' '##ch' '##hh' '##h' 'i' 'have' 'spots'
#  'open' 'sis' '##sy' 'sl' '##ut' 'into' '##x' 'bitch' 'human' 'atm'
#  'amazon' 'boy' 'do' 'you' 'have' 'what' 'it' 'takes' 'can' 'you' 'live'
#  'up' 'to' 'my']
# Sentencia final: 3
# ['nt', 'sp', '##00', '##ky', '##bit', '##ch', '##hh', '##h', 'i', 'have', 'spots', 'open', 'sis', '##sy', 'sb', '##ut', 'into', '##x', 'bitch', 'blockbuster', 'atm', 'girl', 'boy', 'say', 'you', 'see', 'what', 'it', 'is', 'can', 'you', 'live', 'up', 'to', 'my']
#
#
# Sentencia original:
# ['venus' 'astro' '##logy' 'living' 'standards' 'ni' '##t' 'x' '##8' '##9'
#  's' 'illusion' 'i' 'x' '##8' '##9' 'm' 'fucking' 'nwa' '##iting'
#  'waiting' 'wai' 'x' '##8' '##9']
# Sentencia final: 3
# ['venus', 'astro', '##logy', 'living', 'norms', 'ni', '##t', 'pinto', '##8', '##9', 'croft', 'illusion', 'ma', 'x', '##8', '##9', 'goddamn', 'fucking', 'nwa', '##iting', 'crying', 'wai', 'x', '##8', '##9']
#
#
# Sentencia original:
# ['add' 'me' 'on' 'snap' '##cha' '##t' 'and' 'watch' 'me' 'cum' 'colt'
#  '##oe' '##8' 'send' '##nu' '##des' 'nude' 'nude' 'snap' '##cha' '##t'
#  'girls' 'boo' '##bs' 'pussy' 'horn' '##y']
# Sentencia final: 3
# ['add', 'me', 'on', 'dammit', '##cha', '##t', 'and', 'watch', 'me', 'cum', 'creamy', '##oe', '##8', 'send', '##nu', '##des', 'explicit', 'nude', 'snap', '##cha', '##t', 'lads', 'prostitute', '##bs', 'pussy', 'horn', '##y']
#
#
# Sentencia original:
# ['rt' 'ole' '##sm' '##eh' '##a' '##86' 'he' 'need' 'me' 'to' 'eat' 'his'
#  'dick' 'because' 'eat' 'dick' 'it' 's' 'my' 'skill' 'sl' '##ut' 'ass'
#  'dick' 'cock' 'jail' '##bai' '##t' 'bbc' 'gang' '##bang' 'cu' '##cko'
#  '##ld']
# Sentencia final: 3
# ['rt', 'ol', '##sm', '##eh', '##a', '##86', 'he', 'want', 'me', 'to', 'eat', 'his', 'dick', 'because', 'eat', 'dick', 'it', 'work', 'my', 'skill', 'sl', '##ut', 'ass', 'dick', 'butt', 'penis', '##bai', '##t', 'moran', 'croft', '##bang', 'susie', '##cko', '##ld']
#
#
# Sentencia original:
# ['rt' 'tia' '##po' '##gai' '##51' 'please' 'sleep' 'i' 'will' 'do' 'it'
#  'for' 'you' 'guy' 'gt' 'register' 'note' 'verify' 'email' 'to' 'send'
#  'ms' '##g' 'to' 'girls' 'sl' '##ut']
# Sentencia final: 3
# ['rt', 'tia', '##po', '##gai', '##51', 'please', 'slept', 'slept', 'will', 'have', 'it', 'for', 'you', 'guy', 'gt', 'register', 'note', 'compute', 'email', 'to', 'copying', 'ms', '##g', 'to', 'boys', 'sl', '##ut']
#
#
# # terms modificados promedio 5.54772937905468 términos por sentencia
# Largo de sentencia promedio 24.099165894346616 términos por sentencia
# para esta ejecución se debiesen reemplazar 6820  de 13638 terminos
# Resumen de modificaciones: {'JJ': 410, 'NN': 4540, 'NNS': 371, 'VBG': 172, 'VB': 179, 'VBP': 38, 'VBZ': 109, 'VBN': 89, 'VBD': 64, 'JJS': 13, 'JJR': 1}
# Este proceso tomó 38.68378663063049 seg
#
#
# Generando 0 nuevos ejemplos para la clase NonH
# Consultando por la clase NonH
# Entrega label 0
# No se generan ejemplos
# Resumen de modificaciones: {}
# Este proceso tomó 0.43619203567504883 seg
#
#
# Generando 3585 nuevos ejemplos para la clase PhysicalH
# Consultando por la clase PhysicalH
# Entrega label 2
# Sentencia original:
# ['deep' '##th' '##ro' '##at' 'cum' '##shot' 'perfect' 'boo' '##bs'
#  'jewish' 'indian' 'pussy' 'naked' 'lesbian' 'japanese' 'beau' '##t' 'x'
#  '##8' '##9' 't' 'co' 'g' '##f' '##w' '##x' '##st' '##n' '##2' '##fk']
# Sentencia final: 2
# ['deep', '##th', '##ro', '##at', 'cum', '##shot', 'perfect', 'chopped', '##bs', 'jewish', 'indian', 'pussy', 'naked', 'lesbian', 'japanese', 'racist', '##t', 'x', '##8', '##9', 't', 'hu', 'g', '##f', '##w', '##x', '##st', '##n', '##2', '##fk']
#
#
# Sentencia original:
# ['rt' 'debbie' '##d' '##7' '##47' '##9' '##9' '##11' '##8' 'steve' '##d'
#  '##48' '##48' 'how' 'dare' 'she' 'honest' 'people' 'and' 'children'
#  'were' 'killed' 'in' 'manchester' 'and' 'this' 'sc' '##um' 'says' 'that'
#  's' 'fair' 're' '##tal' '##i']
# Sentencia final: 2
# ['rt', 'behave', '##d', '##7', '##47', '##9', '##9', '##11', '##8', 'hussain', '##d', '##48', '##48', 'how', 'behave', 'she', 'honest', 'people', 'and', 'women', 'were', 'tortured', 'in', 'manchester', 'and', 'this', 'sc', '##um', 'wants', 'that', 's', 'fair', 'head', '##tal', '##i']
#
#
# Sentencia original:
# ['pr' '##ae' '##tors' '##uit' 'which' 'specifically' 'i' 'x' '##8' '##9'
#  'd' 'personally' 'pitch' 'black' 'world' 'devil' 'there' 'rap' '##ist'
#  'an' 'x' '##8' '##9' 't' 'co' 'bu' '##rg' '##t' '##j' '##fr' '##ya']
# Sentencia final: 2
# ['pr', '##ae', '##tors', '##uit', 'which', 'specifically', 'world', 'cute', '##8', '##9', 'd', 'personally', 'pitch', 'white', 'baby', 'devil', 'there', 'murderer', '##ist', 'an', 'wall', '##8', '##9', 'useless', 'co', 'bu', '##rg', '##t', '##j', '##fr', '##ya']
#
#
# Sentencia original:
# ['sas' '##sy' 'wants' 'signing' 'first' 'prepare' 'good' 'don' 't' 'know'
#  'x' '##8' '##9' 't' 'co' 'qi' '##q' '##gi' '##b' '##17' '##ik']
# Sentencia final: 2
# ['want', '##sy', 'gets', 'behave', 'first', 'prepare', 'good', 'love', 't', 'know', 'hussain', '##8', '##9', 'rt', 'co', 'qi', '##q', '##gi', '##b', '##17', '##ik']
#
#
# Sentencia original:
# ['bb' '##adi' '##cal' '##i' 'sarcastic' '##fe' '##m' '##23' 'ms' '##vani'
#  '##llar' '##ose' 'facebook' 'habit' '##ually' 'hara' '##ss' 'calling'
#  'addicted' 'drug' '##gy' 'hooker' 'for' 'x' '##8' '##9']
# Sentencia final: 2
# ['bb', '##adi', '##cal', '##i', 'aesthetic', '##fe', '##m', '##23', 'rt', '##vani', '##llar', '##ose', 'facebook', 'twitter', '##ually', 'hara', '##ss', 'calling', 'addicted', 'drug', '##gy', 'hooker', 'for', 'cute', '##8', '##9']
#
#
# Sentencia original:
# ['hot' 'british' 'sl' '##ut' 'cr' '##iss' '##y' 'will' 'give' 'you' 'a'
#  'wet' 'dream' 'when' 'she' 'rubs' 'on' 'her' 'pussy' 'cam' '##girl']
# Sentencia final: 2
# ['black', 'british', 'chopped', '##ut', 'cr', '##iss', '##y', 'will', 'have', 'you', 'a', 'wet', 'wish', 'when', 'she', 'rubs', 'on', 'her', 'gonna', 'girl', '##girl']
#
#
# Sentencia original:
# ['the' 'woman' 'brutally' 'tortured' 'minor' 'servant' 'starved' 'major'
#  'am' '##mara' 'm' 'x' '##8' '##9' 't' 'co' 'y' '##j' '##9' '##6' '##d'
#  '##2' '##x' '##gr' '##p']
# Sentencia final: 2
# ['the', 'woman', 'brutally', 'obliged', 'hooker', 'anwar', 'addicted', 'big', 'are', '##mara', 'rt', 'x', '##8', '##9', 't', 'eve', 'y', '##j', '##9', '##6', '##d', '##2', '##x', '##gr', '##p']
#
#
# Sentencia original:
# ['p' '##0' '##rn' '##sf' '##w' 'daddy' 'behave' 'baby' 'daddy' 'tight'
#  'open' 'yeah' 'little' 'x' '##8' '##9']
# Sentencia final: 2
# ['p', '##0', '##rn', '##sf', '##w', 'anwar', 'behave', 'baby', 'juicy', 'tight', 'open', 'yeah', 'other', 'homework', '##8', '##9']
# Sentencia original:
# ['what' 'i' 'don' 't' 'get' 'is' 'how' 'y' 'all' 'try' 'to' 'drag' 'becky'
#  'for' 'body' 'shame' 'charlotte' 'when' 'she' 'didn' 't' 'but' 'laugh'
#  'at' 'a' 'fan' 'th']
# Sentencia final: 2
# ['what', 'head', 'didn', 'time', 'get', 'has', 'how', 'y', 'all', 'laugh', 'to', 'drag', 'becky', 'for', 'murderer', 'bed', 'charlotte', 'when', 'she', 'didn', 't', 'but', 'th', 'at', 'a', 'hasn', 'way']
#
#
# # terms modificados promedio 5.622036262203626 términos por sentencia
# Largo de sentencia promedio 24.10878661087866 términos por sentencia
# para esta ejecución se debiesen reemplazar 22090  de 44287 terminos
# Resumen de modificaciones: {'NN': 15089, 'NNS': 893, 'VBN': 387, 'VBZ': 566, 'JJ': 1015, 'VB': 867, 'VBP': 143, 'VBD': 382, 'VBG': 745, 'JJS': 68}
# Este proceso tomó 83.13538837432861 seg
#
#
# Generando 3606 nuevos ejemplos para la clase IndirectH
# Consultando por la clase IndirectH
# Entrega label 1
# Sentencia original:
# ['the' 'people' 'that' 'work' 'in' 'the' 'dining' 'hall' 'are' 'all'
#  'sitting' 'here' 'talking' 'shit' 'about' 'this' 'girl' 'that' 'came'
#  'in' 'first' 'thing']
# Sentencia final: 1
# ['the', 'people', 'that', 'work', 'in', 'the', 'dining', 'hall', 'are', 'all', 'being', 'here', 'messing', 'dude', 'about', 'this', 'man', 'that', 'came', 'in', 'first', 'thing']
#
#
# Sentencia original:
# ['i' 'will' 'never' 'understand' 'how' 'girls' 'can' 'sl' '##ut' 'shame'
#  'other' 'girls' 'for' 'having' 'male' 'friends']
# Sentencia final: 1
# ['co', 'will', 'never', 'feminism', 'how', 'girls', 'can', 'sl', '##ut', 'girl', 'unacceptable', 'girls', 'for', 'being', 'hairy', 'people']
#
#
# Sentencia original:
# ['shy' '##ler' '##lit' '##tle' '##e' 'honestly' 'can' 'x' '##8' '##9' 't'
#  'relate' 'girls' 'shame' 'different' 'every' 'weekend' 'fuck' '##in'
#  'number' 'x' '##8' '##9']
# Sentencia final: 1
# ['faulty', '##ler', '##lit', '##tle', '##e', 'honestly', 'can', 'asleep', '##8', '##9', 't', 'relate', 'girlfriends', 'shame', 'disappointed', 'every', 'faulty', 'fuck', '##in', 'faulty', 'x', '##8', '##9']
#
#
# Sentencia original:
# ['the' '##kat' '##ied' '##ren' '##nen' 'katie' 'is' 'totally' 'turning'
#  'into' 'one' 'of' 'those' 'girls' 'who' 'gets' 'married' 'and' 'forget'
#  'two' 'years' 'ago' 'she' 'wa']
# Sentencia final: 1
# ['the', '##kat', '##ied', '##ren', '##nen', 'feminism', 'has', 'totally', 'taking', 'into', 'one', 'of', 'those', 'boys', 'who', 'wants', 'uploaded', 'and', 'wife', 'two', 'thinks', 'ago', 'she', 'wa']
#
#
# Sentencia original:
# ['baku' '##bro' '##ws' 'freaked' '##by' '##du' '##bu' '##l' '##g' 'sara'
#  '##ot' '##5' 'how' 'can' 'u' 'go' 'from' 'wonder' 'girls' 'and' 'miss'
#  'a' 'to' 'twice' 'and' 'these' 'ladies' 'l' '##m' '##fa' '##o' 'i' 'can'
#  't']
# Sentencia final: 1
# ['baku', '##bro', '##ws', 'freaked', '##by', '##du', '##bu', '##l', '##g', 'sara', '##ot', '##5', 'how', 'can', 'u', 'be', 'from', 'wonder', 'girls', 'and', 'miss', 'a', 'to', 'twice', 'and', 'these', 'ladies', 'leftist', '##m', '##fa', '##o', 'work', 'can', 't']
#
#
# Sentencia original:
# ['love' '##toy' 'ca' 'that' 's' 'a' 'well' 'trained' 'girl']
# Sentencia final: 1
# ['hate', '##toy', 'ca', 'that', 'time', 'a', 'well', 'trained', 'woman']
#
#
# Sentencia original:
# ['just' 'inn' '##7' 'kai' '##tma' '##rie' '##ox' 'sl' '##ut' 'arm' '##pit'
#  '##s' 'hairy' 'surely' 'don' 't' 'feminist' 'so' 'x' '##8' '##9' 't' 'co'
#  'ca' '##y' '##z' '##13' '##cu' '##3' '##e']
# Sentencia final: 1
# ['just', 'inn', '##7', 'kai', '##tma', '##rie', '##ox', 'wa', '##ut', 'arm', '##pit', '##s', 'leftist', 'surely', 'didn', 'didn', 'leftist', 'so', 'x', '##8', '##9', 'school', 'co', 'ca', '##y', '##z', '##13', '##cu', '##3', '##e']
#
#
# Sentencia original:
# ['number' 't' 'you' 'should' 'do' 'to' 'him' 'all' 'by' 'now' 'you' 'will'
#  'need' 'to' 'make' 'him' 'a' 'few' 'times' 'until' 'she' 'is' 'ready'
#  'and' 'he' 'just' 'lets' 'h']
# Sentencia final: 1
# ['time', 'time', 'you', 'should', 'do', 'to', 'him', 'all', 'by', 'now', 'you', 'will', 'need', 'to', 'have', 'him', 'a', 'few', 'times', 'until', 'she', 'is', 'black', 'and', 'he', 'just', 'mosques', 'll']
#
#
# Sentencia original:
# ['mrs' 'hc' '##m' 'tr' '##ad' '##po' '##aster' '##100' '##0' 'also'
#  'though' 'if' 'eggs' 'are' 'the' 'resource' 'guys' 'are' 'after' 'vs' 'a'
#  'good' 'and' 'vi' '##rt' '##uous' 'wife' 'who' 'will']
# Sentencia final: 1
# ['mrs', 'leftist', '##m', 'tr', '##ad', '##po', '##aster', '##100', '##0', 'also', 'though', 'if', 'eggs', 'are', 'the', 'resource', 'guys', 'are', 'after', 'mrs', 'a', 'good', 'and', 'vi', '##rt', '##uous', 'girlfriend', 'who', 'will']
#
#
# # terms modificados promedio 5.098169717138103 términos por sentencia
# Largo de sentencia promedio 22.820854132002218 términos por sentencia
# para esta ejecución se debiesen reemplazar 20113  de 40213 terminos
# Resumen de modificaciones: {'VBG': 746, 'NN': 13081, 'JJ': 1081, 'NNS': 1309, 'VBZ': 580, 'VB': 617, 'VBP': 41, 'VBN': 576, 'VBD': 353}
# Este proceso tomó 75.55966567993164 seg
#
# --------------------------------------------------------
#
# Generando ejemplos en base a probabilidad -->  0.5
# --------------------------------------------------------
#
#
# Generando 1079 nuevos ejemplos para la clase SexualH
# Consultando por la clase SexualH
# Entrega label 3
# Sentencia original:
# ['pic' 'mexican' 'school' 'girl' 'naked' 'melanie' 'sa' '##fk' '##a'
#  'fake' 'nude' 'photos' 'hardcore' 'sl' '##ut' 'movies' 'alicia' 'moore'
#  'porn' 'star' 'too' '##n' 'love']
# Sentencia final: 3
# ['pic', 'mexican', 'school', 'girl', 'naked', 'melanie', 'sa', '##fk', '##a', 'gangster', 'nude', 'photos', 'hardcore', 'brighton', '##ut', 'movies', 'alicia', 'moore', 'porn', 'star', 'too', '##n', 'love']
#
#
# Sentencia original:
# ['girl' 'dirty' 'quarterback' 'latino' 'pokemon' 'young' 'hand' '##jo'
#  '##b' 'kissing' 'gang' '##bang' 'w' 'x' '##8' '##9' 't' 'co' 'wr' '##m'
#  '##4' '##x' '##o' '##00' '##v' '##j']
# Sentencia final: 3
# ['prostitute', 'brunette', 'boy', 'latino', 'pokemon', 'young', 'pinto', '##jo', '##b', 'embracing', 'gang', '##bang', 'w', 'x', '##8', '##9', 't', 'co', 'wr', '##m', '##4', '##x', '##o', '##00', '##v', '##j']
#
#
# Sentencia original:
# ['mil' '##ion' '##do' '##lla' '##me' '##at' 'sex' '##ting' 'n' 'ng' '##ir'
#  '##l' 'daddy' 'n' 'nme' 'listen' 'bitch' 'gonna' 'watch' 'these' 'what']
# Sentencia final: 3
# ['mil', '##ion', '##do', '##lla', '##me', '##at', 'sex', '##ting', 'n', 'hs', '##ir', '##l', 'daddy', 'mommy', 'nme', 'listen', 'bitch', 'gonna', 'watch', 'these', 'what']
#
#
# Sentencia original:
# ['museum' 'sl' '##ut' 'if' 'you' 'know' 'somewhere' 'we' 'can' 'do' 'it'
#  'then' 'i' 'am' 'game']
# Sentencia final: 3
# ['museum', 'bat', '##ut', 'if', 'you', 'know', 'somewhere', 'we', 'can', 'do', 'it', 'then', 'day', 'am', 'time']
#
#
# Sentencia original:
# ['rt' 'sp' '##00' '##ky' '##bit' '##ch' '##hh' '##h' 'i' 'have' 'spots'
#  'open' 'sis' '##sy' 'sl' '##ut' 'into' '##x' 'bitch' 'human' 'atm'
#  'amazon' 'boy' 'do' 'you' 'have' 'what' 'it' 'takes' 'can' 'you' 'live'
#  'up' 'to' 'my']
# Sentencia final: 3
# ['rt', 'sp', '##00', '##ky', '##bit', '##ch', '##hh', '##h', 'i', 'have', 'spots', 'active', 'sis', '##sy', 'sl', '##ut', 'into', '##x', 'bitch', 'blockbuster', 'atm', 'girl', 'boy', 'do', 'you', 'have', 'what', 'it', 'takes', 'can', 'you', 'live', 'up', 'to', 'my']
#
#
# Sentencia original:
# ['venus' 'astro' '##logy' 'living' 'standards' 'ni' '##t' 'x' '##8' '##9'
#  's' 'illusion' 'i' 'x' '##8' '##9' 'm' 'fucking' 'nwa' '##iting'
#  'waiting' 'wai' 'x' '##8' '##9']
# Sentencia final: 3
# ['venus', 'astro', '##logy', 'woken', 'standards', 'standard', '##t', 'x', '##8', '##9', 's', 'illusion', 'i', 'x', '##8', '##9', 'm', 'moaning', 'nwa', '##iting', 'waiting', 'wai', 'x', '##8', '##9']
#
#
# Sentencia original:
# ['add' 'me' 'on' 'snap' '##cha' '##t' 'and' 'watch' 'me' 'cum' 'colt'
#  '##oe' '##8' 'send' '##nu' '##des' 'nude' 'nude' 'snap' '##cha' '##t'
#  'girls' 'boo' '##bs' 'pussy' 'horn' '##y']
# Sentencia final: 3
# ['expect', 'me', 'on', 'snap', '##cha', '##t', 'and', 'watch', 'me', 'cum', 'colt', '##oe', '##8', 'send', '##nu', '##des', 'prostitute', 'kemp', 'disgrace', '##cha', '##t', 'girls', 'boo', '##bs', 'pussy', 'horn', '##y']
#
#
# Sentencia original:
# ['rt' 'ole' '##sm' '##eh' '##a' '##86' 'he' 'need' 'me' 'to' 'eat' 'his'
#  'dick' 'because' 'eat' 'dick' 'it' 's' 'my' 'skill' 'sl' '##ut' 'ass'
#  'dick' 'cock' 'jail' '##bai' '##t' 'bbc' 'gang' '##bang' 'cu' '##cko'
#  '##ld']
# Sentencia final: 3
# ['nt', 'ol', '##sm', '##eh', '##a', '##86', 'he', 'bonn', 'me', 'to', 'ate', 'his', 'dick', 'because', 'eat', 'drink', 'it', 'waist', 'my', 'skill', 'sl', '##ut', 'ass', 'butt', 'cock', 'jail', '##bai', '##t', 'bbc', 'gang', '##bang', 'cu', '##cko', '##ld']
#
#
# Sentencia original:
# ['rt' 'tia' '##po' '##gai' '##51' 'please' 'sleep' 'i' 'will' 'do' 'it'
#  'for' 'you' 'guy' 'gt' 'register' 'note' 'verify' 'email' 'to' 'send'
#  'ms' '##g' 'to' 'girls' 'sl' '##ut']
# Sentencia final: 3
# ['gia', 'tia', '##po', '##gai', '##51', 'please', 'sleep', 'i', 'will', 'go', 'it', 'for', 'you', 'brunette', 'gt', 'needy', 'note', 'clench', 'ipad', 'to', 'send', 'day', '##g', 'to', 'girls', 'girl', '##ut']
# # terms modificados promedio 5.414272474513439 términos por sentencia
# Largo de sentencia promedio 24.047265987025025 términos por sentencia
# para esta ejecución se debiesen reemplazar 6664  de 13576 terminos
# Resumen de modificaciones: {'NN': 4454, 'VBG': 190, 'JJ': 416, 'VB': 169, 'NNS': 317, 'VBZ': 113, 'VBN': 87, 'VBD': 57, 'VBP': 25, 'JJS': 12, 'JJR': 2}
# Este proceso tomó 37.58118462562561 seg
#
#
# Generando 0 nuevos ejemplos para la clase NonH
# Consultando por la clase NonH
# Entrega label 0
# No se generan ejemplos
# Resumen de modificaciones: {}
# Este proceso tomó 0.4368889331817627 seg
#
#
# Generando 3585 nuevos ejemplos para la clase PhysicalH
# Consultando por la clase PhysicalH
# Entrega label 2
# Sentencia original:
# ['deep' '##th' '##ro' '##at' 'cum' '##shot' 'perfect' 'boo' '##bs'
#  'jewish' 'indian' 'pussy' 'naked' 'lesbian' 'japanese' 'beau' '##t' 'x'
#  '##8' '##9' 't' 'co' 'g' '##f' '##w' '##x' '##st' '##n' '##2' '##fk']
# Sentencia final: 2
# ['world', '##th', '##ro', '##at', 'cum', '##shot', 'perfect', 'chopped', '##bs', 'muslim', 'indian', 'pussy', 'islamic', 'jealous', 'japanese', 'beau', '##t', 'minor', '##8', '##9', 'rt', 'se', 'se', '##f', '##w', '##x', '##st', '##n', '##2', '##fk']
#
#
# Sentencia original:
# ['rt' 'debbie' '##d' '##7' '##47' '##9' '##9' '##11' '##8' 'steve' '##d'
#  '##48' '##48' 'how' 'dare' 'she' 'honest' 'people' 'and' 'children'
#  'were' 'killed' 'in' 'manchester' 'and' 'this' 'sc' '##um' 'says' 'that'
#  's' 'fair' 're' '##tal' '##i']
# Sentencia final: 2
# ['rt', 'behave', '##d', '##7', '##47', '##9', '##9', '##11', '##8', 'steve', '##d', '##48', '##48', 'how', 'dare', 'she', 'everybody', 'people', 'and', 'children', 'were', 'killed', 'in', 'kill', 'and', 'this', 'state', '##um', 'is', 'that', 'racist', 'fair', 're', '##tal', '##i']
#
#
# Sentencia original:
# ['pr' '##ae' '##tors' '##uit' 'which' 'specifically' 'i' 'x' '##8' '##9'
#  'd' 'personally' 'pitch' 'black' 'world' 'devil' 'there' 'rap' '##ist'
#  'an' 'x' '##8' '##9' 't' 'co' 'bu' '##rg' '##t' '##j' '##fr' '##ya']
# Sentencia final: 2
# ['rt', '##ae', '##tors', '##uit', 'which', 'specifically', 'i', 'x', '##8', '##9', 'hussain', 'personally', 'pitch', 'black', 'world', 'state', 'there', 'rap', '##ist', 'an', 'x', '##8', '##9', 're', 'co', 'bu', '##rg', '##t', '##j', '##fr', '##ya']
#
#
# Sentencia original:
# ['sas' '##sy' 'wants' 'signing' 'first' 'prepare' 'good' 'don' 't' 'know'
#  'x' '##8' '##9' 't' 'co' 'qi' '##q' '##gi' '##b' '##17' '##ik']
# Sentencia final: 2
# ['sas', '##sy', 'wants', 'behave', 'first', 'destroy', 'ready', 'don', 'didn', 'know', 'x', '##8', '##9', 't', 'co', 'qi', '##q', '##gi', '##b', '##17', '##ik']
#
#
# Sentencia original:
# ['bb' '##adi' '##cal' '##i' 'sarcastic' '##fe' '##m' '##23' 'ms' '##vani'
#  '##llar' '##ose' 'facebook' 'habit' '##ually' 'hara' '##ss' 'calling'
#  'addicted' 'drug' '##gy' 'hooker' 'for' 'x' '##8' '##9']
# Sentencia final: 2
# ['ll', '##adi', '##cal', '##i', 'sarcastic', '##fe', '##m', '##23', 'family', '##vani', '##llar', '##ose', 'facebook', 'habit', '##ually', 'hara', '##ss', 'choking', 'addicted', 'drug', '##gy', 'hooker', 'for', 'x', '##8', '##9']
#
#
# Sentencia original:
# ['hot' 'british' 'sl' '##ut' 'cr' '##iss' '##y' 'will' 'give' 'you' 'a'
#  'wet' 'dream' 'when' 'she' 'rubs' 'on' 'her' 'pussy' 'cam' '##girl']
# Sentencia final: 2
# ['other', 'british', 'sl', '##ut', 'fl', '##iss', '##y', 'will', 'have', 'you', 'a', 'wet', 'life', 'when', 'she', 'rubs', 'on', 'her', 'pussy', 'gonna', '##girl']
#
#
# Sentencia original:
# ['the' 'woman' 'brutally' 'tortured' 'minor' 'servant' 'starved' 'major'
#  'am' '##mara' 'm' 'x' '##8' '##9' 't' 'co' 'y' '##j' '##9' '##6' '##d'
#  '##2' '##x' '##gr' '##p']
# Sentencia final: 2
# ['the', 'gonna', 'brutally', 'tortured', 'hooker', 'servant', 'addicted', 'big', 'are', '##mara', 'anwar', 'chopped', '##8', '##9', 't', 'co', 'y', '##j', '##9', '##6', '##d', '##2', '##x', '##gr', '##p']
#
#
# Sentencia original:
# ['p' '##0' '##rn' '##sf' '##w' 'daddy' 'behave' 'baby' 'daddy' 'tight'
#  'open' 'yeah' 'little' 'x' '##8' '##9']
# Sentencia final: 2
# ['se', '##0', '##rn', '##sf', '##w', 'anwar', 'anwar', 'cute', 'strict', 'juicy', 'open', 'fat', 'little', 'x', '##8', '##9']
#
#
# Sentencia original:
# ['what' 'i' 'don' 't' 'get' 'is' 'how' 'y' 'all' 'try' 'to' 'drag' 'becky'
#  'for' 'body' 'shame' 'charlotte' 'when' 'she' 'didn' 't' 'but' 'laugh'
#  'at' 'a' 'fan' 'th']
# Sentencia final: 2
# ...
#  'into' 'one' 'of' 'those' 'girls' 'who' 'gets' 'married' 'and' 'forget'
#  'two' 'years' 'ago' 'she' 'wa']
# Sentencia final: 1
# ['the', '##kat', '##ied', '##ren', '##nen', 'katie', 'gets', 'totally', 'taking', 'into', 'one', 'of', 'those', 'girls', 'who', 'gets', 'married', 'and', 'feminism', 'two', 'aren', 'ago', 'she', 'wa']
#
#
# Sentencia original:
# ['baku' '##bro' '##ws' 'freaked' '##by' '##du' '##bu' '##l' '##g' 'sara'
#  '##ot' '##5' 'how' 'can' 'u' 'go' 'from' 'wonder' 'girls' 'and' 'miss'
#  'a' 'to' 'twice' 'and' 'these' 'ladies' 'l' '##m' '##fa' '##o' 'i' 'can'
#  't']
# Sentencia final: 1
# ['baku', '##bro', '##ws', 'freaked', '##by', '##du', '##bu', '##l', '##g', 'leftist', '##ot', '##5', 'how', 'can', 'u', 'go', 'from', 'wonder', 'girls', 'and', 'miss', 'a', 'to', 'twice', 'and', 'these', 'ladies', 'woman', '##m', '##fa', '##o', 'i', 'can', 't']
#
#
# Sentencia original:
# ['love' '##toy' 'ca' 'that' 's' 'a' 'well' 'trained' 'girl']
# Sentencia final: 1
# ['love', '##toy', 'ca', 'that', 's', 'a', 'well', 'trained', 'girlfriend']
#
#
# Sentencia original:
# ['just' 'inn' '##7' 'kai' '##tma' '##rie' '##ox' 'sl' '##ut' 'arm' '##pit'
#  '##s' 'hairy' 'surely' 'don' 't' 'feminist' 'so' 'x' '##8' '##9' 't' 'co'
#  'ca' '##y' '##z' '##13' '##cu' '##3' '##e']
# Sentencia final: 1
# ['just', 'inn', '##7', 'kai', '##tma', '##rie', '##ox', 'cheryl', '##ut', 'arm', '##pit', '##s', 'didn', 'surely', 'didn', 'didn', 'feminist', 'so', 'feminism', '##8', '##9', 'rt', 'co', 'ca', '##y', '##z', '##13', '##cu', '##3', '##e']
#
#
# Sentencia original:
# ['number' 't' 'you' 'should' 'do' 'to' 'him' 'all' 'by' 'now' 'you' 'will'
#  'need' 'to' 'make' 'him' 'a' 'few' 'times' 'until' 'she' 'is' 'ready'
#  'and' 'he' 'just' 'lets' 'h']
# Sentencia final: 1
# ['work', 't', 'you', 'should', 'see', 'to', 'him', 'all', 'by', 'now', 'you', 'will', 'want', 'to', 'have', 'him', 'a', 'few', 'times', 'until', 'she', 'is', 'much', 'and', 'he', 'just', 'mosques', 'h']
#
#
# Sentencia original:
# ['mrs' 'hc' '##m' 'tr' '##ad' '##po' '##aster' '##100' '##0' 'also'
#  'though' 'if' 'eggs' 'are' 'the' 'resource' 'guys' 'are' 'after' 'vs' 'a'
#  'good' 'and' 'vi' '##rt' '##uous' 'wife' 'who' 'will']
# Sentencia final: 1
# ['mrs', 'hc', '##m', 'rt', '##ad', '##po', '##aster', '##100', '##0', 'also', 'though', 'if', 'aren', 'are', 'the', 'resource', 'aren', 'are', 'after', 'right', 'a', 'new', 'and', 'vi', '##rt', '##uous', 'girlfriend', 'who', 'will']
# # terms modificados promedio 5.12534664448142 términos por sentencia
# Largo de sentencia promedio 22.86577925679423 términos por sentencia
# para esta ejecución se debiesen reemplazar 20193  de 40304 terminos
# Resumen de modificaciones: {'NN': 13086, 'VBG': 779, 'VBD': 374, 'JJ': 1091, 'NNS': 1352, 'VBZ': 615, 'VB': 591, 'VBN': 560, 'VBP': 34}
# Este proceso tomó 75.75208497047424 seg
#
# --------------------------------------------------------
#
# Generando ejemplos en base a probabilidad -->  0.5
# --------------------------------------------------------
#
#
# Generando 1079 nuevos ejemplos para la clase SexualH
# Consultando por la clase SexualH
# Entrega label 3
# Sentencia original:
# ['pic' 'mexican' 'school' 'girl' 'naked' 'melanie' 'sa' '##fk' '##a'
#  'fake' 'nude' 'photos' 'hardcore' 'sl' '##ut' 'movies' 'alicia' 'moore'
#  'porn' 'star' 'too' '##n' 'love']
# Sentencia final: 3
# ['college', 'mexican', 'nude', 'teenager', 'appalled', 'melanie', 'yvonne', '##fk', '##a', 'fake', 'photo', 'photos', 'photo', 'brighton', '##ut', 'james', 'alicia', 'moore', 'porn', 'cleavage', 'too', '##n', 'music']
#
#
# Sentencia original:
# ['girl' 'dirty' 'quarterback' 'latino' 'pokemon' 'young' 'hand' '##jo'
#  '##b' 'kissing' 'gang' '##bang' 'w' 'x' '##8' '##9' 't' 'co' 'wr' '##m'
#  '##4' '##x' '##o' '##00' '##v' '##j']
# Sentencia final: 3
# ['boy', 'brunette', 'boy', 'latino', 'pokemon', 'noteworthy', 'hand', '##jo', '##b', 'kissing', 'gang', '##bang', 'w', 'x', '##8', '##9', 'rb', 'co', 'wr', '##m', '##4', '##x', '##o', '##00', '##v', '##j']
#
#
# Sentencia original:
# ['mil' '##ion' '##do' '##lla' '##me' '##at' 'sex' '##ting' 'n' 'ng' '##ir'
#  '##l' 'daddy' 'n' 'nme' 'listen' 'bitch' 'gonna' 'watch' 'these' 'what']
# Sentencia final: 3
# ['mil', '##ion', '##do', '##lla', '##me', '##at', 'sex', '##ting', 'intercourse', 'hs', '##ir', '##l', 'mommy', 'n', 'nme', 'listen', 'bitch', 'gotta', 'wanna', 'these', 'what']
#
#
# Sentencia original:
# ['museum' 'sl' '##ut' 'if' 'you' 'know' 'somewhere' 'we' 'can' 'do' 'it'
#  'then' 'i' 'am' 'game']
# Sentencia final: 3
# ['league', 'bat', '##ut', 'if', 'you', 'believe', 'somewhere', 'we', 'can', 'run', 'it', 'then', 'time', 'am', 'time']
#
#
# Sentencia original:
# ['rt' 'sp' '##00' '##ky' '##bit' '##ch' '##hh' '##h' 'i' 'have' 'spots'
#  'open' 'sis' '##sy' 'sl' '##ut' 'into' '##x' 'bitch' 'human' 'atm'
#  'amazon' 'boy' 'do' 'you' 'have' 'what' 'it' 'takes' 'can' 'you' 'live'
#  'up' 'to' 'my']
# Sentencia final: 3
# ['rt', 'sp', '##00', '##ky', '##bit', '##ch', '##hh', '##h', 'need', 'have', 'spots', 'open', 'salty', '##sy', 'gal', '##ut', 'into', '##x', 'bitch', 'human', 'atm', 'amazon', 'boy', 'know', 'you', 'know', 'what', 'it', 'takes', 'can', 'you', 'live', 'up', 'to', 'my']
#
#
# Sentencia original:
# ['venus' 'astro' '##logy' 'living' 'standards' 'ni' '##t' 'x' '##8' '##9'
#  's' 'illusion' 'i' 'x' '##8' '##9' 'm' 'fucking' 'nwa' '##iting'
#  'waiting' 'wai' 'x' '##8' '##9']
# Sentencia final: 3
# ['venus', 'astro', '##logy', 'standard', 'cooks', 'standard', '##t', 'np', '##8', '##9', 'croft', 'illusion', 'i', 'ik', '##8', '##9', 'pentagon', 'freaking', 'nwa', '##iting', 'yelling', 'wai', 'ce', '##8', '##9']
#
#
# Sentencia original:
# ['add' 'me' 'on' 'snap' '##cha' '##t' 'and' 'watch' 'me' 'cum' 'colt'
#  '##oe' '##8' 'send' '##nu' '##des' 'nude' 'nude' 'snap' '##cha' '##t'
#  'girls' 'boo' '##bs' 'pussy' 'horn' '##y']
# Sentencia final: 3
# ['say', 'me', 'on', 'snap', '##cha', '##t', 'and', 'watch', 'me', 'cum', 'colt', '##oe', '##8', 'anand', '##nu', '##des', 'prostitute', 'nude', 'disgrace', '##cha', '##t', 'girls', 'boo', '##bs', 'pussy', 'horn', '##y']
#
#
# Sentencia original:
# ['rt' 'ole' '##sm' '##eh' '##a' '##86' 'he' 'need' 'me' 'to' 'eat' 'his'
#  'dick' 'because' 'eat' 'dick' 'it' 's' 'my' 'skill' 'sl' '##ut' 'ass'
#  'dick' 'cock' 'jail' '##bai' '##t' 'bbc' 'gang' '##bang' 'cu' '##cko'
#  '##ld']
# Sentencia final: 3
# ['nt', 'ole', '##sm', '##eh', '##a', '##86', 'he', 'need', 'me', 'to', 'eat', 'his', 'ate', 'because', 'cock', 'dick', 'it', 's', 'my', 'skill', 'sl', '##ut', 'ass', 'butt', 'butt', 'jail', '##bai', '##t', 'duran', 'gang', '##bang', 'duran', '##cko', '##ld']
#
#
# Sentencia original:
# ['rt' 'tia' '##po' '##gai' '##51' 'please' 'sleep' 'i' 'will' 'do' 'it'
#  'for' 'you' 'guy' 'gt' 'register' 'note' 'verify' 'email' 'to' 'send'
#  'ms' '##g' 'to' 'girls' 'sl' '##ut']
# Sentencia final: 3
# ['rt', 'tia', '##po', '##gai', '##51', 'please', 'creamy', 'i', 'will', 'say', 'it', 'for', 'you', 'guy', 'gt', 'pinto', 'note', 'jogging', 'email', 'to', 'send', 'ns', '##g', 'to', 'boys', 'girl', '##ut']
#
#
# # terms modificados promedio 5.4763670064874885 términos por sentencia
# Largo de sentencia promedio 24.09731232622799 términos por sentencia
# para esta ejecución se debiesen reemplazar 6770  de 13608 terminos
# Resumen de modificaciones: {'NN': 4472, 'JJ': 414, 'NNS': 341, 'VB': 177, 'VBG': 194, 'VBZ': 105, 'VBN': 97, 'VBD': 62, 'VBP': 32, 'JJS': 14, 'JJR': 1}
# Este proceso tomó 37.657217025756836 seg
#
#
# Generando 0 nuevos ejemplos para la clase NonH
# Consultando por la clase NonH
# Entrega label 0
# No se generan ejemplos
# Resumen de modificaciones: {}
# Este proceso tomó 0.43819379806518555 seg
#
#
# Generando 3585 nuevos ejemplos para la clase PhysicalH
# Consultando por la clase PhysicalH
# Entrega label 2
# Sentencia original:
# ['deep' '##th' '##ro' '##at' 'cum' '##shot' 'perfect' 'boo' '##bs'
#  'jewish' 'indian' 'pussy' 'naked' 'lesbian' 'japanese' 'beau' '##t' 'x'
#  '##8' '##9' 't' 'co' 'g' '##f' '##w' '##x' '##st' '##n' '##2' '##fk']
# Sentencia final: 2
# ['time', '##th', '##ro', '##at', 'cum', '##shot', 'perfect', 'boo', '##bs', 'muslim', 'indian', 'pussy', 'british', 'jealous', 'japanese', 'beau', '##t', 'line', '##8', '##9', 't', 'co', 'rt', '##f', '##w', '##x', '##st', '##n', '##2', '##fk']
#
#
# Sentencia original:
# ['rt' 'debbie' '##d' '##7' '##47' '##9' '##9' '##11' '##8' 'steve' '##d'
#  '##48' '##48' 'how' 'dare' 'she' 'honest' 'people' 'and' 'children'
#  'were' 'killed' 'in' 'manchester' 'and' 'this' 'sc' '##um' 'says' 'that'
#  's' 'fair' 're' '##tal' '##i']
# Sentencia final: 2
# ['racist', 'behave', '##d', '##7', '##47', '##9', '##9', '##11', '##8', 'hu', '##d', '##48', '##48', 'how', 'behave', 'she', 'everybody', 'women', 'and', 'women', 'were', 'killed', 'in', 'kill', 'and', 'this', 'sc', '##um', 'says', 'that', 's', 'hussain', 're', '##tal', '##i']
#
#
# Sentencia original:
# ['pr' '##ae' '##tors' '##uit' 'which' 'specifically' 'i' 'x' '##8' '##9'
#  'd' 'personally' 'pitch' 'black' 'world' 'devil' 'there' 'rap' '##ist'
#  'an' 'x' '##8' '##9' 't' 'co' 'bu' '##rg' '##t' '##j' '##fr' '##ya']
# Sentencia final: 2
# ['anwar', '##ae', '##tors', '##uit', 'which', 'specifically', 'i', 'cute', '##8', '##9', 'd', 'personally', 'pitch', 'white', 'world', 'devil', 'there', 'life', '##ist', 'an', 'hu', '##8', '##9', 't', 'co', 'bu', '##rg', '##t', '##j', '##fr', '##ya']
#
#
# Sentencia original:
# ['sas' '##sy' 'wants' 'signing' 'first' 'prepare' 'good' 'don' 't' 'know'
#  'x' '##8' '##9' 't' 'co' 'qi' '##q' '##gi' '##b' '##17' '##ik']
# Sentencia final: 2
# ['sas', '##sy', 'gets', 'signing', 'first', 'prepare', 'ready', 'didn', 't', 'do', 'th', '##8', '##9', 't', 'co', 'qi', '##q', '##gi', '##b', '##17', '##ik']
#
#
# Sentencia original:
# ['bb' '##adi' '##cal' '##i' 'sarcastic' '##fe' '##m' '##23' 'ms' '##vani'
#  '##llar' '##ose' 'facebook' 'habit' '##ually' 'hara' '##ss' 'calling'
#  'addicted' 'drug' '##gy' 'hooker' 'for' 'x' '##8' '##9']
# Sentencia final: 2
# ['bb', '##adi', '##cal', '##i', 'aesthetic', '##fe', '##m', '##23', 'rt', '##vani', '##llar', '##ose', 'facebook', 'twitter', '##ually', 'hara', '##ss', 'disgusting', 'addicted', 'suicidal', '##gy', 'shouldn', 'for', 'racist', '##8', '##9']
#
#
# Sentencia original:
# ['hot' 'british' 'sl' '##ut' 'cr' '##iss' '##y' 'will' 'give' 'you' 'a'
#  'wet' 'dream' 'when' 'she' 'rubs' 'on' 'her' 'pussy' 'cam' '##girl']
# Sentencia final: 2
# ['white', 'japanese', 'chopped', '##ut', 'fl', '##iss', '##y', 'will', 'do', 'you', 'a', 'wet', 'day', 'when', 'she', 'rubs', 'on', 'her', 'pussy', 'bullshit', '##girl']
#
#
# Sentencia original:
# ['the' 'woman' 'brutally' 'tortured' 'minor' 'servant' 'starved' 'major'
#  'am' '##mara' 'm' 'x' '##8' '##9' 't' 'co' 'y' '##j' '##9' '##6' '##d'
#  '##2' '##x' '##gr' '##p']
# Sentencia final: 2
# ['the', 'girl', 'brutally', 'tortured', 'beaten', 'servant', 'starved', 'big', 'are', '##mara', 'm', 'x', '##8', '##9', 'rt', 'rt', 'rt', '##j', '##9', '##6', '##d', '##2', '##x', '##gr', '##p']
# Sentencia original:
# ['p' '##0' '##rn' '##sf' '##w' 'daddy' 'behave' 'baby' 'daddy' 'tight'
#  'open' 'yeah' 'little' 'x' '##8' '##9']
# Sentencia final: 2
# ['p', '##0', '##rn', '##sf', '##w', 'daddy', 'anwar', 'baby', 'strict', 'juicy', 'open', 'fair', 'big', 'hussain', '##8', '##9']
#
#
# Sentencia original:
# ['what' 'i' 'don' 't' 'get' 'is' 'how' 'y' 'all' 'try' 'to' 'drag' 'becky'
#  'for' 'body' 'shame' 'charlotte' 'when' 'she' 'didn' 't' 'but' 'laugh'
#  'at' 'a' 'fan' 'th']
# Sentencia final: 2
# ['what', 'i', 'didn', 're', 'be', 'gets', 'how', 're', 'all', 'time', 'to', 'behave', 'becky', 'for', 'girl', 'shame', 'charlotte', 'when', 'she', 'didn', 'doesn', 'but', 'name', 'at', 'a', 'time', 'th']
#
#
# # terms modificados promedio 5.697629009762901 términos por sentencia
# Largo de sentencia promedio 24.12050209205021 términos por sentencia
# para esta ejecución se debiesen reemplazar 22422  de 44337 terminos
# Resumen de modificaciones: {'NN': 15287, 'JJ': 1036, 'NNS': 961, 'VBZ': 569, 'VB': 873, 'VBG': 698, 'VBP': 140, 'JJS': 66, 'VBN': 402, 'VBD': 394}
# Este proceso tomó 84.20009350776672 seg
#
#
# Generando 3606 nuevos ejemplos para la clase IndirectH
# Consultando por la clase IndirectH
# Entrega label 1
# Sentencia original:
# ['the' 'people' 'that' 'work' 'in' 'the' 'dining' 'hall' 'are' 'all'
#  'sitting' 'here' 'talking' 'shit' 'about' 'this' 'girl' 'that' 'came'
#  'in' 'first' 'thing']
# Sentencia final: 1
# ['the', 'women', 'that', 'man', 'in', 'the', 'dining', 'hall', 'are', 'all', 'sitting', 'here', 'being', 'shit', 'about', 'this', 'girl', 'that', 'came', 'in', 'first', 'thing']
#
#
# Sentencia original:
# ['i' 'will' 'never' 'understand' 'how' 'girls' 'can' 'sl' '##ut' 'shame'
#  'other' 'girls' 'for' 'having' 'male' 'friends']
# Sentencia final: 1
# ['i', 'will', 'never', 'girl', 'how', 'girls', 'can', 'faulty', '##ut', 'girl', 'few', 'girls', 'for', 'having', 'faulty', 'girlfriends']
#
#
# Sentencia original:
# ['shy' '##ler' '##lit' '##tle' '##e' 'honestly' 'can' 'x' '##8' '##9' 't'
#  'relate' 'girls' 'shame' 'different' 'every' 'weekend' 'fuck' '##in'
#  'number' 'x' '##8' '##9']
# Sentencia final: 1
# ['shy', '##ler', '##lit', '##tle', '##e', 'honestly', 'can', 'x', '##8', '##9', 't', 'faulty', 'girls', 'faulty', 'other', 'every', 'rapper', 'leftist', '##in', 'number', 'faulty', '##8', '##9']
#
#
# Sentencia original:
# ['the' '##kat' '##ied' '##ren' '##nen' 'katie' 'is' 'totally' 'turning'
#  'into' 'one' 'of' 'those' 'girls' 'who' 'gets' 'married' 'and' 'forget'
#  'two' 'years' 'ago' 'she' 'wa']
# Sentencia final: 1
# ['the', '##kat', '##ied', '##ren', '##nen', 'katie', 'gets', 'totally', 'turning', 'into', 'one', 'of', 'those', 'girls', 'who', 'gets', 'married', 'and', 'forget', 'two', 'years', 'ago', 'she', 'wa']
#
#
# Sentencia original:
# ['baku' '##bro' '##ws' 'freaked' '##by' '##du' '##bu' '##l' '##g' 'sara'
#  '##ot' '##5' 'how' 'can' 'u' 'go' 'from' 'wonder' 'girls' 'and' 'miss'
#  'a' 'to' 'twice' 'and' 'these' 'ladies' 'l' '##m' '##fa' '##o' 'i' 'can'
#  't']
# Sentencia final: 1
# ['baku', '##bro', '##ws', 'freaked', '##by', '##du', '##bu', '##l', '##g', 'leftist', '##ot', '##5', 'how', 'can', 'work', 'do', 'from', 'wonder', 'girls', 'and', 'miss', 'a', 'to', 'twice', 'and', 'these', 'ladies', 'l', '##m', '##fa', '##o', 'i', 'can', 'time']
#
#
# Sentencia original:
# ['love' '##toy' 'ca' 'that' 's' 'a' 'well' 'trained' 'girl']
# Sentencia final: 1
# ['love', '##toy', 'ca', 'that', 's', 'a', 'well', 'trained', 'woman']
#
#
# Sentencia original:
# ['just' 'inn' '##7' 'kai' '##tma' '##rie' '##ox' 'sl' '##ut' 'arm' '##pit'
#  '##s' 'hairy' 'surely' 'don' 't' 'feminist' 'so' 'x' '##8' '##9' 't' 'co'
#  'ca' '##y' '##z' '##13' '##cu' '##3' '##e']
# Sentencia final: 1
# ['just', 'inn', '##7', 'faulty', '##tma', '##rie', '##ox', 'wa', '##ut', 'arm', '##pit', '##s', 'hairy', 'surely', 'feminism', 't', 'didn', 'so', 'feminism', '##8', '##9', 't', 'co', 'ca', '##y', '##z', '##13', '##cu', '##3', '##e']
#
#
# Sentencia original:
# ['number' 't' 'you' 'should' 'do' 'to' 'him' 'all' 'by' 'now' 'you' 'will'
#  'need' 'to' 'make' 'him' 'a' 'few' 'times' 'until' 'she' 'is' 'ready'
#  'and' 'he' 'just' 'lets' 'h']
# Sentencia final: 1
# ['number', 'week', 'you', 'should', 'do', 'to', 'him', 'all', 'by', 'now', 'you', 'will', 'need', 'to', 'make', 'him', 'a', 'few', 'times', 'until', 'she', 'is', 'ready', 'and', 'he', 'just', 'feels', 'll']
#
#
# Sentencia original:
# ['mrs' 'hc' '##m' 'tr' '##ad' '##po' '##aster' '##100' '##0' 'also'
#  'though' 'if' 'eggs' 'are' 'the' 'resource' 'guys' 'are' 'after' 'vs' 'a'
#  'good' 'and' 'vi' '##rt' '##uous' 'wife' 'who' 'will']
# Sentencia final: 1
# ['mrs', 'leftist', '##m', 'tr', '##ad', '##po', '##aster', '##100', '##0', 'also', 'though', 'if', 'aren', 'are', 'the', 'resource', 'guys', 'are', 'after', 'right', 'a', 'good', 'and', 'faulty', '##rt', '##uous', 'girlfriend', 'who', 'will']
#
#
# # terms modificados promedio 5.080144204104271 términos por sentencia
# Largo de sentencia promedio 22.849972268441487 términos por sentencia
# para esta ejecución se debiesen reemplazar 20003  de 40279 terminos
# Resumen de modificaciones: {'NNS': 1372, 'NN': 13026, 'VBG': 747, 'JJ': 1046, 'VBZ': 578, 'VB': 605, 'VBD': 348, 'VBN': 569, 'VBP': 28}
# Este proceso tomó 75.23544812202454 seg

# %%
prob=0.5 
TOPN=1

fs_macro={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
fs_none={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
accs={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
confusions={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}


for i in range(1,6):
    print ("----------------------- Entrenando running ", i,"-----------------------")
    macro_augmented=np.load('../../../new_data_augmented/harassment/Aumento_'+str(i)+'-run_'+str(prob)+'_app1_Top'+str(TOPN)+'.npy', allow_pickle=True)
    
    ids_train=macro_augmented[:,0]
    tws_train=macro_augmented[:,1]
    labels_train=macro_augmented[:,2]
    class_weights= compute_class_weight('balanced', np.unique(labels_train), labels_train)
    print ("Pesos de clases:", class_weights)
    
    etiq=labels_train.copy()
    sentences = tws_train
    n_labels = np.array(etiq)

    input_ids = []
    for sent in sentences:
        encoded_sent = tokenizer_loaded.encode(list(sent),add_special_tokens = False)    
        input_ids.append(encoded_sent)
    input_ids = pad_sequences(input_ids,maxlen=MAX_LEN,dtype="long",value=0, truncating="post", padding="post")
    y_train=to_categorical(n_labels,num_classes=4)
    shape=np.asarray(input_ids).shape
    x_train=np.zeros((shape[0], shape[1], 768))
    j=0
    for in_id in input_ids:
        x_train[j]=M_BERT_space[in_id]
        j+=1

    ###########################################################
    ############################################################
    ############################################################
    
    cnn1=create_ccn1(x_train.shape[1:])
    trained =train_model(cnn1, x_train, y_train, x_val, y_val, class_weights, e=30, BS=32, verb=0, focal=True)
    trained.save('../../../new_data_augmented/harassment_baselines/'+str(prob)+'/cnn1_'+str(i)+'-exec_app1_Top_'+str(TOPN)+'.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(trained, x_train, x_val, x_test, etiq, etiq_v, etiq_t, 'cnn1')
    fs_macro['cnn1'].append(f1_ma_t)
    fs_none['cnn1'].append(f1_t)
    accs['cnn1'].append(acc_t)
    confusions['cnn1'].append(matriz_t)
    
    cnn2=create_cnn2(x_train.shape[1:])
    trained =train_model(cnn2, x_train, y_train, x_val, y_val, class_weights, e=30, BS=32, verb=0, focal=True)
    trained.save('../../../new_data_augmented/harassment_baselines/'+str(prob)+'/cnn2_'+str(i)+'-exec_app1_Top_'+str(TOPN)+'.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(trained, x_train, x_val, x_test, etiq, etiq_v, etiq_t, 'cnn2')
    fs_macro['cnn2'].append(f1_ma_t)
    fs_none['cnn2'].append(f1_t)
    accs['cnn2'].append(acc_t)
    confusions['cnn2'].append(matriz_t)
    
    rnn1=create_complex_GRU_2(128,64,"adam",x_train.shape[1:])
    trained =train_model(rnn1, x_train, y_train, x_val, y_val, class_weights, e=30, BS=32, verb=0, focal=True)
    trained.save('../../../new_data_augmented/harassment_baselines/'+str(prob)+'/rnn1_'+str(i)+'-exec_app1_Top_'+str(TOPN)+'.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(trained, x_train, x_val, x_test, etiq, etiq_v, etiq_t, 'rnn1')
    fs_macro['rnn1'].append(f1_ma_t)
    fs_none['rnn1'].append(f1_t)
    accs['rnn1'].append(acc_t)
    confusions['rnn1'].append(matriz_t)
    
    rnn2=create_complex_GRU_3(256,128,64,"adam",x_train.shape[1:])
    trained =train_model(rnn2, x_train, y_train, x_val, y_val, class_weights, e=30, BS=32, verb=0, focal=True)
    trained.save('../../../new_data_augmented/harassment_baselines/'+str(prob)+'/rnn2_'+str(i)+'-exec_app1_Top_'+str(TOPN)+'.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(trained, x_train, x_val, x_test, etiq, etiq_v, etiq_t, 'rnn2')
    fs_macro['rnn2'].append(f1_ma_t)
    fs_none['rnn2'].append(f1_t)
    accs['rnn2'].append(acc_t)
    confusions['rnn2'].append(matriz_t)
    
    rnn3=create_complex_GRU_3(256,128,64,"adam",x_train.shape[1:])
    trained =train_model(rnn3, x_train, y_train, x_val, y_val, class_weights, e=30, BS=32, verb=0, focal=False)
    trained.save('../../../new_data_augmented/harassment_baselines/'+str(prob)+'/rnn3_'+str(i)+'-exec_app1_Top_'+str(TOPN)+'.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(trained, x_train, x_val, x_test, etiq, etiq_v, etiq_t, 'rnn3')
    fs_macro['rnn3'].append(f1_ma_t)
    fs_none['rnn3'].append(f1_t)
    accs['rnn3'].append(acc_t)
    confusions['rnn3'].append(matriz_t)
# Out:
# ----------------------- Entrenando running  1 -----------------------
# Pesos de clases: [1. 1. 1. 1.]
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:Large dropout rate: 0.65 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.65 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:1702: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:1205: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
#
# Accuracy sobre Train cnn1 : 0.9780114722753346
# F1-score None sobre Train cnn1 : [0.95751096 0.99835976 0.99849829 0.95769283]
# F1-score macro sobre Train cnn1 : 0.9780154621915955
#
# Accuracy sobre Val cnn1 : 0.6668235294117647
# F1-score None sobre Val cnn1 : [0.74456084 0.         0.06382979 0.61211743]
# F1-score macro sobre Val cnn1 : 0.355127012969064
#
# Accuracy sobre Test cnn1 : 0.6905322656617994
# F1-score None sobre Test cnn1 : [0.8013913  0.         0.14141414 0.52703863]
# F1-score macro sobre Test cnn1 : 0.36746101809285237
# WARNING:tensorflow:Large dropout rate: 0.65 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.65 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
#
# Accuracy sobre Train cnn2 : 0.9751434034416826
# F1-score None sobre Train cnn2 : [0.95240671 0.99849624 0.99849624 0.9512531 ]
# F1-score macro sobre Train cnn2 : 0.9751630714626935
#
# Accuracy sobre Val cnn2 : 0.6630588235294118
# F1-score None sobre Val cnn2 : [0.73709874 0.02469136 0.04651163 0.6006006 ]
# F1-score macro sobre Val cnn2 : 0.35222558172043006
#
# Accuracy sobre Test cnn2 : 0.6858219500706547
# F1-score None sobre Test cnn2 : [0.79723661 0.         0.02597403 0.51541096]
# F1-score macro sobre Test cnn2 : 0.33465539993283266
#
# Accuracy sobre Train rnn1 : 0.9909177820267686
# F1-score None sobre Train rnn1 : [0.98450144 0.9975356  0.9972752  0.98436013]
# F1-score macro sobre Train rnn1 : 0.9909180916358822
#
# Accuracy sobre Val rnn1 : 0.6451764705882352
# F1-score None sobre Val rnn1 : [0.73688491 0.04395604 0.05970149 0.60973983]
# F1-score macro sobre Val rnn1 : 0.36257056890261874
#
# Accuracy sobre Test rnn1 : 0.6674517192651908
# F1-score None sobre Test rnn1 : [0.78531469 0.09917355 0.09606987 0.53474903]
# F1-score macro sobre Test rnn1 : 0.3788267856945904
# WARNING:tensorflow:Large dropout rate: 0.65 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
#
# Accuracy sobre Train rnn2 : 0.9748019666757717
# F1-score None sobre Train rnn2 : [0.96736402 0.99645777 0.97880056 0.95715037]
# F1-score macro sobre Train rnn2 : 0.9749431770794202
#
# Accuracy sobre Val rnn2 : 0.6089411764705882
# F1-score None sobre Val rnn2 : [0.67522465 0.11864407 0.04347826 0.56832476]
# F1-score macro sobre Val rnn2 : 0.35141793316337244
#
# Accuracy sobre Test rnn2 : 0.5972680169571362
# F1-score None sobre Test rnn2 : [0.71882086 0.0875     0.07317073 0.45213549]
# F1-score macro sobre Test rnn2 : 0.3329067716894821
#
# Accuracy sobre Train rnn3 : 0.9941955749795138
# F1-score None sobre Train rnn3 : [0.98927393 0.99890651 0.99918033 0.98943089]
# F1-score macro sobre Train rnn3 : 0.9941979139645309
#
# Accuracy sobre Val rnn3 : 0.6094117647058823
# F1-score None sobre Val rnn3 : [0.67834259 0.06315789 0.05882353 0.56815578]
# F1-score macro sobre Val rnn3 : 0.3421199493591428
#
# Accuracy sobre Test rnn3 : 0.6255299105040037
# F1-score None sobre Test rnn3 : [0.74775745 0.03030303 0.06122449 0.45728234]
# F1-score macro sobre Test rnn3 : 0.32414182718730145
# ----------------------- Entrenando running  2 -----------------------
# Pesos de clases: [1. 1. 1. 1.]
#
# Accuracy sobre Train cnn1 : 0.9775334608030593
# F1-score None sobre Train cnn1 : [0.9562336  0.99863425 0.99876999 0.95652174]
# F1-score macro sobre Train cnn1 : 0.9775398961566331
#
# Accuracy sobre Val cnn1 : 0.7058823529411765
# F1-score None sobre Val cnn1 : [0.77989871 0.         0.04347826 0.63805253]
# F1-score macro sobre Val cnn1 : 0.3653573764378614
#
# Accuracy sobre Test cnn1 : 0.7343382006594442
# F1-score None sobre Test cnn1 : [0.83465608 0.         0.025      0.57253385]
# F1-score macro sobre Test cnn1 : 0.3580474834464196
#
# Accuracy sobre Train cnn2 : 0.9730264954930347
# F1-score None sobre Train cnn2 : [0.94749965 0.9979483  0.99795054 0.94878344]
# F1-score macro sobre Train cnn2 : 0.9730454822759171
#
# Accuracy sobre Val cnn2 : 0.6145882352941177
# F1-score None sobre Val cnn2 : [0.68117798 0.         0.04255319 0.56934307]
# F1-score macro sobre Val cnn2 : 0.3232685585338543
#
# Accuracy sobre Test cnn2 : 0.6316533207724918
# F1-score None sobre Test cnn2 : [0.75082327 0.         0.02531646 0.47289157]
# F1-score macro sobre Test cnn2 : 0.31225782327297213
#
# Accuracy sobre Train rnn1 : 0.9868888281890194
# F1-score None sobre Train rnn1 : [0.97491639 0.99918122 0.99781957 0.97555735]
# F1-score macro sobre Train rnn1 : 0.9868686315646003
#
# Accuracy sobre Val rnn1 : 0.512
# F1-score None sobre Val rnn1 : [0.56578947 0.04918033 0.04145078 0.53016049]
# F1-score macro sobre Val rnn1 : 0.2966452664375387
#
# Accuracy sobre Test rnn1 : 0.5049458313707018
# F1-score None sobre Test rnn1 : [0.61965989 0.18823529 0.14440433 0.41642651]
# F1-score macro sobre Test rnn1 : 0.34218150784420986
#
# Accuracy sobre Train rnn2 : 0.9923518164435946
# F1-score None sobre Train rnn2 : [0.98596539 0.99863388 0.998635   0.98617007]
# F1-score macro sobre Train rnn2 : 0.9923510839730736
#
# Accuracy sobre Val rnn2 : 0.6691764705882353
# F1-score None sobre Val rnn2 : [0.7516939  0.03305785 0.06896552 0.62898936]
# F1-score macro sobre Val rnn2 : 0.37067665803403643
#
# Accuracy sobre Test rnn2 : 0.6787564766839378
# F1-score None sobre Test rnn2 : [0.79647218 0.07692308 0.09210526 0.5019685 ]
# F1-score macro sobre Test rnn2 : 0.3668672571374664
#
# Accuracy sobre Train rnn3 : 0.9778748975689703
# F1-score None sobre Train rnn3 : [0.95558087 0.99876965 0.9989077  0.95816393]
# F1-score macro sobre Train rnn3 : 0.9778555380352748
# Accuracy sobre Val rnn3 : 0.576
# F1-score None sobre Val rnn3 : [0.63418955 0.06976744 0.05555556 0.54852781]
# F1-score macro sobre Val rnn3 : 0.3270100884396553
#
# Accuracy sobre Test rnn3 : 0.5638247762600094
# F1-score None sobre Test rnn3 : [0.68322981 0.10344828 0.12371134 0.4186685 ]
# F1-score macro sobre Test rnn3 : 0.33226448166107814
# ----------------------- Entrenando running  3 -----------------------
# Pesos de clases: [1. 1. 1. 1.]
#
# Accuracy sobre Train cnn1 : 0.9782163343348812
# F1-score None sobre Train cnn1 : [0.9573907  0.99863463 0.99863388 0.95819331]
# F1-score macro sobre Train cnn1 : 0.9782131280307218
#
# Accuracy sobre Val cnn1 : 0.6931764705882353
# F1-score None sobre Val cnn1 : [0.77195746 0.         0.06153846 0.62547771]
# F1-score macro sobre Val cnn1 : 0.3647434080282912
#
# Accuracy sobre Test cnn1 : 0.689119170984456
# F1-score None sobre Test cnn1 : [0.79944675 0.         0.09756098 0.51972556]
# F1-score macro sobre Test cnn1 : 0.3541833206813453
#
# Accuracy sobre Train cnn2 : 0.9725484840207593
# F1-score None sobre Train cnn2 : [0.94725511 0.99863313 0.99877133 0.94553015]
# F1-score macro sobre Train cnn2 : 0.9725474306181024
#
# Accuracy sobre Val cnn2 : 0.6672941176470588
# F1-score None sobre Val cnn2 : [0.74331984 0.         0.07017544 0.60547112]
# F1-score macro sobre Val cnn2 : 0.35474160031830804
#
# Accuracy sobre Test cnn2 : 0.6957136128120585
# F1-score None sobre Test cnn2 : [0.80757315 0.         0.0952381  0.52173913]
# F1-score macro sobre Test cnn2 : 0.3561375938536756
#
# Accuracy sobre Train rnn1 : 0.9599153236820541
# F1-score None sobre Train rnn1 : [0.98589621 0.93348858 0.99520482 0.92591171]
# F1-score macro sobre Train rnn1 : 0.9601253282602515
#
# Accuracy sobre Val rnn1 : 0.5557647058823529
# F1-score None sobre Val rnn1 : [0.60636364 0.         0.07017544 0.53388947]
# F1-score macro sobre Val rnn1 : 0.3026071357890413
#
# Accuracy sobre Test rnn1 : 0.5581723975506359
# F1-score None sobre Test rnn1 : [0.68185328 0.01851852 0.10714286 0.41086351]
# F1-score macro sobre Test rnn1 : 0.3045945418159903
#
# Accuracy sobre Train rnn2 : 0.9919420923245015
# F1-score None sobre Train rnn2 : [0.98567888 0.99849624 0.99849993 0.98509081]
# F1-score macro sobre Train rnn2 : 0.9919414648192368
#
# Accuracy sobre Val rnn2 : 0.6536470588235294
# F1-score None sobre Val rnn2 : [0.74610156 0.04       0.05504587 0.62613557]
# F1-score macro sobre Val rnn2 : 0.3668207501169196
#
# Accuracy sobre Test rnn2 : 0.6665096561469619
# F1-score None sobre Test rnn2 : [0.7835123  0.13636364 0.12903226 0.50528338]
# F1-score macro sobre Test rnn2 : 0.38854789307344606
#
# Accuracy sobre Train rnn3 : 0.9875717017208413
# F1-score None sobre Train rnn3 : [0.97599777 0.9980916  0.99659632 0.97943825]
# F1-score macro sobre Train rnn3 : 0.9875309854662304
#
# Accuracy sobre Val rnn3 : 0.47294117647058825
# F1-score None sobre Val rnn3 : [0.52698104 0.07142857 0.03319502 0.50110375]
# F1-score macro sobre Val rnn3 : 0.2831770963212164
#
# Accuracy sobre Test rnn3 : 0.46019783325482805
# F1-score None sobre Test rnn3 : [0.55545852 0.20408163 0.15209125 0.40213761]
# F1-score macro sobre Test rnn3 : 0.32844225281004746
# ----------------------- Entrenando running  4 -----------------------
# Pesos de clases: [1. 1. 1. 1.]
#
# Accuracy sobre Train cnn1 : 0.9768505872712374
# F1-score None sobre Train cnn1 : [0.95441989 0.9989071  0.99904463 0.95500608]
# F1-score macro sobre Train cnn1 : 0.9768444257600082
#
# Accuracy sobre Val cnn1 : 0.7171764705882353
# F1-score None sobre Val cnn1 : [0.79816514 0.025      0.05128205 0.6624913 ]
# F1-score macro sobre Val cnn1 : 0.3842346225547323
#
# Accuracy sobre Test cnn1 : 0.74234573716439
# F1-score None sobre Test cnn1 : [0.84234528 0.         0.13207547 0.57320872]
# F1-score macro sobre Test cnn1 : 0.38690736782812757
#
# Accuracy sobre Train cnn2 : 0.9702267140125649
# F1-score None sobre Train cnn2 : [0.94337091 0.9984987  0.99822622 0.94066852]
# F1-score macro sobre Train cnn2 : 0.9701910897072112
#
# Accuracy sobre Val cnn2 : 0.6663529411764706
# F1-score None sobre Val cnn2 : [0.7433414  0.02105263 0.0625     0.6100434 ]
# F1-score macro sobre Val cnn2 : 0.35923435833336426
#
# Accuracy sobre Test cnn2 : 0.682053697597739
# F1-score None sobre Test cnn2 : [0.79401531 0.03361345 0.04597701 0.51972556]
# F1-score macro sobre Test cnn2 : 0.3483328310016851
#
# Accuracy sobre Train rnn1 : 0.8374760994263862
# F1-score None sobre Train rnn1 : [0.8917082  0.84738829 0.76326488 0.88061923]
# F1-score macro sobre Train rnn1 : 0.8457451520648308
#
# Accuracy sobre Val rnn1 : 0.3402352941176471
# F1-score None sobre Val rnn1 : [0.43161726 0.         0.03747535 0.46650525]
# F1-score macro sobre Val rnn1 : 0.23389946400612588
#
# Accuracy sobre Test rnn1 : 0.371172868582195
# F1-score None sobre Test rnn1 : [0.47272727 0.05357143 0.1168688  0.41589649]
# F1-score macro sobre Test rnn1 : 0.2647659968799641
#
# Accuracy sobre Train rnn2 : 0.9877765637803879
# F1-score None sobre Train rnn2 : [0.98203924 0.99808482 0.99367958 0.97748593]
# F1-score macro sobre Train rnn2 : 0.9878223909220338
#
# Accuracy sobre Val rnn2 : 0.6230588235294118
# F1-score None sobre Val rnn2 : [0.6924384  0.04651163 0.08510638 0.57288712]
# F1-score macro sobre Val rnn2 : 0.34923588445613907
#
# Accuracy sobre Test rnn2 : 0.6434291097503533
# F1-score None sobre Test rnn2 : [0.76128566 0.08196721 0.10989011 0.4778481 ]
# F1-score macro sobre Test rnn2 : 0.35774777174120004
#
# Accuracy sobre Train rnn3 : 0.9913957934990439
# F1-score None sobre Train rnn3 : [0.98675768 0.99918033 0.99497214 0.98462383]
# F1-score macro sobre Train rnn3 : 0.9913834957656762
#
# Accuracy sobre Val rnn3 : 0.5816470588235294
# F1-score None sobre Val rnn3 : [0.6634741  0.05479452 0.06451613 0.562954  ]
# F1-score macro sobre Val rnn3 : 0.33643468534634735
#
# Accuracy sobre Test rnn3 : 0.5817239755063589
# F1-score None sobre Test rnn3 : [0.71249525 0.09326425 0.13574661 0.45537948]
# F1-score macro sobre Test rnn3 : 0.3492213976263848
# ----------------------- Entrenando running  5 -----------------------
# Pesos de clases: [1. 1. 1. 1.]
#
# Accuracy sobre Train cnn1 : 0.9638759901666212
# F1-score None sobre Train cnn1 : [0.93253295 0.9989077  0.99849993 0.92508611]
# F1-score macro sobre Train cnn1 : 0.9637566727471423
#
# Accuracy sobre Val cnn1 : 0.7402352941176471
# F1-score None sobre Val cnn1 : [0.81584906 0.06896552 0.0952381  0.67034483]
# F1-score macro sobre Val cnn1 : 0.41259937416736375
#
# Accuracy sobre Test cnn1 : 0.74234573716439
# F1-score None sobre Test cnn1 : [0.84018265 0.         0.07142857 0.58103976]
# F1-score macro sobre Test cnn1 : 0.37316274379551995
#
# Accuracy sobre Train cnn2 : 0.9379950833105709
# F1-score None sobre Train cnn2 : [0.8891358  0.99877032 0.99753762 0.86415612]
# F1-score macro sobre Train cnn2 : 0.9373999668357176
#
# Accuracy sobre Val cnn2 : 0.7769411764705882
# F1-score None sobre Val cnn2 : [0.84632035 0.02352941 0.07843137 0.70789866]
# F1-score macro sobre Val cnn2 : 0.41404494733810066
#
# Accuracy sobre Test cnn2 : 0.790390956194065
# F1-score None sobre Test cnn2 : [0.87530713 0.         0.05063291 0.63065327]
# F1-score macro sobre Test cnn2 : 0.3891483257577971
#
# Accuracy sobre Train rnn1 : 0.9778066102157881
# F1-score None sobre Train rnn1 : [0.9655814  0.98986075 0.99396268 0.96157107]
# F1-score macro sobre Train rnn1 : 0.9777439733392
#
# Accuracy sobre Val rnn1 : 0.6607058823529411
# F1-score None sobre Val rnn1 : [0.77090626 0.07692308 0.03508772 0.62149533]
# F1-score macro sobre Val rnn1 : 0.37610309636973244
#
# Accuracy sobre Test rnn1 : 0.6867640131888837
# F1-score None sobre Test rnn1 : [0.80482089 0.14285714 0.12371134 0.515625  ]
# F1-score macro sobre Test rnn1 : 0.39675359339723487
#
# Accuracy sobre Train rnn2 : 0.9812892652280798
# F1-score None sobre Train rnn2 : [0.96522544 0.99739833 0.99849788 0.96407945]
# F1-score macro sobre Train rnn2 : 0.9813002750711705
#
# Accuracy sobre Val rnn2 : 0.7487058823529412
# F1-score None sobre Val rnn2 : [0.82166544 0.05063291 0.05882353 0.67962563]
# F1-score macro sobre Val rnn2 : 0.4026868773052452
#
# Accuracy sobre Test rnn2 : 0.7442298634008478
# F1-score None sobre Test rnn2 : [0.84296998 0.05128205 0.1322314  0.55753262]
# F1-score macro sobre Test rnn2 : 0.3960040155081254
#
# Accuracy sobre Train rnn3 : 0.9939907129199672
# F1-score None sobre Train rnn3 : [0.99071546 0.99918033 0.99616228 0.98992923]
# F1-score macro sobre Train rnn3 : 0.9939968242624407
# Accuracy sobre Val rnn3 : 0.6908235294117647
# F1-score None sobre Val rnn3 : [0.76326207 0.04819277 0.04651163 0.62703379]
# F1-score macro sobre Val rnn3 : 0.37125006641439606
#
# Accuracy sobre Test rnn3 : 0.7112576542628356
# F1-score None sobre Test rnn3 : [0.81618887 0.13114754 0.09756098 0.53481894]
# F1-score macro sobre Test rnn3 : 0.3949290820623279

# %%
for key in fs_none.keys():
    temp=np.zeros(4)
    for result in fs_none[key]:
        temp+=result
    print ("(0.5) F1-score promedio para",key,":" ,temp/5)

print ("")
for key in fs_macro.keys():
    temp=np.sum(fs_macro[key])
    print ("(0.5) F1-score macro promedio para",key,":" ,temp/5, "desvest: ",np.std(fs_macro[key]))

print ("")
for key in accs.keys():
    temp=np.sum(accs[key])
    print ("(0.5) Accuracy promedio para",key,":" ,temp/5)
# Out:
# (0.5) F1-score promedio para cnn1 : [0.82360441 0.         0.09349583 0.5547093 ]
# (0.5) F1-score promedio para cnn2 : [0.80499109 0.00672269 0.0486277  0.5320841 ]
# (0.5) F1-score promedio para rnn1 : [0.6728752  0.10047119 0.11763944 0.45871211]
# (0.5) F1-score promedio para rnn2 : [0.7806122  0.0868072  0.10728595 0.49895362]
# (0.5) F1-score promedio para rnn3 : [0.70302598 0.11244895 0.11406693 0.45365737]
#
# (0.5) F1-score macro promedio para cnn1 : 0.36795238676885295 desvest:  0.011613568454419654
# (0.5) F1-score macro promedio para cnn2 : 0.3481063947637925 desvest:  0.025357605848276663
# (0.5) F1-score macro promedio para rnn1 : 0.3374244851263979 desvest:  0.048194987161967705
# (0.5) F1-score macro promedio para rnn2 : 0.36841474182994405 desvest:  0.022554408457447377
# (0.5) F1-score macro promedio para rnn3 : 0.34579980826942797 desvest:  0.02599596414684129
#
# (0.5) Accuracy promedio para cnn1 : 0.719736222326896
# (0.5) Accuracy promedio para cnn2 : 0.6971267074894018
# (0.5) Accuracy promedio para rnn1 : 0.5577013659915215
# (0.5) Accuracy promedio para rnn2 : 0.6660386245878473
# (0.5) Accuracy promedio para rnn3 : 0.5885068299576071

# %%
for key in confusions.keys():
    temp=np.sum(confusions[key], axis=0)/5.0
    plot_confusion_matrix(temp, ['NonH','IndirectH','PhysicalH','SexualH'], "(0.5) Classic - Confusion Matrix "+str(key), cmap='Purples')

# %% [markdown]
# ## Generar 0.85 harassment [positivo + negativo]

# %%
prob= 0.85
TOPN = 1

fs_macro={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
fs_none={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
accs={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
confusions={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}

aum_weight=det_samples(train['Label'], dict_cl)

for i in range(1,6): 
    macro_augmented=[]
    print ("\n--------------------------------------------------------")
    print ("\nGenerando ejemplos en base a probabilidad --> ", prob)
    print ("--------------------------------------------------------")
    for clase in aum_weight:
        start_time=time.time()
        print ("\n\nGenerando", aum_weight[clase], "nuevos ejemplos para la clase", clase)
        muestras, dict_aumentos=aumentar_clase(clase, aum_weight[clase], tags, prob, TOPN)
        macro_augmented+=muestras
        print ("Resumen de modificaciones:", dict_aumentos)
        elapsed_time= time.time() - start_time
        print ("Este proceso tomó", elapsed_time, "seg")   

    macro_augmented = np.asarray(macro_augmented, dtype=object)
    np.random.shuffle(macro_augmented)
    np.save('../../../new_data_augmented/harassment/Aumento_'+str(i)+'-run_'+str(prob)+'_app1_Top'+str(TOPN)+'.npy', macro_augmented)
# Out:
# --------------------------------------------------------
#
# Generando ejemplos en base a probabilidad -->  0.85
# --------------------------------------------------------
#
#
# Generando 1079 nuevos ejemplos para la clase SexualH
# Consultando por la clase SexualH
# Entrega label 3
# Sentencia original:
# ['pic' 'mexican' 'school' 'girl' 'naked' 'melanie' 'sa' '##fk' '##a'
#  'fake' 'nude' 'photos' 'hardcore' 'sl' '##ut' 'movies' 'alicia' 'moore'
#  'porn' 'star' 'too' '##n' 'love']
# Sentencia final: 3
# ['pic', 'colombian', 'silvia', 'silvia', 'live', 'melanie', 'valentin', '##fk', '##a', 'gangster', 'nude', 'videos', 'photographer', 'rampage', '##ut', 'films', 'alicia', 'movie', 'pornography', 'ellen', 'too', '##n', 'man']
#
#
# Sentencia original:
# ['girl' 'dirty' 'quarterback' 'latino' 'pokemon' 'young' 'hand' '##jo'
#  '##b' 'kissing' 'gang' '##bang' 'w' 'x' '##8' '##9' 't' 'co' 'wr' '##m'
#  '##4' '##x' '##o' '##00' '##v' '##j']
# Sentencia final: 3
# ['boy', 'brunette', 'boy', 'latino', 'pokemon', 'japanese', 'hand', '##jo', '##b', 'menacing', 'bop', '##bang', 'gangster', 'wc', '##8', '##9', 'cr', 'con', 'wr', '##m', '##4', '##x', '##o', '##00', '##v', '##j']
#
#
# Sentencia original:
# ['mil' '##ion' '##do' '##lla' '##me' '##at' 'sex' '##ting' 'n' 'ng' '##ir'
#  '##l' 'daddy' 'n' 'nme' 'listen' 'bitch' 'gonna' 'watch' 'these' 'what']
# Sentencia final: 3
# ['mil', '##ion', '##do', '##lla', '##me', '##at', 'change', '##ting', 'n', 'ng', '##ir', '##l', 'mcconnell', 'mommy', 'mommy', 'gotta', 'gotta', 'gonna', 'gotta', 'these', 'what']
#
#
# Sentencia original:
# ['museum' 'sl' '##ut' 'if' 'you' 'know' 'somewhere' 'we' 'can' 'do' 'it'
#  'then' 'i' 'am' 'game']
# Sentencia final: 3
# ['league', 'gonna', '##ut', 'if', 'you', 'have', 'somewhere', 'we', 'can', 'happen', 'it', 'then', 'im', 'are', 'game']
#
#
# Sentencia original:
# ['rt' 'sp' '##00' '##ky' '##bit' '##ch' '##hh' '##h' 'i' 'have' 'spots'
#  'open' 'sis' '##sy' 'sl' '##ut' 'into' '##x' 'bitch' 'human' 'atm'
#  'amazon' 'boy' 'do' 'you' 'have' 'what' 'it' 'takes' 'can' 'you' 'live'
#  'up' 'to' 'my']
# Sentencia final: 3
# ['nt', 'sp', '##00', '##ky', '##bit', '##ch', '##hh', '##h', 'pinto', 'have', 'spots', 'noteworthy', 'sb', '##sy', 'sum', '##ut', 'into', '##x', 'asshole', 'blockbuster', 'atm', 'girl', 'girl', 'do', 'you', 'be', 'what', 'it', 'gives', 'can', 'you', 'alive', 'up', 'to', 'my']
#
#
# Sentencia original:
# ['venus' 'astro' '##logy' 'living' 'standards' 'ni' '##t' 'x' '##8' '##9'
#  's' 'illusion' 'i' 'x' '##8' '##9' 'm' 'fucking' 'nwa' '##iting'
#  'waiting' 'wai' 'x' '##8' '##9']
# Sentencia final: 3
# ['venus', 'astro', '##logy', 'lifestyle', 'norms', 'moran', '##t', 'pinto', '##8', '##9', 's', 'illusion', 'iv', 'pinto', '##8', '##9', 'nylon', 'menacing', 'nwa', '##iting', 'appealing', 'wai', 'ce', '##8', '##9']
#
#
# Sentencia original:
# ['add' 'me' 'on' 'snap' '##cha' '##t' 'and' 'watch' 'me' 'cum' 'colt'
#  '##oe' '##8' 'send' '##nu' '##des' 'nude' 'nude' 'snap' '##cha' '##t'
#  'girls' 'boo' '##bs' 'pussy' 'horn' '##y']
# Sentencia final: 3
# ['add', 'me', 'on', 'spring', '##cha', '##t', 'and', 'call', 'me', 'nippon', 'creamy', '##oe', '##8', 'anand', '##nu', '##des', 'umm', 'kemp', 'bikini', '##cha', '##t', 'girls', 'prostitute', '##bs', 'bum', 'horn', '##y']
#
#
# Sentencia original:
# ['rt' 'ole' '##sm' '##eh' '##a' '##86' 'he' 'need' 'me' 'to' 'eat' 'his'
#  'dick' 'because' 'eat' 'dick' 'it' 's' 'my' 'skill' 'sl' '##ut' 'ass'
#  'dick' 'cock' 'jail' '##bai' '##t' 'bbc' 'gang' '##bang' 'cu' '##cko'
#  '##ld']
# Sentencia final: 3
# ['nt', 'ol', '##sm', '##eh', '##a', '##86', 'he', 'want', 'me', 'to', 'ate', 'his', 'ate', 'because', 'eat', 'dick', 'it', 'jock', 'my', 'skill', 'butt', '##ut', 'asshole', 'butt', 'cock', 'penis', '##bai', '##t', 'nme', 'gangster', '##bang', 'susie', '##cko', '##ld']
#
#
# Sentencia original:
# ['rt' 'tia' '##po' '##gai' '##51' 'please' 'sleep' 'i' 'will' 'do' 'it'
#  'for' 'you' 'guy' 'gt' 'register' 'note' 'verify' 'email' 'to' 'send'
#  'ms' '##g' 'to' 'girls' 'sl' '##ut']
# Sentencia final: 3
# ['dino', 'tia', '##po', '##gai', '##51', 'childish', 'sleep', 'work', 'will', 'go', 'it', 'for', 'you', 'brunette', 'notice', 'stabbed', 'compute', 'jogging', 'ipad', 'to', 'facebook', 'day', '##g', 'to', 'boys', 'gonna', '##ut']
#
#
# # terms modificados promedio 9.321594068582021 términos por sentencia
# Largo de sentencia promedio 24.027803521779425 términos por sentencia
# para esta ejecución se debiesen reemplazar 11454  de 13528 terminos
# Resumen de modificaciones: {'JJ': 703, 'NN': 7656, 'NNS': 567, 'VBG': 310, 'VB': 315, 'VBP': 47, 'VBZ': 186, 'VBN': 149, 'VBD': 97, 'JJS': 24, 'JJR': 4}
# Este proceso tomó 61.46395421028137 seg
#
#
# Generando 0 nuevos ejemplos para la clase NonH
# Consultando por la clase NonH
# Entrega label 0
# No se generan ejemplos
# Resumen de modificaciones: {}
# Este proceso tomó 0.435316801071167 seg
#
#
# Generando 3585 nuevos ejemplos para la clase PhysicalH
# Consultando por la clase PhysicalH
# Entrega label 2
# Sentencia original:
# ['deep' '##th' '##ro' '##at' 'cum' '##shot' 'perfect' 'boo' '##bs'
#  'jewish' 'indian' 'pussy' 'naked' 'lesbian' 'japanese' 'beau' '##t' 'x'
#  '##8' '##9' 't' 'co' 'g' '##f' '##w' '##x' '##st' '##n' '##2' '##fk']
# Sentencia final: 2
# ['time', '##th', '##ro', '##at', 'pitch', '##shot', 'divine', 'chopped', '##bs', 'muslim', 'japanese', 'muslim', 'islamic', 'aesthetic', 'horrible', 'racist', '##t', 'rt', '##8', '##9', 'th', 'se', 'rt', '##f', '##w', '##x', '##st', '##n', '##2', '##fk']
#
#
# Sentencia original:
# ['rt' 'debbie' '##d' '##7' '##47' '##9' '##9' '##11' '##8' 'steve' '##d'
#  '##48' '##48' 'how' 'dare' 'she' 'honest' 'people' 'and' 'children'
#  'were' 'killed' 'in' 'manchester' 'and' 'this' 'sc' '##um' 'says' 'that'
#  's' 'fair' 're' '##tal' '##i']
# Sentencia final: 2
# ['co', 'behave', '##d', '##7', '##47', '##9', '##9', '##11', '##8', 'hussain', '##d', '##48', '##48', 'how', 'behave', 'she', 'everybody', 'people', 'and', 'children', 'was', 'tortured', 'in', 'manchester', 'and', 'this', 'state', '##um', 'says', 'that', 'ma', 'fair', 're', '##tal', '##i']
#
#
# Sentencia original:
# ['pr' '##ae' '##tors' '##uit' 'which' 'specifically' 'i' 'x' '##8' '##9'
#  'd' 'personally' 'pitch' 'black' 'world' 'devil' 'there' 'rap' '##ist'
#  'an' 'x' '##8' '##9' 't' 'co' 'bu' '##rg' '##t' '##j' '##fr' '##ya']
# Sentencia final: 2
# ['pr', '##ae', '##tors', '##uit', 'which', 'specifically', 'i', 'time', '##8', '##9', 'th', 'personally', 'pitch', 'white', 'anwar', 'devil', 'there', 'murderer', '##ist', 'an', 'agree', '##8', '##9', 're', 'whore', 'rt', '##rg', '##t', '##j', '##fr', '##ya']
#
#
# Sentencia original:
# ['sas' '##sy' 'wants' 'signing' 'first' 'prepare' 'good' 'don' 't' 'know'
#  'x' '##8' '##9' 't' 'co' 'qi' '##q' '##gi' '##b' '##17' '##ik']
# Sentencia final: 2
# ['want', '##sy', 'gets', 'anwar', 'first', 'prepare', 'good', 'love', 'head', 'do', 'name', '##8', '##9', 't', 'guess', 'qi', '##q', '##gi', '##b', '##17', '##ik']
#
#
# Sentencia original:
# ['bb' '##adi' '##cal' '##i' 'sarcastic' '##fe' '##m' '##23' 'ms' '##vani'
#  '##llar' '##ose' 'facebook' 'habit' '##ually' 'hara' '##ss' 'calling'
#  'addicted' 'drug' '##gy' 'hooker' 'for' 'x' '##8' '##9']
# Sentencia final: 2
# ['bb', '##adi', '##cal', '##i', 'aesthetic', '##fe', '##m', '##23', 'rt', '##vani', '##llar', '##ose', 'terrorism', 'twitter', '##ually', 'hara', '##ss', 'choking', 'fucked', 'hussain', '##gy', 'suicidal', 'for', 'suicidal', '##8', '##9']
#
#
# Sentencia original:
# ['hot' 'british' 'sl' '##ut' 'cr' '##iss' '##y' 'will' 'give' 'you' 'a'
#  'wet' 'dream' 'when' 'she' 'rubs' 'on' 'her' 'pussy' 'cam' '##girl']
# Sentencia final: 2
# ['japanese', 'japanese', 'rt', '##ut', 'fl', '##iss', '##y', 'will', 'give', 'you', 'a', 'wish', 'day', 'when', 'she', 'rubs', 'on', 'her', 'girl', 'girl', '##girl']
#
#
# Sentencia original:
# ['the' 'woman' 'brutally' 'tortured' 'minor' 'servant' 'starved' 'major'
#  'am' '##mara' 'm' 'x' '##8' '##9' 't' 'co' 'y' '##j' '##9' '##6' '##d'
#  '##2' '##x' '##gr' '##p']
# Sentencia final: 2
# ['the', 'girl', 'brutally', 'starved', 'minor', 'beaten', 'addicted', 'big', 'are', '##mara', 'ur', 'suicidal', '##8', '##9', 'rt', 're', 're', '##j', '##9', '##6', '##d', '##2', '##x', '##gr', '##p']
#
#
# Sentencia original:
# ['p' '##0' '##rn' '##sf' '##w' 'daddy' 'behave' 'baby' 'daddy' 'tight'
#  'open' 'yeah' 'little' 'x' '##8' '##9']
# Sentencia final: 2
# ['please', '##0', '##rn', '##sf', '##w', 'anwar', 'anwar', 'cute', 'strict', 'behave', 'horrible', 'juicy', 'big', 'suicidal', '##8', '##9']
#
#
# Sentencia original:
# ['what' 'i' 'don' 't' 'get' 'is' 'how' 'y' 'all' 'try' 'to' 'drag' 'becky'
#  'for' 'body' 'shame' 'charlotte' 'when' 'she' 'didn' 't' 'but' 'laugh'
#  'at' 'a' 'fan' 'th']
# Sentencia final: 2
# ['what', 'didn', 'didn', 't', 'get', 'has', 'how', 'co', 'all', 'nah', 'to', 'behave', 'becky', 'for', 'body', 'messy', 'charlotte', 'when', 'she', 'doesn', 'doesn', 'but', 'wanna', 'at', 'a', 'time', 'th']
# # terms modificados promedio 9.522733612273361 términos por sentencia
# Largo de sentencia promedio 24.073919107391912 términos por sentencia
# para esta ejecución se debiesen reemplazar 37452  de 44140 terminos
# Resumen de modificaciones: {'NN': 25521, 'JJ': 1766, 'VBD': 661, 'VBN': 665, 'VBZ': 966, 'VB': 1458, 'VBG': 1221, 'VBP': 240, 'NNS': 1536, 'JJS': 105}
# Este proceso tomó 132.54164505004883 seg
#
#
# Generando 3606 nuevos ejemplos para la clase IndirectH
# Consultando por la clase IndirectH
# Entrega label 1
# Sentencia original:
# ['the' 'people' 'that' 'work' 'in' 'the' 'dining' 'hall' 'are' 'all'
#  'sitting' 'here' 'talking' 'shit' 'about' 'this' 'girl' 'that' 'came'
#  'in' 'first' 'thing']
# Sentencia final: 1
# ['the', 'women', 'that', 'man', 'in', 'the', 'dining', 'hall', 'are', 'all', 'being', 'here', 'doing', 'anything', 'about', 'this', 'woman', 'that', 'was', 'in', 'first', 'time']
#
#
# Sentencia original:
# ['i' 'will' 'never' 'understand' 'how' 'girls' 'can' 'sl' '##ut' 'shame'
#  'other' 'girls' 'for' 'having' 'male' 'friends']
# Sentencia final: 1
# ['part', 'will', 'never', 'understand', 'how', 'ladies', 'can', 'embarrassment', '##ut', 'girl', 'unacceptable', 'boys', 'for', 'smashing', 'feminist', 'girlfriends']
#
#
# Sentencia original:
# ['shy' '##ler' '##lit' '##tle' '##e' 'honestly' 'can' 'x' '##8' '##9' 't'
#  'relate' 'girls' 'shame' 'different' 'every' 'weekend' 'fuck' '##in'
#  'number' 'x' '##8' '##9']
# Sentencia final: 1
# ['right', '##ler', '##lit', '##tle', '##e', 'honestly', 'can', 'confirm', '##8', '##9', 'faulty', 'feminism', 'girls', 'shame', 'problematic', 'every', 'faulty', 'time', '##in', 'time', 'leftist', '##8', '##9']
#
#
# Sentencia original:
# ['the' '##kat' '##ied' '##ren' '##nen' 'katie' 'is' 'totally' 'turning'
#  'into' 'one' 'of' 'those' 'girls' 'who' 'gets' 'married' 'and' 'forget'
#  'two' 'years' 'ago' 'she' 'wa']
# Sentencia final: 1
# ['the', '##kat', '##ied', '##ren', '##nen', 'feminism', 'gets', 'totally', 'turning', 'into', 'one', 'of', 'those', 'boys', 'who', 'gets', 'lucky', 'and', 'faulty', 'two', 'times', 'ago', 'she', 'ask']
#
#
# Sentencia original:
# ['baku' '##bro' '##ws' 'freaked' '##by' '##du' '##bu' '##l' '##g' 'sara'
#  '##ot' '##5' 'how' 'can' 'u' 'go' 'from' 'wonder' 'girls' 'and' 'miss'
#  'a' 'to' 'twice' 'and' 'these' 'ladies' 'l' '##m' '##fa' '##o' 'i' 'can'
#  't']
# Sentencia final: 1
# ['baku', '##bro', '##ws', 'freaked', '##by', '##du', '##bu', '##l', '##g', 'sara', '##ot', '##5', 'how', 'can', 'time', 'be', 'from', 'wonder', 'girls', 'and', 'girl', 'a', 'to', 'twice', 'and', 'these', 'women', 'woman', '##m', '##fa', '##o', 'time', 'can', 'didn']
#
#
# Sentencia original:
# ['love' '##toy' 'ca' 'that' 's' 'a' 'well' 'trained' 'girl']
# Sentencia final: 1
# ['time', '##toy', 'ca', 'that', 'll', 'a', 'well', 'tortured', 'woman']
#
#
# Sentencia original:
# ['just' 'inn' '##7' 'kai' '##tma' '##rie' '##ox' 'sl' '##ut' 'arm' '##pit'
#  '##s' 'hairy' 'surely' 'don' 't' 'feminist' 'so' 'x' '##8' '##9' 't' 'co'
#  'ca' '##y' '##z' '##13' '##cu' '##3' '##e']
# Sentencia final: 1
# ['just', 'inn', '##7', 'faulty', '##tma', '##rie', '##ox', 'faulty', '##ut', 'arm', '##pit', '##s', 'didn', 'surely', 'didn', 'didn', 'didn', 'so', 'x', '##8', '##9', 'rt', 'time', 'ca', '##y', '##z', '##13', '##cu', '##3', '##e']
#
#
# Sentencia original:
# ['number' 't' 'you' 'should' 'do' 'to' 'him' 'all' 'by' 'now' 'you' 'will'
#  'need' 'to' 'make' 'him' 'a' 'few' 'times' 'until' 'she' 'is' 'ready'
#  'and' 'he' 'just' 'lets' 'h']
# Sentencia final: 1
# ['time', 'time', 'you', 'should', 'have', 'to', 'him', 'all', 'by', 'now', 'you', 'will', 'want', 'to', 'make', 'him', 'a', 'other', 'people', 'until', 'she', 'has', 'other', 'and', 'he', 'just', 'mosques', 'h']
#
#
# Sentencia original:
# ['mrs' 'hc' '##m' 'tr' '##ad' '##po' '##aster' '##100' '##0' 'also'
#  'though' 'if' 'eggs' 'are' 'the' 'resource' 'guys' 'are' 'after' 'vs' 'a'
#  'good' 'and' 'vi' '##rt' '##uous' 'wife' 'who' 'will']
# Sentencia final: 1
# ['ms', 'leftist', '##m', 'rt', '##ad', '##po', '##aster', '##100', '##0', 'also', 'though', 'if', 'people', 'are', 'the', 'want', 'aren', 'are', 'after', 'right', 'a', 'good', 'and', 'hairy', '##rt', '##uous', 'girlfriend', 'who', 'will']
#
#
# # terms modificados promedio 8.58763172490294 términos por sentencia
# Largo de sentencia promedio 22.707986688851914 términos por sentencia
# para esta ejecución se debiesen reemplazar 33841  de 39784 terminos
# Resumen de modificaciones: {'NNS': 2181, 'NN': 22061, 'VBG': 1275, 'VBD': 604, 'JJ': 1822, 'VBZ': 977, 'VB': 1030, 'VBN': 957, 'VBP': 60}
# Este proceso tomó 119.53549790382385 seg
#
# --------------------------------------------------------
#
# Generando ejemplos en base a probabilidad -->  0.85
# --------------------------------------------------------
#
#
# Generando 1079 nuevos ejemplos para la clase SexualH
# Consultando por la clase SexualH
# Entrega label 3
# Sentencia original:
# ['pic' 'mexican' 'school' 'girl' 'naked' 'melanie' 'sa' '##fk' '##a'
#  'fake' 'nude' 'photos' 'hardcore' 'sl' '##ut' 'movies' 'alicia' 'moore'
#  'porn' 'star' 'too' '##n' 'love']
# Sentencia final: 3
# ['college', 'french', 'silvia', 'girlfriend', 'naked', 'melanie', 'valentin', '##fk', '##a', 'gangster', 'gangster', 'prostitutes', 'photographer', 'brighton', '##ut', 'james', 'alicia', 'movie', 'kendrick', 'cleavage', 'too', '##n', 'work']
#
#
# Sentencia original:
# ['girl' 'dirty' 'quarterback' 'latino' 'pokemon' 'young' 'hand' '##jo'
#  '##b' 'kissing' 'gang' '##bang' 'w' 'x' '##8' '##9' 't' 'co' 'wr' '##m'
#  '##4' '##x' '##o' '##00' '##v' '##j']
# Sentencia final: 3
# ['teenager', 'gonna', 'boy', 'latino', 'pokemon', 'japanese', 'pinto', '##jo', '##b', 'menacing', 'bop', '##bang', 'gangster', 'wc', '##8', '##9', 'rb', 're', 'wr', '##m', '##4', '##x', '##o', '##00', '##v', '##j']
#
#
# Sentencia original:
# ['mil' '##ion' '##do' '##lla' '##me' '##at' 'sex' '##ting' 'n' 'ng' '##ir'
#  '##l' 'daddy' 'n' 'nme' 'listen' 'bitch' 'gonna' 'watch' 'these' 'what']
# Sentencia final: 3
# ['peyton', '##ion', '##do', '##lla', '##me', '##at', 'prostitution', '##ting', 'sexy', 'hs', '##ir', '##l', 'mommy', 'n', 'mommy', 'gotta', 'gotta', 'wanna', 'wanna', 'these', 'what']
#
#
# Sentencia original:
# ['museum' 'sl' '##ut' 'if' 'you' 'know' 'somewhere' 'we' 'can' 'do' 'it'
#  'then' 'i' 'am' 'game']
# Sentencia final: 3
# ['league', 'sl', '##ut', 'if', 'you', 'believe', 'somewhere', 'we', 'can', 'do', 'it', 'then', 'mine', 'are', 'game']
#
#
# Sentencia original:
# ['rt' 'sp' '##00' '##ky' '##bit' '##ch' '##hh' '##h' 'i' 'have' 'spots'
#  'open' 'sis' '##sy' 'sl' '##ut' 'into' '##x' 'bitch' 'human' 'atm'
#  'amazon' 'boy' 'do' 'you' 'have' 'what' 'it' 'takes' 'can' 'you' 'live'
#  'up' 'to' 'my']
# Sentencia final: 3
# ['rt', 'sp', '##00', '##ky', '##bit', '##ch', '##hh', '##h', 'need', 'see', 'spots', 'active', 'hey', '##sy', 'gal', '##ut', 'into', '##x', 'vampire', 'blockbuster', 'atm', 'girl', 'jogging', 'say', 'you', 'be', 'what', 'it', 'is', 'can', 'you', 'live', 'up', 'to', 'my']
#
#
# Sentencia original:
# ['venus' 'astro' '##logy' 'living' 'standards' 'ni' '##t' 'x' '##8' '##9'
#  's' 'illusion' 'i' 'x' '##8' '##9' 'm' 'fucking' 'nwa' '##iting'
#  'waiting' 'wai' 'x' '##8' '##9']
# Sentencia final: 3
# ['venus', 'astro', '##logy', 'living', 'cooks', 'standard', '##t', 'pinto', '##8', '##9', 'croft', 'illusion', 'time', 'pinto', '##8', '##9', 'goddamn', 'educating', 'nwa', '##iting', 'scrolling', 'wai', 'x', '##8', '##9']
#
#
# Sentencia original:
# ['add' 'me' 'on' 'snap' '##cha' '##t' 'and' 'watch' 'me' 'cum' 'colt'
#  '##oe' '##8' 'send' '##nu' '##des' 'nude' 'nude' 'snap' '##cha' '##t'
#  'girls' 'boo' '##bs' 'pussy' 'horn' '##y']
# Sentencia final: 3
# ['happen', 'me', 'on', 'ba', '##cha', '##t', 'and', 'work', 'me', 'cum', 'creamy', '##oe', '##8', 'blackish', '##nu', '##des', 'nude', 'kemp', 'disgrace', '##cha', '##t', 'girls', 'fulham', '##bs', 'blue', 'horn', '##y']
#
#
# Sentencia original:
# ['rt' 'ole' '##sm' '##eh' '##a' '##86' 'he' 'need' 'me' 'to' 'eat' 'his'
#  'dick' 'because' 'eat' 'dick' 'it' 's' 'my' 'skill' 'sl' '##ut' 'ass'
#  'dick' 'cock' 'jail' '##bai' '##t' 'bbc' 'gang' '##bang' 'cu' '##cko'
#  '##ld']
# Sentencia final: 3
# ['ol', 'ole', '##sm', '##eh', '##a', '##86', 'he', 'bonn', 'me', 'to', 'dinner', 'his', 'ate', 'because', 'penis', 'll', 'it', 's', 'my', 'skill', 'butt', '##ut', 'butt', 'asshole', 'butt', 'penis', '##bai', '##t', 'duran', 'croft', '##bang', 'duran', '##cko', '##ld']
#
#
# Sentencia original:
# ['rt' 'tia' '##po' '##gai' '##51' 'please' 'sleep' 'i' 'will' 'do' 'it'
#  'for' 'you' 'guy' 'gt' 'register' 'note' 'verify' 'email' 'to' 'send'
#  'ms' '##g' 'to' 'girls' 'sl' '##ut']
# Sentencia final: 3
# ['po', 'tia', '##po', '##gai', '##51', 'perceive', 'slept', 'slept', 'will', 'do', 'it', 'for', 'you', 'brunette', 'place', 'pinto', 'compute', 'clench', 'ipad', 'to', 'send', 'day', '##g', 'to', 'girls', 'girl', '##ut']
# # terms modificados promedio 9.407784986098239 términos por sentencia
# Largo de sentencia promedio 24.027803521779425 términos por sentencia
# para esta ejecución se debiesen reemplazar 11569  de 13528 terminos
# Resumen de modificaciones: {'NN': 7715, 'JJ': 704, 'NNS': 580, 'VBG': 325, 'VB': 302, 'VBP': 50, 'VBZ': 186, 'VBN': 156, 'VBD': 101, 'JJS': 28, 'JJR': 4}
# Este proceso tomó 62.03997182846069 seg
#
#
# Generando 0 nuevos ejemplos para la clase NonH
# Consultando por la clase NonH
# Entrega label 0
# No se generan ejemplos
# Resumen de modificaciones: {}
# Este proceso tomó 0.4353830814361572 seg
#
#
# Generando 3585 nuevos ejemplos para la clase PhysicalH
# Consultando por la clase PhysicalH
# Entrega label 2
# Sentencia original:
# ['deep' '##th' '##ro' '##at' 'cum' '##shot' 'perfect' 'boo' '##bs'
#  'jewish' 'indian' 'pussy' 'naked' 'lesbian' 'japanese' 'beau' '##t' 'x'
#  '##8' '##9' 't' 'co' 'g' '##f' '##w' '##x' '##st' '##n' '##2' '##fk']
# Sentencia final: 2
# ['time', '##th', '##ro', '##at', 'cum', '##shot', 'crotch', 'chopped', '##bs', 'muslim', 'lesbian', 'pussy', 'islamic', 'islamic', 'powerful', 'racist', '##t', 'cute', '##8', '##9', 'th', 'non', 'se', '##f', '##w', '##x', '##st', '##n', '##2', '##fk']
#
#
# Sentencia original:
# ['rt' 'debbie' '##d' '##7' '##47' '##9' '##9' '##11' '##8' 'steve' '##d'
#  '##48' '##48' 'how' 'dare' 'she' 'honest' 'people' 'and' 'children'
#  'were' 'killed' 'in' 'manchester' 'and' 'this' 'sc' '##um' 'says' 'that'
#  's' 'fair' 're' '##tal' '##i']
# Sentencia final: 2
# ['rt', 'behave', '##d', '##7', '##47', '##9', '##9', '##11', '##8', 'hussain', '##d', '##48', '##48', 'how', 'guess', 'she', 'everybody', 'women', 'and', 'sons', 'were', 'been', 'in', 'kill', 'and', 'this', 'state', '##um', 'wants', 'that', 's', 'body', 'ma', '##tal', '##i']
#
#
# Sentencia original:
# ['pr' '##ae' '##tors' '##uit' 'which' 'specifically' 'i' 'x' '##8' '##9'
#  'd' 'personally' 'pitch' 'black' 'world' 'devil' 'there' 'rap' '##ist'
#  'an' 'x' '##8' '##9' 't' 'co' 'bu' '##rg' '##t' '##j' '##fr' '##ya']
# Sentencia final: 2
# ['anwar', '##ae', '##tors', '##uit', 'which', 'specifically', 'pic', 'someone', '##8', '##9', 'chopped', 'personally', 'pitch', 'white', 'state', 'state', 'there', 'life', '##ist', 'an', 'racist', '##8', '##9', 'shi', 'rt', 'se', '##rg', '##t', '##j', '##fr', '##ya']
#
#
# Sentencia original:
# ['sas' '##sy' 'wants' 'signing' 'first' 'prepare' 'good' 'don' 't' 'know'
#  'x' '##8' '##9' 't' 'co' 'qi' '##q' '##gi' '##b' '##17' '##ik']
# Sentencia final: 2
# ['hasn', '##sy', 'wants', 'behave', 'first', 'destroy', 'horrible', 'didn', 'smack', 'do', 'rt', '##8', '##9', 't', 'hussain', 'qi', '##q', '##gi', '##b', '##17', '##ik']
#
#
# Sentencia original:
# ['bb' '##adi' '##cal' '##i' 'sarcastic' '##fe' '##m' '##23' 'ms' '##vani'
#  '##llar' '##ose' 'facebook' 'habit' '##ually' 'hara' '##ss' 'calling'
#  'addicted' 'drug' '##gy' 'hooker' 'for' 'x' '##8' '##9']
# Sentencia final: 2
# ['ll', '##adi', '##cal', '##i', 'aesthetic', '##fe', '##m', '##23', 'anwar', '##vani', '##llar', '##ose', 'terrorism', 'twitter', '##ually', 'hara', '##ss', 'calling', 'fucked', 'hussain', '##gy', 'hooker', 'for', 'suicidal', '##8', '##9']
#
#
# Sentencia original:
# ['hot' 'british' 'sl' '##ut' 'cr' '##iss' '##y' 'will' 'give' 'you' 'a'
#  'wet' 'dream' 'when' 'she' 'rubs' 'on' 'her' 'pussy' 'cam' '##girl']
# Sentencia final: 2
# ['other', 'white', 'hussain', '##ut', 'fl', '##iss', '##y', 'will', 'have', 'you', 'a', 'wish', 'dream', 'when', 'she', 'rubs', 'on', 'her', 'eve', 'cam', '##girl']
#
#
# Sentencia original:
# ['the' 'woman' 'brutally' 'tortured' 'minor' 'servant' 'starved' 'major'
#  'am' '##mara' 'm' 'x' '##8' '##9' 't' 'co' 'y' '##j' '##9' '##6' '##d'
#  '##2' '##x' '##gr' '##p']
# Sentencia final: 2
# ['the', 'girl', 'brutally', 'starved', 'minor', 'servant', 'addicted', 'big', 'are', '##mara', 'ur', 'state', '##8', '##9', 'th', 'messy', 'rt', '##j', '##9', '##6', '##d', '##2', '##x', '##gr', '##p']
#
#
# Sentencia original:
# ['p' '##0' '##rn' '##sf' '##w' 'daddy' 'behave' 'baby' 'daddy' 'tight'
#  'open' 'yeah' 'little' 'x' '##8' '##9']
# Sentencia final: 2
# ['husband', '##0', '##rn', '##sf', '##w', 'anwar', 'anwar', 'juicy', 'messy', 'okay', 'horrible', 'okay', 'little', 'minor', '##8', '##9']
#
#
# Sentencia original:
# ['what' 'i' 'don' 't' 'get' 'is' 'how' 'y' 'all' 'try' 'to' 'drag' 'becky'
#  'for' 'body' 'shame' 'charlotte' 'when' 'she' 'didn' 't' 'but' 'laugh'
#  'at' 'a' 'fan' 'th']
# Sentencia final: 2
# ['what', 'head', 'don', 'head', 'be', 'has', 'how', 'time', 'all', 'laugh', 'to', 'behave', 'becky', 'for', 'murderer', 'throat', 'charlotte', 'when', 'she', 'doesn', 'cute', 'but', 'laugh', 'at', 'a', 'fan', 'fl']
#
#
# # terms modificados promedio 9.538912133891213 términos por sentencia
# Largo de sentencia promedio 24.073919107391912 términos por sentencia
# para esta ejecución se debiesen reemplazar 37530  de 44140 terminos
# Resumen de modificaciones: {'NN': 25593, 'JJ': 1752, 'NNS': 1535, 'VBN': 654, 'VBZ': 960, 'VB': 1471, 'VBP': 246, 'VBG': 1208, 'JJS': 102, 'VBD': 676}
# Este proceso tomó 133.1016652584076 seg
#
#
# Generando 3606 nuevos ejemplos para la clase IndirectH
# Consultando por la clase IndirectH
# Entrega label 1
# Sentencia original:
# ['the' 'people' 'that' 'work' 'in' 'the' 'dining' 'hall' 'are' 'all'
#  'sitting' 'here' 'talking' 'shit' 'about' 'this' 'girl' 'that' 'came'
#  'in' 'first' 'thing']
# Sentencia final: 1
# ['the', 'women', 'that', 'time', 'in', 'the', 'dining', 'right', 'are', 'all', 'being', 'here', 'messing', 'part', 'about', 'this', 'girl', 'that', 'was', 'in', 'first', 'part']
#
#
# Sentencia original:
# ['i' 'will' 'never' 'understand' 'how' 'girls' 'can' 'sl' '##ut' 'shame'
#  'other' 'girls' 'for' 'having' 'male' 'friends']
# Sentencia final: 1
# ['part', 'will', 'never', 'feminism', 'how', 'boys', 'can', 'embarrassment', '##ut', 'girl', 'new', 'girls', 'for', 'enjoying', 'male', 'females']
#
#
# Sentencia original:
# ['shy' '##ler' '##lit' '##tle' '##e' 'honestly' 'can' 'x' '##8' '##9' 't'
#  'relate' 'girls' 'shame' 'different' 'every' 'weekend' 'fuck' '##in'
#  'number' 'x' '##8' '##9']
# Sentencia final: 1
# ['leftist', '##ler', '##lit', '##tle', '##e', 'honestly', 'can', 'ha', '##8', '##9', 'cheryl', 'relate', 'girls', 'girl', 'new', 'every', 'faulty', 'week', '##in', 'time', 'time', '##8', '##9']
#
#
# Sentencia original:
# ['the' '##kat' '##ied' '##ren' '##nen' 'katie' 'is' 'totally' 'turning'
#  'into' 'one' 'of' 'those' 'girls' 'who' 'gets' 'married' 'and' 'forget'
#  'two' 'years' 'ago' 'she' 'wa']
# Sentencia final: 1
# ['the', '##kat', '##ied', '##ren', '##nen', 'faulty', 'gets', 'totally', 'being', 'into', 'one', 'of', 'those', 'boys', 'who', 'wants', 'such', 'and', 'asleep', 'two', 'times', 'ago', 'she', 'wa']
#
#
# Sentencia original:
# ['baku' '##bro' '##ws' 'freaked' '##by' '##du' '##bu' '##l' '##g' 'sara'
#  '##ot' '##5' 'how' 'can' 'u' 'go' 'from' 'wonder' 'girls' 'and' 'miss'
#  'a' 'to' 'twice' 'and' 'these' 'ladies' 'l' '##m' '##fa' '##o' 'i' 'can'
#  't']
# Sentencia final: 1
# ['baku', '##bro', '##ws', 'freaked', '##by', '##du', '##bu', '##l', '##g', 'leftist', '##ot', '##5', 'how', 'can', 'week', 'go', 'from', 'wonder', 'boys', 'and', 'girl', 'a', 'to', 'twice', 'and', 'these', 'people', 'woman', '##m', '##fa', '##o', 'i', 'can', 'time']
#
#
# Sentencia original:
# ['love' '##toy' 'ca' 'that' 's' 'a' 'well' 'trained' 'girl']
# Sentencia final: 1
# ['want', '##toy', 'ca', 'that', 's', 'a', 'well', 'tortured', 'training']
#
#
# Sentencia original:
# ['just' 'inn' '##7' 'kai' '##tma' '##rie' '##ox' 'sl' '##ut' 'arm' '##pit'
#  '##s' 'hairy' 'surely' 'don' 't' 'feminist' 'so' 'x' '##8' '##9' 't' 'co'
#  'ca' '##y' '##z' '##13' '##cu' '##3' '##e']
# Sentencia final: 1
# ['just', 'inn', '##7', 'faulty', '##tma', '##rie', '##ox', 'faulty', '##ut', 'faulty', '##pit', '##s', 'didn', 'surely', 'doesn', 'didn', 'didn', 'so', 'feminism', '##8', '##9', 't', 'ha', 'ca', '##y', '##z', '##13', '##cu', '##3', '##e']
#
#
# Sentencia original:
# ['number' 't' 'you' 'should' 'do' 'to' 'him' 'all' 'by' 'now' 'you' 'will'
#  'need' 'to' 'make' 'him' 'a' 'few' 'times' 'until' 'she' 'is' 'ready'
#  'and' 'he' 'just' 'lets' 'h']
# Sentencia final: 1
# ['doesn', 'time', 'you', 'should', 'say', 'to', 'him', 'all', 'by', 'now', 'you', 'will', 'want', 'to', 'have', 'him', 'a', 'few', 'years', 'until', 'she', 'has', 'other', 'and', 'he', 'just', 'feels', 'h']
#
#
# Sentencia original:
# ['mrs' 'hc' '##m' 'tr' '##ad' '##po' '##aster' '##100' '##0' 'also'
#  'though' 'if' 'eggs' 'are' 'the' 'resource' 'guys' 'are' 'after' 'vs' 'a'
#  'good' 'and' 'vi' '##rt' '##uous' 'wife' 'who' 'will']
# Sentencia final: 1
# ['ms', 'hc', '##m', 'rt', '##ad', '##po', '##aster', '##100', '##0', 'also', 'though', 'if', 'aren', 'are', 'the', 'work', 'aren', 'are', 'after', 'right', 'a', 'different', 'and', 'faulty', '##rt', '##uous', 'girlfriend', 'who', 'will']
# # terms modificados promedio 8.56073211314476 términos por sentencia
# Largo de sentencia promedio 22.707986688851914 términos por sentencia
# para esta ejecución se debiesen reemplazar 33730  de 39784 terminos
# Resumen de modificaciones: {'NNS': 2245, 'NN': 21976, 'VBG': 1268, 'VBD': 598, 'JJ': 1761, 'VBZ': 990, 'VBN': 962, 'VB': 1020, 'VBP': 50}
# Este proceso tomó 119.48838448524475 seg
#
# --------------------------------------------------------
#
# Generando ejemplos en base a probabilidad -->  0.85
# --------------------------------------------------------
#
#
# Generando 1079 nuevos ejemplos para la clase SexualH
# Consultando por la clase SexualH
# Entrega label 3
# Sentencia original:
# ['pic' 'mexican' 'school' 'girl' 'naked' 'melanie' 'sa' '##fk' '##a'
#  'fake' 'nude' 'photos' 'hardcore' 'sl' '##ut' 'movies' 'alicia' 'moore'
#  'porn' 'star' 'too' '##n' 'love']
# Sentencia final: 3
# ['pic', 'colombian', 'nude', 'girl', 'live', 'melanie', 'sa', '##fk', '##a', 'fake', 'gangster', 'videos', 'porn', 'sl', '##ut', 'dishes', 'alicia', 'movie', 'porn', 'cleavage', 'too', '##n', 'lover']
#
#
# Sentencia original:
# ['girl' 'dirty' 'quarterback' 'latino' 'pokemon' 'young' 'hand' '##jo'
#  '##b' 'kissing' 'gang' '##bang' 'w' 'x' '##8' '##9' 't' 'co' 'wr' '##m'
#  '##4' '##x' '##o' '##00' '##v' '##j']
# Sentencia final: 3
# ['brunette', 'brunette', 'boy', 'latino', 'pokemon', 'noteworthy', 'hand', '##jo', '##b', 'embracing', 'gangster', '##bang', 'wc', 'wc', '##8', '##9', 'rb', 'ko', 'wr', '##m', '##4', '##x', '##o', '##00', '##v', '##j']
#
#
# Sentencia original:
# ['mil' '##ion' '##do' '##lla' '##me' '##at' 'sex' '##ting' 'n' 'ng' '##ir'
#  '##l' 'daddy' 'n' 'nme' 'listen' 'bitch' 'gonna' 'watch' 'these' 'what']
# Sentencia final: 3
# ['concerto', '##ion', '##do', '##lla', '##me', '##at', 'change', '##ting', 'cat', 'hs', '##ir', '##l', 'ebony', 'creamy', 'mommy', 'gotta', 'gotta', 'gotta', 'watch', 'these', 'what']
#
#
# Sentencia original:
# ['museum' 'sl' '##ut' 'if' 'you' 'know' 'somewhere' 'we' 'can' 'do' 'it'
#  'then' 'i' 'am' 'game']
# Sentencia final: 3
# ['league', 'bat', '##ut', 'if', 'you', 'see', 'somewhere', 'we', 'can', 'do', 'it', 'then', 'play', 'are', 'game']
#
#
# Sentencia original:
# ['rt' 'sp' '##00' '##ky' '##bit' '##ch' '##hh' '##h' 'i' 'have' 'spots'
#  'open' 'sis' '##sy' 'sl' '##ut' 'into' '##x' 'bitch' 'human' 'atm'
#  'amazon' 'boy' 'do' 'you' 'have' 'what' 'it' 'takes' 'can' 'you' 'live'
#  'up' 'to' 'my']
# Sentencia final: 3
# ['bt', 'sp', '##00', '##ky', '##bit', '##ch', '##hh', '##h', 'i', 'have', 'spots', 'active', 'salty', '##sy', 'gal', '##ut', 'into', '##x', 'family', 'whore', 'atm', 'girl', 'boy', 'go', 'you', 'know', 'what', 'it', 'makes', 'can', 'you', 'dead', 'up', 'to', 'my']
#
#
# Sentencia original:
# ['venus' 'astro' '##logy' 'living' 'standards' 'ni' '##t' 'x' '##8' '##9'
#  's' 'illusion' 'i' 'x' '##8' '##9' 'm' 'fucking' 'nwa' '##iting'
#  'waiting' 'wai' 'x' '##8' '##9']
# Sentencia final: 3
# ['venus', 'astro', '##logy', 'woken', 'cooks', 'cullen', '##t', 'x', '##8', '##9', 'dino', 'illusion', 'pinto', 'pinto', '##8', '##9', 'dubai', 'freaking', 'nwa', '##iting', 'shouting', 'wai', 'heartbreak', '##8', '##9']
#
#
# Sentencia original:
# ['add' 'me' 'on' 'snap' '##cha' '##t' 'and' 'watch' 'me' 'cum' 'colt'
#  '##oe' '##8' 'send' '##nu' '##des' 'nude' 'nude' 'snap' '##cha' '##t'
#  'girls' 'boo' '##bs' 'pussy' 'horn' '##y']
# Sentencia final: 3
# ['say', 'me', 'on', 'ba', '##cha', '##t', 'and', 'mori', 'me', 'insist', 'creamy', '##oe', '##8', 'disrupt', '##nu', '##des', 'bikini', 'kemp', 'bikini', '##cha', '##t', 'boys', 'girl', '##bs', 'bum', 'horn', '##y']
#
#
# Sentencia original:
# ['rt' 'ole' '##sm' '##eh' '##a' '##86' 'he' 'need' 'me' 'to' 'eat' 'his'
#  'dick' 'because' 'eat' 'dick' 'it' 's' 'my' 'skill' 'sl' '##ut' 'ass'
#  'dick' 'cock' 'jail' '##bai' '##t' 'bbc' 'gang' '##bang' 'cu' '##cko'
#  '##ld']
# Sentencia final: 3
# ['rt', 'ol', '##sm', '##eh', '##a', '##86', 'he', 'bonn', 'me', 'to', 'prefer', 'his', 'ate', 'because', 'penis', 'ate', 'it', 'penis', 'my', 'skill', 'butt', '##ut', 'asshole', 'dick', 'butt', 'penis', '##bai', '##t', 'moran', 'croft', '##bang', 'duran', '##cko', '##ld']
#
#
# Sentencia original:
# ['rt' 'tia' '##po' '##gai' '##51' 'please' 'sleep' 'i' 'will' 'do' 'it'
#  'for' 'you' 'guy' 'gt' 'register' 'note' 'verify' 'email' 'to' 'send'
#  'ms' '##g' 'to' 'girls' 'sl' '##ut']
# Sentencia final: 3
# ['po', 'tia', '##po', '##gai', '##51', 'slept', 'work', 'stay', 'will', 'have', 'it', 'for', 'you', 'dude', 'verify', 'stabbed', 'compute', 'compute', 'ipad', 'to', 'bring', 'ms', '##g', 'to', 'boys', 'girl', '##ut']

# %%
prob=0.85 
TOPN=1

fs_macro={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
fs_none={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
accs={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
confusions={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}


for i in range(1,6):
    print ("----------------------- Entrenando running ", i,"-----------------------")
    macro_augmented=np.load('../../../new_data_augmented/harassment/Aumento_'+str(i)+'-run_'+str(prob)+'_app1_Top'+str(TOPN)+'.npy', allow_pickle=True)
    
    ids_train=macro_augmented[:,0]
    tws_train=macro_augmented[:,1]
    labels_train=macro_augmented[:,2]
    class_weights= compute_class_weight('balanced', np.unique(labels_train), labels_train)
    print ("Pesos de clases:", class_weights)
    
    etiq=labels_train.copy()
    sentences = tws_train
    n_labels = np.array(etiq)

    input_ids = []
    for sent in sentences:
        encoded_sent = tokenizer_loaded.encode(list(sent),add_special_tokens = False)    
        input_ids.append(encoded_sent)
    input_ids = pad_sequences(input_ids,maxlen=MAX_LEN,dtype="long",value=0, truncating="post", padding="post")
    y_train=to_categorical(n_labels,num_classes=4)
    shape=np.asarray(input_ids).shape
    x_train=np.zeros((shape[0], shape[1], 768))
    j=0
    for in_id in input_ids:
        x_train[j]=M_BERT_space[in_id]
        j+=1

    ###########################################################
    ############################################################
    ############################################################
    
    cnn1=create_ccn1(x_train.shape[1:])
    trained =train_model(cnn1, x_train, y_train, x_val, y_val, class_weights, e=30, BS=32, verb=0, focal=True)
    trained.save('../../../new_data_augmented/harassment_baselines/'+str(prob)+'/cnn1_'+str(i)+'-exec_app1_Top_'+str(TOPN)+'.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(trained, x_train, x_val, x_test, etiq, etiq_v, etiq_t, 'cnn1')
    fs_macro['cnn1'].append(f1_ma_t)
    fs_none['cnn1'].append(f1_t)
    accs['cnn1'].append(acc_t)
    confusions['cnn1'].append(matriz_t)
    
    cnn2=create_cnn2(x_train.shape[1:])
    trained =train_model(cnn2, x_train, y_train, x_val, y_val, class_weights, e=30, BS=32, verb=0, focal=True)
    trained.save('../../../new_data_augmented/harassment_baselines/'+str(prob)+'/cnn2_'+str(i)+'-exec_app1_Top_'+str(TOPN)+'.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(trained, x_train, x_val, x_test, etiq, etiq_v, etiq_t, 'cnn2')
    fs_macro['cnn2'].append(f1_ma_t)
    fs_none['cnn2'].append(f1_t)
    accs['cnn2'].append(acc_t)
    confusions['cnn2'].append(matriz_t)
    
    rnn1=create_complex_GRU_2(128,64,"adam",x_train.shape[1:])
    trained =train_model(rnn1, x_train, y_train, x_val, y_val, class_weights, e=30, BS=32, verb=0, focal=True)
    trained.save('../../../new_data_augmented/harassment_baselines/'+str(prob)+'/rnn1_'+str(i)+'-exec_app1_Top_'+str(TOPN)+'.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(trained, x_train, x_val, x_test, etiq, etiq_v, etiq_t, 'rnn1')
    fs_macro['rnn1'].append(f1_ma_t)
    fs_none['rnn1'].append(f1_t)
    accs['rnn1'].append(acc_t)
    confusions['rnn1'].append(matriz_t)
    
    rnn2=create_complex_GRU_3(256,128,64,"adam",x_train.shape[1:])
    trained =train_model(rnn2, x_train, y_train, x_val, y_val, class_weights, e=30, BS=32, verb=0, focal=True)
    trained.save('../../../new_data_augmented/harassment_baselines/'+str(prob)+'/rnn2_'+str(i)+'-exec_app1_Top_'+str(TOPN)+'.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(trained, x_train, x_val, x_test, etiq, etiq_v, etiq_t, 'rnn2')
    fs_macro['rnn2'].append(f1_ma_t)
    fs_none['rnn2'].append(f1_t)
    accs['rnn2'].append(acc_t)
    confusions['rnn2'].append(matriz_t)
    
    rnn3=create_complex_GRU_3(256,128,64,"adam",x_train.shape[1:])
    trained =train_model(rnn3, x_train, y_train, x_val, y_val, class_weights, e=30, BS=32, verb=0, focal=False)
    trained.save('../../../new_data_augmented/harassment_baselines/'+str(prob)+'/rnn3_'+str(i)+'-exec_app1_Top_'+str(TOPN)+'.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(trained, x_train, x_val, x_test, etiq, etiq_v, etiq_t, 'rnn3')
    fs_macro['rnn3'].append(f1_ma_t)
    fs_none['rnn3'].append(f1_t)
    accs['rnn3'].append(acc_t)
    confusions['rnn3'].append(matriz_t)
# Out:
# ----------------------- Entrenando running  1 -----------------------
# Pesos de clases: [1. 1. 1. 1.]
#
# Accuracy sobre Train cnn1 : 0.9776700355094237
# F1-score None sobre Train cnn1 : [0.95741795 0.99876965 0.99795054 0.95659341]
# F1-score macro sobre Train cnn1 : 0.9776828881656994
#
# Accuracy sobre Val cnn1 : 0.6390588235294118
# F1-score None sobre Val cnn1 : [0.71148225 0.         0.07843137 0.58265896]
# F1-score macro sobre Val cnn1 : 0.34314314669596946
#
# Accuracy sobre Test cnn1 : 0.6424870466321243
# F1-score None sobre Test cnn1 : [0.75982533 0.03669725 0.07317073 0.48201989]
# F1-score macro sobre Test cnn1 : 0.3379282999522811
#
# Accuracy sobre Train cnn2 : 0.9456432668669762
# F1-score None sobre Train cnn2 : [0.88268326 0.99781182 0.99794886 0.90240277]
# F1-score macro sobre Train cnn2 : 0.9452116771766055
#
# Accuracy sobre Val cnn2 : 0.552
# F1-score None sobre Val cnn2 : [0.60302891 0.         0.04255319 0.52766393]
# F1-score macro sobre Val cnn2 : 0.29331150956517593
#
# Accuracy sobre Test cnn2 : 0.5280263777673104
# F1-score None sobre Test cnn2 : [0.64431725 0.         0.02531646 0.41114551]
# F1-score macro sobre Test cnn2 : 0.2701948047973789
#
# Accuracy sobre Train rnn1 : 0.9887325867249386
# F1-score None sobre Train rnn1 : [0.98304165 0.99904489 0.99483555 0.97786999]
# F1-score macro sobre Train rnn1 : 0.9886980197947166
#
# Accuracy sobre Val rnn1 : 0.6475294117647059
# F1-score None sobre Val rnn1 : [0.77374517 0.08571429 0.04819277 0.63864043]
# F1-score macro sobre Val rnn1 : 0.3865731649704751
#
# Accuracy sobre Test rnn1 : 0.6693358455016486
# F1-score None sobre Test rnn1 : [0.79250426 0.23478261 0.14893617 0.52565707]
# F1-score macro sobre Test rnn1 : 0.42547002729784356
#
# Accuracy sobre Train rnn2 : 0.9922835290904125
# F1-score None sobre Train rnn2 : [0.98606036 0.9989083  0.99863537 0.98550324]
# F1-score macro sobre Train rnn2 : 0.9922768181572
#
# Accuracy sobre Val rnn2 : 0.619764705882353
# F1-score None sobre Val rnn2 : [0.71950719 0.06410256 0.0516129  0.63454411]
# F1-score macro sobre Val rnn2 : 0.36744169023310613
#
# Accuracy sobre Test rnn2 : 0.6391898257183232
# F1-score None sobre Test rnn2 : [0.75948461 0.20304569 0.13138686 0.52599388]
# F1-score macro sobre Test rnn2 : 0.40497776006585406
#
# Accuracy sobre Train rnn3 : 0.9913957934990439
# F1-score None sobre Train rnn3 : [0.98764415 0.99863537 0.99483555 0.98442197]
# F1-score macro sobre Train rnn3 : 0.9913842622750699
#
# Accuracy sobre Val rnn3 : 0.5392941176470588
# F1-score None sobre Val rnn3 : [0.6449626  0.03703704 0.04584527 0.53026316]
# F1-score macro sobre Val rnn3 : 0.3145270179063848
#
# Accuracy sobre Test rnn3 : 0.5525200188412623
# F1-score None sobre Test rnn3 : [0.67809821 0.16774194 0.13939394 0.44686192]
# F1-score macro sobre Test rnn3 : 0.3580240017226453
# ----------------------- Entrenando running  2 -----------------------
# Pesos de clases: [1. 1. 1. 1.]
#
# Accuracy sobre Train cnn1 : 0.9784894837476099
# F1-score None sobre Train cnn1 : [0.9572697  0.99890681 0.99931741 0.95845099]
# F1-score macro sobre Train cnn1 : 0.9784862249790147
#
# Accuracy sobre Val cnn1 : 0.6367058823529411
# F1-score None sobre Val cnn1 : [0.70791246 0.         0.04081633 0.58600917]
# F1-score macro sobre Val cnn1 : 0.3336844896887492
#
# Accuracy sobre Test cnn1 : 0.6387187941592086
# F1-score None sobre Test cnn1 : [0.75770925 0.         0.04938272 0.48384673]
# F1-score macro sobre Test cnn1 : 0.3227346747328301
#
# Accuracy sobre Train cnn2 : 0.9757579896203223
# F1-score None sobre Train cnn2 : [0.95298849 0.99822429 0.99863425 0.95318805]
# F1-score macro sobre Train cnn2 : 0.9757587709815628
#
# Accuracy sobre Val cnn2 : 0.6630588235294118
# F1-score None sobre Val cnn2 : [0.7402863  0.         0.04444444 0.60095579]
# F1-score macro sobre Val cnn2 : 0.3464216343792833
#
# Accuracy sobre Test cnn2 : 0.6712199717381064
# F1-score None sobre Test cnn2 : [0.78736244 0.01769912 0.02531646 0.50767987]
# F1-score macro sobre Test cnn2 : 0.33451447092744485
#
# Accuracy sobre Train rnn1 : 0.9897568970226714
# F1-score None sobre Train rnn1 : [0.97983591 0.9994537  0.99904359 0.9806867 ]
# F1-score macro sobre Train rnn1 : 0.9897549719090872
#
# Accuracy sobre Val rnn1 : 0.5995294117647059
# F1-score None sobre Val rnn1 : [0.66492829 0.06122449 0.03703704 0.56204786]
# F1-score macro sobre Val rnn1 : 0.3313094191050592
#
# Accuracy sobre Test rnn1 : 0.5817239755063589
# F1-score None sobre Test rnn1 : [0.70019194 0.1221374  0.08602151 0.43895554]
# F1-score macro sobre Test rnn1 : 0.3368265971022806
#
# Accuracy sobre Train rnn2 : 0.9919420923245015
# F1-score None sobre Train rnn2 : [0.98587299 0.99877234 0.99659632 0.98647726]
# F1-score macro sobre Train rnn2 : 0.9919297279975354
#
# Accuracy sobre Val rnn2 : 0.5614117647058824
# F1-score None sobre Val rnn2 : [0.67635742 0.03524229 0.03614458 0.57988166]
# F1-score macro sobre Val rnn2 : 0.33190648589168925
#
# Accuracy sobre Test rnn2 : 0.5666509656146962
# F1-score None sobre Test rnn2 : [0.69656992 0.20338983 0.13414634 0.45286686]
# F1-score macro sobre Test rnn2 : 0.37174323846158575
#
# Accuracy sobre Train rnn3 : 0.9913275061458617
# F1-score None sobre Train rnn3 : [0.98408304 0.99849829 0.99808743 0.98463198]
# F1-score macro sobre Train rnn3 : 0.9913251866164936
#
# Accuracy sobre Val rnn3 : 0.5312941176470588
# F1-score None sobre Val rnn3 : [0.58190255 0.03636364 0.01724138 0.53397539]
# F1-score macro sobre Val rnn3 : 0.2923707389465324
#
# Accuracy sobre Test rnn3 : 0.5054168629298162
# F1-score None sobre Test rnn3 : [0.61474037 0.15053763 0.11594203 0.41329857]
# F1-score macro sobre Test rnn3 : 0.3236296494360652
# ----------------------- Entrenando running  3 -----------------------
# Pesos de clases: [1. 1. 1. 1.]
#
# Accuracy sobre Train cnn1 : 0.9780114722753346
# F1-score None sobre Train cnn1 : [0.95724099 0.99863351 0.99808429 0.95816177]
# F1-score macro sobre Train cnn1 : 0.9780301411630117
#
# Accuracy sobre Val cnn1 : 0.6724705882352942
# F1-score None sobre Val cnn1 : [0.74767864 0.         0.         0.60932768]
# F1-score macro sobre Val cnn1 : 0.33925158092855234
#
# Accuracy sobre Test cnn1 : 0.6806406029203956
# F1-score None sobre Test cnn1 : [0.79386118 0.         0.02564103 0.51428571]
# F1-score macro sobre Test cnn1 : 0.33344697971485554
#
# Accuracy sobre Train cnn2 : 0.9766457252116908
# F1-score None sobre Train cnn2 : [0.95524862 0.9976741  0.99822186 0.95557351]
# F1-score macro sobre Train cnn2 : 0.976679520584496
#
# Accuracy sobre Val cnn2 : 0.6851764705882353
# F1-score None sobre Val cnn2 : [0.76141326 0.         0.04545455 0.61538462]
# F1-score macro sobre Val cnn2 : 0.35556310501725347
#
# Accuracy sobre Test cnn2 : 0.6914743287800282
# F1-score None sobre Test cnn2 : [0.80194242 0.01818182 0.05063291 0.52640545]
# F1-score macro sobre Test cnn2 : 0.3492906505278518
#
# Accuracy sobre Train rnn1 : 0.8842529363561868
# F1-score None sobre Train rnn1 : [0.92013185 0.96625724 0.77660819 0.85789726]
# F1-score macro sobre Train rnn1 : 0.880223633043269
#
# Accuracy sobre Val rnn1 : 0.7388235294117647
# F1-score None sobre Val rnn1 : [0.8096313  0.02702703 0.         0.66531714]
# F1-score macro sobre Val rnn1 : 0.3754938669397503
#
# Accuracy sobre Test rnn1 : 0.7503532736693358
# F1-score None sobre Test rnn1 : [0.84445864 0.         0.         0.58092176]
# F1-score macro sobre Test rnn1 : 0.3563450992957402
#
# Accuracy sobre Train rnn2 : 0.9554766457252117
# F1-score None sobre Train rnn2 : [0.91444642 0.99063103 0.99658982 0.92030719]
# F1-score macro sobre Train rnn2 : 0.9554936146461804
#
# Accuracy sobre Val rnn2 : 0.44376470588235295
# F1-score None sobre Val rnn2 : [0.44604317 0.02597403 0.01834862 0.47875354]
# F1-score macro sobre Val rnn2 : 0.2422798390928375
#
# Accuracy sobre Test rnn2 : 0.42534149788035797
# F1-score None sobre Test rnn2 : [0.51171171 0.08547009 0.1        0.36221353]
# F1-score macro sobre Test rnn2 : 0.26484883107297863
#
# Accuracy sobre Train rnn3 : 0.9923518164435946
# F1-score None sobre Train rnn3 : [0.98863792 0.99781719 0.99464506 0.98833107]
# F1-score macro sobre Train rnn3 : 0.9923578111563823
#
# Accuracy sobre Val rnn3 : 0.6258823529411764
# F1-score None sobre Val rnn3 : [0.70182724 0.09411765 0.05       0.58333333]
# F1-score macro sobre Val rnn3 : 0.35731955572926843
#
# Accuracy sobre Test rnn3 : 0.6325953838907207
# F1-score None sobre Test rnn3 : [0.75261073 0.10638298 0.07407407 0.475     ]
# F1-score macro sobre Test rnn3 : 0.3520169459505399
# ----------------------- Entrenando running  4 -----------------------
# Pesos de clases: [1. 1. 1. 1.]
#
# Accuracy sobre Train cnn1 : 0.976714012564873
# F1-score None sobre Train cnn1 : [0.95554957 0.99877032 0.998635   0.95387173]
# F1-score macro sobre Train cnn1 : 0.9767066547003274
#
# Accuracy sobre Val cnn1 : 0.7355294117647059
# F1-score None sobre Val cnn1 : [0.81054614 0.         0.04081633 0.66167461]
# F1-score macro sobre Val cnn1 : 0.37825926861689363
#
# Accuracy sobre Test cnn1 : 0.765897315120113
# F1-score None sobre Test cnn1 : [0.8585209  0.         0.07407407 0.60695469]
# F1-score macro sobre Test cnn1 : 0.38488741588552183
#
# Accuracy sobre Train cnn2 : 0.9745288172630429
# F1-score None sobre Train cnn2 : [0.95021495 0.99849665 0.99863351 0.95081967]
# F1-score macro sobre Train cnn2 : 0.9745411948924344
#
# Accuracy sobre Val cnn2 : 0.6555294117647059
# F1-score None sobre Val cnn2 : [0.73122692 0.08474576 0.07272727 0.60365854]
# F1-score macro sobre Val cnn2 : 0.37308962259168177
#
# Accuracy sobre Test cnn2 : 0.6552048987282147
# F1-score None sobre Test cnn2 : [0.77357143 0.         0.05063291 0.48803828]
# F1-score macro sobre Test cnn2 : 0.3280606543689489
#
# Accuracy sobre Train rnn1 : 0.9646271510516252
# F1-score None sobre Train rnn1 : [0.92935178 0.99437354 0.99918033 0.93551689]
# F1-score macro sobre Train rnn1 : 0.9646056356601252
#
# Accuracy sobre Val rnn1 : 0.47858823529411765
# F1-score None sobre Val rnn1 : [0.4970297  0.02631579 0.05479452 0.49207112]
# F1-score macro sobre Val rnn1 : 0.26755278316148473
#
# Accuracy sobre Test rnn1 : 0.4743287800282619
# F1-score None sobre Test rnn1 : [0.57424893 0.10344828 0.13186813 0.38150965]
# F1-score macro sobre Test rnn1 : 0.2977687473844245
#
# Accuracy sobre Train rnn2 : 0.978899207866703
# F1-score None sobre Train rnn2 : [0.9729805  0.99863239 0.98306496 0.96153846]
# F1-score macro sobre Train rnn2 : 0.9790540779901272
#
# Accuracy sobre Val rnn2 : 0.5355294117647059
# F1-score None sobre Val rnn2 : [0.57835821 0.04651163 0.08510638 0.52103396]
# F1-score macro sobre Val rnn2 : 0.30775254456996237
#
# Accuracy sobre Test rnn2 : 0.49740932642487046
# F1-score None sobre Test rnn2 : [0.60375783 0.07575758 0.0952381  0.39633028]
# F1-score macro sobre Test rnn2 : 0.2927709437587624
#
# Accuracy sobre Train rnn3 : 0.9909177820267686
# F1-score None sobre Train rnn3 : [0.98962032 0.9989071  0.99120076 0.98388208]
# F1-score macro sobre Train rnn3 : 0.9909025654127775
#
# Accuracy sobre Val rnn3 : 0.5694117647058824
# F1-score None sobre Val rnn3 : [0.72380179 0.10909091 0.04305284 0.53776978]
# F1-score macro sobre Val rnn3 : 0.3534288295004657
#
# Accuracy sobre Test rnn3 : 0.6415449835138954
# F1-score None sobre Test rnn3 : [0.77090654 0.22510823 0.12903226 0.53952321]
# F1-score macro sobre Test rnn3 : 0.4161425576765788
# ----------------------- Entrenando running  5 -----------------------
# Pesos de clases: [1. 1. 1. 1.]
#
# Accuracy sobre Train cnn1 : 0.9731630701993991
# F1-score None sobre Train cnn1 : [0.94606869 0.99877032 0.99808534 0.9496781 ]
# F1-score macro sobre Train cnn1 : 0.9731506129824596
#
# Accuracy sobre Val cnn1 : 0.6282352941176471
# F1-score None sobre Val cnn1 : [0.69847973 0.02702703 0.04651163 0.5733711 ]
# F1-score macro sobre Val cnn1 : 0.3363473723698994
#
# Accuracy sobre Test cnn1 : 0.6354215732454075
# F1-score None sobre Test cnn1 : [0.75365497 0.         0.05       0.48060837]
# F1-score macro sobre Test cnn1 : 0.32106583394481136
#
# Accuracy sobre Train cnn2 : 0.9758945643266868
# F1-score None sobre Train cnn2 : [0.95321239 0.99863388 0.998771   0.95296691]
# F1-score macro sobre Train cnn2 : 0.9758960434510516
#
# Accuracy sobre Val cnn2 : 0.6898823529411765
# F1-score None sobre Val cnn2 : [0.76561878 0.05063291 0.07142857 0.62421973]
# F1-score macro sobre Val cnn2 : 0.37797499762404296
#
# Accuracy sobre Test cnn2 : 0.7037211493170042
# F1-score None sobre Test cnn2 : [0.81220014 0.03539823 0.075      0.53568282]
# F1-score macro sobre Test cnn2 : 0.3645702966379869
#
# Accuracy sobre Train rnn1 : 0.9139579349904398
# F1-score None sobre Train rnn1 : [0.8591878  0.94889463 0.99146688 0.85949248]
# F1-score macro sobre Train rnn1 : 0.9147604492778751
#
# Accuracy sobre Val rnn1 : 0.40752941176470586
# F1-score None sobre Val rnn1 : [0.39190628 0.02777778 0.03539823 0.4526749 ]
# F1-score macro sobre Val rnn1 : 0.22693929706642502
#
# Accuracy sobre Test rnn1 : 0.38530381535562885
# F1-score None sobre Test rnn1 : [0.45381336 0.01834862 0.13559322 0.34591195]
# F1-score macro sobre Test rnn1 : 0.2384167881188874
#
# Accuracy sobre Train rnn2 : 0.9921469543840481
# F1-score None sobre Train rnn2 : [0.98563415 0.99863239 0.99863239 0.985724  ]
# F1-score macro sobre Train rnn2 : 0.992155729299985
#
# Accuracy sobre Val rnn2 : 0.68
# F1-score None sobre Val rnn2 : [0.76306483 0.04761905 0.03603604 0.62251656]
# F1-score macro sobre Val rnn2 : 0.3673091182380921
#
# Accuracy sobre Test rnn2 : 0.700423928403203
# F1-score None sobre Test rnn2 : [0.8087395  0.03603604 0.1        0.53076923]
# F1-score macro sobre Test rnn2 : 0.36888619065089645
#
# Accuracy sobre Train rnn3 : 0.9928981152690521
# F1-score None sobre Train rnn3 : [0.98786542 0.99713857 0.99904385 0.98752711]
# F1-score macro sobre Train rnn3 : 0.9928937381527678
#
# Accuracy sobre Val rnn3 : 0.5816470588235294
# F1-score None sobre Val rnn3 : [0.67237687 0.07929515 0.06486486 0.58017299]
# F1-score macro sobre Val rnn3 : 0.3491774700175433
#
# Accuracy sobre Test rnn3 : 0.6029203956665097
# F1-score None sobre Test rnn3 : [0.72605293 0.12280702 0.12345679 0.48081841]
# F1-score macro sobre Test rnn3 : 0.3632837869547157

# %%
for key in fs_none.keys():
    temp=np.zeros(4)
    for result in fs_none[key]:
        temp+=result
    print ("(0.85) F1-score promedio para",key,":" ,temp/5)

print ("")
for key in fs_macro.keys():
    temp=np.sum(fs_macro[key])
    print ("(0.85) F1-score macro promedio para",key,":" ,temp/5, "desvest: ",np.std(fs_macro[key]))

print ("")
for key in accs.keys():
    temp=np.sum(accs[key])
    print ("(0.85) Accuracy promedio para",key,":" ,temp/5)
# Out:
# (0.85) F1-score promedio para cnn1 : [0.78471433 0.00733945 0.05445371 0.51354308]
# (0.85) F1-score promedio para cnn2 : [0.76387874 0.01425583 0.04537975 0.49379039]
# (0.85) F1-score promedio para rnn1 : [0.67304342 0.09574338 0.10048381 0.45459119]
# (0.85) F1-score promedio para rnn2 : [0.67605271 0.12073984 0.11215426 0.45363476]
# (0.85) F1-score promedio para rnn3 : [0.70848175 0.15451556 0.11637982 0.47110042]
#
# (0.85) F1-score macro promedio para cnn1 : 0.34001264084606 desvest:  0.023318265041193435
# (0.85) F1-score macro promedio para cnn2 : 0.3293261754519223 desvest:  0.03214270459147205
# (0.85) F1-score macro promedio para rnn1 : 0.3309654518398353 desvest:  0.062091659108941315
# (0.85) F1-score macro promedio para rnn2 : 0.3406453928020155 desvest:  0.052802185156896594
# (0.85) F1-score macro promedio para rnn3 : 0.362619388348109 desvest:  0.03006293460037831
#
# (0.85) Accuracy promedio para cnn1 : 0.6726330664154498
# (0.85) Accuracy promedio para cnn2 : 0.6499293452661329
# (0.85) Accuracy promedio para rnn1 : 0.5722091380122467
# (0.85) Accuracy promedio para rnn2 : 0.5658031088082902
# (0.85) Accuracy promedio para rnn3 : 0.5869995289684409

# %%
for key in confusions.keys():
    temp=np.sum(confusions[key], axis=0)/5.0
    plot_confusion_matrix(temp, ['NonH','IndirectH','PhysicalH','SexualH'], "(0.85) Classic - Confusion Matrix "+str(key), cmap='Purples')

# %% [markdown]
# # Baselines sin aumento

# %%
ids_train=train['tweet_id']
tws_train=train['Tweet']
labels_train=[d_lab[lb] for lb in train['Label']]
class_weights= compute_class_weight('balanced', np.unique(labels_train), labels_train)
print ("Pesos de clases:", class_weights)

etiq=labels_train.copy()
etiq=np.asarray(etiq)
sentences = tws_train
n_labels = np.array(etiq)

y_train=to_categorical(n_labels,num_classes=4)
input_ids = []
i=0
for sent in sentences:
    temp=cleaner(sent)
    encoded_sent2 = tokenizer_loaded.encode(temp[0],add_special_tokens = False)            
    input_ids.append(encoded_sent2)
    """if i<3:
        print ("-----------------------------------------------------------------")
        print ("\nsentencia original:", sent)
        #print ("\nsentencia procesada My cleaner:",temp[0])
        print ("\nsentencia tokenizada usando Transformer vocabulary:", encoded_sent)
        print ("\nsentencia tokenizada usando Transformer Tokenizer:", encoded_sent2)
    i+=1"""

input_ids = pad_sequences(input_ids, maxlen=MAX_LEN, dtype="long", value=0, truncating="post", padding="post")

shape=np.asarray(input_ids).shape
x_train=np.zeros((shape[0], shape[1], 768))
j=0
for in_id in input_ids:
    x_train[j]=M_BERT_space[in_id]
    j+=1
    
x_train.shape
# Out:
# Pesos de clases: [ 0.43526359 28.97272727 20.96710526  0.61715724]
# (6374, 50, 768)

# %%
Counter(n_labels)
# Out:
# Counter({3: 2582, 0: 3661, 2: 76, 1: 55})

# %%
fs_macro={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
fs_none={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
accs={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
confusions={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}

for i in range(1,6): 
    print ("----------------------- Entrenando running ", i,"-----------------------")
    
    cnn1=create_ccn1(x_train.shape[1:])
    trained =train_model(cnn1, x_train, y_train, x_val, y_val, class_weights, e=30, BS=32, verb=0, focal=True)
    trained.save('../../../new_data_augmented/harassment_baselines/0.0_cw/cnn1_'+str(i)+'-exec.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(trained, x_train, x_val, x_test, etiq, etiq_v, etiq_t, 'cnn1')
    fs_macro['cnn1'].append(f1_ma_t)
    fs_none['cnn1'].append(f1_t)
    accs['cnn1'].append(acc_t)
    confusions['cnn1'].append(matriz_t)
    
    cnn2=create_cnn2(x_train.shape[1:])
    trained =train_model(cnn2, x_train, y_train, x_val, y_val, class_weights, e=30, BS=32, verb=0, focal=True)
    trained.save('../../../new_data_augmented/harassment_baselines/0.0_cw/cnn2_'+str(i)+'-exec.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(trained, x_train, x_val, x_test, etiq, etiq_v, etiq_t, 'cnn2')
    fs_macro['cnn2'].append(f1_ma_t)
    fs_none['cnn2'].append(f1_t)
    accs['cnn2'].append(acc_t)
    confusions['cnn2'].append(matriz_t)
    
    rnn1=create_complex_GRU_2(128,64,"adam",x_train.shape[1:])
    trained =train_model(rnn1, x_train, y_train, x_val, y_val, class_weights, e=30, BS=32, verb=0, focal=True)
    trained.save('../../../new_data_augmented/harassment_baselines/0.0_cw/rnn1_'+str(i)+'-exec.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(trained, x_train, x_val, x_test, etiq, etiq_v, etiq_t, 'rnn1')
    fs_macro['rnn1'].append(f1_ma_t)
    fs_none['rnn1'].append(f1_t)
    accs['rnn1'].append(acc_t)
    confusions['rnn1'].append(matriz_t)
    
    rnn2=create_complex_GRU_3(256,128,64,"adam",x_train.shape[1:])
    trained =train_model(rnn2, x_train, y_train, x_val, y_val, class_weights, e=30, BS=32, verb=0, focal=True)
    trained.save('../../../new_data_augmented/harassment_baselines/0.0_cw/rnn2_'+str(i)+'-exec.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(trained, x_train, x_val, x_test, etiq, etiq_v, etiq_t, 'rnn2')
    fs_macro['rnn2'].append(f1_ma_t)
    fs_none['rnn2'].append(f1_t)
    accs['rnn2'].append(acc_t)
    confusions['rnn2'].append(matriz_t)
    
    rnn3=create_complex_GRU_3(256,128,64,"adam",x_train.shape[1:])
    trained =train_model(rnn3, x_train, y_train, x_val, y_val, class_weights, e=30, BS=32, verb=0, focal=False)
    trained.save('../../../new_data_augmented/harassment_baselines/0.0_cw/rnn3_'+str(i)+'-exec.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(trained, x_train, x_val, x_test, etiq, etiq_v, etiq_t, 'rnn3')
    fs_macro['rnn3'].append(f1_ma_t)
    fs_none['rnn3'].append(f1_t)
    accs['rnn3'].append(acc_t)
    confusions['rnn3'].append(matriz_t)
# Out:
# ----------------------- Entrenando running  1 -----------------------
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:Large dropout rate: 0.65 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.65 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:1702: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:1205: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
#
# Accuracy sobre Train cnn1 : 0.8948854722309382
# F1-score None sobre Train cnn1 : [0.91097196 0.90756303 0.88741722 0.87178488]
# F1-score macro sobre Train cnn1 : 0.8944342701176091
#
# Accuracy sobre Val cnn1 : 0.8790588235294118
# F1-score None sobre Val cnn1 : [0.92652796 0.         0.05       0.83239171]
# F1-score macro sobre Val cnn1 : 0.45222991803379065
#
# Accuracy sobre Test cnn1 : 0.8243052284503062
# F1-score None sobre Test cnn1 : [0.89985816 0.         0.         0.60853432]
# F1-score macro sobre Test cnn1 : 0.3770981197121015
# WARNING:tensorflow:Large dropout rate: 0.65 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.65 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
#
# Accuracy sobre Train cnn2 : 0.897081895199247
# F1-score None sobre Train cnn2 : [0.91255605 0.89256198 0.82222222 0.87893052]
# F1-score macro sobre Train cnn2 : 0.8765676952659961
#
# Accuracy sobre Val cnn2 : 0.8748235294117647
# F1-score None sobre Val cnn2 : [0.926781   0.02739726 0.08163265 0.8229927 ]
# F1-score macro sobre Val cnn2 : 0.4647009041759116
#
# Accuracy sobre Test cnn2 : 0.8337258596325954
# F1-score None sobre Test cnn2 : [0.90650407 0.         0.07594937 0.66774716]
# F1-score macro sobre Test cnn2 : 0.4125501489561395
#
# Accuracy sobre Train rnn1 : 0.7447442736115469
# F1-score None sobre Train rnn1 : [0.88607955 0.53398058 0.12624585 0.69660307]
# F1-score macro sobre Train rnn1 : 0.5607272615877005
#
# Accuracy sobre Val rnn1 : 0.7496470588235294
# F1-score None sobre Val rnn1 : [0.89938817 0.05517241 0.025      0.62158956]
# F1-score macro sobre Val rnn1 : 0.4002875365491192
#
# Accuracy sobre Test rnn1 : 0.7550635892604804
# F1-score None sobre Test rnn1 : [0.8751898  0.1        0.11721612 0.548     ]
# F1-score macro sobre Test rnn1 : 0.41010147843855704
# WARNING:tensorflow:Large dropout rate: 0.65 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
#
# Accuracy sobre Train rnn2 : 0.5955443991214309
# F1-score None sobre Train rnn2 : [0.70903237 0.11969532 0.10948905 0.6906538 ]
# F1-score macro sobre Train rnn2 : 0.40721763375392206
#
# Accuracy sobre Val rnn2 : 0.5247058823529411
# F1-score None sobre Val rnn2 : [0.68789809 0.06320542 0.02816901 0.5947644 ]
# F1-score macro sobre Val rnn2 : 0.34350922969236597
#
# Accuracy sobre Test rnn2 : 0.4889307583608102
# F1-score None sobre Test rnn2 : [0.64611689 0.09565217 0.08880995 0.50758621]
# F1-score macro sobre Test rnn2 : 0.3345413052596098
#
# Accuracy sobre Train rnn3 : 0.9588955130216504
# F1-score None sobre Train rnn3 : [0.97243599 0.08695652 0.64974619 0.96344892]
# F1-score macro sobre Train rnn3 : 0.6681469059929516
#
# Accuracy sobre Val rnn3 : 0.8527058823529412
# F1-score None sobre Val rnn3 : [0.91027845 0.02531646 0.02985075 0.81338912]
# F1-score macro sobre Val rnn3 : 0.44470869237630384
#
# Accuracy sobre Test rnn3 : 0.8007536504945831
# F1-score None sobre Test rnn3 : [0.88764742 0.         0.10714286 0.6743295 ]
# F1-score macro sobre Test rnn3 : 0.4172799457547098
# ----------------------- Entrenando running  2 -----------------------
#
# Accuracy sobre Train cnn1 : 0.8649199874490117
# F1-score None sobre Train cnn1 : [0.89069767 0.89430894 0.90540541 0.82077264]
# F1-score macro sobre Train cnn1 : 0.8777961659563526
#
# Accuracy sobre Val cnn1 : 0.8578823529411764
# F1-score None sobre Val cnn1 : [0.91274325 0.         0.05128205 0.77229801]
# F1-score macro sobre Val cnn1 : 0.43408082732606534
#
# Accuracy sobre Test cnn1 : 0.8068770607630711
# F1-score None sobre Test cnn1 : [0.88882713 0.         0.02597403 0.48602151]
# F1-score macro sobre Test cnn1 : 0.35020566438289547
#
# Accuracy sobre Train cnn2 : 0.8191088798242862
# F1-score None sobre Train cnn2 : [0.86168521 0.91891892 0.86206897 0.7335511 ]
# F1-score macro sobre Train cnn2 : 0.844056048914028
#
# Accuracy sobre Val cnn2 : 0.8291764705882353
# F1-score None sobre Val cnn2 : [0.89369479 0.02777778 0.08333333 0.68949233]
# F1-score macro sobre Val cnn2 : 0.4235745570791122
#
# Accuracy sobre Test cnn2 : 0.7856806406029204
# F1-score None sobre Test cnn2 : [0.87633672 0.         0.05       0.32929782]
# F1-score macro sobre Test cnn2 : 0.3139086339828882
#
# Accuracy sobre Train rnn1 : 0.8944148101663006
# F1-score None sobre Train rnn1 : [0.91100055 0.69677419 0.80213904 0.88046422]
# F1-score macro sobre Train rnn1 : 0.8225945001018923
#
# Accuracy sobre Val rnn1 : 0.8456470588235294
# F1-score None sobre Val rnn1 : [0.90951743 0.07246377 0.05263158 0.82319392]
# F1-score macro sobre Val rnn1 : 0.46445167242164476
#
# Accuracy sobre Test rnn1 : 0.8186528497409327
# F1-score None sobre Test rnn1 : [0.89864662 0.16666667 0.06779661 0.71181102]
# F1-score macro sobre Test rnn1 : 0.4612302292498897
#
# Accuracy sobre Train rnn2 : 0.4956071540633825
# F1-score None sobre Train rnn2 : [0.53846154 0.11022044 0.33860045 0.53272967]
# F1-score macro sobre Train rnn2 : 0.3800030261142631
#
# Accuracy sobre Val rnn2 : 0.3948235294117647
# F1-score None sobre Val rnn2 : [0.49954421 0.07289294 0.05714286 0.38237385]
# F1-score macro sobre Val rnn2 : 0.2529884630464308
#
# Accuracy sobre Test rnn2 : 0.3763542157324541
# F1-score None sobre Test rnn2 : [0.50194049 0.12643678 0.03436426 0.29503106]
# F1-score macro sobre Test rnn2 : 0.23944314756735113
#
# Accuracy sobre Train rnn3 : 0.9690931910887982
# F1-score None sobre Train rnn3 : [0.97894596 0.73846154 0.63247863 0.96827914]
# F1-score macro sobre Train rnn3 : 0.8295413178240357
#
# Accuracy sobre Val rnn3 : 0.859764705882353
# F1-score None sobre Val rnn3 : [0.91521118 0.04819277 0.04878049 0.78403275]
# F1-score macro sobre Val rnn3 : 0.44905429759187987
# Accuracy sobre Test rnn3 : 0.8228921337729628
# F1-score None sobre Test rnn3 : [0.89985653 0.10344828 0.02197802 0.62093863]
# F1-score macro sobre Test rnn3 : 0.411555363493995
# ----------------------- Entrenando running  3 -----------------------
#
# Accuracy sobre Train cnn1 : 0.8533103231879511
# F1-score None sobre Train cnn1 : [0.88316631 0.89655172 0.85915493 0.80095507]
# F1-score macro sobre Train cnn1 : 0.859957007333261
#
# Accuracy sobre Val cnn1 : 0.8531764705882353
# F1-score None sobre Val cnn1 : [0.90835663 0.         0.05128205 0.76086957]
# F1-score macro sobre Val cnn1 : 0.4301270622485015
#
# Accuracy sobre Test cnn1 : 0.7974564295807819
# F1-score None sobre Test cnn1 : [0.88373378 0.         0.         0.41986456]
# F1-score macro sobre Test cnn1 : 0.3258995837549086
#
# Accuracy sobre Train cnn2 : 0.8573893944148102
# F1-score None sobre Train cnn2 : [0.87995669 0.9122807  0.8625     0.82320551]
# F1-score macro sobre Train cnn2 : 0.8694857251315746
#
# Accuracy sobre Val cnn2 : 0.8395294117647059
# F1-score None sobre Val cnn2 : [0.89986996 0.         0.04761905 0.75212064]
# F1-score macro sobre Val cnn2 : 0.4249024123780377
#
# Accuracy sobre Test cnn2 : 0.7814413565708902
# F1-score None sobre Test cnn2 : [0.87803485 0.         0.         0.43339254]
# F1-score macro sobre Test cnn2 : 0.3278568467877485
#
# Accuracy sobre Train rnn1 : 0.6165673046752431
# F1-score None sobre Train rnn1 : [0.777811   0.14771049 0.10629371 0.60865166]
# F1-score macro sobre Train rnn1 : 0.41011671387309856
#
# Accuracy sobre Val rnn1 : 0.5524705882352942
# F1-score None sobre Val rnn1 : [0.73925049 0.06217617 0.03703704 0.54499366]
# F1-score macro sobre Val rnn1 : 0.3458643397002945
#
# Accuracy sobre Test rnn1 : 0.5544041450777202
# F1-score None sobre Test rnn1 : [0.72820513 0.0911271  0.10273973 0.52038835]
# F1-score macro sobre Test rnn1 : 0.36061507551710786
#
# Accuracy sobre Train rnn2 : 0.6510825227486664
# F1-score None sobre Train rnn2 : [0.72292756 0.22633745 0.19762846 0.6655574 ]
# F1-score macro sobre Train rnn2 : 0.4531127173157079
#
# Accuracy sobre Val rnn2 : 0.5397647058823529
# F1-score None sobre Val rnn2 : [0.67817509 0.07142857 0.02209945 0.52425532]
# F1-score macro sobre Val rnn2 : 0.32398960764243534
#
# Accuracy sobre Test rnn2 : 0.4936410739519548
# F1-score None sobre Test rnn2 : [0.63209076 0.09615385 0.09876543 0.43920829]
# F1-score macro sobre Test rnn2 : 0.31655458351630555
#
# Accuracy sobre Train rnn3 : 0.9818010668340131
# F1-score None sobre Train rnn3 : [0.99037288 0.66666667 0.66666667 0.98552426]
# F1-score macro sobre Train rnn3 : 0.8273076178350707
#
# Accuracy sobre Val rnn3 : 0.8527058823529412
# F1-score None sobre Val rnn3 : [0.91116917 0.08421053 0.08       0.78811122]
# F1-score macro sobre Val rnn3 : 0.46587272860850526
#
# Accuracy sobre Test rnn3 : 0.8158266603862458
# F1-score None sobre Test rnn3 : [0.89326669 0.14084507 0.04705882 0.65048544]
# F1-score macro sobre Test rnn3 : 0.4329140042784738
# ----------------------- Entrenando running  4 -----------------------
#
# Accuracy sobre Train cnn1 : 0.8991214308126765
# F1-score None sobre Train cnn1 : [0.91397109 0.89256198 0.89189189 0.87878788]
# F1-score macro sobre Train cnn1 : 0.8943032121096314
#
# Accuracy sobre Val cnn1 : 0.8832941176470588
# F1-score None sobre Val cnn1 : [0.92943089 0.         0.05263158 0.83943662]
# F1-score macro sobre Val cnn1 : 0.45537477324365533
#
# Accuracy sobre Test cnn1 : 0.8299576071596797
# F1-score None sobre Test cnn1 : [0.90351873 0.         0.         0.62962963]
# F1-score macro sobre Test cnn1 : 0.38328708958674906
#
# Accuracy sobre Train cnn2 : 0.8089112017571384
# F1-score None sobre Train cnn2 : [0.85433834 0.88695652 0.9047619  0.71398054]
# F1-score macro sobre Train cnn2 : 0.8400093262889867
#
# Accuracy sobre Val cnn2 : 0.8338823529411765
# F1-score None sobre Val cnn2 : [0.89707674 0.         0.04545455 0.70035253]
# F1-score macro sobre Val cnn2 : 0.41072095189555347
#
# Accuracy sobre Test cnn2 : 0.7894488930758361
# F1-score None sobre Test cnn2 : [0.87936246 0.         0.         0.35764706]
# F1-score macro sobre Test cnn2 : 0.3092523802596059
#
# Accuracy sobre Train rnn1 : 0.8067147787888296
# F1-score None sobre Train rnn1 : [0.87269456 0.32738095 0.26548673 0.81189649]
# F1-score macro sobre Train rnn1 : 0.5693646800197865
#
# Accuracy sobre Val rnn1 : 0.7501176470588236
# F1-score None sobre Val rnn1 : [0.86792453 0.09561753 0.05       0.73058485]
# F1-score macro sobre Val rnn1 : 0.43603172739314633
#
# Accuracy sobre Test rnn1 : 0.7503532736693358
# F1-score None sobre Test rnn1 : [0.87593132 0.0952381  0.07792208 0.65088757]
# F1-score macro sobre Test rnn1 : 0.4249947680088968
#
# Accuracy sobre Train rnn2 : 0.3555067461562598
# F1-score None sobre Train rnn2 : [0.10455228 0.13602015 0.17078652 0.54542881]
# F1-score macro sobre Train rnn2 : 0.2391969395411408
#
# Accuracy sobre Val rnn2 : 0.22070588235294117
# F1-score None sobre Val rnn2 : [0.13553114 0.0661157  0.01960784 0.37153721]
# F1-score macro sobre Val rnn2 : 0.1481979722967096
#
# Accuracy sobre Test rnn2 : 0.20160150730098916
# F1-score None sobre Test rnn2 : [0.16310461 0.09195402 0.07027027 0.30066146]
# F1-score macro sobre Test rnn2 : 0.15649759009593217
#
# Accuracy sobre Train rnn3 : 0.9604643865704424
# F1-score None sobre Train rnn3 : [0.97058037 0.71028037 0.76258993 0.95621019]
# F1-score macro sobre Train rnn3 : 0.8499152155136935
#
# Accuracy sobre Val rnn3 : 0.8672941176470588
# F1-score None sobre Val rnn3 : [0.91857506 0.05194805 0.0952381  0.80040527]
# F1-score macro sobre Val rnn3 : 0.4665416198224384
#
# Accuracy sobre Test rnn3 : 0.8280734809232219
# F1-score None sobre Test rnn3 : [0.89994282 0.03508772 0.05       0.64981949]
# F1-score macro sobre Test rnn3 : 0.40871250958855243
# ----------------------- Entrenando running  5 -----------------------
#
# Accuracy sobre Train cnn1 : 0.8768434264198306
# F1-score None sobre Train cnn1 : [0.89842821 0.82170543 0.91390728 0.84378191]
# F1-score macro sobre Train cnn1 : 0.8694557078331728
#
# Accuracy sobre Val cnn1 : 0.8738823529411764
# F1-score None sobre Val cnn1 : [0.92307692 0.         0.04651163 0.81836327]
# F1-score macro sobre Val cnn1 : 0.4469879561092484
#
# Accuracy sobre Test cnn1 : 0.8200659444182761
# F1-score None sobre Test cnn1 : [0.89595051 0.         0.         0.58267717]
# F1-score macro sobre Test cnn1 : 0.36965691788526434
#
# Accuracy sobre Train cnn2 : 0.8812362723564481
# F1-score None sobre Train cnn2 : [0.89630882 0.8907563  0.86792453 0.8615041 ]
# F1-score macro sobre Train cnn2 : 0.8791234363794118
#
# Accuracy sobre Val cnn2 : 0.8578823529411764
# F1-score None sobre Val cnn2 : [0.91312997 0.         0.05       0.79322638]
# F1-score macro sobre Val cnn2 : 0.4390890887341192
#
# Accuracy sobre Test cnn2 : 0.8177107866227037
# F1-score None sobre Test cnn2 : [0.89914731 0.         0.         0.62537764]
# F1-score macro sobre Test cnn2 : 0.38113123827983775
#
# Accuracy sobre Train rnn1 : 0.34421085660495765
# F1-score None sobre Train rnn1 : [0.52296015 0.09954751 0.05016502 0.40981155]
# F1-score macro sobre Train rnn1 : 0.27062105653290747
#
# Accuracy sobre Val rnn1 : 0.3171764705882353
# F1-score None sobre Val rnn1 : [0.49090015 0.08290155 0.05128205 0.3800905 ]
# F1-score macro sobre Val rnn1 : 0.2512935627472319
#
# Accuracy sobre Test rnn1 : 0.29062647197362224
# F1-score None sobre Test rnn1 : [0.42816901 0.13719512 0.08812261 0.33653846]
# F1-score macro sobre Test rnn1 : 0.24750630073454322
#
# Accuracy sobre Train rnn2 : 0.5409475996234704
# F1-score None sobre Train rnn2 : [0.65466282 0.05547151 0.28682171 0.63823934]
# F1-score macro sobre Train rnn2 : 0.40879884234256675
#
# Accuracy sobre Val rnn2 : 0.44
# F1-score None sobre Val rnn2 : [0.59045905 0.07462687 0.01104972 0.53465347]
# F1-score macro sobre Val rnn2 : 0.30269727516991823
#
# Accuracy sobre Test rnn2 : 0.43429109750353273
# F1-score None sobre Test rnn2 : [0.57595208 0.12890232 0.06306306 0.5129683 ]
# F1-score macro sobre Test rnn2 : 0.32022143857465
#
# Accuracy sobre Train rnn3 : 0.9463445246313147
# F1-score None sobre Train rnn3 : [0.96138068 0.13559322 0.65030675 0.94447499]
# F1-score macro sobre Train rnn3 : 0.6729389078133122
#
# Accuracy sobre Val rnn3 : 0.8376470588235294
# F1-score None sobre Val rnn3 : [0.897418   0.         0.04761905 0.77760252]
# F1-score macro sobre Val rnn3 : 0.4306598938663435
#
# Accuracy sobre Test rnn3 : 0.7781441356570891
# F1-score None sobre Test rnn3 : [0.87464115 0.         0.02439024 0.60737527]
# F1-score macro sobre Test rnn3 : 0.3766016658443681

# %%
for key in fs_none.keys():
    temp=np.zeros(4)
    for result in fs_none[key]:
        temp+=result
    print ("(0.0_cw) F1-score promedio para",key,":" ,temp/5)

print ("")
for key in fs_macro.keys():
    temp=np.sum(fs_macro[key])
    print ("(0.0_cw) F1-score macro promedio para",key,":" ,temp/5, "desvest: ",np.std(fs_macro[key]))

print ("")
for key in accs.keys():
    temp=np.sum(accs[key])
    print ("(0.0_cw) Accuracy promedio para",key,":" ,temp/5)
# Out:
# (0.0_cw) F1-score promedio para cnn1 : [0.89437766 0.         0.00519481 0.54534544]
# (0.0_cw) F1-score promedio para cnn2 : [0.88787708 0.         0.02518987 0.48269245]
# (0.0_cw) F1-score promedio para rnn1 : [0.76122838 0.1180454  0.09075943 0.55352508]
# (0.0_cw) F1-score promedio para rnn2 : [0.50384097 0.10781983 0.07105459 0.41109106]
# (0.0_cw) F1-score promedio para rnn3 : [0.89107092 0.05587621 0.05011399 0.64058967]
#
# (0.0_cw) F1-score macro promedio para cnn1 : 0.3612294750643838 desvest:  0.020876300705597428
# (0.0_cw) F1-score macro promedio para cnn2 : 0.348939849653244 desvest:  0.04081502171297419
# (0.0_cw) F1-score macro promedio para rnn1 : 0.3808895703897989 desvest:  0.0741017911540763
# (0.0_cw) F1-score macro promedio para rnn2 : 0.2734516130027697 desvest:  0.06724886965074642
# (0.0_cw) F1-score macro promedio para rnn3 : 0.40941269779201983 desvest:  0.018416569139648196
#
# (0.0_cw) Accuracy promedio para cnn1 : 0.8157324540744231
# (0.0_cw) Accuracy promedio para cnn2 : 0.8016015073009891
# (0.0_cw) Accuracy promedio para rnn1 : 0.6338200659444183
# (0.0_cw) Accuracy promedio para rnn2 : 0.39896373056994816
# (0.0_cw) Accuracy promedio para rnn3 : 0.8091380122468206

# %%
for key in confusions.keys():
    temp=np.sum(confusions[key], axis=0)/5.0
    plot_confusion_matrix(temp,['NonH','IndirectH','PhysicalH','SexualH'], "(0.0_cw) Confusion Matrix "+str(key), cmap='Greens')

# %%
cambiar a harassment_baselines

# %% [markdown]
# ### Sin generar con nuevo preprocesamiento SIN CW

# %%
class_weights=np.asarray([1.,1.,1.,1.])

fs_macro={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
fs_none={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
accs={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
confusions={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}

for i in range(1,6): 
    print ("----------------------- Entrenando running ", i,"-----------------------")
    
    cnn1=create_ccn1(x_train.shape[1:])
    trained =train_model(cnn1, x_train, y_train, x_val, y_val, class_weights, e=30, BS=32, verb=0, focal=True)
    trained.save('../../../new_data_augmented/harassment_baselines/0.0/cnn1_'+str(i)+'-exec.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(trained, x_train, x_val, x_test, etiq, etiq_v, etiq_t, 'cnn1')
    fs_macro['cnn1'].append(f1_ma_t)
    fs_none['cnn1'].append(f1_t)
    accs['cnn1'].append(acc_t)
    confusions['cnn1'].append(matriz_t)
    
    cnn2=create_cnn2(x_train.shape[1:])
    trained =train_model(cnn2, x_train, y_train, x_val, y_val, class_weights, e=30, BS=32, verb=0, focal=True)
    trained.save('../../../new_data_augmented/harassment_baselines/0.0/cnn2_'+str(i)+'-exec.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(trained, x_train, x_val, x_test, etiq, etiq_v, etiq_t, 'cnn2')
    fs_macro['cnn2'].append(f1_ma_t)
    fs_none['cnn2'].append(f1_t)
    accs['cnn2'].append(acc_t)
    confusions['cnn2'].append(matriz_t)
    
    rnn1=create_complex_GRU_2(128,64,"adam",x_train.shape[1:])
    trained =train_model(rnn1, x_train, y_train, x_val, y_val, class_weights, e=30, BS=32, verb=0, focal=True)
    trained.save('../../../new_data_augmented/harassment_baselines/0.0/rnn1_'+str(i)+'-exec.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(trained, x_train, x_val, x_test, etiq, etiq_v, etiq_t, 'rnn1')
    fs_macro['rnn1'].append(f1_ma_t)
    fs_none['rnn1'].append(f1_t)
    accs['rnn1'].append(acc_t)
    confusions['rnn1'].append(matriz_t)
    
    rnn2=create_complex_GRU_3(256,128,64,"adam",x_train.shape[1:])
    trained =train_model(rnn2, x_train, y_train, x_val, y_val, class_weights, e=30, BS=32, verb=0, focal=True)
    trained.save('../../../new_data_augmented/harassment_baselines/0.0/rnn2_'+str(i)+'-exec.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(trained, x_train, x_val, x_test, etiq, etiq_v, etiq_t, 'rnn2')
    fs_macro['rnn2'].append(f1_ma_t)
    fs_none['rnn2'].append(f1_t)
    accs['rnn2'].append(acc_t)
    confusions['rnn2'].append(matriz_t)
    
    rnn3=create_complex_GRU_3(256,128,64,"adam",x_train.shape[1:])
    trained =train_model(rnn3, x_train, y_train, x_val, y_val, class_weights, e=30, BS=32, verb=0, focal=False)
    trained.save('../../../new_data_augmented/harassment_baselines/0.0/rnn3_'+str(i)+'-exec.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(trained, x_train, x_val, x_test, etiq, etiq_v, etiq_t, 'rnn3')
    fs_macro['rnn3'].append(f1_ma_t)
    fs_none['rnn3'].append(f1_t)
    accs['rnn3'].append(acc_t)
    confusions['rnn3'].append(matriz_t)
# Out:
# ----------------------- Entrenando running  1 -----------------------
#
# Accuracy sobre Train cnn1 : 0.9676812048948855
# F1-score None sobre Train cnn1 : [0.97517241 0.77777778 0.74380165 0.96576508]
# F1-score macro sobre Train cnn1 : 0.8656292321580397
#
# Accuracy sobre Val cnn1 : 0.8936470588235295
# F1-score None sobre Val cnn1 : [0.93592233 0.         0.05405405 0.85931559]
# F1-score macro sobre Val cnn1 : 0.46232299337618843
#
# Accuracy sobre Test cnn1 : 0.8473857748469148
# F1-score None sobre Test cnn1 : [0.91076569 0.         0.         0.73559322]
# F1-score macro sobre Test cnn1 : 0.41158972707668584
#
# Accuracy sobre Train cnn2 : 0.9304989017885158
# F1-score None sobre Train cnn2 : [0.94396664 0.8627451  0.88571429 0.91183775]
# F1-score macro sobre Train cnn2 : 0.9010659431756277
#
# Accuracy sobre Val cnn2 : 0.859764705882353
# F1-score None sobre Val cnn2 : [0.91253102 0.         0.05263158 0.7742639 ]
# F1-score macro sobre Val cnn2 : 0.434856625087998
#
# Accuracy sobre Test cnn2 : 0.8195949128591615
# F1-score None sobre Test cnn2 : [0.89398601 0.         0.         0.5807771 ]
# F1-score macro sobre Test cnn2 : 0.36869077752513335
#
# Accuracy sobre Train rnn1 : 0.7842798870411045
# F1-score None sobre Train rnn1 : [0.83520659 0.10454985 0.2887931  0.90798541]
# F1-score macro sobre Train rnn1 : 0.5341337377554974
#
# Accuracy sobre Val rnn1 : 0.6936470588235294
# F1-score None sobre Val rnn1 : [0.81006006 0.11231102 0.04225352 0.74617737]
# F1-score macro sobre Val rnn1 : 0.42770049158404805
#
# Accuracy sobre Test rnn1 : 0.6961846443711729
# F1-score None sobre Test rnn1 : [0.82497509 0.15264188 0.12030075 0.63959391]
# F1-score macro sobre Test rnn1 : 0.43437790762755
#
# Accuracy sobre Train rnn2 : 0.967367430185127
# F1-score None sobre Train rnn2 : [0.97498626 0.79674797 0.78125    0.96761683]
# F1-score macro sobre Train rnn2 : 0.8801502637888923
#
# Accuracy sobre Val rnn2 : 0.8305882352941176
# F1-score None sobre Val rnn2 : [0.9004676  0.05882353 0.04651163 0.77153558]
# F1-score macro sobre Val rnn2 : 0.4443345849283734
#
# Accuracy sobre Test rnn2 : 0.796514366462553
# F1-score None sobre Test rnn2 : [0.88768443 0.0729927  0.07352941 0.63496933]
# F1-score macro sobre Test rnn2 : 0.4172939675119717
#
# Accuracy sobre Train rnn3 : 0.9010040790712268
# F1-score None sobre Train rnn3 : [0.97999459 0.6259542  0.21639344 0.87264049]
# F1-score macro sobre Train rnn3 : 0.6737456800587884
#
# Accuracy sobre Val rnn3 : 0.8282352941176471
# F1-score None sobre Val rnn3 : [0.92626132 0.09433962 0.08860759 0.70693512]
# F1-score macro sobre Val rnn3 : 0.4540359150387515
#
# Accuracy sobre Test rnn3 : 0.8106453132359868
# F1-score None sobre Test rnn3 : [0.90614137 0.11290323 0.10650888 0.56287425]
# F1-score macro sobre Test rnn3 : 0.42210693009159833
# ----------------------- Entrenando running  2 -----------------------
#
# Accuracy sobre Train cnn1 : 0.973642924380295
# F1-score None sobre Train cnn1 : [0.9794362  0.61728395 0.83076923 0.97458606]
# F1-score macro sobre Train cnn1 : 0.850518859991322
#
# Accuracy sobre Val cnn1 : 0.8837647058823529
# F1-score None sobre Val cnn1 : [0.92939666 0.         0.05405405 0.83625731]
# F1-score macro sobre Val cnn1 : 0.4549270065958127
#
# Accuracy sobre Test cnn1 : 0.8398492699010833
# F1-score None sobre Test cnn1 : [0.90722823 0.         0.         0.68727273]
# F1-score macro sobre Test cnn1 : 0.39862523930253013
#
# Accuracy sobre Train cnn2 : 0.9709758393473487
# F1-score None sobre Train cnn2 : [0.97720406 0.63414634 0.81818182 0.97143945]
# F1-score macro sobre Train cnn2 : 0.8502429190250156
#
# Accuracy sobre Val cnn2 : 0.8898823529411765
# F1-score None sobre Val cnn2 : [0.93462158 0.         0.05263158 0.84749035]
# F1-score macro sobre Val cnn2 : 0.4586858761343887
#
# Accuracy sobre Test cnn2 : 0.8356099858690532
# F1-score None sobre Test cnn2 : [0.9048433  0.         0.         0.67148014]
# F1-score macro sobre Test cnn2 : 0.39408086231190925
#
# Accuracy sobre Train rnn1 : 0.9424223407593348
# F1-score None sobre Train rnn1 : [0.95053457 0.75       0.85314685 0.93747728]
# F1-score macro sobre Train rnn1 : 0.872789675729192
#
# Accuracy sobre Val rnn1 : 0.8315294117647059
# F1-score None sobre Val rnn1 : [0.89074461 0.05405405 0.         0.7716786 ]
# F1-score macro sobre Val rnn1 : 0.4291193151786771
#
# Accuracy sobre Test rnn1 : 0.7979274611398963
# F1-score None sobre Test rnn1 : [0.88398134 0.01769912 0.02298851 0.65222623]
# F1-score macro sobre Test rnn1 : 0.3942237979314011
#
# Accuracy sobre Train rnn2 : 0.9215563225604017
# F1-score None sobre Train rnn2 : [0.93323636 0.93103448 0.77948718 0.91190219]
# F1-score macro sobre Train rnn2 : 0.8889150548344388
#
# Accuracy sobre Val rnn2 : 0.8390588235294117
# F1-score None sobre Val rnn2 : [0.9043659  0.06741573 0.05797101 0.78441128]
# F1-score macro sobre Val rnn2 : 0.4535409815360818
#
# Accuracy sobre Test rnn2 : 0.8111163447951013
# F1-score None sobre Test rnn2 : [0.89195826 0.05084746 0.         0.68468468]
# F1-score macro sobre Test rnn2 : 0.406872599727736
#
# Accuracy sobre Train rnn3 : 0.9727016002510198
# F1-score None sobre Train rnn3 : [0.98664096 0.25396825 0.49275362 0.97465002]
# F1-score macro sobre Train rnn3 : 0.6770032136550528
#
# Accuracy sobre Val rnn3 : 0.8512941176470589
# F1-score None sobre Val rnn3 : [0.90866035 0.         0.         0.78849408]
# F1-score macro sobre Val rnn3 : 0.4242886074152431
#
# Accuracy sobre Test rnn3 : 0.8082901554404145
# F1-score None sobre Test rnn3 : [0.89287888 0.         0.04938272 0.63906856]
# F1-score macro sobre Test rnn3 : 0.395332540045747
# ----------------------- Entrenando running  3 -----------------------
#
# Accuracy sobre Train cnn1 : 0.9750549105742077
# F1-score None sobre Train cnn1 : [0.9789357  0.91428571 0.95172414 0.97160167]
# F1-score macro sobre Train cnn1 : 0.9541368041750588
#
# Accuracy sobre Val cnn1 : 0.8931764705882353
# F1-score None sobre Val cnn1 : [0.93658537 0.         0.05128205 0.85902256]
# F1-score macro sobre Val cnn1 : 0.4617224933816718
#
# Accuracy sobre Test cnn1 : 0.8473857748469148
# F1-score None sobre Test cnn1 : [0.9116038  0.         0.         0.73096447]
# F1-score macro sobre Test cnn1 : 0.4106420669384271
#
# Accuracy sobre Train cnn2 : 0.9717602761217445
# F1-score None sobre Train cnn2 : [0.97946156 0.80851064 0.77697842 0.96929742]
# F1-score macro sobre Train cnn2 : 0.8835620087129221
#
# Accuracy sobre Val cnn2 : 0.8884705882352941
# F1-score None sobre Val cnn2 : [0.93346444 0.         0.05263158 0.84954128]
# F1-score macro sobre Val cnn2 : 0.4589093253100637
#
# Accuracy sobre Test cnn2 : 0.8469147432878003
# F1-score None sobre Test cnn2 : [0.91131143 0.         0.         0.7392    ]
# F1-score macro sobre Test cnn2 : 0.4126278569351556
#
# Accuracy sobre Train rnn1 : 0.9563853153435833
# F1-score None sobre Train rnn1 : [0.96452387 0.87931034 0.91780822 0.94707298]
# F1-score macro sobre Train rnn1 : 0.9271788530447035
#
# Accuracy sobre Val rnn1 : 0.8531764705882353
# F1-score None sobre Val rnn1 : [0.91008    0.1        0.11538462 0.78725591]
# F1-score macro sobre Val rnn1 : 0.4781801312356708
#
# Accuracy sobre Test rnn1 : 0.7951012717852096
# F1-score None sobre Test rnn1 : [0.88184932 0.12345679 0.06521739 0.53278689]
# F1-score macro sobre Test rnn1 : 0.4008275954355498
#
# Accuracy sobre Train rnn2 : 0.8799811735174145
# F1-score None sobre Train rnn2 : [0.8858836  0.84684685 0.875      0.87415197]
# F1-score macro sobre Train rnn2 : 0.8704706046494625
#
# Accuracy sobre Val rnn2 : 0.7529411764705882
# F1-score None sobre Val rnn2 : [0.82542056 0.03738318 0.05333333 0.70638909]
# F1-score macro sobre Val rnn2 : 0.40563153998743157
#
# Accuracy sobre Test rnn2 : 0.7385774846914743
# F1-score None sobre Test rnn2 : [0.84017066 0.01680672 0.12068966 0.58091286]
# F1-score macro sobre Test rnn2 : 0.38964497514931834
#
# Accuracy sobre Train rnn3 : 0.9708189519924694
# F1-score None sobre Train rnn3 : [0.98019665 0.48704663 0.72727273 0.98301158]
# F1-score macro sobre Train rnn3 : 0.7943818977680707
#
# Accuracy sobre Val rnn3 : 0.824
# F1-score None sobre Val rnn3 : [0.89216022 0.11764706 0.02857143 0.7920434 ]
# F1-score macro sobre Val rnn3 : 0.45760552653408526
#
# Accuracy sobre Test rnn3 : 0.7767310409797457
# F1-score None sobre Test rnn3 : [0.86876972 0.12785388 0.10434783 0.67924528]
# F1-score macro sobre Test rnn3 : 0.44505417661817287
# ----------------------- Entrenando running  4 -----------------------
# Accuracy sobre Train cnn1 : 0.972074050831503
# F1-score None sobre Train cnn1 : [0.97826087 0.90384615 0.80314961 0.96894647]
# F1-score macro sobre Train cnn1 : 0.9135507739260266
#
# Accuracy sobre Val cnn1 : 0.8870588235294118
# F1-score None sobre Val cnn1 : [0.93208883 0.         0.05263158 0.84332689]
# F1-score macro sobre Val cnn1 : 0.45701182412446684
#
# Accuracy sobre Test cnn1 : 0.8351389543099388
# F1-score None sobre Test cnn1 : [0.90419501 0.         0.         0.6641791 ]
# F1-score macro sobre Test cnn1 : 0.3920935289538701
#
# Accuracy sobre Train cnn2 : 0.972074050831503
# F1-score None sobre Train cnn2 : [0.97859577 0.82474227 0.84210526 0.96893691]
# F1-score macro sobre Train cnn2 : 0.9035950535032298
#
# Accuracy sobre Val cnn2 : 0.8851764705882353
# F1-score None sobre Val cnn2 : [0.93111182 0.         0.05263158 0.8372549 ]
# F1-score macro sobre Val cnn2 : 0.4552495760104409
#
# Accuracy sobre Test cnn2 : 0.8294865756005653
# F1-score None sobre Test cnn2 : [0.90096208 0.         0.         0.63773585]
# F1-score macro sobre Test cnn2 : 0.3846744829206309
#
# Accuracy sobre Train rnn1 : 0.9679949796046439
# F1-score None sobre Train rnn1 : [0.97399398 0.89320388 0.90361446 0.96307752]
# F1-score macro sobre Train rnn1 : 0.9334724591901186
#
# Accuracy sobre Val rnn1 : 0.867764705882353
# F1-score None sobre Val rnn1 : [0.92171053 0.08108108 0.06557377 0.81488372]
# F1-score macro sobre Val rnn1 : 0.47081227470472664
#
# Accuracy sobre Test rnn1 : 0.8191238813000471
# F1-score None sobre Test rnn1 : [0.89964371 0.01851852 0.05309735 0.66971081]
# F1-score macro sobre Test rnn1 : 0.4102425939528882
#
# Accuracy sobre Train rnn2 : 0.8726074678380923
# F1-score None sobre Train rnn2 : [0.91946309 0.20484171 0.38020833 0.91815805]
# F1-score macro sobre Train rnn2 : 0.6056677968230242
#
# Accuracy sobre Val rnn2 : 0.7336470588235294
# F1-score None sobre Val rnn2 : [0.84545784 0.06956522 0.05797101 0.74701195]
# F1-score macro sobre Val rnn2 : 0.43000150494028544
#
# Accuracy sobre Test rnn2 : 0.7395195478097033
# F1-score None sobre Test rnn2 : [0.85293175 0.11494253 0.14473684 0.6656    ]
# F1-score macro sobre Test rnn2 : 0.44455278087106964
#
# Accuracy sobre Train rnn3 : 0.9606212739253216
# F1-score None sobre Train rnn3 : [0.9728139  0.24390244 0.7047619  0.96541353]
# F1-score macro sobre Train rnn3 : 0.7217229447415433
#
# Accuracy sobre Val rnn3 : 0.804235294117647
# F1-score None sobre Val rnn3 : [0.8786168  0.04123711 0.02325581 0.74776967]
# F1-score macro sobre Val rnn3 : 0.4227198477203089
#
# Accuracy sobre Test rnn3 : 0.7677814413565709
# F1-score None sobre Test rnn3 : [0.86512218 0.06578947 0.11023622 0.625     ]
# F1-score macro sobre Test rnn3 : 0.4165369693976205
# ----------------------- Entrenando running  5 -----------------------
#
# Accuracy sobre Train cnn1 : 0.9643865704424224
# F1-score None sobre Train cnn1 : [0.97011365 0.93203883 0.89361702 0.95927097]
# F1-score macro sobre Train cnn1 : 0.9387601193694912
#
# Accuracy sobre Val cnn1 : 0.8969411764705882
# F1-score None sobre Val cnn1 : [0.93869479 0.         0.04761905 0.87216682]
# F1-score macro sobre Val cnn1 : 0.4646201644355239
#
# Accuracy sobre Test cnn1 : 0.8572774375883184
# F1-score None sobre Test cnn1 : [0.91784038 0.         0.         0.7804878 ]
# F1-score macro sobre Test cnn1 : 0.42458204511622577
#
# Accuracy sobre Train cnn2 : 0.9730153749607782
# F1-score None sobre Train cnn2 : [0.97986207 0.79120879 0.81538462 0.97062725]
# F1-score macro sobre Train cnn2 : 0.8892706814726379
#
# Accuracy sobre Val cnn2 : 0.8856470588235295
# F1-score None sobre Val cnn2 : [0.93203883 0.         0.05405405 0.83920076]
# F1-score macro sobre Val cnn2 : 0.4563234125463348
#
# Accuracy sobre Test cnn2 : 0.8346679227508244
# F1-score None sobre Test cnn2 : [0.90566038 0.         0.         0.66431095]
# F1-score macro sobre Test cnn2 : 0.3924928328555237
#
# Accuracy sobre Train rnn1 : 0.6490429871352369
# F1-score None sobre Train rnn1 : [0.56549834 0.7804878  0.82681564 0.70064041]
# F1-score macro sobre Train rnn1 : 0.7183605492948251
#
# Accuracy sobre Val rnn1 : 0.56
# F1-score None sobre Val rnn1 : [0.6199095  0.0173913  0.03076923 0.54086022]
# F1-score macro sobre Val rnn1 : 0.3022325631083159
#
# Accuracy sobre Test rnn1 : 0.5303815355628827
# F1-score None sobre Test rnn1 : [0.64979592 0.05633803 0.02020202 0.41800643]
# F1-score macro sobre Test rnn1 : 0.28608559940163714
#
# Accuracy sobre Train rnn2 : 0.9679949796046439
# F1-score None sobre Train rnn2 : [0.97366607 0.88888889 0.89156627 0.96405354]
# F1-score macro sobre Train rnn2 : 0.929543690111691
#
# Accuracy sobre Val rnn2 : 0.8564705882352941
# F1-score None sobre Val rnn2 : [0.91508492 0.         0.07894737 0.80692168]
# F1-score macro sobre Val rnn2 : 0.4502384898200256
#
# Accuracy sobre Test rnn2 : 0.8238341968911918
# F1-score None sobre Test rnn2 : [0.90026954 0.         0.12280702 0.69781022]
# F1-score macro sobre Test rnn2 : 0.4302216945752344
#
# Accuracy sobre Train rnn3 : 0.9093191088798243
# F1-score None sobre Train rnn3 : [0.95107296 0.05194805 0.35406699 0.93638677]
# F1-score macro sobre Train rnn3 : 0.5733686918538031
#
# Accuracy sobre Val rnn3 : 0.7915294117647059
# F1-score None sobre Val rnn3 : [0.88456091 0.06024096 0.04545455 0.78228782]
# F1-score macro sobre Val rnn3 : 0.44313605967594416
#
# Accuracy sobre Test rnn3 : 0.7517663683466792
# F1-score None sobre Test rnn3 : [0.86343042 0.07048458 0.17813765 0.68035191]
# F1-score macro sobre Test rnn3 : 0.4481011400474979

# %%
for key in fs_none.keys():
    temp=np.zeros(4)
    for result in fs_none[key]:
        temp+=result
    print ("(0.0) F1-score promedio para",key,":" ,temp/5)

print ("")
for key in fs_macro.keys():
    temp=np.sum(fs_macro[key])
    print ("(0.0) F1-score macro promedio para",key,":" ,temp/5, "desvest: ",np.std(fs_macro[key]))

print ("")
for key in accs.keys():
    temp=np.sum(accs[key])
    print ("(0.0) Accuracy promedio para",key,":" ,temp/5)
# Out:
# (0.0) F1-score promedio para cnn1 : [0.91032662 0.         0.         0.71969946]
# (0.0) F1-score promedio para cnn2 : [0.90335264 0.         0.         0.65870081]
# (0.0) F1-score promedio para rnn1 : [0.82804907 0.07373087 0.0563612  0.58246485]
# (0.0) F1-score promedio para rnn2 : [0.87460293 0.05111788 0.09235259 0.65279542]
# (0.0) F1-score promedio para rnn3 : [0.87926851 0.07540623 0.10972266 0.637308  ]
#
# (0.0) F1-score macro promedio para cnn1 : 0.4075065214775478 desvest:  0.011265125231832566
# (0.0) F1-score macro promedio para cnn2 : 0.39051336250967056 desvest:  0.014254921617789037
# (0.0) F1-score macro promedio para rnn1 : 0.38515149886980526 desvest:  0.05137100626402339
# (0.0) F1-score macro promedio para rnn2 : 0.417717203567066 desvest:  0.01888038704127149
# (0.0) F1-score macro promedio para rnn3 : 0.42542635124012734 desvest:  0.019468306115510446
#
# (0.0) Accuracy promedio para cnn1 : 0.845407442298634
# (0.0) Accuracy promedio para cnn2 : 0.8332548280734808
# (0.0) Accuracy promedio para rnn1 : 0.7277437588318417
# (0.0) Accuracy promedio para rnn2 : 0.7819123881300047
# (0.0) Accuracy promedio para rnn3 : 0.7830428638718795

# %%
for key in confusions.keys():
    temp=np.sum(confusions[key], axis=0)/5.0
    plot_confusion_matrix(temp, ['NonH','IndirectH','PhysicalH','SexualH'], "(0.0) Confusion Matrix "+str(key), cmap='YlGn')
