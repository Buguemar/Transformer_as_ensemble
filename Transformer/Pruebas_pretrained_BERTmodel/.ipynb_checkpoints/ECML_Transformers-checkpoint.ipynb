# %%
import ast
from collections import Counter
from gensim import utils, matutils 
from gensim.corpora.dictionary import Dictionary
from gensim.utils import deprecated
import itertools
from nltk.corpus import stopwords
import numpy as np
from numpy import linalg as LA
from numpy.random import binomial
from numpy import dot, float32 as REAL, memmap as np_memmap, \
    double, array, zeros, vstack, sqrt, newaxis, integer, \
    ndarray, sum as np_sum, prod, argmax
from numpy.linalg import norm
import math, copy, time
import warnings 

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context(context="talk")
# %matplotlib inline

from keras import backend as K
from keras.models import load_model
from keras.preprocessing.sequence import pad_sequences
from keras import backend as K
import keras
from keras.utils import to_categorical
from keras.preprocessing import sequence
from keras.models import load_model

import os, sys, re, io, nltk, torch
import pandas as pd

from scipy import stats
from scipy.stats import bernoulli
from scipy.spatial import distance
from sklearn.utils.class_weight import compute_class_weight
from sklearn.utils import class_weight
from sklearn.preprocessing import Normalizer, normalize
from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import accuracy_score,f1_score, confusion_matrix, recall_score, precision_score

from six import string_types, integer_types
from six.moves import zip, range
if not sys.warnoptions:
    warnings.simplefilter("ignore")

from tqdm import tqdm, trange
import time
import transformers
from transformers import (
    WEIGHTS_NAME,
    AdamW,
    BertConfig,
    BertForMaskedLM,
    BertForSequenceClassification,
    BertTokenizer,
    CamembertConfig,
    CamembertForMaskedLM,
    CamembertTokenizer,
    DistilBertConfig,
    DistilBertForMaskedLM,
    DistilBertTokenizer,
    GPT2Config,
    GPT2LMHeadModel,
    GPT2Tokenizer,
    OpenAIGPTConfig,
    OpenAIGPTLMHeadModel,
    OpenAIGPTTokenizer,
    RobertaConfig,
    RobertaForMaskedLM,
    RobertaTokenizer,
    get_linear_schedule_with_warmup,
)

import torch.nn.functional as F
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler
from torch.autograd import Variable
import re
from nltk.corpus import stopwords
from nltk import WordNetLemmatizer
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.porter import *

stemmer_sn = SnowballStemmer("english")
stemmer = PorterStemmer()

stoplist = stopwords.words("english")
lemmatizer=WordNetLemmatizer()


'''
Compatible with tensorflow backend
gamma entre más alto más tolerante (queremos un gamma chico pero no demasiado! 0.25 - 5)
alpha pesos por clase (weights)
'''
def focal_loss(gamma=2., weights=1):   #weights np.asarray()
    weights= K.variable(weights)
    def focal_loss_fixed(y_true, y_pred):
        y_true = K.clip(y_true, K.epsilon(),1)
        y_pred = K.clip(y_pred,K.epsilon(),1)
        return - K.sum(weights* K.pow(1. - y_pred, gamma)* y_true * K.log(y_pred), axis=-1) 
    return focal_loss_fixed

keras.losses.focal_loss=keras.losses.MSE
keras.losses.focal_loss_fixed=keras.losses.MSE

n_gpu = torch.cuda.device_count()
torch.cuda.get_device_name(0)

if torch.cuda.is_available():     
    device = torch.device("cuda")
    print('There are',torch.cuda.device_count(),'GPU(s) available.')
    print('We will use the GPU:', torch.cuda.get_device_name(0))

else:
    print('No GPU available, using the CPU instead.')
    device = torch.device("cpu")

########## no alcanza memoria de GPU para esta tarea
device = torch.device("cpu")


if not sys.warnoptions:
    warnings.simplefilter("ignore")
    
class Dummy_Embeddings(nn.Module):
    def __init__(self, d_model, dummy_vectors): 
        super(Dummy_Embeddings, self).__init__()
        aux = dummy_vectors.float().to(device)
        self.index2dummy = nn.Embedding(aux.size()[0], d_model)
        self.index2dummy.weigth=nn.Parameter(aux)
        self.index2dummy.weigth.requires_grad=False
        self.d_model = d_model

    def forward(self, x):
        aux=x.numpy()
        new_x= aux #- np.ones(aux.shape)
        new_x= torch.from_numpy(new_x).float().to(device)
        return self.index2dummy(new_x.long()) * math.sqrt(self.d_model) #debiese retornar matriz de batch_size x [ind_tw, k1,k2,k3,k4,k5,k6] (si son 6 modelos)
    
def match(objetos,ejemplo):
    i=0
    for obj in objetos:
        if obj==ejemplo:
            return i
        i+=1
        
def plot_confusion_matrix(cm, target_names, title='Confusion matrix (f1-score)',cmap=None, normalize=True):    
    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy
    if cmap is None:
        cmap = plt.get_cmap('Blues')
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        
    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap, vmin=0, vmax=1)
    plt.title(title)
    plt.colorbar()
    
    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)
    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()
    
    
class EncoderDecoderLogSoft(nn.Module):
    def __init__(self, encoder, src_embed, sequential):
        super(EncoderDecoderLogSoft, self).__init__()
        self.encoder = encoder
        self.linearSoft = sequential
        self.src_embed = src_embed
        
    def forward(self, src, src_mask):
        out=self.encode(src, src_mask)
        retorno=self.toSoftmax(out)
        return retorno
    
    def encode(self, src, src_mask):
        return self.encoder(self.src_embed(src), src_mask)
    
    def toSoftmax(self, tensor):
        a=tensor.size()[0]
        b=tensor.size()[-1]
        c=tensor.size()[-2]
        new_tensor= np.zeros((a, b))
        ini=True
        for ai in range(a):
            for ci in range(c):
                if ini:
                    new_tensor[ai]=tensor.data[ai][ci].numpy()
                    ini=False
                else: 
                    new_tensor[ai]*=tensor.data[ai][ci].numpy()
            ini=True
        new_tensor=torch.from_numpy(new_tensor)
        lineal=self.linearSoft(new_tensor.float())
        return F.log_softmax(lineal, dim = -1)
    
    def decode(self, memory, src_mask, tgt, tgt_mask):
        return self.decoder(self.tgt_embed(tgt), memory, src_mask, tgt_mask)
    
def clones(module, N):
    return nn.ModuleList([copy.deepcopy(module) for _ in range(N)])


class EncoderDecoderSoft(nn.Module):
    def __init__(self, encoder, src_embed, sequential):
        super(EncoderDecoderSoft, self).__init__()
        self.encoder = encoder
        self.linearSoft = sequential
        self.src_embed = src_embed
        
    def forward(self, src, src_mask):
        out=self.encode(src, src_mask)
        retorno=self.toSoftmax(out)
        return retorno
    
    def encode(self, src, src_mask):
        return self.encoder(self.src_embed(src), src_mask)
    
    def toSoftmax(self, tensor):
        a=tensor.size()[0]
        b=tensor.size()[-1]
        c=tensor.size()[-2]
        new_tensor= np.zeros((a, b))
        ini=True
        for ai in range(a):
            for ci in range(c):
                if ini:
                    new_tensor[ai]=tensor.data[ai][ci].numpy()
                    ini=False
                else: 
                    new_tensor[ai]*=tensor.data[ai][ci].numpy()
            ini=True
            
        new_tensor=torch.from_numpy(new_tensor)
        lineal=self.linearSoft(new_tensor.float())
        return F.softmax(lineal, dim = -1)
    
    def decode(self, memory, src_mask, tgt, tgt_mask):
        return self.decoder(self.tgt_embed(tgt), memory, src_mask, tgt_mask)
    
def clones(module, N):
    return nn.ModuleList([copy.deepcopy(module) for _ in range(N)])

class EncoderDecoder(nn.Module):
    def __init__(self, encoder, src_embed, generator):
        super(EncoderDecoder, self).__init__()
        self.encoder = encoder
        self.src_embed = src_embed
        self.generator = generator
        
    def forward(self, src, src_mask):
        return  self.encode(src, src_mask)

    def encode(self, src, src_mask):
        return self.encoder(self.src_embed(src), src_mask)
    
    def decode(self, memory, src_mask, tgt, tgt_mask):
        return self.decoder(self.tgt_embed(tgt), memory, src_mask, tgt_mask)
    
class Encoder(nn.Module):
    def __init__(self, layer, N):
        super(Encoder, self).__init__()
        self.layers = clones(layer, N)
        self.norm = LayerNorm(layer.size)
        
    def forward(self, x, mask):
        for layer in self.layers:
            x = layer(x, mask)
        return self.norm(x)
    
class LayerNorm(nn.Module):
    def __init__(self, features, eps=1e-6):
        super(LayerNorm, self).__init__()
        self.a_2 = nn.Parameter(torch.ones(features))
        self.b_2 = nn.Parameter(torch.zeros(features))
        self.eps = eps

    def forward(self, x):
        mean = x.mean(-1, keepdim=True)
        std = x.std(-1, keepdim=True)
        return self.a_2 * (x - mean) / (std + self.eps) + self.b_2
    
class SublayerConnection(nn.Module):
    def __init__(self, size, dropout):
        super(SublayerConnection, self).__init__()
        self.norm = LayerNorm(size)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, sublayer):
        return x + self.dropout(sublayer(self.norm(x)))    
    
class EncoderLayer(nn.Module):
    def __init__(self, size, self_attn, feed_forward, dropout):
        super(EncoderLayer, self).__init__()
        self.self_attn = self_attn
        self.feed_forward = feed_forward
        self.sublayer = clones(SublayerConnection(size, dropout), 2)
        self.size = size

    def forward(self, x, mask):
        x = self.sublayer[0](x, lambda x: self.self_attn(x, x, x, mask))
        return self.sublayer[1](x, self.feed_forward)
    
def subsequent_mask(size):
    attn_shape = (1, size, size)
    subsequent_mask = np.triu(np.ones(attn_shape), k=1).astype('uint8')
    return torch.from_numpy(subsequent_mask) == 0

class Generator(nn.Module):
    def __init__(self, d_model, vocab):
        super(Generator, self).__init__()
        self.proj = nn.Linear(d_model, vocab)

    def forward(self, x):
        return F.log_softmax(self.proj(x), dim=-1)
    
def attention(query, key, value, mask=None, dropout=None):
    d_k = query.size(-1)
    scores = torch.matmul(query, key.transpose(-2, -1)) \
             / math.sqrt(d_k)
    if mask is not None:
        scores = scores.masked_fill(mask == 0, -1e9)
    p_attn = F.softmax(scores, dim = -1)
    if dropout is not None:
        p_attn = dropout(p_attn)
    return torch.matmul(p_attn, value), p_attn

class MultiHeadedAttention(nn.Module):
    def __init__(self, h, d_model, dropout=0.1):
        super(MultiHeadedAttention, self).__init__()
        assert d_model % h == 0
        self.d_k = d_model // h
        self.h = h
        self.linears = clones(nn.Linear(d_model, d_model), 4)
        self.attn = None
        self.dropout = nn.Dropout(p=dropout)
        
    def forward(self, query, key, value, mask=None):
        #print ("mask para attn...", mask)
        if mask is not None:
            mask = mask.unsqueeze(1)
        nbatches = query.size(0)
        
        query, key, value = \
            [l(x).view(nbatches, -1, self.h, self.d_k).transpose(1, 2)
             for l, x in zip(self.linears, (query, key, value))]
         
        x, self.attn = attention(query, key, value, mask=mask, 
                                 dropout=self.dropout)
        
        x = x.transpose(1, 2).contiguous() \
             .view(nbatches, -1, self.h * self.d_k)
        return self.linears[-1](x)
    
class PositionalText(nn.Module):
    def __init__(self, d_model, dropout, max_len=50):
        super(PositionalText, self).__init__()
        self.dropout = nn.Dropout(p=dropout)
        
    def forward(self, x):
        x_text=x.data[:,0][:,None,:]
        x_machines=x.data[:,1:]
        
        x_return = x_machines* x_text
        return self.dropout(x_return)
    
class PositionalText_concat(nn.Module):
    def __init__(self, d_model, dropout, max_len=50):
        super(PositionalText_concat, self).__init__()
        self.dropout = nn.Dropout(p=dropout)
        
    def forward(self, x):
        return self.dropout(x)   

    
global max_src_in_batch, max_tgt_in_batch

def batch_size_fn(new, count, sofar):
    global max_src_in_batch, max_tgt_in_batch
    if count == 1:
        max_src_in_batch = 0
        max_tgt_in_batch = 0
    max_src_in_batch = max(max_src_in_batch,  len(new.src))
    max_tgt_in_batch = max(max_tgt_in_batch,  len(new.trg) + 2)
    src_elements = count * max_src_in_batch
    tgt_elements = count * max_tgt_in_batch
    maximo=max(src_elements, tgt_elements)
    return maximo

class NoamOpt:
    "Optim wrapper that implements rate."
    def __init__(self, model_size, factor, warmup, optimizer):
        self.optimizer = optimizer
        self._step = 0
        self.warmup = warmup
        self.factor = factor
        self.model_size = model_size
        self._rate = 0
        
    def step(self):
        "Update parameters and rate"
        self._step += 1
        rate = self.rate()
        for p in self.optimizer.param_groups:
            p['lr'] = rate
        self._rate = rate
        #print ("Rate de Noam_opt", self._rate, self._step)
        self.optimizer.step()
        
    def rate(self, step = None):
        "Implement `lrate` above"
        if step is None:
            step = self._step
        return self.factor * \
            (self.model_size ** (-0.5) *
            min(step ** (-0.5), step * self.warmup ** (-1.5)))
        
def get_std_opt(model):
    return NoamOpt(model.src_embed[0].d_model, 2, 4000,
            torch.optim.Adam(model.parameters(), lr=0, betas=(0.9, 0.98), eps=1e-9))

class LabelSmoothing(nn.Module):
    "Implement label smoothing."
    def __init__(self, size, padding_idx, smoothing=0.0):
        super(LabelSmoothing, self).__init__()
        self.criterion = nn.KLDivLoss(size_average=False)
        self.padding_idx = padding_idx
        self.confidence = 1.0 - smoothing
        self.smoothing = smoothing
        self.size = size
        self.true_dist = None
        
    def forward(self, x, target):
        assert x.size(1) == self.size
        true_dist = x.data.clone()
        true_dist.fill_(self.smoothing / (self.size - 2))
        true_dist.scatter_(1, target.data.unsqueeze(1), self.confidence)
        mask = torch.nonzero(target.data == self.padding_idx)
        self.true_dist = true_dist
        return self.criterion(x, Variable(true_dist, requires_grad=False))
    
class LabelCCE(nn.Module):
    def __init__(self, class_weights):
        super(LabelCCE, self).__init__()
        self.criterion = nn.CrossEntropyLoss(weight=class_weights)
                       
    def forward(self, x, target):
        return self.criterion(x, target)
    
class FocalLoss(nn.Module):
    def __init__(self, weights, gamma=2.0, reduce=True):#, logits=False, reduce=True):
        super(FocalLoss, self).__init__()
        self.weights = weights
        self.gamma = gamma
        #self.logits = logits
        self.reduce = reduce

    def forward(self, x, y):
        tensors = []
        for l in y:
            tensors.append(torch.zeros(4).scatter_(0, torch.tensor(l), 1))
        result = torch.stack(tensors, 0)
        
        CCE_loss = F.cross_entropy(x, result.long().argmax(dim=-1), reduction='none', weight=self.weights.float())
        pt = torch.exp(-CCE_loss)
        factor= (1-pt)**self.gamma * CCE_loss
        
        F_loss = factor  #*self.weights.float()-- peso esta dentro de la funcion

        if self.reduce:
            return torch.mean(F_loss)
        else:
            return F_loss
        
class SimpleLossComputeFL:
    "A simple loss compute and train function."
    def __init__(self, criterion, opt=None):
        self.criterion = criterion
        self.opt = opt
        
    def __call__(self, x, y, norm, mode):
        y_new=(y.float()-torch.ones((y.shape))).int() 
        #print ("nuevo Y en simplelosscompute", y_new, "antes era", y)
        # ahora
        #y_new=(y.float()).int()
        ac=accuracy_scorer(x, y_new)
        f1=f_scorer(x, y_new)
        cm=compute_confusion_matrix(x, y_new)
        tempa= x.contiguous().view(-1, x.size(-1))
        tempb= y_new.long().contiguous().view(-1)
        loss = self.criterion(tempa, tempb) #/ norm
        if mode!='Test':
            loss.backward()
        if self.opt is not None:
            self.opt.step()
            self.opt.optimizer.zero_grad()
        return [loss.data, ac ,f1, cm] #*norm #[0] * norm
    
class PositionwiseFeedForward(nn.Module):
    "Implements FFN equation."
    def __init__(self, d_model, d_ff, dropout=0.1):
        super(PositionwiseFeedForward, self).__init__()
        self.w_1 = nn.Linear(d_model, d_ff)
        self.w_2 = nn.Linear(d_ff, d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        return self.w_2(self.dropout(F.relu(self.w_1(x))))
    
def accuracy_scorer(predicho, target):
    predicho= torch.argmax(predicho, dim=1)
    return accuracy_score(target.numpy(),predicho.numpy())

def f_scorer(predicho, target):
    predicho= torch.argmax(predicho, dim=1)
    return f1_score(target.numpy(),predicho.numpy(), average=None, labels=[0,1,2,3])

def compute_confusion_matrix(predicho, target):
    predicho= torch.argmax(predicho, dim=1)
    return confusion_matrix(target.numpy(), predicho.numpy(), labels=[0,1,2,3])

def data_gen(batch_size,mode,n_machines,new_matrix):  
    x_data=[] 
    y_data=[]
    if mode=='Train':
        max_objs=matrix.shape[1]
        x_list=np.arange(max_objs)
        np.random.shuffle(x_list)        #indices desordenados de seccion train
        objs=ids_train
        labels=etiq     #np.load("matrices/y_train_num_4.npy")
        labels=np.asarray(labels) #+ np.ones(labels.shape),dtype='uint8')
    if mode=='Val':
        max_objs=matrix_val.shape[1] 
        x_list=np.arange(max_objs)
        x_list=[x+matrix.shape[1] for x in x_list]   
        np.random.shuffle(x_list)        #indices desordenados de seccion val
        objs=ids_val   #df_val['Unnamed: 0'].values        
        labels=np.asarray(etiq_v)     #np.load("matrices/y_val_num_4.npy")
        labels=np.asarray(labels) #+ np.ones(labels.shape),dtype='uint8') 
    if mode=='Test':
        max_objs=matrix_test.shape[1] 
        x_list=np.arange(max_objs)
        x_list=[x+matrix.shape[1]+matrix_val.shape[1] for x in x_list]
        total=matrix.shape[1]+matrix_val.shape[1]
        objs=ids_test   #np.arange(total, total+max_objs)
        
    #----------------------------------- COMPLETA MINI BATCHES ----------------------    
    if len(x_list)%batch_size==0:
        n_batches=len(x_list)/batch_size
        for nb in range(n_batches): 
            x_data.append(x_list[nb*batch_size:(nb+1)*batch_size])
    else:
        n_batches=int(len(x_list)/batch_size)
        resto=int(len(x_list)-n_batches*batch_size)
        to_repeat=batch_size-resto        
        for nb in range(n_batches): 
            x_data.append(x_list[nb*batch_size:(nb+1)*batch_size])
        cola=list(x_list[(nb+1)*batch_size:])
        for i in range(to_repeat):
            indice= np.random.randint(len(x_list))
            cola.append(x_list[indice])
        x_data.append(np.asarray(cola))
        if mode=='Test':
            print ("SE TUVIERON QUE REPETIR", to_repeat, "EJEMPLOS")
            
    #print ("x data antes ", x_data[0])
    #-------------------------------- CONSTRUCCION MINI BATCHES (X,Y)----------------------   
    new_x_data=[] 
    for batch in x_data:
        temp=[]
        #print (batch)
        for exam in batch:
            if mode=='Train':
                temp2=[fromId2num[objs[exam]]] ### obj evaluado en maquinas
            elif mode=='Val':
                temp2=[fromId2num[objs[exam-matrix.shape[1]]]] 
            else:
                temp2=[fromId2num[objs[exam-matrix.shape[1]-matrix_val.shape[1]]]]   
            for m in range(n_machines): 
                temp2= temp2 + [np.argmax(new_matrix[m][exam])+1] 
            temp.append(temp2)
        new_x_data.append(temp)   
    #print ("x data ahora ", new_x_data[0])
    
    if mode=='Train' or mode=='Val':    
        y_data=[]
        for batch in new_x_data:
            temp_y=[]
            for exam in batch:
                q=fromNum2Id[exam[0]]
                indice=match(objs, q)   
                temp_y.append([labels[indice]+1])       
            y_data.append(temp_y)
        y_data=np.asarray(y_data)
        
    new_x_data=np.asarray(new_x_data)
    if mode=='Test':
        for x in new_x_data:
            src = Variable(torch.from_numpy(np.asarray(x)), requires_grad=False)
            yield Batch(src, None, 0)        
    else:          
        for x,y in zip(new_x_data, y_data):
            src = Variable(torch.from_numpy(np.asarray(x)), requires_grad=False)
            har = Variable(torch.from_numpy(np.asarray(y)), requires_grad=False)
            yield Batch(src, har, 0)
            

def make_model_concat(target, N=2, d_model=768, d_ff=128, h=4, dropout=0.35, soft=True):  #recibir src_vocab si lo utiliza dummy_Emb
    c = copy.deepcopy
    attn = MultiHeadedAttention(h, d_model)
    ff = PositionwiseFeedForward(d_model, d_ff, dropout)
    position = PositionalText_concat(d_model, dropout)
    if soft:
        print ("Creando modelo con salida Softmax")
        model = EncoderDecoderSoft(
            Encoder(EncoderLayer(d_model, c(attn), c(ff), dropout), N),
            nn.Sequential(Dummy_Embeddings(768, K_list_new), c(position)),
            nn.Linear(d_model, 4))
    else:
        print ("")
        print ("Creando modelo con salida Log_softmax")
        model = EncoderDecoderLogSoft(
            Encoder(EncoderLayer(d_model, c(attn), c(ff), dropout), N),
            nn.Sequential(Dummy_Embeddings(768, K_list_new), c(position)),
            nn.Linear(d_model, 4))

    for p in model.parameters():
        if p.dim() > 1:
            nn.init.xavier_uniform(p)
    return model

class Batch:
    def __init__(self, src, trg=None, pad=0):
        self.src = src
        self.src_mask = (src != pad).unsqueeze(-2)
        if trg is not None:
            self.trg = trg[:, :]
            self.trg_y = trg[:, 0:]
            self.trg_mask = \
                self.make_std_mask(self.trg, pad)
            self.ntokens = (self.trg_y != pad).data.sum()
            
    @staticmethod
    def make_std_mask(tgt, pad):
        tgt_mask = (tgt != pad).unsqueeze(-2)
        tgt_mask = tgt_mask & Variable(
            subsequent_mask(tgt.size(-1)).type_as(tgt_mask.data))
        return tgt_mask
    
def run_epoch(data_iter, model, loss_compute, mode):
    if mode=='Test':
        with torch.no_grad():
            start = time.time()
            pred_classes=[]
            for i, batch in enumerate(data_iter):
                out = model.forward(batch.src, batch.src_mask)
                pred_classes.append(out.argmax(dim=-1).cpu().numpy())
            return pred_classes
    
    else:
        start = time.time()
        total_learners = 0
        total_datos = 0
        total_loss = 0
        total_acc=0
        total_fm1=0
        total_fs=0
        n_batches = 0
        cm_last=np.zeros((4,4))
        for i, batch in enumerate(data_iter):
            out = model.forward(batch.src, batch.src_mask)
            loss,acc,f1,cm = loss_compute(out, batch.trg_y, batch.ntokens, mode)
            cm_last+=cm
            f_ma=np.mean(f1)
            total_loss += loss
            total_acc += np.array(acc)
            total_fm1 += np.sum(f1)/4.0    #4 clases (macro)
            total_fs += f1                 #none  
            total_datos += batch.ntokens
            n_batches += 1
        return total_loss/n_batches, torch.from_numpy(np.array(total_acc))/n_batches, torch.from_numpy(np.array(total_fm1))/n_batches, torch.from_numpy(np.array(total_fs))/n_batches, cm_last

emoji_pattern = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags=re.UNICODE)

def cleaner(post): 
    #re.sub(r'([a-z])\1+', r'\1', "user i think that ' s all you loooooove ")
    s= re.sub(r"http\S+", " html ", post)   ##########elimina http    
    s= re.sub(r'#\w+ ?', " hashtag ", s) ########3
    s= re.sub(r'@\w+ ?', " user ", s)##############    
    s= s.lower()
    s=emoji_pattern.sub(r'', s)
    s=re.sub(r"'\b", " ' ", s)
    s=re.sub(r"\b'\b", " ' ", s)
    s=re.sub(r"\b’", " ’ ", s)
    s=re.sub(r"‘\b", " ‘ ", s)
    s=re.sub(r"\b’\b", " ‘ ", s)
    s = re.sub(r"-", " - ", s)
    s = re.sub(r"\(", " ", s)
    s = re.sub(r"\)", " ", s)
    s = re.sub(r"\?", " ? ", s)    
    s = re.sub(r"\/", " ", s)
    s = re.sub(r"' ", " ' ", s)
    s = re.sub(r" '", " ' ", s)
    s = re.sub(r"\!", " ! ", s)
    s=re.sub("[\.]+", " . ", s)
    s=re.sub("[\,]+", " , ", s)
    s=re.sub("[\;]+", " ; ", s)
    s=re.sub("[\:]+", " : ", s)
    s=re.sub('[\"]+', ' " ', s)
    s=re.sub(r'\b[0-9]\b', " number ",  s)
    s=re.sub(r'\b[0-9]*[0-9]\b', " number ",  s)    
    s=re.sub(r'\b”', ' " ', s)
    sl= list(s.split())
    #sl= [stemmer.stem(wd) for wd in sl]
    ############3
    sl_2=[]
    for wd in sl:
        try: 
            q=Word2Index[wd]
            sl_2.append(wd)
        except:
            try: 
                if stemmer.stem(wd) in Word2Index.keys():
                    sl_2.append(stemmer.stem(wd))
                    #print ("dejamos el stemmed de", wd)
                elif lemmatizer.lemmatize(wd) in Word2Index.keys():
                    sl_2.append(lemmatizer.lemmatize(wd))
                else:
                    sl_2.append(wd)
                    #print ("dejamos el lema de", wd)
                #print ("veamos si ",stemmer.stem(wd), "\tdel termino ", wd, "\testa:")
                #r=Word2Index[stemmer.stem(wd)]
                #sl_2.append(stemmer.stem(wd))
                
            except:
                sl_2.append(wd)
    sl=sl_2
    ##########
    s=' '.join([word for word in sl])# if word not in stoplist])
    return s, sl
# Out:
# Using TensorFlow backend.
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# There are 1 GPU(s) available.
# We will use the GPU: GeForce GTX 1060 6GB

# %%
import gc
import resource

def mem():
    print('Memory usage         : % 2.2f MB' % round(
        resource.getrusage(resource.RUSAGE_SELF).ru_maxrss/1024.0/1024.0,1)
    )

# %%
train =pd.read_csv("../../Fine-Tuning/CSV_Harassment/train_format.csv")
val=pd.read_csv("../../Fine-Tuning/CSV_Harassment/val_format.csv")
test=pd.read_csv("../../Fine-Tuning/CSV_Harassment/test_format.csv")

dict_cl=dict()
dict_cl[0]="NonH"
dict_cl[1]="IndirectH"
dict_cl[2]="PhysicalH"
dict_cl[3]="SexualH"

#sdqc
d_lab=dict()
d_lab["NonH"]=0
d_lab["IndirectH"]=1
d_lab["PhysicalH"]=2
d_lab["SexualH"]=3

etiq=[d_lab[y] for y in train['Label']]
etiq_v=[d_lab[y] for y in val['Label']]
etiq_t=[d_lab[y] for y in test['Label']]

tokenizer_loaded = BertTokenizer.from_pretrained('bert-base-uncased')
model_loaded = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=4)#'bert-base-uncased',  num_labels=4) 
idx_2_token = tokenizer_loaded.ids_to_tokens
Word2Index=tokenizer_loaded.vocab
M_BERT_space = model_loaded.bert.embeddings.word_embeddings.weight.detach().cpu().numpy()
transformer = Normalizer().fit(M_BERT_space) 
M_BERT_space=transformer.transform(M_BERT_space)


##########################################################
class_weights= [1.0, 1.0, 1.0, 1.0]
class_weights=np.asarray(class_weights)
print ("Pesos de clases:", class_weights)

MAX_LEN=50
#########################################################
# Out:
# Pesos de clases: [1. 1. 1. 1.]

# %%
MAX_LEN=50

n_labels = np.array(etiq)
y_train=to_categorical(n_labels,num_classes=4)
sentences = train['Tweet'].values
input_ids = []
i=0
for sent in sentences:
    temp=cleaner(sent)
    encoded_sent2 = tokenizer_loaded.encode(temp[0],add_special_tokens = False) 
    input_ids.append(encoded_sent2)
input_ids = pad_sequences(input_ids, maxlen=MAX_LEN, dtype="long", value=0, truncating="post", padding="post")


n_labels_val = np.array(etiq_v)
y_val=to_categorical(n_labels_val,num_classes=4)
sentences_val = val['Tweet'].values
input_ids_val = []
i=0
for sent in sentences_val:
    temp=cleaner(sent)
    encoded_sent2 = tokenizer_loaded.encode(temp[0],add_special_tokens = False) 
    input_ids_val.append(encoded_sent2)   
input_ids_val = pad_sequences(input_ids_val, maxlen=MAX_LEN, dtype="long", value=0, truncating="post", padding="post")



n_labels_test = np.array(etiq_t)
y_test=to_categorical(n_labels_test,num_classes=4)
sentences_test = test['Tweet'].values
input_ids_test = []
i=0
for sent in sentences_test:
    temp=cleaner(sent)
    encoded_sent2 = tokenizer_loaded.encode(temp[0],add_special_tokens = False)             
    input_ids_test.append(encoded_sent2)
input_ids_test = pad_sequences(input_ids_test, maxlen=MAX_LEN, dtype="long", value=0, truncating="post", padding="post")



shape_val=np.asarray(input_ids_val).shape
x_val=np.zeros((shape_val[0], shape_val[1], 768))
i=0
for in_id in input_ids_val:
    x_val[i]=M_BERT_space[in_id]
    i+=1
    
shape_test=np.asarray(input_ids_test).shape
x_test=np.zeros((shape_test[0], shape_test[1], 768))
i=0
for in_id in input_ids_test:
    x_test[i]=M_BERT_space[in_id]
    i+=1

x_test.shape
# Out:
# (2123, 50, 768)

# %%
etiq=[d_lab[lb] for lb in train['Label']]
n_labels = np.array(etiq)
y_train=to_categorical(n_labels,num_classes=4)
ids_train=train['tweet_id']

sentences = train['Tweet'].values
input_ids = []
for sent in sentences:
    temp=cleaner(sent)
    encoded_sent2 = tokenizer_loaded.encode(temp[0],add_special_tokens = False)             
    input_ids.append(encoded_sent2)
input_ids = pad_sequences(input_ids, maxlen=MAX_LEN, dtype="long", value=0, truncating="post", padding="post")

shape=np.asarray(input_ids).shape
x_train=np.zeros((shape[0], shape[1], 768))
j=0
for in_id in input_ids:
    x_train[j]=M_BERT_space[in_id]
    j+=1

x_train.shape
# Out:
# (6374, 50, 768)

# %%
ids_train=[str(ide)+'_train_0' for ide in ids_train]
ids_val=[str(ide)+'_val_0' for ide in val['tweet_id']]
ids_test=[str(ide)+'_test_0' for ide in test['tweet_id']]

#class_weights= compute_class_weight('balanced', np.unique(labels_train), labels_train) #[1.0, 1.0, 1.0, 1.0] #
#class_weights= [1.0, 1.0, 1.0, 1.0]
#print ("\nPesos de clases:", class_weights)

# %%
ids_test[:5]
# Out:
# ['0_test_0', '1_test_0', '2_test_0', '3_test_0', '4_test_0']

# %% [markdown]
# ## Standar

# %%
global_accs=[]
global_fnones=[]
global_fmacros=[]
global_cms=[]
global_attn=[]
dict_attn_enc={'00':[], '01':[], '02':[], '03':[], '10':[], '11':[], '12':[], '13':[]}
  
prob=0.0

for trans in range(1,6): 
    print ("Entrenando Run #", trans)
    
    cnn1 = load_model('../../../new_data_augmented/harassment_baselines/'+str(prob)+'/cnn1_'+str(trans)+'-exec.h5')
    cnn2 = load_model('../../../new_data_augmented/harassment_baselines/'+str(prob)+'/cnn2_'+str(trans)+'-exec.h5')
    rnn1 = load_model('../../../new_data_augmented/harassment_baselines/'+str(prob)+'/rnn1_'+str(trans)+'-exec.h5')
    rnn2 = load_model('../../../new_data_augmented/harassment_baselines/'+str(prob)+'/rnn2_'+str(trans)+'-exec.h5')
    rnn3 = load_model('../../../new_data_augmented/harassment_baselines/'+str(prob)+'/rnn3_'+str(trans)+'-exec.h5')

    list_models=['cnn1', 'cnn2', 'rnn1', 'rnn2', 'rnn3']
    index_models=np.arange(5)
    dict_models=dict((key, value) for (key, value) in zip(index_models,list_models))
    modelos=[cnn1, cnn2, rnn1, rnn2, rnn3]
    ind=np.arange(5)
    dict_trainedModel=dict((key, value) for (key, value) in zip(ind,modelos))

    bs=32
    predicciones_all=[]
    predicciones_all_val=[]
    predicciones_all_test=[]

    for i in dict_trainedModel.keys(): 
        a_evaluar=dict_models[i]
        predicciones_all.append(dict_trainedModel[i].predict(x_train, batch_size=bs))
    for i in dict_trainedModel.keys(): 
        a_evaluar=dict_models[i]
        predicciones_all_val.append(dict_trainedModel[i].predict(x_val, batch_size=bs))
    for i in dict_trainedModel.keys(): 
        a_evaluar=dict_models[i]
        predicciones_all_test.append(dict_trainedModel[i].predict(x_test, batch_size=bs))

    matrix=np.asarray(predicciones_all)
    matrix_val=np.asarray(predicciones_all_val)
    matrix_test=np.asarray(predicciones_all_test)
    new_matrix=np.concatenate([matrix,matrix_val,matrix_test], axis=1)
    
    mem()
    print('GC collected objects : %d' % gc.collect())
    mem()
    
    gc.collect()    
    
    print('GC collected objects : %d' % gc.collect())
    mem()
    
    ####### eliminar modelos de memoria
    keras.backend.clear_session()
    gc.collect()
    ####################
    #del tokenizer_loaded 
    #del model_loaded 
    #del idx_2_token 
    #del M_BERT_space
    #del cnn1, cnn2, rnn1, rnn2, rnn3
    torch.cuda.empty_cache()
    ####################
    
    fromId2num={}
    keys=ids_train+ids_val+ids_test
    values=np.arange(5,len(keys)+5)
    for key, value in list(zip(keys,values)):
        fromId2num[key]=value   #original largo --> valor tabla (index)

    fromNum2Id={}
    for value, key in list(zip(values,keys)):
        fromNum2Id[value]=key   #valor tabla (index) --> original largo

    espacio=[np.ones(768)]
    Ks=np.load("../../../../BERTransformer/Orthogonals_768.npy")
    random=np.random.randint(Ks.shape[0], size=4)
    K_list=Ks[random]
    K_list_ext=espacio+list(K_list)
    objs_train=ids_train.copy()
    objs_val=ids_val     #df_val['Unnamed: 0'].values
    objs_test=ids_test    #np.arange(df_test.shape[0])
    llaves=ids_train+ids_val+ids_test

    K_list_new=K_list_ext
    for i in llaves:
        vector=np.load("../../../BaS_Original/ECML/Original/"+str(i)+".npy")
        norm=np.linalg.norm(vector)
        vector= vector / norm
        K_list_new.append(vector)

    K_list_new= np.asarray(K_list_new, dtype='float32')
    print ("Shape de los IDs cargados como string:", K_list_new.shape )
    K_list_new=torch.from_numpy(K_list_new).float().to(device)
    class_weights=np.asarray(class_weights)
    pesos = torch.from_numpy(class_weights).float()
    print (pesos)
    
    ############################################# TRANSFORMER ##########################################

    V = 4    
    criterion = FocalLoss(weights=pesos)
    model = make_model_concat(4, N=2,d_model=768, d_ff=128, h=4, dropout=0.35)
    #model.cuda()
    model_opt = NoamOpt(model.src_embed[0].d_model, 1, 500, torch.optim.Adam(model.parameters(), lr=0, betas=(0.9, 0.98), eps=1e-5))

    for epoch in range(40):
        model.train()
        DATA=data_gen(bs, 'Train', 5, new_matrix)
        loss_train, acc_train,fma_train, f_none, cm_train=run_epoch(DATA, model, SimpleLossComputeFL(criterion, model_opt), 'Train')
        
        model.eval()
        loss_val, acc_val,fma_val, f_val_none, cm_val=run_epoch(data_gen(bs, 'Val', 5, new_matrix), model, SimpleLossComputeFL(criterion, None),'Val')
        print ("Epoch",epoch, "\tacc_val:",acc_val, "\tF-macro_val:",fma_val)

    model.eval()
    print ("Testing run #",trans)
    predicciones = run_epoch(data_gen(bs, 'Test', 5, new_matrix), model, SimpleLossComputeFL(criterion, None),'Test')
    predicciones=np.concatenate(predicciones, axis=-1)
    
    glo_acc=accuracy_score(etiq_t, predicciones[:-21])
    glo_fno=f1_score(etiq_t,predicciones[:-21], average=None)
    glo_fma=f1_score(etiq_t,predicciones[:-21], average='macro')

    print("Test_ acc:",glo_acc) 
    print("Test_ f1 none:",glo_fno) 
    print("Test_ f1 macro:",glo_fma) 

    glo_cm=confusion_matrix(etiq_t, predicciones[:-21])
    plot_confusion_matrix(glo_cm,["NonH","IndirectH","PhysicalH","SexualH"],"Confusion Matrix Transformer 40-e Harassment NoAum-SinCW")
    global_accs.append(glo_acc)
    global_fnones.append(glo_fno)
    global_fmacros.append(glo_fma)
    global_cms.append(glo_cm)

    label=[['Text', 'm1', 'm2','m3','m4','m5']]
    for layer in range(2):
        fig, axs = plt.subplots(1,4, figsize=(20, 10))
        print ("Encoder Layer Attention head", layer)
        for head in range(4):
            matriz_attn=model.encoder.layers[layer].self_attn.attn[0,head].data
            dict_attn_enc[str(layer)+str(head)].append(matriz_attn)
            sns.heatmap(matriz_attn, xticklabels=label[0], yticklabels=label[0],
                        vmin=0.0, vmax=1.0, linewidths=.5, cmap="Blues", cbar=False, square=True, ax=axs[head]) #, annot=False,cbar_kws={"orientation": "horizontal","pad": 0.25})
        plt.show()
# Out:
# Entrenando Run # 1
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:Large dropout rate: 0.65 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.65 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:Large dropout rate: 0.65 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.65 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.65 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:From /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Memory usage         :  7.70 MB
# GC collected objects : 113
# Memory usage         :  7.70 MB
# GC collected objects : 0
# Memory usage         :  7.70 MB
# Shape de los IDs cargados como string: (10627, 768)
# tensor([1., 1., 1., 1.])
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.7934, dtype=torch.float64) 	F-macro_val: tensor(0.3937, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.8867, dtype=torch.float64) 	F-macro_val: tensor(0.4429, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.8918, dtype=torch.float64) 	F-macro_val: tensor(0.4440, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.8918, dtype=torch.float64) 	F-macro_val: tensor(0.4498, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.8904, dtype=torch.float64) 	F-macro_val: tensor(0.4472, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.8881, dtype=torch.float64) 	F-macro_val: tensor(0.4438, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.8895, dtype=torch.float64) 	F-macro_val: tensor(0.4483, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.8899, dtype=torch.float64) 	F-macro_val: tensor(0.4473, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.8862, dtype=torch.float64) 	F-macro_val: tensor(0.4439, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.8890, dtype=torch.float64) 	F-macro_val: tensor(0.4457, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.8899, dtype=torch.float64) 	F-macro_val: tensor(0.4473, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.8913, dtype=torch.float64) 	F-macro_val: tensor(0.4482, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.8913, dtype=torch.float64) 	F-macro_val: tensor(0.4479, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.8909, dtype=torch.float64) 	F-macro_val: tensor(0.4483, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.8909, dtype=torch.float64) 	F-macro_val: tensor(0.4487, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.8923, dtype=torch.float64) 	F-macro_val: tensor(0.4482, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.8909, dtype=torch.float64) 	F-macro_val: tensor(0.4464, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.8913, dtype=torch.float64) 	F-macro_val: tensor(0.4502, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.8913, dtype=torch.float64) 	F-macro_val: tensor(0.4471, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.8913, dtype=torch.float64) 	F-macro_val: tensor(0.4483, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.8927, dtype=torch.float64) 	F-macro_val: tensor(0.4496, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.8923, dtype=torch.float64) 	F-macro_val: tensor(0.4508, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.8923, dtype=torch.float64) 	F-macro_val: tensor(0.4493, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.8913, dtype=torch.float64) 	F-macro_val: tensor(0.4491, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.8923, dtype=torch.float64) 	F-macro_val: tensor(0.4505, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.8909, dtype=torch.float64) 	F-macro_val: tensor(0.4487, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.8909, dtype=torch.float64) 	F-macro_val: tensor(0.4465, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.8899, dtype=torch.float64) 	F-macro_val: tensor(0.4475, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.8913, dtype=torch.float64) 	F-macro_val: tensor(0.4504, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.8913, dtype=torch.float64) 	F-macro_val: tensor(0.4471, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.8904, dtype=torch.float64) 	F-macro_val: tensor(0.4458, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.8918, dtype=torch.float64) 	F-macro_val: tensor(0.4458, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.8918, dtype=torch.float64) 	F-macro_val: tensor(0.4489, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.8904, dtype=torch.float64) 	F-macro_val: tensor(0.4484, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.8913, dtype=torch.float64) 	F-macro_val: tensor(0.4490, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.8913, dtype=torch.float64) 	F-macro_val: tensor(0.4508, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.8923, dtype=torch.float64) 	F-macro_val: tensor(0.4502, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.8923, dtype=torch.float64) 	F-macro_val: tensor(0.4489, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.8918, dtype=torch.float64) 	F-macro_val: tensor(0.4480, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.8918, dtype=torch.float64) 	F-macro_val: tensor(0.4496, dtype=torch.float64)
# Testing run # 1
# SE TUVIERON QUE REPETIR 21 EJEMPLOS
# Test_ acc: 0.8440885539331136
# Test_ f1 none: [0.9103488  0.         0.02439024 0.71986418]
# Test_ f1 macro: 0.41365080604068044
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 2
# Memory usage         :  8.00 MB
# GC collected objects : 804596
# Memory usage         :  8.00 MB
# GC collected objects : 0
# Memory usage         :  8.00 MB
# Shape de los IDs cargados como string: (10627, 768)
# tensor([1., 1., 1., 1.])
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.8298, dtype=torch.float64) 	F-macro_val: tensor(0.4094, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.8927, dtype=torch.float64) 	F-macro_val: tensor(0.4469, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.8876, dtype=torch.float64) 	F-macro_val: tensor(0.4426, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.8927, dtype=torch.float64) 	F-macro_val: tensor(0.4475, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.8876, dtype=torch.float64) 	F-macro_val: tensor(0.4476, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.8876, dtype=torch.float64) 	F-macro_val: tensor(0.4485, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.8904, dtype=torch.float64) 	F-macro_val: tensor(0.4481, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.8923, dtype=torch.float64) 	F-macro_val: tensor(0.4494, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.8923, dtype=torch.float64) 	F-macro_val: tensor(0.4476, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.8918, dtype=torch.float64) 	F-macro_val: tensor(0.4502, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.8918, dtype=torch.float64) 	F-macro_val: tensor(0.4492, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.8918, dtype=torch.float64) 	F-macro_val: tensor(0.4479, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.8909, dtype=torch.float64) 	F-macro_val: tensor(0.4471, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.8941, dtype=torch.float64) 	F-macro_val: tensor(0.4510, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.8932, dtype=torch.float64) 	F-macro_val: tensor(0.4495, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.8918, dtype=torch.float64) 	F-macro_val: tensor(0.4481, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.8895, dtype=torch.float64) 	F-macro_val: tensor(0.4480, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.8909, dtype=torch.float64) 	F-macro_val: tensor(0.4483, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.8890, dtype=torch.float64) 	F-macro_val: tensor(0.4469, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.8927, dtype=torch.float64) 	F-macro_val: tensor(0.4480, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.8899, dtype=torch.float64) 	F-macro_val: tensor(0.4465, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.8895, dtype=torch.float64) 	F-macro_val: tensor(0.4486, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.8918, dtype=torch.float64) 	F-macro_val: tensor(0.4470, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.8927, dtype=torch.float64) 	F-macro_val: tensor(0.4507, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.8913, dtype=torch.float64) 	F-macro_val: tensor(0.4497, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.8923, dtype=torch.float64) 	F-macro_val: tensor(0.4504, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.8941, dtype=torch.float64) 	F-macro_val: tensor(0.4480, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.8923, dtype=torch.float64) 	F-macro_val: tensor(0.4496, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.8918, dtype=torch.float64) 	F-macro_val: tensor(0.4482, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.8899, dtype=torch.float64) 	F-macro_val: tensor(0.4483, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.8895, dtype=torch.float64) 	F-macro_val: tensor(0.4462, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.8909, dtype=torch.float64) 	F-macro_val: tensor(0.4531, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.8913, dtype=torch.float64) 	F-macro_val: tensor(0.4498, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.8918, dtype=torch.float64) 	F-macro_val: tensor(0.4479, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.8927, dtype=torch.float64) 	F-macro_val: tensor(0.4489, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.8923, dtype=torch.float64) 	F-macro_val: tensor(0.4493, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.8909, dtype=torch.float64) 	F-macro_val: tensor(0.4449, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.8918, dtype=torch.float64) 	F-macro_val: tensor(0.4487, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.8918, dtype=torch.float64) 	F-macro_val: tensor(0.4468, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.8923, dtype=torch.float64) 	F-macro_val: tensor(0.4508, dtype=torch.float64)
# Testing run # 2
# SE TUVIERON QUE REPETIR 21 EJEMPLOS
# Test_ acc: 0.8407913330193123
# Test_ f1 none: [0.90840797 0.         0.         0.7076412 ]
# Test_ f1 macro: 0.40401229264677785
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 3
# Memory usage         :  8.00 MB
# GC collected objects : 804574
# Memory usage         :  8.00 MB
# GC collected objects : 0
# Memory usage         :  8.00 MB
# Shape de los IDs cargados como string: (10627, 768)
# tensor([1., 1., 1., 1.])
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.8722, dtype=torch.float64) 	F-macro_val: tensor(0.4332, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.8918, dtype=torch.float64) 	F-macro_val: tensor(0.4468, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.8932, dtype=torch.float64) 	F-macro_val: tensor(0.4464, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.8932, dtype=torch.float64) 	F-macro_val: tensor(0.4473, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.8951, dtype=torch.float64) 	F-macro_val: tensor(0.4510, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.8946, dtype=torch.float64) 	F-macro_val: tensor(0.4513, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.8941, dtype=torch.float64) 	F-macro_val: tensor(0.4516, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.8951, dtype=torch.float64) 	F-macro_val: tensor(0.4531, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.8951, dtype=torch.float64) 	F-macro_val: tensor(0.4516, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.8955, dtype=torch.float64) 	F-macro_val: tensor(0.4489, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.8927, dtype=torch.float64) 	F-macro_val: tensor(0.4510, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.8937, dtype=torch.float64) 	F-macro_val: tensor(0.4508, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.8946, dtype=torch.float64) 	F-macro_val: tensor(0.4517, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.8946, dtype=torch.float64) 	F-macro_val: tensor(0.4511, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.8955, dtype=torch.float64) 	F-macro_val: tensor(0.4519, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.8955, dtype=torch.float64) 	F-macro_val: tensor(0.4500, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.8946, dtype=torch.float64) 	F-macro_val: tensor(0.4487, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.8941, dtype=torch.float64) 	F-macro_val: tensor(0.4526, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.8946, dtype=torch.float64) 	F-macro_val: tensor(0.4518, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.8946, dtype=torch.float64) 	F-macro_val: tensor(0.4498, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.8946, dtype=torch.float64) 	F-macro_val: tensor(0.4509, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.8937, dtype=torch.float64) 	F-macro_val: tensor(0.4480, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.8946, dtype=torch.float64) 	F-macro_val: tensor(0.4502, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.8955, dtype=torch.float64) 	F-macro_val: tensor(0.4519, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.8951, dtype=torch.float64) 	F-macro_val: tensor(0.4526, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.8955, dtype=torch.float64) 	F-macro_val: tensor(0.4518, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.8951, dtype=torch.float64) 	F-macro_val: tensor(0.4522, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.8937, dtype=torch.float64) 	F-macro_val: tensor(0.4487, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.8937, dtype=torch.float64) 	F-macro_val: tensor(0.4489, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.8937, dtype=torch.float64) 	F-macro_val: tensor(0.4515, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.8946, dtype=torch.float64) 	F-macro_val: tensor(0.4498, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.8946, dtype=torch.float64) 	F-macro_val: tensor(0.4512, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.8946, dtype=torch.float64) 	F-macro_val: tensor(0.4509, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.8946, dtype=torch.float64) 	F-macro_val: tensor(0.4474, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.8946, dtype=torch.float64) 	F-macro_val: tensor(0.4516, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.8951, dtype=torch.float64) 	F-macro_val: tensor(0.4485, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.8941, dtype=torch.float64) 	F-macro_val: tensor(0.4500, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.8951, dtype=torch.float64) 	F-macro_val: tensor(0.4500, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.8946, dtype=torch.float64) 	F-macro_val: tensor(0.4499, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.8932, dtype=torch.float64) 	F-macro_val: tensor(0.4491, dtype=torch.float64)
# Testing run # 3
# SE TUVIERON QUE REPETIR 21 EJEMPLOS
# Test_ acc: 0.8487988695242581
# Test_ f1 none: [0.91173055 0.01869159 0.         0.74636511]
# Test_ f1 macro: 0.4191968099175029
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 4
# Memory usage         :  8.00 MB
# GC collected objects : 804574
# Memory usage         :  8.00 MB
# GC collected objects : 0
# Memory usage         :  8.00 MB
# Shape de los IDs cargados como string: (10627, 768)
# tensor([1., 1., 1., 1.])
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.8605, dtype=torch.float64) 	F-macro_val: tensor(0.4235, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.8890, dtype=torch.float64) 	F-macro_val: tensor(0.4440, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.8895, dtype=torch.float64) 	F-macro_val: tensor(0.4463, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.8885, dtype=torch.float64) 	F-macro_val: tensor(0.4441, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.8899, dtype=torch.float64) 	F-macro_val: tensor(0.4477, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.8890, dtype=torch.float64) 	F-macro_val: tensor(0.4447, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.8885, dtype=torch.float64) 	F-macro_val: tensor(0.4461, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.8890, dtype=torch.float64) 	F-macro_val: tensor(0.4471, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.8895, dtype=torch.float64) 	F-macro_val: tensor(0.4445, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.8876, dtype=torch.float64) 	F-macro_val: tensor(0.4474, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.8899, dtype=torch.float64) 	F-macro_val: tensor(0.4469, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.8904, dtype=torch.float64) 	F-macro_val: tensor(0.4475, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.8885, dtype=torch.float64) 	F-macro_val: tensor(0.4433, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.8881, dtype=torch.float64) 	F-macro_val: tensor(0.4453, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.8871, dtype=torch.float64) 	F-macro_val: tensor(0.4442, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.8876, dtype=torch.float64) 	F-macro_val: tensor(0.4455, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.8904, dtype=torch.float64) 	F-macro_val: tensor(0.4456, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.8904, dtype=torch.float64) 	F-macro_val: tensor(0.4475, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.8890, dtype=torch.float64) 	F-macro_val: tensor(0.4472, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.8876, dtype=torch.float64) 	F-macro_val: tensor(0.4436, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.8909, dtype=torch.float64) 	F-macro_val: tensor(0.4477, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.8909, dtype=torch.float64) 	F-macro_val: tensor(0.4475, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.8899, dtype=torch.float64) 	F-macro_val: tensor(0.4460, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.8913, dtype=torch.float64) 	F-macro_val: tensor(0.4470, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.8890, dtype=torch.float64) 	F-macro_val: tensor(0.4469, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.8904, dtype=torch.float64) 	F-macro_val: tensor(0.4456, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.8904, dtype=torch.float64) 	F-macro_val: tensor(0.4460, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.8913, dtype=torch.float64) 	F-macro_val: tensor(0.4466, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.8913, dtype=torch.float64) 	F-macro_val: tensor(0.4456, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.8899, dtype=torch.float64) 	F-macro_val: tensor(0.4454, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.8909, dtype=torch.float64) 	F-macro_val: tensor(0.4468, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.8913, dtype=torch.float64) 	F-macro_val: tensor(0.4466, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.8913, dtype=torch.float64) 	F-macro_val: tensor(0.4486, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.8899, dtype=torch.float64) 	F-macro_val: tensor(0.4476, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.8899, dtype=torch.float64) 	F-macro_val: tensor(0.4427, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.8918, dtype=torch.float64) 	F-macro_val: tensor(0.4459, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.8918, dtype=torch.float64) 	F-macro_val: tensor(0.4471, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.8909, dtype=torch.float64) 	F-macro_val: tensor(0.4443, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.8909, dtype=torch.float64) 	F-macro_val: tensor(0.4488, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.8909, dtype=torch.float64) 	F-macro_val: tensor(0.4465, dtype=torch.float64)
# Testing run # 4
# SE TUVIERON QUE REPETIR 21 EJEMPLOS
# Test_ acc: 0.833254828073481
# Test_ f1 none: [0.90394511 0.01869159 0.         0.66666667]
# Test_ f1 macro: 0.3973258417359987
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 5
# Memory usage         :  8.10 MB
# GC collected objects : 804574
# Memory usage         :  8.10 MB
# GC collected objects : 0
# Memory usage         :  8.10 MB
# Shape de los IDs cargados como string: (10627, 768)
# tensor([1., 1., 1., 1.])
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.8540, dtype=torch.float64) 	F-macro_val: tensor(0.4175, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.8904, dtype=torch.float64) 	F-macro_val: tensor(0.4451, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.8951, dtype=torch.float64) 	F-macro_val: tensor(0.4480, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.8946, dtype=torch.float64) 	F-macro_val: tensor(0.4522, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.8965, dtype=torch.float64) 	F-macro_val: tensor(0.4501, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.8960, dtype=torch.float64) 	F-macro_val: tensor(0.4532, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.8969, dtype=torch.float64) 	F-macro_val: tensor(0.4524, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.8969, dtype=torch.float64) 	F-macro_val: tensor(0.4524, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.8951, dtype=torch.float64) 	F-macro_val: tensor(0.4508, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.8951, dtype=torch.float64) 	F-macro_val: tensor(0.4526, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.8960, dtype=torch.float64) 	F-macro_val: tensor(0.4535, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.8937, dtype=torch.float64) 	F-macro_val: tensor(0.4479, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.8965, dtype=torch.float64) 	F-macro_val: tensor(0.4520, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.8960, dtype=torch.float64) 	F-macro_val: tensor(0.4517, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.8946, dtype=torch.float64) 	F-macro_val: tensor(0.4523, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.8955, dtype=torch.float64) 	F-macro_val: tensor(0.4515, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.8960, dtype=torch.float64) 	F-macro_val: tensor(0.4493, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.8974, dtype=torch.float64) 	F-macro_val: tensor(0.4503, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.8946, dtype=torch.float64) 	F-macro_val: tensor(0.4512, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.8974, dtype=torch.float64) 	F-macro_val: tensor(0.4504, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.8955, dtype=torch.float64) 	F-macro_val: tensor(0.4529, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.8960, dtype=torch.float64) 	F-macro_val: tensor(0.4514, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.8988, dtype=torch.float64) 	F-macro_val: tensor(0.4532, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.8974, dtype=torch.float64) 	F-macro_val: tensor(0.4532, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.8969, dtype=torch.float64) 	F-macro_val: tensor(0.4511, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.8983, dtype=torch.float64) 	F-macro_val: tensor(0.4514, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.8965, dtype=torch.float64) 	F-macro_val: tensor(0.4509, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.8974, dtype=torch.float64) 	F-macro_val: tensor(0.4520, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.8965, dtype=torch.float64) 	F-macro_val: tensor(0.4531, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.8965, dtype=torch.float64) 	F-macro_val: tensor(0.4483, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.8979, dtype=torch.float64) 	F-macro_val: tensor(0.4526, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.8955, dtype=torch.float64) 	F-macro_val: tensor(0.4488, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.8974, dtype=torch.float64) 	F-macro_val: tensor(0.4540, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.8979, dtype=torch.float64) 	F-macro_val: tensor(0.4500, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.8965, dtype=torch.float64) 	F-macro_val: tensor(0.4507, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.
#         [0.19603963, 0.14681969, 0.14681971, 0.20094399, 0.14681971,
#          0.16255727],
#         [0.19603965, 0.14681972, 0.1468197 , 0.20094398, 0.1468197 ,
#          0.16255729],
#         [0.20672718, 0.15666881, 0.15666884, 0.16202999, 0.15666884,
#          0.16123635],
#         [0.19603965, 0.14681972, 0.1468197 , 0.20094398, 0.1468197 ,
#          0.16255729],
#         [0.19648952, 0.15188732, 0.15188734, 0.18547801, 0.15188734,
#          0.16237047]])]

# %%
np.save("ECML_Attn_prom_SinAum_newCleaner_NoCW.npy", global_attn)

# %%
"Listo"
# Out:
# 'Listo'

# %% [markdown]
# ## Sin aumento con CW

# %%
class_weights= compute_class_weight('balanced', np.unique(etiq), etiq) #[1.0, 1.0, 1.0, 1.0] #
#class_weights= [1.0, 1.0, 1.0, 1.0]
print ("\nPesos de clases:", class_weights)
# Out:
# Pesos de clases: [ 0.43526359 28.97272727 20.96710526  0.61715724]

# %%
global_accs=[]
global_fnones=[]
global_fmacros=[]
global_cms=[]
global_attn=[]
dict_attn_enc={'00':[], '01':[], '02':[], '03':[], '10':[], '11':[], '12':[], '13':[]}
  
prob=0.0

for trans in range(1,6): 
    print ("Entrenando Run #", trans)
    
    cnn1 = load_model('../../../new_data_augmented/harassment_baselines/'+str(prob)+'_cw/cnn1_'+str(trans)+'-exec.h5')
    cnn2 = load_model('../../../new_data_augmented/harassment_baselines/'+str(prob)+'_cw/cnn2_'+str(trans)+'-exec.h5')
    rnn1 = load_model('../../../new_data_augmented/harassment_baselines/'+str(prob)+'_cw/rnn1_'+str(trans)+'-exec.h5')
    rnn2 = load_model('../../../new_data_augmented/harassment_baselines/'+str(prob)+'_cw/rnn2_'+str(trans)+'-exec.h5')
    rnn3 = load_model('../../../new_data_augmented/harassment_baselines/'+str(prob)+'_cw/rnn3_'+str(trans)+'-exec.h5')

    list_models=['cnn1', 'cnn2', 'rnn1', 'rnn2', 'rnn3']
    index_models=np.arange(5)
    dict_models=dict((key, value) for (key, value) in zip(index_models,list_models))
    modelos=[cnn1, cnn2, rnn1, rnn2, rnn3]
    ind=np.arange(5)
    dict_trainedModel=dict((key, value) for (key, value) in zip(ind,modelos))

    bs=32
    predicciones_all=[]
    predicciones_all_val=[]
    predicciones_all_test=[]

    for i in dict_trainedModel.keys(): 
        a_evaluar=dict_models[i]
        predicciones_all.append(dict_trainedModel[i].predict(x_train, batch_size=bs))
    for i in dict_trainedModel.keys(): 
        a_evaluar=dict_models[i]
        predicciones_all_val.append(dict_trainedModel[i].predict(x_val, batch_size=bs))
    for i in dict_trainedModel.keys(): 
        a_evaluar=dict_models[i]
        predicciones_all_test.append(dict_trainedModel[i].predict(x_test, batch_size=bs))

    matrix=np.asarray(predicciones_all)
    matrix_val=np.asarray(predicciones_all_val)
    matrix_test=np.asarray(predicciones_all_test)
    new_matrix=np.concatenate([matrix,matrix_val,matrix_test], axis=1)
    
    mem()
    print('GC collected objects : %d' % gc.collect())
    mem()
    
    gc.collect()    
    
    print('GC collected objects : %d' % gc.collect())
    mem()
    
    ####### eliminar modelos de memoria
    keras.backend.clear_session()
    gc.collect()
    ####################
    #del tokenizer_loaded 
    #del model_loaded 
    #del idx_2_token 
    #del M_BERT_space
    #del cnn1, cnn2, rnn1, rnn2, rnn3
    torch.cuda.empty_cache()
    ####################
    
    fromId2num={}
    keys=ids_train+ids_val+ids_test
    values=np.arange(5,len(keys)+5)
    for key, value in list(zip(keys,values)):
        fromId2num[key]=value   #original largo --> valor tabla (index)

    fromNum2Id={}
    for value, key in list(zip(values,keys)):
        fromNum2Id[value]=key   #valor tabla (index) --> original largo

    espacio=[np.ones(768)]
    Ks=np.load("../../../../BERTransformer/Orthogonals_768.npy")
    random=np.random.randint(Ks.shape[0], size=4)
    K_list=Ks[random]
    K_list_ext=espacio+list(K_list)
    objs_train=ids_train.copy()
    objs_val=ids_val     #df_val['Unnamed: 0'].values
    objs_test=ids_test    #np.arange(df_test.shape[0])
    llaves=ids_train+ids_val+ids_test

    K_list_new=K_list_ext
    for i in llaves:
        vector=np.load("../../../BaS_Original/ECML/Original/"+str(i)+".npy")
        norm=np.linalg.norm(vector)
        vector= vector / norm
        K_list_new.append(vector)

    K_list_new= np.asarray(K_list_new, dtype='float32')
    print ("Shape de los IDs cargados como string:", K_list_new.shape )
    K_list_new=torch.from_numpy(K_list_new).float().to(device)
    class_weights=np.asarray(class_weights)
    pesos = torch.from_numpy(class_weights).float()
    print (pesos)
    
    ############################################# TRANSFORMER ##########################################

    V = 4    
    criterion = FocalLoss(weights=pesos)
    model = make_model_concat(4, N=2,d_model=768, d_ff=128, h=4, dropout=0.35)
    #model.cuda()
    model_opt = NoamOpt(model.src_embed[0].d_model, 1, 500, torch.optim.Adam(model.parameters(), lr=0, betas=(0.9, 0.98), eps=1e-5))

    for epoch in range(40):
        model.train()
        DATA=data_gen(bs, 'Train', 5, new_matrix)
        loss_train, acc_train,fma_train, f_none, cm_train=run_epoch(DATA, model, SimpleLossComputeFL(criterion, model_opt), 'Train')
        
        model.eval()
        loss_val, acc_val,fma_val, f_val_none, cm_val=run_epoch(data_gen(bs, 'Val', 5, new_matrix), model, SimpleLossComputeFL(criterion, None),'Val')
        print ("Epoch",epoch, "\tacc_val:",acc_val, "\tF-macro_val:",fma_val)

    model.eval()
    print ("Testing run #",trans)
    predicciones = run_epoch(data_gen(bs, 'Test', 5, new_matrix), model, SimpleLossComputeFL(criterion, None),'Test')
    predicciones=np.concatenate(predicciones, axis=-1)
    
    glo_acc=accuracy_score(etiq_t, predicciones[:-21])
    glo_fno=f1_score(etiq_t,predicciones[:-21], average=None)
    glo_fma=f1_score(etiq_t,predicciones[:-21], average='macro')

    print("Test_ acc:",glo_acc) 
    print("Test_ f1 none:",glo_fno) 
    print("Test_ f1 macro:",glo_fma) 

    glo_cm=confusion_matrix(etiq_t, predicciones[:-21])
    plot_confusion_matrix(glo_cm,["NonH","IndirectH","PhysicalH","SexualH"],"Confusion Matrix Transformer 40-e Harassment NoAum-ConCW")
    global_accs.append(glo_acc)
    global_fnones.append(glo_fno)
    global_fmacros.append(glo_fma)
    global_cms.append(glo_cm)

    label=[['Text', 'm1', 'm2','m3','m4','m5']]
    for layer in range(2):
        fig, axs = plt.subplots(1,4, figsize=(20, 10))
        print ("Encoder Layer Attention head", layer)
        for head in range(4):
            matriz_attn=model.encoder.layers[layer].self_attn.attn[0,head].data
            dict_attn_enc[str(layer)+str(head)].append(matriz_attn)
            sns.heatmap(matriz_attn, xticklabels=label[0], yticklabels=label[0],
                        vmin=0.0, vmax=1.0, linewidths=.5, cmap="Blues", cbar=False, square=True, ax=axs[head]) #, annot=False,cbar_kws={"orientation": "horizontal","pad": 0.25})
        plt.show()
# Out:
# Entrenando Run # 1
# Memory usage         :  8.10 MB
# GC collected objects : 804554
# Memory usage         :  8.10 MB
# GC collected objects : 0
# Memory usage         :  8.10 MB
# Shape de los IDs cargados como string: (10627, 768)
# tensor([ 0.4353, 28.9727, 20.9671,  0.6172])
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.8405, dtype=torch.float64) 	F-macro_val: tensor(0.4329, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.8685, dtype=torch.float64) 	F-macro_val: tensor(0.4379, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.8517, dtype=torch.float64) 	F-macro_val: tensor(0.4375, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.8806, dtype=torch.float64) 	F-macro_val: tensor(0.4470, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.8811, dtype=torch.float64) 	F-macro_val: tensor(0.4444, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.8811, dtype=torch.float64) 	F-macro_val: tensor(0.4483, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.8839, dtype=torch.float64) 	F-macro_val: tensor(0.4497, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.8857, dtype=torch.float64) 	F-macro_val: tensor(0.4537, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.8862, dtype=torch.float64) 	F-macro_val: tensor(0.4516, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.8885, dtype=torch.float64) 	F-macro_val: tensor(0.4521, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.8867, dtype=torch.float64) 	F-macro_val: tensor(0.4500, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.8862, dtype=torch.float64) 	F-macro_val: tensor(0.4495, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.8890, dtype=torch.float64) 	F-macro_val: tensor(0.4535, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.8881, dtype=torch.float64) 	F-macro_val: tensor(0.4507, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.8881, dtype=torch.float64) 	F-macro_val: tensor(0.4506, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.8871, dtype=torch.float64) 	F-macro_val: tensor(0.4483, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.8848, dtype=torch.float64) 	F-macro_val: tensor(0.4475, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.8871, dtype=torch.float64) 	F-macro_val: tensor(0.4505, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.8881, dtype=torch.float64) 	F-macro_val: tensor(0.4513, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.8885, dtype=torch.float64) 	F-macro_val: tensor(0.4486, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.8890, dtype=torch.float64) 	F-macro_val: tensor(0.4510, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.8871, dtype=torch.float64) 	F-macro_val: tensor(0.4519, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.8848, dtype=torch.float64) 	F-macro_val: tensor(0.4448, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.8848, dtype=torch.float64) 	F-macro_val: tensor(0.4493, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.8853, dtype=torch.float64) 	F-macro_val: tensor(0.4473, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.8862, dtype=torch.float64) 	F-macro_val: tensor(0.4512, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.8853, dtype=torch.float64) 	F-macro_val: tensor(0.4470, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.8857, dtype=torch.float64) 	F-macro_val: tensor(0.4483, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.8862, dtype=torch.float64) 	F-macro_val: tensor(0.4454, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.8857, dtype=torch.float64) 	F-macro_val: tensor(0.4480, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.8876, dtype=torch.float64) 	F-macro_val: tensor(0.4482, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.8853, dtype=torch.float64) 	F-macro_val: tensor(0.4492, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.8843, dtype=torch.float64) 	F-macro_val: tensor(0.4445, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.8862, dtype=torch.float64) 	F-macro_val: tensor(0.4497, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.8857, dtype=torch.float64) 	F-macro_val: tensor(0.4478, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.8857, dtype=torch.float64) 	F-macro_val: tensor(0.4505, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.8862, dtype=torch.float64) 	F-macro_val: tensor(0.4479, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.8857, dtype=torch.float64) 	F-macro_val: tensor(0.4455, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.8867, dtype=torch.float64) 	F-macro_val: tensor(0.4452, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.8862, dtype=torch.float64) 	F-macro_val: tensor(0.4473, dtype=torch.float64)
# Testing run # 1
# SE TUVIERON QUE REPETIR 21 EJEMPLOS
# Test_ acc: 0.8464437117286858
# Test_ f1 none: [0.91465568 0.         0.02469136 0.7322239 ]
# Test_ f1 macro: 0.4178927352533374
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 2
# Memory usage         :  8.10 MB
# GC collected objects : 756030
# Memory usage         :  8.10 MB
# GC collected objects : 0
# Memory usage         :  8.10 MB
# Shape de los IDs cargados como string: (10627, 768)
# tensor([ 0.4353, 28.9727, 20.9671,  0.6172])
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.8419, dtype=torch.float64) 	F-macro_val: tensor(0.4116, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.8671, dtype=torch.float64) 	F-macro_val: tensor(0.4314, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.8685, dtype=torch.float64) 	F-macro_val: tensor(0.4342, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.8708, dtype=torch.float64) 	F-macro_val: tensor(0.4434, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.8713, dtype=torch.float64) 	F-macro_val: tensor(0.4435, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.8736, dtype=torch.float64) 	F-macro_val: tensor(0.4436, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.8745, dtype=torch.float64) 	F-macro_val: tensor(0.4416, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.8783, dtype=torch.float64) 	F-macro_val: tensor(0.4472, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.8764, dtype=torch.float64) 	F-macro_val: tensor(0.4465, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.8792, dtype=torch.float64) 	F-macro_val: tensor(0.4455, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.8759, dtype=torch.float64) 	F-macro_val: tensor(0.4427, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.8778, dtype=torch.float64) 	F-macro_val: tensor(0.4448, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.8783, dtype=torch.float64) 	F-macro_val: tensor(0.4463, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.8797, dtype=torch.float64) 	F-macro_val: tensor(0.4460, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.8806, dtype=torch.float64) 	F-macro_val: tensor(0.4474, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.8787, dtype=torch.float64) 	F-macro_val: tensor(0.4435, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.8825, dtype=torch.float64) 	F-macro_val: tensor(0.4493, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.8778, dtype=torch.float64) 	F-macro_val: tensor(0.4415, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.8806, dtype=torch.float64) 	F-macro_val: tensor(0.4467, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.8820, dtype=torch.float64) 	F-macro_val: tensor(0.4464, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.8825, dtype=torch.float64) 	F-macro_val: tensor(0.4487, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.8792, dtype=torch.float64) 	F-macro_val: tensor(0.4474, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.8815, dtype=torch.float64) 	F-macro_val: tensor(0.4501, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.8834, dtype=torch.float64) 	F-macro_val: tensor(0.4513, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.8839, dtype=torch.float64) 	F-macro_val: tensor(0.4488, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.8834, dtype=torch.float64) 	F-macro_val: tensor(0.4488, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.8825, dtype=torch.float64) 	F-macro_val: tensor(0.4500, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.8825, dtype=torch.float64) 	F-macro_val: tensor(0.4487, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.8848, dtype=torch.float64) 	F-macro_val: tensor(0.4498, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.8829, dtype=torch.float64) 	F-macro_val: tensor(0.4474, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.8811, dtype=torch.float64) 	F-macro_val: tensor(0.4444, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.8820, dtype=torch.float64) 	F-macro_val: tensor(0.4502, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.8834, dtype=torch.float64) 	F-macro_val: tensor(0.4521, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.8839, dtype=torch.float64) 	F-macro_val: tensor(0.4479, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.8834, dtype=torch.float64) 	F-macro_val: tensor(0.4471, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.8829, dtype=torch.float64) 	F-macro_val: tensor(0.4466, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.8820, dtype=torch.float64) 	F-macro_val: tensor(0.4484, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.8829, dtype=torch.float64) 	F-macro_val: tensor(0.4456, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.8839, dtype=torch.float64) 	F-macro_val: tensor(0.4480, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.8820, dtype=torch.float64) 	F-macro_val: tensor(0.4442, dtype=torch.float64)
# Testing run # 2
# SE TUVIERON QUE REPETIR 21 EJEMPLOS
# Test_ acc: 0.83843617522374
# Test_ f1 none: [0.90930165 0.         0.         0.69636964]
# Test_ f1 macro: 0.40141782216471433
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 3
# Memory usage         :  8.10 MB
# GC collected objects : 756018
# Memory usage         :  8.10 MB
# GC collected objects : 0
# Memory usage         :  8.10 MB
# Shape de los IDs cargados como string: (10627, 768)
# tensor([ 0.4353, 28.9727, 20.9671,  0.6172])
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.6982, dtype=torch.float64) 	F-macro_val: tensor(0.3473, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.7910, dtype=torch.float64) 	F-macro_val: tensor(0.4173, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.8078, dtype=torch.float64) 	F-macro_val: tensor(0.4243, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.8302, dtype=torch.float64) 	F-macro_val: tensor(0.4293, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.8521, dtype=torch.float64) 	F-macro_val: tensor(0.4302, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.8573, dtype=torch.float64) 	F-macro_val: tensor(0.4359, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.8344, dtype=torch.float64) 	F-macro_val: tensor(0.4332, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.8493, dtype=torch.float64) 	F-macro_val: tensor(0.4406, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.8563, dtype=torch.float64) 	F-macro_val: tensor(0.4411, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.8582, dtype=torch.float64) 	F-macro_val: tensor(0.4403, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.8559, dtype=torch.float64) 	F-macro_val: tensor(0.4302, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.8498, dtype=torch.float64) 	F-macro_val: tensor(0.4259, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.8605, dtype=torch.float64) 	F-macro_val: tensor(0.4307, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.8624, dtype=torch.float64) 	F-macro_val: tensor(0.4336, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.8624, dtype=torch.float64) 	F-macro_val: tensor(0.4327, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.8652, dtype=torch.float64) 	F-macro_val: tensor(0.4353, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.8633, dtype=torch.float64) 	F-macro_val: tensor(0.4331, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.8657, dtype=torch.float64) 	F-macro_val: tensor(0.4316, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.8601, dtype=torch.float64) 	F-macro_val: tensor(0.4276, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.8652, dtype=torch.float64) 	F-macro_val: tensor(0.4331, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.8680, dtype=torch.float64) 	F-macro_val: tensor(0.4322, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.8680, dtype=torch.float64) 	F-macro_val: tensor(0.4345, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.8713, dtype=torch.float64) 	F-macro_val: tensor(0.4360, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.8694, dtype=torch.float64) 	F-macro_val: tensor(0.4358, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.8708, dtype=torch.float64) 	F-macro_val: tensor(0.4380, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.8708, dtype=torch.float64) 	F-macro_val: tensor(0.4367, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.8689, dtype=torch.float64) 	F-macro_val: tensor(0.4334, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.8699, dtype=torch.float64) 	F-macro_val: tensor(0.4345, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.8703, dtype=torch.float64) 	F-macro_val: tensor(0.4351, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.8685, dtype=torch.float64) 	F-macro_val: tensor(0.4363, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.8615, dtype=torch.float64) 	F-macro_val: tensor(0.4313, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.8680, dtype=torch.float64) 	F-macro_val: tensor(0.4332, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.8694, dtype=torch.float64) 	F-macro_val: tensor(0.4355, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.8633, dtype=torch.float64) 	F-macro_val: tensor(0.4292, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.8685, dtype=torch.float64) 	F-macro_val: tensor(0.4327, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.8699, dtype=torch.float64) 	F-macro_val: tensor(0.4334, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.8708, dtype=torch.float64) 	F-macro_val: tensor(0.4366, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.8703, dtype=torch.float64) 	F-macro_val: tensor(0.4369, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.8708, dtype=torch.float64) 	F-macro_val: tensor(0.4338, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.8717, dtype=torch.float64) 	F-macro_val: tensor(0.4360, dtype=torch.float64)
# Testing run # 3
# SE TUVIERON QUE REPETIR 21 EJEMPLOS
# Test_ acc: 0.8308996702779087
# Test_ f1 none: [0.90481856 0.01851852 0.02439024 0.6945245 ]
# Test_ f1 macro: 0.4105629546197292
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 4
# Memory usage         :  8.10 MB
# GC collected objects : 756022
# Memory usage         :  8.10 MB
# GC collected objects : 0
# Memory usage         :  8.10 MB
# Shape de los IDs cargados como string: (10627, 768)
# tensor([ 0.4353, 28.9727, 20.9671,  0.6172])
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.8312, dtype=torch.float64) 	F-macro_val: tensor(0.4190, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.8577, dtype=torch.float64) 	F-macro_val: tensor(0.4438, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.8647, dtype=torch.float64) 	F-macro_val: tensor(0.4456, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.8787, dtype=torch.float64) 	F-macro_val: tensor(0.4396, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.8797, dtype=torch.float64) 	F-macro_val: tensor(0.4424, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.8783, dtype=torch.float64) 	F-macro_val: tensor(0.4419, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.8801, dtype=torch.float64) 	F-macro_val: tensor(0.4425, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.8792, dtype=torch.float64) 	F-macro_val: tensor(0.4404, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.8806, dtype=torch.float64) 	F-macro_val: tensor(0.4421, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.8801, dtype=torch.float64) 	F-macro_val: tensor(0.4421, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.8811, dtype=torch.float64) 	F-macro_val: tensor(0.4441, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.8806, dtype=torch.float64) 	F-macro_val: tensor(0.4418, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.8778, dtype=torch.float64) 	F-macro_val: tensor(0.4404, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.8773, dtype=torch.float64) 	F-macro_val: tensor(0.4437, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.8815, dtype=torch.float64) 	F-macro_val: tensor(0.4438, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.8815, dtype=torch.float64) 	F-macro_val: tensor(0.4433, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.8797, dtype=torch.float64) 	F-macro_val: tensor(0.4420, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.8811, dtype=torch.float64) 	F-macro_val: tensor(0.4423, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.8815, dtype=torch.float64) 	F-macro_val: tensor(0.4445, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.8806, dtype=torch.float64) 	F-macro_val: tensor(0.4396, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.8825, dtype=torch.float64) 	F-macro_val: tensor(0.4436, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.8806, dtype=torch.float64) 	F-macro_val: tensor(0.4423, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.8811, dtype=torch.float64) 	F-macro_val: tensor(0.4429, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.8783, dtype=torch.float64) 	F-macro_val: tensor(0.4409, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.8773, dtype=torch.float64) 	F-macro_val: tensor(0.4395, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.8797, dtype=torch.float64) 	F-macro_val: tensor(0.4420, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.8825, dtype=torch.float64) 	F-macro_val: tensor(0.4392, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.8792, dtype=torch.float64) 	F-macro_val: tensor(0.4405, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.8815, dtype=torch.float64) 	F-macro_val: tensor(0.4424, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.8815, dtype=torch.float64) 	F-macro_val: tensor(0.4432, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.8825, dtype=torch.float64) 	F-macro_val: tensor(0.4429, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.8806, dtype=torch.float64) 	F-macro_val: tensor(0.4407, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.8820, dtype=torch.float64) 	F-macro_val: tensor(0.4427, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.8825, dtype=torch.float64) 	F-macro_val: tensor(0.4436, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.8792, dtype=torch.float64) 	F-macro_val: tensor(0.4413, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.8829, dtype=torch.float64) 	F-macro_val: tensor(0.4441, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.8829, dtype=torch.float64) 	F-macro_val: tensor(0.4436, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.8797, dtype=torch.float64) 	F-macro_val: tensor(0.4402, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.8783, dtype=torch.float64) 	F-macro_val: tensor(0.4402, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.8783, dtype=torch.float64) 	F-macro_val: tensor(0.4414, dtype=torch.float64)
# Testing run # 4
# SE TUVIERON QUE REPETIR 21 EJEMPLOS
# Test_ acc: 0.8455016486104568
# Test_ f1 none: [0.91295367 0.         0.         0.73481481]
# Test_ f1 macro: 0.4119421221162147
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 5
# Memory usage         :  8.10 MB
# GC collected objects : 756022
# Memory usage         :  8.10 MB
# GC collected objects : 0
# Memory usage         :  8.10 MB
# Shape de los IDs cargados como string: (10627, 768)
# tensor([ 0.4353, 28.9727, 20.9671,  0.6172])
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.7509, dtype=torch.float64) 	F-macro_val: tensor(0.3172, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.8689, dtype=torch.float64) 	F-macro_val: tensor(0.4363, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.8797, dtype=torch.float64) 	F-macro_val: tensor(0.4472, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.8750, dtype=torch.float64) 	F-macro_val: tensor(0.4392, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.8759, dtype=torch.float64) 	F-macro_val: tensor(0.4382, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.8773, dtype=torch.float64) 	F-macro_val: tensor(0.4399, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.8755, dtype=torch.float64) 	F-macro_val: tensor(0.4394, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.8745, dtype=torch.float64) 	F-macro_val: tensor(0.4395, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.8764, dtype=torch.float64) 	F-macro_val: tensor(0.4395, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.8787, dtype=torch.float64) 	F-macro_val: tensor(0.4398, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.8736, dtype=torch.float64) 	F-macro_val: tensor(0.4348, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.8722, dtype=torch.float64) 	F-macro_val: tensor(0.4370, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.8661, dtype=torch.float64) 	F-macro_val: tensor(0.4333, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.8745, dtype=torch.float64) 	F-macro_val: tensor(0.4358, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.8736, dtype=torch.float64) 	F-macro_val: tensor(0.4375, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.8801, dtype=torch.float64) 	F-macro_val: tensor(0.4412, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.8783, dtype=torch.float64) 	F-macro_val: tensor(0.4401, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.8787, dtype=torch.float64) 	F-macro_val: tensor(0.4390, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.8787, dtype=torch.float64) 	F-macro_val: tensor(0.4415, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.8773, dtype=torch.float64) 	F-macro_val: tensor(0.4390, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.8773, dtype=torch.float64) 	F-macro_val: tensor(0.4377, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.8792, dtype=torch.float64) 	F-macro_val: tensor(0.4373, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.8797, dtype=torch.float64) 	F-macro_val: tensor(0.4395, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.8806, dtype=torch.float64) 	F-macro_val: tensor(0.4410, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.8797, dtype=torch.float64) 	F-macro_val: tensor(0.4409, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.8801, dtype=torch.float64) 	F-macro_val: tensor(0.4419, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.8759, dtype=torch.float64) 	F-macro_val: tensor(0.4403, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.8736, dtype=torch.float64) 	F-macro_val: tensor(0.4381, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.8759, dtype=torch.float64) 	F-macro_val: tensor(0.4393, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.8755, dtype=torch.float64) 	F-macro_val: tensor(0.4394, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.8759, dtype=torch.float64) 	F-macro_val: tensor(0.4386, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.8750, dtype=torch.float64) 	F-macro_val: tensor(0.4382, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.8787, dtype=torch.float64) 	F-macro_val: tensor(0.4401, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.8801, dtype=torch.float64) 	F-macro_val: tensor(0.4414, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.8787, dtype=torch.float64) 	F-macro_val: tensor(0.4408, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.8792, dtype=torch.float64) 	F-macro_val: tensor(0.4416, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.8801, dtype=torch.float64) 	F-macro_val: tensor(0.4403, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.8797, dtype=torch.float64) 	F-macro_val: tensor(0.4406, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.8783, dtype=torch.float64) 	F-macro_val: tensor(0.4401, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0
#         [0.13852434, 0.16825209, 0.18208121, 0.15168509, 0.17737606,
#          0.18208117],
#         [0.12127917, 0.15612827, 0.15569069, 0.1927601 , 0.21845107,
#          0.1556907 ],
#         [0.1419231 , 0.14532297, 0.14488542, 0.18195483, 0.24102825,
#          0.1448854 ],
#         [0.13852435, 0.16825209, 0.1820812 , 0.15168512, 0.17737606,
#          0.18208118]])]

# %%
np.save("ECML_Attn_prom_SinAum_newCleaner_CW.npy", global_attn)

# %% [markdown]
# # Aumentando

# %%
def data_gen(batch_size,mode,n_machines,new_matrix):  
    """ESTA FUNCION DEBERÁ RETORNAR MATRICES DE TAMAÑO BATCH_SIZE * TW,M1,M2,M3,M4,M5,M6
    CADA EJEMPLO DEBERÁ SER ESTILO [ID_T, 1,2,1,2,1,2] SIENDO 1 CUANDO LA CLASE PREDICHA ES LA 0
    2 PARA CLASE PREDICHA 1, ETC. ID_T DEBEŔA INICIAR EN 5 PARA REFERIRSE AL PRIMER TW (EL PRIMERO DE TRAIN)"""
    x_data=[] 
    y_data=[]
    if mode=='Train':
        max_objs=matrix.shape[1]
        x_list=np.arange(max_objs)
        np.random.shuffle(x_list)        #indices desordenados de seccion train
        objs=ids_train
        labels=etiq     #np.load("matrices/y_train_num_4.npy")
        labels=np.asarray(labels) #+ np.ones(labels.shape),dtype='uint8')
    if mode=='Val':
        max_objs=matrix_val.shape[1] 
        x_list=np.arange(max_objs)
        x_list=[x+matrix.shape[1] for x in x_list]   
        np.random.shuffle(x_list)        #indices desordenados de seccion val
        objs=ids_val    #df_val['Unnamed: 0'].values        
        labels=np.asarray(etiq_v)     #np.load("matrices/y_val_num_4.npy")
        labels=np.asarray(labels) #+ np.ones(labels.shape),dtype='uint8') 
    if mode=='Test':
        max_objs=matrix_test.shape[1] 
        x_list=np.arange(max_objs)
        x_list=[x+matrix.shape[1]+matrix_val.shape[1] for x in x_list]
        total=matrix.shape[1]+matrix_val.shape[1]
        objs=ids_test     #np.arange(total, total+max_objs)
        
    #----------------------------------- COMPLETA MINI BATCHES ----------------------    
    if len(x_list)%batch_size==0:
        n_batches=len(x_list)/batch_size
        for nb in range(n_batches): 
            x_data.append(x_list[nb*batch_size:(nb+1)*batch_size])
    else:
        n_batches=int(len(x_list)/batch_size)
        resto=int(len(x_list)-n_batches*batch_size)
        to_repeat=batch_size-resto        
        for nb in range(n_batches): 
            x_data.append(x_list[nb*batch_size:(nb+1)*batch_size])
        cola=list(x_list[(nb+1)*batch_size:])
        for i in range(to_repeat):
            indice= np.random.randint(len(x_list))
            cola.append(x_list[indice])
        x_data.append(np.asarray(cola))
        if mode=='Test':
            print ("SE TUVIERON QUE REPETIR", to_repeat, "EJEMPLOS")
    #print ("los indices de train k voy a acceder random son", x_data[0])
            
    #-------------------------------- CONSTRUCCION MINI BATCHES (X,Y)----------------------   
    new_x_data=[] 
    for batch in x_data:
        #print ("transformando batch", batch)
        temp=[]
        for pos in batch:
            #print("en especifico el numerito", pos)
            temp2=[index_embeddings[pos+5]]#fromId2num[objs[exam]]] ### obj evaluado en maquinas  
            #print ("me dice que es el embed en index", temp2)
            for m in range(n_machines): 
                #print ("machine ",m,"dice:", np.argmax(new_matrix[m][pos])+1)
                temp2= temp2 + [np.argmax(new_matrix[m][pos])+1] 
                #matrix[4][cosa-5])+1)
            temp.append(temp2)
        new_x_data.append(temp)   

    if mode=='Train' or mode=='Val':    
        y_data=[]
        for conjunto in range(len(new_x_data)):
            batch=new_x_data[conjunto]
            temp_y=[]
            for linea in range(len(batch)):
                indice=x_data[conjunto][linea]  #pos
                lab=d_lab[lab_str_embeddings[indice+5]]+1 #labels_train
                temp_y.append([lab])       
            y_data.append(temp_y)
            
        y_data=np.asarray(y_data)
        
    new_x_data=np.asarray(new_x_data)
    #print ("primer batch X.Y", new_x_data[0], y_data[0])
    if mode=='Test':
        for x in new_x_data:
            src = Variable(torch.from_numpy(np.asarray(x)), requires_grad=False)
            yield Batch(src, None, 0)        
    else:          
        for x,y in zip(new_x_data, y_data):
            src = Variable(torch.from_numpy(np.asarray(x)), requires_grad=False)
            har = Variable(torch.from_numpy(np.asarray(y)), requires_grad=False)
            yield Batch(src, har, 0)

# %%
def make_model_concat(target, N=2, d_model=768, d_ff=128, h=4, dropout=0.35, soft=True):  #recibir src_vocab si lo utiliza dummy_Emb
    c = copy.deepcopy
    attn = MultiHeadedAttention(h, d_model)
    ff = PositionwiseFeedForward(d_model, d_ff, dropout)
    position = PositionalText_concat(d_model, dropout)
    if soft:
        print ("Creando modelo con salida Softmax")
        model = EncoderDecoderSoft(
            Encoder(EncoderLayer(d_model, c(attn), c(ff), dropout), N),
            nn.Sequential(Dummy_Embeddings(768, K_list_new), c(position)),
            nn.Linear(d_model, 4))
    else:
        print ("")
        print ("Creando modelo con salida Log_softmax")
        model = EncoderDecoderLogSoft(
            Encoder(EncoderLayer(d_model, c(attn), c(ff), dropout), N),
            nn.Sequential(Dummy_Embeddings(768, K_list_new), c(position)),
            nn.Linear(d_model, 4))

    for p in model.parameters():
        if p.dim() > 1:
            nn.init.xavier_uniform(p)
    return model

class Batch:
    def __init__(self, src, trg=None, pad=0):
        self.src = src
        self.src_mask = (src != pad).unsqueeze(-2)
        if trg is not None:
            self.trg = trg[:, :]
            self.trg_y = trg[:, 0:]
            self.trg_mask = \
                self.make_std_mask(self.trg, pad)
            self.ntokens = (self.trg_y != pad).data.sum()
            
    @staticmethod
    def make_std_mask(tgt, pad):
        tgt_mask = (tgt != pad).unsqueeze(-2)
        tgt_mask = tgt_mask & Variable(
            subsequent_mask(tgt.size(-1)).type_as(tgt_mask.data))
        return tgt_mask
    
def run_epoch(data_iter, model, loss_compute, mode):
    if mode=='Test':
        with torch.no_grad():
            start = time.time()
            pred_classes=[]
            for i, batch in enumerate(data_iter):
                out = model.forward(batch.src, batch.src_mask)
                pred_classes.append(out.argmax(dim=-1).cpu().numpy())
            return pred_classes
    
    else:
        start = time.time()
        total_learners = 0
        total_datos = 0
        total_loss = 0
        total_acc=0
        total_fm1=0
        total_fs=0
        n_batches = 0
        cm_last=np.zeros((4,4))
        for i, batch in enumerate(data_iter):
            out = model.forward(batch.src, batch.src_mask)
            loss,acc,f1,cm = loss_compute(out, batch.trg_y, batch.ntokens, mode)
            cm_last+=cm
            f_ma=np.mean(f1)
            total_loss += loss
            total_acc += np.array(acc)
            total_fm1 += np.sum(f1)/4.0    #4 clases (macro)
            total_fs += f1                 #none  
            total_datos += batch.ntokens
            n_batches += 1
        return total_loss/n_batches, torch.from_numpy(np.array(total_acc))/n_batches, torch.from_numpy(np.array(total_fm1))/n_batches, torch.from_numpy(np.array(total_fs))/n_batches, cm_last

# %% [markdown]
# ## 0.15

# %%
global_accs=[]
global_fnones=[]
global_fmacros=[]
global_cms=[]
global_attn=[]
dict_attn_enc={'00':[], '01':[], '02':[], '03':[], '10':[], '11':[], '12':[], '13':[]}
  
prob=0.15

for trans in range(1,6): 
    print ("Entrenando Run #", trans)
    macro_augmented= np.load('../../../new_data_augmented/harassment/Aumento_'+str(trans)+'-run_'+str(prob)+'_app1_Top1.npy', allow_pickle=True)

    ids_train=macro_augmented[:,0]
    #ids_train=[str(ide)+'_train_0' for ide in ids_train]
    ids_val=val['tweet_id']
    ids_val=[str(ide)+'_val_0' for ide in ids_val]
    ids_test=test['tweet_id']
    ids_test=[str(ide)+'_test_0' for ide in ids_test]
    
    sentences=macro_augmented[:,1]
    labels_train=macro_augmented[:,2]
    class_weights= [1.0, 1.0, 1.0, 1.0]
        
    n_labels=np.array(labels_train.copy())
    y_train=to_categorical(n_labels,num_classes=4)
    
    input_ids = []
    for sent in sentences:
        encoded_sent = tokenizer_loaded.encode(list(sent),add_special_tokens = False)    
        input_ids.append(encoded_sent)
    input_ids = pad_sequences(input_ids, maxlen=MAX_LEN, dtype="long", 
                              value=0, truncating="post", padding="post")
        
    shape=np.asarray(input_ids).shape
    x_train=np.zeros((shape[0], shape[1], 768))
    j=0
    for in_id in input_ids:
        x_train[j]=M_BERT_space[in_id]
        j+=1
    
    cnn1 = load_model('../../../new_data_augmented/harassment_baselines/'+str(prob)+'/cnn1_'+str(trans)+'-exec_app1_Top_1.h5')
    cnn2 = load_model('../../../new_data_augmented/harassment_baselines/'+str(prob)+'/cnn2_'+str(trans)+'-exec_app1_Top_1.h5')
    rnn1 = load_model('../../../new_data_augmented/harassment_baselines/'+str(prob)+'/rnn1_'+str(trans)+'-exec_app1_Top_1.h5')
    rnn2 = load_model('../../../new_data_augmented/harassment_baselines/'+str(prob)+'/rnn2_'+str(trans)+'-exec_app1_Top_1.h5')
    rnn3 = load_model('../../../new_data_augmented/harassment_baselines/'+str(prob)+'/rnn3_'+str(trans)+'-exec_app1_Top_1.h5')

    list_models=['cnn1', 'cnn2', 'rnn1', 'rnn2', 'rnn3']
    index_models=np.arange(5)
    dict_models=dict((key, value) for (key, value) in zip(index_models,list_models))
    modelos=[cnn1, cnn2, rnn1, rnn2, rnn3]
    ind=np.arange(5)
    dict_trainedModel=dict((key, value) for (key, value) in zip(ind,modelos))

    bs=32
    predicciones_all=[]
    predicciones_all_val=[]
    predicciones_all_test=[]

    for i in dict_trainedModel.keys(): 
        a_evaluar=dict_models[i]
        predicciones_all.append(dict_trainedModel[i].predict(x_train, batch_size=bs))
    for i in dict_trainedModel.keys(): 
        a_evaluar=dict_models[i]
        predicciones_all_val.append(dict_trainedModel[i].predict(x_val, batch_size=bs))
    for i in dict_trainedModel.keys(): 
        a_evaluar=dict_models[i]
        predicciones_all_test.append(dict_trainedModel[i].predict(x_test, batch_size=bs))

    matrix=np.asarray(predicciones_all)
    matrix_val=np.asarray(predicciones_all_val)
    matrix_test=np.asarray(predicciones_all_test)
    new_matrix=np.concatenate([matrix,matrix_val,matrix_test], axis=1)
    
    mem()
    print('GC collected objects : %d' % gc.collect())
    mem()
    
    gc.collect()    
    
    print('GC collected objects : %d' % gc.collect())
    mem()
    
    ####### eliminar modelos de memoria
    keras.backend.clear_session()
    gc.collect()  
    torch.cuda.empty_cache()
    
    espacio=[np.ones(768)]
    Ks=np.load("../../../../BERTransformer/Orthogonals_768.npy")
    random=np.random.randint(Ks.shape[0], size=4)
    K_list=Ks[random]
    K_list_ext=espacio+list(K_list)
    index_embeddings=[0,1,2,3,4]
    lab_str_embeddings=['','','','','']
    
    j=0
    for sen in sentences:
        lab=labels_train[j]
        folder=dict_cl[lab]
        ide=ids_train[j]  #creado en data augmentation
        
        if type(sen)==list:
            #recuperar en generados por folder y prob             
            vector=np.load('../../../BaS_Original/ECML/'+str(prob)+'/'+str(trans)+'/'+folder+'/'+str(ide)+'_train_1.npy')
        else:
            #recuperar de original
            vector=np.load('../../../BaS_Original/ECML/Original/'+str(ide)+'_train_0.npy')
        
        norm=np.linalg.norm(vector)
        vector= vector / norm
        index_embeddings.append(j+5)
        lab_str_embeddings.append(folder)
        K_list_ext.append(vector)
        j+=1

    lab_val=val['Label']
    lab_test=test['Label']
    llaves=np.concatenate([ids_val,ids_test])
    clases=np.concatenate([lab_val,lab_test])

    num=0
    for llave in llaves: 
        clase=clases[num]
        vector=np.load('../../../BaS_Original/ECML/Original/'+str(llave)+'.npy')
        
        norm=np.linalg.norm(vector)
        vector= vector / norm
        index_embeddings.append(num+5+macro_augmented.shape[0])
        lab_str_embeddings.append(clase)
        K_list_ext.append(vector)

    K_list_new= np.asarray(K_list_ext, dtype='float32')
    K_list_new=torch.from_numpy(K_list_new).float().to(device)
    class_weights=np.asarray(class_weights)
    pesos = torch.from_numpy(class_weights).float()
    print (pesos)

    ###################################### TRANSFORMER ###############################
    V = 4
    criterion = FocalLoss(weights=pesos)
    model = make_model_concat(4, N=2,d_model=768, d_ff=128, h=4, dropout=0.35)
    model_opt = NoamOpt(model.src_embed[0].d_model, 1, 500, torch.optim.Adam(model.parameters(), lr=0, betas=(0.9, 0.98), eps=1e-5))

    for epoch in range(40):  #40
        model.train()
        DATA=data_gen(bs, 'Train', 5, new_matrix)
        loss_train, acc_train,fma_train, f_none, cm_train=run_epoch(DATA, model, SimpleLossComputeFL(criterion, model_opt), 'Train')
        
        model.eval()
        loss_val, acc_val,fma_val, f_val_none, cm_val=run_epoch(data_gen(bs, 'Val', 5, new_matrix), model, SimpleLossComputeFL(criterion, None),'Val')
        print ("Epoch",epoch, "\tacc_val:",acc_val, "\tF-macro_val:",fma_val)
    
    model.eval()
    print ("Testing run #",trans)
    predicciones = run_epoch(data_gen(bs, 'Test', 5, new_matrix), model, SimpleLossComputeFL(criterion, None),'Test')
    predicciones=np.concatenate(predicciones, axis=-1)
    
    glo_acc=accuracy_score(etiq_t, predicciones[:-21])
    glo_fno=f1_score(etiq_t,predicciones[:-21], average=None)
    glo_fma=f1_score(etiq_t,predicciones[:-21], average='macro')

    glo_cm=confusion_matrix(etiq_t, predicciones[:-21])

    plot_confusion_matrix(glo_cm,["NonH","IndirectH","PhysicalH","SexualH"],"0.15 - Transformer 40-e Harassment")
    global_accs.append(glo_acc)
    global_fnones.append(glo_fno)
    global_fmacros.append(glo_fma)
    global_cms.append(glo_cm)

    print("Test_ acc:",glo_acc) 
    print("Test_ f1 none:",glo_fno) 
    print("Test_ f1 macro:",glo_fma) 

    label=[['Text', 'm1', 'm2','m3','m4','m5']]
    for layer in range(2):
        fig, axs = plt.subplots(1,4, figsize=(20, 10))
        print ("Encoder Layer Attention head", layer)
        for head in range(4):
            matriz_attn=model.encoder.layers[layer].self_attn.attn[0,head].data
            dict_attn_enc[str(layer)+str(head)].append(matriz_attn)
            sns.heatmap(matriz_attn, xticklabels=label[0], yticklabels=label[0],
                        vmin=0.0, vmax=1.0, linewidths=.5, cmap="Blues", cbar=False, square=True, ax=axs[head]) #, annot=False,cbar_kws={"orientation": "horizontal","pad": 0.25})
        plt.show()
# Out:
# Entrenando Run # 1
# Memory usage         :  12.30 MB
# GC collected objects : 756042
# Memory usage         :  12.30 MB
# GC collected objects : 0
# Memory usage         :  12.30 MB
# tensor([1., 1., 1., 1.])
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.5732, dtype=torch.float64) 	F-macro_val: tensor(0.1812, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.5695, dtype=torch.float64) 	F-macro_val: tensor(0.1801, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.5728, dtype=torch.float64) 	F-macro_val: tensor(0.1810, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.5709, dtype=torch.float64) 	F-macro_val: tensor(0.1808, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.5718, dtype=torch.float64) 	F-macro_val: tensor(0.1809, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.5723, dtype=torch.float64) 	F-macro_val: tensor(0.1810, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.5718, dtype=torch.float64) 	F-macro_val: tensor(0.1810, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.5704, dtype=torch.float64) 	F-macro_val: tensor(0.1807, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.5714, dtype=torch.float64) 	F-macro_val: tensor(0.1808, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.5700, dtype=torch.float64) 	F-macro_val: tensor(0.1803, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.5704, dtype=torch.float64) 	F-macro_val: tensor(0.1804, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.5709, dtype=torch.float64) 	F-macro_val: tensor(0.1806, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.5718, dtype=torch.float64) 	F-macro_val: tensor(0.1809, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.5732, dtype=torch.float64) 	F-macro_val: tensor(0.1811, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.5700, dtype=torch.float64) 	F-macro_val: tensor(0.1804, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.5709, dtype=torch.float64) 	F-macro_val: tensor(0.1806, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.5714, dtype=torch.float64) 	F-macro_val: tensor(0.1810, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.5714, dtype=torch.float64) 	F-macro_val: tensor(0.1808, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.5723, dtype=torch.float64) 	F-macro_val: tensor(0.1809, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.5737, dtype=torch.float64) 	F-macro_val: tensor(0.1813, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.5714, dtype=torch.float64) 	F-macro_val: tensor(0.1809, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.5700, dtype=torch.float64) 	F-macro_val: tensor(0.1806, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.5695, dtype=torch.float64) 	F-macro_val: tensor(0.1805, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.5700, dtype=torch.float64) 	F-macro_val: tensor(0.1805, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.5718, dtype=torch.float64) 	F-macro_val: tensor(0.1808, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.5732, dtype=torch.float64) 	F-macro_val: tensor(0.1813, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.5742, dtype=torch.float64) 	F-macro_val: tensor(0.1811, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.5718, dtype=torch.float64) 	F-macro_val: tensor(0.1810, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.5700, dtype=torch.float64) 	F-macro_val: tensor(0.1805, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.5704, dtype=torch.float64) 	F-macro_val: tensor(0.1808, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.5704, dtype=torch.float64) 	F-macro_val: tensor(0.1809, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.5681, dtype=torch.float64) 	F-macro_val: tensor(0.1801, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.5695, dtype=torch.float64) 	F-macro_val: tensor(0.1803, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.5709, dtype=torch.float64) 	F-macro_val: tensor(0.1808, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.5709, dtype=torch.float64) 	F-macro_val: tensor(0.1806, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.5709, dtype=torch.float64) 	F-macro_val: tensor(0.1809, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.5690, dtype=torch.float64) 	F-macro_val: tensor(0.1802, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.5709, dtype=torch.float64) 	F-macro_val: tensor(0.1808, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.5709, dtype=torch.float64) 	F-macro_val: tensor(0.1806, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.5718, dtype=torch.float64) 	F-macro_val: tensor(0.1809, dtype=torch.float64)
# Testing run # 1
# SE TUVIERON QUE REPETIR 21 EJEMPLOS
# Test_ acc: 0.7790861987753179
# Test_ f1 none: [0.87049905 0.         0.05128205 0.61297539]
# Test_ f1 macro: 0.3836891238032559
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 2
# Memory usage         :  12.30 MB
# GC collected objects : 756050
# Memory usage         :  12.30 MB
# GC collected objects : 0
# Memory usage         :  12.30 MB
# tensor([1., 1., 1., 1.])
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.4981, dtype=torch.float64) 	F-macro_val: tensor(0.1651, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.4986, dtype=torch.float64) 	F-macro_val: tensor(0.1653, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.4678, dtype=torch.float64) 	F-macro_val: tensor(0.1584, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.4869, dtype=torch.float64) 	F-macro_val: tensor(0.1623, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.5233, dtype=torch.float64) 	F-macro_val: tensor(0.1708, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.5005, dtype=torch.float64) 	F-macro_val: tensor(0.1663, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.5009, dtype=torch.float64) 	F-macro_val: tensor(0.1652, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.5219, dtype=torch.float64) 	F-macro_val: tensor(0.1707, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.5215, dtype=torch.float64) 	F-macro_val: tensor(0.1701, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.5238, dtype=torch.float64) 	F-macro_val: tensor(0.1707, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.5215, dtype=torch.float64) 	F-macro_val: tensor(0.1697, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.5210, dtype=torch.float64) 	F-macro_val: tensor(0.1700, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.5233, dtype=torch.float64) 	F-macro_val: tensor(0.1709, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.5289, dtype=torch.float64) 	F-macro_val: tensor(0.1716, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.5331, dtype=torch.float64) 	F-macro_val: tensor(0.1725, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.5317, dtype=torch.float64) 	F-macro_val: tensor(0.1725, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.5322, dtype=torch.float64) 	F-macro_val: tensor(0.1727, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.5308, dtype=torch.float64) 	F-macro_val: tensor(0.1722, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.5308, dtype=torch.float64) 	F-macro_val: tensor(0.1723, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.5294, dtype=torch.float64) 	F-macro_val: tensor(0.1722, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.5331, dtype=torch.float64) 	F-macro_val: tensor(0.1731, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.5303, dtype=torch.float64) 	F-macro_val: tensor(0.1721, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.5299, dtype=torch.float64) 	F-macro_val: tensor(0.1718, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.5294, dtype=torch.float64) 	F-macro_val: tensor(0.1719, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.5289, dtype=torch.float64) 	F-macro_val: tensor(0.1717, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.5303, dtype=torch.float64) 	F-macro_val: tensor(0.1722, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.5312, dtype=torch.float64) 	F-macro_val: tensor(0.1728, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.5299, dtype=torch.float64) 	F-macro_val: tensor(0.1723, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.5285, dtype=torch.float64) 	F-macro_val: tensor(0.1717, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.5308, dtype=torch.float64) 	F-macro_val: tensor(0.1725, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.5294, dtype=torch.float64) 	F-macro_val: tensor(0.1718, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.5303, dtype=torch.float64) 	F-macro_val: tensor(0.1720, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.5294, dtype=torch.float64) 	F-macro_val: tensor(0.1723, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.5312, dtype=torch.float64) 	F-macro_val: tensor(0.1723, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.5312, dtype=torch.float64) 	F-macro_val: tensor(0.1721, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.5308, dtype=torch.float64) 	F-macro_val: tensor(0.1722, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.5317, dtype=torch.float64) 	F-macro_val: tensor(0.1723, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.5308, dtype=torch.float64) 	F-macro_val: tensor(0.1723, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.5308, dtype=torch.float64) 	F-macro_val: tensor(0.1725, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.5308, dtype=torch.float64) 	F-macro_val: tensor(0.1721, dtype=torch.float64)
# Testing run # 2
# SE TUVIERON QUE REPETIR 21 EJEMPLOS
# Test_ acc: 0.7597739048516251
# Test_ f1 none: [0.85241648 0.03539823 0.09638554 0.60599793]
# Test_ f1 macro: 0.39754954536546644
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 3
# Memory usage         :  12.30 MB
# GC collected objects : 756050
# Memory usage         :  12.30 MB
# GC collected objects : 0
# Memory usage         :  12.30 MB
# tensor([1., 1., 1., 1.])
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.4044, dtype=torch.float64) 	F-macro_val: tensor(0.1423, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.4011, dtype=torch.float64) 	F-macro_val: tensor(0.1416, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.4062, dtype=torch.float64) 	F-macro_val: tensor(0.1430, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.4958, dtype=torch.float64) 	F-macro_val: tensor(0.1646, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.4953, dtype=torch.float64) 	F-macro_val: tensor(0.1645, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.4972, dtype=torch.float64) 	F-macro_val: tensor(0.1648, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.4939, dtype=torch.float64) 	F-macro_val: tensor(0.1640, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.4967, dtype=torch.float64) 	F-macro_val: tensor(0.1648, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.4963, dtype=torch.float64) 	F-macro_val: tensor(0.1648, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.4953, dtype=torch.float64) 	F-macro_val: tensor(0.1645, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.4963, dtype=torch.float64) 	F-macro_val: tensor(0.1645, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.4958, dtype=torch.float64) 	F-macro_val: tensor(0.1647, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.4949, dtype=torch.float64) 	F-macro_val: tensor(0.1643, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.4049, dtype=torch.float64) 	F-macro_val: tensor(0.1427, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.4958, dtype=torch.float64) 	F-macro_val: tensor(0.1644, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.4953, dtype=torch.float64) 	F-macro_val: tensor(0.1642, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.4958, dtype=torch.float64) 	F-macro_val: tensor(0.1644, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.4963, dtype=torch.float64) 	F-macro_val: tensor(0.1645, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.4963, dtype=torch.float64) 	F-macro_val: tensor(0.1645, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.4939, dtype=torch.float64) 	F-macro_val: tensor(0.1639, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.4949, dtype=torch.float64) 	F-macro_val: tensor(0.1647, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.4949, dtype=torch.float64) 	F-macro_val: tensor(0.1643, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.4958, dtype=torch.float64) 	F-macro_val: tensor(0.1644, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.4944, dtype=torch.float64) 	F-macro_val: tensor(0.1642, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.4967, dtype=torch.float64) 	F-macro_val: tensor(0.1651, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.4958, dtype=torch.float64) 	F-macro_val: tensor(0.1647, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.4944, dtype=torch.float64) 	F-macro_val: tensor(0.1641, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.4953, dtype=torch.float64) 	F-macro_val: tensor(0.1644, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.4935, dtype=torch.float64) 	F-macro_val: tensor(0.1641, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.4939, dtype=torch.float64) 	F-macro_val: tensor(0.1644, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.4958, dtype=torch.float64) 	F-macro_val: tensor(0.1642, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.4949, dtype=torch.float64) 	F-macro_val: tensor(0.1648, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.4939, dtype=torch.float64) 	F-macro_val: tensor(0.1639, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.4944, dtype=torch.float64) 	F-macro_val: tensor(0.1644, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.4953, dtype=torch.float64) 	F-macro_val: tensor(0.1644, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.4958, dtype=torch.float64) 	F-macro_val: tensor(0.1645, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.4958, dtype=torch.float64) 	F-macro_val: tensor(0.1644, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.4953, dtype=torch.float64) 	F-macro_val: tensor(0.1642, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.4939, dtype=torch.float64) 	F-macro_val: tensor(0.1639, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.4944, dtype=torch.float64) 	F-macro_val: tensor(0.1645, dtype=torch.float64)
# Testing run # 3
# SE TUVIERON QUE REPETIR 21 EJEMPLOS
# Test_ acc: 0.731040979745643
# Test_ f1 none: [0.83272607 0.03603604 0.11627907 0.5592233 ]
# Test_ f1 macro: 0.3860661187522166
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 4
# Memory usage         :  12.30 MB
# GC collected objects : 756050
# Memory usage         :  12.30 MB
# GC collected objects : 0
# Memory usage         :  12.30 MB
# tensor([1., 1., 1., 1.])
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.4660, dtype=torch.float64) 	F-macro_val: tensor(0.1579, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.4762, dtype=torch.float64) 	F-macro_val: tensor(0.1601, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.4762, dtype=torch.float64) 	F-macro_val: tensor(0.1599, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.4725, dtype=torch.float64) 	F-macro_val: tensor(0.1593, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.4776, dtype=torch.float64) 	F-macro_val: tensor(0.1604, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.4650, dtype=torch.float64) 	F-macro_val: tensor(0.1577, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.4729, dtype=torch.float64) 	F-macro_val: tensor(0.1592, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.4748, dtype=torch.float64) 	F-macro_val: tensor(0.1598, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.4771, dtype=torch.float64) 	F-macro_val: tensor(0.1604, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.4753, dtype=torch.float64) 	F-macro_val: tensor(0.1596, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.4767, dtype=torch.float64) 	F-macro_val: tensor(0.1603, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.4771, dtype=torch.float64) 	F-macro_val: tensor(0.1604, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.4771, dtype=torch.float64) 	F-macro_val: tensor(0.1607, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.4757, dtype=torch.float64) 	F-macro_val: tensor(0.1600, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.4781, dtype=torch.float64) 	F-macro_val: tensor(0.1606, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.4753, dtype=torch.float64) 	F-macro_val: tensor(0.1598, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.4762, dtype=torch.float64) 	F-macro_val: tensor(0.1599, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.4776, dtype=torch.float64) 	F-macro_val: tensor(0.1604, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.4767, dtype=torch.float64) 	F-macro_val: tensor(0.1604, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.4757, dtype=torch.float64) 	F-macro_val: tensor(0.1598, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.4743, dtype=torch.float64) 	F-macro_val: tensor(0.1595, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.4762, dtype=torch.float64) 	F-macro_val: tensor(0.1600, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.4771, dtype=torch.float64) 	F-macro_val: tensor(0.1605, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.4762, dtype=torch.float64) 	F-macro_val: tensor(0.1600, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.4776, dtype=torch.float64) 	F-macro_val: tensor(0.1608, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.4790, dtype=torch.float64) 	F-macro_val: tensor(0.1608, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.4776, dtype=torch.float64) 	F-macro_val: tensor(0.1605, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.4785, dtype=torch.float64) 	F-macro_val: tensor(0.1609, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.4753, dtype=torch.float64) 	F-macro_val: tensor(0.1597, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.4785, dtype=torch.float64) 	F-macro_val: tensor(0.1606, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.4781, dtype=torch.float64) 	F-macro_val: tensor(0.1608, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.4776, dtype=torch.float64) 	F-macro_val: tensor(0.1605, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.4776, dtype=torch.float64) 	F-macro_val: tensor(0.1606, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.4781, dtype=torch.float64) 	F-macro_val: tensor(0.1606, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.4767, dtype=torch.float64) 	F-macro_val: tensor(0.1604, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.4785, dtype=torch.float64) 	F-macro_val: tensor(0.1605, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.4762, dtype=torch.float64) 	F-macro_val: tensor(0.1601, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.4771, dtype=torch.float64) 	F-macro_val: tensor(0.1604, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.4776, dtype=torch.float64) 	F-macro_val: tensor(0.1605, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.4771, dtype=torch.float64) 	F-macro_val: tensor(0.1606, dtype=torch.float64)
# Testing run # 4
# SE TUVIERON QUE REPETIR 21 EJEMPLOS
# Test_ acc: 0.7027790861987753
# Test_ f1 none: [0.80910326 0.         0.13186813 0.53490481]
# Test_ f1 macro: 0.3689690494536899
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 5
# Memory usage         :  12.30 MB
# GC collected objects : 756050
# Memory usage         :  12.30 MB
# GC collected objects : 0
# Memory usage         :  12.30 MB
# tensor([1., 1., 1., 1.])
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.5140, dtype=torch.float64) 	F-macro_val: tensor(0.1685, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.4580, dtype=torch.float64) 	F-macro_val: tensor(0.1558, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.5140, dtype=torch.float64) 	F-macro_val: tensor(0.1687, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.5117, dtype=torch.float64) 	F-macro_val: tensor(0.1683, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.5135, dtype=torch.float64) 	F-macro_val: tensor(0.1685, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.5149, dtype=torch.float64) 	F-macro_val: tensor(0.1688, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.5191, dtype=torch.float64) 	F-macro_val: tensor(0.1695, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.5159, dtype=torch.float64) 	F-macro_val: tensor(0.1689, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.5201, dtype=torch.float64) 	F-macro_val: tensor(0.1696, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.5215, dtype=torch.float64) 	F-macro_val: tensor(0.1699, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.5187, dtype=torch.float64) 	F-macro_val: tensor(0.1693, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.5191, dtype=torch.float64) 	F-macro_val: tensor(0.1696, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.5210, dtype=torch.float64) 	F-macro_val: tensor(0.1703, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.5196, dtype=torch.float64) 	F-macro_val: tensor(0.1700, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.5163, dtype=torch.float64) 	F-macro_val: tensor(0.1696, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.5205, dtype=torch.float64) 	F-macro_val: tensor(0.1703, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.5210, dtype=torch.float64) 	F-macro_val: tensor(0.1700, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.5145, dtype=torch.float64) 	F-macro_val: tensor(0.1684, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.5126, dtype=torch.float64) 	F-macro_val: tensor(0.1683, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.5205, dtype=torch.float64) 	F-macro_val: tensor(0.1700, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.5145, dtype=torch.float64) 	F-macro_val: tensor(0.1690, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.5149, dtype=torch.float64) 	F-macro_val: tensor(0.1690, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.5149, dtype=torch.float64) 	F-macro_val: tensor(0.1687, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.5131, dtype=torch.float64) 	F-macro_val: tensor(0.1687, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.5168, dtype=torch.float64) 	F-macro_val: tensor(0.1693, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.5187, dtype=torch.float64) 	F-macro_val: tensor(0.1696, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.5145, dtype=torch.float64) 	F-macro_val: tensor(0.1686, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.5149, dtype=torch.float64) 	F-macro_val: tensor(0.1690, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.5191, dtype=torch.float64) 	F-macro_val: tensor(0.1693, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.5205, dtype=torch.float64) 	F-macro_val: tensor(0.1699, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.5163, dtype=torch.float64) 	F-macro_val: tensor(0.1693, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.5140, dtype=torch.float64) 	F-macro_val: tensor(0.1687, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.5191, dtype=torch.float64) 	F-macro_val: tensor(0.1696, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.5215, dtype=torch.float64) 	F-macro_val: tensor(0.1706, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.5196, dtype=torch.float64) 	F-macro_val: tensor(0.1696, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.5215, dtype=torch.float64) 	F-macro_val: tensor(0.1703, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.5163, dtype=torch.float64) 	F-macro_val: tensor(0.1689, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.5154, dtype=torch.float64) 	F-macro_val: tensor(0.1690, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.5205, dtype=torch.float64) 	F-macro_val: tensor(0.1704, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.5191, dtype=torch.float64) 	F-macro_val: tensor(0.1696, dtype=torch.float64)
# Testing run # 5
# SE TUVIERON QUE REPETIR 21 EJEMPLOS
# Test_ acc: 0.7588318417333961
# Test_ f1 none: [0.85585295 0.         0.07228916 0.58909853]
# Test_ f1 macro: 0.3793101599455856
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1

# %%
print ("Acc Test:", np.mean(np.asarray(global_accs)))
print ("F-macro Test:", np.mean(np.asarray(global_fmacros)))
nh=np.mean(np.asarray(global_fnones)[:,0])
ih=np.mean(np.asarray(global_fnones)[:,1])
ph=np.mean(np.asarray(global_fnones)[:,2])
sh=np.mean(np.asarray(global_fnones)[:,3])
print ("N-I-P-S:", nh,ih,ph,sh)
# Out:
# Acc Test: 0.7463024022609515
# F-macro Test: 0.38311679946404287
# N-I-P-S: 0.8441195619308541 0.014286853224906321 0.09362079034256114 0.58043999235785

# %%
global_fnones
# Out:
# [array([0.87049905, 0.        , 0.05128205, 0.61297539]),
#  array([0.85241648, 0.03539823, 0.09638554, 0.60599793]),
#  array([0.83272607, 0.03603604, 0.11627907, 0.5592233 ]),
#  array([0.80910326, 0.        , 0.13186813, 0.53490481]),
#  array([0.85585295, 0.        , 0.07228916, 0.58909853])]

# %%
m_temp=np.zeros((4,4))
for m in global_cms:
    #print ("matrix",m, np.asarray(m, dtype='int').shape)
    m_temp+=np.asarray(m)
    #print ("\nLa suma dio:", m_temp)
m_temp
# Out:
# array([[6.467e+03, 1.000e+01, 1.900e+01, 1.509e+03],
#        [3.850e+02, 4.000e+00, 1.000e+00, 1.400e+02],
#        [1.890e+02, 3.000e+00, 2.000e+01, 1.680e+02],
#        [2.670e+02, 1.000e+00, 1.000e+00, 1.431e+03]])

# %%
plot_confusion_matrix(glo_cm,["NonH","IndirectH","PhysicalH","SexualH"],"Transformer 0.15", cmap='Purples')

# %%
label=[['Text', 'm1', 'm2','m3','m4','m5']]
for layer in range(2):
    fig, axs = plt.subplots(1,4, figsize=(20, 10))
    print ("Encoder Layer Attention head Promedio", layer)
    for head in range(4):
        at=np.zeros((6,6))
        matriz_attn= dict_attn_enc[str(layer)+str(head)]  #lista de 5 corridas en cada pos
        for m in matriz_attn:
            at+=m.numpy()
        sns.heatmap(at/5., xticklabels=label[0], yticklabels=label[0],
                    vmin=0.0, vmax=1.0, linewidths=.5, cmap="Purples", cbar=False, square=True, ax=axs[head]) #, annot=False,cbar_kws={"orientation": "horizontal","pad": 0.25})
    plt.show()
# Out:
# Encoder Layer Attention head Promedio 0
# Encoder Layer Attention head Promedio 1

# %%
for h in range(2):
    for hy in range(4):
        to_mean=dict_attn_enc[str(h)+str(hy)]
        at=np.zeros((6,6))
        for m in to_mean:
            at+=m.numpy()  
        print (np.asarray(at))
        global_attn.append(at/5.)
        
global_attn
# Out:
# [[0.41272995 0.86209567 1.07374416 0.72886155 1.08711607 0.83545255]
#  [1.34657671 0.29257266 0.68516082 0.86390032 0.69314677 1.11864264]
#  [1.8943996  0.25624167 0.53179799 1.08758135 0.51240445 0.71757497]
#  [1.05216751 0.69220368 1.05762044 0.69701696 0.58396975 0.91702157]
#  [1.44832253 0.56299054 0.81116741 0.95707952 0.37335482 0.84708514]
#  [1.19551603 0.76172203 0.97487904 0.7317976  0.47405684 0.86202839]]
# [[1.0528817  0.84266222 0.49809582 1.09302337 0.52759188 0.98574496]
#  [1.04095114 0.47513431 0.62766609 1.26937205 0.79696489 0.78991145]
#  [0.93840966 0.59370844 0.5512956  0.83632848 1.04830333 1.03195448]
#  [0.91315381 1.17729521 1.19073576 0.43792471 0.89680803 0.38408256]
#  [1.19097143 0.80831055 1.09360664 0.88876046 0.48558218 0.53276875]
#  [0.96904822 1.13228213 1.08599505 0.81853009 0.65297619 0.34116823]]
# [[1.43884769 0.41709919 0.65179072 0.55399266 1.08807305 0.85019677]
#  [0.7839687  0.91952788 0.61174139 0.8962869  1.19049098 0.59798415]
#  array([[0.18402878, 0.173741  , 0.12218931, 0.2091284 , 0.11680241,
#          0.19411012],
#         [0.15418151, 0.1071068 , 0.14226383, 0.1958357 , 0.13919102,
#          0.26142114],
#         [0.1367375 , 0.12522137, 0.14481183, 0.21963481, 0.14040071,
#          0.23319378],
#         [0.20316779, 0.13903452, 0.13062753, 0.15025528, 0.14995242,
#          0.22696243],
#         [0.18385878, 0.13924537, 0.15749754, 0.18811738, 0.12392006,
#          0.20736085],
#         [0.21489063, 0.14371397, 0.15464766, 0.16605646, 0.13040855,
#          0.19028273]]),
#  array([[0.15989514, 0.1516243 , 0.10223514, 0.23837672, 0.18240867,
#          0.16546005],
#         [0.1917767 , 0.1258312 , 0.08385121, 0.23807043, 0.17538459,
#          0.18508591],
#         [0.17555915, 0.1314989 , 0.07957939, 0.23310852, 0.18760314,
#          0.19265088],
#         [0.21841455, 0.1823888 , 0.16753337, 0.16792995, 0.14852276,
#          0.11521059],
#         [0.19045572, 0.17681239, 0.14138329, 0.20463995, 0.13315593,
#          0.1535527 ],
#         [0.2285045 , 0.16757605, 0.15180959, 0.15338236, 0.15992351,
#          0.138804  ]])]

# %%
np.save("ECML_Attn_prom_0-15_newCleaner.npy", global_attn)

# %% [markdown]
# # 0.5

# %%
global_accs=[]
global_fnones=[]
global_fmacros=[]
global_cms=[]
global_attn=[]
dict_attn_enc={'00':[], '01':[], '02':[], '03':[], '10':[], '11':[], '12':[], '13':[]}
  
prob=0.5

for trans in range(1,6): 
    print ("Entrenando Run #", trans)
    macro_augmented= np.load('../../../new_data_augmented/harassment/Aumento_'+str(trans)+'-run_'+str(prob)+'_app1_Top1.npy', allow_pickle=True)

    ids_train=macro_augmented[:,0]
    #ids_train=[str(ide)+'_train_0' for ide in ids_train]
    ids_val=val['tweet_id']
    ids_val=[str(ide)+'_val_0' for ide in ids_val]
    ids_test=test['tweet_id']
    ids_test=[str(ide)+'_test_0' for ide in ids_test]
    
    sentences=macro_augmented[:,1]
    labels_train=macro_augmented[:,2]
    class_weights= [1.0, 1.0, 1.0, 1.0]
        
    n_labels=np.array(labels_train.copy())
    y_train=to_categorical(n_labels,num_classes=4)
    
    input_ids = []
    for sent in sentences:
        encoded_sent = tokenizer_loaded.encode(list(sent),add_special_tokens = False)    
        input_ids.append(encoded_sent)
    input_ids = pad_sequences(input_ids, maxlen=MAX_LEN, dtype="long", 
                              value=0, truncating="post", padding="post")
        
    shape=np.asarray(input_ids).shape
    x_train=np.zeros((shape[0], shape[1], 768))
    j=0
    for in_id in input_ids:
        x_train[j]=M_BERT_space[in_id]
        j+=1
    
    cnn1 = load_model('../../../new_data_augmented/harassment_baselines/'+str(prob)+'/cnn1_'+str(trans)+'-exec_app1_Top_1.h5')
    cnn2 = load_model('../../../new_data_augmented/harassment_baselines/'+str(prob)+'/cnn2_'+str(trans)+'-exec_app1_Top_1.h5')
    rnn1 = load_model('../../../new_data_augmented/harassment_baselines/'+str(prob)+'/rnn1_'+str(trans)+'-exec_app1_Top_1.h5')
    rnn2 = load_model('../../../new_data_augmented/harassment_baselines/'+str(prob)+'/rnn2_'+str(trans)+'-exec_app1_Top_1.h5')
    rnn3 = load_model('../../../new_data_augmented/harassment_baselines/'+str(prob)+'/rnn3_'+str(trans)+'-exec_app1_Top_1.h5')

    list_models=['cnn1', 'cnn2', 'rnn1', 'rnn2', 'rnn3']
    index_models=np.arange(5)
    dict_models=dict((key, value) for (key, value) in zip(index_models,list_models))
    modelos=[cnn1, cnn2, rnn1, rnn2, rnn3]
    ind=np.arange(5)
    dict_trainedModel=dict((key, value) for (key, value) in zip(ind,modelos))

    bs=32
    predicciones_all=[]
    predicciones_all_val=[]
    predicciones_all_test=[]

    for i in dict_trainedModel.keys(): 
        a_evaluar=dict_models[i]
        predicciones_all.append(dict_trainedModel[i].predict(x_train, batch_size=bs))
    for i in dict_trainedModel.keys(): 
        a_evaluar=dict_models[i]
        predicciones_all_val.append(dict_trainedModel[i].predict(x_val, batch_size=bs))
    for i in dict_trainedModel.keys(): 
        a_evaluar=dict_models[i]
        predicciones_all_test.append(dict_trainedModel[i].predict(x_test, batch_size=bs))

    matrix=np.asarray(predicciones_all)
    matrix_val=np.asarray(predicciones_all_val)
    matrix_test=np.asarray(predicciones_all_test)
    new_matrix=np.concatenate([matrix,matrix_val,matrix_test], axis=1)
    
    mem()
    print('GC collected objects : %d' % gc.collect())
    mem()
    
    gc.collect()    
    
    print('GC collected objects : %d' % gc.collect())
    mem()
    
    ####### eliminar modelos de memoria
    keras.backend.clear_session()
    gc.collect()  
    torch.cuda.empty_cache()
    
    espacio=[np.ones(768)]
    Ks=np.load("../../../../BERTransformer/Orthogonals_768.npy")
    random=np.random.randint(Ks.shape[0], size=4)
    K_list=Ks[random]
    K_list_ext=espacio+list(K_list)
    index_embeddings=[0,1,2,3,4]
    lab_str_embeddings=['','','','','']
    
    j=0
    for sen in sentences:
        lab=labels_train[j]
        folder=dict_cl[lab]
        ide=ids_train[j]  #creado en data augmentation
        
        if type(sen)==list:
            #recuperar en generados por folder y prob             
            vector=np.load('../../../BaS_Original/ECML/'+str(prob)+'/'+str(trans)+'/'+folder+'/'+str(ide)+'_train_1.npy')
        else:
            #recuperar de original
            vector=np.load('../../../BaS_Original/ECML/Original/'+str(ide)+'_train_0.npy')
        
        norm=np.linalg.norm(vector)
        vector= vector / norm
        index_embeddings.append(j+5)
        lab_str_embeddings.append(folder)
        K_list_ext.append(vector)
        j+=1

    lab_val=val['Label']
    lab_test=test['Label']
    llaves=np.concatenate([ids_val,ids_test])
    clases=np.concatenate([lab_val,lab_test])

    num=0
    for llave in llaves: 
        clase=clases[num]
        vector=np.load('../../../BaS_Original/ECML/Original/'+str(llave)+'.npy')
        
        norm=np.linalg.norm(vector)
        vector= vector / norm
        index_embeddings.append(num+5+macro_augmented.shape[0])
        lab_str_embeddings.append(clase)
        K_list_ext.append(vector)

    K_list_new= np.asarray(K_list_ext, dtype='float32')
    K_list_new=torch.from_numpy(K_list_new).float().to(device)
    class_weights=np.asarray(class_weights)
    pesos = torch.from_numpy(class_weights).float()
    print (pesos)

    ###################################### TRANSFORMER ###############################
    V = 4
    criterion = FocalLoss(weights=pesos)
    model = make_model_concat(4, N=2,d_model=768, d_ff=128, h=4, dropout=0.35)
    model_opt = NoamOpt(model.src_embed[0].d_model, 1, 500, torch.optim.Adam(model.parameters(), lr=0, betas=(0.9, 0.98), eps=1e-5))

    for epoch in range(40):  #40
        model.train()
        DATA=data_gen(bs, 'Train', 5, new_matrix)
        loss_train, acc_train,fma_train, f_none, cm_train=run_epoch(DATA, model, SimpleLossComputeFL(criterion, model_opt), 'Train')
        
        model.eval()
        loss_val, acc_val,fma_val, f_val_none, cm_val=run_epoch(data_gen(bs, 'Val', 5, new_matrix), model, SimpleLossComputeFL(criterion, None),'Val')
        print ("Epoch",epoch, "\tacc_val:",acc_val, "\tF-macro_val:",fma_val)
    
    model.eval()
    print ("Testing run #",trans)
    predicciones = run_epoch(data_gen(bs, 'Test', 5, new_matrix), model, SimpleLossComputeFL(criterion, None),'Test')
    predicciones=np.concatenate(predicciones, axis=-1)
    
    glo_acc=accuracy_score(etiq_t, predicciones[:-21])
    glo_fno=f1_score(etiq_t,predicciones[:-21], average=None)
    glo_fma=f1_score(etiq_t,predicciones[:-21], average='macro')

    glo_cm=confusion_matrix(etiq_t, predicciones[:-21])

    plot_confusion_matrix(glo_cm,["NonH","IndirectH","PhysicalH","SexualH"],"0.15 - Transformer 40-e Harassment")
    global_accs.append(glo_acc)
    global_fnones.append(glo_fno)
    global_fmacros.append(glo_fma)
    global_cms.append(glo_cm)

    print("Test_ acc:",glo_acc) 
    print("Test_ f1 none:",glo_fno) 
    print("Test_ f1 macro:",glo_fma) 

    label=[['Text', 'm1', 'm2','m3','m4','m5']]
    for layer in range(2):
        fig, axs = plt.subplots(1,4, figsize=(20, 10))
        print ("Encoder Layer Attention head", layer)
        for head in range(4):
            matriz_attn=model.encoder.layers[layer].self_attn.attn[0,head].data
            dict_attn_enc[str(layer)+str(head)].append(matriz_attn)
            sns.heatmap(matriz_attn, xticklabels=label[0], yticklabels=label[0],
                        vmin=0.0, vmax=1.0, linewidths=.5, cmap="Blues", cbar=False, square=True, ax=axs[head]) #, annot=False,cbar_kws={"orientation": "horizontal","pad": 0.25})
        plt.show()
# Out:
# Entrenando Run # 1
# Memory usage         :  12.30 MB
# GC collected objects : 756050
# Memory usage         :  12.30 MB
# GC collected objects : 0
# Memory usage         :  12.30 MB
# tensor([1., 1., 1., 1.])
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.3871, dtype=torch.float64) 	F-macro_val: tensor(0.1385, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.4534, dtype=torch.float64) 	F-macro_val: tensor(0.1546, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.4496, dtype=torch.float64) 	F-macro_val: tensor(0.1541, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.3895, dtype=torch.float64) 	F-macro_val: tensor(0.1388, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.4510, dtype=torch.float64) 	F-macro_val: tensor(0.1543, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.4529, dtype=torch.float64) 	F-macro_val: tensor(0.1549, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.4534, dtype=torch.float64) 	F-macro_val: tensor(0.1546, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.4529, dtype=torch.float64) 	F-macro_val: tensor(0.1545, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.4529, dtype=torch.float64) 	F-macro_val: tensor(0.1547, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.4543, dtype=torch.float64) 	F-macro_val: tensor(0.1551, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.3871, dtype=torch.float64) 	F-macro_val: tensor(0.1382, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.4524, dtype=torch.float64) 	F-macro_val: tensor(0.1546, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.4524, dtype=torch.float64) 	F-macro_val: tensor(0.1544, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.4534, dtype=torch.float64) 	F-macro_val: tensor(0.1551, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.4538, dtype=torch.float64) 	F-macro_val: tensor(0.1547, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.4534, dtype=torch.float64) 	F-macro_val: tensor(0.1546, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.4534, dtype=torch.float64) 	F-macro_val: tensor(0.1541, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.4543, dtype=torch.float64) 	F-macro_val: tensor(0.1548, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.4515, dtype=torch.float64) 	F-macro_val: tensor(0.1541, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.4538, dtype=torch.float64) 	F-macro_val: tensor(0.1545, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.4543, dtype=torch.float64) 	F-macro_val: tensor(0.1547, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.4529, dtype=torch.float64) 	F-macro_val: tensor(0.1544, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.4529, dtype=torch.float64) 	F-macro_val: tensor(0.1547, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.4548, dtype=torch.float64) 	F-macro_val: tensor(0.1544, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.4515, dtype=torch.float64) 	F-macro_val: tensor(0.1545, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.4548, dtype=torch.float64) 	F-macro_val: tensor(0.1551, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.4534, dtype=torch.float64) 	F-macro_val: tensor(0.1552, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.4529, dtype=torch.float64) 	F-macro_val: tensor(0.1547, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.4515, dtype=torch.float64) 	F-macro_val: tensor(0.1545, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.4520, dtype=torch.float64) 	F-macro_val: tensor(0.1544, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.4515, dtype=torch.float64) 	F-macro_val: tensor(0.1542, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.4520, dtype=torch.float64) 	F-macro_val: tensor(0.1543, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.4534, dtype=torch.float64) 	F-macro_val: tensor(0.1546, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.4543, dtype=torch.float64) 	F-macro_val: tensor(0.1550, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.4543, dtype=torch.float64) 	F-macro_val: tensor(0.1547, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.4529, dtype=torch.float64) 	F-macro_val: tensor(0.1545, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.4543, dtype=torch.float64) 	F-macro_val: tensor(0.1548, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.4548, dtype=torch.float64) 	F-macro_val: tensor(0.1549, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.4529, dtype=torch.float64) 	F-macro_val: tensor(0.1546, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.4524, dtype=torch.float64) 	F-macro_val: tensor(0.1539, dtype=torch.float64)
# Testing run # 1
# SE TUVIERON QUE REPETIR 21 EJEMPLOS
# Test_ acc: 0.6792275082430523
# Test_ f1 none: [0.7926915  0.03508772 0.09756098 0.51162791]
# Test_ f1 macro: 0.3592420246806032
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 2
# Memory usage         :  12.30 MB
# GC collected objects : 756050
# Memory usage         :  12.30 MB
# GC collected objects : 0
# Memory usage         :  12.30 MB
# tensor([1., 1., 1., 1.])
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.4272, dtype=torch.float64) 	F-macro_val: tensor(0.1486, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.5009, dtype=torch.float64) 	F-macro_val: tensor(0.1658, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.4398, dtype=torch.float64) 	F-macro_val: tensor(0.1512, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.5056, dtype=torch.float64) 	F-macro_val: tensor(0.1666, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.5079, dtype=torch.float64) 	F-macro_val: tensor(0.1672, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.5023, dtype=torch.float64) 	F-macro_val: tensor(0.1664, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.5075, dtype=torch.float64) 	F-macro_val: tensor(0.1672, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.5056, dtype=torch.float64) 	F-macro_val: tensor(0.1671, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.5051, dtype=torch.float64) 	F-macro_val: tensor(0.1668, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.5065, dtype=torch.float64) 	F-macro_val: tensor(0.1668, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.5061, dtype=torch.float64) 	F-macro_val: tensor(0.1670, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.5061, dtype=torch.float64) 	F-macro_val: tensor(0.1668, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.5056, dtype=torch.float64) 	F-macro_val: tensor(0.1669, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.5065, dtype=torch.float64) 	F-macro_val: tensor(0.1670, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.5042, dtype=torch.float64) 	F-macro_val: tensor(0.1661, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.5051, dtype=torch.float64) 	F-macro_val: tensor(0.1660, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.5075, dtype=torch.float64) 	F-macro_val: tensor(0.1674, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.5061, dtype=torch.float64) 	F-macro_val: tensor(0.1670, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.5065, dtype=torch.float64) 	F-macro_val: tensor(0.1671, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.5056, dtype=torch.float64) 	F-macro_val: tensor(0.1669, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.5056, dtype=torch.float64) 	F-macro_val: tensor(0.1668, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.5051, dtype=torch.float64) 	F-macro_val: tensor(0.1667, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.5047, dtype=torch.float64) 	F-macro_val: tensor(0.1670, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.5079, dtype=torch.float64) 	F-macro_val: tensor(0.1672, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.5065, dtype=torch.float64) 	F-macro_val: tensor(0.1671, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.5070, dtype=torch.float64) 	F-macro_val: tensor(0.1669, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.5047, dtype=torch.float64) 	F-macro_val: tensor(0.1667, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.5047, dtype=torch.float64) 	F-macro_val: tensor(0.1663, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.5079, dtype=torch.float64) 	F-macro_val: tensor(0.1673, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.5075, dtype=torch.float64) 	F-macro_val: tensor(0.1674, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.5070, dtype=torch.float64) 	F-macro_val: tensor(0.1670, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.5056, dtype=torch.float64) 	F-macro_val: tensor(0.1668, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.5051, dtype=torch.float64) 	F-macro_val: tensor(0.1668, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.5079, dtype=torch.float64) 	F-macro_val: tensor(0.1671, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.5065, dtype=torch.float64) 	F-macro_val: tensor(0.1671, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.5061, dtype=torch.float64) 	F-macro_val: tensor(0.1668, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.5056, dtype=torch.float64) 	F-macro_val: tensor(0.1666, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.5065, dtype=torch.float64) 	F-macro_val: tensor(0.1671, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.5075, dtype=torch.float64) 	F-macro_val: tensor(0.1672, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.5070, dtype=torch.float64) 	F-macro_val: tensor(0.1671, dtype=torch.float64)
# Testing run # 2
# SE TUVIERON QUE REPETIR 21 EJEMPLOS
# Test_ acc: 0.7305699481865285
# Test_ f1 none: [0.83349819 0.01834862 0.04761905 0.55686275]
# Test_ f1 macro: 0.3640821507960529
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 3
# Memory usage         :  12.30 MB
# GC collected objects : 756050
# Memory usage         :  12.30 MB
# GC collected objects : 0
# Memory usage         :  12.30 MB
# tensor([1., 1., 1., 1.])
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.5014, dtype=torch.float64) 	F-macro_val: tensor(0.1656, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.5028, dtype=torch.float64) 	F-macro_val: tensor(0.1662, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.5042, dtype=torch.float64) 	F-macro_val: tensor(0.1664, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.5028, dtype=torch.float64) 	F-macro_val: tensor(0.1663, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.5037, dtype=torch.float64) 	F-macro_val: tensor(0.1665, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.5028, dtype=torch.float64) 	F-macro_val: tensor(0.1665, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.5019, dtype=torch.float64) 	F-macro_val: tensor(0.1662, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.5023, dtype=torch.float64) 	F-macro_val: tensor(0.1661, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.4384, dtype=torch.float64) 	F-macro_val: tensor(0.1514, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.4389, dtype=torch.float64) 	F-macro_val: tensor(0.1510, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.4380, dtype=torch.float64) 	F-macro_val: tensor(0.1512, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.4394, dtype=torch.float64) 	F-macro_val: tensor(0.1509, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.5028, dtype=torch.float64) 	F-macro_val: tensor(0.1663, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.5014, dtype=torch.float64) 	F-macro_val: tensor(0.1658, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.5028, dtype=torch.float64) 	F-macro_val: tensor(0.1665, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.4366, dtype=torch.float64) 	F-macro_val: tensor(0.1505, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.5037, dtype=torch.float64) 	F-macro_val: tensor(0.1664, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.4384, dtype=torch.float64) 	F-macro_val: tensor(0.1509, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.5028, dtype=torch.float64) 	F-macro_val: tensor(0.1663, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.5028, dtype=torch.float64) 	F-macro_val: tensor(0.1660, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.5037, dtype=torch.float64) 	F-macro_val: tensor(0.1663, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.5023, dtype=torch.float64) 	F-macro_val: tensor(0.1661, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.5042, dtype=torch.float64) 	F-macro_val: tensor(0.1664, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.5033, dtype=torch.float64) 	F-macro_val: tensor(0.1664, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.5009, dtype=torch.float64) 	F-macro_val: tensor(0.1656, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.5019, dtype=torch.float64) 	F-macro_val: tensor(0.1661, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.5033, dtype=torch.float64) 	F-macro_val: tensor(0.1666, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.4398, dtype=torch.float64) 	F-macro_val: tensor(0.1515, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.5033, dtype=torch.float64) 	F-macro_val: tensor(0.1660, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.5033, dtype=torch.float64) 	F-macro_val: tensor(0.1661, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.5037, dtype=torch.float64) 	F-macro_val: tensor(0.1667, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.5019, dtype=torch.float64) 	F-macro_val: tensor(0.1661, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.5033, dtype=torch.float64) 	F-macro_val: tensor(0.1664, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.5023, dtype=torch.float64) 	F-macro_val: tensor(0.1663, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.5005, dtype=torch.float64) 	F-macro_val: tensor(0.1655, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.5028, dtype=torch.float64) 	F-macro_val: tensor(0.1661, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.5023, dtype=torch.float64) 	F-macro_val: tensor(0.1659, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.5033, dtype=torch.float64) 	F-macro_val: tensor(0.1666, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.4384, dtype=torch.float64) 	F-macro_val: tensor(0.1513, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.5023, dtype=torch.float64) 	F-macro_val: tensor(0.1661, dtype=torch.float64)
# Testing run # 3
# SE TUVIERON QUE REPETIR 21 EJEMPLOS
# Test_ acc: 0.7263306641544983
# Test_ f1 none: [0.8312812  0.03669725 0.14285714 0.54932302]
# Test_ f1 macro: 0.39003965149375414
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 4
# Memory usage         :  12.30 MB
# GC collected objects : 756050
# Memory usage         :  12.30 MB
# GC collected objects : 0
# Memory usage         :  12.30 MB
# tensor([1., 1., 1., 1.])
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.5084, dtype=torch.float64) 	F-macro_val: tensor(0.1675, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.5089, dtype=torch.float64) 	F-macro_val: tensor(0.1675, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.5065, dtype=torch.float64) 	F-macro_val: tensor(0.1666, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.5084, dtype=torch.float64) 	F-macro_val: tensor(0.1675, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.5075, dtype=torch.float64) 	F-macro_val: tensor(0.1672, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.5107, dtype=torch.float64) 	F-macro_val: tensor(0.1679, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.5121, dtype=torch.float64) 	F-macro_val: tensor(0.1679, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.5075, dtype=torch.float64) 	F-macro_val: tensor(0.1671, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.5107, dtype=torch.float64) 	F-macro_val: tensor(0.1678, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.5103, dtype=torch.float64) 	F-macro_val: tensor(0.1679, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.5084, dtype=torch.float64) 	F-macro_val: tensor(0.1674, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.5093, dtype=torch.float64) 	F-macro_val: tensor(0.1675, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.5079, dtype=torch.float64) 	F-macro_val: tensor(0.1673, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.5075, dtype=torch.float64) 	F-macro_val: tensor(0.1673, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.5093, dtype=torch.float64) 	F-macro_val: tensor(0.1676, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.5089, dtype=torch.float64) 	F-macro_val: tensor(0.1674, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.5093, dtype=torch.float64) 	F-macro_val: tensor(0.1675, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.5098, dtype=torch.float64) 	F-macro_val: tensor(0.1672, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.5089, dtype=torch.float64) 	F-macro_val: tensor(0.1678, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.5098, dtype=torch.float64) 	F-macro_val: tensor(0.1677, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.5084, dtype=torch.float64) 	F-macro_val: tensor(0.1671, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.5079, dtype=torch.float64) 	F-macro_val: tensor(0.1674, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.5084, dtype=torch.float64) 	F-macro_val: tensor(0.1675, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.5089, dtype=torch.float64) 	F-macro_val: tensor(0.1673, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.5107, dtype=torch.float64) 	F-macro_val: tensor(0.1681, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.5121, dtype=torch.float64) 	F-macro_val: tensor(0.1679, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.5089, dtype=torch.float64) 	F-macro_val: tensor(0.1677, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.5089, dtype=torch.float64) 	F-macro_val: tensor(0.1674, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.5084, dtype=torch.float64) 	F-macro_val: tensor(0.1672, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.5093, dtype=torch.float64) 	F-macro_val: tensor(0.1678, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.5089, dtype=torch.float64) 	F-macro_val: tensor(0.1674, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.5084, dtype=torch.float64) 	F-macro_val: tensor(0.1673, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.5084, dtype=torch.float64) 	F-macro_val: tensor(0.1671, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.5098, dtype=torch.float64) 	F-macro_val: tensor(0.1677, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.5065, dtype=torch.float64) 	F-macro_val: tensor(0.1672, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.5103, dtype=torch.float64) 	F-macro_val: tensor(0.1677, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.5098, dtype=torch.float64) 	F-macro_val: tensor(0.1679, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.5079, dtype=torch.float64) 	F-macro_val: tensor(0.1675, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.5089, dtype=torch.float64) 	F-macro_val: tensor(0.1677, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.5089, dtype=torch.float64) 	F-macro_val: tensor(0.1674, dtype=torch.float64)
# Testing run # 4
# SE TUVIERON QUE REPETIR 21 EJEMPLOS
# Test_ acc: 0.7362223268959021
# Test_ f1 none: [0.83864542 0.01834862 0.11111111 0.56811594]
# Test_ f1 macro: 0.38405527383000027
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 5
# Memory usage         :  12.30 MB
# GC collected objects : 756050
# Memory usage         :  12.30 MB
# GC collected objects : 0
# Memory usage         :  12.30 MB
# tensor([1., 1., 1., 1.])
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.5555, dtype=torch.float64) 	F-macro_val: tensor(0.1775, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.5121, dtype=torch.float64) 	F-macro_val: tensor(0.1680, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.5112, dtype=torch.float64) 	F-macro_val: tensor(0.1680, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.5117, dtype=torch.float64) 	F-macro_val: tensor(0.1681, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.5121, dtype=torch.float64) 	F-macro_val: tensor(0.1682, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.5117, dtype=torch.float64) 	F-macro_val: tensor(0.1681, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.5107, dtype=torch.float64) 	F-macro_val: tensor(0.1679, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.5121, dtype=torch.float64) 	F-macro_val: tensor(0.1684, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.5103, dtype=torch.float64) 	F-macro_val: tensor(0.1680, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.5117, dtype=torch.float64) 	F-macro_val: tensor(0.1681, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.5121, dtype=torch.float64) 	F-macro_val: tensor(0.1680, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.5117, dtype=torch.float64) 	F-macro_val: tensor(0.1681, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.5103, dtype=torch.float64) 	F-macro_val: tensor(0.1677, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.5117, dtype=torch.float64) 	F-macro_val: tensor(0.1680, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.5117, dtype=torch.float64) 	F-macro_val: tensor(0.1683, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.5126, dtype=torch.float64) 	F-macro_val: tensor(0.1684, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.5117, dtype=torch.float64) 	F-macro_val: tensor(0.1681, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.5112, dtype=torch.float64) 	F-macro_val: tensor(0.1683, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.5117, dtype=torch.float64) 	F-macro_val: tensor(0.1682, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.5131, dtype=torch.float64) 	F-macro_val: tensor(0.1685, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.5107, dtype=torch.float64) 	F-macro_val: tensor(0.1680, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.5093, dtype=torch.float64) 	F-macro_val: tensor(0.1675, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.5107, dtype=torch.float64) 	F-macro_val: tensor(0.1680, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.5117, dtype=torch.float64) 	F-macro_val: tensor(0.1680, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.5117, dtype=torch.float64) 	F-macro_val: tensor(0.1681, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.5117, dtype=torch.float64) 	F-macro_val: tensor(0.1681, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.5121, dtype=torch.float64) 	F-macro_val: tensor(0.1683, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.5121, dtype=torch.float64) 	F-macro_val: tensor(0.1685, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.5121, dtype=torch.float64) 	F-macro_val: tensor(0.1682, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.5112, dtype=torch.float64) 	F-macro_val: tensor(0.1679, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.5121, dtype=torch.float64) 	F-macro_val: tensor(0.1675, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.5126, dtype=torch.float64) 	F-macro_val: tensor(0.1684, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.5103, dtype=torch.float64) 	F-macro_val: tensor(0.1678, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.5121, dtype=torch.float64) 	F-macro_val: tensor(0.1684, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.5112, dtype=torch.float64) 	F-macro_val: tensor(0.1679, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.5121, dtype=torch.float64) 	F-macro_val: tensor(0.1685, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.5121, dtype=torch.float64) 	F-macro_val: tensor(0.1683, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.5093, dtype=torch.float64) 	F-macro_val: tensor(0.1680, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.5107, dtype=torch.float64) 	F-macro_val: tensor(0.1679, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.5112, dtype=torch.float64) 	F-macro_val: tensor(0.1679, dtype=torch.float64)
# Testing run # 5
# SE TUVIERON QUE REPETIR 21 EJEMPLOS
# Test_ acc: 0.7272727272727273
# Test_ f1 none: [0.82873296 0.04958678 0.09876543 0.56123433]
# Test_ f1 macro: 0.3845798737976868
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1

# %%
print ("Acc Test:", np.mean(np.asarray(global_accs)))
print ("F-macro Test:", np.mean(np.asarray(global_fmacros)))
nh=np.mean(np.asarray(global_fnones)[:,0])
ih=np.mean(np.asarray(global_fnones)[:,1])
ph=np.mean(np.asarray(global_fnones)[:,2])
sh=np.mean(np.asarray(global_fnones)[:,3])
print ("N-I-P-S:", nh,ih,ph,sh)
# Out:
# Acc Test: 0.7199246349505417
# F-macro Test: 0.3763997949196195
# N-I-P-S: 0.8249698512433173 0.03161379831411876 0.09958274185916462 0.5494327882618771

# %%
global_fnones
# Out:
# [array([0.7926915 , 0.03508772, 0.09756098, 0.51162791]),
#  array([0.83349819, 0.01834862, 0.04761905, 0.55686275]),
#  array([0.8312812 , 0.03669725, 0.14285714, 0.54932302]),
#  array([0.83864542, 0.01834862, 0.11111111, 0.56811594]),
#  array([0.82873296, 0.04958678, 0.09876543, 0.56123433])]

# %%
m_temp=np.zeros((4,4))
for m in global_cms:
    #print ("matrix",m, np.asarray(m, dtype='int').shape)
    m_temp+=np.asarray(m)
    #print ("\nLa suma dio:", m_temp)
m_temp
# Out:
# array([[6.150e+03, 1.500e+01, 2.900e+01, 1.811e+03],
#        [3.420e+02, 9.000e+00, 0.000e+00, 1.790e+02],
#        [1.750e+02, 4.000e+00, 2.200e+01, 1.790e+02],
#        [2.310e+02, 4.000e+00, 4.000e+00, 1.461e+03]])

# %%
plot_confusion_matrix(glo_cm,["NonH","IndirectH","PhysicalH","SexualH"],"Transformer 0.5", cmap='Purples')

# %%
label=[['Text', 'm1', 'm2','m3','m4','m5']]
for layer in range(2):
    fig, axs = plt.subplots(1,4, figsize=(20, 10))
    print ("Encoder Layer Attention head Promedio", layer)
    for head in range(4):
        at=np.zeros((6,6))
        matriz_attn= dict_attn_enc[str(layer)+str(head)]  #lista de 5 corridas en cada pos
        for m in matriz_attn:
            at+=m.numpy()
        sns.heatmap(at/5., xticklabels=label[0], yticklabels=label[0],
                    vmin=0.0, vmax=1.0, linewidths=.5, cmap="Purples", cbar=False, square=True, ax=axs[head]) #, annot=False,cbar_kws={"orientation": "horizontal","pad": 0.25})
    plt.show()
# Out:
# Encoder Layer Attention head Promedio 0
# Encoder Layer Attention head Promedio 1

# %%
for h in range(2):
    for hy in range(4):
        to_mean=dict_attn_enc[str(h)+str(hy)]
        at=np.zeros((6,6))
        for m in to_mean:
            at+=m.numpy()  
        print (np.asarray(at))
        global_attn.append(at/5.)
        
global_attn
# Out:
# [[0.66025936 0.90427893 0.54975192 1.02026906 0.96100682 0.90443394]
#  [1.22452012 1.50322344 0.61750969 0.41375436 0.82669681 0.41429561]
#  [0.87746521 1.22069157 0.90668422 0.53478519 0.85564173 0.60473211]
#  [1.32853606 0.80043434 0.84635533 0.89206416 0.82178233 0.31082793]
#  [1.33339336 1.10951818 0.53528119 0.79952403 0.56653388 0.65574938]
#  [1.40118822 0.63455538 0.50353924 0.81271237 0.98509541 0.66290927]]
# [[1.02152682 0.60303785 0.64838163 0.83534456 0.95802511 0.93368398]
#  [1.0250277  0.92718416 1.08265454 0.70757518 0.67381226 0.58374625]
#  [1.63239104 1.01481886 0.62712958 0.70817515 0.40449538 0.61298998]
#  [0.96946117 0.67594664 1.01486823 1.13643712 0.62668461 0.57660236]
#  [0.41680068 1.12134223 0.91986103 0.72161473 0.69032191 1.13005945]
#  [0.95637772 0.75406118 0.71057019 0.6048057  1.07726305 0.89692222]]
# [[0.50668003 0.64693791 0.88804107 0.79014837 1.23281278 0.93537984]
#  [0.69128595 0.63297568 0.28635274 0.71995011 1.32891083 1.34052458]
#  [0.79257723 0.41948345 0.46317973 0.79520587 1.46639562 1.06315797]
#  [1.3704896  0.63958756 0.57648321 1.18977521 0.48670948 0.73695507]
#  [0.90729467 0.47319199 0.47754606 1.29771146 0.8975991  0.94665688]
#  array([[0.20430536, 0.12060757, 0.12967633, 0.16706891, 0.19160502,
#          0.1867368 ],
#         [0.20500554, 0.18543683, 0.21653091, 0.14151504, 0.13476245,
#          0.11674925],
#         [0.32647821, 0.20296377, 0.12542592, 0.14163503, 0.08089908,
#          0.122598  ],
#         [0.19389223, 0.13518933, 0.20297365, 0.22728742, 0.12533692,
#          0.11532047],
#         [0.08336014, 0.22426845, 0.18397221, 0.14432295, 0.13806438,
#          0.22601189],
#         [0.19127554, 0.15081224, 0.14211404, 0.12096114, 0.21545261,
#          0.17938444]]),
#  array([[0.10133601, 0.12938758, 0.17760821, 0.15802967, 0.24656256,
#          0.18707597],
#         [0.13825719, 0.12659514, 0.05727055, 0.14399002, 0.26578217,
#          0.26810492],
#         [0.15851545, 0.08389669, 0.09263595, 0.15904117, 0.29327912,
#          0.21263159],
#         [0.27409792, 0.12791751, 0.11529664, 0.23795504, 0.0973419 ,
#          0.14739101],
#         [0.18145893, 0.0946384 , 0.09550921, 0.25954229, 0.17951982,
#          0.18933138],
#         [0.1446899 , 0.15213148, 0.14509922, 0.20469385, 0.19828397,
#          0.1551016 ]]),
#  array([[0.09951021, 0.18259183, 0.19866279, 0.12965064, 0.12681002,
#          0.26277454],
#         [0.13250232, 0.18629209, 0.19094262, 0.11724985, 0.22973383,
#          0.14327928],
#         [0.10182063, 0.27295318, 0.17875439, 0.1279355 , 0.17551832,
#          0.14301797],
#         [0.13162266, 0.23284608, 0.17476737, 0.15666991, 0.11058705,
#          0.19350691],
#         [0.12122088, 0.25073247, 0.1145064 , 0.16505646, 0.15389642,
#          0.19458735],
#         [0.07961858, 0.13893441, 0.11424208, 0.13309739, 0.25237367,
#          0.28173385]]),
#  array([[0.14091181, 0.14143405, 0.16489366, 0.16011231, 0.20069429,
#          0.19195389],
#         [0.17334361, 0.18669252, 0.14267347, 0.13902318, 0.15142819,
#          0.20683902],
#         [0.19547968, 0.15341583, 0.11859253, 0.1487926 , 0.12786405,
#          0.25585527],
#         [0.17782379, 0.18185813, 0.13658196, 0.16666841, 0.14131129,
#          0.19575644],
#         [0.17026131, 0.14769903, 0.11339252, 0.16023311, 0.17584086,
#          0.23257316],
#         [0.11714679, 0.17035618, 0.16571176, 0.12448086, 0.20017346,
#          0.22213094]]),
#  array([[0.17566465, 0.19598415, 0.13004109, 0.18277155, 0.10929341,
#          0.20624516],
#         [0.16397718, 0.14949555, 0.12288704, 0.16522551, 0.14715487,
#          0.25125988],
#         [0.15374913, 0.19102045, 0.11715278, 0.15419175, 0.14853981,
#          0.23534606],
#         [0.1725024 , 0.16250106, 0.13626333, 0.15444357, 0.1493277 ,
#          0.22496193],
#         [0.14368074, 0.19143217, 0.12468373, 0.16228315, 0.14625433,
#          0.23166588],
#         [0.14639084, 0.16765085, 0.18746511, 0.1331942 , 0.15769581,
#          0.20760317]]),
#  array([[0.14989412, 0.21424471, 0.19177707, 0.15915223, 0.12973353,
#          0.15519833],
#         [0.22467657, 0.20941212, 0.12397936, 0.15743343, 0.08403708,
#          0.20046149],
#         [0.2263398 , 0.19281292, 0.13731716, 0.15870281, 0.08532247,
#          0.19950483],
#         [0.20190212, 0.19877639, 0.10633341, 0.18057472, 0.11694849,
#          0.19546488],
#         [0.26039848, 0.18461164, 0.11706345, 0.17074198, 0.09714332,
#          0.17004115],
#         [0.23199131, 0.23643219, 0.16886861, 0.11897528, 0.07249377,
#          0.17123884]]),
#  array([[0.17661669, 0.15958321, 0.11340094, 0.21611918, 0.17721804,
#          0.15706193],
#         [0.14958276, 0.18051139, 0.13970281, 0.13757431, 0.21234784,
#          0.18028092],
#         [0.12064076, 0.15546693, 0.12251014, 0.18518374, 0.20758598,
#          0.20861247],
#         [0.15997052, 0.14602829, 0.1085587 , 0.20631953, 0.17790054,
#          0.20122245],
#         [0.12057585, 0.16061935, 0.14009339, 0.16471593, 0.21357443,
#          0.20042112],
#         [0.17032236, 0.17915783, 0.09528984, 0.17900135, 0.18483075,
#          0.19139792]])]

# %%
np.save("ECML_Attn_prom_0-5_newCleaner.npy", global_attn)

# %% [markdown]
# ## 0.85

# %%
global_accs=[]
global_fnones=[]
global_fmacros=[]
global_cms=[]
global_attn=[]
dict_attn_enc={'00':[], '01':[], '02':[], '03':[], '10':[], '11':[], '12':[], '13':[]}
  
prob=0.85

for trans in range(1,6): 
    print ("Entrenando Run #", trans)
    macro_augmented= np.load('../../../new_data_augmented/harassment/Aumento_'+str(trans)+'-run_'+str(prob)+'_app1_Top1.npy', allow_pickle=True)

    ids_train=macro_augmented[:,0]
    #ids_train=[str(ide)+'_train_0' for ide in ids_train]
    ids_val=val['tweet_id']
    ids_val=[str(ide)+'_val_0' for ide in ids_val]
    ids_test=test['tweet_id']
    ids_test=[str(ide)+'_test_0' for ide in ids_test]
    
    sentences=macro_augmented[:,1]
    labels_train=macro_augmented[:,2]
    class_weights= [1.0, 1.0, 1.0, 1.0]
        
    n_labels=np.array(labels_train.copy())
    y_train=to_categorical(n_labels,num_classes=4)
    
    input_ids = []
    for sent in sentences:
        encoded_sent = tokenizer_loaded.encode(list(sent),add_special_tokens = False)    
        input_ids.append(encoded_sent)
    input_ids = pad_sequences(input_ids, maxlen=MAX_LEN, dtype="long", 
                              value=0, truncating="post", padding="post")
        
    shape=np.asarray(input_ids).shape
    x_train=np.zeros((shape[0], shape[1], 768))
    j=0
    for in_id in input_ids:
        x_train[j]=M_BERT_space[in_id]
        j+=1
    
    cnn1 = load_model('../../../new_data_augmented/harassment_baselines/'+str(prob)+'/cnn1_'+str(trans)+'-exec_app1_Top_1.h5')
    cnn2 = load_model('../../../new_data_augmented/harassment_baselines/'+str(prob)+'/cnn2_'+str(trans)+'-exec_app1_Top_1.h5')
    rnn1 = load_model('../../../new_data_augmented/harassment_baselines/'+str(prob)+'/rnn1_'+str(trans)+'-exec_app1_Top_1.h5')
    rnn2 = load_model('../../../new_data_augmented/harassment_baselines/'+str(prob)+'/rnn2_'+str(trans)+'-exec_app1_Top_1.h5')
    rnn3 = load_model('../../../new_data_augmented/harassment_baselines/'+str(prob)+'/rnn3_'+str(trans)+'-exec_app1_Top_1.h5')

    list_models=['cnn1', 'cnn2', 'rnn1', 'rnn2', 'rnn3']
    index_models=np.arange(5)
    dict_models=dict((key, value) for (key, value) in zip(index_models,list_models))
    modelos=[cnn1, cnn2, rnn1, rnn2, rnn3]
    ind=np.arange(5)
    dict_trainedModel=dict((key, value) for (key, value) in zip(ind,modelos))

    bs=32
    predicciones_all=[]
    predicciones_all_val=[]
    predicciones_all_test=[]

    for i in dict_trainedModel.keys(): 
        a_evaluar=dict_models[i]
        predicciones_all.append(dict_trainedModel[i].predict(x_train, batch_size=bs))
    for i in dict_trainedModel.keys(): 
        a_evaluar=dict_models[i]
        predicciones_all_val.append(dict_trainedModel[i].predict(x_val, batch_size=bs))
    for i in dict_trainedModel.keys(): 
        a_evaluar=dict_models[i]
        predicciones_all_test.append(dict_trainedModel[i].predict(x_test, batch_size=bs))

    matrix=np.asarray(predicciones_all)
    matrix_val=np.asarray(predicciones_all_val)
    matrix_test=np.asarray(predicciones_all_test)
    new_matrix=np.concatenate([matrix,matrix_val,matrix_test], axis=1)
    
    mem()
    print('GC collected objects : %d' % gc.collect())
    mem()
    
    gc.collect()    
    
    print('GC collected objects : %d' % gc.collect())
    mem()
    
    ####### eliminar modelos de memoria
    keras.backend.clear_session()
    gc.collect()  
    torch.cuda.empty_cache()
    
    espacio=[np.ones(768)]
    Ks=np.load("../../../../BERTransformer/Orthogonals_768.npy")
    random=np.random.randint(Ks.shape[0], size=4)
    K_list=Ks[random]
    K_list_ext=espacio+list(K_list)
    index_embeddings=[0,1,2,3,4]
    lab_str_embeddings=['','','','','']
    
    j=0
    for sen in sentences:
        lab=labels_train[j]
        folder=dict_cl[lab]
        ide=ids_train[j]  #creado en data augmentation
        
        if type(sen)==list:
            #recuperar en generados por folder y prob             
            vector=np.load('../../../BaS_Original/ECML/'+str(prob)+'/'+str(trans)+'/'+folder+'/'+str(ide)+'_train_1.npy')
        else:
            #recuperar de original
            vector=np.load('../../../BaS_Original/ECML/Original/'+str(ide)+'_train_0.npy')
        
        norm=np.linalg.norm(vector)
        vector= vector / norm
        index_embeddings.append(j+5)
        lab_str_embeddings.append(folder)
        K_list_ext.append(vector)
        j+=1

    lab_val=val['Label']
    lab_test=test['Label']
    llaves=np.concatenate([ids_val,ids_test])
    clases=np.concatenate([lab_val,lab_test])

    num=0
    for llave in llaves: 
        clase=clases[num]
        vector=np.load('../../../BaS_Original/ECML/Original/'+str(llave)+'.npy')
        
        norm=np.linalg.norm(vector)
        vector= vector / norm
        index_embeddings.append(num+5+macro_augmented.shape[0])
        lab_str_embeddings.append(clase)
        K_list_ext.append(vector)

    K_list_new= np.asarray(K_list_ext, dtype='float32')
    K_list_new=torch.from_numpy(K_list_new).float().to(device)
    class_weights=np.asarray(class_weights)
    pesos = torch.from_numpy(class_weights).float()
    print (pesos)

    ###################################### TRANSFORMER ###############################
    V = 4
    criterion = FocalLoss(weights=pesos)
    model = make_model_concat(4, N=2,d_model=768, d_ff=128, h=4, dropout=0.35)
    model_opt = NoamOpt(model.src_embed[0].d_model, 1, 500, torch.optim.Adam(model.parameters(), lr=0, betas=(0.9, 0.98), eps=1e-5))

    for epoch in range(40):  #40
        model.train()
        DATA=data_gen(bs, 'Train', 5, new_matrix)
        loss_train, acc_train,fma_train, f_none, cm_train=run_epoch(DATA, model, SimpleLossComputeFL(criterion, model_opt), 'Train')
        
        model.eval()
        loss_val, acc_val,fma_val, f_val_none, cm_val=run_epoch(data_gen(bs, 'Val', 5, new_matrix), model, SimpleLossComputeFL(criterion, None),'Val')
        print ("Epoch",epoch, "\tacc_val:",acc_val, "\tF-macro_val:",fma_val)
    
    model.eval()
    print ("Testing run #",trans)
    predicciones = run_epoch(data_gen(bs, 'Test', 5, new_matrix), model, SimpleLossComputeFL(criterion, None),'Test')
    predicciones=np.concatenate(predicciones, axis=-1)
    
    glo_acc=accuracy_score(etiq_t, predicciones[:-21])
    glo_fno=f1_score(etiq_t,predicciones[:-21], average=None)
    glo_fma=f1_score(etiq_t,predicciones[:-21], average='macro')

    glo_cm=confusion_matrix(etiq_t, predicciones[:-21])

    plot_confusion_matrix(glo_cm,["NonH","IndirectH","PhysicalH","SexualH"],"0.15 - Transformer 40-e Harassment")
    global_accs.append(glo_acc)
    global_fnones.append(glo_fno)
    global_fmacros.append(glo_fma)
    global_cms.append(glo_cm)

    print("Test_ acc:",glo_acc) 
    print("Test_ f1 none:",glo_fno) 
    print("Test_ f1 macro:",glo_fma) 

    label=[['Text', 'm1', 'm2','m3','m4','m5']]
    for layer in range(2):
        fig, axs = plt.subplots(1,4, figsize=(20, 10))
        print ("Encoder Layer Attention head", layer)
        for head in range(4):
            matriz_attn=model.encoder.layers[layer].self_attn.attn[0,head].data
            dict_attn_enc[str(layer)+str(head)].append(matriz_attn)
            sns.heatmap(matriz_attn, xticklabels=label[0], yticklabels=label[0],
                        vmin=0.0, vmax=1.0, linewidths=.5, cmap="Blues", cbar=False, square=True, ax=axs[head]) #, annot=False,cbar_kws={"orientation": "horizontal","pad": 0.25})
        plt.show()
# Out:
# Entrenando Run # 1
# Memory usage         :  12.30 MB
# GC collected objects : 756050
# Memory usage         :  12.30 MB
# GC collected objects : 0
# Memory usage         :  12.30 MB
# tensor([1., 1., 1., 1.])
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.4240, dtype=torch.float64) 	F-macro_val: tensor(0.1476, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.4240, dtype=torch.float64) 	F-macro_val: tensor(0.1476, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.4277, dtype=torch.float64) 	F-macro_val: tensor(0.1484, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.5070, dtype=torch.float64) 	F-macro_val: tensor(0.1672, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.5075, dtype=torch.float64) 	F-macro_val: tensor(0.1670, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.4366, dtype=torch.float64) 	F-macro_val: tensor(0.1505, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.5079, dtype=torch.float64) 	F-macro_val: tensor(0.1672, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.5079, dtype=torch.float64) 	F-macro_val: tensor(0.1674, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.5056, dtype=torch.float64) 	F-macro_val: tensor(0.1664, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.5070, dtype=torch.float64) 	F-macro_val: tensor(0.1671, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.5065, dtype=torch.float64) 	F-macro_val: tensor(0.1669, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.4333, dtype=torch.float64) 	F-macro_val: tensor(0.1498, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.5075, dtype=torch.float64) 	F-macro_val: tensor(0.1672, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.4389, dtype=torch.float64) 	F-macro_val: tensor(0.1513, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.4249, dtype=torch.float64) 	F-macro_val: tensor(0.1478, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.4394, dtype=torch.float64) 	F-macro_val: tensor(0.1511, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.4384, dtype=torch.float64) 	F-macro_val: tensor(0.1513, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.4370, dtype=torch.float64) 	F-macro_val: tensor(0.1510, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.4375, dtype=torch.float64) 	F-macro_val: tensor(0.1509, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.4370, dtype=torch.float64) 	F-macro_val: tensor(0.1508, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.4370, dtype=torch.float64) 	F-macro_val: tensor(0.1511, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.4380, dtype=torch.float64) 	F-macro_val: tensor(0.1510, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.4338, dtype=torch.float64) 	F-macro_val: tensor(0.1502, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.4380, dtype=torch.float64) 	F-macro_val: tensor(0.1512, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.4394, dtype=torch.float64) 	F-macro_val: tensor(0.1516, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.5089, dtype=torch.float64) 	F-macro_val: tensor(0.1672, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.5075, dtype=torch.float64) 	F-macro_val: tensor(0.1669, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.5079, dtype=torch.float64) 	F-macro_val: tensor(0.1676, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.5070, dtype=torch.float64) 	F-macro_val: tensor(0.1671, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.5079, dtype=torch.float64) 	F-macro_val: tensor(0.1675, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.5093, dtype=torch.float64) 	F-macro_val: tensor(0.1677, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.5075, dtype=torch.float64) 	F-macro_val: tensor(0.1672, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.5042, dtype=torch.float64) 	F-macro_val: tensor(0.1667, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.5070, dtype=torch.float64) 	F-macro_val: tensor(0.1672, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.5084, dtype=torch.float64) 	F-macro_val: tensor(0.1676, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.5098, dtype=torch.float64) 	F-macro_val: tensor(0.1675, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.5098, dtype=torch.float64) 	F-macro_val: tensor(0.1674, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.5084, dtype=torch.float64) 	F-macro_val: tensor(0.1674, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.5075, dtype=torch.float64) 	F-macro_val: tensor(0.1667, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.5089, dtype=torch.float64) 	F-macro_val: tensor(0.1673, dtype=torch.float64)
# Testing run # 1
# SE TUVIERON QUE REPETIR 21 EJEMPLOS
# Test_ acc: 0.7093735280263778
# Test_ f1 none: [0.81546811 0.15625    0.11666667 0.54666667]
# Test_ f1 macro: 0.4087628618272275
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 2
# Memory usage         :  12.30 MB
# GC collected objects : 756050
# Memory usage         :  12.30 MB
# GC collected objects : 0
# Memory usage         :  12.30 MB
# tensor([1., 1., 1., 1.])
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.3960, dtype=torch.float64) 	F-macro_val: tensor(0.1401, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.4016, dtype=torch.float64) 	F-macro_val: tensor(0.1418, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.4156, dtype=torch.float64) 	F-macro_val: tensor(0.1451, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.4151, dtype=torch.float64) 	F-macro_val: tensor(0.1452, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.4151, dtype=torch.float64) 	F-macro_val: tensor(0.1457, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.4137, dtype=torch.float64) 	F-macro_val: tensor(0.1448, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.4151, dtype=torch.float64) 	F-macro_val: tensor(0.1458, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.4072, dtype=torch.float64) 	F-macro_val: tensor(0.1429, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.4011, dtype=torch.float64) 	F-macro_val: tensor(0.1409, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.4011, dtype=torch.float64) 	F-macro_val: tensor(0.1417, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.4081, dtype=torch.float64) 	F-macro_val: tensor(0.1435, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.4151, dtype=torch.float64) 	F-macro_val: tensor(0.1453, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.4156, dtype=torch.float64) 	F-macro_val: tensor(0.1456, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.4151, dtype=torch.float64) 	F-macro_val: tensor(0.1447, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.4160, dtype=torch.float64) 	F-macro_val: tensor(0.1457, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.4142, dtype=torch.float64) 	F-macro_val: tensor(0.1453, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.4165, dtype=torch.float64) 	F-macro_val: tensor(0.1455, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.4151, dtype=torch.float64) 	F-macro_val: tensor(0.1453, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.4165, dtype=torch.float64) 	F-macro_val: tensor(0.1455, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.4142, dtype=torch.float64) 	F-macro_val: tensor(0.1451, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.4156, dtype=torch.float64) 	F-macro_val: tensor(0.1453, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.4165, dtype=torch.float64) 	F-macro_val: tensor(0.1458, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.4165, dtype=torch.float64) 	F-macro_val: tensor(0.1458, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.4151, dtype=torch.float64) 	F-macro_val: tensor(0.1453, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.4165, dtype=torch.float64) 	F-macro_val: tensor(0.1459, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.4146, dtype=torch.float64) 	F-macro_val: tensor(0.1452, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.4142, dtype=torch.float64) 	F-macro_val: tensor(0.1450, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.4151, dtype=torch.float64) 	F-macro_val: tensor(0.1451, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.4160, dtype=torch.float64) 	F-macro_val: tensor(0.1458, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.4170, dtype=torch.float64) 	F-macro_val: tensor(0.1454, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.4151, dtype=torch.float64) 	F-macro_val: tensor(0.1455, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.4146, dtype=torch.float64) 	F-macro_val: tensor(0.1452, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.4151, dtype=torch.float64) 	F-macro_val: tensor(0.1451, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.4151, dtype=torch.float64) 	F-macro_val: tensor(0.1456, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.4170, dtype=torch.float64) 	F-macro_val: tensor(0.1457, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.4146, dtype=torch.float64) 	F-macro_val: tensor(0.1454, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.4156, dtype=torch.float64) 	F-macro_val: tensor(0.1454, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.4137, dtype=torch.float64) 	F-macro_val: tensor(0.1453, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.4170, dtype=torch.float64) 	F-macro_val: tensor(0.1458, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.4174, dtype=torch.float64) 	F-macro_val: tensor(0.1459, dtype=torch.float64)
# Testing run # 2
# SE TUVIERON QUE REPETIR 21 EJEMPLOS
# Test_ acc: 0.6415449835138954
# Test_ f1 none: [0.75743119 0.09677419 0.06976744 0.48970252]
# Test_ f1 macro: 0.35341883630796855
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 3
# Memory usage         :  12.30 MB
# GC collected objects : 756050
# Memory usage         :  12.30 MB
# GC collected objects : 0
# Memory usage         :  12.30 MB
# tensor([1., 1., 1., 1.])
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.4543, dtype=torch.float64) 	F-macro_val: tensor(0.1549, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.5303, dtype=torch.float64) 	F-macro_val: tensor(0.1724, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.5294, dtype=torch.float64) 	F-macro_val: tensor(0.1721, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.5294, dtype=torch.float64) 	F-macro_val: tensor(0.1718, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.5336, dtype=torch.float64) 	F-macro_val: tensor(0.1726, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.5354, dtype=torch.float64) 	F-macro_val: tensor(0.1731, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.5345, dtype=torch.float64) 	F-macro_val: tensor(0.1731, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.5340, dtype=torch.float64) 	F-macro_val: tensor(0.1730, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.5326, dtype=torch.float64) 	F-macro_val: tensor(0.1729, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.5354, dtype=torch.float64) 	F-macro_val: tensor(0.1731, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.5326, dtype=torch.float64) 	F-macro_val: tensor(0.1725, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.5336, dtype=torch.float64) 	F-macro_val: tensor(0.1729, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.5331, dtype=torch.float64) 	F-macro_val: tensor(0.1729, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.5331, dtype=torch.float64) 	F-macro_val: tensor(0.1728, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.5326, dtype=torch.float64) 	F-macro_val: tensor(0.1728, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.5345, dtype=torch.float64) 	F-macro_val: tensor(0.1730, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.5331, dtype=torch.float64) 	F-macro_val: tensor(0.1728, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.5340, dtype=torch.float64) 	F-macro_val: tensor(0.1730, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.5322, dtype=torch.float64) 	F-macro_val: tensor(0.1727, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.5350, dtype=torch.float64) 	F-macro_val: tensor(0.1733, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.5345, dtype=torch.float64) 	F-macro_val: tensor(0.1732, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.5340, dtype=torch.float64) 	F-macro_val: tensor(0.1730, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.5336, dtype=torch.float64) 	F-macro_val: tensor(0.1732, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.5326, dtype=torch.float64) 	F-macro_val: tensor(0.1725, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.5336, dtype=torch.float64) 	F-macro_val: tensor(0.1730, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.5340, dtype=torch.float64) 	F-macro_val: tensor(0.1731, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.5345, dtype=torch.float64) 	F-macro_val: tensor(0.1732, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.5326, dtype=torch.float64) 	F-macro_val: tensor(0.1729, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.5340, dtype=torch.float64) 	F-macro_val: tensor(0.1732, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.5345, dtype=torch.float64) 	F-macro_val: tensor(0.1728, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.5350, dtype=torch.float64) 	F-macro_val: tensor(0.1733, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.5322, dtype=torch.float64) 	F-macro_val: tensor(0.1727, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.5326, dtype=torch.float64) 	F-macro_val: tensor(0.1728, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.5350, dtype=torch.float64) 	F-macro_val: tensor(0.1732, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.5336, dtype=torch.float64) 	F-macro_val: tensor(0.1730, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.5336, dtype=torch.float64) 	F-macro_val: tensor(0.1724, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.5336, dtype=torch.float64) 	F-macro_val: tensor(0.1730, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.5340, dtype=torch.float64) 	F-macro_val: tensor(0.1731, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.5345, dtype=torch.float64) 	F-macro_val: tensor(0.1732, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.5336, dtype=torch.float64) 	F-macro_val: tensor(0.1730, dtype=torch.float64)
# Testing run # 3
# SE TUVIERON QUE REPETIR 21 EJEMPLOS
# Test_ acc: 0.7461139896373057
# Test_ f1 none: [0.84327142 0.         0.12195122 0.5775076 ]
# Test_ f1 macro: 0.3856825605532437
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 4
# Memory usage         :  12.30 MB
# GC collected objects : 756050
# Memory usage         :  12.30 MB
# GC collected objects : 0
# Memory usage         :  12.30 MB
# tensor([1., 1., 1., 1.])
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.5392, dtype=torch.float64) 	F-macro_val: tensor(0.1743, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.5131, dtype=torch.float64) 	F-macro_val: tensor(0.1682, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.5149, dtype=torch.float64) 	F-macro_val: tensor(0.1688, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.5131, dtype=torch.float64) 	F-macro_val: tensor(0.1686, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.5168, dtype=torch.float64) 	F-macro_val: tensor(0.1692, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.4165, dtype=torch.float64) 	F-macro_val: tensor(0.1457, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.5149, dtype=torch.float64) 	F-macro_val: tensor(0.1683, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.5131, dtype=torch.float64) 	F-macro_val: tensor(0.1687, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.5140, dtype=torch.float64) 	F-macro_val: tensor(0.1683, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.5163, dtype=torch.float64) 	F-macro_val: tensor(0.1693, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.5131, dtype=torch.float64) 	F-macro_val: tensor(0.1685, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.5163, dtype=torch.float64) 	F-macro_val: tensor(0.1692, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.5145, dtype=torch.float64) 	F-macro_val: tensor(0.1686, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.5154, dtype=torch.float64) 	F-macro_val: tensor(0.1690, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.5145, dtype=torch.float64) 	F-macro_val: tensor(0.1686, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.5149, dtype=torch.float64) 	F-macro_val: tensor(0.1688, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.5145, dtype=torch.float64) 	F-macro_val: tensor(0.1687, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.5140, dtype=torch.float64) 	F-macro_val: tensor(0.1685, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.5145, dtype=torch.float64) 	F-macro_val: tensor(0.1684, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.5177, dtype=torch.float64) 	F-macro_val: tensor(0.1695, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.5135, dtype=torch.float64) 	F-macro_val: tensor(0.1683, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.5163, dtype=torch.float64) 	F-macro_val: tensor(0.1692, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.5140, dtype=torch.float64) 	F-macro_val: tensor(0.1685, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.5159, dtype=torch.float64) 	F-macro_val: tensor(0.1692, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.5177, dtype=torch.float64) 	F-macro_val: tensor(0.1694, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.5173, dtype=torch.float64) 	F-macro_val: tensor(0.1691, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.5149, dtype=torch.float64) 	F-macro_val: tensor(0.1687, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.5168, dtype=torch.float64) 	F-macro_val: tensor(0.1690, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.5154, dtype=torch.float64) 	F-macro_val: tensor(0.1691, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.5163, dtype=torch.float64) 	F-macro_val: tensor(0.1692, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.4431, dtype=torch.float64) 	F-macro_val: tensor(0.1523, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.4459, dtype=torch.float64) 	F-macro_val: tensor(0.1532, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.5173, dtype=torch.float64) 	F-macro_val: tensor(0.1693, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.4473, dtype=torch.float64) 	F-macro_val: tensor(0.1533, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.5149, dtype=torch.float64) 	F-macro_val: tensor(0.1686, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.5173, dtype=torch.float64) 	F-macro_val: tensor(0.1692, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.5159, dtype=torch.float64) 	F-macro_val: tensor(0.1691, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.5173, dtype=torch.float64) 	F-macro_val: tensor(0.1694, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.5154, dtype=torch.float64) 	F-macro_val: tensor(0.1693, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.5177, dtype=torch.float64) 	F-macro_val: tensor(0.1695, dtype=torch.float64)
# Testing run # 4
# SE TUVIERON QUE REPETIR 21 EJEMPLOS
# Test_ acc: 0.7428167687235044
# Test_ f1 none: [0.84050298 0.07017544 0.11764706 0.58146341]
# Test_ f1 macro: 0.40244722255358145
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1
# Entrenando Run # 5
# Memory usage         :  12.30 MB
# GC collected objects : 756050
# Memory usage         :  12.30 MB
# GC collected objects : 0
# Memory usage         :  12.30 MB
# tensor([1., 1., 1., 1.])
# Creando modelo con salida Softmax
# Epoch 0 	acc_val: tensor(0.4221, dtype=torch.float64) 	F-macro_val: tensor(0.1469, dtype=torch.float64)
# Epoch 1 	acc_val: tensor(0.4277, dtype=torch.float64) 	F-macro_val: tensor(0.1487, dtype=torch.float64)
# Epoch 2 	acc_val: tensor(0.4277, dtype=torch.float64) 	F-macro_val: tensor(0.1486, dtype=torch.float64)
# Epoch 3 	acc_val: tensor(0.4282, dtype=torch.float64) 	F-macro_val: tensor(0.1484, dtype=torch.float64)
# Epoch 4 	acc_val: tensor(0.4286, dtype=torch.float64) 	F-macro_val: tensor(0.1486, dtype=torch.float64)
# Epoch 5 	acc_val: tensor(0.4263, dtype=torch.float64) 	F-macro_val: tensor(0.1482, dtype=torch.float64)
# Epoch 6 	acc_val: tensor(0.4268, dtype=torch.float64) 	F-macro_val: tensor(0.1481, dtype=torch.float64)
# Epoch 7 	acc_val: tensor(0.4272, dtype=torch.float64) 	F-macro_val: tensor(0.1486, dtype=torch.float64)
# Epoch 8 	acc_val: tensor(0.4291, dtype=torch.float64) 	F-macro_val: tensor(0.1489, dtype=torch.float64)
# Epoch 9 	acc_val: tensor(0.4986, dtype=torch.float64) 	F-macro_val: tensor(0.1655, dtype=torch.float64)
# Epoch 10 	acc_val: tensor(0.4986, dtype=torch.float64) 	F-macro_val: tensor(0.1653, dtype=torch.float64)
# Epoch 11 	acc_val: tensor(0.4254, dtype=torch.float64) 	F-macro_val: tensor(0.1480, dtype=torch.float64)
# Epoch 12 	acc_val: tensor(0.4277, dtype=torch.float64) 	F-macro_val: tensor(0.1483, dtype=torch.float64)
# Epoch 13 	acc_val: tensor(0.4995, dtype=torch.float64) 	F-macro_val: tensor(0.1655, dtype=torch.float64)
# Epoch 14 	acc_val: tensor(0.4967, dtype=torch.float64) 	F-macro_val: tensor(0.1647, dtype=torch.float64)
# Epoch 15 	acc_val: tensor(0.5000, dtype=torch.float64) 	F-macro_val: tensor(0.1653, dtype=torch.float64)
# Epoch 16 	acc_val: tensor(0.5000, dtype=torch.float64) 	F-macro_val: tensor(0.1655, dtype=torch.float64)
# Epoch 17 	acc_val: tensor(0.4977, dtype=torch.float64) 	F-macro_val: tensor(0.1649, dtype=torch.float64)
# Epoch 18 	acc_val: tensor(0.5005, dtype=torch.float64) 	F-macro_val: tensor(0.1658, dtype=torch.float64)
# Epoch 19 	acc_val: tensor(0.4991, dtype=torch.float64) 	F-macro_val: tensor(0.1657, dtype=torch.float64)
# Epoch 20 	acc_val: tensor(0.5000, dtype=torch.float64) 	F-macro_val: tensor(0.1653, dtype=torch.float64)
# Epoch 21 	acc_val: tensor(0.4995, dtype=torch.float64) 	F-macro_val: tensor(0.1655, dtype=torch.float64)
# Epoch 22 	acc_val: tensor(0.5000, dtype=torch.float64) 	F-macro_val: tensor(0.1654, dtype=torch.float64)
# Epoch 23 	acc_val: tensor(0.5023, dtype=torch.float64) 	F-macro_val: tensor(0.1660, dtype=torch.float64)
# Epoch 24 	acc_val: tensor(0.4991, dtype=torch.float64) 	F-macro_val: tensor(0.1655, dtype=torch.float64)
# Epoch 25 	acc_val: tensor(0.5014, dtype=torch.float64) 	F-macro_val: tensor(0.1656, dtype=torch.float64)
# Epoch 26 	acc_val: tensor(0.4981, dtype=torch.float64) 	F-macro_val: tensor(0.1650, dtype=torch.float64)
# Epoch 27 	acc_val: tensor(0.4986, dtype=torch.float64) 	F-macro_val: tensor(0.1651, dtype=torch.float64)
# Epoch 28 	acc_val: tensor(0.4995, dtype=torch.float64) 	F-macro_val: tensor(0.1651, dtype=torch.float64)
# Epoch 29 	acc_val: tensor(0.4995, dtype=torch.float64) 	F-macro_val: tensor(0.1654, dtype=torch.float64)
# Epoch 30 	acc_val: tensor(0.4981, dtype=torch.float64) 	F-macro_val: tensor(0.1649, dtype=torch.float64)
# Epoch 31 	acc_val: tensor(0.4986, dtype=torch.float64) 	F-macro_val: tensor(0.1653, dtype=torch.float64)
# Epoch 32 	acc_val: tensor(0.4977, dtype=torch.float64) 	F-macro_val: tensor(0.1651, dtype=torch.float64)
# Epoch 33 	acc_val: tensor(0.5019, dtype=torch.float64) 	F-macro_val: tensor(0.1658, dtype=torch.float64)
# Epoch 34 	acc_val: tensor(0.4995, dtype=torch.float64) 	F-macro_val: tensor(0.1653, dtype=torch.float64)
# Epoch 35 	acc_val: tensor(0.4277, dtype=torch.float64) 	F-macro_val: tensor(0.1486, dtype=torch.float64)
# Epoch 36 	acc_val: tensor(0.4272, dtype=torch.float64) 	F-macro_val: tensor(0.1482, dtype=torch.float64)
# Epoch 37 	acc_val: tensor(0.4995, dtype=torch.float64) 	F-macro_val: tensor(0.1658, dtype=torch.float64)
# Epoch 38 	acc_val: tensor(0.4995, dtype=torch.float64) 	F-macro_val: tensor(0.1653, dtype=torch.float64)
# Epoch 39 	acc_val: tensor(0.4977, dtype=torch.float64) 	F-macro_val: tensor(0.1650, dtype=torch.float64)
# Testing run # 5
# SE TUVIERON QUE REPETIR 21 EJEMPLOS
# Test_ acc: 0.7202072538860104
# Test_ f1 none: [0.8251091  0.05042017 0.07142857 0.55263158]
# Test_ f1 macro: 0.3748973538638968
# Encoder Layer Attention head 0
# Encoder Layer Attention head 1

# %%
print ("Acc Test:", np.mean(np.asarray(global_accs)))
print ("F-macro Test:", np.mean(np.asarray(global_fmacros)))
nh=np.mean(np.asarray(global_fnones)[:,0])
ih=np.mean(np.asarray(global_fnones)[:,1])
ph=np.mean(np.asarray(global_fnones)[:,2])
sh=np.mean(np.asarray(global_fnones)[:,3])
#         [0.1721765 , 0.14503887, 0.14503889, 0.14852784, 0.20808983,
#          0.18112806]]),
#  array([[0.28514657, 0.18815086, 0.18815086, 0.12515599, 0.0941062 ,
#          0.11928951],
#         [0.31538664, 0.09167777, 0.09167777, 0.23481473, 0.15013025,
#          0.11631282],
#         [0.31538663, 0.09167777, 0.09167777, 0.23481474, 0.15013026,
#          0.11631282],
#         [0.25773654, 0.118642  , 0.11864201, 0.20580596, 0.16649545,
#          0.13267802],
#         [0.32921122, 0.10636298, 0.10636298, 0.2389009 , 0.09876294,
#          0.12039898],
#         [0.19546892, 0.11210957, 0.11210959, 0.24464751, 0.15996303,
#          0.17570136]]),
#  array([[0.13838977, 0.17130783, 0.1713078 , 0.16942289, 0.1645654 ,
#          0.18500632],
#         [0.16343976, 0.17098661, 0.17098663, 0.18734549, 0.15144167,
#          0.15579984],
#         [0.16343982, 0.17098663, 0.17098657, 0.18734551, 0.15144164,
#          0.15579985],
#         [0.21486113, 0.16292688, 0.16292688, 0.17923036, 0.13784829,
#          0.14220647],
#         [0.22357662, 0.15937313, 0.15937308, 0.17019836, 0.1488261 ,
#          0.1386527 ],
#         [0.20544095, 0.1609613 , 0.1609613 , 0.17178655, 0.13588271,
#          0.1649672 ]]),
#  array([[0.20557635, 0.14486793, 0.14486793, 0.18806999, 0.17032084,
#          0.14629699],
#         [0.21028622, 0.14115596, 0.14115598, 0.17275589, 0.167967  ,
#          0.16667894],
#         [0.21028617, 0.14115596, 0.14115599, 0.17275594, 0.16796698,
#          0.16667897],
#         [0.18716538, 0.14812752, 0.14812754, 0.1698318 , 0.17401788,
#          0.17272984],
#         [0.19768822, 0.14273656, 0.1427366 , 0.17341588, 0.17608381,
#          0.16733892],
#         [0.18001738, 0.1574674 , 0.15746744, 0.18814671, 0.18335778,
#          0.1335433 ]]),
#  array([[0.20415119, 0.15273492, 0.15273504, 0.13579975, 0.14454153,
#          0.21003757],
#         [0.24719275, 0.13925326, 0.13925335, 0.14888559, 0.13642786,
#          0.1889872 ],
#         [0.24719281, 0.13925329, 0.13925332, 0.14888558, 0.13642783,
#          0.18898717],
#         [0.2427548 , 0.15466518, 0.15466526, 0.12940783, 0.1329738 ,
#          0.18553314],
#         [0.23748311, 0.15496864, 0.15496864, 0.14573498, 0.12100807,
#          0.18583657],
#         [0.2562025 , 0.15708051, 0.15708057, 0.14784687, 0.13538911,
#          0.14640044]]),
#  array([[0.22920549, 0.15957566, 0.15957565, 0.1523176 , 0.15887858,
#          0.14044705],
#         [0.23992414, 0.15460475, 0.15460476, 0.14131031, 0.15920706,
#          0.15034899],
#         [0.23992415, 0.15460475, 0.15460475, 0.14131032, 0.15920704,
#          0.15034898],
#         [0.24932397, 0.15361193, 0.15361196, 0.1468694 , 0.15272042,
#          0.14386233],
#         [0.23314123, 0.15946746, 0.15946745, 0.14067917, 0.15752686,
#          0.14971783],
#         [0.22946573, 0.16313954, 0.16313952, 0.14435127, 0.16224798,
#          0.13765599]])]

# %%
np.save("ECML_Attn_prom_0-85_newCleaner.npy", global_attn)
