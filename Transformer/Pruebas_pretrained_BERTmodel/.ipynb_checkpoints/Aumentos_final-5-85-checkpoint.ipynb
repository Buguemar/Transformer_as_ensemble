# %%
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler
from keras.preprocessing.sequence import pad_sequences
import pandas as pd
from models import *
import time
import re, io, nltk, torch 
from nltk.corpus import stopwords
from numpy import linalg as LA
from numpy.linalg import norm
from sklearn.preprocessing import normalize
from sklearn.model_selection import train_test_split
from tqdm import tqdm, trange
from sklearn.utils.class_weight import compute_class_weight
from gensim import utils, matutils  
from gensim.corpora.dictionary import Dictionary
from six import string_types, integer_types
from six.moves import zip, range
from numpy import linalg as LA
from sklearn.preprocessing import Normalizer
from scipy import stats
from gensim.utils import deprecated
from numpy import dot, float32 as REAL, memmap as np_memmap, \
    double, array, zeros, vstack, sqrt, newaxis, integer, \
    ndarray, sum as np_sum, prod, argmax
from collections import Counter
from scipy.spatial import distance
from numpy.random import binomial
from scipy.stats import bernoulli
import numpy as np

import transformers
from transformers import (
    WEIGHTS_NAME,
    AdamW,
    BertConfig,
    BertForMaskedLM,
    BertForSequenceClassification,
    BertTokenizer,
    CamembertConfig,
    CamembertForMaskedLM,
    CamembertTokenizer,
    DistilBertConfig,
    DistilBertForMaskedLM,
    DistilBertTokenizer,
    GPT2Config,
    GPT2LMHeadModel,
    GPT2Tokenizer,
    OpenAIGPTConfig,
    OpenAIGPTLMHeadModel,
    OpenAIGPTTokenizer,
    RobertaConfig,
    RobertaForMaskedLM,
    RobertaTokenizer,
    get_linear_schedule_with_warmup,
)

n_gpu = torch.cuda.device_count()
torch.cuda.get_device_name(0)

if torch.cuda.is_available():     
    device = torch.device("cuda")
    print('There are',torch.cuda.device_count(),'GPU(s) available.')
    print('We will use the GPU:', torch.cuda.get_device_name(0))

else:
    print('No GPU available, using the CPU instead.')
    device = torch.device("cpu")

from keras.preprocessing.sequence import pad_sequences
import matplotlib.pyplot as plt


dict_cl=dict()
dict_cl[0]='support'
dict_cl[1]='denying'
dict_cl[2]='questioning'
dict_cl[3]='commenting'

#sdqc
d_lab=dict()
d_lab["support"]=0
d_lab["denying"]=1
d_lab["questioning"]=2
d_lab["commenting"]=3

train =pd.read_csv("../../Fine-Tuning/CSV_Stance/train_semeval_raw.csv")
val=pd.read_csv("../../Fine-Tuning/CSV_Stance/dev_semeval_raw.csv")
test=pd.read_csv("../../Fine-Tuning/CSV_Stance/test_semeval_raw.csv")
# Out:
# Using TensorFlow backend.
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/casapanshop/anaconda2/envs/newpy3_tf1/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# There are 1 GPU(s) available.
# We will use the GPU: GeForce GTX 1060 6GB

# %%
import re
from nltk.corpus import stopwords
from nltk import WordNetLemmatizer
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.porter import *

stemmer_sn = SnowballStemmer("english")
stemmer = PorterStemmer()

stoplist = stopwords.words("english")
lemmatizer=WordNetLemmatizer()

emoji_pattern = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags=re.UNICODE)

def cleaner(post): 
    #re.sub(r'([a-z])\1+', r'\1', "user i think that ' s all you loooooove ")
    s= re.sub(r"http\S+", " html ", post)   ##########elimina http    
    s= re.sub(r'#\w+ ?', " hashtag ", s) ########3
    s= re.sub(r'@\w+ ?', " user ", s)##############    
    s= s.lower()
    s=emoji_pattern.sub(r'', s)
    s=re.sub(r"'\b", " ' ", s)
    s=re.sub(r"\b'\b", " ' ", s)
    s=re.sub(r"\b’", " ’ ", s)
    s=re.sub(r"‘\b", " ‘ ", s)
    s=re.sub(r"\b’\b", " ‘ ", s)
    s = re.sub(r"-", " - ", s)
    s = re.sub(r"\(", " ", s)
    s = re.sub(r"\)", " ", s)
    s = re.sub(r"\?", " ? ", s)    
    s = re.sub(r"\/", " ", s)
    s = re.sub(r"' ", " ' ", s)
    s = re.sub(r" '", " ' ", s)
    s = re.sub(r"\!", " ! ", s)
    s=re.sub("[\.]+", " . ", s)
    s=re.sub("[\,]+", " , ", s)
    s=re.sub("[\;]+", " ; ", s)
    s=re.sub("[\:]+", " : ", s)
    s=re.sub('[\"]+', ' " ', s)
    s=re.sub(r'\b[0-9]\b', " number ",  s)
    s=re.sub(r'\b[0-9]*[0-9]\b', " number ",  s)    
    s=re.sub(r'\b”', ' " ', s)
    sl= list(s.split())
    #sl= [stemmer.stem(wd) for wd in sl]
    ############3
    sl_2=[]
    for wd in sl:
        try: 
            q=Word2Index[wd]
            sl_2.append(wd)
        except:
            try: 
                r=Word2Index[stemmer.stem(wd)]
                sl_2.append(stemmer.stem(wd))
            except:
                sl_2.append(wd)
    sl=sl_2
    ##########
    s=' '.join([word for word in sl])# if word not in stoplist])
    return s, sl

# %%
tokenizer_loaded = BertTokenizer.from_pretrained('bert-base-uncased')
model_loaded = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=4)#'bert-base-uncased',  num_labels=4) 
idx_2_token = tokenizer_loaded.ids_to_tokens
Word2Index=tokenizer_loaded.vocab
M_BERT_space = model_loaded.bert.embeddings.word_embeddings.weight.detach().cpu().numpy()

# %%
not_found=[]
found=[]
found_train=[]
pos_tag_nf=[]

MAX_LEN=50

etiq=[]
for et in train['Label'].values:
    etiq.append(d_lab[et])
n_labels = np.array(etiq)
y_train=to_categorical(n_labels,num_classes=4)
sentences = train['Tweet'].values
input_ids = []
i=0

for sent in sentences:
    temp=cleaner(sent)
    encoded_sent2 = tokenizer_loaded.encode(temp[0],add_special_tokens = False) 
    encoded_sent=[]
    iterar=temp[1]
    for wd in iterar:
        try:
            indice=Word2Index[wd]
            encoded_sent.append(wd)
            if wd not in found:
                found.append(wd)
                found_train.append(wd)
        except: 
            if wd not in not_found:
                not_found.append(wd)
                pos_tag_nf.append(nltk.pos_tag([wd])[0][-1])

    input_ids.append(encoded_sent2)
    """ if i<3:
        print ("-----------------------------------------------------------------")
        print ("\nsentencia original:", sent)
        #print ("\nsentencia procesada My cleaner:",temp[0])
        print ("\nsentencia tokenizada usando Transformer vocabulary:", encoded_sent)
        print ("\nsentencia tokenizada usando Transformer Tokenizer:", encoded_sent2)
    i+=1"""

input_ids = pad_sequences(input_ids, maxlen=MAX_LEN, dtype="long", value=0, truncating="post", padding="post")

# %%
etiq_v=[]
for et in val['Label'].values:
    etiq_v.append(d_lab[et])
n_labels_val = np.array(etiq_v)
y_val=to_categorical(n_labels_val,num_classes=4)
sentences_val = val['Tweet'].values
input_ids_val = []
i=0
for sent in sentences_val:
    temp=cleaner(sent)
    encoded_sent2 = tokenizer_loaded.encode(temp[0],add_special_tokens = False) 
    encoded_sent=[]
    iterar=temp[1]
    for wd in iterar:
        try:
            indice=Word2Index[wd]
            encoded_sent.append(wd)
            if wd not in found: 
                found.append(wd)
        except: 
            if wd not in not_found:
                not_found.append(wd)
                pos_tag_nf.append(nltk.pos_tag([wd])[0][-1])
            
    input_ids_val.append(encoded_sent2)
    """if i<3:
        print ("-----------------------------------------------------------------")
        print ("\nsentencia original:", sent)
        #print ("\nsentencia procesada My cleaner:",temp[0])
        print ("\nsentencia tokenizada usando Transformer vocabulary:", encoded_sent)
        print ("\nsentencia tokenizada usando Transformer Tokenizer:", encoded_sent2)
    i+=1"""
    
input_ids_val = pad_sequences(input_ids_val, maxlen=MAX_LEN, dtype="long", value=0, truncating="post", padding="post")


etiq_t=[]
for et in test['Label'].values:
    etiq_t.append(d_lab[et])
n_labels_test = np.array(etiq_t)
y_test=to_categorical(n_labels_test,num_classes=4)
sentences_test = test['Tweet'].values
input_ids_test = []
i=0
for sent in sentences_test:
    temp=cleaner(sent)
    #encoded_sent=[Word2Index[wd] for wd in temp]
    encoded_sent2 = tokenizer_loaded.encode(temp[0],add_special_tokens = False) 
    encoded_sent=[]
    iterar=temp[1]
    for wd in iterar:
        try:
            indice=Word2Index[wd]
            encoded_sent.append(wd)
            if wd not in found:
                found.append(wd)            
        except: 
            if wd not in not_found:
                #print ("not found", wd)
                not_found.append(wd)
                pos_tag_nf.append(nltk.pos_tag([wd])[0][-1])
            
    input_ids_test.append(encoded_sent2)
    """if i<3:
        print ("-----------------------------------------------------------------")
        print ("\nsentencia original:", sent)
        #print ("\nsentencia procesada My cleaner:",temp[0])
        print ("\nsentencia tokenizada usando Transformer vocabulary:", encoded_sent)
        print ("\nsentencia tokenizada usando Transformer Tokenizer:", encoded_sent2)
    i+=1"""

input_ids_test = pad_sequences(input_ids_test, maxlen=MAX_LEN, dtype="long", value=0, truncating="post", padding="post")

# %%
len(not_found)
# Out:
# 1910

# %%
print ("[my_cleaner] \t#Palabras NO encontradas en vocab BERT:",len(not_found))
print ("[my_cleaner] \t#Palabras encontradas en vocab BERT:",len(found))
print ("Distribución de palabras no encontradas en POS tag:", Counter(pos_tag_nf) )
# Out:
# [my_cleaner] 	#Palabras NO encontradas en vocab BERT: 1910
# [my_cleaner] 	#Palabras encontradas en vocab BERT: 5168
# Distribución de palabras no encontradas en POS tag: Counter({'NN': 1390, 'NNS': 220, 'VBG': 82, 'JJ': 82, 'VBN': 52, 'CD': 39, 'RB': 33, 'VBD': 5, 'VB': 4, 'JJS': 2, 'IN': 1})

# %%
for wd in not_found[:30]:
    print ("[",wd,"] \t\tlema:",lemmatizer.lemmatize(wd), "\tStem:",stemmer.stem(wd), "\tStem snow:", stemmer_sn.stem(wd))
# Out:
# [ lol ] 		lema: lol 	Stem: lol 	Stem snow: lol
# [ hashtag ] 		lema: hashtag 	Stem: hashtag 	Stem snow: hashtag
# [ harass ] 		lema: harass 	Stem: harass 	Stem snow: harass
# [ smear ] 		lema: smear 	Stem: smear 	Stem snow: smear
# [ schaut ] 		lema: schaut 	Stem: schaut 	Stem snow: schaut
# [ genau ] 		lema: genau 	Stem: genau 	Stem snow: genau
# [ hin ] 		lema: hin 	Stem: hin 	Stem snow: hin
# [ messieurs ] 		lema: monsieur 	Stem: messieur 	Stem snow: messieur
# [ gendarmes ] 		lema: gendarme 	Stem: gendarm 	Stem snow: gendarm
# [ wd ] 		lema: wd 	Stem: wd 	Stem snow: wd
# [ retweeted ] 		lema: retweeted 	Stem: retweet 	Stem snow: retweet
# [ favourited ] 		lema: favourited 	Stem: favourit 	Stem snow: favourit
# [ tweet ] 		lema: tweet 	Stem: tweet 	Stem snow: tweet
# [ omg ] 		lema: omg 	Stem: omg 	Stem snow: omg
# [ wouldve ] 		lema: wouldve 	Stem: wouldv 	Stem snow: wouldv
# [ krauts ] 		lema: kraut 	Stem: kraut 	Stem snow: kraut
# [ +&gt ] 		lema: +&gt 	Stem: +&gt 	Stem snow: +&gt
# [ firedoor ] 		lema: firedoor 	Stem: firedoor 	Stem snow: firedoor
# [ lindt ] 		lema: lindt 	Stem: lindt 	Stem snow: lindt
# [ prayerz ] 		lema: prayerz 	Stem: prayerz 	Stem snow: prayerz
# [ in2 ] 		lema: in2 	Stem: in2 	Stem snow: in2
# [ 4x ] 		lema: 4x 	Stem: 4x 	Stem snow: 4x
# [ yup ] 		lema: yup 	Stem: yup 	Stem snow: yup
# [ kosher ] 		lema: kosher 	Stem: kosher 	Stem snow: kosher
# [ rcmp ] 		lema: rcmp 	Stem: rcmp 	Stem snow: rcmp
# [ isnt ] 		lema: isnt 	Stem: isnt 	Stem snow: isnt
# [ ugh ] 		lema: ugh 	Stem: ugh 	Stem snow: ugh
# [ darams ] 		lema: darams 	Stem: daram 	Stem snow: daram
# [ cric ] 		lema: cric 	Stem: cric 	Stem snow: cric
# [ hebdo ] 		lema: hebdo 	Stem: hebdo 	Stem snow: hebdo

# %%
def my_normalize(v):
    norm = np.linalg.norm(v)
    if norm == 0: 
        return v
    return v/norm

#el peso max es igual a la clase mas grande
def det_samples(df, dict_class, c_weights=None):
    conteos= Counter(df)
    aumentos= dict()
    maxi= max(conteos.values())
    for clase in conteos:
        if conteos[clase]==maxi:
            class_maxi=clase
            
    if c_weights is None:        # uniform class weights
        for tipo in conteos:
            actual= conteos[tipo]
            if actual<maxi:
                aumentos[tipo]=int(maxi-actual)
            else:
                aumentos[tipo]=0
        return aumentos   
    else:
        try:
            weigths=my_normalize(c_weights)
            max_wei=max(weigths)
            class_max= list(weigths).index(max_wei)
            str_class=dict_class[class_max]
            samples_max=conteos[str_class]
            
            clase=0
            for peso in weigths:
                k=dict_class[clase]
                if peso == max_wei:
                    aumentos[k]= int(samples_max-conteos[k])
                    #print ("aumentos[k]", aumentos[k], 'sampples min', samples_max, 'conteos[clase]', conteos[clase])
                else:
                    futuro=(samples_max/max_wei)*peso
                    aumentos[k]=int(futuro-conteos[k])
                    #print ("aumentos[k] para pesos no minimos ", aumentos[k], "futuro", futuro, "actual", conteos[k])
                clase+=1
            return aumentos
        except:
            print ("No se ha especificado el vector de pesos par balance de datos")
            
            
def Sort_Tuple(tup):  
    return(sorted(tup, key = lambda x: x[1]))   
  
def re_generar(muestra, tags_all, tag, prob):
    sent, indices, tags = just_tag_word(muestra, tags_all, tag)
    noise_mask = bernoulli.rvs(prob, size=sent.shape)
    bool_list=list(map(bool,noise_mask))
    to_replace=sent[bool_list]
    indix=indices[bool_list]  
    tagx=tags[bool_list] 
    idx_to_orig=len(sent)
    return  to_replace , indix, tagx, idx_to_orig

puntos='!?."()[´]“<>¡¿-/;:=_”@#.'

def just_tag_word(sentence, tags_all, tag):
    n_sentence=[]
    indices=[]
    valid=[]
    i=0
    for wd in sentence:
        if wd in puntos or wd[0]=='#':
            i+=1
            continue
        else:
            if tags_all[i] not in tag:
                i+=1
                continue
            else:
                n_sentence.append(wd)
                indices.append(i)
                valid.append(tags_all[i])
            i+=1
    return np.asarray(n_sentence), np.asarray(indices), np.asarray(valid)

def all_tag_word(sentence):    
    n_sentence=[]
    for wd in sentence:
        if wd in puntos or wd[0]=='#':
            continue
        else:
            n_sentence.append(wd)    
    return np.asarray(n_sentence), np.asarray(indices), np.asarray(valid)
    
def all_tag_word2(sentence):
    n_sentence=[]
    for wd in sentence:
        if ('unused' in token) or token.isdigit() or token[:-2].isdigit() or token in puntos or "##" in token or len(token) < 2: 
            continue
        else:
            n_sentence.append(wd)
    return np.asarray(n_sentence)
        
def check_word(token, tag, clase):
    if ('unused' in token) or token.isdigit() or token[:-2].isdigit() or token in puntos or "##" in token or len(token) < 2: 
        return False
    else:
        if nltk.pos_tag([token])[0][-1]==tag and token in vocabulary[clase]:
            return True
        else: 
            return False

def check_vocab(token, clase):
    if ('unused' in token) or token.isdigit() or token[:-2].isdigit() or  token in puntos or "##" in token or len(token) < 2: 
        return False
    else:
        if token in vocabulary[clase]:
            return True
        else: 
            return False
        
def check_tag(token, tag):
    if ('unused' in token) or token.isdigit() or token[:-2].isdigit() or token in puntos or "##" in token or len(token) < 2: 
        return False
    else:
        if nltk.pos_tag([token])[0][-1]==tag:
            return True
        else: 
            return False
        
def check_vocab(token, clase):
    if ('unused' in token) or token.isdigit() or token[:-2].isdigit() or token in puntos or "##" in token or len(token) < 2: 
        return False
    else:
        if token in vocabulary[clase]:
            return True
        else: 
            return False
            
def check_valid(lista, tags):
    keep=[]
    lista_tag= [nltk.pos_tag([wd])[0][-1] for wd in lista] 
    #print ("Tags de pos/neg:", lista_tag)
    for tag, word in list(zip(lista_tag , lista)):
        if tag in tags:
            keep.append(word)
    return keep
            
def my_most_similar_cosmul(space, M_BERT_space, bias, positive=None, negative=None, topn=1 ): #agregar space de vpcab
    if isinstance(topn, int) and topn < 1:
        return []
    if positive is None:
        positive = []
    #if negative is None:
    #    negative = []
    if isinstance(positive, str) and not negative:
        positive = [positive]
  
    ids_pos = [
        Word2Index[word] if isinstance(word, string_types) else 'Tipo positivo no admitido'
        for word in positive
    ]    
    positive = [M_BERT_space[idx] for idx in ids_pos]  #space de vocab
    
    if negative is None:
        negative = []
    else: 
        #print ("\n\nSE SOLICITAN NEGATIVOS\n\n")
        ids_nega= [
            Word2Index[word] if isinstance(word, string_types) else 'Tipo negativo no admitido'
            for word in negative
        ]
        negative = [M_BERT_space[idx] for idx in ids_nega] #space de vocab

    if not positive:
        raise ValueError("cannot compute similarity with no input")
    
    
    pos_dists = [((1 + dot(space, term))/2) for term in positive]
    
    pos_dists[0]=pos_dists[0] + bias
    neg_dists = [((1 + dot(space, term))/2) for term in negative]
    dists = prod(pos_dists, axis=0) / (prod(neg_dists, axis=0) + 0.000001)
    
    if not topn:
        return dists
    best = matutils.argsort(dists, topn=topn + len(positive + negative), reverse=True)  #ordena en vocab used


    return best, dists[best] #retorna indices y distancias asociadas


def find_positive(lista, target, id_target, bias, window=4):
    to_return=[target]
    to_return=to_return*int(bias)
    positive_temp=find_window(lista, target, id_target, window=window)
    to_return+=positive_temp
    
    return to_return
                  

def find_window(lista, target, id_target, window=4):  #wind debe ser par   
    to_return=[]
    sub_w=int(window/2)
    
    if id_target >= sub_w and id_target + sub_w < len(lista):
        atras=lista[id_target-sub_w:id_target]
        adelante=lista[id_target+1:id_target+1+sub_w]
        
    elif id_target  < sub_w:
        atras=lista[:id_target]
        adelante=lista[id_target+1:id_target+sub_w+1]
        
    elif id_target + sub_w >= len(lista): 
        atras=lista[id_target-sub_w:id_target]
        adelante= lista[id_target+1:]
        
    to_return+=atras
    to_return+=adelante
    return to_return


def find_negative(target, not_sent, window=4):
    cleaned = cleaner(not_sent)[0]
    cleaned= tokenizer_loaded.tokenize(cleaned, add_special_tokens = False)
    ide = cleaned.index(target)
    wind_neg=find_window(list(cleaned), target, ide, window=window)
   
    return wind_neg


def sample_neg_class(cl):
    if type(cl) != list:
        cl = [cl]
    aux = list(d_lab.keys())
    for value in cl:
        aux.remove(value)
    samp_neg = np.random.choice(aux)
    
    used_classes = cl
    used_classes.append(samp_neg)
    return samp_neg, used_classes

def check_special(lista):
    exceptions=['[CLS]', '[SEP]', '[MASK]']
    to_return=[]
    for item in lista:  #es una tupla
        if item[0] not in exceptions: 
            to_return.append(item[0])
        else:
            continue
    return to_return

def choose_replace(candidatos, ide, target):
    candidatos=check_special(candidatos)
    try:
        candidatos.remove(target)
    except:
        pass
    
    elem=np.random.choice(candidatos)
    return (elem, ide)
        

def aumentar_clase(clase, num_ejem, tags_all, prob, TOPN):
    dict_resumen=dict()
    new_sample=[]
    indx=train['Label']==clase
    print ("Consultando por la clase", clase)
    label=d_lab[clase]    
    print ("Entrega label", label)
    contador=1
    
    no_modificados=0
    modificados=0
    terms_modif=0  
    terms_supuestos=0  
    totales=0
    largos=0
    SENT_LEN=0
    TOPE_LEN=0
    
    if num_ejem>0:
        while (len(new_sample)<num_ejem):
            muestras=train['Tweet'][indx]
            tw_ids=train['Tw_id'][indx]
            for muestra in muestras:  
                if len(new_sample)<num_ejem:
                    pre=np.asarray(tokenizer_loaded.tokenize(cleaner(muestra)[0], add_special_tokens=False))                    
                    tags_pre= [nltk.pos_tag([wd])[0][-1] for wd in pre]
                    terms, indxs, tagx, tope_replace= re_generar(pre, tags_pre, tags_all, prob)  #terms to replace
                    terms_supuestos+=len(terms)

                    news=[]
                    TOPE_LEN+=tope_replace
                    SENT_LEN+=len(terms)
                    
                    if len(terms)>0:     
                        
                        for term, ind, tag in list(zip(terms, indxs, tagx)):                           
                            mask_words = np.asarray(d_vocab[clase]) & np.asarray(d_pos[tag])
                            vocab_used_pos = np.arange(len(mask_words))[mask_words]
                            space= M_BERT_space[mask_words] #vocab de clase y tag
                            
                            if term!='user' and term!='hashtag' and term!='html':
                                not_clase, used_classes = sample_neg_class(clase) #definir clases a buscar
                                
                                valid_pos=[]
                                pos = find_positive(list(pre), term, ind, bias=1, window=4) #se puede cambiar la ventana! 
                                valid_pos=check_valid(pos, tags_all)

                                id_need = 999999999 #simbolo de que no encontró tweet
                                neg = []
                                while(id_need == 999999999):
                                    try:
                                        id_need = np.random.choice(dic_IdxI[not_clase][term]) #sample id
                                    except:
                                        if len(used_classes) == len(d_lab.keys()): 
                                            break #ya revisó todas las clases
                                        not_clase, used_classes = sample_neg_class(used_classes) # change class 

                                valid_neg=[]
                                if id_need != 999999999: #si encontró tweet
                                    not_sent = train["Tweet"][id_need]
                                    neg = find_negative(term, not_sent, window=4) 
                                    valid_neg=check_valid(neg, tags_all)

                                if len(valid_neg)<1 or len(valid_pos)<1:
                                    continue
                                    #pass

                                best, dists_best = my_most_similar_cosmul(space, M_BERT_space, 0.0, positive=valid_pos, negative=valid_neg, topn=TOPN)
                                #best, dists_best = my_most_similar_cosmul(space, M_BERT_space, 0.0, positive=valid_pos, negative=None, topn=TOPN)

                                todo_words = {
                                    Word2Index[word] for word in valid_pos + valid_neg
                                    if not isinstance(word, ndarray) and word in Word2Index
                                    }
                                result = []
                                for sim, dist_sim in list(zip(best, dists_best)):
                                    n_sim = vocab_used_pos[sim]
                                    if n_sim not in todo_words:
                                        result.append((idx_2_token[n_sim], float(dist_sim)))
                                        
                                if len(result)>0:
                                    candidatos = result[:TOPN] #+2
                                else:
                                    continue

                                new = choose_replace(candidatos, ind, term)  
                                news.append(new) 
                                if tag in dict_resumen.keys():
                                    dict_resumen[tag]+=1
                                else:
                                    dict_resumen[tag]=1
                                
                        cambia=False
                        news= Sort_Tuple(news) 
                        
                        if len(news)<1:
                            no_modificados+=1
                            continue
                        else:
                            x=np.asarray(news)[:,1]
                            y=np.asarray(news)[:,0]
                            n_news=np.asarray(np.vstack((x,y))).T

                            nueva_sent=[]
                            cont_new=0
                            for i in range(len(pre)):
                                try:
                                    if int(n_news[cont_new][0])==i:
                                        nueva_sent.append(n_news[cont_new][1])                 
                                        cont_new+=1
                                    else: 
                                        nueva_sent.append(pre[i])
                                except: 
                                    nueva_sent.append(pre[i])
                       
                            totales+=cont_new
                            new_sample.append([contador, nueva_sent, label])
                            modificados+=1
                            terms_modif+=len(news)
                            largos+=len(pre)
                            contador+=1
                            
                            #"""
                            if len(new_sample)<10:
                                print ("Sentencia original:")
                                print (pre)
                                print ("Sentencia final:" , label)
                                print (nueva_sent)
                                print ("")
                                print ("")
                            #"""                              

                else:
                    count= Counter(train['Label'])   
                    for muestra, twid in list(zip(muestras,tw_ids)) :
                        pre=np.asarray(cleaner(muestra)[1])
                        new_sample.append([twid, pre, label])
                    break
                    
    else:
        count= Counter(train['Label'])
        news= train[indx].sample(count[clase]+num_ejem)
        news_tw=news['Tweet'].values
        news_id=news['Tw_id'].values
        for muestra, twid in list(zip(news_tw, news_id)):
            pre=np.asarray(cleaner(muestra)[1])
            new_sample.append([twid, pre, label])

    try:
        print ("# terms modificados promedio", terms_modif/modificados ,"términos por sentencia")
        print ("Largo de sentencia promedio", largos/modificados ,"términos por sentencia")
        print ("para esta ejecución se debiesen reemplazar", SENT_LEN, " de" ,TOPE_LEN, "terminos")

    except: 
        print ("No se generan ejemplos")

    return new_sample, dict_resumen


def predict_data(trained, x_train, x_val, x_test, etiq, etiq_v, etiq_t, name_model):
    etiq = etiq.astype("int")
    trainPredict = trained.predict(x_train, batch_size=32)
    trainPredict=[np.argmax(pred) for pred in trainPredict]
    acc= accuracy_score(etiq, trainPredict)  
    f1=f1_score(etiq, trainPredict, average=None)  # labels=np.unique(trainPredict)
    f1_ma=f1_score(etiq, trainPredict, average='macro')  # labels=np.unique(trainPredict)
    #matriz=normalize(confusion_matrix(etiq, trainPredict))
    print ("")
    print ("Accuracy sobre Train", name_model, ":",acc)  
    print ("F1-score None sobre Train", name_model, ":",f1)
    print ("F1-score macro sobre Train", name_model, ":",f1_ma)
    ########################################
    trainPredict = trained.predict(x_val, batch_size=32)
    trainPredict=[np.argmax(pred) for pred in trainPredict]
    acc= accuracy_score(etiq_v, trainPredict)  
    f1=f1_score(etiq_v, trainPredict, average=None)  # labels=np.unique(trainPredict)
    f1_ma=f1_score(etiq_v, trainPredict, average='macro')  # labels=np.unique(trainPredict)
    #matriz=normalize(confusion_matrix(etiq_v, trainPredict))
    print ("")
    print ("Accuracy sobre Val", name_model, ":",acc)  
    print ("F1-score None sobre Val", name_model, ":",f1)
    print ("F1-score macro sobre Val", name_model, ":",f1_ma)
    ########################################
    trainPredict = trained.predict(x_test, batch_size=32)
    trainPredict=[np.argmax(pred) for pred in trainPredict]
    acc_t= accuracy_score(etiq_t, trainPredict)  
    f1_t=f1_score(etiq_t, trainPredict, average=None)  # labels=np.unique(trainPredict)
    f1_ma_t=f1_score(etiq_t, trainPredict, average='macro')  # labels=np.unique(trainPredict)
    matriz_t=normalize(confusion_matrix(etiq_t, trainPredict))
    print ("")
    print ("Accuracy sobre Test", name_model, ":",acc_t)  
    print ("F1-score None sobre Test", name_model, ":",f1_t)
    print ("F1-score macro sobre Test", name_model, ":",f1_ma_t)
    
    return f1_ma_t, f1_t, acc_t, matriz_t

# %%
transformer = Normalizer().fit(M_BERT_space) 
M_BERT_space=transformer.transform(M_BERT_space)

tr_s=train.loc[train['Label']=='support']
tr_d=train.loc[train['Label']=='denying']
tr_q=train.loc[train['Label']=='questioning']
tr_c=train.loc[train['Label']=='commenting']
keys=['support', 'denying', 'questioning', 'commenting']

dict_vocab={}
for key in keys: 
    tr_k=train.loc[train['Label']==key]
    tr_k=tr_k['Tweet'].values    
    trs_k=[]
    for tw in tr_k:
        encoded = cleaner(tw)[1]
        apen=[]
        for wd in encoded:
            try: 
                h=Word2Index[wd]
                apen.append(wd)
            except: 
                continue
        
        #trs_k+=list(set(encoded))
        trs_k+=apen
    dict_vocab[key]=list(set(trs_k ))
    print ("#terms ",key,":",len(dict_vocab[key]))
# Out:
# #terms  support : 1773
# #terms  denying : 1219
# #terms  questioning : 1043
# #terms  commenting : 3790

# %%
all_terms=[]
for key in keys:
    all_terms+=dict_vocab[key]
    
len(set(all_terms))
# Out:
# 4455

# %%
len(found_train)
# Out:
# 4455

# %%
vocabulary=dict_vocab
dic_IdxI = {value: {} for value in d_lab.keys()}
for i, (muestra, label) in enumerate(list(zip(train['Tweet'],train['Label']))):
    pre=np.asarray(cleaner(muestra)[1])
    for token in pre:
        if token not in dic_IdxI[label]:
            dic_IdxI[label][token] = [i]
        else:
            dic_IdxI[label][token].append(i)

# %%
tags=['NN','NNS', 'JJ', 'JJR', 'JJS', 'VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ']
clases=['support', 'denying', 'questioning', 'commenting']

# %%
d_pos= dict()
for tag in tags:
    d_pos[tag]= [check_tag(k, tag) for k in idx_2_token.values()]
    
d_vocab=dict()
for clase in clases:
    d_vocab[clase]= [check_vocab(k, clase) for k in idx_2_token.values()]

# %%
d_vocab['denying'] and d_pos['NN'][:10]
# Out:
# [True, False, False, False, False, False, False, False, False, False]

# %%
shape_val=np.asarray(input_ids_val).shape
x_val=np.zeros((shape_val[0], shape_val[1], 768))
i=0
for in_id in input_ids_val:
    x_val[i]=M_BERT_space[in_id]
    i+=1
    
shape_test=np.asarray(input_ids_test).shape
x_test=np.zeros((shape_test[0], shape_test[1], 768))
i=0
for in_id in input_ids_test:
    x_test[i]=M_BERT_space[in_id]
    i+=1

x_test.shape
# Out:
# (1021, 50, 768)

# %%
 tokenizer_loaded.encode('the dog')
# Out:
# [101, 1996, 3899, 102]

# %%
for i in range(4,6):
    print (i)
# Out:
# 4
# 5

# %% [markdown]
# ### Generar 0.5 en stance [pos + negativo classic]

# %%
prob= 0.5
TOPN = 1

fs_macro={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
fs_none={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
accs={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
confusions={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}

aum_weight=det_samples(train['Label'], dict_cl)

for i in range(1,6): 
    macro_augmented=[]
    print ("\n--------------------------------------------------------")
    print ("\nGenerando ejemplos en base a probabilidad --> ", prob)
    print ("--------------------------------------------------------")
    for clase in aum_weight:
        start_time=time.time()
        print ("\n\nGenerando", aum_weight[clase], "nuevos ejemplos para la clase", clase)
        muestras, dict_aumentos=aumentar_clase(clase, aum_weight[clase], tags, prob, TOPN)
        macro_augmented+=muestras
        print ("Resumen de modificaciones:", dict_aumentos)
        elapsed_time= time.time() - start_time
        print ("Este proceso tomó", elapsed_time, "seg")   

    macro_augmented = np.asarray(macro_augmented, dtype=object)
    np.random.shuffle(macro_augmented)
    np.save('../../../new_data_augmented/stance/Aumento_'+str(i)+'-run_'+str(prob)+'_app1_Top'+str(TOPN)+'.npy', macro_augmented)
# Out:
# --------------------------------------------------------
#
# Generando ejemplos en base a probabilidad -->  0.5
# --------------------------------------------------------
#
#
# Generando 2404 nuevos ejemplos para la clase questioning
# Consultando por la clase questioning
# Entrega label 2
# Sentencia original:
# ['user' 'user' 'clarified' 'that' 'earlier' '.' 'cheers']
# Sentencia final: 2
# ['user', 'user', 'clarified', 'that', 'earlier', '.', 'words']
#
#
# Sentencia original:
# ['user' 'user' 'any' 'chance' 'that' "'" 's' 'being' 'said' 'for' 'fear'
#  'of' 'retribution' '?']
# Sentencia final: 2
# ['user', 'user', 'any', 'possibility', 'that', "'", 'thought', 'having', 'said', 'for', 'hate', 'of', 'retribution', '?']
#
#
# Sentencia original:
# ['user' 'user' 'user' 'user' 'ah' 'true' '.' 'problem' 'now' 'is' 'we' "'"
#  'll' 'probably' 'only' 'get' 'coroner' "'" 's' 'details' 'they' 'won' "'"
#  't' 'make' 'it' '.']
# Sentencia final: 2
# ['user', 'user', 'user', 'user', 'ah', 'true', '.', 'situation', 'now', 'is', 'we', "'", 'gonna', 'probably', 'only', 'get', 'helpful', "'", 'retribution', 'facts', 'they', 'won', "'", 't', 'give', 'it', '.']
#
#
# Sentencia original:
# ['user' ',' 'hi' 'betty' '.' 'you' 'are' 'in' 'australia' '?']
# Sentencia final: 2
# ['user', ',', 'hi', 'betty', '.', 'you', 'am', 'in', 'australia', '?']
#
#
# Sentencia original:
# ['user' 'user' 'if' 'so' 'that' 'hostage' 'will' 'be' 'the' 'person'
#  'best' 'able' 'to' 'give' 'an' 'insight' 'into' 'the' 'attack' ',' 'if'
#  'the' 'suspects' 'were' 'responsible' '.']
# Sentencia final: 2
# ['user', 'user', 'if', 'so', 'that', 'hostage', 'will', 'go', 'the', 'man', 'best', 'able', 'to', 'identify', 'an', 'insight', 'into', 'the', 'attack', ',', 'if', 'the', 'weren', 'were', 'concerned', '.']
#
#
# Sentencia original:
# ['user' 'i' 'thought' 'police' 'asked' 'media' 'not' 'to' 'report'
#  'demands' '.' 'why' 'you' 'giving' 'these' 'terrorists' 'a' 'voice' '?']
# Sentencia final: 2
# ['user', 'i', 'umm', 'police', 'asked', 'media', 'not', 'to', 'report', 'demands', '.', 'why', 'you', 'giving', 'these', 'terrorists', 'a', 'voice', '?']
#
#
# Sentencia original:
# ['user' 'user' 'you' "'" 're' 'choosing' 'to' 'talk' 'about' 'a' '"'
#  'robbery' '"' 'based' 'on' 'a' 'tape' 'that' 'only' 'shows' 'a'
#  'confrontation' 'not' 'a' 'crime' '.' 'so' 'stop' '!']
# Sentencia final: 2
# ['user', 'user', 'you', "'", 'choice', 'choosing', 'to', 'talk', 'about', 'a', '"', 'something', '"', 'focused', 'on', 'a', 'tape', 'that', 'only', 'shows', 'a', 'robbery', 'not', 'a', 'murder', '.', 'so', 'time', '!']
#
#
# Sentencia original:
# ['user' 'is' 'this' 'photo' 'from' 'last' 'night' '?' '?' 'please'
#  'clarify' 'because' 'you' 'are' 'using' 'present' 'tense' '.']
# Sentencia final: 2
# ['user', 'is', 'this', 'photo', 'from', 'last', 'night', '?', '?', 'court', 'clarify', 'because', 'you', 'are', 'using', 'use', 'tense', '.']
#
#
# Sentencia original:
# ['user' 'source' '?']
# Sentencia final: 2
# ['user', 'manipulate', '?']
#
#
# # terms modificados promedio 3.2774542429284526 términos por sentencia
# Largo de sentencia promedio 17.606073211314477 términos por sentencia
# para esta ejecución se debiesen reemplazar 11517  de 23138 terminos
# Resumen de modificaciones: {'NNS': 732, 'NN': 4466, 'VBG': 372, 'VB': 541, 'VBP': 203, 'JJ': 478, 'VBN': 278, 'VBZ': 456, 'VBD': 326, 'JJR': 14, 'JJS': 13}
# Este proceso tomó 38.895973205566406 seg
#
#
# Generando 0 nuevos ejemplos para la clase commenting
# Consultando por la clase commenting
# Entrega label 3
# No se generan ejemplos
# Resumen de modificaciones: {}
# Este proceso tomó 0.19248151779174805 seg
#
#
# Generando 1893 nuevos ejemplos para la clase support
# Consultando por la clase support
# Entrega label 0
# Sentencia original:
# ['user' 'some' 'good' 'news' '!']
# Sentencia final: 0
# ['user', 'some', 'bad', 'man', '!']
#
#
# Sentencia original:
# ['shoot' 'unarmed' 'kid' '.' 'conceal' 'evidence' '.' 'impose' 'martial'
#  'law' '.' 'hara' '##ss' 'reporters' '.' 'sm' '##ear' 'the' 'victim' '.'
#  'worst' '.' 'police' '.' 'ever' '.' 'hash' '##tag' 'hash' '##tag']
# Sentencia final: 0
# ['shot', 'unarmed', 'kid', '.', 'hiding', 'coroner', '.', 'impose', 'qaeda', 'law', '.', 'hara', '##ss', 'inquiries', '.', 'sm', '##ear', 'the', 'horrific', '.', 'worst', '.', 'people', '.', 'ever', '.', 'hash', '##tag', 'jihad', '##tag']
#
#
# Sentencia original:
# ['“' 'user' ':' 'several' 'hostages' 'freed' 'at' 'jewish' 'supermarket'
#  'in' 'paris' '.' 'photo' 'thomas' 'samson' 'hash' '##tag' 'html' 'sc'
#  '##ha' '##ut' 'gen' '##au' 'hi' '##n' '!']
# Sentencia final: 0
# ['“', 'user', ':', 'several', 'hostages', 'freed', 'at', 'jewish', 'moscow', 'in', 'photograph', '.', 'photo', 'thomas', 'carnage', 'jihad', '##tag', 'html', 'sc', '##ha', '##ut', 'gen', '##au', 'hi', '##n', '!']
#
#
# Sentencia original:
# ['“' 'user' ':' 'breaking' 'news' ':' 'gunmen' 'take' 'hostages' 'at'
#  'sydney' 'cafe' ',' 'wave' 'islamic' 'flag' 'html' 'html']
# Sentencia final: 0
# ['“', 'user', ':', 'dropping', 'gunfire', ':', 'journalists', 'take', 'perpetrators', 'at', 'sydney', 'cafe', ',', 'wave', 'islamic', 'fascism', 'html', 'html']
#
#
# Sentencia original:
# ['breaking' 'news' ':' 'gunmen' 'take' 'hostages' 'at' 'sydney' 'cafe' ','
#  'wave' 'islamic' 'flag' 'html' 'html']
# Sentencia final: 0
# ['breaking', 'news', ':', 'gunmen', 'impose', 'terrorists', 'at', 'sydney', 'cafe', ',', 'wave', 'iranian', 'fascism', 'html', 'html']
#
#
# Sentencia original:
# ['user' 'user' 'like' 'i' 'said' 'it' "'" 's' 'directly' 'across' 'from'
#  'a' 'big' 'news' 'channel' '.']
# Sentencia final: 0
# ['user', 'user', 'like', 'time', 'said', 'it', "'", 's', 'directly', 'across', 'from', 'a', 'big', 'news', 'channel', '.']
#
#
# Sentencia original:
# ['user' 'best' 'news' 'i' 'have' 'heard' ',' 'kay' 'you' 'are' 'doing'
#  'an' 'amazing' 'job' 'thank' 'you']
# Sentencia final: 0
# ['user', 'best', 'information', 'i', 'see', 'heard', ',', 'kay', 'you', 'am', 'doing', 'an', 'frustrating', 'awesome', 'honor', 'you']
#
#
# Sentencia original:
# ['"' 'user' ':' 'the' 'hash' '##tag' 'attack' 'suspects' 'have'
#  'reportedly' 'fired' 'shots' 'while' 'rob' 'a' 'petrol' 'station' 'html'
#  'hash' '##tag']
# Sentencia final: 0
# ['"', 'user', ':', 'the', 'qaeda', '##tag', 'attack', 'suspects', 'have', 'reportedly', 'fired', 'gunmen', 'while', 'robbed', 'a', 'petrol', 'station', 'html', 'hash', '##tag']
#
#
# Sentencia original:
# ['we' 'can' 'see' 'people' 'coming' 'out' 'a' 'fired' '##oor' 'near' 'the'
#  'lin' '##dt' 'cafe' 'to' 'waiting' 'police' '.' 'number' '-' 'number'
#  'people' '.' 'hard' 'to' 'see' '.' 'hash' '##tag']
# Sentencia final: 0
# ['we', 'can', 'see', 'men', 'coming', 'out', 'a', 'fired', '##oor', 'near', 'the', 'lin', '##dt', 'cafe', 'to', 'waiting', 'police', '.', 'number', '-', 'person', 'children', '.', 'many', 'to', 'see', '.', 'hash', '##tag']
#
#
# # terms modificados promedio 4.246698362387744 términos por sentencia
# Largo de sentencia promedio 20.29688325409403 términos por sentencia
# para esta ejecución se debiesen reemplazar 11015  de 22133 terminos
# Resumen de modificaciones: {'JJ': 527, 'NN': 4962, 'NNS': 890, 'VBG': 438, 'VB': 296, 'VBP': 96, 'VBZ': 232, 'VBN': 302, 'VBD': 229, 'JJS': 60, 'JJR': 7}
# Este proceso tomó 41.134838581085205 seg
#
#
# Generando 2401 nuevos ejemplos para la clase denying
# Consultando por la clase denying
# Entrega label 1
# Sentencia original:
# ['user' 'legally' 'speaking' 'it' 'doesn' "'" 't' 'matter' '.' 'the'
#  'question' 'of' 'reasonable' 'fear' 'is' 'at' 'issue' '+' 'the' 'k'
#  '##ra' '##uts' 'were' 'definitely' 'afraid' 'of' 'my' 'grandpa' '.']
# Sentencia final: 1
# ['user', 'legally', 'speaking', 'it', 'doesn', "'", 't', 'need', '.', 'the', 'question', 'of', 'plausible', 'afraid', 'is', 'at', 'issue', 'problem', 'the', 'k', '##ra', '##uts', 'was', 'definitely', 'afraid', 'of', 'my', 'grandpa', '.']
#
#
# Sentencia original:
# ['user' 'user' 'user' 'user' 'what' 'other' 'info' 'do' 'they' 'have'
#  'ready' 'to' 'release' '?' 'all' 'they' 'have' 'said' 'is' 'this' 'is'
#  'why' 'we' 'approached' 'him' '.']
# Sentencia final: 1
# ['user', 'user', 'user', 'user', 'what', 'other', 'info', 'do', 'they', 'have', 'ready', 'to', 'freed', '?', 'all', 'they', 'do', 'had', 'has', 'this', 'is', 'why', 'we', 'contacted', 'him', '.']
#
#
# Sentencia original:
# ['user' 'user' '"' 'grease' 'my' 'palm' 'with' 'silver' 'lo' '##vie' '.'
#  '"' 'the' 'disgrace' '##ful' 'prick' '.' 'run' "'" 'em' 'outta' 'town'
#  'folks' '.']
# Sentencia final: 1
# ['user', 'user', '"', 'grease', 'my', 'palm', 'with', 'silver', 'life', '##vie', '.', '"', 'the', 'disgrace', '##ful', 'leftist', '.', 'run', "'", 'worthless', 'outta', 'yer', 'folks', '.']
#
#
# Sentencia original:
# ['user' 'user' 'it' "'" 's' 'not' 'a' 'matter' 'of' 'criticism' ',' 'it'
#  "'" 's' 'insulting' 'and' 'dem' '##ean' '##ing' 'and' 'offensive']
# Sentencia final: 1
# ['user', 'user', 'it', "'", 's', 'not', 'a', 'matter', 'of', 'discussion', ',', 'it', "'", 'insult', 'insulting', 'and', 'leftist', '##ean', '##ing', 'and', 'white']
#
#
# Sentencia original:
# ['user' 'of' 'course' ',' 'however' 'please' 'do' 'not' 'try' 'and'
#  'compare' 'it' 'to' 'hundreds' 'of' 'years' 'of' 'systemic' 'oppression'
#  'of' 'a' 'whole' 'people']
# Sentencia final: 1
# ['user', 'of', 'topic', ',', 'however', 'please', 'do', 'not', 'try', 'and', 'compare', 'it', 'to', 'hundreds', 'of', 'riots', 'of', 'systemic', 'oppression', 'of', 'a', 'entire', 'people']
#
#
# Sentencia original:
# ['heartbreak' 'for' 'hash' '##tag' 'and' 'canada' '.' '“' 'user' ':'
#  'soldier' 'killed' 'in' 'canada' 'shooting' 'was' 'a' 'young' 'res'
#  '##er' '##vis' '##t' 'with' 'a' 'son' 'html']
# Sentencia final: 1
# ['damn', 'for', 'qaeda', '##tag', 'and', 'canada', '.', '“', 'user', ':', 'soldier', 'killed', 'in', 'canada', 'shooting', 'were', 'a', 'young', 'res', '##er', '##vis', '##t', 'with', 'a', 'son', 'html']
#
#
# Sentencia original:
# ['user' '"' 'may' 'be' '"' 'really' '?' 'forehead' 'smack']
# Sentencia final: 1
# ['user', '"', 'may', 'be', '"', 'really', '?', 'forehead', 'stupidity']
#
#
# Sentencia original:
# ['user' 'user' 'user' 'i' "'" 'm' 'not' 'watching' 'it' ',' 'but' 'it'
#  'sounds' 'as' 'if' 'it' 'is' 'being' 'treated' 'as' 'sport' '.']
# Sentencia final: 1
# ['user', 'user', 'user', 'i', "'", 'watch', 'not', 'watching', 'it', ',', 'but', 'it', 'media', 'as', 'if', 'it', 'has', 'having', 'treated', 'as', 'treat', '.']
#
#
# Sentencia original:
# ['user' 'kindly' 'verify' 'your' 'report' 'of' 'shooting' 'at' 'ride'
#  '##au' 'centre' 'ottawa' ',' 'canada' '.' 'local' 'reports' 'state'
#  'otherwise' '.']
# Sentencia final: 1
# ['user', 'kindly', 'verify', 'your', 'report', 'of', 'shooting', 'at', 'ride', '##au', 'centre', 'ottawa', ',', 'canada', '.', 'current', 'reports', 'state', 'otherwise', '.']
# # terms modificados promedio 3.851728446480633 términos por sentencia
# Largo de sentencia promedio 20.18908788004998 términos por sentencia
# para esta ejecución se debiesen reemplazar 13187  de 26402 terminos
# Resumen de modificaciones: {'NN': 5406, 'JJ': 737, 'VBD': 301, 'VB': 552, 'VBZ': 442, 'VBN': 317, 'NNS': 894, 'VBG': 410, 'VBP': 159, 'JJR': 19, 'JJS': 11}
# Este proceso tomó 45.679264068603516 seg
#
# --------------------------------------------------------
#
# Generando ejemplos en base a probabilidad -->  0.5
# --------------------------------------------------------
#
#
# Generando 2404 nuevos ejemplos para la clase questioning
# Consultando por la clase questioning
# Entrega label 2
# Sentencia original:
# ['user' 'user' 'clarified' 'that' 'earlier' '.' 'cheers']
# Sentencia final: 2
# ['user', 'user', 'clarified', 'that', 'earlier', '.', 'words']
#
#
# Sentencia original:
# ['user' 'user' 'any' 'chance' 'that' "'" 's' 'being' 'said' 'for' 'fear'
#  'of' 'retribution' '?']
# Sentencia final: 2
# ['user', 'user', 'any', 'chance', 'that', "'", 'thought', 'being', 'said', 'for', 'reply', 'of', 'retribution', '?']
#
#
# Sentencia original:
# ['user' 'user' 'user' 'how' 'stupid' 'html']
# Sentencia final: 2
# ['user', 'user', 'user', 'how', 'expensive', 'html']
#
#
# Sentencia original:
# ['user' 'user' 'user' 'user' 'ah' 'true' '.' 'problem' 'now' 'is' 'we' "'"
#  'll' 'probably' 'only' 'get' 'coroner' "'" 's' 'details' 'they' 'won' "'"
#  't' 'make' 'it' '.']
# Sentencia final: 2
# ['user', 'user', 'user', 'user', 'ah', 'real', '.', 'problem', 'now', 'is', 'we', "'", 'won', 'probably', 'only', 'get', 'coroner', "'", 's', 'details', 'they', 'won', "'", 'splitting', 'be', 'it', '.']
#
#
# Sentencia original:
# ['user' ',' 'hi' 'betty' '.' 'you' 'are' 'in' 'australia' '?']
# Sentencia final: 2
# ['user', ',', 'clarify', 'betty', '.', 'you', 'are', 'in', 'australia', '?']
#
#
# Sentencia original:
# ['user' 'user' 'if' 'so' 'that' 'hostage' 'will' 'be' 'the' 'person'
#  'best' 'able' 'to' 'give' 'an' 'insight' 'into' 'the' 'attack' ',' 'if'
#  'the' 'suspects' 'were' 'responsible' '.']
# Sentencia final: 2
# ['user', 'user', 'if', 'so', 'that', 'time', 'will', 'happen', 'the', 'person', 'best', 'unable', 'to', 'get', 'an', 'insight', 'into', 'the', 'attack', ',', 'if', 'the', 'thanks', 'was', 'responsible', '.']
#
#
# Sentencia original:
# ['user' 'i' 'thought' 'police' 'asked' 'media' 'not' 'to' 'report'
#  'demands' '.' 'why' 'you' 'giving' 'these' 'terrorists' 'a' 'voice' '?']
# Sentencia final: 2
# ['user', 'i', 'clarify', 'police', 'called', 'people', 'not', 'to', 'reporting', 'reports', '.', 'why', 'you', 'going', 'these', 'terrorists', 'a', 'voice', '?']
#
#
# Sentencia original:
# ['user' 'user' 'you' "'" 're' 'choosing' 'to' 'talk' 'about' 'a' '"'
#  'robbery' '"' 'based' 'on' 'a' 'tape' 'that' 'only' 'shows' 'a'
#  'confrontation' 'not' 'a' 'crime' '.' 'so' 'stop' '!']
# Sentencia final: 2
# ['user', 'user', 'you', "'", 'choice', 'choosing', 'to', 'talk', 'about', 'a', '"', 'robbery', '"', 'made', 'on', 'a', 'gunshot', 'that', 'only', 'weeks', 'a', 'show', 'not', 'a', 'crime', '.', 'so', 'thank', '!']
#
#
# Sentencia original:
# ['user' 'is' 'this' 'photo' 'from' 'last' 'night' '?' '?' 'please'
#  'clarify' 'because' 'you' 'are' 'using' 'present' 'tense' '.']
# Sentencia final: 2
# ['user', 'has', 'this', 'photo', 'from', 'next', 'night', '?', '?', 'please', 'clarify', 'because', 'you', 'am', 'being', 'present', 'tense', '.']
#
#
# # terms modificados promedio 3.266638935108153 términos por sentencia
# Largo de sentencia promedio 17.602745424292845 términos por sentencia
# para esta ejecución se debiesen reemplazar 11555  de 23229 terminos
# Resumen de modificaciones: {'NNS': 767, 'NN': 4461, 'JJ': 500, 'VB': 516, 'VBD': 328, 'VBN': 294, 'VBG': 333, 'VBZ': 458, 'VBP': 174, 'JJR': 9, 'JJS': 13}
# Este proceso tomó 38.978275299072266 seg
#
#
# Generando 0 nuevos ejemplos para la clase commenting
# Consultando por la clase commenting
# Entrega label 3
# No se generan ejemplos
# Resumen de modificaciones: {}
# Este proceso tomó 0.19480323791503906 seg
#
#
# Generando 1893 nuevos ejemplos para la clase support
# Consultando por la clase support
# Entrega label 0
# Sentencia original:
# ['user' 'some' 'good' 'news' '!']
# Sentencia final: 0
# ['user', 'some', 'bad', 'news', '!']
#
#
# Sentencia original:
# ['shoot' 'unarmed' 'kid' '.' 'conceal' 'evidence' '.' 'impose' 'martial'
#  'law' '.' 'hara' '##ss' 'reporters' '.' 'sm' '##ear' 'the' 'victim' '.'
#  'worst' '.' 'police' '.' 'ever' '.' 'hash' '##tag' 'hash' '##tag']
# Sentencia final: 0
# ['assassinate', 'uniformed', 'assassinate', '.', 'hiding', 'evidence', '.', 'impose', 'assassinate', 'lawyer', '.', 'hara', '##ss', 'journalists', '.', 'sm', '##ear', 'the', 'victim', '.', 'fastest', '.', 'cops', '.', 'ever', '.', 'qaeda', '##tag', 'hash', '##tag']
#
#
# Sentencia original:
# ['“' 'user' ':' 'several' 'hostages' 'freed' 'at' 'jewish' 'supermarket'
#  'in' 'paris' '.' 'photo' 'thomas' 'samson' 'hash' '##tag' 'html' 'sc'
#  '##ha' '##ut' 'gen' '##au' 'hi' '##n' '!']
# Sentencia final: 0
# ['“', 'user', ':', 'several', 'hostages', 'jew', 'at', 'jew', 'moscow', 'in', 'photograph', '.', 'photo', 'henry', 'samson', 'jihad', '##tag', 'html', 'sc', '##ha', '##ut', 'gen', '##au', 'hi', '##n', '!']
#
#
# Sentencia original:
# ['“' 'user' ':' 'breaking' 'news' ':' 'gunmen' 'take' 'hostages' 'at'
#  'sydney' 'cafe' ',' 'wave' 'islamic' 'flag' 'html' 'html']
# Sentencia final: 0
# ['“', 'user', ':', 'stealing', 'broken', ':', 'journalists', 'impose', 'hostages', 'at', 'hostage', 'cafe', ',', 'wave', 'islamic', 'fascism', 'html', 'html']
#
#
# Sentencia original:
# ['breaking' 'news' ':' 'gunmen' 'take' 'hostages' 'at' 'sydney' 'cafe' ','
#  'wave' 'islamic' 'flag' 'html' 'html']
# Sentencia final: 0
# ['breaking', 'gunfire', ':', 'gunmen', 'take', 'perpetrators', 'at', 'sydney', 'chicago', ',', 'wave', 'swiss', 'islam', 'html', 'html']
#
#
# Sentencia original:
# ['user' 'user' 'like' 'i' 'said' 'it' "'" 's' 'directly' 'across' 'from'
#  'a' 'big' 'news' 'channel' '.']
# Sentencia final: 0
# ['user', 'user', 'like', 'i', 'said', 'it', "'", 's', 'directly', 'across', 'from', 'a', 'big', 'news', 'channels', '.']
#
#
# Sentencia original:
# ['user' 'best' 'news' 'i' 'have' 'heard' ',' 'kay' 'you' 'are' 'doing'
#  'an' 'amazing' 'job' 'thank' 'you']
# Sentencia final: 0
# ['user', 'best', 'use', 'found', 'know', 'hear', ',', 'kay', 'you', 'am', 'doing', 'an', 'frustrating', 'employee', 'wow', 'you']
#
#
# Sentencia original:
# ['"' 'user' ':' 'the' 'hash' '##tag' 'attack' 'suspects' 'have'
#  'reportedly' 'fired' 'shots' 'while' 'rob' 'a' 'petrol' 'station' 'html'
#  'hash' '##tag']
# Sentencia final: 0
# ['"', 'user', ':', 'the', 'hash', '##tag', 'attack', 'suspects', 'have', 'reportedly', 'harmed', 'gunmen', 'while', 'robbed', 'a', 'petrol', 'carnage', 'html', 'qaeda', '##tag']
#
#
# Sentencia original:
# ['we' 'can' 'see' 'people' 'coming' 'out' 'a' 'fired' '##oor' 'near' 'the'
#  'lin' '##dt' 'cafe' 'to' 'waiting' 'police' '.' 'number' '-' 'number'
#  'people' '.' 'hard' 'to' 'see' '.' 'hash' '##tag']
# Sentencia final: 0
# ['we', 'can', 'come', 'men', 'being', 'out', 'a', 'mohamed', '##oor', 'near', 'the', 'lin', '##dt', 'wait', 'to', 'waiting', 'police', '.', 'number', '-', 'number', 'things', '.', 'hard', 'to', 'see', '.', 'hash', '##tag']
#
#
# # terms modificados promedio 4.246698362387744 términos por sentencia
# Largo de sentencia promedio 20.367670364500793 términos por sentencia
# para esta ejecución se debiesen reemplazar 11074  de 22175 terminos
# Resumen de modificaciones: {'JJ': 527, 'NN': 5005, 'NNS': 885, 'JJS': 58, 'VBG': 412, 'VB': 307, 'VBP': 89, 'VBN': 301, 'VBZ': 215, 'VBD': 231, 'JJR': 9}
# Este proceso tomó 41.5098192691803 seg
#
#
# Generando 2401 nuevos ejemplos para la clase denying
# Consultando por la clase denying
# Entrega label 1
# Sentencia original:
# ['user' 'legally' 'speaking' 'it' 'doesn' "'" 't' 'matter' '.' 'the'
#  'question' 'of' 'reasonable' 'fear' 'is' 'at' 'issue' '+' 'the' 'k'
#  '##ra' '##uts' 'were' 'definitely' 'afraid' 'of' 'my' 'grandpa' '.']
# Sentencia final: 1
# ['user', 'legally', 'speaking', 'it', 'doesn', "'", 't', 'matter', '.', 'the', 'debate', 'of', 'reasonable', 'lie', 'is', 'at', 'problem', 'problem', 'the', 'k', '##ra', '##uts', 'was', 'definitely', 'fear', 'of', 'my', 'grandpa', '.']
#
#
# Sentencia original:
# ['user' 'user' 'user' 'user' 'what' 'other' 'info' 'do' 'they' 'have'
#  'ready' 'to' 'release' '?' 'all' 'they' 'have' 'said' 'is' 'this' 'is'
#  'why' 'we' 'approached' 'him' '.']
# Sentencia final: 1
# ['user', 'user', 'user', 'user', 'what', 'other', 'info', 'take', 'they', 'go', 'ready', 'to', 'release', '?', 'all', 'they', 'have', 'was', 'is', 'this', 'is', 'why', 'we', 'contacted', 'him', '.']
#
#
# Sentencia original:
# ['user' 'user' '"' 'grease' 'my' 'palm' 'with' 'silver' 'lo' '##vie' '.'
#  '"' 'the' 'disgrace' '##ful' 'prick' '.' 'run' "'" 'em' 'outta' 'town'
#  'folks' '.']
# Sentencia final: 1
# ['user', 'user', '"', 'grease', 'my', 'palm', 'with', 'silver', 'life', '##vie', '.', '"', 'the', 'disgrace', '##ful', 'prick', '.', 'run', "'", 'worthless', 'outta', 'town', 'folks', '.']
#
#
# Sentencia original:
# ['user' 'user' 'it' "'" 's' 'not' 'a' 'matter' 'of' 'criticism' ',' 'it'
#  "'" 's' 'insulting' 'and' 'dem' '##ean' '##ing' 'and' 'offensive']
# Sentencia final: 1
# ['user', 'user', 'it', "'", 's', 'not', 'a', 'matter', 'of', 'criticism', ',', 'it', "'", 's', 'murdering', 'and', 'leftist', '##ean', '##ing', 'and', 'white']
#
#
# Sentencia original:
# ['user' 'of' 'course' ',' 'however' 'please' 'do' 'not' 'try' 'and'
#  'compare' 'it' 'to' 'hundreds' 'of' 'years' 'of' 'systemic' 'oppression'
#  'of' 'a' 'whole' 'people']
# Sentencia final: 1
# ['user', 'of', 'use', ',', 'however', 'please', 'go', 'not', 'try', 'and', 'attempt', 'it', 'to', 'days', 'of', 'years', 'of', 'systemic', 'oppression', 'of', 'a', 'whole', 'men']
#
#
# Sentencia original:
# ['heartbreak' 'for' 'hash' '##tag' 'and' 'canada' '.' '“' 'user' ':'
#  'soldier' 'killed' 'in' 'canada' 'shooting' 'was' 'a' 'young' 'res'
#  '##er' '##vis' '##t' 'with' 'a' 'son' 'html']
# Sentencia final: 1
# ['heartbreak', 'for', 'hash', '##tag', 'and', 'canadian', '.', '“', 'user', ':', 'soldier', 'murdered', 'in', 'shoot', 'being', 'was', 'a', 'new', 'res', '##er', '##vis', '##t', 'with', 'a', 'son', 'html']
#
#
# Sentencia original:
# ['user' 'user' 'user' 'i' "'" 'm' 'not' 'watching' 'it' ',' 'but' 'it'
#  'sounds' 'as' 'if' 'it' 'is' 'being' 'treated' 'as' 'sport' '.']
# Sentencia final: 1
# ['user', 'user', 'user', 'i', "'", 'm', 'not', 'watching', 'it', ',', 'but', 'it', 'sounds', 'as', 'if', 'it', 'is', 'having', 'fascinated', 'as', 'sport', '.']
#
#
# Sentencia original:
# ['user' 'kindly' 'verify' 'your' 'report' 'of' 'shooting' 'at' 'ride'
#  '##au' 'centre' 'ottawa' ',' 'canada' '.' 'local' 'reports' 'state'
#  'otherwise' '.']
# Sentencia final: 1
# ['user', 'kindly', 'verify', 'your', 'report', 'of', 'coming', 'at', 'ride', '##au', 'halifax', 'canadian', ',', 'canada', '.', 'systemic', 'people', 'country', 'otherwise', '.']
#
#
# Sentencia original:
# ['“' 'user' ':' 'hash' '##tag' 'three' 'men' 'including' 'two' 'brothers'
#  'identified' 'in' 'france' 'newspaper' 'attack' ':' 'source' 'html'
#  'hash' '##tag' '”']
# Sentencia final: 1
# ['“', 'user', ':', 'hash', '##tag', 'three', 'people', 'being', 'two', 'brothers', 'confirmed', 'in', 'france', 'newspaper', 'attack', ':', 'source', 'html', 'qaeda', '##tag', '”']
# # terms modificados promedio 3.8958767180341525 términos por sentencia
# Largo de sentencia promedio 20.367346938775512 términos por sentencia
# para esta ejecución se debiesen reemplazar 13345  de 26715 terminos
# Resumen de modificaciones: {'NN': 5465, 'VBD': 313, 'VB': 579, 'VBN': 313, 'VBG': 433, 'JJ': 746, 'NNS': 878, 'VBZ': 429, 'VBP': 160, 'JJS': 13, 'JJR': 25}
# Este proceso tomó 46.356165409088135 seg
#
# --------------------------------------------------------
#
# Generando ejemplos en base a probabilidad -->  0.5
# --------------------------------------------------------
#
#
# Generando 2404 nuevos ejemplos para la clase questioning
# Consultando por la clase questioning
# Entrega label 2
# Sentencia original:
# ['user' 'user' 'clarified' 'that' 'earlier' '.' 'cheers']
# Sentencia final: 2
# ['user', 'user', 'commented', 'that', 'earlier', '.', 'cheers']
#
#
# Sentencia original:
# ['user' 'user' 'any' 'chance' 'that' "'" 's' 'being' 'said' 'for' 'fear'
#  'of' 'retribution' '?']
# Sentencia final: 2
# ['user', 'user', 'any', 'chance', 'that', "'", 's', 'having', 'said', 'for', 'fear', 'of', 'retribution', '?']
#
#
# Sentencia original:
# ['user' 'user' 'user' 'how' 'stupid' 'html']
# Sentencia final: 2
# ['user', 'user', 'user', 'how', 'sarcastic', 'html']
#
#
# Sentencia original:
# ['user' 'user' 'user' 'user' 'ah' 'true' '.' 'problem' 'now' 'is' 'we' "'"
#  'll' 'probably' 'only' 'get' 'coroner' "'" 's' 'details' 'they' 'won' "'"
#  't' 'make' 'it' '.']
# Sentencia final: 2
# ['user', 'user', 'user', 'user', 'gunshot', 'true', '.', 'problem', 'now', 'is', 'we', "'", 'gonna', 'probably', 'only', 'get', 'coroner', "'", 's', 'details', 'they', 'retribution', "'", 'man', 'make', 'it', '.']
#
#
# Sentencia original:
# ['user' ',' 'hi' 'betty' '.' 'you' 'are' 'in' 'australia' '?']
# Sentencia final: 2
# ['user', ',', 'hi', 'betty', '.', 'you', 'am', 'in', 'children', '?']
#
#
# Sentencia original:
# ['user' 'user' 'if' 'so' 'that' 'hostage' 'will' 'be' 'the' 'person'
#  'best' 'able' 'to' 'give' 'an' 'insight' 'into' 'the' 'attack' ',' 'if'
#  'the' 'suspects' 'were' 'responsible' '.']
# Sentencia final: 2
# ['user', 'user', 'if', 'so', 'that', 'hand', 'will', 'get', 'the', 'man', 'most', 'unable', 'to', 'give', 'an', 'coroner', 'into', 'the', 'point', ',', 'if', 'the', 'suspects', 'were', 'concerned', '.']
#
#
# Sentencia original:
# ['user' 'i' 'thought' 'police' 'asked' 'media' 'not' 'to' 'report'
#  'demands' '.' 'why' 'you' 'giving' 'these' 'terrorists' 'a' 'voice' '?']
# Sentencia final: 2
# ['user', 'time', 'thought', 'police', 'called', 'media', 'not', 'to', 'report', 'reports', '.', 'why', 'you', 'giving', 'these', 'terrorists', 'a', 'voice', '?']
#
#
# Sentencia original:
# ['user' 'user' 'you' "'" 're' 'choosing' 'to' 'talk' 'about' 'a' '"'
#  'robbery' '"' 'based' 'on' 'a' 'tape' 'that' 'only' 'shows' 'a'
#  'confrontation' 'not' 'a' 'crime' '.' 'so' 'stop' '!']
# Sentencia final: 2
# ['user', 'user', 'you', "'", 're', 'choosing', 'to', 'talk', 'about', 'a', '"', 'robbery', '"', 'called', 'on', 'a', 'gunshot', 'that', 'only', 'investigations', 'a', 'robbery', 'not', 'a', 'crime', '.', 'so', 'time', '!']
#
#
# Sentencia original:
# ['user' 'is' 'this' 'photo' 'from' 'last' 'night' '?' '?' 'please'
#  'clarify' 'because' 'you' 'are' 'using' 'present' 'tense' '.']
# Sentencia final: 2
# ['user', 'has', 'this', 'photo', 'from', 'last', 'night', '?', '?', 'understand', 'clarify', 'because', 'you', 'am', 'trying', 'present', 'tense', '.']
#
#
# # terms modificados promedio 3.3082362728785357 términos por sentencia
# Largo de sentencia promedio 17.60565723793677 términos por sentencia
# para esta ejecución se debiesen reemplazar 11592  de 23146 terminos
# Resumen de modificaciones: {'VBN': 280, 'VBG': 345, 'JJ': 514, 'NN': 4554, 'VBP': 180, 'NNS': 763, 'VB': 509, 'JJS': 7, 'VBZ': 467, 'VBD': 325, 'JJR': 9}
# Este proceso tomó 39.39748668670654 seg
#
#
# Generando 0 nuevos ejemplos para la clase commenting
# Consultando por la clase commenting
# Entrega label 3
# No se generan ejemplos
# Resumen de modificaciones: {}
# Este proceso tomó 0.1923973560333252 seg
#
#
# Generando 1893 nuevos ejemplos para la clase support
# Consultando por la clase support
# Entrega label 0
# Sentencia original:
# ['shoot' 'unarmed' 'kid' '.' 'conceal' 'evidence' '.' 'impose' 'martial'
#  'law' '.' 'hara' '##ss' 'reporters' '.' 'sm' '##ear' 'the' 'victim' '.'
#  'worst' '.' 'police' '.' 'ever' '.' 'hash' '##tag' 'hash' '##tag']
# Sentencia final: 0
# ['shoot', 'unarmed', 'assassinate', '.', 'conceal', 'assassinate', '.', 'impose', 'martial', 'lawyer', '.', 'hara', '##ss', 'reporters', '.', 'sm', '##ear', 'the', 'horrific', '.', 'worst', '.', 'cops', '.', 'ever', '.', 'hash', '##tag', 'jihad', '##tag']
#
#
# Sentencia original:
# ['“' 'user' ':' 'several' 'hostages' 'freed' 'at' 'jewish' 'supermarket'
#  'in' 'paris' '.' 'photo' 'thomas' 'samson' 'hash' '##tag' 'html' 'sc'
#  '##ha' '##ut' 'gen' '##au' 'hi' '##n' '!']
# Sentencia final: 0
# ['“', 'user', ':', 'several', 'hostages', 'leftist', 'at', 'jew', 'supermarket', 'in', 'paris', '.', 'photo', 'henry', 'carnage', 'jihad', '##tag', 'html', 'sc', '##ha', '##ut', 'gen', '##au', 'hi', '##n', '!']
#
#
# Sentencia original:
# ['“' 'user' ':' 'breaking' 'news' ':' 'gunmen' 'take' 'hostages' 'at'
#  'sydney' 'cafe' ',' 'wave' 'islamic' 'flag' 'html' 'html']
# Sentencia final: 0
# ['“', 'user', ':', 'stealing', 'cnn', ':', 'gunmen', 'take', 'perpetrators', 'at', 'london', 'cafe', ',', 'wave', 'iranian', 'islam', 'html', 'html']
#
#
# Sentencia original:
# ['breaking' 'news' ':' 'gunmen' 'take' 'hostages' 'at' 'sydney' 'cafe' ','
#  'wave' 'islamic' 'flag' 'html' 'html']
# Sentencia final: 0
# ['stealing', 'news', ':', 'journalists', 'take', 'hostages', 'at', 'hostage', 'cafe', ',', 'wave', 'swiss', 'flag', 'html', 'html']
#
#
# Sentencia original:
# ['user' 'user' 'like' 'i' 'said' 'it' "'" 's' 'directly' 'across' 'from'
#  'a' 'big' 'news' 'channel' '.']
# Sentencia final: 0
# ['user', 'user', 'like', 'use', 'said', 'it', "'", 're', 'directly', 'across', 'from', 'a', 'big', 'news', 'channels', '.']
#
#
# Sentencia original:
# ['user' 'best' 'news' 'i' 'have' 'heard' ',' 'kay' 'you' 'are' 'doing'
#  'an' 'amazing' 'job' 'thank' 'you']
# Sentencia final: 0
# ['user', 'best', 'news', 'comedic', 'have', 'heard', ',', 'kay', 'you', 'are', 'exciting', 'an', 'frustrating', 'employee', 'thank', 'you']
#
#
# Sentencia original:
# ['"' 'user' ':' 'the' 'hash' '##tag' 'attack' 'suspects' 'have'
#  'reportedly' 'fired' 'shots' 'while' 'rob' 'a' 'petrol' 'station' 'html'
#  'hash' '##tag']
# Sentencia final: 0
# ['"', 'user', ':', 'the', 'qaeda', '##tag', 'attack', 'assaults', 'have', 'reportedly', 'fired', 'gunmen', 'while', 'assassinate', 'a', 'petrol', 'station', 'html', 'hash', '##tag']
#
#
# Sentencia original:
# ['we' 'can' 'see' 'people' 'coming' 'out' 'a' 'fired' '##oor' 'near' 'the'
#  'lin' '##dt' 'cafe' 'to' 'waiting' 'police' '.' 'number' '-' 'number'
#  'people' '.' 'hard' 'to' 'see' '.' 'hash' '##tag']
# Sentencia final: 0
# ['we', 'can', 'come', 'people', 'coming', 'out', 'a', 'killed', '##oor', 'near', 'the', 'lin', '##dt', 'leftist', 'to', 'waiting', 'policemen', '.', 'number', '-', 'person', 'people', '.', 'black', 'to', 'see', '.', 'hear', '##tag']
#
#
# Sentencia original:
# ['flag' 'in' 'window' 'of' 'sydney' 'lin' '##dt' 'cafe' 'not' 'an' 'isis'
#  'flag' '.' 'reads' ':' '‘' 'there' 'is' 'no' 'god' 'but' 'allah' 'and'
#  'muhammad' 'is' 'the' 'messenger' 'of' 'god' '’' 'user']
# Sentencia final: 0
# ['map', 'in', 'window', 'of', 'sydney', 'lin', '##dt', 'shop', 'not', 'an', 'isis', 'read', '.', 'publishes', ':', 'isn', 'there', 'gets', 'no', 'satan', 'but', 'allah', 'and', 'islam', 'is', 'the', 'messenger', 'of', 'assassinate', 'qaeda', 'user']
#
#
# # terms modificados promedio 4.317485472794506 términos por sentencia
# Largo de sentencia promedio 20.398837823560488 términos por sentencia
# para esta ejecución se debiesen reemplazar 11128  de 22189 terminos
# Resumen de modificaciones: {'NN': 5088, 'NNS': 927, 'VBG': 384, 'JJ': 553, 'VB': 299, 'VBN': 312, 'VBZ': 209, 'VBP': 98, 'VBD': 239, 'JJS': 58, 'JJR': 6}
# Este proceso tomó 41.7729229927063 seg
#
#
# Generando 2401 nuevos ejemplos para la clase denying
# Consultando por la clase denying
# Entrega label 1
# Sentencia original:
# ['user' 'legally' 'speaking' 'it' 'doesn' "'" 't' 'matter' '.' 'the'
#  'question' 'of' 'reasonable' 'fear' 'is' 'at' 'issue' '+' 'the' 'k'
#  '##ra' '##uts' 'were' 'definitely' 'afraid' 'of' 'my' 'grandpa' '.']
# Sentencia final: 1
# ['user', 'legally', 'speaking', 'it', 'didn', "'", 't', 'matter', '.', 'the', 'question', 'of', 'plausible', 'fear', 'is', 'at', 'issue', 'problem', 'the', 'k', '##ra', '##uts', 'was', 'definitely', 'fear', 'of', 'my', 'grandpa', '.']
#
#
# Sentencia original:
# ['user' 'user' 'user' 'user' 'what' 'other' 'info' 'do' 'they' 'have'
#  'ready' 'to' 'release' '?' 'all' 'they' 'have' 'said' 'is' 'this' 'is'
#  'why' 'we' 'approached' 'him' '.']
# Sentencia final: 1
# ['user', 'user', 'user', 'user', 'what', 'other', 'helpful', 'do', 'they', 'be', 'ready', 'to', 'freed', '?', 'all', 'they', 'have', 'said', 'is', 'this', 'has', 'why', 'we', 'contacted', 'him', '.']
#
#
# Sentencia original:
# ['user' 'user' '"' 'grease' 'my' 'palm' 'with' 'silver' 'lo' '##vie' '.'
#  '"' 'the' 'disgrace' '##ful' 'prick' '.' 'run' "'" 'em' 'outta' 'town'
#  'folks' '.']
# Sentencia final: 1
# ['user', 'user', '"', 'grease', 'my', 'palm', 'with', 'silver', 'life', '##vie', '.', '"', 'the', 'disgrace', '##ful', 'leftist', '.', 'come', "'", 'op', 'gonna', 'town', 'italians', '.']
#
#
# Sentencia original:
# ['user' 'user' 'it' "'" 's' 'not' 'a' 'matter' 'of' 'criticism' ',' 'it'
#  "'" 's' 'insulting' 'and' 'dem' '##ean' '##ing' 'and' 'offensive']
# Sentencia final: 1
# ['user', 'user', 'it', "'", 'sure', 'not', 'a', 'discussion', 'of', 'criticism', ',', 'it', "'", 's', 'disgusting', 'and', 'leftist', '##ean', '##ing', 'and', 'white']
#
#
# Sentencia original:
# ['user' 'of' 'course' ',' 'however' 'please' 'do' 'not' 'try' 'and'
#  'compare' 'it' 'to' 'hundreds' 'of' 'years' 'of' 'systemic' 'oppression'
#  'of' 'a' 'whole' 'people']
# Sentencia final: 1
# ['user', 'of', 'victim', ',', 'however', 'please', 'do', 'not', 'attempt', 'and', 'compare', 'it', 'to', 'days', 'of', 'minutes', 'of', 'systemic', 'oppression', 'of', 'a', 'entire', 'people']
#
#
# Sentencia original:
# ['heartbreak' 'for' 'hash' '##tag' 'and' 'canada' '.' '“' 'user' ':'
#  'soldier' 'killed' 'in' 'canada' 'shooting' 'was' 'a' 'young' 'res'
#  '##er' '##vis' '##t' 'with' 'a' 'son' 'html']
# Sentencia final: 1
# ['reprint', 'for', 'qaeda', '##tag', 'and', 'canada', '.', '“', 'user', ':', 'soldier', 'murdered', 'in', 'wwii', 'shooting', 'were', 'a', 'new', 'res', '##er', '##vis', '##t', 'with', 'a', 'son', 'html']
#
#
# Sentencia original:
# ['user' 'user' 'user' 'i' "'" 'm' 'not' 'watching' 'it' ',' 'but' 'it'
#  'sounds' 'as' 'if' 'it' 'is' 'being' 'treated' 'as' 'sport' '.']
# Sentencia final: 1
# ['user', 'user', 'user', 'employee', "'", 'watch', 'not', 'listening', 'it', ',', 'but', 'it', 'media', 'as', 'if', 'it', 'seems', 'being', 'treated', 'as', 'sport', '.']
# Sentencia original:
# ['user' 'kindly' 'verify' 'your' 'report' 'of' 'shooting' 'at' 'ride'
#  '##au' 'centre' 'ottawa' ',' 'canada' '.' 'local' 'reports' 'state'
#  'otherwise' '.']
# Sentencia final: 1
# ['user', 'kindly', 'verify', 'your', 'reporting', 'of', 'shooting', 'at', 'ride', '##au', 'centre', 'canadian', ',', 'canada', '.', 'local', 'reports', 'county', 'otherwise', '.']
#
#
# Sentencia original:
# ['“' 'user' ':' 'hash' '##tag' 'three' 'men' 'including' 'two' 'brothers'
#  'identified' 'in' 'france' 'newspaper' 'attack' ':' 'source' 'html'
#  'hash' '##tag' '”']
# Sentencia final: 1
# ['“', 'user', ':', 'qaeda', '##tag', 'three', 'people', 'including', 'two', 'members', 'identified', 'in', 'journalism', 'newspaper', 'assault', ':', 'source', 'html', 'hash', '##tag', '”']
#
#
# # terms modificados promedio 3.8713036234902125 términos por sentencia
# Largo de sentencia promedio 20.205747605164515 términos por sentencia
# para esta ejecución se debiesen reemplazar 13188  de 26416 terminos
# Resumen de modificaciones: {'NN': 5396, 'JJ': 754, 'VBD': 318, 'VB': 566, 'VBZ': 417, 'VBN': 304, 'NNS': 938, 'VBG': 424, 'VBP': 148, 'JJR': 18, 'JJS': 12}
# Este proceso tomó 45.75547766685486 seg
#
# --------------------------------------------------------
#
# Generando ejemplos en base a probabilidad -->  0.5
# --------------------------------------------------------
#
#
# Generando 2404 nuevos ejemplos para la clase questioning
# Consultando por la clase questioning
# Entrega label 2
# Sentencia original:
# ['user' 'user' 'any' 'chance' 'that' "'" 's' 'being' 'said' 'for' 'fear'
#  'of' 'retribution' '?']
# Sentencia final: 2
# ['user', 'user', 'any', 'possibility', 'that', "'", 's', 'going', 'said', 'for', 'fear', 'of', 'retribution', '?']
#
#
# Sentencia original:
# ['user' 'user' 'user' 'how' 'stupid' 'html']
# Sentencia final: 2
# ['user', 'user', 'user', 'how', 'sarcastic', 'html']
#
#
# Sentencia original:
# ['user' 'user' 'user' 'user' 'ah' 'true' '.' 'problem' 'now' 'is' 'we' "'"
#  'll' 'probably' 'only' 'get' 'coroner' "'" 's' 'details' 'they' 'won' "'"
#  't' 'make' 'it' '.']
# Sentencia final: 2
# ['user', 'user', 'user', 'user', 'ah', 'true', '.', 'situation', 'now', 'seems', 'we', "'", 'll', 'probably', 'only', 'get', 'helpful', "'", 's', 'details', 'they', 'won', "'", 't', 'find', 'it', '.']
#
#
# Sentencia original:
# ['user' ',' 'hi' 'betty' '.' 'you' 'are' 'in' 'australia' '?']
# Sentencia final: 2
# ['user', ',', 'hi', 'betty', '.', 'you', 'am', 'in', 'australia', '?']
#
#
# Sentencia original:
# ['user' 'user' 'if' 'so' 'that' 'hostage' 'will' 'be' 'the' 'person'
#  'best' 'able' 'to' 'give' 'an' 'insight' 'into' 'the' 'attack' ',' 'if'
#  'the' 'suspects' 'were' 'responsible' '.']
# Sentencia final: 2
# ['user', 'user', 'if', 'so', 'that', 'wasn', 'will', 'get', 'the', 'helpful', 'worst', 'able', 'to', 'assume', 'an', 'insight', 'into', 'the', 'time', ',', 'if', 'the', 'suspects', 'were', 'concerned', '.']
#
#
# Sentencia original:
# ['user' 'i' 'thought' 'police' 'asked' 'media' 'not' 'to' 'report'
#  'demands' '.' 'why' 'you' 'giving' 'these' 'terrorists' 'a' 'voice' '?']
# Sentencia final: 2
# ['user', 'man', 'clarify', 'police', 'asked', 'journalists', 'not', 'to', 'group', 'reports', '.', 'why', 'you', 'causing', 'these', 'terrorists', 'a', 'voice', '?']
#
#
# Sentencia original:
# ['user' 'user' 'you' "'" 're' 'choosing' 'to' 'talk' 'about' 'a' '"'
#  'robbery' '"' 'based' 'on' 'a' 'tape' 'that' 'only' 'shows' 'a'
#  'confrontation' 'not' 'a' 'crime' '.' 'so' 'stop' '!']
# Sentencia final: 2
# ['user', 'user', 'you', "'", 'choice', 'choosing', 'to', 'talk', 'about', 'a', '"', 'robbery', '"', 'focused', 'on', 'a', 'gunshot', 'that', 'only', 'shows', 'a', 'confrontation', 'not', 'a', 'theft', '.', 'so', 'stop', '!']
#
#
# Sentencia original:
# ['user' 'is' 'this' 'photo' 'from' 'last' 'night' '?' '?' 'please'
#  'clarify' 'because' 'you' 'are' 'using' 'present' 'tense' '.']
# Sentencia final: 2
# ['user', 'is', 'this', 'part', 'from', 'unarmed', 'night', '?', '?', 'divert', 'clarify', 'because', 'you', 'are', 'trying', 'present', 'tense', '.']
#
#
# Sentencia original:
# ['user' 'user' 'why' 'was' 'this' 'mad' 'man' 'not' 'behind' 'bars' '?'
#  'u' '##gh']
# Sentencia final: 2
# ['user', 'user', 'why', 'was', 'this', 'mad', 'person', 'not', 'behind', 'bars', '?', 'u', '##gh']
#
#
# # terms modificados promedio 3.276622296173045 términos por sentencia
# Largo de sentencia promedio 17.621048252911812 términos por sentencia
# para esta ejecución se debiesen reemplazar 11557  de 23097 terminos
# Resumen de modificaciones: {'NN': 4527, 'VBG': 363, 'JJ': 505, 'VBZ': 442, 'VB': 525, 'VBP': 192, 'JJS': 12, 'NNS': 720, 'VBN': 264, 'VBD': 314, 'JJR': 13}
# Este proceso tomó 39.03023028373718 seg
#
#
# Generando 0 nuevos ejemplos para la clase commenting
# Consultando por la clase commenting
# Entrega label 3
# No se generan ejemplos
# Resumen de modificaciones: {}
# Este proceso tomó 0.19708561897277832 seg
#
#
# Generando 1893 nuevos ejemplos para la clase support
# Consultando por la clase support
# Entrega label 0
# Sentencia original:
# ['user' 'some' 'good' 'news' '!']
# Sentencia final: 0
# ['user', 'some', 'new', 'news', '!']
#
#
# Sentencia original:
# ['“' 'user' ':' 'several' 'hostages' 'freed' 'at' 'jewish' 'supermarket'
#  'in' 'paris' '.' 'photo' 'thomas' 'samson' 'hash' '##tag' 'html' 'sc'
#  '##ha' '##ut' 'gen' '##au' 'hi' '##n' '!']
# Sentencia final: 0
# ['“', 'user', ':', 'several', 'hostages', 'freed', 'at', 'jewish', 'grocery', 'in', 'paris', '.', 'photo', 'thomas', 'carnage', 'jihad', '##tag', 'html', 'sc', '##ha', '##ut', 'gen', '##au', 'hi', '##n', '!']
#
#
# Sentencia original:
# ['“' 'user' ':' 'breaking' 'news' ':' 'gunmen' 'take' 'hostages' 'at'
#  'sydney' 'cafe' ',' 'wave' 'islamic' 'flag' 'html' 'html']
# Sentencia final: 0
# ['“', 'user', ':', 'breaking', 'gunfire', ':', 'demands', 'take', 'hostages', 'at', 'hostage', 'toronto', ',', 'wave', 'swiss', 'flag', 'html', 'html']
#
#
# Sentencia original:
# ['breaking' 'news' ':' 'gunmen' 'take' 'hostages' 'at' 'sydney' 'cafe' ','
#  'wave' 'islamic' 'flag' 'html' 'html']
# Sentencia final: 0
# ['breaking', 'news', ':', 'gunmen', 'assume', 'hostages', 'at', 'sydney', 'cafe', ',', 'wave', 'islamic', 'fascism', 'html', 'html']
#
#
# Sentencia original:
# ['user' 'user' 'like' 'i' 'said' 'it' "'" 's' 'directly' 'across' 'from'
#  'a' 'big' 'news' 'channel' '.']
# Sentencia final: 0
# ['user', 'user', 'like', 'i', 'said', 'it', "'", 're', 'directly', 'across', 'from', 'a', 'huge', 'show', 'channel', '.']
#
#
# Sentencia original:
# ['user' 'best' 'news' 'i' 'have' 'heard' ',' 'kay' 'you' 'are' 'doing'
#  'an' 'amazing' 'job' 'thank' 'you']
# Sentencia final: 0
# ['user', 'most', 'use', 'i', 'know', 'heard', ',', 'kay', 'you', 'are', 'doing', 'an', 'amazing', 'employee', 'thank', 'you']
#
#
# Sentencia original:
# ['"' 'user' ':' 'the' 'hash' '##tag' 'attack' 'suspects' 'have'
#  'reportedly' 'fired' 'shots' 'while' 'rob' 'a' 'petrol' 'station' 'html'
#  'hash' '##tag']
# Sentencia final: 0
# ['"', 'user', ':', 'the', 'qaeda', '##tag', 'suspect', 'attacks', 'assume', 'reportedly', 'harmed', 'gunmen', 'while', 'robbed', 'a', 'petrol', 'jihad', 'html', 'hash', '##tag']
#
#
# Sentencia original:
# ['we' 'can' 'see' 'people' 'coming' 'out' 'a' 'fired' '##oor' 'near' 'the'
#  'lin' '##dt' 'cafe' 'to' 'waiting' 'police' '.' 'number' '-' 'number'
#  'people' '.' 'hard' 'to' 'see' '.' 'hash' '##tag']
# Sentencia final: 0
# ['we', 'can', 'see', 'people', 'coming', 'out', 'a', 'fired', '##oor', 'near', 'the', 'lin', '##dt', 'leftist', 'to', 'waiting', 'people', '.', 'number', '-', 'number', 'people', '.', 'black', 'to', 'see', '.', 'hash', '##tag']
#
#
# Sentencia original:
# ['flag' 'in' 'window' 'of' 'sydney' 'lin' '##dt' 'cafe' 'not' 'an' 'isis'
#  'flag' '.' 'reads' ':' '‘' 'there' 'is' 'no' 'god' 'but' 'allah' 'and'
#  'muhammad' 'is' 'the' 'messenger' 'of' 'god' '’' 'user']
# Sentencia final: 0
# ['map', 'in', 'window', 'of', 'comedic', 'lin', '##dt', 'shop', 'not', 'an', 'isis', 'flag', '.', 'publishes', ':', '‘', 'there', 'is', 'no', 'satan', 'but', 'jesus', 'and', 'islam', 'is', 'the', 'satan', 'of', 'customer', '’', 'user']
#
#
# # terms modificados promedio 4.182250396196514 términos por sentencia
# Largo de sentencia promedio 20.264131008980453 términos por sentencia
# para esta ejecución se debiesen reemplazar 10868  de 22003 terminos
# Resumen de modificaciones: {'JJ': 546, 'NN': 4922, 'NNS': 855, 'VB': 288, 'JJS': 61, 'VBN': 301, 'VBZ': 228, 'VBP': 95, 'VBD': 236, 'VBG': 375, 'JJR': 10}
# Este proceso tomó 40.8900351524353 seg
#
#
# Generando 2401 nuevos ejemplos para la clase denying
# Consultando por la clase denying
# Entrega label 1
# Sentencia original:
# ['user' 'legally' 'speaking' 'it' 'doesn' "'" 't' 'matter' '.' 'the'
#  'question' 'of' 'reasonable' 'fear' 'is' 'at' 'issue' '+' 'the' 'k'
#  '##ra' '##uts' 'were' 'definitely' 'afraid' 'of' 'my' 'grandpa' '.']
# Sentencia final: 1
# ['user', 'legally', 'speaking', 'it', 'doesn', "'", 'didn', 'issue', '.', 'the', 'gonna', 'of', 'reasonable', 'hope', 'is', 'at', 'problem', '+', 'the', 'k', '##ra', '##uts', 'were', 'definitely', 'afraid', 'of', 'my', 'grandpa', '.']
#
#
# Sentencia original:
# ['user' 'user' 'user' 'user' 'what' 'other' 'info' 'do' 'they' 'have'
#  'ready' 'to' 'release' '?' 'all' 'they' 'have' 'said' 'is' 'this' 'is'
#  'why' 'we' 'approached' 'him' '.']
# Sentencia final: 1
# ['user', 'user', 'user', 'user', 'what', 'other', 'info', 'do', 'they', 'have', 'prepared', 'to', 'release', '?', 'all', 'they', 'have', 'said', 'is', 'this', 'has', 'why', 'we', 'approached', 'him', '.']
#
#
# Sentencia original:
# ['user' 'user' '"' 'grease' 'my' 'palm' 'with' 'silver' 'lo' '##vie' '.'
#  '"' 'the' 'disgrace' '##ful' 'prick' '.' 'run' "'" 'em' 'outta' 'town'
#  'folks' '.']
# Sentencia final: 1
# ['user', 'user', '"', 'grease', 'my', 'palm', 'with', 'silver', 'lo', '##vie', '.', '"', 'the', 'insult', '##ful', 'leftist', '.', 'come', "'", 'worthless', 'outta', 'yer', 'italians', '.']
#
#
# Sentencia original:
# ['user' 'user' 'it' "'" 's' 'not' 'a' 'matter' 'of' 'criticism' ',' 'it'
#  "'" 's' 'insulting' 'and' 'dem' '##ean' '##ing' 'and' 'offensive']
# Sentencia final: 1
# ['user', 'user', 'it', "'", 'time', 'not', 'a', 'irrelevant', 'of', 'discussion', ',', 'it', "'", 'll', 'disgusting', 'and', 'dem', '##ean', '##ing', 'and', 'offensive']
#
#
# Sentencia original:
# ['user' 'of' 'course' ',' 'however' 'please' 'do' 'not' 'try' 'and'
#  'compare' 'it' 'to' 'hundreds' 'of' 'years' 'of' 'systemic' 'oppression'
#  'of' 'a' 'whole' 'people']
# Sentencia final: 1
# ['user', 'of', 'victim', ',', 'however', 'don', 'go', 'not', 'attempt', 'and', 'compare', 'it', 'to', 'days', 'of', 'years', 'of', 'systemic', 'oppression', 'of', 'a', 'whole', 'people']
#
#
# Sentencia original:
# ['heartbreak' 'for' 'hash' '##tag' 'and' 'canada' '.' '“' 'user' ':'
#  'soldier' 'killed' 'in' 'canada' 'shooting' 'was' 'a' 'young' 'res'
#  '##er' '##vis' '##t' 'with' 'a' 'son' 'html']
# Sentencia final: 1
# ['heartbreak', 'for', 'hash', '##tag', 'and', 'canada', '.', '“', 'user', ':', 'victim', 'killed', 'in', 'shot', 'shooting', 'were', 'a', 'new', 'res', '##er', '##vis', '##t', 'with', 'a', 'son', 'html']
#
#
# Sentencia original:
# ['user' '"' 'may' 'be' '"' 'really' '?' 'forehead' 'smack']
# Sentencia final: 1
# ['user', '"', 'may', 'be', '"', 'really', '?', 'forehead', 'stupidity']
#
#
# Sentencia original:
# ['user' 'user' 'user' 'i' "'" 'm' 'not' 'watching' 'it' ',' 'but' 'it'
#  'sounds' 'as' 'if' 'it' 'is' 'being' 'treated' 'as' 'sport' '.']
# Sentencia final: 1
# ['user', 'user', 'user', 'victim', "'", 'watch', 'not', 'watching', 'it', ',', 'but', 'it', 'looks', 'as', 'if', 'it', 'is', 'having', 'treated', 'as', 'treat', '.']
#
#
# Sentencia original:
# ['user' 'kindly' 'verify' 'your' 'report' 'of' 'shooting' 'at' 'ride'
#  '##au' 'centre' 'ottawa' ',' 'canada' '.' 'local' 'reports' 'state'
#  'otherwise' '.']
# Sentencia final: 1
# ['user', 'kindly', 'verify', 'your', 'report', 'of', 'shooting', 'at', 'ride', '##au', 'place', 'ottawa', ',', 'canadian', '.', 'local', 'reports', 'report', 'otherwise', '.']
# # terms modificados promedio 3.85381091211995 términos por sentencia
# Largo de sentencia promedio 20.194918783840066 términos por sentencia
# para esta ejecución se debiesen reemplazar 13182  de 26438 terminos
# Resumen de modificaciones: {'NN': 5339, 'JJ': 756, 'VBZ': 422, 'VB': 576, 'NNS': 910, 'VBG': 433, 'VBD': 320, 'VBN': 312, 'JJS': 15, 'VBP': 151, 'JJR': 19}
# Este proceso tomó 45.58380579948425 seg
#
# --------------------------------------------------------
#
# Generando ejemplos en base a probabilidad -->  0.5
# --------------------------------------------------------
#
#
# Generando 2404 nuevos ejemplos para la clase questioning
# Consultando por la clase questioning
# Entrega label 2
# Sentencia original:
# ['user' 'user' 'clarified' 'that' 'earlier' '.' 'cheers']
# Sentencia final: 2
# ['user', 'user', 'commented', 'that', 'earlier', '.', 'words']
#
#
# Sentencia original:
# ['user' 'user' 'any' 'chance' 'that' "'" 's' 'being' 'said' 'for' 'fear'
#  'of' 'retribution' '?']
# Sentencia final: 2
# ['user', 'user', 'any', 'possibility', 'that', "'", 's', 'saying', 'said', 'for', 'reply', 'of', 'retribution', '?']
#
#
# Sentencia original:
# ['user' 'user' 'user' 'how' 'stupid' 'html']
# Sentencia final: 2
# ['user', 'user', 'user', 'how', 'illegal', 'html']
#
#
# Sentencia original:
# ['user' 'user' 'user' 'user' 'ah' 'true' '.' 'problem' 'now' 'is' 'we' "'"
#  'll' 'probably' 'only' 'get' 'coroner' "'" 's' 'details' 'they' 'won' "'"
#  't' 'make' 'it' '.']
# Sentencia final: 2
# ['user', 'user', 'user', 'user', 'gunshot', 'real', '.', 'situation', 'now', 'is', 'we', "'", 'gonna', 'probably', 'only', 'happen', 'helpful', "'", 's', 'people', 'they', 'won', "'", 'found', 'give', 'it', '.']
#
#
# Sentencia original:
# ['user' ',' 'hi' 'betty' '.' 'you' 'are' 'in' 'australia' '?']
# Sentencia final: 2
# ['user', ',', 'clarify', 'betty', '.', 'you', 'am', 'in', 'people', '?']
#
#
# Sentencia original:
# ['user' 'user' 'if' 'so' 'that' 'hostage' 'will' 'be' 'the' 'person'
#  'best' 'able' 'to' 'give' 'an' 'insight' 'into' 'the' 'attack' ',' 'if'
#  'the' 'suspects' 'were' 'responsible' '.']
# Sentencia final: 2
# ['user', 'user', 'if', 'so', 'that', 'hostage', 'will', 'get', 'the', 'person', 'most', 'able', 'to', 'give', 'an', 'insight', 'into', 'the', 'action', ',', 'if', 'the', 'weren', 'was', 'sarcastic', '.']
#
#
# Sentencia original:
# ['user' 'i' 'thought' 'police' 'asked' 'media' 'not' 'to' 'report'
#  'demands' '.' 'why' 'you' 'giving' 'these' 'terrorists' 'a' 'voice' '?']
# Sentencia final: 2
# ['user', 'i', 'thought', 'people', 'asked', 'media', 'not', 'to', 'report', 'demands', '.', 'why', 'you', 'causing', 'these', 'terrorists', 'a', 'voice', '?']
#
#
# Sentencia original:
# ['user' 'user' 'you' "'" 're' 'choosing' 'to' 'talk' 'about' 'a' '"'
#  'robbery' '"' 'based' 'on' 'a' 'tape' 'that' 'only' 'shows' 'a'
#  'confrontation' 'not' 'a' 'crime' '.' 'so' 'stop' '!']
# Sentencia final: 2
# ['user', 'user', 'you', "'", 're', 'choosing', 'to', 'talk', 'about', 'a', '"', 'robbery', '"', 'made', 'on', 'a', 'tape', 'that', 'only', 'cartoons', 'a', 'confrontation', 'not', 'a', 'crime', '.', 'so', 'stop', '!']
#
#
# Sentencia original:
# ['user' 'is' 'this' 'photo' 'from' 'last' 'night' '?' '?' 'please'
#  'clarify' 'because' 'you' 'are' 'using' 'present' 'tense' '.']
# Sentencia final: 2
# ['user', 'is', 'this', 'photo', 'from', 'last', 'day', '?', '?', 'something', 'clarify', 'because', 'you', 'am', 'being', 'present', 'tense', '.']
#
#
# # terms modificados promedio 3.274126455906822 términos por sentencia
# Largo de sentencia promedio 17.554076539101498 términos por sentencia
# para esta ejecución se debiesen reemplazar 11539  de 22906 terminos
# Resumen de modificaciones: {'VBN': 295, 'NNS': 757, 'NN': 4509, 'VBG': 356, 'JJ': 499, 'VB': 491, 'VBP': 191, 'JJS': 13, 'VBD': 324, 'VBZ': 426, 'JJR': 10}
# Este proceso tomó 38.94364547729492 seg
#
#
# Generando 0 nuevos ejemplos para la clase commenting
# Consultando por la clase commenting
# Entrega label 3
# No se generan ejemplos
# Resumen de modificaciones: {}
# Este proceso tomó 0.19331598281860352 seg
#
#
# Generando 1893 nuevos ejemplos para la clase support
# Consultando por la clase support
# Entrega label 0
# Sentencia original:
# ['shoot' 'unarmed' 'kid' '.' 'conceal' 'evidence' '.' 'impose' 'martial'
#  'law' '.' 'hara' '##ss' 'reporters' '.' 'sm' '##ear' 'the' 'victim' '.'
#  'worst' '.' 'police' '.' 'ever' '.' 'hash' '##tag' 'hash' '##tag']
# Sentencia final: 0
# ['shoot', 'uniformed', 'kid', '.', 'conceal', 'carnage', '.', 'apologize', 'martial', 'law', '.', 'hara', '##ss', 'reporters', '.', 'sm', '##ear', 'the', 'martyrs', '.', 'worst', '.', 'police', '.', 'ever', '.', 'qaeda', '##tag', 'jihad', '##tag']
#
#
# Sentencia original:
# ['“' 'user' ':' 'several' 'hostages' 'freed' 'at' 'jewish' 'supermarket'
#  'in' 'paris' '.' 'photo' 'thomas' 'samson' 'hash' '##tag' 'html' 'sc'
#  '##ha' '##ut' 'gen' '##au' 'hi' '##n' '!']
# Sentencia final: 0
# ['“', 'user', ':', 'numerous', 'hostages', 'leftist', 'at', 'jew', 'supermarket', 'in', 'paris', '.', 'photo', 'henry', 'carnage', 'jihad', '##tag', 'html', 'sc', '##ha', '##ut', 'gen', '##au', 'chen', '##n', '!']
#
#
# Sentencia original:
# ['“' 'user' ':' 'breaking' 'news' ':' 'gunmen' 'take' 'hostages' 'at'
#  'sydney' 'cafe' ',' 'wave' 'islamic' 'flag' 'html' 'html']
# Sentencia final: 0
# ['“', 'user', ':', 'breaking', 'broken', ':', 'gunmen', 'assume', 'hostages', 'at', 'sydney', 'cafe', ',', 'wave', 'satirical', 'flag', 'html', 'html']
#
#
# Sentencia original:
# ['breaking' 'news' ':' 'gunmen' 'take' 'hostages' 'at' 'sydney' 'cafe' ','
#  'wave' 'islamic' 'flag' 'html' 'html']
# Sentencia final: 0
# ['breaking', 'news', ':', 'gunmen', 'take', 'hostages', 'at', 'sydney', 'storm', ',', 'wave', 'islamic', 'fascism', 'html', 'html']
#
#
# Sentencia original:
# ['user' 'user' 'like' 'i' 'said' 'it' "'" 's' 'directly' 'across' 'from'
#  'a' 'big' 'news' 'channel' '.']
# Sentencia final: 0
# ['user', 'user', 'like', 'claimed', 'said', 'it', "'", 'head', 'directly', 'across', 'from', 'a', 'new', 'show', 'channels', '.']
#
#
# Sentencia original:
# ['user' 'best' 'news' 'i' 'have' 'heard' ',' 'kay' 'you' 'are' 'doing'
#  'an' 'amazing' 'job' 'thank' 'you']
# Sentencia final: 0
# ['user', 'best', 'news', 'time', 'do', 'heard', ',', 'kay', 'you', 'are', 'suggesting', 'an', 'frustrating', 'job', 'wow', 'you']
#
#
# Sentencia original:
# ['"' 'user' ':' 'the' 'hash' '##tag' 'attack' 'suspects' 'have'
#  'reportedly' 'fired' 'shots' 'while' 'rob' 'a' 'petrol' 'station' 'html'
#  'hash' '##tag']
# Sentencia final: 0
# ['"', 'user', ':', 'the', 'hash', '##tag', 'assault', 'suspects', 'impose', 'reportedly', 'harmed', 'shots', 'while', 'rob', 'a', 'petrol', 'station', 'html', 'qaeda', '##tag']
#
#
# Sentencia original:
# ['we' 'can' 'see' 'people' 'coming' 'out' 'a' 'fired' '##oor' 'near' 'the'
#  'lin' '##dt' 'cafe' 'to' 'waiting' 'police' '.' 'number' '-' 'number'
#  'people' '.' 'hard' 'to' 'see' '.' 'hash' '##tag']
# Sentencia final: 0
# ['we', 'can', 'see', 'men', 'seeing', 'out', 'a', 'fired', '##oor', 'near', 'the', 'lin', '##dt', 'cafe', 'to', 'waiting', 'police', '.', 'group', '-', 'person', 'men', '.', 'many', 'to', 'see', '.', 'hear', '##tag']
#
#
# Sentencia original:
# ['flag' 'in' 'window' 'of' 'sydney' 'lin' '##dt' 'cafe' 'not' 'an' 'isis'
#  'flag' '.' 'reads' ':' '‘' 'there' 'is' 'no' 'god' 'but' 'allah' 'and'
#  'muhammad' 'is' 'the' 'messenger' 'of' 'god' '’' 'user']
# Sentencia final: 0
# ['flag', 'in', 'window', 'of', 'sydney', 'lin', '##dt', 'cafe', 'not', 'an', 'standard', 'flag', '.', 'publishes', ':', '‘', 'there', 'is', 'no', 'god', 'but', 'islam', 'and', 'muhammad', 'appears', 'the', 'messenger', 'of', 'customer', 'qaeda', 'user']
#
#
# # terms modificados promedio 4.289487585842578 términos por sentencia
# Largo de sentencia promedio 20.324352879027998 términos por sentencia
# para esta ejecución se debiesen reemplazar 11145  de 22096 terminos
# Resumen de modificaciones: {'JJ': 589, 'NN': 5050, 'VB': 307, 'NNS': 904, 'VBG': 376, 'VBN': 296, 'VBZ': 212, 'VBP': 103, 'VBD': 215, 'JJS': 60, 'JJR': 8}
# Este proceso tomó 42.53870940208435 seg
#
#
# Generando 2401 nuevos ejemplos para la clase denying
# Consultando por la clase denying
# Entrega label 1
# Sentencia original:
# ['user' 'legally' 'speaking' 'it' 'doesn' "'" 't' 'matter' '.' 'the'
#  'question' 'of' 'reasonable' 'fear' 'is' 'at' 'issue' '+' 'the' 'k'
#  '##ra' '##uts' 'were' 'definitely' 'afraid' 'of' 'my' 'grandpa' '.']
# Sentencia final: 1
# ['user', 'legally', 'talking', 'it', 'doesn', "'", 't', 'issue', '.', 'the', 'debate', 'of', 'reasonable', 'afraid', 'is', 'at', 'issue', '+', 'the', 'k', '##ra', '##uts', 'were', 'definitely', 'didn', 'of', 'my', 'grandpa', '.']
#
#
# Sentencia original:
# ['user' 'user' 'user' 'user' 'what' 'other' 'info' 'do' 'they' 'have'
#  'ready' 'to' 'release' '?' 'all' 'they' 'have' 'said' 'is' 'this' 'is'
#  'why' 'we' 'approached' 'him' '.']
# Sentencia final: 1
# ['user', 'user', 'user', 'user', 'what', 'different', 'info', 'be', 'they', 'have', 'prepared', 'to', 'release', '?', 'all', 'they', 'say', 'had', 'has', 'this', 'is', 'why', 'we', 'approached', 'him', '.']
#
#
# Sentencia original:
# ['user' 'user' '"' 'grease' 'my' 'palm' 'with' 'silver' 'lo' '##vie' '.'
#  '"' 'the' 'disgrace' '##ful' 'prick' '.' 'run' "'" 'em' 'outta' 'town'
#  'folks' '.']
# Sentencia final: 1
# ['user', 'user', '"', 'grease', 'my', 'palm', 'with', 'silver', 'life', '##vie', '.', '"', 'the', 'disgrace', '##ful', 'leftist', '.', 'run', "'", 'em', 'gonna', 'yer', 'folks', '.']
#
#
# Sentencia original:
# ['user' 'user' 'it' "'" 's' 'not' 'a' 'matter' 'of' 'criticism' ',' 'it'
#  "'" 's' 'insulting' 'and' 'dem' '##ean' '##ing' 'and' 'offensive']
# Sentencia final: 1
# ['user', 'user', 'it', "'", 's', 'not', 'a', 'discussion', 'of', 'discussion', ',', 'it', "'", 's', 'insulting', 'and', 'dem', '##ean', '##ing', 'and', 'offensive']
#
#
# Sentencia original:
# ['user' 'of' 'course' ',' 'however' 'please' 'do' 'not' 'try' 'and'
#  'compare' 'it' 'to' 'hundreds' 'of' 'years' 'of' 'systemic' 'oppression'
#  'of' 'a' 'whole' 'people']
# Sentencia final: 1
# ['user', 'of', 'course', ',', 'however', 'please', 'do', 'not', 'try', 'and', 'compare', 'it', 'to', 'days', 'of', 'years', 'of', 'systemic', 'oppression', 'of', 'a', 'entire', 'people']
#
#
# Sentencia original:
# ['heartbreak' 'for' 'hash' '##tag' 'and' 'canada' '.' '“' 'user' ':'
#  'soldier' 'killed' 'in' 'canada' 'shooting' 'was' 'a' 'young' 'res'
#  '##er' '##vis' '##t' 'with' 'a' 'son' 'html']
# Sentencia final: 1
# ['heartbreak', 'for', 'hash', '##tag', 'and', 'canada', '.', '“', 'user', ':', 'soldier', 'murdered', 'in', 'shot', 'shooting', 'was', 'a', 'young', 'res', '##er', '##vis', '##t', 'with', 'a', 'son', 'html']
#
#
# Sentencia original:
# ['user' '"' 'may' 'be' '"' 'really' '?' 'forehead' 'smack']
# Sentencia final: 1
# ['user', '"', 'may', 'be', '"', 'really', '?', 'forehead', 'gotta']
#
#
# Sentencia original:
# ['user' 'user' 'user' 'i' "'" 'm' 'not' 'watching' 'it' ',' 'but' 'it'
#  'sounds' 'as' 'if' 'it' 'is' 'being' 'treated' 'as' 'sport' '.']
# Sentencia final: 1
# ['user', 'user', 'user', 'i', "'", 'watch', 'not', 'listening', 'it', ',', 'but', 'it', 'looks', 'as', 'if', 'it', 'is', 'being', 'treated', 'as', 'treat', '.']
#
#
# Sentencia original:
# ['user' 'kindly' 'verify' 'your' 'report' 'of' 'shooting' 'at' 'ride'
#  '##au' 'centre' 'ottawa' ',' 'canada' '.' 'local' 'reports' 'state'
#  'otherwise' '.']
# Sentencia final: 1
# ['user', 'kindly', 'verify', 'your', 'report', 'of', 'fleeing', 'at', 'ride', '##au', 'centre', 'ottawa', ',', 'canadian', '.', 'french', 'people', 'state', 'otherwise', '.']
# # terms modificados promedio 3.9058725531028737 términos por sentencia
# Largo de sentencia promedio 20.2457309454394 términos por sentencia
# para esta ejecución se debiesen reemplazar 13252  de 26494 terminos
# Resumen de modificaciones: {'VBG': 438, 'NN': 5410, 'JJ': 769, 'VB': 600, 'VBD': 328, 'VBZ': 436, 'NNS': 923, 'VBN': 291, 'VBP': 149, 'JJR': 19, 'JJS': 15}
# Este proceso tomó 45.96486783027649 seg

# %%
TOPN=1
prob=0.5


fs_macro={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
fs_none={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
accs={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
confusions={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}

for i in range(1,6):
    print ("----------------------- Entrenando running ", i,"-----------------------")
    macro_augmented=np.load('../../../new_data_augmented/stance/Aumento_'+str(i)+'-run_'+str(prob)+'_app1_Top'+str(TOPN)+'.npy', allow_pickle=True)
    
    ids_train=macro_augmented[:,0]
    tws_train=macro_augmented[:,1]
    labels_train=macro_augmented[:,2]
    class_weights= compute_class_weight('balanced', np.unique(labels_train), labels_train)
    print ("Pesos de clases:", class_weights)
    
    etiq=labels_train.copy()
    sentences = tws_train
    n_labels = np.array(etiq)

    input_ids = []
    for sent in sentences:
        encoded_sent = tokenizer_loaded.encode(list(sent),add_special_tokens = False)    
        input_ids.append(encoded_sent)
    input_ids = pad_sequences(input_ids,maxlen=MAX_LEN,dtype="long",value=0, truncating="post", padding="post")
    y_train=to_categorical(n_labels,num_classes=4)
    shape=np.asarray(input_ids).shape
    x_train=np.zeros((shape[0], shape[1], 768))
    j=0
    for in_id in input_ids:
        x_train[j]=M_BERT_space[in_id]
        j+=1

    ###########################################################
    ############################################################
    ############################################################
    
    cnn1=create_ccn1(x_train.shape[1:])
    trained =train_model(cnn1, x_train, y_train, x_val, y_val, class_weights, e=30, BS=32, verb=0, focal=True)
    trained.save('../../../new_data_augmented/stance_baselines/0.5/cnn1_'+str(i)+'-exec_app1_Top_'+str(TOPN)+'.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(trained, x_train, x_val, x_test, etiq, etiq_v, etiq_t, 'cnn1')
    fs_macro['cnn1'].append(f1_ma_t)
    fs_none['cnn1'].append(f1_t)
    accs['cnn1'].append(acc_t)
    confusions['cnn1'].append(matriz_t)
    
    cnn2=create_cnn2(x_train.shape[1:])
    trained =train_model(cnn2, x_train, y_train, x_val, y_val, class_weights, e=30, BS=32, verb=0, focal=True)
    trained.save('../../../new_data_augmented/stance_baselines/0.5/cnn2_'+str(i)+'-exec_app1_Top_'+str(TOPN)+'.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(trained, x_train, x_val, x_test, etiq, etiq_v, etiq_t, 'cnn2')
    fs_macro['cnn2'].append(f1_ma_t)
    fs_none['cnn2'].append(f1_t)
    accs['cnn2'].append(acc_t)
    confusions['cnn2'].append(matriz_t)
    
    rnn1=create_complex_GRU_2(128,64,"adam",x_train.shape[1:])
    trained =train_model(rnn1, x_train, y_train, x_val, y_val, class_weights, e=30, BS=32, verb=0, focal=True)
    trained.save('../../../new_data_augmented/stance_baselines/0.5/rnn1_'+str(i)+'-exec_app1_Top_'+str(TOPN)+'.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(trained, x_train, x_val, x_test, etiq, etiq_v, etiq_t, 'rnn1')
    fs_macro['rnn1'].append(f1_ma_t)
    fs_none['rnn1'].append(f1_t)
    accs['rnn1'].append(acc_t)
    confusions['rnn1'].append(matriz_t)
    
    rnn2=create_complex_GRU_3(256,128,64,"adam",x_train.shape[1:])
    trained =train_model(rnn2, x_train, y_train, x_val, y_val, class_weights, e=30, BS=32, verb=0, focal=True)
    trained.save('../../../new_data_augmented/stance_baselines/0.5/rnn2_'+str(i)+'-exec_app1_Top_'+str(TOPN)+'.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(trained, x_train, x_val, x_test, etiq, etiq_v, etiq_t, 'rnn2')
    fs_macro['rnn2'].append(f1_ma_t)
    fs_none['rnn2'].append(f1_t)
    accs['rnn2'].append(acc_t)
    confusions['rnn2'].append(matriz_t)
    
    rnn3=create_complex_GRU_3(256,128,64,"adam",x_train.shape[1:])
    trained =train_model(rnn3, x_train, y_train, x_val, y_val, class_weights, e=30, BS=32, verb=0, focal=False)
    trained.save('../../../new_data_augmented/stance_baselines/0.5/rnn3_'+str(i)+'-exec_app1_Top_'+str(TOPN)+'.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(trained, x_train, x_val, x_test, etiq, etiq_v, etiq_t, 'rnn3')
    fs_macro['rnn3'].append(f1_ma_t)
    fs_none['rnn3'].append(f1_t)
    accs['rnn3'].append(acc_t)
    confusions['rnn3'].append(matriz_t)
# Out:
# ----------------------- Entrenando running  1 -----------------------
# Pesos de clases: [1. 1. 1. 1.]
# WARNING:tensorflow:Large dropout rate: 0.65 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.65 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
#
# Accuracy sobre Train cnn1 : 0.9756766642282371
# F1-score None sobre Train cnn1 : [0.96278467 0.99413919 0.99156582 0.95447184]
# F1-score macro sobre Train cnn1 : 0.9757403810540323
#
# Accuracy sobre Val cnn1 : 0.5516014234875445
# F1-score None sobre Val cnn1 : [0.44444444 0.22222222 0.6984127  0.64310954]
# F1-score macro sobre Val cnn1 : 0.5020472264288519
#
# Accuracy sobre Test cnn1 : 0.5386875612144956
# F1-score None sobre Test cnn1 : [0.19310345 0.21834061 0.60176991 0.6615266 ]
# F1-score macro sobre Test cnn1 : 0.4186851427449491
# WARNING:tensorflow:Large dropout rate: 0.65 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
#
# Accuracy sobre Train cnn2 : 0.9735735186539868
# F1-score None sobre Train cnn2 : [0.95622655 0.99284272 0.99504314 0.95036252]
# F1-score macro sobre Train cnn2 : 0.9736187343255327
#
# Accuracy sobre Val cnn2 : 0.5516014234875445
# F1-score None sobre Val cnn2 : [0.53968254 0.22222222 0.61538462 0.60144928]
# F1-score macro sobre Val cnn2 : 0.49468466316292403
#
# Accuracy sobre Test cnn2 : 0.49853085210577863
# F1-score None sobre Test cnn2 : [0.13333333 0.21487603 0.52513966 0.64136328]
# F1-score macro sobre Test cnn2 : 0.37867807886785226
#
# Accuracy sobre Train rnn1 : 0.9568397951719093
# F1-score None sobre Train rnn1 : [0.97676148 0.93981721 0.96164071 0.95062638]
# F1-score macro sobre Train rnn1 : 0.9572114463578895
#
# Accuracy sobre Val rnn1 : 0.4412811387900356
# F1-score None sobre Val rnn1 : [0.48366013 0.16494845 0.44       0.51908397]
# F1-score macro sobre Val rnn1 : 0.40192313844821265
#
# Accuracy sobre Test rnn1 : 0.4701273261508325
# F1-score None sobre Test rnn1 : [0.15833333 0.18567639 0.37086093 0.62480377]
# F1-score macro sobre Test rnn1 : 0.3349186051798765
#
# Accuracy sobre Train rnn2 : 0.9361741038771031
# F1-score None sobre Train rnn2 : [0.91584354 0.98442714 0.95304591 0.89150695]
# F1-score macro sobre Train rnn2 : 0.9362058834565927
#
# Accuracy sobre Val rnn2 : 0.49110320284697506
# F1-score None sobre Val rnn2 : [0.44285714 0.08333333 0.42553191 0.60714286]
# F1-score macro sobre Val rnn2 : 0.38971631205673757
#
# Accuracy sobre Test rnn2 : 0.5377081292850147
# F1-score None sobre Test rnn2 : [0.19101124 0.15277778 0.32898172 0.68511593]
# F1-score macro sobre Test rnn2 : 0.3394716670399154
#
# Accuracy sobre Train rnn3 : 0.9587600585223116
# F1-score None sobre Train rnn3 : [0.97254902 0.95849455 0.96498202 0.93979813]
# F1-score macro sobre Train rnn3 : 0.9589559277160098
#
# Accuracy sobre Val rnn3 : 0.5088967971530249
# F1-score None sobre Val rnn3 : [0.5477707  0.15584416 0.38095238 0.6013986 ]
# F1-score macro sobre Val rnn3 : 0.42149145970802016
#
# Accuracy sobre Test rnn3 : 0.5230166503428012
# F1-score None sobre Test rnn3 : [0.08910891 0.18691589 0.35862069 0.68267831]
# F1-score macro sobre Test rnn3 : 0.32933094997400025
# ----------------------- Entrenando running  2 -----------------------
# Pesos de clases: [1. 1. 1. 1.]
#
# Accuracy sobre Train cnn1 : 0.9748536942209217
# F1-score None sobre Train cnn1 : [0.95841069 0.99376833 0.9939748  0.95335854]
# F1-score macro sobre Train cnn1 : 0.9748780928734884
#
# Accuracy sobre Val cnn1 : 0.5587188612099644
# F1-score None sobre Val cnn1 : [0.51315789 0.18461538 0.70175439 0.63888889]
# F1-score macro sobre Val cnn1 : 0.509604138551507
#
# Accuracy sobre Test cnn1 : 0.5230166503428012
# F1-score None sobre Test cnn1 : [0.17869416 0.22707424 0.56       0.64779874]
# F1-score macro sobre Test cnn1 : 0.4033917840054566
#
# Accuracy sobre Train cnn2 : 0.9686356986100951
# F1-score None sobre Train cnn2 : [0.94540613 0.98584906 0.99468183 0.94831858]
# F1-score macro sobre Train cnn2 : 0.9685638980896321
#
# Accuracy sobre Val cnn2 : 0.5195729537366548
# F1-score None sobre Val cnn2 : [0.3697479  0.16666667 0.62745098 0.67567568]
# F1-score macro sobre Val cnn2 : 0.4598853054735408
#
# Accuracy sobre Test cnn2 : 0.5523996082272282
# F1-score None sobre Test cnn2 : [0.05780347 0.20529801 0.50537634 0.69659667]
# F1-score macro sobre Test cnn2 : 0.3662686236548809
#
# Accuracy sobre Train rnn1 : 0.9834491587417703
# F1-score None sobre Train rnn1 : [0.97682839 0.99134279 0.99633028 0.96946425]
# F1-score macro sobre Train rnn1 : 0.9834914255618441
#
# Accuracy sobre Val rnn1 : 0.5551601423487544
# F1-score None sobre Val rnn1 : [0.54022989 0.20833333 0.52       0.62758621]
# F1-score macro sobre Val rnn1 : 0.4740373563218391
#
# Accuracy sobre Test rnn1 : 0.5210577864838394
# F1-score None sobre Test rnn1 : [0.18618619 0.15730337 0.46073298 0.66119403]
# F1-score macro sobre Test rnn1 : 0.3663541427791608
#
# Accuracy sobre Train rnn2 : 0.9689100219458668
# F1-score None sobre Train rnn2 : [0.95664585 0.98391469 0.99559633 0.93868282]
# F1-score macro sobre Train rnn2 : 0.9687099229744631
#
# Accuracy sobre Val rnn2 : 0.46619217081850534
# F1-score None sobre Val rnn2 : [0.54054054 0.09677419 0.4137931  0.51361868]
# F1-score macro sobre Val rnn2 : 0.3911816286450013
#
# Accuracy sobre Test rnn2 : 0.4515181194906954
# F1-score None sobre Test rnn2 : [0.11695906 0.15833333 0.45714286 0.5984    ]
# F1-score macro sobre Test rnn2 : 0.332708813700919
#
# Accuracy sobre Train rnn3 : 0.9547366495976591
# F1-score None sobre Train rnn3 : [0.93161736 0.96242467 0.99035838 0.93323684]
# F1-score macro sobre Train rnn3 : 0.9544093128305196
#
# Accuracy sobre Val rnn3 : 0.46619217081850534
# F1-score None sobre Val rnn3 : [0.54878049 0.13333333 0.48571429 0.50592885]
# F1-score macro sobre Val rnn3 : 0.41843924015185946
#
# Accuracy sobre Test rnn3 : 0.4505386875612145
# F1-score None sobre Test rnn3 : [0.12334802 0.17834395 0.41155235 0.58986928]
# F1-score macro sobre Test rnn3 : 0.32577839857047
# ----------------------- Entrenando running  3 -----------------------
# Pesos de clases: [1. 1. 1. 1.]
#
# Accuracy sobre Train cnn1 : 0.9633321141185077
# F1-score None sobre Train cnn1 : [0.93777388 0.99153478 0.99432338 0.92981791]
# F1-score macro sobre Train cnn1 : 0.9633624883703216
#
# Accuracy sobre Val cnn1 : 0.5551601423487544
# F1-score None sobre Val cnn1 : [0.54166667 0.19512195 0.63157895 0.60294118]
# F1-score macro sobre Val cnn1 : 0.4928271854312971
#
# Accuracy sobre Test cnn1 : 0.5034280117531832
# F1-score None sobre Test cnn1 : [0.16842105 0.21590909 0.53521127 0.63786332]
# F1-score macro sobre Test cnn1 : 0.3893511815375579
#
# Accuracy sobre Train cnn2 : 0.96991587417703
# F1-score None sobre Train cnn2 : [0.94754846 0.99321474 0.99356499 0.94578524]
# F1-score macro sobre Train cnn2 : 0.9700283594995299
#
# Accuracy sobre Val cnn2 : 0.6120996441281139
# F1-score None sobre Val cnn2 : [0.54901961 0.27906977 0.58181818 0.69453376]
# F1-score macro sobre Val cnn2 : 0.5261103297902644
#
# Accuracy sobre Test cnn2 : 0.6003917727717923
# F1-score None sobre Test cnn2 : [0.09142857 0.20909091 0.45502646 0.739369  ]
# F1-score macro sobre Test cnn2 : 0.3737287335435483
#
# Accuracy sobre Train rnn1 : 0.9827176298463789
# F1-score None sobre Train rnn1 : [0.97547782 0.99376376 0.99300442 0.96876148]
# F1-score macro sobre Train rnn1 : 0.9827518703209139
#
# Accuracy sobre Val rnn1 : 0.5231316725978647
# F1-score None sobre Val rnn1 : [0.51977401 0.18181818 0.52459016 0.57857143]
# F1-score macro sobre Val rnn1 : 0.4511884464058679
#
# Accuracy sobre Test rnn1 : 0.5004897159647405
# F1-score None sobre Test rnn1 : [0.08695652 0.14285714 0.39053254 0.65365148]
# F1-score macro sobre Test rnn1 : 0.3184994228149649
#
# Accuracy sobre Train rnn2 : 0.9441294806144843
# F1-score None sobre Train rnn2 : [0.90573566 0.97142857 0.99226519 0.90973174]
# F1-score macro sobre Train rnn2 : 0.9447902915986527
#
# Accuracy sobre Val rnn2 : 0.47686832740213525
# F1-score None sobre Val rnn2 : [0.5042735  0.06451613 0.48979592 0.5       ]
# F1-score macro sobre Val rnn2 : 0.38964638791827727
#
# Accuracy sobre Test rnn2 : 0.40254652301665034
# F1-score None sobre Test rnn2 : [0.13861386 0.12       0.35555556 0.55509528]
# F1-score macro sobre Test rnn2 : 0.29231617362233325
# Accuracy sobre Train rnn3 : 0.9613204096561814
# F1-score None sobre Train rnn3 : [0.92713421 0.99190879 0.99470706 0.9314599 ]
# F1-score macro sobre Train rnn3 : 0.9613024908181256
#
# Accuracy sobre Val rnn3 : 0.5765124555160143
# F1-score None sobre Val rnn3 : [0.484375   0.08695652 0.51428571 0.69811321]
# F1-score macro sobre Val rnn3 : 0.4459326108930036
#
# Accuracy sobre Test rnn3 : 0.643486777668952
# F1-score None sobre Test rnn3 : [0.06666667 0.12587413 0.42424242 0.77623762]
# F1-score macro sobre Test rnn3 : 0.34825521013639826
# ----------------------- Entrenando running  4 -----------------------
# Pesos de clases: [1. 1. 1. 1.]
#
# Accuracy sobre Train cnn1 : 0.9705559619604974
# F1-score None sobre Train cnn1 : [0.95322781 0.9928322  0.99358622 0.94262755]
# F1-score macro sobre Train cnn1 : 0.9705684450212018
#
# Accuracy sobre Val cnn1 : 0.5800711743772242
# F1-score None sobre Val cnn1 : [0.55172414 0.25806452 0.7037037  0.61313869]
# F1-score macro sobre Val cnn1 : 0.5316577609737894
#
# Accuracy sobre Test cnn1 : 0.49951028403525954
# F1-score None sobre Test cnn1 : [0.14356436 0.23129252 0.51       0.6398141 ]
# F1-score macro sobre Test cnn1 : 0.38116774276030174
#
# Accuracy sobre Train cnn2 : 0.9753108997805413
# F1-score None sobre Train cnn2 : [0.95997007 0.99301471 0.99412628 0.95459383]
# F1-score macro sobre Train cnn2 : 0.9754262223592894
#
# Accuracy sobre Val cnn2 : 0.594306049822064
# F1-score None sobre Val cnn2 : [0.54878049 0.2173913  0.65384615 0.66666667]
# F1-score macro sobre Val cnn2 : 0.5216711531663811
#
# Accuracy sobre Test cnn2 : 0.5954946131243879
# F1-score None sobre Test cnn2 : [0.13385827 0.2122905  0.58333333 0.72829922]
# F1-score macro sobre Test cnn2 : 0.41444533188880817
#
# Accuracy sobre Train rnn1 : 0.9667154352596927
# F1-score None sobre Train rnn1 : [0.95264918 0.9846552  0.98714932 0.94198212]
# F1-score macro sobre Train rnn1 : 0.966608956529393
#
# Accuracy sobre Val rnn1 : 0.42704626334519574
# F1-score None sobre Val rnn1 : [0.46       0.05263158 0.44186047 0.45378151]
# F1-score macro sobre Val rnn1 : 0.3520683891671723
#
# Accuracy sobre Test rnn1 : 0.41625857002938293
# F1-score None sobre Test rnn1 : [0.1691974  0.1375     0.47794118 0.53959965]
# F1-score macro sobre Test rnn1 : 0.3310595563262261
#
# Accuracy sobre Train rnn2 : 0.9657095830285296
# F1-score None sobre Train rnn2 : [0.95174888 0.98607038 0.98156081 0.94407895]
# F1-score macro sobre Train rnn2 : 0.9658647548982866
#
# Accuracy sobre Val rnn2 : 0.5516014234875445
# F1-score None sobre Val rnn2 : [0.56994819 0.0952381  0.47826087 0.61921708]
# F1-score macro sobre Val rnn2 : 0.4406660582955859
#
# Accuracy sobre Test rnn2 : 0.47698334965719885
# F1-score None sobre Test rnn2 : [0.17662338 0.15740741 0.28767123 0.64092664]
# F1-score macro sobre Test rnn2 : 0.3156571644585343
#
# Accuracy sobre Train rnn3 : 0.9697329919531822
# F1-score None sobre Train rnn3 : [0.94755043 0.99378428 0.99136506 0.94647202]
# F1-score macro sobre Train rnn3 : 0.9697929464139985
#
# Accuracy sobre Val rnn3 : 0.5551601423487544
# F1-score None sobre Val rnn3 : [0.44615385 0.16949153 0.39285714 0.70031546]
# F1-score macro sobre Val rnn3 : 0.4272044929619917
#
# Accuracy sobre Test rnn3 : 0.6209598432908913
# F1-score None sobre Test rnn3 : [0.06622517 0.14772727 0.36633663 0.76536682]
# F1-score macro sobre Test rnn3 : 0.33641397320980265
# ----------------------- Entrenando running  5 -----------------------
# Pesos de clases: [1. 1. 1. 1.]
#
# Accuracy sobre Train cnn1 : 0.972293343087052
# F1-score None sobre Train cnn1 : [0.95706215 0.99032317 0.99300957 0.94919455]
# F1-score macro sobre Train cnn1 : 0.9723973575189666
#
# Accuracy sobre Val cnn1 : 0.5302491103202847
# F1-score None sobre Val cnn1 : [0.52121212 0.19047619 0.57777778 0.60207612]
# F1-score macro sobre Val cnn1 : 0.4728855535083909
#
# Accuracy sobre Test cnn1 : 0.5269343780607247
# F1-score None sobre Test cnn1 : [0.1461794  0.22707424 0.54358974 0.66362946]
# F1-score macro sobre Test cnn1 : 0.3951182105717338
#
# Accuracy sobre Train cnn2 : 0.972201901975128
# F1-score None sobre Train cnn2 : [0.95732496 0.98925123 0.99158742 0.95056343]
# F1-score macro sobre Train cnn2 : 0.9721817593370136
#
# Accuracy sobre Val cnn2 : 0.5587188612099644
# F1-score None sobre Val cnn2 : [0.46896552 0.21621622 0.70175439 0.66433566]
# F1-score macro sobre Val cnn2 : 0.512817945939543
#
# Accuracy sobre Test cnn2 : 0.5122428991185113
# F1-score None sobre Test cnn2 : [0.10526316 0.1863354  0.59292035 0.6459144 ]
# F1-score macro sobre Test cnn2 : 0.3826083281227264
#
# Accuracy sobre Train rnn1 : 0.9807059253840527
# F1-score None sobre Train rnn1 : [0.96725912 0.99229358 0.99762123 0.9657876 ]
# F1-score macro sobre Train rnn1 : 0.9807403806607465
#
# Accuracy sobre Val rnn1 : 0.501779359430605
# F1-score None sobre Val rnn1 : [0.43165468 0.1        0.52777778 0.61168385]
# F1-score macro sobre Val rnn1 : 0.41777907570850537
#
# Accuracy sobre Test rnn1 : 0.5710088148873653
# F1-score None sobre Test rnn1 : [0.18340611 0.17351598 0.47524752 0.7112069 ]
# F1-score macro sobre Test rnn1 : 0.38584412914411925
#
# Accuracy sobre Train rnn2 : 0.946781272860278
# F1-score None sobre Train rnn2 : [0.9061257  0.98935389 0.98618021 0.90634947]
# F1-score macro sobre Train rnn2 : 0.9470023174430799
#
# Accuracy sobre Val rnn2 : 0.5907473309608541
# F1-score None sobre Val rnn2 : [0.63513514 0.08333333 0.42105263 0.67961165]
# F1-score macro sobre Val rnn2 : 0.45478318763321324
#
# Accuracy sobre Test rnn2 : 0.5729676787463271
# F1-score None sobre Test rnn2 : [0.16243655 0.16438356 0.35820896 0.72280702]
# F1-score macro sobre Test rnn2 : 0.3519590206587315
#
# Accuracy sobre Train rnn3 : 0.9856437454279444
# F1-score None sobre Train rnn3 : [0.9769688  0.9952381  0.99743402 0.97307968]
# F1-score macro sobre Train rnn3 : 0.9856801483505605
#
# Accuracy sobre Val rnn3 : 0.5409252669039146
# F1-score None sobre Val rnn3 : [0.54748603 0.13333333 0.5        0.60992908]
# F1-score macro sobre Val rnn3 : 0.4476871112167677
#
# Accuracy sobre Test rnn3 : 0.5475024485798237
# F1-score None sobre Test rnn3 : [0.08921933 0.19587629 0.45320197 0.7005814 ]
# F1-score macro sobre Test rnn3 : 0.35971974632674986

# %%
for key in fs_none.keys():
    temp=np.zeros(4)
    for result in fs_none[key]:
        temp+=result
    print ("(0.5) app1 F1-score promedio para",key,":" ,temp/5)

print ("")
for key in fs_macro.keys():
    temp=np.sum(fs_macro[key])
    print ("(0.5) app1 F1-score macro promedio para",key,":" ,temp/5, "desvest: ",np.std(fs_macro[key]))

print ("")
for key in accs.keys():
    temp=np.sum(accs[key])
    print ("(0.5) app1 Accuracy promedio para",key,":" ,temp/5)
# Out:
# (0.5) app1 F1-score promedio para cnn1 : [0.16599248 0.22393814 0.55011418 0.65012644]
# (0.5) app1 F1-score promedio para cnn2 : [0.10433736 0.20557817 0.53235923 0.69030851]
# (0.5) app1 F1-score promedio para rnn1 : [0.15681591 0.15937058 0.43506303 0.63809117]
# (0.5) app1 F1-score promedio para rnn2 : [0.15712882 0.15058042 0.35751206 0.64046897]
# (0.5) app1 F1-score promedio para rnn3 : [0.08691362 0.1669475  0.40279081 0.70294669]
#
# (0.5) app1 F1-score macro promedio para cnn1 : 0.39754281232399985 desvest:  0.01282445333863013
# (0.5) app1 F1-score macro promedio para cnn2 : 0.3831458192155632 desvest:  0.016573655762200736
# (0.5) app1 F1-score macro promedio para rnn1 : 0.34733517124886953 desvest:  0.024880628038887694
# (0.5) app1 F1-score macro promedio para rnn2 : 0.3264225678960867 desvest:  0.020693217903521043
# (0.5) app1 F1-score macro promedio para rnn3 : 0.33989965564348423 desvest:  0.012537214271565617
#
# (0.5) app1 Accuracy promedio para cnn1 : 0.5183153770812929
# (0.5) app1 Accuracy promedio para cnn2 : 0.5518119490695397
# (0.5) app1 Accuracy promedio para rnn1 : 0.4957884427032321
# (0.5) app1 Accuracy promedio para rnn2 : 0.4883447600391773
# (0.5) app1 Accuracy promedio para rnn3 : 0.5571008814887366

# %%
for key in confusions.keys():
    temp=np.sum(confusions[key], axis=0)/5.0
    plot_confusion_matrix(temp, ['S','D','Q','C'], "(0.5) classic - Confusion Matrix"+str(key), cmap='RdPu')

# %%
"LISTO"
# Out:
# 'LISTO'

# %% [markdown]
# ## Generar 0.85 classic

# %%
prob= 0.85
TOPN = 1

fs_macro={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
fs_none={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
accs={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
confusions={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}

aum_weight=det_samples(train['Label'], dict_cl)

for i in range(1,6): 
    macro_augmented=[]
    print ("\n--------------------------------------------------------")
    print ("\nGenerando ejemplos en base a probabilidad --> ", prob)
    print ("--------------------------------------------------------")
    for clase in aum_weight:
        start_time=time.time()
        print ("\n\nGenerando", aum_weight[clase], "nuevos ejemplos para la clase", clase)
        muestras, dict_aumentos=aumentar_clase(clase, aum_weight[clase], tags, prob, TOPN)
        macro_augmented+=muestras
        print ("Resumen de modificaciones:", dict_aumentos)
        elapsed_time= time.time() - start_time
        print ("Este proceso tomó", elapsed_time, "seg")   

    macro_augmented = np.asarray(macro_augmented, dtype=object)
    np.random.shuffle(macro_augmented)
    np.save('../../../new_data_augmented/stance/Aumento_'+str(i)+'-run_'+str(prob)+'_app1_Top'+str(TOPN)+'.npy', macro_augmented)
# Out:
# --------------------------------------------------------
#
# Generando ejemplos en base a probabilidad -->  0.85
# --------------------------------------------------------
#
#
# Generando 2404 nuevos ejemplos para la clase questioning
# Consultando por la clase questioning
# Entrega label 2
# Sentencia original:
# ['user' 'user' 'clarified' 'that' 'earlier' '.' 'cheers']
# Sentencia final: 2
# ['user', 'user', 'commented', 'that', 'earlier', '.', 'words']
#
#
# Sentencia original:
# ['user' 'user' 'any' 'chance' 'that' "'" 's' 'being' 'said' 'for' 'fear'
#  'of' 'retribution' '?']
# Sentencia final: 2
# ['user', 'user', 'any', 'use', 'that', "'", 're', 'saying', 'reported', 'for', 'terror', 'of', 'retribution', '?']
#
#
# Sentencia original:
# ['user' 'user' 'user' 'how' 'stupid' 'html']
# Sentencia final: 2
# ['user', 'user', 'user', 'how', 'sarcastic', 'html']
#
#
# Sentencia original:
# ['user' 'user' 'user' 'user' 'ah' 'true' '.' 'problem' 'now' 'is' 'we' "'"
#  'll' 'probably' 'only' 'get' 'coroner' "'" 's' 'details' 'they' 'won' "'"
#  't' 'make' 'it' '.']
# Sentencia final: 2
# ['user', 'user', 'user', 'user', 'gunshot', 'reliable', '.', 'home', 'now', 'has', 'we', "'", 'gonna', 'probably', 'only', 'get', 'helpful', "'", 'clarify', 'details', 'they', 'retribution', "'", 't', 'do', 'it', '.']
#
#
# Sentencia original:
# ['user' ',' 'hi' 'betty' '.' 'you' 'are' 'in' 'australia' '?']
# Sentencia final: 2
# ['user', ',', 'jeffrey', 'betty', '.', 'you', 'am', 'in', 'weren', '?']
#
#
# Sentencia original:
# ['user' 'user' 'if' 'so' 'that' 'hostage' 'will' 'be' 'the' 'person'
#  'best' 'able' 'to' 'give' 'an' 'insight' 'into' 'the' 'attack' ',' 'if'
#  'the' 'suspects' 'were' 'responsible' '.']
# Sentencia final: 2
# ['user', 'user', 'if', 'so', 'that', 'remain', 'will', 'go', 'the', 'helpful', 'worst', 'unable', 'to', 'identify', 'an', 'insight', 'into', 'the', 'attack', ',', 'if', 'the', 'suspects', 'resulted', 'concerned', '.']
#
#
# Sentencia original:
# ['user' 'i' 'thought' 'police' 'asked' 'media' 'not' 'to' 'report'
#  'demands' '.' 'why' 'you' 'giving' 'these' 'terrorists' 'a' 'voice' '?']
# Sentencia final: 2
# ['user', 'man', 'ask', 'people', 'suspected', 'journalists', 'not', 'to', 'present', 'reports', '.', 'why', 'you', 'causing', 'these', 'words', 'a', 'voice', '?']
#
#
# Sentencia original:
# ['user' 'user' 'you' "'" 're' 'choosing' 'to' 'talk' 'about' 'a' '"'
#  'robbery' '"' 'based' 'on' 'a' 'tape' 'that' 'only' 'shows' 'a'
#  'confrontation' 'not' 'a' 'crime' '.' 'so' 'stop' '!']
# Sentencia final: 2
# ['user', 'user', 'you', "'", 're', 'choosing', 'to', 'speak', 'about', 'a', '"', 'robbery', '"', 'called', 'on', 'a', 'gunshot', 'that', 'only', 'shows', 'a', 'confrontation', 'not', 'a', 'gonna', '.', 'so', 'start', '!']
#
#
# Sentencia original:
# ['user' 'is' 'this' 'photo' 'from' 'last' 'night' '?' '?' 'please'
#  'clarify' 'because' 'you' 'are' 'using' 'present' 'tense' '.']
# Sentencia final: 2
# ['user', 'has', 'this', 'picture', 'from', 'second', 'day', '?', '?', 'understand', 'clarify', 'because', 'you', 'am', 'trying', 'use', 'tense', '.']
#
#
# # terms modificados promedio 5.121048252911813 términos por sentencia
# Largo de sentencia promedio 16.903910149750416 términos por sentencia
# para esta ejecución se debiesen reemplazar 18037  de 21184 terminos
# Resumen de modificaciones: {'VBN': 446, 'NNS': 1155, 'NN': 7020, 'VBG': 546, 'VBD': 515, 'JJ': 796, 'VBZ': 725, 'VB': 784, 'VBP': 284, 'JJS': 20, 'JJR': 20}
# Este proceso tomó 56.29557418823242 seg
#
#
# Generando 0 nuevos ejemplos para la clase commenting
# Consultando por la clase commenting
# Entrega label 3
# No se generan ejemplos
# Resumen de modificaciones: {}
# Este proceso tomó 0.19086217880249023 seg
#
#
# Generando 1893 nuevos ejemplos para la clase support
# Consultando por la clase support
# Entrega label 0
# Sentencia original:
# ['user' 'some' 'good' 'news' '!']
# Sentencia final: 0
# ['user', 'some', 'good', 'right', '!']
#
#
# Sentencia original:
# ['shoot' 'unarmed' 'kid' '.' 'conceal' 'evidence' '.' 'impose' 'martial'
#  'law' '.' 'hara' '##ss' 'reporters' '.' 'sm' '##ear' 'the' 'victim' '.'
#  'worst' '.' 'police' '.' 'ever' '.' 'hash' '##tag' 'hash' '##tag']
# Sentencia final: 0
# ['assassinate', 'uniformed', 'kid', '.', 'hiding', 'evidence', '.', 'apologize', 'martial', 'lawyer', '.', 'hara', '##ss', 'journalists', '.', 'sm', '##ear', 'the', 'qaeda', '.', 'worst', '.', 'media', '.', 'ever', '.', 'qaeda', '##tag', 'jihad', '##tag']
#
#
# Sentencia original:
# ['“' 'user' ':' 'several' 'hostages' 'freed' 'at' 'jewish' 'supermarket'
#  'in' 'paris' '.' 'photo' 'thomas' 'samson' 'hash' '##tag' 'html' 'sc'
#  '##ha' '##ut' 'gen' '##au' 'hi' '##n' '!']
# Sentencia final: 0
# ['“', 'user', ':', 'numerous', 'perpetrators', 'leftist', 'at', 'jew', 'grocery', 'in', 'photograph', '.', 'photo', 'henry', 'carnage', 'hash', '##tag', 'html', 'sc', '##ha', '##ut', 'gen', '##au', 'chen', '##n', '!']
#
#
# Sentencia original:
# ['“' 'user' ':' 'breaking' 'news' ':' 'gunmen' 'take' 'hostages' 'at'
#  'sydney' 'cafe' ',' 'wave' 'islamic' 'flag' 'html' 'html']
# Sentencia final: 0
# ['“', 'user', ':', 'disturbing', 'news', ':', 'journalists', 'assume', 'militants', 'at', 'hostage', 'twist', ',', 'wave', 'uniformed', 'fascism', 'html', 'html']
#
#
# Sentencia original:
# ['breaking' 'news' ':' 'gunmen' 'take' 'hostages' 'at' 'sydney' 'cafe' ','
#  'wave' 'islamic' 'flag' 'html' 'html']
# Sentencia final: 0
# ['following', 'gunfire', ':', 'perpetrators', 'assume', 'hostages', 'at', 'sydney', 'comedic', ',', 'wave', 'uniformed', 'fascism', 'html', 'html']
#
#
# Sentencia original:
# ['user' 'user' 'like' 'i' 'said' 'it' "'" 's' 'directly' 'across' 'from'
#  'a' 'big' 'news' 'channel' '.']
# Sentencia final: 0
# ['user', 'user', 'like', 'thought', 'was', 'it', "'", 're', 'directly', 'across', 'from', 'a', 'large', 'news', 'channels', '.']
#
#
# Sentencia original:
# ['user' 'best' 'news' 'i' 'have' 'heard' ',' 'kay' 'you' 'are' 'doing'
#  'an' 'amazing' 'job' 'thank' 'you']
# Sentencia final: 0
# ['user', 'most', 'destructive', 'found', 'have', 'hear', ',', 'kay', 'you', 'are', 'doing', 'an', 'protecting', 'wow', 'honor', 'you']
#
#
# Sentencia original:
# ['"' 'user' ':' 'the' 'hash' '##tag' 'attack' 'suspects' 'have'
#  'reportedly' 'fired' 'shots' 'while' 'rob' 'a' 'petrol' 'station' 'html'
#  'hash' '##tag']
# Sentencia final: 0
# ['"', 'user', ':', 'the', 'qaeda', '##tag', 'suspect', 'attacks', 'know', 'reportedly', 'killed', 'gunmen', 'while', 'robbed', 'a', 'petrol', 'jihad', 'html', 'qaeda', '##tag']
#
#
# Sentencia original:
# ['we' 'can' 'see' 'people' 'coming' 'out' 'a' 'fired' '##oor' 'near' 'the'
#  'lin' '##dt' 'cafe' 'to' 'waiting' 'police' '.' 'number' '-' 'number'
#  'people' '.' 'hard' 'to' 'see' '.' 'hash' '##tag']
# Sentencia final: 0
# ['we', 'can', 'come', 'men', 'seeing', 'out', 'a', 'mohamed', '##oor', 'near', 'the', 'lin', '##dt', 'wait', 'to', 'waiting', 'policemen', '.', 'leftist', '-', 'number', 'men', '.', 'hard', 'to', 'do', '.', 'hash', '##tag']
#
#
# # terms modificados promedio 6.9846804014791335 términos por sentencia
# Largo de sentencia promedio 19.920760697305862 términos por sentencia
# para esta ejecución se debiesen reemplazar 18111  de 21313 terminos
# Resumen de modificaciones: {'NN': 8235, 'JJ': 896, 'VB': 505, 'NNS': 1400, 'VBG': 666, 'VBD': 370, 'JJS': 108, 'VBN': 509, 'VBZ': 368, 'VBP': 148, 'JJR': 17}
# Este proceso tomó 64.00058603286743 seg
#
#
# Generando 2401 nuevos ejemplos para la clase denying
# Consultando por la clase denying
# Entrega label 1
# Sentencia original:
# ['user' 'legally' 'speaking' 'it' 'doesn' "'" 't' 'matter' '.' 'the'
#  'question' 'of' 'reasonable' 'fear' 'is' 'at' 'issue' '+' 'the' 'k'
#  '##ra' '##uts' 'were' 'definitely' 'afraid' 'of' 'my' 'grandpa' '.']
# Sentencia final: 1
# ['user', 'legally', 'speaking', 'it', 'didn', "'", 'don', 'friend', '.', 'the', 'question', 'of', 'plausible', 'lie', 'has', 'at', 'issue', 'problem', 'the', 'k', '##ra', '##uts', 'was', 'definitely', 'wasn', 'of', 'my', 'grandpa', '.']
#
#
# Sentencia original:
# ['user' 'user' 'user' 'user' 'what' 'other' 'info' 'do' 'they' 'have'
#  'ready' 'to' 'release' '?' 'all' 'they' 'have' 'said' 'is' 'this' 'is'
#  'why' 'we' 'approached' 'him' '.']
# Sentencia final: 1
# ['user', 'user', 'user', 'user', 'what', 'different', 'rest', 'take', 'they', 'make', 'free', 'to', 'release', '?', 'all', 'they', 'say', 'was', 'has', 'this', 'is', 'why', 'we', 'contacted', 'him', '.']
#
#
# Sentencia original:
# ['user' 'user' '"' 'grease' 'my' 'palm' 'with' 'silver' 'lo' '##vie' '.'
#  '"' 'the' 'disgrace' '##ful' 'prick' '.' 'run' "'" 'em' 'outta' 'town'
#  'folks' '.']
# Sentencia final: 1
# ['user', 'user', '"', 'grease', 'my', 'palm', 'with', 'silver', 'life', '##vie', '.', '"', 'the', 'shame', '##ful', 'leftist', '.', 'run', "'", 'hysteria', 'gonna', 'heartbreak', 'guys', '.']
#
#
# Sentencia original:
# ['user' 'user' 'it' "'" 's' 'not' 'a' 'matter' 'of' 'criticism' ',' 'it'
#  "'" 's' 'insulting' 'and' 'dem' '##ean' '##ing' 'and' 'offensive']
# Sentencia final: 1
# ['user', 'user', 'it', "'", 'man', 'not', 'a', 'topic', 'of', 'discussion', ',', 'it', "'", 's', 'murdering', 'and', 'dem', '##ean', '##ing', 'and', 'red']
#
#
# Sentencia original:
# ['user' 'of' 'course' ',' 'however' 'please' 'do' 'not' 'try' 'and'
#  'compare' 'it' 'to' 'hundreds' 'of' 'years' 'of' 'systemic' 'oppression'
#  'of' 'a' 'whole' 'people']
# Sentencia final: 1
# ['user', 'of', 'victim', ',', 'however', 'disagree', 'go', 'not', 'try', 'and', 'attempt', 'it', 'to', 'days', 'of', 'days', 'of', 'systemic', 'oppression', 'of', 'a', 'entire', 'men']
#
#
# Sentencia original:
# ['user' 'user' 'not' 'confirmed']
# Sentencia final: 1
# ['user', 'user', 'not', 'based']
# Sentencia original:
# ['heartbreak' 'for' 'hash' '##tag' 'and' 'canada' '.' '“' 'user' ':'
#  'soldier' 'killed' 'in' 'canada' 'shooting' 'was' 'a' 'young' 'res'
#  '##er' '##vis' '##t' 'with' 'a' 'son' 'html']
# Sentencia final: 1
# ['heartbreak', 'for', 'qaeda', '##tag', 'and', 'canadian', '.', '“', 'user', ':', 'qaeda', 'murdered', 'in', 'shoot', 'being', 'were', 'a', 'new', 'res', '##er', '##vis', '##t', 'with', 'a', 'son', 'html']
#
#
# Sentencia original:
# ['user' '"' 'may' 'be' '"' 'really' '?' 'forehead' 'smack']
# Sentencia final: 1
# ['user', '"', 'may', 'go', '"', 'really', '?', 'forehead', 'gotta']
#
#
# Sentencia original:
# ['user' 'user' 'user' 'i' "'" 'm' 'not' 'watching' 'it' ',' 'but' 'it'
#  'sounds' 'as' 'if' 'it' 'is' 'being' 'treated' 'as' 'sport' '.']
# Sentencia final: 1
# ['user', 'user', 'user', 'employee', "'", 'watch', 'not', 'listening', 'it', ',', 'but', 'it', 'looks', 'as', 'if', 'it', 'has', 'getting', 'fascinated', 'as', 'treat', '.']
#
#
# # terms modificados promedio 6.315285297792586 términos por sentencia
# Largo de sentencia promedio 19.678883798417328 términos por sentencia
# para esta ejecución se debiesen reemplazar 21507  de 25128 terminos
# Resumen de modificaciones: {'NN': 8767, 'JJ': 1250, 'VBZ': 682, 'VBD': 522, 'VB': 950, 'VBN': 487, 'NNS': 1474, 'VBG': 718, 'VBP': 254, 'JJR': 34, 'JJS': 25}
# Este proceso tomó 69.96378207206726 seg
#
# --------------------------------------------------------
#
# Generando ejemplos en base a probabilidad -->  0.85
# --------------------------------------------------------
#
#
# Generando 2404 nuevos ejemplos para la clase questioning
# Consultando por la clase questioning
# Entrega label 2
# Sentencia original:
# ['user' 'user' 'clarified' 'that' 'earlier' '.' 'cheers']
# Sentencia final: 2
# ['user', 'user', 'commented', 'that', 'earlier', '.', 'words']
#
#
# Sentencia original:
# ['user' 'user' 'any' 'chance' 'that' "'" 's' 'being' 'said' 'for' 'fear'
#  'of' 'retribution' '?']
# Sentencia final: 2
# ['user', 'user', 'any', 'possibility', 'that', "'", 's', 'saying', 'was', 'for', 'reply', 'of', 'retribution', '?']
#
#
# Sentencia original:
# ['user' 'user' 'user' 'how' 'stupid' 'html']
# Sentencia final: 2
# ['user', 'user', 'user', 'how', 'investigative', 'html']
#
#
# Sentencia original:
# ['user' 'user' 'user' 'user' 'ah' 'true' '.' 'problem' 'now' 'is' 'we' "'"
#  'll' 'probably' 'only' 'get' 'coroner' "'" 's' 'details' 'they' 'won' "'"
#  't' 'make' 'it' '.']
# Sentencia final: 2
# ['user', 'user', 'user', 'user', 'gunshot', 'reliable', '.', 'problem', 'now', 'has', 'we', "'", 'gonna', 'probably', 'only', 'find', 'helpful', "'", 'clarify', 'details', 'they', 'retribution', "'", 'home', 'give', 'it', '.']
#
#
# Sentencia original:
# ['user' ',' 'hi' 'betty' '.' 'you' 'are' 'in' 'australia' '?']
# Sentencia final: 2
# ['user', ',', 'niece', 'betty', '.', 'you', 'am', 'in', 'australia', '?']
#
#
# Sentencia original:
# ['user' 'user' 'if' 'so' 'that' 'hostage' 'will' 'be' 'the' 'person'
#  'best' 'able' 'to' 'give' 'an' 'insight' 'into' 'the' 'attack' ',' 'if'
#  'the' 'suspects' 'were' 'responsible' '.']
# Sentencia final: 2
# ['user', 'user', 'if', 'so', 'that', 'hostage', 'will', 'be', 'the', 'person', 'best', 'unable', 'to', 'give', 'an', 'insight', 'into', 'the', 'time', ',', 'if', 'the', 'weren', 'resulted', 'concerned', '.']
#
#
# Sentencia original:
# ['user' 'i' 'thought' 'police' 'asked' 'media' 'not' 'to' 'report'
#  'demands' '.' 'why' 'you' 'giving' 'these' 'terrorists' 'a' 'voice' '?']
# Sentencia final: 2
# ['user', 'blackout', 'ask', 'reporters', 'suspected', 'journalists', 'not', 'to', 'reporting', 'reports', '.', 'why', 'you', 'throwing', 'these', 'terrorists', 'a', 'voice', '?']
#
#
# Sentencia original:
# ['user' 'user' 'you' "'" 're' 'choosing' 'to' 'talk' 'about' 'a' '"'
#  'robbery' '"' 'based' 'on' 'a' 'tape' 'that' 'only' 'shows' 'a'
#  'confrontation' 'not' 'a' 'crime' '.' 'so' 'stop' '!']
# Sentencia final: 2
# ['user', 'user', 'you', "'", 'prefer', 'choosing', 'to', 'speak', 'about', 'a', '"', 'robbery', '"', 'focused', 'on', 'a', 'gunshot', 'that', 'only', 'towards', 'a', 'robbery', 'not', 'a', 'vice', '.', 'so', 'end', '!']
#
#
# Sentencia original:
# ['user' 'is' 'this' 'photo' 'from' 'last' 'night' '?' '?' 'please'
#  'clarify' 'because' 'you' 'are' 'using' 'present' 'tense' '.']
# Sentencia final: 2
# ['user', 'has', 'this', 'picture', 'from', 'second', 'day', '?', '?', 'divert', 'clarify', 'because', 'you', 'am', 'being', 'use', 'tense', '.']
#
#
# # terms modificados promedio 5.102745424292845 términos por sentencia
# Largo de sentencia promedio 16.85648918469218 términos por sentencia
# para esta ejecución se debiesen reemplazar 17972  de 21095 terminos
# Resumen de modificaciones: {'VBN': 430, 'NNS': 1144, 'NN': 7070, 'VBG': 539, 'VBD': 503, 'JJ': 799, 'VBZ': 687, 'VB': 777, 'VBP': 283, 'JJR': 20, 'JJS': 15}
# Este proceso tomó 56.93891954421997 seg
#
#
# Generando 0 nuevos ejemplos para la clase commenting
# Consultando por la clase commenting
# Entrega label 3
# No se generan ejemplos
# Resumen de modificaciones: {}
# Este proceso tomó 0.19165587425231934 seg
#
#
# Generando 1893 nuevos ejemplos para la clase support
# Consultando por la clase support
# Entrega label 0
# Sentencia original:
# ['user' 'some' 'good' 'news' '!']
# Sentencia final: 0
# ['user', 'some', 'strong', 'past', '!']
#
#
# Sentencia original:
# ['shoot' 'unarmed' 'kid' '.' 'conceal' 'evidence' '.' 'impose' 'martial'
#  'law' '.' 'hara' '##ss' 'reporters' '.' 'sm' '##ear' 'the' 'victim' '.'
#  'worst' '.' 'police' '.' 'ever' '.' 'hash' '##tag' 'hash' '##tag']
# Sentencia final: 0
# ['shootout', 'uniformed', 'kid', '.', 'hiding', 'assassinate', '.', 'apologize', 'assassinate', 'lawyer', '.', 'hara', '##ss', 'journalists', '.', 'sm', '##ear', 'the', 'martyrs', '.', 'fastest', '.', 'policemen', '.', 'ever', '.', 'qaeda', '##tag', 'jihad', '##tag']
#
#
# Sentencia original:
# ['“' 'user' ':' 'several' 'hostages' 'freed' 'at' 'jewish' 'supermarket'
#  'in' 'paris' '.' 'photo' 'thomas' 'samson' 'hash' '##tag' 'html' 'sc'
#  '##ha' '##ut' 'gen' '##au' 'hi' '##n' '!']
# Sentencia final: 0
# ['“', 'user', ':', 'several', 'confirms', 'leftist', 'at', 'jewish', 'grocery', 'in', 'photograph', '.', 'france', 'henry', 'carnage', 'jihad', '##tag', 'html', 'horrific', '##ha', '##ut', 'gen', '##au', 'pic', '##n', '!']
#
#
# Sentencia original:
# ['“' 'user' ':' 'breaking' 'news' ':' 'gunmen' 'take' 'hostages' 'at'
#  'sydney' 'cafe' ',' 'wave' 'islamic' 'flag' 'html' 'html']
# Sentencia final: 0
# ['“', 'user', ':', 'disturbing', 'news', ':', 'journalists', 'take', 'perpetrators', 'at', 'hostage', 'nyc', ',', 'wave', 'satirical', 'harassment', 'html', 'html']
#
#
# Sentencia original:
# ['breaking' 'news' ':' 'gunmen' 'take' 'hostages' 'at' 'sydney' 'cafe' ','
#  'wave' 'islamic' 'flag' 'html' 'html']
# Sentencia final: 0
# ['dropping', 'gonna', ':', 'gunmen', 'assume', 'hostages', 'at', 'chicago', 'storm', ',', 'wave', 'uniformed', 'flag', 'html', 'html']
#
#
# Sentencia original:
# ['user' 'user' 'like' 'i' 'said' 'it' "'" 's' 'directly' 'across' 'from'
#  'a' 'big' 'news' 'channel' '.']
# Sentencia final: 0
# ['user', 'user', 'like', 'time', 'had', 'it', "'", 's', 'directly', 'across', 'from', 'a', 'large', 'tv', 'channels', '.']
#
#
# Sentencia original:
# ['user' 'best' 'news' 'i' 'have' 'heard' ',' 'kay' 'you' 'are' 'doing'
#  'an' 'amazing' 'job' 'thank' 'you']
# Sentencia final: 0
# ['user', 'most', 'world', 'hear', 'do', 'hear', ',', 'hear', 'you', 'am', 'exciting', 'an', 'frustrating', 'employee', 'thank', 'you']
#
#
# Sentencia original:
# ['"' 'user' ':' 'the' 'hash' '##tag' 'attack' 'suspects' 'have'
#  'reportedly' 'fired' 'shots' 'while' 'rob' 'a' 'petrol' 'station' 'html'
#  'hash' '##tag']
# Sentencia final: 0
# ['"', 'user', ':', 'the', 'qaeda', '##tag', 'assault', 'attacks', 'take', 'reportedly', 'harmed', 'gunmen', 'while', 'robbed', 'a', 'petrol', 'carnage', 'html', 'qaeda', '##tag']
#
#
# Sentencia original:
# ['we' 'can' 'see' 'people' 'coming' 'out' 'a' 'fired' '##oor' 'near' 'the'
#  'lin' '##dt' 'cafe' 'to' 'waiting' 'police' '.' 'number' '-' 'number'
#  'people' '.' 'hard' 'to' 'see' '.' 'hash' '##tag']
# Sentencia final: 0
# ['we', 'can', 'come', 'men', 'seeing', 'out', 'a', 'mohamed', '##oor', 'near', 'the', 'lin', '##dt', 'wait', 'to', 'driving', 'policemen', '.', 'group', '-', 'name', 'people', '.', 'black', 'to', 'find', '.', 'hear', '##tag']
# # terms modificados promedio 6.9963021658742734 términos por sentencia
# Largo de sentencia promedio 19.89540412044374 términos por sentencia
# para esta ejecución se debiesen reemplazar 18062  de 21289 terminos
# Resumen de modificaciones: {'JJ': 888, 'NN': 8222, 'VB': 500, 'NNS': 1437, 'JJS': 102, 'VBG': 666, 'VBD': 377, 'VBP': 161, 'VBN': 509, 'VBZ': 367, 'JJR': 15}
# Este proceso tomó 63.75723075866699 seg
#
#
# Generando 2401 nuevos ejemplos para la clase denying
# Consultando por la clase denying
# Entrega label 1
# Sentencia original:
# ['user' 'legally' 'speaking' 'it' 'doesn' "'" 't' 'matter' '.' 'the'
#  'question' 'of' 'reasonable' 'fear' 'is' 'at' 'issue' '+' 'the' 'k'
#  '##ra' '##uts' 'were' 'definitely' 'afraid' 'of' 'my' 'grandpa' '.']
# Sentencia final: 1
# ['user', 'legally', 'speaking', 'it', 'don', "'", 'wasn', 'irrelevant', '.', 'the', 'topic', 'of', 'plausible', 'afraid', 'has', 'at', 'update', 'area', 'the', 'k', '##ra', '##uts', 'were', 'definitely', 'fear', 'of', 'my', 'grandpa', '.']
#
#
# Sentencia original:
# ['user' 'user' 'user' 'user' 'what' 'other' 'info' 'do' 'they' 'have'
#  'ready' 'to' 'release' '?' 'all' 'they' 'have' 'said' 'is' 'this' 'is'
#  'why' 'we' 'approached' 'him' '.']
# Sentencia final: 1
# ['user', 'user', 'user', 'user', 'what', 'different', 'work', 'be', 'they', 'go', 'free', 'to', 'time', '?', 'all', 'they', 'be', 'had', 'has', 'this', 'has', 'why', 'we', 'contacted', 'him', '.']
#
#
# Sentencia original:
# ['user' 'user' '"' 'grease' 'my' 'palm' 'with' 'silver' 'lo' '##vie' '.'
#  '"' 'the' 'disgrace' '##ful' 'prick' '.' 'run' "'" 'em' 'outta' 'town'
#  'folks' '.']
# Sentencia final: 1
# ['user', 'user', '"', 'grease', 'my', 'palm', 'with', 'silver', 'life', '##vie', '.', '"', 'the', 'insult', '##ful', 'leftist', '.', 'come', "'", 'worthless', 'gonna', 'worthless', 'people', '.']
#
#
# Sentencia original:
# ['user' 'user' 'it' "'" 's' 'not' 'a' 'matter' 'of' 'criticism' ',' 'it'
#  "'" 's' 'insulting' 'and' 'dem' '##ean' '##ing' 'and' 'offensive']
# Sentencia final: 1
# ['user', 'user', 'it', "'", 're', 'not', 'a', 'discussion', 'of', 'discussion', ',', 'it', "'", 've', 'insulting', 'and', 'dem', '##ean', '##ing', 'and', 'white']
#
#
# Sentencia original:
# ['user' 'of' 'course' ',' 'however' 'please' 'do' 'not' 'try' 'and'
#  'compare' 'it' 'to' 'hundreds' 'of' 'years' 'of' 'systemic' 'oppression'
#  'of' 'a' 'whole' 'people']
# Sentencia final: 1
# ['user', 'of', 'course', ',', 'however', 'behave', 'go', 'not', 'attempt', 'and', 'attempt', 'it', 'to', 'days', 'of', 'riots', 'of', 'systemic', 'oppression', 'of', 'a', 'entire', 'men']
#
#
# Sentencia original:
# ['heartbreak' 'for' 'hash' '##tag' 'and' 'canada' '.' '“' 'user' ':'
#  'soldier' 'killed' 'in' 'canada' 'shooting' 'was' 'a' 'young' 'res'
#  '##er' '##vis' '##t' 'with' 'a' 'son' 'html']
# Sentencia final: 1
# ['damn', 'for', 'qaeda', '##tag', 'and', 'qaeda', '.', '“', 'user', ':', 'employee', 'murdered', 'in', 'canadian', 'being', 'were', 'a', 'new', 'res', '##er', '##vis', '##t', 'with', 'a', 'qaeda', 'html']
#
#
# Sentencia original:
# ['user' '"' 'may' 'be' '"' 'really' '?' 'forehead' 'smack']
# Sentencia final: 1
# ['user', '"', 'may', 'do', '"', 'really', '?', 'forehead', 'gotta']
#
#
# Sentencia original:
# ['user' 'user' 'user' 'i' "'" 'm' 'not' 'watching' 'it' ',' 'but' 'it'
#  'sounds' 'as' 'if' 'it' 'is' 'being' 'treated' 'as' 'sport' '.']
# Sentencia final: 1
# ['user', 'user', 'user', 'verify', "'", 'watch', 'not', 'watching', 'it', ',', 'but', 'it', 'looks', 'as', 'if', 'it', 'has', 'having', 'fascinated', 'as', 'treat', '.']
#
#
# Sentencia original:
# ['user' 'kindly' 'verify' 'your' 'report' 'of' 'shooting' 'at' 'ride'
#  '##au' 'centre' 'ottawa' ',' 'canada' '.' 'local' 'reports' 'state'
#  'otherwise' '.']
# Sentencia final: 1
# ['user', 'kindly', 'verify', 'your', 'report', 'of', 'fleeing', 'at', 'ride', '##au', 'centre', 'canadian', ',', 'canada', '.', 'new', 'reports', 'report', 'otherwise', '.']
#
#
# # terms modificados promedio 6.302790503956684 términos por sentencia
# Largo de sentencia promedio 19.73219491878384 términos por sentencia
# para esta ejecución se debiesen reemplazar 21445  de 25220 terminos
# Resumen de modificaciones: {'NN': 8692, 'JJ': 1272, 'VBZ': 707, 'VB': 940, 'VBD': 518, 'VBN': 499, 'NNS': 1483, 'VBG': 702, 'VBP': 264, 'JJR': 33, 'JJS': 23}
# Este proceso tomó 69.5213074684143 seg
#
# --------------------------------------------------------
#
# Generando ejemplos en base a probabilidad -->  0.85
# --------------------------------------------------------
#
#
# Generando 2404 nuevos ejemplos para la clase questioning
# Consultando por la clase questioning
# Entrega label 2
# Sentencia original:
# ['user' 'user' 'clarified' 'that' 'earlier' '.' 'cheers']
# Sentencia final: 2
# ['user', 'user', 'commented', 'that', 'earlier', '.', 'words']
#
#
# Sentencia original:
# ['user' 'user' 'any' 'chance' 'that' "'" 's' 'being' 'said' 'for' 'fear'
#  'of' 'retribution' '?']
# Sentencia final: 2
# ['user', 'user', 'any', 'possibility', 'that', "'", 's', 'saying', 'was', 'for', 'hate', 'of', 'retribution', '?']
#
#
# Sentencia original:
# ['user' 'user' 'user' 'how' 'stupid' 'html']
# Sentencia final: 2
# ['user', 'user', 'user', 'how', 'sarcastic', 'html']
#
#
# Sentencia original:
# ['user' 'user' 'user' 'user' 'ah' 'true' '.' 'problem' 'now' 'is' 'we' "'"
#  'll' 'probably' 'only' 'get' 'coroner' "'" 's' 'details' 'they' 'won' "'"
#  't' 'make' 'it' '.']
# Sentencia final: 2
# ['user', 'user', 'user', 'user', 'gunshot', 'sarcastic', '.', 'situation', 'now', 'has', 'we', "'", 'gonna', 'probably', 'only', 'identify', 'helpful', "'", 'retribution', 'facts', 'they', 'retribution', "'", 'found', 'be', 'it', '.']
#
#
# Sentencia original:
# ['user' ',' 'hi' 'betty' '.' 'you' 'are' 'in' 'australia' '?']
# Sentencia final: 2
# ['user', ',', 'clarify', 'betty', '.', 'you', 'am', 'in', 'people', '?']
#
#
# Sentencia original:
# ['user' 'user' 'if' 'so' 'that' 'hostage' 'will' 'be' 'the' 'person'
#  'best' 'able' 'to' 'give' 'an' 'insight' 'into' 'the' 'attack' ',' 'if'
#  'the' 'suspects' 'were' 'responsible' '.']
# Sentencia final: 2
# ['user', 'user', 'if', 'so', 'that', 'wasn', 'will', 'be', 'the', 'person', 'most', 'unable', 'to', 'identify', 'an', 'coroner', 'into', 'the', 'time', ',', 'if', 'the', 'weren', 'was', 'sarcastic', '.']
#
#
# Sentencia original:
# ['user' 'i' 'thought' 'police' 'asked' 'media' 'not' 'to' 'report'
#  'demands' '.' 'why' 'you' 'giving' 'these' 'terrorists' 'a' 'voice' '?']
# Sentencia final: 2
# ['user', 'think', 'ask', 'inquiries', 'commented', 'people', 'not', 'to', 'question', 'reports', '.', 'why', 'you', 'causing', 'these', 'tells', 'a', 'voice', '?']
#
#
# Sentencia original:
# ['user' 'user' 'you' "'" 're' 'choosing' 'to' 'talk' 'about' 'a' '"'
#  'robbery' '"' 'based' 'on' 'a' 'tape' 'that' 'only' 'shows' 'a'
#  'confrontation' 'not' 'a' 'crime' '.' 'so' 'stop' '!']
# Sentencia final: 2
# ['user', 'user', 'you', "'", 're', 'choosing', 'to', 'talk', 'about', 'a', '"', 'robbery', '"', 'called', 'on', 'a', 'gunshot', 'that', 'only', 'towards', 'a', 'robbery', 'not', 'a', 'theft', '.', 'so', 'stop', '!']
#
#
# Sentencia original:
# ['user' 'is' 'this' 'photo' 'from' 'last' 'night' '?' '?' 'please'
#  'clarify' 'because' 'you' 'are' 'using' 'present' 'tense' '.']
# Sentencia final: 2
# ['user', 'has', 'this', 'picture', 'from', 'next', 'day', '?', '?', 'understand', 'clarify', 'because', 'you', 'are', 'using', 'present', 'tense', '.']
#
#
# # terms modificados promedio 5.102329450915142 términos por sentencia
# Largo de sentencia promedio 16.897670549084857 términos por sentencia
# para esta ejecución se debiesen reemplazar 17992  de 21195 terminos
# Resumen de modificaciones: {'VBN': 429, 'NNS': 1173, 'NN': 6945, 'VBG': 571, 'VBD': 508, 'JJ': 812, 'VBZ': 713, 'VB': 785, 'VBP': 293, 'JJS': 16, 'JJR': 21}
# Este proceso tomó 57.10836052894592 seg
#
#
# Generando 0 nuevos ejemplos para la clase commenting
# Consultando por la clase commenting
# Entrega label 3
# No se generan ejemplos
# Resumen de modificaciones: {}
# Este proceso tomó 0.19321107864379883 seg
#
#
# Generando 1893 nuevos ejemplos para la clase support
# Consultando por la clase support
# Entrega label 0
# Sentencia original:
# ['user' 'some' 'good' 'news' '!']
# Sentencia final: 0
# ['user', 'some', 'good', 'time', '!']
#
#
# Sentencia original:
# ['shoot' 'unarmed' 'kid' '.' 'conceal' 'evidence' '.' 'impose' 'martial'
#  'law' '.' 'hara' '##ss' 'reporters' '.' 'sm' '##ear' 'the' 'victim' '.'
#  'worst' '.' 'police' '.' 'ever' '.' 'hash' '##tag' 'hash' '##tag']
# Sentencia final: 0
# ['shoot', 'uniformed', 'kid', '.', 'hiding', 'assassinate', '.', 'apologize', 'assassinate', 'lawyer', '.', 'hara', '##ss', 'reporters', '.', 'sm', '##ear', 'the', 'closest', '.', 'best', '.', 'cops', '.', 'ever', '.', 'qaeda', '##tag', 'jihad', '##tag']
#
#
# Sentencia original:
# ['“' 'user' ':' 'several' 'hostages' 'freed' 'at' 'jewish' 'supermarket'
#  'in' 'paris' '.' 'photo' 'thomas' 'samson' 'hash' '##tag' 'html' 'sc'
#  '##ha' '##ut' 'gen' '##au' 'hi' '##n' '!']
# Sentencia final: 0
# ['“', 'user', ':', 'many', 'children', 'freed', 'at', 'jew', 'catholic', 'in', 'photograph', '.', 'photo', 'henry', 'carnage', 'jihad', '##tag', 'html', 'sc', '##ha', '##ut', 'gen', '##au', 'chen', '##n', '!']
#
#
# Sentencia original:
# ['“' 'user' ':' 'breaking' 'news' ':' 'gunmen' 'take' 'hostages' 'at'
#  'sydney' 'cafe' ',' 'wave' 'islamic' 'flag' 'html' 'html']
# Sentencia final: 0
# ['“', 'user', ':', 'frustrating', 'broken', ':', 'journalists', 'take', 'hostages', 'at', 'london', 'toronto', ',', 'wave', 'islamic', 'fascism', 'html', 'html']
#
#
# Sentencia original:
# ['breaking' 'news' ':' 'gunmen' 'take' 'hostages' 'at' 'sydney' 'cafe' ','
#  'wave' 'islamic' 'flag' 'html' 'html']
# Sentencia final: 0
# ['dropping', 'broken', ':', 'demands', 'assume', 'perpetrators', 'at', 'london', 'group', ',', 'wave', 'swiss', 'fascism', 'html', 'html']
# Sentencia original:
# ['user' 'user' 'like' 'i' 'said' 'it' "'" 's' 'directly' 'across' 'from'
#  'a' 'big' 'news' 'channel' '.']
# Sentencia final: 0
# ['user', 'user', 'like', 'use', 'was', 'it', "'", 's', 'directly', 'across', 'from', 'a', 'large', 'show', 'channels', '.']
#
#
# Sentencia original:
# ['user' 'best' 'news' 'i' 'have' 'heard' ',' 'kay' 'you' 'are' 'doing'
#  'an' 'amazing' 'job' 'thank' 'you']
# Sentencia final: 0
# ['user', 'most', 'time', 'hear', 'have', 'hear', ',', 'kay', 'you', 'am', 'exciting', 'an', 'frustrating', 'employee', 'brilliant', 'you']
#
#
# Sentencia original:
# ['"' 'user' ':' 'the' 'hash' '##tag' 'attack' 'suspects' 'have'
#  'reportedly' 'fired' 'shots' 'while' 'rob' 'a' 'petrol' 'station' 'html'
#  'hash' '##tag']
# Sentencia final: 0
# ['"', 'user', ':', 'the', 'qaeda', '##tag', 'assault', 'attacks', 'impose', 'reportedly', 'used', 'shooters', 'while', 'robbed', 'a', 'petrol', 'carnage', 'html', 'qaeda', '##tag']
#
#
# Sentencia original:
# ['we' 'can' 'see' 'people' 'coming' 'out' 'a' 'fired' '##oor' 'near' 'the'
#  'lin' '##dt' 'cafe' 'to' 'waiting' 'police' '.' 'number' '-' 'number'
#  'people' '.' 'hard' 'to' 'see' '.' 'hash' '##tag']
# Sentencia final: 0
# ['we', 'can', 'come', 'men', 'seeing', 'out', 'a', 'made', '##oor', 'near', 'the', 'lin', '##dt', 'wait', 'to', 'dominating', 'policemen', '.', 'group', '-', 'time', 'women', '.', 'hard', 'to', 'impose', '.', 'hear', '##tag']
#
#
# # terms modificados promedio 6.954041204437401 términos por sentencia
# Largo de sentencia promedio 19.89064976228209 términos por sentencia
# para esta ejecución se debiesen reemplazar 18066  de 21262 terminos
# Resumen de modificaciones: {'NN': 8184, 'JJ': 885, 'VB': 490, 'JJS': 102, 'NNS': 1439, 'VBG': 675, 'VBD': 373, 'VBP': 160, 'VBN': 482, 'VBZ': 358, 'JJR': 16}
# Este proceso tomó 64.16402435302734 seg
#
#
# Generando 2401 nuevos ejemplos para la clase denying
# Consultando por la clase denying
# Entrega label 1
# Sentencia original:
# ['user' 'legally' 'speaking' 'it' 'doesn' "'" 't' 'matter' '.' 'the'
#  'question' 'of' 'reasonable' 'fear' 'is' 'at' 'issue' '+' 'the' 'k'
#  '##ra' '##uts' 'were' 'definitely' 'afraid' 'of' 'my' 'grandpa' '.']
# Sentencia final: 1
# ['user', 'legally', 'speaking', 'it', 'didn', "'", 'hasn', 'irrelevant', '.', 'the', 'debate', 'of', 'plausible', 'fear', 'comes', 'at', 'issue', 'problem', 'the', 'k', '##ra', '##uts', 'was', 'definitely', 'fear', 'of', 'my', 'grandpa', '.']
#
#
# Sentencia original:
# ['user' 'user' 'user' 'user' 'what' 'other' 'info' 'do' 'they' 'have'
#  'ready' 'to' 'release' '?' 'all' 'they' 'have' 'said' 'is' 'this' 'is'
#  'why' 'we' 'approached' 'him' '.']
# Sentencia final: 1
# ['user', 'user', 'user', 'user', 'what', 'new', 'helpful', 'take', 'they', 'get', 'free', 'to', 'time', '?', 'all', 'they', 'be', 'was', 'has', 'this', 'is', 'why', 'we', 'contacted', 'him', '.']
#
#
# Sentencia original:
# ['user' 'user' '"' 'grease' 'my' 'palm' 'with' 'silver' 'lo' '##vie' '.'
#  '"' 'the' 'disgrace' '##ful' 'prick' '.' 'run' "'" 'em' 'outta' 'town'
#  'folks' '.']
# Sentencia final: 1
# ['user', 'user', '"', 'grease', 'my', 'palm', 'with', 'silver', 'lo', '##vie', '.', '"', 'the', 'disgrace', '##ful', 'leftist', '.', 'remove', "'", 'hysteria', 'gonna', 'heartbreak', 'guys', '.']
#
#
# Sentencia original:
# ['user' 'user' 'it' "'" 's' 'not' 'a' 'matter' 'of' 'criticism' ',' 'it'
#  "'" 's' 'insulting' 'and' 'dem' '##ean' '##ing' 'and' 'offensive']
# Sentencia final: 1
# ['user', 'user', 'it', "'", 'time', 'not', 'a', 'matter', 'of', 'discussion', ',', 'it', "'", 'll', 'disgusting', 'and', 'leftist', '##ean', '##ing', 'and', 'white']
#
#
# Sentencia original:
# ['user' 'of' 'course' ',' 'however' 'please' 'do' 'not' 'try' 'and'
#  'compare' 'it' 'to' 'hundreds' 'of' 'years' 'of' 'systemic' 'oppression'
#  'of' 'a' 'whole' 'people']
# Sentencia final: 1
# ['user', 'of', 'victim', ',', 'however', 'don', 'go', 'not', 'attempt', 'and', 'attempt', 'it', 'to', 'days', 'of', 'years', 'of', 'systemic', 'oppression', 'of', 'a', 'whole', 'men']
#
#
# Sentencia original:
# ['user' 'user' 'not' 'confirmed']
# Sentencia final: 1
# ['user', 'user', 'not', 'suggested']
#
#
# Sentencia original:
# ['heartbreak' 'for' 'hash' '##tag' 'and' 'canada' '.' '“' 'user' ':'
#  'soldier' 'killed' 'in' 'canada' 'shooting' 'was' 'a' 'young' 'res'
#  '##er' '##vis' '##t' 'with' 'a' 'son' 'html']
# Sentencia final: 1
# ['damn', 'for', 'qaeda', '##tag', 'and', 'ctv', '.', '“', 'user', ':', 'kill', 'murdered', 'in', 'canadian', 'being', 'were', 'a', 'new', 'res', '##er', '##vis', '##t', 'with', 'a', 'son', 'html']
#
#
# Sentencia original:
# ['user' '"' 'may' 'be' '"' 'really' '?' 'forehead' 'smack']
# Sentencia final: 1
# ['user', '"', 'may', 'do', '"', 'really', '?', 'forehead', 'smack']
#
#
# Sentencia original:
# ['user' 'user' 'user' 'i' "'" 'm' 'not' 'watching' 'it' ',' 'but' 'it'
#  'sounds' 'as' 'if' 'it' 'is' 'being' 'treated' 'as' 'sport' '.']
# Sentencia final: 1
# ['user', 'user', 'user', 'i', "'", 'watch', 'not', 'making', 'it', ',', 'but', 'it', 'looks', 'as', 'if', 'it', 'has', 'feeling', 'fascinated', 'as', 'treat', '.']
#
#
# # terms modificados promedio 6.274885464389838 términos por sentencia
# Largo de sentencia promedio 19.658059142024157 términos por sentencia
# para esta ejecución se debiesen reemplazar 21343  de 25090 terminos
# Resumen de modificaciones: {'NN': 8701, 'JJ': 1248, 'VBZ': 675, 'VBD': 525, 'VB': 961, 'VBN': 484, 'NNS': 1441, 'VBG': 715, 'VBP': 260, 'JJS': 25, 'JJR': 31}
# Este proceso tomó 69.34228944778442 seg
#
# --------------------------------------------------------
#
# Generando ejemplos en base a probabilidad -->  0.85
# --------------------------------------------------------
#
#
# Generando 2404 nuevos ejemplos para la clase questioning
# Consultando por la clase questioning
# Entrega label 2
# Sentencia original:
# ['user' 'user' 'clarified' 'that' 'earlier' '.' 'cheers']
# Sentencia final: 2
# ['user', 'user', 'commented', 'that', 'earlier', '.', 'words']
#
#
# Sentencia original:
# ['user' 'user' 'any' 'chance' 'that' "'" 's' 'being' 'said' 'for' 'fear'
#  'of' 'retribution' '?']
# Sentencia final: 2
# ['user', 'user', 'any', 'possibility', 'that', "'", 'thought', 'having', 'reported', 'for', 'fear', 'of', 'retribution', '?']
#
#
# Sentencia original:
# ['user' 'user' 'user' 'user' 'ah' 'true' '.' 'problem' 'now' 'is' 'we' "'"
#  'll' 'probably' 'only' 'get' 'coroner' "'" 's' 'details' 'they' 'won' "'"
#  't' 'make' 'it' '.']
# Sentencia final: 2
# ['user', 'user', 'user', 'user', 'oh', 'sarcastic', '.', 'life', 'now', 'is', 'we', "'", 'gonna', 'probably', 'only', 'take', 'coroner', "'", 'clarify', 'details', 'they', 'retribution', "'", 'time', 'be', 'it', '.']
#
#
# Sentencia original:
# ['user' ',' 'hi' 'betty' '.' 'you' 'are' 'in' 'australia' '?']
# Sentencia final: 2
# ['user', ',', 'clarify', 'betty', '.', 'you', 'am', 'in', 'weren', '?']
#
#
# Sentencia original:
# ['user' 'user' 'if' 'so' 'that' 'hostage' 'will' 'be' 'the' 'person'
#  'best' 'able' 'to' 'give' 'an' 'insight' 'into' 'the' 'attack' ',' 'if'
#  'the' 'suspects' 'were' 'responsible' '.']
# Sentencia final: 2
# ['user', 'user', 'if', 'so', 'that', 'time', 'will', 'identify', 'the', 'man', 'most', 'unable', 'to', 'get', 'an', 'insight', 'into', 'the', 'hit', ',', 'if', 'the', 'suspects', 'was', 'sarcastic', '.']
#
#
# Sentencia original:
# ['user' 'i' 'thought' 'police' 'asked' 'media' 'not' 'to' 'report'
#  'demands' '.' 'why' 'you' 'giving' 'these' 'terrorists' 'a' 'voice' '?']
# Sentencia final: 2
# ['user', 'think', 'thought', 'people', 'asked', 'people', 'not', 'to', 'report', 'demands', '.', 'why', 'you', 'getting', 'these', 'hostages', 'a', 'voice', '?']
#
#
# Sentencia original:
# ['user' 'user' 'you' "'" 're' 'choosing' 'to' 'talk' 'about' 'a' '"'
#  'robbery' '"' 'based' 'on' 'a' 'tape' 'that' 'only' 'shows' 'a'
#  'confrontation' 'not' 'a' 'crime' '.' 'so' 'stop' '!']
# Sentencia final: 2
# ['user', 'user', 'you', "'", 'co', 'choosing', 'to', 'speak', 'about', 'a', '"', 'found', '"', 'focused', 'on', 'a', 'gunshot', 'that', 'only', 'towards', 'a', 'show', 'not', 'a', 'murder', '.', 'so', 'start', '!']
#
#
# Sentencia original:
# ['user' 'is' 'this' 'photo' 'from' 'last' 'night' '?' '?' 'please'
#  'clarify' 'because' 'you' 'are' 'using' 'present' 'tense' '.']
# Sentencia final: 2
# ['user', 'seems', 'this', 'photo', 'from', 'next', 'day', '?', '?', 'court', 'clarify', 'because', 'you', 'am', 'trying', 'present', 'tense', '.']
#
#
# Sentencia original:
# ['user' 'user' 'why' 'was' 'this' 'mad' 'man' 'not' 'behind' 'bars' '?'
#  'u' '##gh']
# Sentencia final: 2
# ['user', 'user', 'why', 'was', 'this', 'time', 'god', 'not', 'behind', 'bars', '?', 'umm', '##gh']
# # terms modificados promedio 5.112312811980034 términos por sentencia
# Largo de sentencia promedio 16.920133111480865 términos por sentencia
# para esta ejecución se debiesen reemplazar 18039  de 21232 terminos
# Resumen de modificaciones: {'VBN': 435, 'NNS': 1166, 'NN': 7049, 'VBG': 534, 'VBD': 506, 'JJ': 795, 'VB': 782, 'VBP': 277, 'JJS': 16, 'VBZ': 708, 'JJR': 22}
# Este proceso tomó 57.099419593811035 seg
#
#
# Generando 0 nuevos ejemplos para la clase commenting
# Consultando por la clase commenting
# Entrega label 3
# No se generan ejemplos
# Resumen de modificaciones: {}
# Este proceso tomó 0.1922774314880371 seg
#
#
# Generando 1893 nuevos ejemplos para la clase support
# Consultando por la clase support
# Entrega label 0
# Sentencia original:
# ['user' 'some' 'good' 'news' '!']
# Sentencia final: 0
# ['user', 'some', 'good', 'right', '!']
#
#
# Sentencia original:
# ['shoot' 'unarmed' 'kid' '.' 'conceal' 'evidence' '.' 'impose' 'martial'
#  'law' '.' 'hara' '##ss' 'reporters' '.' 'sm' '##ear' 'the' 'victim' '.'
#  'worst' '.' 'police' '.' 'ever' '.' 'hash' '##tag' 'hash' '##tag']
# Sentencia final: 0
# ['shoot', 'uniformed', 'assassinate', '.', 'hiding', 'assassinate', '.', 'apologize', 'assassinate', 'lawyer', '.', 'hara', '##ss', 'journalists', '.', 'sm', '##ear', 'the', 'martyrs', '.', 'best', '.', 'policemen', '.', 'ever', '.', 'qaeda', '##tag', 'jihad', '##tag']
#
#
# Sentencia original:
# ['“' 'user' ':' 'several' 'hostages' 'freed' 'at' 'jewish' 'supermarket'
#  'in' 'paris' '.' 'photo' 'thomas' 'samson' 'hash' '##tag' 'html' 'sc'
#  '##ha' '##ut' 'gen' '##au' 'hi' '##n' '!']
# Sentencia final: 0
# ['“', 'user', ':', 'many', 'militants', 'handgun', 'at', 'jew', 'moscow', 'in', 'photograph', '.', 'photo', 'henry', 'carnage', 'jihad', '##tag', 'html', 'sc', '##ha', '##ut', 'gen', '##au', 'pic', '##n', '!']
#
#
# Sentencia original:
# ['“' 'user' ':' 'breaking' 'news' ':' 'gunmen' 'take' 'hostages' 'at'
#  'sydney' 'cafe' ',' 'wave' 'islamic' 'flag' 'html' 'html']
# Sentencia final: 0
# ['“', 'user', ':', 'frustrating', 'leftist', ':', 'journalists', 'assume', 'perpetrators', 'at', 'hostage', 'nyc', ',', 'wave', 'racial', 'fascism', 'html', 'html']
#
#
# Sentencia original:
# ['breaking' 'news' ':' 'gunmen' 'take' 'hostages' 'at' 'sydney' 'cafe' ','
#  'wave' 'islamic' 'flag' 'html' 'html']
# Sentencia final: 0
# ['stealing', 'news', ':', 'journalists', 'assume', 'terrorists', 'at', 'sydney', 'storm', ',', 'wave', 'swiss', 'fascism', 'html', 'html']
#
#
# Sentencia original:
# ['user' 'user' 'like' 'i' 'said' 'it' "'" 's' 'directly' 'across' 'from'
#  'a' 'big' 'news' 'channel' '.']
# Sentencia final: 0
# ['user', 'user', 'like', 'thought', 'had', 'it', "'", 're', 'directly', 'across', 'from', 'a', 'large', 'news', 'channel', '.']
#
#
# Sentencia original:
# ['user' 'best' 'news' 'i' 'have' 'heard' ',' 'kay' 'you' 'are' 'doing'
#  'an' 'amazing' 'job' 'thank' 'you']
# Sentencia final: 0
# ['user', 'most', 'need', 'head', 'do', 'hear', ',', 'hear', 'you', 'am', 'doing', 'an', 'frustrating', 'awesome', 'honor', 'you']
#
#
# Sentencia original:
# ['"' 'user' ':' 'the' 'hash' '##tag' 'attack' 'suspects' 'have'
#  'reportedly' 'fired' 'shots' 'while' 'rob' 'a' 'petrol' 'station' 'html'
#  'hash' '##tag']
# Sentencia final: 0
# ['"', 'user', ':', 'the', 'hash', '##tag', 'attack', 'suspects', 'impose', 'reportedly', 'killed', 'shooters', 'while', 'robbed', 'a', 'petrol', 'carnage', 'html', 'qaeda', '##tag']
#
#
# Sentencia original:
# ['we' 'can' 'see' 'people' 'coming' 'out' 'a' 'fired' '##oor' 'near' 'the'
#  'lin' '##dt' 'cafe' 'to' 'waiting' 'police' '.' 'number' '-' 'number'
#  'people' '.' 'hard' 'to' 'see' '.' 'hash' '##tag']
# Sentencia final: 0
# ['we', 'can', 'come', 'men', 'being', 'out', 'a', 'killed', '##oor', 'near', 'the', 'lin', '##dt', 'wait', 'to', 'dominating', 'cops', '.', 'group', '-', 'number', 'men', '.', 'many', 'to', 'do', '.', 'hear', '##tag']
#
#
# # terms modificados promedio 6.957210776545167 términos por sentencia
# Largo de sentencia promedio 19.91230850501849 términos por sentencia
# para esta ejecución se debiesen reemplazar 18063  de 21330 terminos
# Resumen de modificaciones: {'NN': 8217, 'JJ': 897, 'VB': 503, 'NNS': 1410, 'JJS': 110, 'VBG': 621, 'VBD': 362, 'VBP': 152, 'VBN': 501, 'VBZ': 380, 'JJR': 17}
# Este proceso tomó 64.00781726837158 seg
#
#
# Generando 2401 nuevos ejemplos para la clase denying
# Consultando por la clase denying
# Entrega label 1
# Sentencia original:
# ['user' 'legally' 'speaking' 'it' 'doesn' "'" 't' 'matter' '.' 'the'
#  'question' 'of' 'reasonable' 'fear' 'is' 'at' 'issue' '+' 'the' 'k'
#  '##ra' '##uts' 'were' 'definitely' 'afraid' 'of' 'my' 'grandpa' '.']
# Sentencia final: 1
# ['user', 'legally', 'speaking', 'it', 'hasn', "'", 'wasn', 'matter', '.', 'the', 'topic', 'of', 'plausible', 'hope', 'believes', 'at', 'issue', 'problem', 'the', 'k', '##ra', '##uts', 'died', 'definitely', 'fear', 'of', 'my', 'grandpa', '.']
#
#
# Sentencia original:
# ['user' 'user' 'user' 'user' 'what' 'other' 'info' 'do' 'they' 'have'
#  'ready' 'to' 'release' '?' 'all' 'they' 'have' 'said' 'is' 'this' 'is'
#  'why' 'we' 'approached' 'him' '.']
# Sentencia final: 1
# ['user', 'user', 'user', 'user', 'what', 'unidentified', 'rest', 'take', 'they', 'see', 'prepared', 'to', 'freed', '?', 'all', 'they', 'have', 'had', 'is', 'this', 'has', 'why', 'we', 'contacted', 'him', '.']
#
#
# Sentencia original:
# ['user' 'user' '"' 'grease' 'my' 'palm' 'with' 'silver' 'lo' '##vie' '.'
#  '"' 'the' 'disgrace' '##ful' 'prick' '.' 'run' "'" 'em' 'outta' 'town'
#  'folks' '.']
# Sentencia final: 1
# ['user', 'user', '"', 'grease', 'my', 'palm', 'with', 'silver', 'life', '##vie', '.', '"', 'the', 'disgrace', '##ful', 'leftist', '.', 'come', "'", 'hysteria', 'gonna', 'da', 'guys', '.']
#
#
# Sentencia original:
# ['user' 'user' 'it' "'" 's' 'not' 'a' 'matter' 'of' 'criticism' ',' 'it'
#  "'" 's' 'insulting' 'and' 'dem' '##ean' '##ing' 'and' 'offensive']
# Sentencia final: 1
# ['user', 'user', 'it', "'", 'time', 'not', 'a', 'shouldn', 'of', 'discussion', ',', 'it', "'", 'll', 'murdering', 'and', 'leftist', '##ean', '##ing', 'and', 'white']
#
#
# Sentencia original:
# ['user' 'of' 'course' ',' 'however' 'please' 'do' 'not' 'try' 'and'
#  'compare' 'it' 'to' 'hundreds' 'of' 'years' 'of' 'systemic' 'oppression'
#  'of' 'a' 'whole' 'people']
# Sentencia final: 1
# ['user', 'of', 'victim', ',', 'however', 'disagree', 'go', 'not', 'attempt', 'and', 'compare', 'it', 'to', 'hundreds', 'of', 'riots', 'of', 'systemic', 'oppression', 'of', 'a', 'entire', 'men']
#
#
# Sentencia original:
# ['user' 'user' 'not' 'confirmed']
# Sentencia final: 1
# ['user', 'user', 'not', 'relieved']
#
#
# Sentencia original:
# ['heartbreak' 'for' 'hash' '##tag' 'and' 'canada' '.' '“' 'user' ':'
#  'soldier' 'killed' 'in' 'canada' 'shooting' 'was' 'a' 'young' 'res'
#  '##er' '##vis' '##t' 'with' 'a' 'son' 'html']
# Sentencia final: 1
# ['damn', 'for', 'qaeda', '##tag', 'and', 'canadian', '.', '“', 'user', ':', 'soldier', 'killed', 'in', 'shot', 'being', 'were', 'a', 'new', 'res', '##er', '##vis', '##t', 'with', 'a', 'daughter', 'html']
#
#
# Sentencia original:
# ['user' '"' 'may' 'be' '"' 'really' '?' 'forehead' 'smack']
# Sentencia final: 1
# ['user', '"', 'may', 'have', '"', 'really', '?', 'forehead', 'gotta']
#
#
# Sentencia original:
# ['user' 'user' 'user' 'i' "'" 'm' 'not' 'watching' 'it' ',' 'but' 'it'
#  'sounds' 'as' 'if' 'it' 'is' 'being' 'treated' 'as' 'sport' '.']
# Sentencia final: 1
# ['user', 'user', 'user', 'use', "'", 'watch', 'not', 'listening', 'it', ',', 'but', 'it', 'looks', 'as', 'if', 'it', 'has', 'having', 'fascinated', 'as', 'treat', '.']
#
#
# # terms modificados promedio 6.304872969596001 términos por sentencia
# Largo de sentencia promedio 19.736359850062474 términos por sentencia
# para esta ejecución se debiesen reemplazar 21487  de 25254 terminos
# Resumen de modificaciones: {'NN': 8736, 'JJ': 1230, 'VBZ': 679, 'VBD': 516, 'VB': 946, 'VBN': 527, 'NNS': 1448, 'VBG': 739, 'VBP': 260, 'JJS': 26, 'JJR': 31}
# Este proceso tomó 69.74445295333862 seg
#
# --------------------------------------------------------
#
# Generando ejemplos en base a probabilidad -->  0.85
# --------------------------------------------------------
#
#
# Generando 2404 nuevos ejemplos para la clase questioning
# Consultando por la clase questioning
# Entrega label 2
# Sentencia original:
# ['user' 'user' 'clarified' 'that' 'earlier' '.' 'cheers']
# Sentencia final: 2
# ['user', 'user', 'commented', 'that', 'earlier', '.', 'cheers']
#
#
# Sentencia original:
# ['user' 'user' 'any' 'chance' 'that' "'" 's' 'being' 'said' 'for' 'fear'
#  'of' 'retribution' '?']
# Sentencia final: 2
# ['user', 'user', 'any', 'possibility', 'that', "'", 'thought', 'saying', 'said', 'for', 'thought', 'of', 'retribution', '?']
#
#
# Sentencia original:
# ['user' 'user' 'user' 'how' 'stupid' 'html']
# Sentencia final: 2
# ['user', 'user', 'user', 'how', 'sarcastic', 'html']
#
#
# Sentencia original:
# ['user' 'user' 'user' 'user' 'ah' 'true' '.' 'problem' 'now' 'is' 'we' "'"
#  'll' 'probably' 'only' 'get' 'coroner' "'" 's' 'details' 'they' 'won' "'"
#  't' 'make' 'it' '.']
# Sentencia final: 2
# ['user', 'user', 'user', 'user', 'oh', 'reliable', '.', 'situation', 'now', 'has', 'we', "'", 'll', 'probably', 'only', 'expect', 'helpful', "'", 'retribution', 'facts', 'they', 'retribution', "'", 't', 'do', 'it', '.']
#
#
# Sentencia original:
# ['user' ',' 'hi' 'betty' '.' 'you' 'are' 'in' 'australia' '?']
# Sentencia final: 2
# ['user', ',', 'clarify', 'betty', '.', 'you', 'am', 'in', 'people', '?']
#
#
# Sentencia original:
# ['user' 'user' 'if' 'so' 'that' 'hostage' 'will' 'be' 'the' 'person'
#  'best' 'able' 'to' 'give' 'an' 'insight' 'into' 'the' 'attack' ',' 'if'
#  'the' 'suspects' 'were' 'responsible' '.']
# Sentencia final: 2
# ['user', 'user', 'if', 'so', 'that', 'wasn', 'will', 'happen', 'the', 'person', 'best', 'unable', 'to', 'give', 'an', 'insight', 'into', 'the', 'action', ',', 'if', 'the', 'thanks', 'resulted', 'responsible', '.']
#
#
# Sentencia original:
# ['user' 'i' 'thought' 'police' 'asked' 'media' 'not' 'to' 'report'
#  'demands' '.' 'why' 'you' 'giving' 'these' 'terrorists' 'a' 'voice' '?']
# Sentencia final: 2
# ['user', 'time', 'clarify', 'people', 'clarified', 'media', 'not', 'to', 'report', 'reports', '.', 'why', 'you', 'causing', 'these', 'terrorists', 'a', 'voice', '?']
#
#
# Sentencia original:
# ['user' 'user' 'you' "'" 're' 'choosing' 'to' 'talk' 'about' 'a' '"'
#  'robbery' '"' 'based' 'on' 'a' 'tape' 'that' 'only' 'shows' 'a'
#  'confrontation' 'not' 'a' 'crime' '.' 'so' 'stop' '!']
# Sentencia final: 2
# ['user', 'user', 'you', "'", 'co', 'choosing', 'to', 'talk', 'about', 'a', '"', 'retribution', '"', 'focused', 'on', 'a', 'gunshot', 'that', 'only', 'incidents', 'a', 'confrontation', 'not', 'a', 'crime', '.', 'so', 'start', '!']
# Sentencia original:
# ['user' 'is' 'this' 'photo' 'from' 'last' 'night' '?' '?' 'please'
#  'clarify' 'because' 'you' 'are' 'using' 'present' 'tense' '.']
# Sentencia final: 2
# ['user', 'has', 'this', 'picture', 'from', 'next', 'night', '?', '?', 'something', 'clarify', 'because', 'you', 'am', 'protesting', 'use', 'tense', '.']
#
#
# # terms modificados promedio 5.11189683860233 términos por sentencia
# Largo de sentencia promedio 16.866056572379367 términos por sentencia
# para esta ejecución se debiesen reemplazar 18015  de 21133 terminos
# Resumen de modificaciones: {'VBN': 434, 'NN': 7043, 'VBG': 560, 'JJ': 795, 'VBZ': 706, 'VB': 798, 'NNS': 1147, 'VBP': 290, 'VBD': 484, 'JJR': 20, 'JJS': 12}
# Este proceso tomó 57.22857856750488 seg
#
#
# Generando 0 nuevos ejemplos para la clase commenting
# Consultando por la clase commenting
# Entrega label 3
# No se generan ejemplos
# Resumen de modificaciones: {}
# Este proceso tomó 0.1926259994506836 seg
#
#
# Generando 1893 nuevos ejemplos para la clase support
# Consultando por la clase support
# Entrega label 0
# Sentencia original:
# ['user' 'some' 'good' 'news' '!']
# Sentencia final: 0
# ['user', 'some', 'bad', 'news', '!']
#
#
# Sentencia original:
# ['shoot' 'unarmed' 'kid' '.' 'conceal' 'evidence' '.' 'impose' 'martial'
#  'law' '.' 'hara' '##ss' 'reporters' '.' 'sm' '##ear' 'the' 'victim' '.'
#  'worst' '.' 'police' '.' 'ever' '.' 'hash' '##tag' 'hash' '##tag']
# Sentencia final: 0
# ['shootout', 'uniformed', 'assassinate', '.', 'hiding', 'witness', '.', 'apologize', 'assassinate', 'lawyer', '.', 'hara', '##ss', 'journalists', '.', 'sm', '##ear', 'the', 'horrific', '.', 'best', '.', 'authorities', '.', 'ever', '.', 'qaeda', '##tag', 'jihad', '##tag']
#
#
# Sentencia original:
# ['“' 'user' ':' 'several' 'hostages' 'freed' 'at' 'jewish' 'supermarket'
#  'in' 'paris' '.' 'photo' 'thomas' 'samson' 'hash' '##tag' 'html' 'sc'
#  '##ha' '##ut' 'gen' '##au' 'hi' '##n' '!']
# Sentencia final: 0
# ['“', 'user', ':', 'several', 'children', 'leftist', 'at', 'jew', 'france', 'in', 'photograph', '.', 'photograph', 'henry', 'carnage', 'jihad', '##tag', 'html', 'horrific', '##ha', '##ut', 'gen', '##au', 'ha', '##n', '!']
#
#
# Sentencia original:
# ['“' 'user' ':' 'breaking' 'news' ':' 'gunmen' 'take' 'hostages' 'at'
#  'sydney' 'cafe' ',' 'wave' 'islamic' 'flag' 'html' 'html']
# Sentencia final: 0
# ['“', 'user', ':', 'breaking', 'cnn', ':', 'journalists', 'assume', 'perpetrators', 'at', 'london', 'storm', ',', 'wave', 'islamic', 'fascism', 'html', 'html']
#
#
# Sentencia original:
# ['breaking' 'news' ':' 'gunmen' 'take' 'hostages' 'at' 'sydney' 'cafe' ','
#  'wave' 'islamic' 'flag' 'html' 'html']
# Sentencia final: 0
# ['leading', 'broken', ':', 'gunmen', 'impose', 'terrorists', 'at', 'hostage', 'storm', ',', 'wave', 'swiss', 'fascism', 'html', 'html']
#
#
# Sentencia original:
# ['user' 'user' 'like' 'i' 'said' 'it' "'" 's' 'directly' 'across' 'from'
#  'a' 'big' 'news' 'channel' '.']
# Sentencia final: 0
# ['user', 'user', 'like', 'left', 'was', 'it', "'", 'qaeda', 'directly', 'across', 'from', 'a', 'large', 'news', 'channels', '.']
#
#
# Sentencia original:
# ['user' 'best' 'news' 'i' 'have' 'heard' ',' 'kay' 'you' 'are' 'doing'
#  'an' 'amazing' 'job' 'thank' 'you']
# Sentencia final: 0
# ['user', 'most', 'use', 'hear', 'see', 'hear', ',', 'hear', 'you', 'are', 'disgusting', 'an', 'protecting', 'employee', 'honor', 'you']
#
#
# Sentencia original:
# ['"' 'user' ':' 'the' 'hash' '##tag' 'attack' 'suspects' 'have'
#  'reportedly' 'fired' 'shots' 'while' 'rob' 'a' 'petrol' 'station' 'html'
#  'hash' '##tag']
# Sentencia final: 0
# ['"', 'user', ':', 'the', 'qaeda', '##tag', 'attack', 'suspects', 'assume', 'reportedly', 'killed', 'gunmen', 'while', 'robbed', 'a', 'petrol', 'jihad', 'html', 'qaeda', '##tag']
#
#
# Sentencia original:
# ['we' 'can' 'see' 'people' 'coming' 'out' 'a' 'fired' '##oor' 'near' 'the'
#  'lin' '##dt' 'cafe' 'to' 'waiting' 'police' '.' 'number' '-' 'number'
#  'people' '.' 'hard' 'to' 'see' '.' 'hash' '##tag']
# Sentencia final: 0
# ['we', 'can', 'come', 'men', 'seeing', 'out', 'a', 'fired', '##oor', 'near', 'the', 'lin', '##dt', 'wait', 'to', 'driving', 'rules', '.', 'group', '-', 'number', 'children', '.', 'live', 'to', 'do', '.', 'hear', '##tag']
#
#
# # terms modificados promedio 6.9989434759640785 términos por sentencia
# Largo de sentencia promedio 19.904912836767036 términos por sentencia
# para esta ejecución se debiesen reemplazar 18167  de 21301 terminos
# Resumen de modificaciones: {'JJ': 887, 'NN': 8200, 'VB': 488, 'NNS': 1447, 'JJS': 104, 'VBG': 663, 'VBD': 398, 'VBN': 512, 'VBZ': 386, 'VBP': 152, 'JJR': 12}
# Este proceso tomó 64.05359935760498 seg
#
#
# Generando 2401 nuevos ejemplos para la clase denying
# Consultando por la clase denying
# Entrega label 1
# Sentencia original:
# ['user' 'legally' 'speaking' 'it' 'doesn' "'" 't' 'matter' '.' 'the'
#  'question' 'of' 'reasonable' 'fear' 'is' 'at' 'issue' '+' 'the' 'k'
#  '##ra' '##uts' 'were' 'definitely' 'afraid' 'of' 'my' 'grandpa' '.']
# Sentencia final: 1
# ['user', 'legally', 'speaking', 'it', 'hasn', "'", 't', 'matter', '.', 'the', 'distrust', 'of', 'plausible', 'afraid', 'is', 'at', 'update', 'area', 'the', 'k', '##ra', '##uts', 'were', 'definitely', 'afraid', 'of', 'my', 'grandpa', '.']
#
#
# Sentencia original:
# ['user' 'user' 'user' 'user' 'what' 'other' 'info' 'do' 'they' 'have'
#  'ready' 'to' 'release' '?' 'all' 'they' 'have' 'said' 'is' 'this' 'is'
#  'why' 'we' 'approached' 'him' '.']
# Sentencia final: 1
# ['user', 'user', 'user', 'user', 'what', 'different', 'work', 'be', 'they', 'get', 'free', 'to', 'release', '?', 'all', 'they', 'be', 'had', 'has', 'this', 'has', 'why', 'we', 'approached', 'him', '.']
#
#
# Sentencia original:
# ['user' 'user' '"' 'grease' 'my' 'palm' 'with' 'silver' 'lo' '##vie' '.'
#  '"' 'the' 'disgrace' '##ful' 'prick' '.' 'run' "'" 'em' 'outta' 'town'
#  'folks' '.']
# Sentencia final: 1
# ['user', 'user', '"', 'grease', 'my', 'palm', 'with', 'silver', 'life', '##vie', '.', '"', 'the', 'shame', '##ful', 'leftist', '.', 'run', "'", 'em', 'outta', 'heartbreak', 'folks', '.']
#
#
# Sentencia original:
# ['user' 'user' 'it' "'" 's' 'not' 'a' 'matter' 'of' 'criticism' ',' 'it'
#  "'" 's' 'insulting' 'and' 'dem' '##ean' '##ing' 'and' 'offensive']
# Sentencia final: 1
# ['user', 'user', 'it', "'", 'll', 'not', 'a', 'discussion', 'of', 'discussion', ',', 'it', "'", 'insult', 'murdering', 'and', 'leftist', '##ean', '##ing', 'and', 'offensive']
#
#
# Sentencia original:
# ['user' 'of' 'course' ',' 'however' 'please' 'do' 'not' 'try' 'and'
#  'compare' 'it' 'to' 'hundreds' 'of' 'years' 'of' 'systemic' 'oppression'
#  'of' 'a' 'whole' 'people']
# Sentencia final: 1
# ['user', 'of', 'course', ',', 'however', 'help', 'go', 'not', 'try', 'and', 'compare', 'it', 'to', 'days', 'of', 'years', 'of', 'systemic', 'oppression', 'of', 'a', 'entire', 'men']
#
#
# Sentencia original:
# ['user' 'user' 'not' 'confirmed']
# Sentencia final: 1
# ['user', 'user', 'not', 'based']
#
#
# Sentencia original:
# ['heartbreak' 'for' 'hash' '##tag' 'and' 'canada' '.' '“' 'user' ':'
#  'soldier' 'killed' 'in' 'canada' 'shooting' 'was' 'a' 'young' 'res'
#  '##er' '##vis' '##t' 'with' 'a' 'son' 'html']
# Sentencia final: 1
# ['murder', 'for', 'qaeda', '##tag', 'and', 'canada', '.', '“', 'user', ':', 'employee', 'killed', 'in', 'canada', 'being', 'was', 'a', 'new', 'res', '##er', '##vis', '##t', 'with', 'a', 'daughter', 'html']
#
#
# Sentencia original:
# ['user' '"' 'may' 'be' '"' 'really' '?' 'forehead' 'smack']
# Sentencia final: 1
# ['user', '"', 'may', 'have', '"', 'really', '?', 'forehead', 'stupidity']
#
#
# Sentencia original:
# ['user' 'user' 'user' 'i' "'" 'm' 'not' 'watching' 'it' ',' 'but' 'it'
#  'sounds' 'as' 'if' 'it' 'is' 'being' 'treated' 'as' 'sport' '.']
# Sentencia final: 1
# ['user', 'user', 'user', 'employee', "'", 'watch', 'not', 'listening', 'it', ',', 'but', 'it', 'looks', 'as', 'if', 'it', 'has', 'being', 'fascinated', 'as', 'treat', '.']
#
#
# # terms modificados promedio 6.286963765097876 términos por sentencia
# Largo de sentencia promedio 19.62390670553936 términos por sentencia
# para esta ejecución se debiesen reemplazar 21439  de 25043 terminos
# Resumen de modificaciones: {'NN': 8790, 'JJ': 1247, 'VB': 912, 'VBD': 496, 'VBZ': 689, 'VBG': 725, 'NNS': 1435, 'VBN': 493, 'VBP': 247, 'JJR': 34, 'JJS': 27}
# Este proceso tomó 69.17215251922607 seg

# %%
TOPN=1
prob=0.85

fs_macro={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
fs_none={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
accs={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}
confusions={'cnn1':[], 'cnn2':[], 'rnn1':[],'rnn2':[],'rnn3':[]}

for i in range(1,6):
    print ("----------------------- Entrenando running ", i,"-----------------------")
    macro_augmented=np.load('../../../new_data_augmented/stance/Aumento_'+str(i)+'-run_'+str(prob)+'_app1_Top'+str(TOPN)+'.npy', allow_pickle=True)
    
    ids_train=macro_augmented[:,0]
    tws_train=macro_augmented[:,1]
    labels_train=macro_augmented[:,2]
    class_weights= compute_class_weight('balanced', np.unique(labels_train), labels_train)
    print ("Pesos de clases:", class_weights)
    
    etiq=labels_train.copy()
    sentences = tws_train
    n_labels = np.array(etiq)

    input_ids = []
    for sent in sentences:
        encoded_sent = tokenizer_loaded.encode(list(sent),add_special_tokens = False)    
        input_ids.append(encoded_sent)
    input_ids = pad_sequences(input_ids,maxlen=MAX_LEN,dtype="long",value=0, truncating="post", padding="post")
    y_train=to_categorical(n_labels,num_classes=4)
    shape=np.asarray(input_ids).shape
    x_train=np.zeros((shape[0], shape[1], 768))
    j=0
    for in_id in input_ids:
        x_train[j]=M_BERT_space[in_id]
        j+=1

    ###########################################################
    ############################################################
    ############################################################
    
    cnn1=create_ccn1(x_train.shape[1:])
    trained =train_model(cnn1, x_train, y_train, x_val, y_val, class_weights, e=30, BS=32, verb=0, focal=True)
    trained.save('../../../new_data_augmented/stance_baselines/0.85/cnn1_'+str(i)+'-exec_app1_Top_'+str(TOPN)+'.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(trained, x_train, x_val, x_test, etiq, etiq_v, etiq_t, 'cnn1')
    fs_macro['cnn1'].append(f1_ma_t)
    fs_none['cnn1'].append(f1_t)
    accs['cnn1'].append(acc_t)
    confusions['cnn1'].append(matriz_t)
    
    cnn2=create_cnn2(x_train.shape[1:])
    trained =train_model(cnn2, x_train, y_train, x_val, y_val, class_weights, e=30, BS=32, verb=0, focal=True)
    trained.save('../../../new_data_augmented/stance_baselines/0.85/cnn2_'+str(i)+'-exec_app1_Top_'+str(TOPN)+'.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(trained, x_train, x_val, x_test, etiq, etiq_v, etiq_t, 'cnn2')
    fs_macro['cnn2'].append(f1_ma_t)
    fs_none['cnn2'].append(f1_t)
    accs['cnn2'].append(acc_t)
    confusions['cnn2'].append(matriz_t)
    
    rnn1=create_complex_GRU_2(128,64,"adam",x_train.shape[1:])
    trained =train_model(rnn1, x_train, y_train, x_val, y_val, class_weights, e=30, BS=32, verb=0, focal=True)
    trained.save('../../../new_data_augmented/stance_baselines/0.85/rnn1_'+str(i)+'-exec_app1_Top_'+str(TOPN)+'.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(trained, x_train, x_val, x_test, etiq, etiq_v, etiq_t, 'rnn1')
    fs_macro['rnn1'].append(f1_ma_t)
    fs_none['rnn1'].append(f1_t)
    accs['rnn1'].append(acc_t)
    confusions['rnn1'].append(matriz_t)
    
    rnn2=create_complex_GRU_3(256,128,64,"adam",x_train.shape[1:])
    trained =train_model(rnn2, x_train, y_train, x_val, y_val, class_weights, e=30, BS=32, verb=0, focal=True)
    trained.save('../../../new_data_augmented/stance_baselines/0.85/rnn2_'+str(i)+'-exec_app1_Top_'+str(TOPN)+'.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(trained, x_train, x_val, x_test, etiq, etiq_v, etiq_t, 'rnn2')
    fs_macro['rnn2'].append(f1_ma_t)
    fs_none['rnn2'].append(f1_t)
    accs['rnn2'].append(acc_t)
    confusions['rnn2'].append(matriz_t)
    
    rnn3=create_complex_GRU_3(256,128,64,"adam",x_train.shape[1:])
    trained =train_model(rnn3, x_train, y_train, x_val, y_val, class_weights, e=30, BS=32, verb=0, focal=False)
    trained.save('../../../new_data_augmented/stance_baselines/0.85/rnn3_'+str(i)+'-exec_app1_Top_'+str(TOPN)+'.h5')
    f1_ma_t, f1_t, acc_t, matriz_t = predict_data(trained, x_train, x_val, x_test, etiq, etiq_v, etiq_t, 'rnn3')
    fs_macro['rnn3'].append(f1_ma_t)
    fs_none['rnn3'].append(f1_t)
    accs['rnn3'].append(acc_t)
    confusions['rnn3'].append(matriz_t)
# Out:
# ----------------------- Entrenando running  1 -----------------------
# Pesos de clases: [1. 1. 1. 1.]
#
# Accuracy sobre Train cnn1 : 0.9709217264081931
# F1-score None sobre Train cnn1 : [0.95083193 0.990606   0.99615455 0.94656489]
# F1-score macro sobre Train cnn1 : 0.9710393429840021
#
# Accuracy sobre Val cnn1 : 0.6014234875444839
# F1-score None sobre Val cnn1 : [0.55737705 0.25       0.66666667 0.65517241]
# F1-score macro sobre Val cnn1 : 0.5323040324100246
#
# Accuracy sobre Test cnn1 : 0.5377081292850147
# F1-score None sobre Test cnn1 : [0.12794613 0.2173913  0.48623853 0.6805659 ]
# F1-score macro sobre Test cnn1 : 0.3780354654122549
#
# Accuracy sobre Train cnn2 : 0.9732077542062911
# F1-score None sobre Train cnn2 : [0.95712971 0.9941349  0.99192068 0.94995483]
# F1-score macro sobre Train cnn2 : 0.9732850301947692
#
# Accuracy sobre Val cnn2 : 0.6405693950177936
# F1-score None sobre Val cnn2 : [0.55681818 0.26086957 0.72727273 0.7012987 ]
# F1-score macro sobre Val cnn2 : 0.5615647939017504
#
# Accuracy sobre Test cnn2 : 0.604309500489716
# F1-score None sobre Test cnn2 : [0.11278195 0.22556391 0.52736318 0.740638  ]
# F1-score macro sobre Test cnn2 : 0.4015867628787953
#
# Accuracy sobre Train rnn1 : 0.9783284564740308
# F1-score None sobre Train rnn1 : [0.97163375 0.98570136 0.99114391 0.96471906]
# F1-score macro sobre Train rnn1 : 0.9782995200810636
#
# Accuracy sobre Val rnn1 : 0.4875444839857651
# F1-score None sobre Val rnn1 : [0.50537634 0.17241379 0.57692308 0.52631579]
# F1-score macro sobre Val rnn1 : 0.44525725089655777
#
# Accuracy sobre Test rnn1 : 0.49853085210577863
# F1-score None sobre Test rnn1 : [0.15864023 0.22707424 0.43636364 0.64710425]
# F1-score macro sobre Test rnn1 : 0.3672955864761598
#
# Accuracy sobre Train rnn2 : 0.9754023408924652
# F1-score None sobre Train rnn2 : [0.9658166  0.98529679 0.99559795 0.95466369]
# F1-score macro sobre Train rnn2 : 0.9753437574854751
#
# Accuracy sobre Val rnn2 : 0.5373665480427047
# F1-score None sobre Val rnn2 : [0.56818182 0.15686275 0.5        0.59498208]
# F1-score macro sobre Val rnn2 : 0.455006660533226
#
# Accuracy sobre Test rnn2 : 0.4789422135161606
# F1-score None sobre Test rnn2 : [0.15841584 0.14693878 0.4057971  0.62937063]
# F1-score macro sobre Test rnn2 : 0.3351305869785668
#
# Accuracy sobre Train rnn3 : 0.9757681053401609
# F1-score None sobre Train rnn3 : [0.97024023 0.9731657  0.98893524 0.97065297]
# F1-score macro sobre Train rnn3 : 0.9757485354893236
#
# Accuracy sobre Val rnn3 : 0.501779359430605
# F1-score None sobre Val rnn3 : [0.5258216  0.         0.50704225 0.51937984]
# F1-score macro sobre Val rnn3 : 0.3880609236816247
#
# Accuracy sobre Test rnn3 : 0.4622918707149853
# F1-score None sobre Test rnn3 : [0.15158924 0.13114754 0.40458015 0.60848679]
# F1-score macro sobre Test rnn3 : 0.32395093128517427
# ----------------------- Entrenando running  2 -----------------------
# Pesos de clases: [1. 1. 1. 1.]
#
# Accuracy sobre Train cnn1 : 0.9717446964155084
# F1-score None sobre Train cnn1 : [0.95376147 0.99412844 0.99266324 0.94673913]
# F1-score macro sobre Train cnn1 : 0.9718230703845813
#
# Accuracy sobre Val cnn1 : 0.5871886120996441
# F1-score None sobre Val cnn1 : [0.53631285 0.26315789 0.65384615 0.64846416]
# F1-score macro sobre Val cnn1 : 0.5254452653918832
#
# Accuracy sobre Test cnn1 : 0.5572967678746327
# F1-score None sobre Test cnn1 : [0.10612245 0.18378378 0.4549763  0.70092791]
# F1-score macro sobre Test cnn1 : 0.3614526111793998
#
# Accuracy sobre Train cnn2 : 0.9754023408924652
# F1-score None sobre Train cnn2 : [0.9631913  0.99267399 0.99324201 0.95241608]
# F1-score macro sobre Train cnn2 : 0.9753808452242346
#
# Accuracy sobre Val cnn2 : 0.5373665480427047
# F1-score None sobre Val cnn2 : [0.51190476 0.21052632 0.6440678  0.5971223 ]
# F1-score macro sobre Val cnn2 : 0.4909052941156695
#
# Accuracy sobre Test cnn2 : 0.555337904015671
# F1-score None sobre Test cnn2 : [0.11666667 0.2283105  0.52678571 0.69021339]
# F1-score macro sobre Test cnn2 : 0.3904940688589083
#
# Accuracy sobre Train rnn1 : 0.9006949524506218
# F1-score None sobre Train rnn1 : [0.84487476 0.86723973 0.99101082 0.89755011]
# F1-score macro sobre Train rnn1 : 0.9001688577094098
#
# Accuracy sobre Val rnn1 : 0.3701067615658363
# F1-score None sobre Val rnn1 : [0.22916667 0.09459459 0.55384615 0.53754941]
# F1-score macro sobre Val rnn1 : 0.3537892055555099
#
# Accuracy sobre Test rnn1 : 0.4926542605288932
# F1-score None sobre Test rnn1 : [0.11538462 0.17446809 0.50892857 0.6414791 ]
# F1-score macro sobre Test rnn1 : 0.3600650928995066
#
# Accuracy sobre Train rnn2 : 0.8942026335040234
# F1-score None sobre Train rnn2 : [0.82152853 0.89259441 0.96831384 0.88636364]
# F1-score macro sobre Train rnn2 : 0.8922001036290502
#
# Accuracy sobre Val rnn2 : 0.4483985765124555
# F1-score None sobre Val rnn2 : [0.42016807 0.12389381 0.26086957 0.61971831]
# F1-score macro sobre Val rnn2 : 0.35616243690329286
#
# Accuracy sobre Test rnn2 : 0.5093046033300686
# F1-score None sobre Test rnn2 : [0.07874016 0.15656566 0.31292517 0.67201166]
# F1-score macro sobre Test rnn2 : 0.30506066148039473
#
# Accuracy sobre Train rnn3 : 0.9279444038039503
# F1-score None sobre Train rnn3 : [0.87787611 0.96813125 0.98966408 0.88006483]
# F1-score macro sobre Train rnn3 : 0.9289340662920029
#
# Accuracy sobre Val rnn3 : 0.49110320284697506
# F1-score None sobre Val rnn3 : [0.49781659 0.09090909 0.50847458 0.51587302]
# F1-score macro sobre Val rnn3 : 0.40326831923493905
#
# Accuracy sobre Test rnn3 : 0.38001958863858964
# F1-score None sobre Test rnn3 : [0.11208406 0.11023622 0.44919786 0.5306828 ]
# F1-score macro sobre Test rnn3 : 0.3005502362070037
# ----------------------- Entrenando running  3 -----------------------
# Pesos de clases: [1. 1. 1. 1.]
#
# Accuracy sobre Train cnn1 : 0.9757681053401609
# F1-score None sobre Train cnn1 : [0.96144623 0.99115696 0.99450147 0.95634992]
# F1-score macro sobre Train cnn1 : 0.9758636442415978
#
# Accuracy sobre Val cnn1 : 0.6298932384341637
# F1-score None sobre Val cnn1 : [0.5952381  0.08       0.60606061 0.69966997]
# F1-score macro sobre Val cnn1 : 0.49524216707385027
#
# Accuracy sobre Test cnn1 : 0.604309500489716
# F1-score None sobre Test cnn1 : [0.12727273 0.21333333 0.504      0.73699015]
# F1-score macro sobre Test cnn1 : 0.3953990538294335
#
# Accuracy sobre Train cnn2 : 0.9687271397220191
# F1-score None sobre Train cnn2 : [0.95157299 0.99207957 0.99209704 0.93937126]
# F1-score macro sobre Train cnn2 : 0.9687802162815671
#
# Accuracy sobre Val cnn2 : 0.5551601423487544
# F1-score None sobre Val cnn2 : [0.51456311 0.33333333 0.65384615 0.59124088]
# F1-score macro sobre Val cnn2 : 0.5232458674720031
#
# Accuracy sobre Test cnn2 : 0.49167482859941236
# F1-score None sobre Test cnn2 : [0.1216545  0.18181818 0.53968254 0.63975155]
# F1-score macro sobre Test cnn2 : 0.37072669387807444
#
# Accuracy sobre Train rnn1 : 0.9241038771031456
# F1-score None sobre Train rnn1 : [0.84848485 0.98289963 0.99109577 0.87189354]
# F1-score macro sobre Train rnn1 : 0.9235934453109225
#
# Accuracy sobre Val rnn1 : 0.597864768683274
# F1-score None sobre Val rnn1 : [0.47619048 0.16666667 0.49350649 0.69850746]
# F1-score macro sobre Val rnn1 : 0.4587177747625508
#
# Accuracy sobre Test rnn1 : 0.6787463271302644
# F1-score None sobre Test rnn1 : [0.18045113 0.12727273 0.4797048  0.79712042]
# F1-score macro sobre Test rnn1 : 0.3961372677471035
#
# Accuracy sobre Train rnn2 : 0.9756766642282371
# F1-score None sobre Train rnn2 : [0.96414639 0.98873956 0.99301984 0.95685142]
# F1-score macro sobre Train rnn2 : 0.9756892997994319
#
# Accuracy sobre Val rnn2 : 0.49110320284697506
# F1-score None sobre Val rnn2 : [0.47953216 0.10344828 0.44067797 0.59124088]
# F1-score macro sobre Val rnn2 : 0.4037248204047157
#
# Accuracy sobre Test rnn2 : 0.5063663075416258
# F1-score None sobre Test rnn2 : [0.15438596 0.13559322 0.47619048 0.65446224]
# F1-score macro sobre Test rnn2 : 0.3551579760011673
#
# Accuracy sobre Train rnn3 : 0.9545537673738113
# F1-score None sobre Train rnn3 : [0.9326324  0.98370156 0.96827928 0.93196913]
# F1-score macro sobre Train rnn3 : 0.9541455915148951
#
# Accuracy sobre Val rnn3 : 0.5409252669039146
# F1-score None sobre Val rnn3 : [0.53623188 0.15384615 0.48888889 0.63120567]
# F1-score macro sobre Val rnn3 : 0.45254315013796975
#
# Accuracy sobre Test rnn3 : 0.5631733594515181
# F1-score None sobre Test rnn3 : [0.10687023 0.15720524 0.43636364 0.70710059]
# F1-score macro sobre Test rnn3 : 0.3518849243154797
# ----------------------- Entrenando running  4 -----------------------
# Pesos de clases: [1. 1. 1. 1.]
#
# Accuracy sobre Train cnn1 : 0.9773226042428675
# F1-score None sobre Train cnn1 : [0.96474886 0.99304793 0.99360029 0.95789088]
# F1-score macro sobre Train cnn1 : 0.977321991535224
#
# Accuracy sobre Val cnn1 : 0.5907473309608541
# F1-score None sobre Val cnn1 : [0.56441718 0.22222222 0.56666667 0.66666667]
# F1-score macro sobre Val cnn1 : 0.5049931833674165
#
# Accuracy sobre Test cnn1 : 0.5778648383937316
# F1-score None sobre Test cnn1 : [0.10743802 0.23036649 0.55411255 0.712627  ]
# F1-score macro sobre Test cnn1 : 0.4011360146084851
#
# Accuracy sobre Train cnn2 : 0.9786027798098025
# F1-score None sobre Train cnn2 : [0.96705319 0.99284797 0.99486615 0.95986985]
# F1-score macro sobre Train cnn2 : 0.9786592921195365
#
# Accuracy sobre Val cnn2 : 0.5907473309608541
# F1-score None sobre Val cnn2 : [0.56179775 0.22222222 0.58181818 0.6552901 ]
# F1-score macro sobre Val cnn2 : 0.5052820648096178
#
# Accuracy sobre Test cnn2 : 0.5719882468168462
# F1-score None sobre Test cnn2 : [0.11952191 0.16216216 0.51741294 0.71459075]
# F1-score macro sobre Test cnn2 : 0.3784219392917759
#
# Accuracy sobre Train rnn1 : 0.820683979517191
# F1-score None sobre Train rnn1 : [0.66731612 0.76810575 0.99214612 0.83320463]
# F1-score macro sobre Train rnn1 : 0.8151931565814158
#
# Accuracy sobre Val rnn1 : 0.3096085409252669
# F1-score None sobre Val rnn1 : [0.1686747  0.11111111 0.59701493 0.43103448]
# F1-score macro sobre Val rnn1 : 0.3269588045095117
#
# Accuracy sobre Test rnn1 : 0.40940254652301666
# F1-score None sobre Test rnn1 : [0.02439024 0.16666667 0.48372093 0.54234388]
# F1-score macro sobre Test rnn1 : 0.30428043111572817
#
# Accuracy sobre Train rnn2 : 0.9258412582297001
# F1-score None sobre Train rnn2 : [0.90114297 0.94638428 0.98376623 0.8757377 ]
# F1-score macro sobre Train rnn2 : 0.9267577970550834
#
# Accuracy sobre Val rnn2 : 0.6014234875444839
# F1-score None sobre Val rnn2 : [0.59060403 0.08333333 0.49438202 0.68      ]
# F1-score macro sobre Val rnn2 : 0.4620798456627203
#
# Accuracy sobre Test rnn2 : 0.6150832517140059
# F1-score None sobre Test rnn2 : [0.14666667 0.07017544 0.41642229 0.75434934]
# F1-score macro sobre Test rnn2 : 0.34690343288841863
#
# Accuracy sobre Train rnn3 : 0.9726591075347476
# F1-score None sobre Train rnn3 : [0.95181356 0.99189388 0.99688245 0.95041635]
# F1-score macro sobre Train rnn3 : 0.9727515617837938
#
# Accuracy sobre Val rnn3 : 0.5195729537366548
# F1-score None sobre Val rnn3 : [0.53153153 0.24       0.49122807 0.54263566]
# F1-score macro sobre Val rnn3 : 0.4513488151554247
#
# Accuracy sobre Test rnn3 : 0.455435847208619
# F1-score None sobre Test rnn3 : [0.11816193 0.14814815 0.46153846 0.61035857]
# F1-score macro sobre Test rnn3 : 0.33455177525635305
# ----------------------- Entrenando running  5 -----------------------
# Pesos de clases: [1. 1. 1. 1.]
#
# Accuracy sobre Train cnn1 : 0.9645208485735186
# F1-score None sobre Train cnn1 : [0.95365897 0.97833396 0.99247016 0.93435449]
# F1-score macro sobre Train cnn1 : 0.9647043926966942
#
# Accuracy sobre Val cnn1 : 0.5409252669039146
# F1-score None sobre Val cnn1 : [0.51207729 0.17391304 0.56603774 0.58781362]
# F1-score macro sobre Val cnn1 : 0.45996042352124805
#
# Accuracy sobre Test cnn1 : 0.5386875612144956
# F1-score None sobre Test cnn1 : [0.14130435 0.09090909 0.47120419 0.69045885]
# F1-score macro sobre Test cnn1 : 0.34846911911302614
#
# Accuracy sobre Train cnn2 : 0.9744879297732261
# F1-score None sobre Train cnn2 : [0.96164978 0.99171423 0.99245352 0.95255474]
# F1-score macro sobre Train cnn2 : 0.9745930713278023
#
# Accuracy sobre Val cnn2 : 0.5587188612099644
# F1-score None sobre Val cnn2 : [0.52040816 0.33333333 0.53658537 0.61591696]
# F1-score macro sobre Val cnn2 : 0.5015609543673998
#
# Accuracy sobre Test cnn2 : 0.544564152791381
# F1-score None sobre Test cnn2 : [0.16167665 0.19230769 0.39263804 0.69402448]
# F1-score macro sobre Test cnn2 : 0.3601617134664629
#
# Accuracy sobre Train rnn1 : 0.7117776152158011
# F1-score None sobre Train rnn1 : [0.63735236 0.83533629 0.94773119 0.35946349]
# F1-score macro sobre Train rnn1 : 0.694970829451347
#
# Accuracy sobre Val rnn1 : 0.3096085409252669
# F1-score None sobre Val rnn1 : [0.42763158 0.         0.4        0.13612565]
# F1-score macro sobre Val rnn1 : 0.24093930834940755
#
# Accuracy sobre Test rnn1 : 0.19196865817825662
# F1-score None sobre Test rnn1 : [0.13441483 0.09803922 0.34444444 0.22742475]
# F1-score macro sobre Test rnn1 : 0.20108081031901462
#
# Accuracy sobre Train rnn2 : 0.972201901975128
# F1-score None sobre Train rnn2 : [0.95065727 0.99394384 0.99524506 0.94917631]
# F1-score macro sobre Train rnn2 : 0.972255619695288
#
# Accuracy sobre Val rnn2 : 0.5907473309608541
# F1-score None sobre Val rnn2 : [0.56097561 0.06060606 0.5        0.68686869]
# F1-score macro sobre Val rnn2 : 0.45211258930771125
#
# Accuracy sobre Test rnn2 : 0.5964740450538688
# F1-score None sobre Test rnn2 : [0.16585366 0.09271523 0.45559846 0.73721093]
# F1-score macro sobre Test rnn2 : 0.3628445694870871
#
# Accuracy sobre Train rnn3 : 0.9869239209948792
# F1-score None sobre Train rnn3 : [0.98497067 0.9883594  0.99522234 0.97918188]
# F1-score macro sobre Train rnn3 : 0.9869335768049305
#
# Accuracy sobre Val rnn3 : 0.5409252669039146
# F1-score None sobre Val rnn3 : [0.55813953 0.1509434  0.42857143 0.62633452]
# F1-score macro sobre Val rnn3 : 0.4409972198136296
#
# Accuracy sobre Test rnn3 : 0.5690499510284035
# F1-score None sobre Test rnn3 : [0.1147541  0.19469027 0.45882353 0.72182596]
# F1-score macro sobre Test rnn3 : 0.3725234640423186

# %%
for key in fs_none.keys():
    temp=np.zeros(4)
    for result in fs_none[key]:
        temp+=result
    print ("(0.85) app1 F1-score promedio para",key,":" ,temp/5)

print ("")
for key in fs_macro.keys():
    temp=np.sum(fs_macro[key])
    print ("(0.85) app1 F1-score macro promedio para",key,":" ,temp/5, "desvest: ",np.std(fs_macro[key]))

print ("")
for key in accs.keys():
    temp=np.sum(accs[key])
    print ("(0.85) app1 Accuracy promedio para",key,":" ,temp/5)
# Out:
# (0.85) app1 F1-score promedio para cnn1 : [0.12201673 0.1871568  0.49410632 0.70431396]
# (0.85) app1 F1-score promedio para cnn2 : [0.12646034 0.19803249 0.50077648 0.69584363]
# (0.85) app1 F1-score promedio para rnn1 : [0.12265621 0.15870419 0.45063248 0.57109448]
# (0.85) app1 F1-score promedio para rnn2 : [0.14081246 0.12039766 0.4133867  0.68948096]
# (0.85) app1 F1-score promedio para rnn3 : [0.12069191 0.14828548 0.44210073 0.63569094]
#
# (0.85) app1 F1-score macro promedio para cnn1 : 0.37689845282851986 desvest:  0.019888818345013912
# (0.85) app1 F1-score macro promedio para cnn2 : 0.38027823567480334 desvest:  0.014544887981443369
# (0.85) app1 F1-score macro promedio para rnn1 : 0.32577183771150253 desvest:  0.06908151080660305
# (0.85) app1 F1-score macro promedio para rnn2 : 0.3410194453671269 desvest:  0.020191920127740733
# (0.85) app1 F1-score macro promedio para rnn3 : 0.33669226622126586 desvest:  0.024445290950755583
#
# (0.85) app1 Accuracy promedio para cnn1 : 0.5631733594515181
# (0.85) app1 Accuracy promedio para cnn2 : 0.5535749265426053
# (0.85) app1 Accuracy promedio para rnn1 : 0.45426052889324187
# (0.85) app1 Accuracy promedio para rnn2 : 0.5412340842311459
# (0.85) app1 Accuracy promedio para rnn3 : 0.48599412340842313

# %%
for key in confusions.keys():
    temp=np.sum(confusions[key], axis=0)/5.0
    plot_confusion_matrix(temp, ['S','D','Q','C'], "(0.85) classic - Confusion Matrix "+str(key), cmap='Purples')
